# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph Building and Controller Allocation**

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
# Out:
# Enter the number of controllers to allocate: 5
# Graph with 34 nodes and 46 edges
#
# Controllers:
# [14, 28, 11, 2, 6]
#
# Cluster set for each controller:
# [[4, 10, 14, 15, 16, 17, 18, 19, 22, 23], [13, 26, 27, 28, 29], [7, 9, 11, 12, 30, 32, 33], [0, 2, 3, 5, 8, 21, 24, 25, 31], [1, 6, 20]]
#
# Cluster map for each controller:
# {14: [4, 10, 15, 16, 17, 18, 19, 22, 23], 28: [13, 26, 27, 29], 11: [7, 9, 12, 30, 32, 33], 2: [0, 3, 5, 8, 21, 24, 25, 31], 6: [1, 20]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1):
, (8, 14): 4, (8, 15): 3, (8, 16): 5, (8, 17): 3, (8, 18): 5, (8, 19): 2, (8, 20): 4, (8, 21): 4, (8, 22): 5, (8, 23): 4, (8, 24): 7, (8, 25): 6, (8, 26): 7, (8, 27): 7, (8, 28): 6, (8, 29): 5, (8, 30): 4, (8, 31): 6, (8, 32): 7, (8, 33): 8, (9, 0): 2, (9, 1): 4, (9, 2): 3, (9, 3): 2, (9, 4): 3, (9, 5): 2, (9, 6): 3, (9, 7): 1, (9, 8): 1, (9, 9): 0, (9, 10): 3, (9, 11): 3, (9, 12): 4, (9, 13): 5, (9, 14): 3, (9, 15): 4, (9, 16): 4, (9, 17): 2, (9, 18): 4, (9, 19): 1, (9, 20): 2, (9, 21): 2, (9, 22): 4, (9, 23): 3, (9, 24): 5, (9, 25): 4, (9, 26): 5, (9, 27): 5, (9, 28): 4, (9, 29): 3, (9, 30): 2, (9, 31): 4, (9, 32): 5, (9,  ...
# [[4, 10, 14, 15, 16, 17, 18, 19, 22, 23], [13, 26, 27, 28, 29], [7, 9, 11, 12, 30, 32, 33], [0, 2, 3, 5, 8, 21, 24, 25, 31], [1, 6, 20]]
# [[4, 10, 14, 15, 16, 17, 18, 19, 22, 23], [13, 26, 27, 28, 29], [7, 9, 11, 12, 30, 32, 33], [0, 2, 3, 5, 8, 21, 24, 25, 31], [1, 6, 20]]

# %% [markdown]
# # **Switch Migration Design**

# %% [markdown]
# Some **questions (with answers after discussion)** regarding the cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously - Yes
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool? - Yes

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions(with answers after discussion)** regarding the cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).
#
# We have calcuated hop count using the **Floyd Warshall** algorithm. The hop count is the number of hops involved in the shortest distance between the 2 nodes.

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# [[15, 16, 17, 24, 27, 31], [13, 22, 21, 8, 3, 25, 4], [12, 32, 33, 20, 19, 18, 7], [10, 23, 29, 0, 30, 1], [26, 9, 5]]
# 25
# (6, 14, [4])
# [[15, 16, 17, 24, 27, 31], [13, 22, 21, 8, 3, 25, 4], [12, 32, 33, 20, 19, 18, 7], [10, 23, 29, 0, 30, 1], [26, 9, 5]]
# 4
# At time step 850 the number of switch migrated are : 9
# The migrated switches are [25, 4, 30, 30, 1, 4, 30, 25, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 851
# {14: {15: 1465.88877525, 16: 2821.631336, 17: 6774.112149, 24: 69218.49070000001, 27: 111608.84768333333, 31: 133933.16664}, 28: {13: 1859.110414, 22: 83061.43272000001, 21: 83061.09036, 8: 85640.91381666667, 3: 59246.54216666667, 25: 133930.84414, 4: 155641.1687}, 11: {12: 7723.0, 32: 3856.5854159999994, 33: 2575.682302, 20: 69218.11281666667, 19: 69217.32778333333, 18: 138436.98113333332, 7: 334832.8302}, 2: {10: 98907.8691, 23: 138435.02516666666, 29: 223222.94096666668, 0: 207653.5, 30: 334832.515, 1: 105820.83644000001}, 6: {26: 111611.63193333334, 9: 196815.95586666666, 5: 102008.0934}}
# {(2, 6), (28, 11), (2, 11), (14, 6), (28, 14), (11, 14), (2, 14), (28, 6), (11, 
 7]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# 11 :	 0.12125235560293472
# 2 :	 0.12942518747622228
# 6 :	 0.12277367542331753
# Switches in the controller 6 : [32, 1, 9, 13, 31, 7]
# Switch selected is : 7
# The target controller set for 2 is : [18, 19, 23, 8, 4, 29, 15]
# The mean load ratio is : 0.10377766399699173
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07545401827979545
# 28 :	 0.0699830832026886
# 11 :	 0.12125235560293472
# 2 :	 0.158511162988908
# 6 :	 0.0936876999106318
# Switches in the controller 11 : [21, 22, 25, 16, 5, 26]
# Switch selected is : 16
# The target controller set for 2 is : [18, 19, 23, 8, 4, 29, 15, 7]
# The mean load ratio is : 0.10377766399699173
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07545401827979545
# 28 :	 0.0699830832026886
# 11 :	 0.12092457043379519
# 2 :	 0.15883894815804753
# 6 :	 0.0936876999106318
# Switches in the controller 11 : [21, 22, 25, 5, 26]
# Switch selected is : 26
# The target controller set for 6 is : [32, 1, 9, 13, 31]
# The mean load ratio is : 0.10377766399699173
#
# At time step 938 the number of switch migrated are : 9
# The migrated switches are [33, 20, 33, 29, 15, 20, 7, 16, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 939
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07336680156212977
# 28 :	 0.08189542186680683
# 11 :	 0.09430561198787174
# 2 :	 0.16130048749702902
# 6 :	 0.12308700843361711
# Switches in the controller 2 : [18, 19, 23, 8, 4, 29, 15, 7, 16]
# Switch selected is : 8
# The target controller set for 11 is : [21, 22, 25, 5]
# The mean load ratio is : 0.10679106626949089
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07336680156212977
# 28 :	 0.08189542186680683
# 11 :	 0.11869605290317035
# 2 :	 0.1369100465817304
# 6 :	 0.12308700843361711
# Switches in the controller 2 : [18, 19, 23, 4, 29, 15, 7, 16]
# Switch selected is : 7
# The target controller set for 6 is : [32, 1, 9, 13, 31, 26]
# The mean load ratio is : 0.10679106626949089
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07336680156212977
# 28 :	 0.08189542186680683
# 11 :	 0.11869605290317035
# 2 :	 0.10439351626713145
# 6 :	 0.15560353874821606
# Switches in the controller 6 : [32, 1, 9, 13, 31, 26, 7]
# Switch selected is : 32
# The target controller set for 2 is : [18, 19, 23, 4, 29, 15, 16]
# The mean load ratio is : 0.10679106626949089
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07336680156212977
# 28 :	 0.08189542186680683
# 11 :	 0.11869605290317035
# 2 :	 0.10472571001711789
# 6 :	 0.15527134499822962
# Switches in the controller 6 : [1, 9, 13, 31, 26, 7]
# Switch selected is : 1
# The target controller set for 2 is : [18, 19, 23, 4, 29, 15, 16, 32]
# The mean load ratio is : 0.10679106626949089
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07336680156212977
# 28 :	 0.08189542186680683
# 11 :	 0.11869605290317035
# 2 :	 0.13970562687630786
# 6 :	 0.12029142813903965
# Switches in the controller 6 : [9, 13, 31, 26, 7]
# Switch selected is : 7
# The target controller set for 11 is : [21, 22, 25, 5, 8]
# The mean load ratio is : 0.10679106626949089
#
# At time step 939 the number of switch migrated are : 5
# The migrated switches are [8, 7, 32, 1, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 940
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.06122727261924715
# 28 :	 0.05873520040355257
# 11 :	 0.12538564029774385
# 2 :	 0.1576662553095475
# 6 :	 0.05991658792973196
# Switches in the controller 11 : [21, 22, 25, 5, 8, 7]
# Switch selected is : 22
# The target controller set for 14 is : [17, 10, 0, 27]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07958914346516671
# 28 :	 0.05873520040355257
# 11 :	 0.10702376945182429
# 2 :	 0.1576662553095475
# 6 :	 0.05991658792973196
# Switches in the controller 11 : [21, 25, 5, 8, 7]
# Switch selected is : 5
# The target controller set for 28 is : [3, 12, 30, 24, 33, 20]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07958914346516671
# 28 :	 0.09001458611827143
# 11 :	 0.07574438373710543
# 2 :	 0.1576662553095475
# 6 :	 0.05991658792973196
# Switches in the controller 2 : [18, 19, 23, 4, 29, 15, 16, 32, 1]
# Switch selected is : 19
# The target controller set for 6 is : [9, 13, 31, 26]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07958914346516671
# 28 :	 0.09001458611827143
# 11 :	 0.07574438373710543
# 2 :	 0.1393044294328123
# 6 :	 0.07827841380646716
# Switches in the controller 2 : [18, 23, 4, 29, 15, 16, 32, 1]
# Switch selected is : 1
# The target controller set for 6 is : [9, 13, 31, 26, 19]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07958914346516671
# 28 :	 0.09001458611827143
# 11 :	 0.07574438373710543
# 2 :	 0.08735953890621112
# 6 :	 0.13022330433306833
# Switches in the controller 6 : [9, 13, 31, 26, 19, 1]
# Switch selected is : 26
# The target controller set for 14 is : [17, 10, 0, 27, 22]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.09756117015161238
# 28 :	 0.09001458611827143
# 11 :	 0.07574438373710543
# 2 :	 0.08735953890621112
# 6 :	 0.11225127764662267
# Switches in the controller 6 : [9, 13, 31, 19, 1]
# Switch selected is : 1
# The target controller set for 11 is : [21, 25, 8, 7]
# The mean load ratio is : 0.09258619131196462
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.09756117015161238
# 28 :	 0.09001458611827143
# 11 :	 0.1276892742637066
# 2 :	 0.08735953890621112
# 6 :	 0.06030638712002149
# Switches in the controller 14 : [17, 10, 0, 27, 22, 26]
# Switch selected is : 26
# The target controller set for 2 is : [18, 23, 4, 29, 15, 16, 32]
# The mean load ratio is : 0.09258619131196462
#
# At time step 940 the number of switch migrated are : 7
# The migrated switches are [22, 5, 19, 1, 26, 1, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 941
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09041620719664083
# 28 :	 0.09236176420821604
# 11 :	 0.13607084742030798
# 2 :	 0.11239021558138818
# 6 :	 0.0686541505181719
# Switches in the controller 11 : [21, 25, 8, 7, 1]
# Switch selected is : 21
# The target controller set for 28 is : [3, 12, 30, 24, 33, 20, 5]
# The mean load ratio is : 0.09997863698494498
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09041620719664083
# 28 :	 0.11072389508487387
# 11 :	 0.11770871654365014
# 2 :	 0.11239021558138818
# 6 :	 0.0686541505181719
# Switches in the controller 11 : [25, 8, 7, 1]
# Switch selected is : 8
# The target controller set for 6 is : [9, 13, 31, 19]
# The mean load ratio is : 0.09997863698494498
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.09041620719664083
# 28 :	 0.11072389508487387
# 11 :	 0.09287447549523606
# 2 :	 0.11239021558138818
# 6 :	 0.09348839156658598
# Switches in the controller 28 : [3, 12, 30, 24, 33, 20, 5, 21]
# Switch selected is : 24
# The target controller set for 6 is : [9, 13, 31, 19, 8]
# The mean load ratio is : 0.09997863698494498
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.09041620719664083
# 28 :	 0.09236187100947621
# 11 :	 0.09287447549523606
# 2 :	 0.11239021558138818
# 6 :	 0.11185041564198364
# Switches in the controller 2 : [18, 23, 4, 29, 15, 16, 32, 26]
# Switch selected is : 16
# The target controller set for 28 is : [3, 12, 30, 33, 20, 5, 21]
# The mean load ratio is : 0.09997863698494498
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.09041620719664083
# 28 :	 0.0923922331288851
# 11 :	 0.09287447549523606
# 2 :	 0.11235985346197928
# 6 :	 0.11185041564198364
# Switches in the controller 2 : [18, 23, 4, 29, 15, 32, 26]
# Switch selected is : 29
# The target controller set for 11 is : [25, 7, 1]
# The mean load ratio is : 0.09997863698494498
#
# At time step 941 the number of switch migrated are : 5
# The migrated switches are [21, 8, 24, 16, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 942
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08877589208266232
# 28 :	 0.13153183331156834
# 11 :	 0.1173617942658271
# 2 :	 0.0931540836348538
# 6 :	 0.10659270960393841
# Switches in the controller 11 : [25, 7, 1, 29]
# Switch selected is : 7
# The target controller set for 28 is : [3, 12, 30, 33, 20, 5, 21, 16]
# The mean load ratio is : 0.10748326257976999
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08877589208266232
# 28 :	 0.1604361450934525
# 11 :	 0.08845748248394293
# 2 :	 0.0931540836348538
# 6 :	 0.10659270960393841
# Switches in the controller 28 : [3, 12, 30, 33, 20, 5, 21, 16, 7]
# Switch selected is : 33
# The target controller set for 11 is : [25, 1, 29]
# The mean load ratio is : 0.10748326257976999
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08877589208266232
# 28 :	 0.16015609593877572
# 11 :	 0.08873753163861971
# 2 :	 0.0931540836348538
# 6 :	 0.10659270960393841
# Switches in the controller 28 : [3, 12, 30, 20, 5, 21, 16, 7]
# Switch selected is : 5
# The target controller set for 11 is : [25, 1, 29, 33]
# The mean load ratio is : 0.10748326257976999
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08877589208266232
# 28 :	 0.1284146437904179
# 11 :	 0.12047898378697752
# 2 :	 0.0931540836348538
# 6 :	 0.10659270960393841
# Switches in the controller 28 : [3, 12, 30, 20, 21, 16, 7]
# Switch selected is : 3
# The target controller set for 6 is : [9, 13, 31, 19, 8, 24]
# The mean load ratio is : 0.10748326257976999
#
# At time step 942 the number of switch migrated are : 4
# The migrated switches are [7, 33, 5, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 943
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08076226105028782
# 28 :	 0.09532082909843634
# 11 :	 0.13154951478009
# 2 :	 0.08191572373316189
# 6 :	 0.14250340262659497
# Switches in the controller 6 : [9, 13, 31, 19, 8, 24, 3]
# Switch selected is : 9
# The target controller set for 28 is : [12, 30, 20, 21, 16, 7]
# The mean load ratio is : 0.10641034625771421
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08076226105028782
# 28 :	 0.1162933949080279
# 11 :	 0.13154951478009
# 2 :	 0.08191572373316189
# 6 :	 0.12153083681700341
# Switches in the controller 6 : [13, 31, 19, 8, 24, 3]
# Switch selected is : 31
# The target controller set for 2 is : [18, 23, 4, 15, 32, 26]
# The mean load ratio is : 0.10641034625771421
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08076226105028782
# 28 :	 0.1162933949080279
# 11 :	 0.13154951478009
# 2 :	 0.11056692462831605
# 6 :	 0.09287963592184925
# Switches in the controller 28 : [12, 30, 20, 21, 16, 7, 9]
# Switch selected is : 20
# The target controller set for 14 is : [17, 10, 0, 27, 22]
# The mean load ratio is : 0.10641034625771421
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09912427286980317
# 28 :	 0.09793138308851254
# 11 :	 0.13154951478009
# 2 :	 0.11056692462831605
# 6 :	 0.09287963592184925
# Switches in the controller 11 : [25, 1, 29, 33, 5]
# Switch selected is : 33
# The target controller set for 14 is : [17, 10, 0, 27, 22, 20]
# The mean load ratio is : 0.10641034625771421
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09941045181432064
# 28 :	 0.09793138308851254
# 11 :	 0.13126333583557254
# 2 :	 0.11056692462831605
# 6 :	 0.09287963592184925
# Switches in the controller 11 : [25, 1, 29, 5]
# Switch selected is : 25
# The target controller set for 14 is : [17, 10, 0, 27, 22, 20, 33]
# The mean load ratio is : 0.10641034625771421
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.12806224204409855
# 28 :	 0.09793138308851254
# 11 :	 0.10261154560579461
# 2 :	 0.11056692462831605
# 6 :	 0.09287963592184925
# Switches in the controller 2 : [18, 23, 4, 15, 32, 26, 31]
# Switch selected is : 31
# The target controller set for 11 is : [1, 29, 5]
# The mean load ratio is : 0.10641034625771421
#
# At time step 943 the number of switch migrated are : 6
# The migrated switches are [9, 31, 20, 33, 25, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 944
# The overloaded domains are : [11, 28, 14, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.12316568792399736
# 28 :	 0.0839127982011106
# 11 :	 0.0932511234384997
# 2 :	 0.07294984404143551
# 6 :	 0.07631249633989279
# Switches in the controller 11 : [1, 29, 5, 31]
# Switch selected is : 5
# The target controller set for 28 is : [12, 30, 21, 16, 7, 9]
# The mean load ratio is : 0.08991838998898719
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.12316568792399736
# 28 :	 0.11161467550085968
# 11 :	 0.0655492461387506
# 2 :	 0.07294984404143551
# 6 :	 0.07631249633989279
# Switches in the controller 14 : [17, 10, 0, 27, 22, 20, 33, 25]
# Switch selected is : 10
# The target controller set for 2 is : [18, 23, 4, 15, 32, 26]
# The mean load ratio is : 0.08991838998898719
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.09603940676206588
# 28 :	 0.11161467550085968
# 11 :	 0.0655492461387506
# 2 :	 0.10007612520336699
# 6 :	 0.07631249633989279
# Switches in the controller 14 : [17, 0, 27, 22, 20, 33, 25]
# Switch selected is : 27
# The target controller set for 6 is : [13, 19, 8, 24, 3]
# The mean load ratio is : 0.08991838998898719
#
# At time step 944 the number of switch migrated are : 3
# The migrated switches are [5, 10, 27]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 945
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.0834507214785877
# 28 :	 0.12393272088929992
# 11 :	 0.10271835433355306
# 2 :	 0.10644739264671156
# 6 :	 0.09070060809608504
# Switches in the controller 28 : [12, 30, 21, 16, 7, 9, 5]
# Switch selected is : 9
# The target controller set for 6 is : [13, 19, 8, 24, 3, 27]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.0834507214785877
# 28 :	 0.10321879932487159
# 11 :	 0.10271835433355306
# 2 :	 0.10644739264671156
# 6 :	 0.11141452966051338
# Switches in the controller 28 : [12, 30, 21, 16, 7, 5]
# Switch selected is : 16
# The target controller set for 11 is : [1, 29, 31]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.0834507214785877
# 28 :	 0.10289876344135446
# 11 :	 0.10303839021707019
# 2 :	 0.10644739264671156
# 6 :	 0.11141452966051338
# Switches in the controller 28 : [12, 30, 21, 7, 5]
# Switch selected is : 30
# The target controller set for 6 is : [13, 19, 8, 24, 3, 27, 9]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.0834507214785877
# 28 :	 0.07504612530414362
# 11 :	 0.10303839021707019
# 2 :	 0.10644739264671156
# 6 :	 0.13926716779772422
# Switches in the controller 11 : [1, 29, 31, 16]
# Switch selected is : 16
# The target controller set for 14 is : [17, 0, 22, 20, 33, 25]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08377075736210483
# 28 :	 0.07504612530414362
# 11 :	 0.10271835433355306
# 2 :	 0.10644739264671156
# 6 :	 0.13926716779772422
# Switches in the controller 11 : [1, 29, 31]
# Switch selected is : 31
# The target controller set for 28 is : [12, 21, 7, 5]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.08377075736210483
# 28 :	 0.1028985555555931
# 11 :	 0.07486592408210357
# 2 :	 0.10644739264671156
# 6 :	 0.13926716779772422
# Switches in the controller 2 : [18, 23, 4, 15, 32, 26, 10]
# Switch selected is : 18
# The target controller set for 14 is : [17, 0, 22, 20, 33, 25, 16]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.10213278760081418
# 28 :	 0.1028985555555931
# 11 :	 0.07486592408210357
# 2 :	 0.08808536240800222
# 6 :	 0.13926716779772422
# Switches in the controller 6 : [13, 19, 8, 24, 3, 27, 9, 30]
# Switch selected is : 13
# The target controller set for 28 is : [12, 21, 7, 5, 31]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.10213278760081418
# 28 :	 0.10306428166368478
# 11 :	 0.07486592408210357
# 2 :	 0.08808536240800222
# 6 :	 0.13910144168963254
# Switches in the controller 6 : [19, 8, 24, 3, 27, 9, 30]
# Switch selected is : 30
# The target controller set for 28 is : [12, 21, 7, 5, 31, 13]
# The mean load ratio is : 0.10144995948884745
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.10213278760081418
# 28 :	 0.13091691980089562
# 11 :	 0.07486592408210357
# 2 :	 0.08808536240800222
# 6 :	 0.1112488035524217
# Switches in the controller 6 : [19, 8, 24, 3, 27, 9]
# Switch selected is : 8
# The target controller set for 11 is : [1, 29]
# The mean load ratio is : 0.10144995948884745
#
# At time step 945 the number of switch migrated are : 9
# The migrated switches are [9, 16, 30, 16, 31, 18, 13, 30, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 946
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10179589613722552
# 28 :	 0.12761001937654115
# 11 :	 0.0795589871428772
# 2 :	 0.0808377467919683
# 6 :	 0.1019089266298274
# Switches in the controller 14 : [17, 0, 22, 20, 33, 25, 16, 18]
# Switch selected is : 33
# The target controller set for 6 is : [19, 24, 3, 27, 9]
# The mean load ratio is : 0.0983423152156879
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10153830237928273
# 28 :	 0.12761001937654115
# 11 :	 0.0795589871428772
# 2 :	 0.0808377467919683
# 6 :	 0.10216652038777019
# Switches in the controller 14 : [17, 0, 22, 20, 25, 16, 18]
# Switch selected is : 22
# The target controller set for 11 is : [1, 29, 8]
# The mean load ratio is : 0.0983423152156879
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08317589655879462
# 28 :	 0.12761001937654115
# 11 :	 0.0979213929633653
# 2 :	 0.0808377467919683
# 6 :	 0.10216652038777019
# Switches in the controller 6 : [19, 24, 3, 27, 9, 33]
# Switch selected is : 27
# The target controller set for 11 is : [1, 29, 8, 22]
# The mean load ratio is : 0.0983423152156879
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08317589655879462
# 28 :	 0.12761001937654115
# 11 :	 0.12555438496240112
# 2 :	 0.0808377467919683
# 6 :	 0.07453352838873437
# Switches in the controller 28 : [12, 21, 7, 5, 31, 13, 30]
# Switch selected is : 5
# The target controller set for 11 is : [1, 29, 8, 22, 27]
# The mean load ratio is : 0.0983423152156879
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08317589655879462
# 28 :	 0.1015878055483708
# 11 :	 0.15157659879057148
# 2 :	 0.0808377467919683
# 6 :	 0.07453352838873437
# Switches in the controller 28 : [12, 21, 7, 31, 13, 30]
# Switch selected is : 13
# The target controller set for 14 is : [17, 0, 20, 25, 16, 18]
# The mean load ratio is : 0.0983423152156879
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.0832456477956894
# 28 :	 0.10151805431147602
# 11 :	 0.15157659879057148
# 2 :	 0.0808377467919683
# 6 :	 0.07453352838873437
# Switches in the controller 28 : [12, 21, 7, 31, 30]
# Switch selected is : 31
# The target controller set for 14 is : [17, 0, 20, 25, 16, 18, 13]
# The mean load ratio is : 0.0983423152156879
#
# At time step 946 the number of switch migrated are : 6
# The migrated switches are [33, 22, 27, 5, 13, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 947
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.09035046685222665
# 28 :	 0.05342829986939266
# 11 :	 0.14876970625113914
# 2 :	 0.08533835939707206
# 6 :	 0.06358968882162666
# Switches in the controller 14 : [17, 0, 20, 25, 16, 18, 13, 31]
# Switch selected is : 0
# The target controller set for 28 is : [12, 21, 7, 30]
# The mean load ratio is : 0.08829530423829143
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07198844046006048
# 28 :	 0.07179032626155885
# 11 :	 0.14876970625113914
# 2 :	 0.08533835939707206
# 6 :	 0.06358968882162666
# Switches in the controller 11 : [1, 29, 8, 22, 27, 5]
# Switch selected is : 1
# The target controller set for 14 is : [17, 20, 25, 16, 18, 13, 31]
# The mean load ratio is : 0.08829530423829143
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11430499000158259
# 28 :	 0.07179032626155885
# 11 :	 0.10645315670961703
# 2 :	 0.08533835939707206
# 6 :	 0.06358968882162666
# Switches in the controller 11 : [29, 8, 22, 27, 5]
# Switch selected is : 8
# The target controller set for 28 is : [12, 21, 7, 30, 0]
# The mean load ratio is : 0.08829530423829143
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11430499000158259
# 28 :	 0.08915348254952282
# 11 :	 0.08909000042165305
# 2 :	 0.08533835939707206
# 6 :	 0.06358968882162666
# Switches in the controller 11 : [29, 22, 27, 5]
# Switch selected is : 29
# The target controller set for 14 is : [17, 20, 25, 16, 18, 13, 31, 1]
# The mean load ratio is : 0.08829530423829143
#
# At time step 947 the number of switch migrated are : 4
# The migrated switches are [0, 1, 8, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 948
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1772577614929562
# 28 :	 0.13725245079326664
# 11 :	 0.08478232545928101
# 2 :	 0.09610909129720545
# 6 :	 0.10198633311851278
# Switches in the controller 28 : [12, 21, 7, 30, 0, 8]
# Switch selected is : 30
# The target controller set for 2 is : [23, 4, 15, 32, 26, 10]
# The mean load ratio is : 0.1194775924322444
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1772577614929562
# 28 :	 0.10254494270672601
# 11 :	 0.08478232545928101
# 2 :	 0.1308165993837461
# 6 :	 0.10198633311851278
# Switches in the controller 14 : [17, 20, 25, 16, 18, 13, 31, 1, 29]
# Switch selected is : 13
# The target controller set for 28 is : [12, 21, 7, 0, 8]
# The mean load ratio is : 0.1194775924322444
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.17701123711519096
# 28 :	 0.10279146708449123
# 11 :	 0.08478232545928101
# 2 :	 0.1308165993837461
# 6 :	 0.10198633311851278
# Switches in the controller 14 : [17, 20, 25, 16, 18, 31, 1, 29]
# Switch selected is : 18
# The target controller set for 28 is : [12, 21, 7, 0, 8, 13]
# The mean load ratio is : 0.1194775924322444
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1586494837480048
# 28 :	 0.1211532204516774
# 11 :	 0.08478232545928101
# 2 :	 0.1308165993837461
# 6 :	 0.10198633311851278
# Switches in the controller 14 : [17, 20, 25, 16, 31, 1, 29]
# Switch selected is : 20
# The target controller set for 28 is : [12, 21, 7, 0, 8, 13, 18]
# The mean load ratio is : 0.1194775924322444
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.14028722940173316
# 28 :	 0.13951547479794904
# 11 :	 0.08478232545928101
# 2 :	 0.1308165993837461
# 6 :	 0.10198633311851278
# Switches in the controller 14 : [17, 25, 16, 31, 1, 29]
# Switch selected is : 29
# The target controller set for 11 is : [22, 27, 5]
# The mean load ratio is : 0.1194775924322444
#
# At time step 948 the number of switch migrated are : 5
# The migrated switches are [30, 13, 18, 20, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 949
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.09616702539371574
# 28 :	 0.11600582708319992
# 11 :	 0.09250947218762998
# 2 :	 0.10704547623963596
# 6 :	 0.08155089832883969
# Switches in the controller 28 : [12, 21, 7, 0, 8, 13, 18, 20]
# Switch selected is : 20
# The target controller set for 14 is : [17, 25, 16, 31, 1]
# The mean load ratio is : 0.09865573984660425
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11452881685052173
# 28 :	 0.09764403562639394
# 11 :	 0.09250947218762998
# 2 :	 0.10704547623963596
# 6 :	 0.08155089832883969
# Switches in the controller 14 : [17, 25, 16, 31, 1, 20]
# Switch selected is : 17
# The target controller set for 28 is : [12, 21, 7, 0, 8, 13, 18]
# The mean load ratio is : 0.09865573984660425
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11421345108015643
# 28 :	 0.09795940139675924
# 11 :	 0.09250947218762998
# 2 :	 0.10704547623963596
# 6 :	 0.08155089832883969
# Switches in the controller 14 : [25, 16, 31, 1, 20]
# Switch selected is : 1
# The target controller set for 28 is : [12, 21, 7, 0, 8, 13, 18, 17]
# The mean load ratio is : 0.09865573984660425
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.06042273443814742
# 28 :	 0.15175011803876826
# 11 :	 0.09250947218762998
# 2 :	 0.10704547623963596
# 6 :	 0.08155089832883969
# Switches in the controller 2 : [23, 4, 15, 32, 26, 10, 30]
# Switch selected is : 26
# The target controller set for 11 is : [22, 27, 5, 29]
# The mean load ratio is : 0.09865573984660425
#
# At time step 949 the number of switch migrated are : 4
# The migrated switches are [20, 17, 1, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 950
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.06145146836960724
# 28 :	 0.12904573566938626
# 11 :	 0.10297594226491145
# 2 :	 0.08894966871177123
# 6 :	 0.06722147341024014
# Switches in the controller 11 : [22, 27, 5, 29, 26]
# Switch selected is : 29
# The target controller set for 14 is : [25, 16, 31, 20]
# The mean load ratio is : 0.08992885768518327
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08279733593941369
# 28 :	 0.12904573566938626
# 11 :	 0.08163007469510501
# 2 :	 0.08894966871177123
# 6 :	 0.06722147341024014
# Switches in the controller 28 : [12, 21, 7, 0, 8, 13, 18, 17, 1]
# Switch selected is : 12
# The target controller set for 6 is : [19, 24, 3, 9, 33]
# The mean load ratio is : 0.08992885768518327
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08279733593941369
# 28 :	 0.12873566892096097
# 11 :	 0.08163007469510501
# 2 :	 0.08894966871177123
# 6 :	 0.06753154015866543
# Switches in the controller 28 : [21, 7, 0, 8, 13, 18, 17, 1]
# Switch selected is : 17
# The target controller set for 2 is : [23, 4, 15, 32, 10, 30]
# The mean load ratio is : 0.08992885768518327
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08279733593941369
# 28 :	 0.12836551600711177
# 11 :	 0.08163007469510501
# 2 :	 0.08931982162562042
# 6 :	 0.06753154015866543
# Switches in the controller 28 : [21, 7, 0, 8, 13, 18, 1]
# Switch selected is : 18
# The target controller set for 11 is : [22, 27, 5, 26]
# The mean load ratio is : 0.08992885768518327
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08279733593941369
# 28 :	 0.11000323871864197
# 11 :	 0.09999235198357481
# 2 :	 0.08931982162562042
# 6 :	 0.06753154015866543
# Switches in the controller 28 : [21, 7, 0, 8, 13, 1]
# Switch selected is : 7
# The target controller set for 11 is : [22, 27, 5, 26, 18]
# The mean load ratio is : 0.08992885768518327
#
# At time step 950 the number of switch migrated are : 5
# The migrated switches are [29, 12, 17, 18, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 951
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11484225730370252
# 28 :	 0.0762516293474759
# 11 :	 0.15720244650938
# 2 :	 0.09328112364322037
# 6 :	 0.08861895163228023
# Switches in the controller 11 : [22, 27, 5, 26, 18, 7]
# Switch selected is : 22
# The target controller set for 2 is : [23, 4, 15, 32, 10, 30, 17]
# The mean load ratio is : 0.10603928168721181
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11484225730370252
# 28 :	 0.0762516293474759
# 11 :	 0.13884075954148697
# 2 :	 0.11164281061111339
# 6 :	 0.08861895163228023
# Switches in the controller 11 : [27, 5, 26, 18, 7]
# Switch selected is : 18
# The target controller set for 2 is : [23, 4, 15, 32, 10, 30, 17, 22]
# The mean load ratio is : 0.10603928168721181
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11484225730370252
# 28 :	 0.0762516293474759
# 11 :	 0.12047844055560517
# 2 :	 0.1300051295969952
# 6 :	 0.08861895163228023
# Switches in the controller 11 : [27, 5, 26, 7]
# Switch selected is : 5
# The target controller set for 6 is : [19, 24, 3, 9, 33, 12]
# The mean load ratio is : 0.10603928168721181
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.11484225730370252
# 28 :	 0.0762516293474759
# 11 :	 0.09619399959920778
# 2 :	 0.1300051295969952
# 6 :	 0.11290339258867761
# Switches in the controller 2 : [23, 4, 15, 32, 10, 30, 17, 22, 18]
# Switch selected is : 30
# The target controller set for 14 is : [25, 16, 31, 20, 29]
# The mean load ratio is : 0.10603928168721181
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1469067231872276
# 28 :	 0.0762516293474759
# 11 :	 0.09619399959920778
# 2 :	 0.09794066371347013
# 6 :	 0.11290339258867761
# Switches in the controller 14 : [25, 16, 31, 20, 29, 30]
# Switch selected is : 20
# The target controller set for 11 is : [27, 26, 7]
# The mean load ratio is : 0.10603928168721181
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.12854464541497182
# 28 :	 0.0762516293474759
# 11 :	 0.11455607737146356
# 2 :	 0.09794066371347013
# 6 :	 0.11290339258867761
# Switches in the controller 14 : [25, 16, 31, 29, 30]
# Switch selected is : 30
# The target controller set for 28 is : [21, 0, 8, 13, 1]
# The mean load ratio is : 0.10603928168721181
#
# At time step 951 the number of switch migrated are : 6
# The migrated switches are [22, 18, 5, 30, 20, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 952
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.10795214781755512
# 28 :	 0.14745479314516513
# 11 :	 0.12630806478256928
# 2 :	 0.11401706884114422
# 6 :	 0.14924908422921118
# Switches in the controller 28 : [21, 0, 8, 13, 1, 30]
# Switch selected is : 0
# The target controller set for 11 is : [27, 26, 7, 20]
# The mean load ratio is : 0.12899623176312897
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.10795214781755512
# 28 :	 0.12909276675299894
# 11 :	 0.14467009117473548
# 2 :	 0.11401706884114422
# 6 :	 0.14924908422921118
# Switches in the controller 28 : [21, 8, 13, 1, 30]
# Switch selected is : 13
# The target controller set for 14 is : [25, 16, 31, 29]
# The mean load ratio is : 0.12899623176312897
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.10805872721755007
# 28 :	 0.128986187353004
# 11 :	 0.14467009117473548
# 2 :	 0.11401706884114422
# 6 :	 0.14924908422921118
# Switches in the controller 11 : [27, 26, 7, 20, 0]
# Switch selected is : 26
# The target controller set for 14 is : [25, 16, 31, 29, 13]
# The mean load ratio is : 0.12899623176312897
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.14404095348570578
# 28 :	 0.128986187353004
# 11 :	 0.10868786490657978
# 2 :	 0.11401706884114422
# 6 :	 0.14924908422921118
# Switches in the controller 6 : [19, 24, 3, 9, 33, 12, 5]
# Switch selected is : 19
# The target controller set for 2 is : [23, 4, 15, 32, 10, 17, 22, 18]
# The mean load ratio is : 0.12899623176312897
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.14404095348570578
# 28 :	 0.128986187353004
# 11 :	 0.10868786490657978
# 2 :	 0.13237891885383238
# 6 :	 0.13088723421652304
# Switches in the controller 6 : [24, 3, 9, 33, 12, 5]
# Switch selected is : 3
# The target controller set for 11 is : [27, 7, 20, 0]
# The mean load ratio is : 0.12899623176312897
#
# At time step 952 the number of switch migrated are : 5
# The migrated switches are [0, 13, 26, 19, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 953
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.07835497029572985
# 28 :	 0.10774848045149782
# 11 :	 0.11407250566669469
# 2 :	 0.11989905474931474
# 6 :	 0.07219467588486976
# Switches in the controller 28 : [21, 8, 1, 30]
# Switch selected is : 8
# The target controller set for 2 is : [23, 4, 15, 32, 10, 17, 22, 18, 19]
# The mean load ratio is : 0.09845393740962137
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07835497029572985
# 28 :	 0.0921189377681984
# 11 :	 0.11407250566669469
# 2 :	 0.13552859743261414
# 6 :	 0.07219467588486976
# Switches in the controller 11 : [27, 7, 20, 0, 3]
# Switch selected is : 0
# The target controller set for 6 is : [24, 9, 33, 12, 5]
# The mean load ratio is : 0.09845393740962137
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07835497029572985
# 28 :	 0.0921189377681984
# 11 :	 0.0957104792745285
# 2 :	 0.13552859743261414
# 6 :	 0.09055670227703594
# Switches in the controller 2 : [23, 4, 15, 32, 10, 17, 22, 18, 19, 8]
# Switch selected is : 15
# The target controller set for 14 is : [25, 16, 31, 29, 13, 26]
# The mean load ratio is : 0.09845393740962137
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07850527575111706
# 28 :	 0.0921189377681984
# 11 :	 0.0957104792745285
# 2 :	 0.13537829197722695
# 6 :	 0.09055670227703594
# Switches in the controller 2 : [23, 4, 32, 10, 17, 22, 18, 19, 8]
# Switch selected is : 23
# The target controller set for 14 is : [25, 16, 31, 29, 13, 26, 15]
# The mean load ratio is : 0.09845393740962137
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.09686743226697457
# 28 :	 0.0921189377681984
# 11 :	 0.0957104792745285
# 2 :	 0.11701613546136944
# 6 :	 0.09055670227703594
# Switches in the controller 2 : [4, 32, 10, 17, 22, 18, 19, 8]
# Switch selected is : 22
# The target controller set for 11 is : [27, 7, 20, 3]
# The mean load ratio is : 0.09845393740962137
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.09686743226697457
# 28 :	 0.0921189377681984
# 11 :	 0.11407239514710948
# 2 :	 0.09865421958878845
# 6 :	 0.09055670227703594
# Switches in the controller 2 : [4, 32, 10, 17, 18, 19, 8]
# Switch selected is : 17
# The target controller set for 11 is : [27, 7, 20, 3, 22]
# The mean load ratio is : 0.09845393740962137
#
# At time step 953 the number of switch migrated are : 6
# The migrated switches are [8, 0, 15, 23, 22, 17]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 954
# The overloaded domains are : [2, 11, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.0959456029757213
# 28 :	 0.06798367369142794
# 11 :	 0.10958673440734437
# 2 :	 0.11712727387631369
# 6 :	 0.09966885322341244
# Switches in the controller 6 : [24, 9, 33, 12, 5, 0]
# Switch selected is : 12
# The target controller set for 2 is : [4, 32, 10, 18, 19, 8]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.0959456029757213
# 28 :	 0.06798367369142794
# 11 :	 0.10958673440734437
# 2 :	 0.11736726279838021
# 6 :	 0.09942886430134593
# Switches in the controller 6 : [24, 9, 33, 5, 0]
# Switch selected is : 24
# The target controller set for 11 is : [27, 7, 20, 3, 22, 17]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.0959456029757213
# 28 :	 0.06798367369142794
# 11 :	 0.12794895111939153
# 2 :	 0.11736726279838021
# 6 :	 0.08106664758929877
# Switches in the controller 11 : [27, 7, 20, 3, 22, 17, 24]
# Switch selected is : 27
# The target controller set for 14 is : [25, 16, 31, 29, 13, 26, 15, 23]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11520492399281512
# 28 :	 0.06798367369142794
# 11 :	 0.10868963010229771
# 2 :	 0.11736726279838021
# 6 :	 0.08106664758929877
# Switches in the controller 11 : [7, 20, 3, 22, 17, 24]
# Switch selected is : 7
# The target controller set for 28 is : [21, 1, 30]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.11520492399281512
# 28 :	 0.08724243432466183
# 11 :	 0.08943086946906381
# 2 :	 0.11736726279838021
# 6 :	 0.08106664758929877
# Switches in the controller 2 : [4, 32, 10, 18, 19, 8, 12]
# Switch selected is : 8
# The target controller set for 11 is : [20, 3, 22, 17, 24]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11520492399281512
# 28 :	 0.08724243432466183
# 11 :	 0.11139746831063296
# 2 :	 0.09540066395681106
# 6 :	 0.08106664758929877
# Switches in the controller 14 : [25, 16, 31, 29, 13, 26, 15, 23, 27]
# Switch selected is : 16
# The target controller set for 28 is : [21, 1, 30, 7]
# The mean load ratio is : 0.09806242763484396
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1151131350322278
# 28 :	 0.08733422328524916
# 11 :	 0.11139746831063296
# 2 :	 0.09540066395681106
# 6 :	 0.08106664758929877
# Switches in the controller 14 : [25, 31, 29, 13, 26, 15, 23, 27]
# Switch selected is : 25
# The target controller set for 28 is : [21, 1, 30, 7, 16]
# The mean load ratio is : 0.09806242763484396
#
# At time step 954 the number of switch migrated are : 7
# The migrated switches are [12, 24, 27, 7, 8, 16, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 955
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.13775038652669153
# 28 :	 0.13063609538039878
# 11 :	 0.08190072824974824
# 2 :	 0.08492650956962562
# 6 :	 0.058471983633054135
# Switches in the controller 28 : [21, 1, 30, 7, 16, 25]
# Switch selected is : 25
# The target controller set for 14 is : [31, 29, 13, 26, 15, 23, 27]
# The mean load ratio is : 0.09873714067190366
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1674951702064142
# 28 :	 0.10089131170067613
# 11 :	 0.08190072824974824
# 2 :	 0.08492650956962562
# 6 :	 0.058471983633054135
# Switches in the controller 28 : [21, 1, 30, 7, 16]
# Switch selected is : 1
# The target controller set for 11 is : [20, 3, 22, 17, 24, 8]
# The mean load ratio is : 0.09873714067190366
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.1674951702064142
# 28 :	 0.07817973372942827
# 11 :	 0.1046123062209961
# 2 :	 0.08492650956962562
# 6 :	 0.058471983633054135
# Switches in the controller 11 : [20, 3, 22, 17, 24, 8, 1]
# Switch selected is : 1
# The target controller set for 6 is : [9, 33, 5, 0]
# The mean load ratio is : 0.09873714067190366
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1674951702064142
# 28 :	 0.07817973372942827
# 11 :	 0.08190072824974826
# 2 :	 0.08492650956962562
# 6 :	 0.08118356160430198
# Switches in the controller 14 : [31, 29, 13, 26, 15, 23, 27, 25]
# Switch selected is : 23
# The target controller set for 2 is : [4, 32, 10, 18, 19, 12]
# The mean load ratio is : 0.09873714067190366
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.14913314283713763
# 28 :	 0.07817973372942827
# 11 :	 0.08190072824974826
# 2 :	 0.10328853693890219
# 6 :	 0.08118356160430198
# Switches in the controller 14 : [31, 29, 13, 26, 15, 27, 25]
# Switch selected is : 26
# The target controller set for 6 is : [9, 33, 5, 0, 1]
# The mean load ratio is : 0.09873714067190366
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11938777320067509
# 28 :	 0.07817973372942827
# 11 :	 0.08190072824974826
# 2 :	 0.10328853693890219
# 6 :	 0.11092893124076453
# Switches in the controller 14 : [31, 29, 13, 15, 27, 25]
# Switch selected is : 29
# The target controller set for 11 is : [20, 3, 22, 17, 24, 8]
# The mean load ratio is : 0.09873714067190366
#
# At time step 955 the number of switch migrated are : 6
# The migrated switches are [25, 1, 1, 23, 26, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 956
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08009577731030548
# 28 :	 0.07194723951347645
# 11 :	 0.10489216008327273
# 2 :	 0.09641726331010018
# 6 :	 0.14305250193084226
# Switches in the controller 6 : [9, 33, 5, 0, 1, 26]
# Switch selected is : 5
# The target controller set for 2 is : [4, 32, 10, 18, 19, 12, 23]
# The mean load ratio is : 0.09928098842959943
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08009577731030548
# 28 :	 0.07194723951347645
# 11 :	 0.10489216008327273
# 2 :	 0.12252109892254656
# 6 :	 0.11694866631839589
# Switches in the controller 6 : [9, 33, 0, 1, 26]
# Switch selected is : 33
# The target controller set for 28 is : [21, 30, 7, 16]
# The mean load ratio is : 0.09928098842959943
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08009577731030548
# 28 :	 0.07218020983930161
# 11 :	 0.10489216008327273
# 2 :	 0.12252109892254656
# 6 :	 0.11671569599257073
# Switches in the controller 6 : [9, 0, 1, 26]
# Switch selected is : 1
# The target controller set for 2 is : [4, 32, 10, 18, 19, 12, 23, 5]
# The mean load ratio is : 0.09928098842959943
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08009577731030548
# 28 :	 0.07218020983930161
# 11 :	 0.10489216008327273
# 2 :	 0.17211699118811574
# 6 :	 0.06711980372700156
# Switches in the controller 11 : [20, 3, 22, 17, 24, 8, 29]
# Switch selected is : 8
# The target controller set for 6 is : [9, 0, 26]
# The mean load ratio is : 0.09928098842959943
#
# At time step 956 the number of switch migrated are : 4
# The migrated switches are [5, 33, 1, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 957
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10727685869109371
# 28 :	 0.09005392672933168
# 11 :	 0.09449239171554664
# 2 :	 0.14484734545882
# 6 :	 0.10260192473817863
# Switches in the controller 2 : [4, 32, 10, 18, 19, 12, 23, 5, 1]
# Switch selected is : 19
# The target controller set for 6 is : [9, 0, 26, 8]
# The mean load ratio is : 0.10785448946659412
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10727685869109371
# 28 :	 0.09005392672933168
# 11 :	 0.09449239171554664
# 2 :	 0.12648545519891083
# 6 :	 0.12096381499808781
# Switches in the controller 2 : [4, 32, 10, 18, 12, 23, 5, 1]
# Switch selected is : 10
# The target controller set for 6 is : [9, 0, 26, 8, 19]
# The mean load ratio is : 0.10785448946659412
#
# At time step 957 the number of switch migrated are : 2
# The migrated switches are [19, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 958
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0530124848499618
# 11 :	 0.07397503667452002
# 2 :	 0.12426138973279993
# 6 :	 0.12540723022819356
# Switches in the controller 2 : [4, 32, 18, 12, 23, 5, 1]
# Switch selected is : 23
# The target controller set for 6 is : [9, 0, 26, 8, 19, 10]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0530124848499618
# 11 :	 0.07397503667452002
# 2 :	 0.10589935165952225
# 6 :	 0.14376926830147124
# Switches in the controller 2 : [4, 32, 18, 12, 5, 1]
# Switch selected is : 18
# The target controller set for 11 is : [20, 3, 22, 17, 24, 29]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0530124848499618
# 11 :	 0.09233699498287244
# 2 :	 0.08753739335116982
# 6 :	 0.14376926830147124
# Switches in the controller 2 : [4, 32, 12, 5, 1]
# Switch selected is : 4
# The target controller set for 6 is : [9, 0, 26, 8, 19, 10, 23]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0530124848499618
# 11 :	 0.09233699498287244
# 2 :	 0.06354172595365612
# 6 :	 0.16776493569898493
# Switches in the controller 6 : [9, 0, 26, 8, 19, 10, 23, 4]
# Switch selected is : 10
# The target controller set for 11 is : [20, 3, 22, 17, 24, 29, 18]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0530124848499618
# 11 :	 0.11922770332839541
# 2 :	 0.06354172595365612
# 6 :	 0.14087422735346197
# Switches in the controller 6 : [9, 0, 26, 8, 19, 23, 4]
# Switch selected is : 9
# The target controller set for 28 is : [21, 30, 7, 16, 33]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0723853571030333
# 11 :	 0.11922770332839541
# 2 :	 0.06354172595365612
# 6 :	 0.12150135510039048
# Switches in the controller 6 : [0, 26, 8, 19, 23, 4]
# Switch selected is : 23
# The target controller set for 11 is : [20, 3, 22, 17, 24, 29, 18, 10]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0723853571030333
# 11 :	 0.1375897414016731
# 2 :	 0.06354172595365612
# 6 :	 0.10313931702711279
# Switches in the controller 6 : [0, 26, 8, 19, 4]
# Switch selected is : 19
# The target controller set for 2 is : [32, 12, 5, 1]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.05082912990429199
# 28 :	 0.0723853571030333
# 11 :	 0.1375897414016731
# 2 :	 0.081903453588795
# 6 :	 0.08477758939197391
# Switches in the controller 11 : [20, 3, 22, 17, 24, 29, 18, 10, 23]
# Switch selected is : 20
# The target controller set for 14 is : [31, 13, 15, 27, 25]
# The mean load ratio is : 0.08549705427795347
#
# Balance the overloaded controller : 11
# ...
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.13813911562782094
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.10746963832950507
# 6 :	 0.13126154775831686
# Switches in the controller 2 : [32, 21, 4, 31, 19, 24]
# Switch selected is : 32
# The target controller set for 14 is : [26, 9, 15, 30, 22, 23, 17, 5]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.13834827023846663
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.10726048371885936
# 6 :	 0.13126154775831686
# Switches in the controller 2 : [21, 4, 31, 19, 24]
# Switch selected is : 21
# The target controller set for 14 is : [26, 9, 15, 30, 22, 23, 17, 5, 32]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1567103657003996
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.0888983882569264
# 6 :	 0.13126154775831686
# Switches in the controller 14 : [26, 9, 15, 30, 22, 23, 17, 5, 32, 21]
# Switch selected is : 26
# The target controller set for 6 is : [33, 10, 1, 8, 18]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.138659130488952
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.0888983882569264
# 6 :	 0.14931278296976444
# Switches in the controller 14 : [9, 15, 30, 22, 23, 17, 5, 32, 21]
# Switch selected is : 23
# The target controller set for 2 is : [4, 31, 19, 24]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.120297022634076
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.10726049611180241
# 6 :	 0.14931278296976444
# Switches in the controller 14 : [9, 15, 30, 22, 17, 5, 32, 21]
# Switch selected is : 15
# The target controller set for 2 is : [4, 31, 19, 24, 23]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11993188053850645
# 28 :	 0.07560411155199254
# 11 :	 0.07278895276970998
# 2 :	 0.10762563820737196
# 6 :	 0.14931278296976444
# Switches in the controller 14 : [9, 30, 22, 17, 5, 32, 21]
# Switch selected is : 32
# The target controller set for 28 is : [13, 12, 3, 0, 25]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11972272592786075
# 28 :	 0.07581326616263824
# 11 :	 0.07278895276970998
# 2 :	 0.10762563820737196
# 6 :	 0.14931278296976444
# Switches in the controller 14 : [9, 30, 22, 17, 5, 21]
# Switch selected is : 9
# The target controller set for 11 is : [27, 7, 16, 29, 20]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08681880253740298
# 28 :	 0.07581326616263824
# 11 :	 0.10569287616016773
# 2 :	 0.10762563820737196
# 6 :	 0.14931278296976444
# Switches in the controller 6 : [33, 10, 1, 8, 18, 26]
# Switch selected is : 26
# The target controller set for 11 is : [27, 7, 16, 29, 20, 9]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08681880253740298
# 28 :	 0.07581326616263824
# 11 :	 0.12374411137161533
# 2 :	 0.10762563820737196
# 6 :	 0.13126154775831686
# Switches in the controller 6 : [33, 10, 1, 8, 18]
# Switch selected is : 33
# The target controller set for 11 is : [27, 7, 16, 29, 20, 9, 26]
# The mean load ratio is : 0.10505267320746907
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08681880253740298
# 28 :	 0.07581326616263824
# 11 :	 0.1239551801910268
# 2 :	 0.10762563820737196
# 6 :	 0.1310504789389054
# Switches in the controller 6 : [10, 1, 8, 18]
# Switch selected is : 10
# The target controller set for 11 is : [27, 7, 16, 29, 20, 9, 26, 33]
# The mean load ratio is : 0.10505267320746907
#
# At time step 994 the number of switch migrated are : 11
# The migrated switches are [5, 32, 21, 26, 23, 15, 32, 9, 26, 33, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 995
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.08045161420880186
# 28 :	 0.055544533446676675
# 11 :	 0.14783523263595996
# 2 :	 0.10089324858764338
# 6 :	 0.07225248644031781
# Switches in the controller 2 : [4, 31, 19, 24, 23, 15]
# Switch selected is : 31
# The target controller set for 14 is : [30, 22, 17, 5, 21]
# The mean load ratio is : 0.09139542306387993
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10117850055133956
# 28 :	 0.055544533446676675
# 11 :	 0.14783523263595996
# 2 :	 0.08016636224510568
# 6 :	 0.07225248644031781
# Switches in the controller 14 : [30, 22, 17, 5, 21, 31]
# Switch selected is : 17
# The target controller set for 28 is : [13, 12, 3, 0, 25, 32]
# The mean load ratio is : 0.09139542306387993
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1010195637758348
# 28 :	 0.055703470222181424
# 11 :	 0.14783523263595996
# 2 :	 0.08016636224510568
# 6 :	 0.07225248644031781
# Switches in the controller 14 : [30, 22, 5, 21, 31]
# Switch selected is : 21
# The target controller set for 6 is : [1, 8, 18]
# The mean load ratio is : 0.09139542306387993
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08265760614836473
# 28 :	 0.055703470222181424
# 11 :	 0.14783523263595996
# 2 :	 0.08016636224510568
# 6 :	 0.09061444406778789
# Switches in the controller 11 : [27, 7, 16, 29, 20, 9, 26, 33, 10]
# Switch selected is : 29
# The target controller set for 28 is : [13, 12, 3, 0, 25, 32, 17]
# The mean load ratio is : 0.09139542306387993
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08265760614836473
# 28 :	 0.07643035928382722
# 11 :	 0.12710834357431416
# 2 :	 0.08016636224510568
# 6 :	 0.09061444406778789
# Switches in the controller 11 : [27, 7, 16, 20, 9, 26, 33, 10]
# Switch selected is : 20
# The target controller set for 6 is : [1, 8, 18, 21]
# The mean load ratio is : 0.09139542306387993
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08265760614836473
# 28 :	 0.07643035928382722
# 11 :	 0.10874641948251051
# 2 :	 0.08016636224510568
# 6 :	 0.10897636815959152
# Switches in the controller 11 : [27, 7, 16, 9, 26, 33, 10]
# Switch selected is : 10
# The target controller set for 28 is : [13, 12, 3, 0, 25, 32, 17, 29]
# The mean load ratio is : 0.09139542306387993
#
# At time step 995 the number of switch migrated are : 6
# The migrated switches are [31, 17, 21, 29, 20, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 996
# The overloaded domains are : [11, 28, 6, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.11157809329855035
# 28 :	 0.1581058159150884
# 11 :	 0.13562047336654862
# 2 :	 0.08049653639148617
# 6 :	 0.11824387273978214
# Switches in the controller 28 : [13, 12, 3, 0, 25, 32, 17, 29, 10]
# Switch selected is : 25
# The target controller set for 6 is : [1, 8, 18, 21, 20]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.11157809329855035
# 28 :	 0.12262296519699045
# 11 :	 0.13562047336654862
# 2 :	 0.08049653639148617
# 6 :	 0.15372672345788008
# Switches in the controller 28 : [13, 12, 3, 0, 32, 17, 29, 10]
# Switch selected is : 10
# The target controller set for 14 is : [30, 22, 5, 31]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1350636199052752
# 28 :	 0.09913743859026558
# 11 :	 0.13562047336654862
# 2 :	 0.08049653639148617
# 6 :	 0.15372672345788008
# Switches in the controller 14 : [30, 22, 5, 31, 10]
# Switch selected is : 5
# The target controller set for 2 is : [4, 19, 24, 23, 15]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.11281378471864138
# 28 :	 0.09913743859026558
# 11 :	 0.13562047336654862
# 2 :	 0.10274637157812
# 6 :	 0.15372672345788008
# Switches in the controller 6 : [1, 8, 18, 21, 20, 25]
# Switch selected is : 18
# The target controller set for 14 is : [30, 22, 31, 10]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.13117588848380196
# 28 :	 0.09913743859026558
# 11 :	 0.13562047336654862
# 2 :	 0.10274637157812
# 6 :	 0.13536461969271948
# Switches in the controller 6 : [1, 8, 21, 20, 25]
# Switch selected is : 25
# The target controller set for 2 is : [4, 19, 24, 23, 15, 5]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13117588848380196
# 28 :	 0.09913743859026558
# 11 :	 0.13562047336654862
# 2 :	 0.13822922229621795
# 6 :	 0.09988176897462153
# Switches in the controller 11 : [27, 7, 16, 9, 26, 33]
# Switch selected is : 16
# The target controller set for 28 is : [13, 12, 3, 0, 32, 17, 29]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13117588848380196
# 28 :	 0.09933248333820896
# 11 :	 0.13542542861860524
# 2 :	 0.13822922229621795
# 6 :	 0.09988176897462153
# Switches in the controller 11 : [27, 7, 9, 26, 33]
# Switch selected is : 33
# The target controller set for 2 is : [4, 19, 24, 23, 15, 5, 25]
# The mean load ratio is : 0.12080895834229115
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13117588848380196
# 28 :	 0.09933248333820896
# 11 :	 0.13521460832545204
# 2 :	 0.13844004258937115
# 6 :	 0.09988176897462153
# Switches in the controller 11 : [27, 7, 9, 26]
# Switch selected is : 9
# The target controller set for 6 is : [1, 8, 21, 20]
# The mean load ratio is : 0.12080895834229115
#
# At time step 996 the number of switch migrated are : 8
# The migrated switches are [25, 10, 5, 18, 25, 16, 33, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 997
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.10326364273994643
# 28 :	 0.10583795199250434
# 11 :	 0.06760213567322781
# 2 :	 0.12623259378782783
# 6 :	 0.09153096095205945
# Switches in the controller 28 : [13, 12, 3, 0, 32, 17, 29, 16]
# Switch selected is : 13
# The target controller set for 6 is : [1, 8, 21, 20, 9]
# The mean load ratio is : 0.09889345702911319
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.10326364273994643
# 28 :	 0.10578109735285733
# 11 :	 0.06760213567322781
# 2 :	 0.12623259378782783
# 6 :	 0.09158781559170646
# Switches in the controller 28 : [12, 3, 0, 32, 17, 29, 16]
# Switch selected is : 0
# The target controller set for 11 is : [27, 7, 26]
# The mean load ratio is : 0.09889345702911319
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10326364273994643
# 28 :	 0.08741907096069115
# 11 :	 0.085964162065394
# 2 :	 0.12623259378782783
# 6 :	 0.09158781559170646
# Switches in the controller 14 : [30, 22, 31, 10, 18]
# Switch selected is : 31
# The target controller set for 28 is : [12, 3, 32, 17, 29, 16]
# The mean load ratio is : 0.09889345702911319
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.0807293191275033
# 28 :	 0.10995339457313429
# 11 :	 0.085964162065394
# 2 :	 0.12623259378782783
# 6 :	 0.09158781559170646
# Switches in the controller 2 : [4, 19, 24, 23, 15, 5, 25, 33]
# Switch selected is : 24
# The target controller set for 28 is : [12, 3, 32, 17, 29, 16, 31]
# The mean load ratio is : 0.09889345702911319
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.0807293191275033
# 28 :	 0.12831555047885046
# 11 :	 0.085964162065394
# 2 :	 0.10787043788211165
# 6 :	 0.09158781559170646
# Switches in the controller 2 : [4, 19, 23, 15, 5, 25, 33]
# Switch selected is : 4
# The target controller set for 28 is : [12, 3, 32, 17, 29, 16, 31, 24]
# The mean load ratio is : 0.09889345702911319
#
# At time step 997 the number of switch migrated are : 5
# The migrated switches are [13, 0, 31, 24, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 998
# The overloaded domains are : [11, 28, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08484268837225444
# 28 :	 0.09160476248362784
# 11 :	 0.08237943034199646
# 2 :	 0.07982683857024224
# 6 :	 0.12230912480285465
# Switches in the controller 6 : [1, 8, 21, 20, 9, 13]
# Switch selected is : 21
# The target controller set for 28 is : [12, 3, 32, 17, 29, 16, 31, 24, 4]
# The mean load ratio is : 0.09219256891419512
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08484268837225444
# 28 :	 0.10996692042314846
# 11 :	 0.08237943034199646
# 2 :	 0.07982683857024224
# 6 :	 0.10394696686333404
# Switches in the controller 6 : [1, 8, 20, 9, 13]
# Switch selected is : 13
# The target controller set for 14 is : [30, 22, 10, 18]
# The mean load ratio is : 0.09219256891419512
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08488073638782417
# 28 :	 0.10996692042314846
# 11 :	 0.08237943034199646
# 2 :	 0.07982683857024224
# 6 :	 0.1039089188477643
# Switches in the controller 6 : [1, 8, 20, 9]
# Switch selected is : 1
# The target controller set for 11 is : [27, 7, 26, 0]
# The mean load ratio is : 0.09219256891419512
#
# At time step 998 the number of switch migrated are : 3
# The migrated switches are [21, 13, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09390809182295952
# 28 :	 0.1520029462029408
# 11 :	 0.1539338997265671
# 2 :	 0.10071518302759562
# 6 :	 0.06886911983159628
# Switches in the controller 11 : [27, 7, 26, 0, 1]
# Switch selected is : 7
# The target controller set for 6 is : [8, 20, 9]
# The mean load ratio is : 0.11388584812233186
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09390809182295952
# 28 :	 0.1520029462029408
# 11 :	 0.11802633433482221
# 2 :	 0.10071518302759562
# 6 :	 0.10477668522334117
# Switches in the controller 11 : [27, 26, 0, 1]
# Switch selected is : 0
# The target controller set for 14 is : [30, 22, 10, 18, 13]
# The mean load ratio is : 0.11388584812233186
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1122701182151257
# 28 :	 0.1520029462029408
# 11 :	 0.09966430794265602
# 2 :	 0.10071518302759562
# 6 :	 0.10477668522334117
# Switches in the controller 28 : [12, 3, 32, 17, 29, 16, 31, 24, 4, 21]
# Switch selected is : 32
# The target controller set for 6 is : [8, 20, 9, 7]
# The mean load ratio is : 0.11388584812233186
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1122701182151257
# 28 :	 0.15179228162059552
# 11 :	 0.09966430794265602
# 2 :	 0.10071518302759562
# 6 :	 0.10498734980568644
# Switches in the controller 28 : [12, 3, 17, 29, 16, 31, 24, 4, 21]
# Switch selected is : 21
# The target controller set for 6 is : [8, 20, 9, 7, 32]
# The mean load ratio is : 0.11388584812233186
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1122701182151257
# 28 :	 0.1334301486570775
# 11 :	 0.09966430794265602
# 2 :	 0.10071518302759562
# 6 :	 0.12334948276920446
# Switches in the controller 28 : [12, 3, 17, 29, 16, 31, 24, 4]
# Switch selected is : 31
# The target controller set for 11 is : [27, 26, 1]
# The mean load ratio is : 0.11388584812233186
#
# At time step 999 the number of switch migrated are : 5
# The migrated switches are [7, 0, 32, 21, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 0.7
epsilon_dec = 0.0025
epsilon_min = 0.05

load_controller = []

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon * epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# Switch selected is : 1
# The underloaded domains are : [14, 28, 2]
# The target controller set for 14 is : [13, 19, 31, 3, 9]
# The mean load ratio is : 0.11641456395659586
# The reward is = 0.6897306579749171
# Q value = 6.2653398129457525
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13447649506842332
# 28 :	 0.09188990356567737
# 11 :	 0.15627779114890286
# 2 :	 0.10226745329321311
# 6 :	 0.09716117670676258
# [(824896.3577, 27), (824885.1919, 26), (824882.3156, 29), (644670.839, 10), (415311.158, 23)]
# Switches in the controller 11 : [23, 29, 26, 27, 10]
# Switch selected is : 27
# The underloaded domains are : [28, 2, 6]
# The target controller set for 6 is : [32, 18, 0, 4, 30]
# The mean load ratio is : 0.11641456395659586
# The reward is = 1.8330737542009936
# Q value = 6.747526083949625
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13447649506842332
# 28 :	 0.09188990356567737
# 11 :	 0.11980653328209792
# 2 :	 0.10226745329321311
# 6 :	 0.13363243457356752
# [(824885.1919, 26), (824882.3156, 29), (644670.839, 10), (415311.158, 23)]
# Switches in the controller 11 : [23, 29, 26, 10]
# Switch selected is : 26
# The underloaded domains are : [28, 2]
# The target controller set for 28 is : [12, 17, 16, 22, 7, 25]
# The mean load ratio is : 0.11641456395659586
# The reward is = 0.7836272933237669
# Q value = 5.652390968125673
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.13447649506842332
# 28 :	 0.1283606677574075
# 11 :	 0.08333576909036779
# 2 :	 0.10226745329321311
# 6 :	 0.13363243457356752
# [(861788.9357, 1), (824883.2243, 31), (506346.1671, 3), (430349.9847, 9), (415313.5613, 19), (2868.582421, 13)]
# Switches in the controller 14 : [13, 19, 31, 3, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [11, 2]
# Taking a random action
# The target controller set for 11 is : [23, 29, 10]
# The mean load ratio is : 0.11641456395659586
# The reward is = 1.0862777053871528
# Q value = 6.757909163556641
#
# At time step 913 the number of switch migrated are : 4
# The migrated switches are [1, 27, 26, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 914
# 0.13437228096646162
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.10261351420070136
# 28 :	 0.12605869788948157
# 11 :	 0.09946133657345885
# 2 :	 0.10434584640109647
# 6 :	 0.13844623470656325
# [(807124.583, 25), (807120.3544, 26), (807118.4189, 7), (415307.4348, 22), (8033.532848000001, 17), (6211.0, 12), (243.83061690000002, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 7, 25, 26]
# Switch selected is : 25
# The underloaded domains are : [14, 11, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 5, 8]
# The mean load ratio is : 0.1141851259542603
# The reward is = 0.9279622405424789
# Q value = 6.488651926021899
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.10261351420070136
# 28 :	 0.09037318597946771
# 11 :	 0.09946133657345885
# 2 :	 0.14003135831111033
# 6 :	 0.13844623470656325
# [(807119.5705, 30), (807111.9767, 27), (680278.0076, 4), (415311.8401, 18), (415307.0, 0), (6208.483137, 32)]
# Switches in the controller 6 : [32, 18, 0, 4, 30, 27]
# Switch selected is : 30
# The underloaded domains are : [14, 28, 11]
# The target controller set for 11 is : [23, 29, 10, 1]
# The mean load ratio is : 0.1141851259542603
# The reward is = 1.2243454168667973
# Q value = 6.841522163591997
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10261351420070136
# 28 :	 0.09037318597946771
# 11 :	 0.13514662686511017
# 2 :	 0.14003135831111033
# 6 :	 0.10276094441491193
# [(807124.583, 25), (697262.6498, 8), (415313.1897, 21), (415303.3384, 24), (415297.1365, 20), (404958.874, 5), (6217.6208240000005, 33), (5711.352855, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 5, 8, 25]
# Switch selected is : 25
# The underloaded domains are : [14, 28, 6]
# The target controller set for 6 is : [32, 18, 0, 4, 27]
# The mean load ratio is : 0.1141851259542603
# The reward is = 0.7910979476722568
# Q value = 5.763196492737609
#
# At time step 914 the number of switch migrated are : 3
# The migrated switches are [25, 30, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 915
# 0.22863974763721576
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11971477684672992
# 28 :	 0.06642518920293276
# 11 :	 0.14142553065685654
# 2 :	 0.10673386916135458
# 6 :	 0.10250288596794027
# [(1391219.801, 3), (535565.8949, 31), (415300.9573, 19), (360849.5754, 9), (4737.955394, 13)]
# Switches in the controller 14 : [13, 19, 31, 3, 9]
# Switch selected is : 3
# The underloaded domains are : [28, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 5, 8]
# The mean load ratio is : 0.10736045036716282
# The reward is = 0.4115770808334761
# Q value = 6.555550007245343
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.05820458148940103
# 28 :	 0.06642518920293276
# 11 :	 0.14142553065685654
# 2 :	 0.16824406451868346
# 6 :	 0.10250288596794027
# [(1391219.801, 3), (652636.7082, 8), (505428.1306, 5), (415309.9141, 21), (415305.6598, 20), (415299.8603, 24), (6856.476812999999, 33), (3239.020098, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 5, 8, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 28, 6]
# The target controller set for 14 is : [13, 19, 31, 9]
# The mean load ratio is : 0.10736045036716282
# The reward is = 2.4921066659329005
# Q value = 6.667204160209097
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11971477684672992
# 28 :	 0.06642518920293276
# 11 :	 0.14142553065685654
# 2 :	 0.10673386916135458
# 6 :	 0.10250288596794027
# [(887559.0261, 1), (824744.5624, 10), (535559.6245, 30), (535554.6552, 29), (415303.8636, 23)]
# Switches in the controller 11 : [23, 29, 10, 1, 30]
# Switch selected is : 1
# The underloaded domains are : [28, 2, 6]
# Taking a random action
# The target controller set for 28 is : [12, 17, 16, 22, 7, 26]
# The mean load ratio is : 0.10736045036716282
# The reward is = 8.524618833729706
# Q value = 10.100961496417291
#
# At time step 915 the number of switch migrated are : 3
# The migrated switches are [3, 3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 916
# 0.09829106409859553
# The overloaded domains are : [2, 11, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.09937755743405784
# 28 :	 0.08759421043392114
# 11 :	 0.0996063153270489
# 2 :	 0.09512002335376873
# 6 :	 0.1174137787264505
# [(665312.0731, 4), (576601.0424, 25), (576600.9878, 27), (415311.4917, 18), (415307.0, 0), (6498.279289, 32)]
# Switches in the controller 6 : [32, 18, 0, 4, 27, 25]
# Switch selected is : 4
# The underloaded domains are : [14, 28, 11, 2]
# The target controller set for 11 is : [23, 29, 10, 30]
# The mean load ratio is : 0.09982237705504941
# The reward is = 0.6612658711691674
# Q value = 7.375772216633561
#
# At time step 916 the number of switch migrated are : 1
# The migrated switches are [4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 917
# 0.12807597160853565
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.09508193372192691
# 28 :	 0.09307235968391578
# 11 :	 0.08849737015045844
# 2 :	 0.10614483939523488
# 6 :	 0.07054963571132955
# [(910531.48, 1), (415313.5969, 22), (379772.2822, 7), (379763.3678, 26), (7844.290981, 17), (6336.683542, 16), (5522.0, 12)]
# Switches in the controller 28 : [12, 17, 16, 22, 7, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [11, 6]
# The target controller set for 11 is : [23, 29, 10, 30, 4]
# The mean load ratio is : 0.0906692277325731
# The reward is = 0.2988706835314878
# Q value = 6.880098140495107
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09508193372192691
# 28 :	 0.052814904195185426
# 11 :	 0.1287548256391888
# 2 :	 0.10614483939523488
# 6 :	 0.07054963571132955
# [(910531.48, 1), (492649.0302, 4), (415305.3628, 23), (379770.9566, 29), (379766.6406, 30), (334115.9217, 10)]
# Switches in the controller 11 : [23, 29, 10, 30, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [28, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 7, 26]
# The mean load ratio is : 0.0906692277325731
# The reward is = 5.669637633876769
# Q value = 10.331808397900923
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.09508193372192691
# 28 :	 0.09307235968391578
# 11 :	 0.08849737015045844
# 2 :	 0.10614483939523488
# 6 :	 0.07054963571132955
# [(925079.4513, 3), (425562.5879, 9), (415310.2159, 19), (379757.8426, 31), (4825.567857, 13)]
# Switches in the controller 14 : [13, 19, 31, 9, 3]
# Switch selected is : 3
# The underloaded domains are : [11, 6]
# The target controller set for 11 is : [23, 29, 10, 30, 4]
# The mean load ratio is : 0.0906692277325731
# The reward is = 0.4067783087595893
# Q value = 7.286590177796797
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.05418126674636134
# 28 :	 0.09307235968391578
# 11 :	 0.12939803712602402
# 2 :	 0.10614483939523488
# 6 :	 0.07054963571132955
# [(630207.964, 5), (513619.7154, 8), (415309.1158, 20), (415308.5495, 21), (415302.7277, 24), (5525.451334, 33), (5479.741359000001, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 5, 8]
# Switch selected is : 5
# The underloaded domains are : [14, 6]
# The target controller set for 14 is : [13, 19, 31, 9]
# The mean load ratio is : 0.0906692277325731
# The reward is = 5.325213395912376
# Q value = 8.922377576305719
#
# At time step 917 the number of switch migrated are : 4
# The migrated switches are [1, 1, 3, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 918
# 0.19312480039835087
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08205079051655267
# 28 :	 0.07746008976256552
# 11 :	 0.11571579925042301
# 2 :	 0.07797135154837392
# 6 :	 0.06855203497720914
# [(801727.702, 10), (415306.977, 23), (363115.8473, 4), (356650.8343, 29), (356643.0134, 30), (323782.0918, 3)]
# Switches in the controller 11 : [23, 29, 10, 30, 4, 3]
# Switch selected is : 10
# The underloaded domains are : [14, 28, 2, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 7, 26, 1]
# The mean load ratio is : 0.08435001321102485
# The reward is = 0.5918725621389648
# Q value = 7.377488115451694
#
# At time step 918 the number of switch migrated are : 1
# The migrated switches are [10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 919
# 0.2771862163370319
# The overloaded domains are : [11, 28, 6, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.096213501210432
# 28 :	 0.16274525847291046
# 11 :	 0.14871315927698073
# 2 :	 0.07717277492771016
# 6 :	 0.10302061764396984
# [(808233.8904, 3), (747037.6484, 30), (747032.4462, 29), (645941.7841, 4), (415305.4382, 23)]
# Switches in the controller 11 : [23, 29, 30, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 2, 6]
# The target controller set for 14 is : [13, 19, 31, 9, 5]
# The mean load ratio is : 0.11757306230640063
# The reward is = 1.8445188849348597
# Q value = 7.367460449656701
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1319480590834463
# 28 :	 0.16274525847291046
# 11 :	 0.11297860140396643
# 2 :	 0.07717277492771016
# 6 :	 0.10302061764396984
# [(808233.8904, 3), (747029.0899, 31), (573028.6878, 5), (439112.2052, 9), (415302.874, 19), (1656.2747, 13)]
# Switches in the controller 14 : [13, 19, 31, 9, 5, 3]
# Switch selected is : 3
# The underloaded domains are : [11, 2, 6]
# The target controller set for 11 is : [23, 29, 30, 4]
# The mean load ratio is : 0.11757306230640063
# The reward is = 0.7775500181256515
# Q value = 6.479711090483821
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.09621350121043201
# 28 :	 0.16274525847291046
# 11 :	 0.14871315927698073
# 2 :	 0.07717277492771016
# 6 :	 0.10302061764396984
# [(1144796.131, 1), (747037.9624, 7), (747029.4859999999, 26), (604794.2453, 10), (415305.5784, 22), (11192.5153, 16), (5390.248413, 17), (5379.0, 12)]
# Switches in the controller 28 : [12, 17, 16, 22, 7, 26, 1, 10]
# Switch selected is : 1
# The underloaded domains are : [14, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8]
# The mean load ratio is : 0.11757306230640063
# The reward is = 1.7025339258583905
# Q value = 7.364379707972196
#
# At time step 919 the number of switch migrated are : 3
# The migrated switches are [3, 3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 920
# 0.13003162241096972
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.0888871132703959
# 28 :	 0.0948773003422119
# 11 :	 0.12408994641230045
# 2 :	 0.09606937196487979
# 6 :	 0.0906442793479476
# [(632181.4199, 3), (606160.3428, 30), (606154.7911, 29), (546832.1946, 4), (415301.7549, 23)]
# Switches in the controller 11 : [23, 29, 30, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 28, 2, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 7, 26, 10]
# The mean load ratio is : 0.09891360226754714
# The reward is = 1.1720657987296743
# Q value = 6.747274202766804
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.0888871132703959
# 28 :	 0.12282802574978001
# 11 :	 0.09613922100473234
# 2 :	 0.09606937196487979
# 6 :	 0.0906442793479476
# [(632181.4199, 3), (606154.466, 7), (606151.8075, 26), (501905.8687, 10), (415299.4511, 22), (7446.467645000001, 17), (7269.0, 12), (1680.266039, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 7, 26, 10, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 11, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 1]
# The mean load ratio is : 0.09891360226754714
# The reward is = 1.502240141792506
# Q value = 7.594494550312784
#
# At time step 920 the number of switch migrated are : 2
# The migrated switches are [3, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 921
# 0.22130019476187435
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.0880047199009544
# 28 :	 0.09663229026154192
# 11 :	 0.0947378740434175
# 2 :	 0.14884175867407307
# 6 :	 0.0892557699428034
# [(980168.9768, 1), (709400.1524, 3), (420666.1212, 8), (415306.6665, 21), (415305.1064, 24), (415304.805, 20), (6200.868598, 33), (4107.1343560000005, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 1, 3]
# Switch selected is : 1
# The underloaded domains are : [14, 28, 11, 6]
# The target controller set for 14 is : [13, 19, 31, 9, 5]
# The mean load ratio is : 0.10349448256455807
# The reward is = 1.0186029118936362
# Q value = 6.977358202045636
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.13134106776117377
# 28 :	 0.09663229026154192
# 11 :	 0.0947378740434175
# 2 :	 0.1055054108138537
# 6 :	 0.0892557699428034
# [(709400.1524, 3), (420666.1212, 8), (415306.6665, 21), (415305.1064, 24), (415304.805, 20), (6200.868598, 33), (4107.1343560000005, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 11, 6]
# The target controller set for 11 is : [23, 29, 30, 4]
# The mean load ratio is : 0.10349448256455807
# The reward is = 0.7707285302472898
# Q value = 6.744999381241195
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.13134106776117377
# 28 :	 0.09663229026154192
# 11 :	 0.12610268205526298
# 2 :	 0.07414060280200821
# 6 :	 0.0892557699428034
# [(709400.1524, 3), (590969.2115, 29), (590963.8915, 30), (545511.221, 4), (415309.4993, 23)]
# Switches in the controller 11 : [23, 29, 30, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 2, 6]
# Taking a random action
# The target controller set for 6 is : [32, 18, 0, 27, 25]
# The mean load ratio is : 0.10349448256455807
# The reward is = 1.0400693293901515
# Q value = 6.420876362200036
#
# At time step 921 the number of switch migrated are : 3
# The migrated switches are [1, 3, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 922
# 0.16262870864035664
# The overloaded domains are : [11, 28, 14, 6]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.1414101917225023
# 28 :	 0.104638832330288
# 11 :	 0.11740455664857664
# 2 :	 0.08518510046557866
# 6 :	 0.11893107638219504
# [(777847.5524, 4), (731136.2687, 30), (731133.2641, 29), (415305.2068, 23)]
# Switches in the controller 11 : [23, 29, 30, 4]
# Switch selected is : 4
# The underloaded domains are : [28, 2]
# The target controller set for 28 is : [12, 17, 16, 22, 7, 26, 10]
# The mean load ratio is : 0.11351395150982813
# The reward is = 0.49548709837638566
# Q value = 6.185889651263922
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1414101917225023
# 28 :	 0.13902991479759694
# 11 :	 0.08301347418126771
# 2 :	 0.08518510046557866
# 6 :	 0.11893107638219504
# [(731154.5290000001, 31), (730212.3447, 5), (662996.5041, 1), (657254.5514, 9), (415309.6476, 19), (1447.2234210000001, 13)]
# Switches in the controller 14 : [13, 19, 31, 9, 5, 1]
# Switch selected is : 31
# The underloaded domains are : [11, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8]
# The mean load ratio is : 0.11351395150982813
# The reward is = 5.37708502110291
# Q value = 8.778961460419051
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.1090835544198567
# 28 :	 0.13902991479759694
# 11 :	 0.08301347418126771
# 2 :	 0.11751173776822427
# 6 :	 0.11893107638219504
# [(731135.6908, 25), (731129.9488, 27), (415307.0, 0), (415306.2368, 18), (390946.1763, 3), (6123.620946, 32)]
# Switches in the controller 6 : [32, 18, 0, 27, 25, 3]
# Switch selected is : 25
# The underloaded domains are : [14, 11]
# The target controller set for 11 is : [23, 29, 30]
# The mean load ratio is : 0.11351395150982813
# The reward is = 0.7808964374023173
# Q value = 6.513180137950629
#
# At time step 922 the number of switch migrated are : 3
# The migrated switches are [4, 31, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 923
# 0.49791173276131556
# The overloaded domains are : [2, 28, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.1119676970503153
# 28 :	 0.10156771866239435
# 11 :	 0.07873572785801784
# 2 :	 0.09944353796726398
# 6 :	 0.25722165198751185
# [(4525304.717, 3), (455172.0207, 27), (415307.0, 0), (415305.8037, 18), (6675.3577700000005, 32)]
# Switches in the controller 6 : [32, 18, 0, 27, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 28, 11, 2]
# The target controller set for 11 is : [23, 29, 30, 25]
# The mean load ratio is : 0.12978726670510066
# The reward is = 0.2165106939564571
# Q value = 5.82951186040994
#
# At time step 923 the number of switch migrated are : 1
# The migrated switches are [3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 924
# 0.29248066583814014
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.07165544226611079
# 28 :	 0.11952220366400593
# 11 :	 0.14469060956437504
# 2 :	 0.09513592808141635
# 6 :	 0.06761736004015133
# [(692580.0947, 7), (692564.2139, 26), (657165.9455, 4), (415305.5506, 22), (230704.1724, 10), (6606.293293, 17), (6135.0, 12), (2257.3490739999997, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 7, 26, 10, 4]
# Switch selected is : 7
# The underloaded domains are : [14, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 31]
# The mean load ratio is : 0.09972430872321189
# The reward is = 0.9707062656277816
# Q value = 6.55071202436095
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07165544226611079
# 28 :	 0.08890106321231511
# 11 :	 0.14469060956437504
# 2 :	 0.12575706853310717
# 6 :	 0.06761736004015133
# [(692580.0947, 7), (692576.3637, 31), (415317.4631, 21), (415307.8228, 24), (415302.9933, 20), (201240.1423, 8), (6153.276207, 33), (5858.83295, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 31, 7]
# Switch selected is : 7
# The underloaded domains are : [14, 28, 6]
# The target controller set for 14 is : [13, 19, 9, 5, 1]
# The mean load ratio is : 0.09972430872321189
# The reward is = 4.607712711037758
# Q value = 9.24273472081691
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1022765827178016
# 28 :	 0.08890106321231511
# 11 :	 0.14469060956437504
# 2 :	 0.09513592808141635
# 6 :	 0.06761736004015133
# [(692580.0947, 7), (446950.977, 5), (415307.7542, 19), (394595.3457, 9), (363375.4667, 1), (452.51651880000003, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 1, 7]
# Switch selected is : 7
# The underloaded domains are : [28, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 31]
# The mean load ratio is : 0.09972430872321189
# The reward is = 0.6081533477538781
# Q value = 7.758425175563049
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07165544226611079
# 28 :	 0.08890106321231511
# 11 :	 0.14469060956437504
# 2 :	 0.12575706853310717
# 6 :	 0.06761736004015133
# [(779502.6978, 3), (692591.2928, 30), (692587.0766, 29), (692577.8252, 25), (415311.4494, 23)]
# Switches in the controller 11 : [23, 29, 30, 25, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 28, 6]
# The target controller set for 14 is : [13, 19, 9, 5, 1]
# The mean load ratio is : 0.09972430872321189
# The reward is = 7.525994151450738
# Q value = 10.721119244469604
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.1061197039081451
# 28 :	 0.08890106321231511
# 11 :	 0.11022634792234073
# 2 :	 0.12575706853310717
# 6 :	 0.06761736004015133
# [(692591.2928, 30), (692587.0766, 29), (692577.8252, 25), (415311.4494, 23)]
# Switches in the controller 11 : [23, 29, 30, 25]
# Switch selected is : 30
# The underloaded domains are : [28, 6]
# Taking a random action
# The target controller set for 6 is : [32, 18, 0, 27]
# The mean load ratio is : 0.09972430872321189
# The reward is = 1.060433167971777
# Q value = 5.836053167100296
#
# At time step 924 the number of switch migrated are : 5
# The migrated switches are [7, 7, 7, 3, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 925
# 0.16646905256225186
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.1411377789646574
# 28 :	 0.11633236288743114
# 11 :	 0.09206989747774377
# 2 :	 0.14697416629608975
# 6 :	 0.11071791827567976
# [(833555.4639, 31), (833549.5931, 7), (415312.9453, 21), (415309.5033, 24), (415309.2629, 20), (400140.0419, 8), (6459.208624, 33), (4583.148201, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 31, 7]
# Switch selected is : 31
# The underloaded domains are : [28, 11, 6]
# The target controller set for 11 is : [23, 29, 25]
# The mean load ratio is : 0.12144642478032038
# The reward is = 2.542489187420899
# Q value = 8.72636334762625
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1411377789646574
# 28 :	 0.11633236288743114
# 11 :	 0.12892400161628736
# 2 :	 0.11012006215754616
# 6 :	 0.11071791827567976
# [(890233.6634, 1), (678283.0312, 9), (656633.7965, 3), (546908.9217, 5), (415308.8788, 19), (4845.155685, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 1, 3]
# Switch selected is : 1
# The underloaded domains are : [28, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 7]
# The mean load ratio is : 0.12144642478032038
# The reward is = 0.5852446976071398
# Q value = 7.336465471532605
#
# At time step 925 the number of switch migrated are : 2
# The migrated switches are [31, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 926
# 0.19127893791693756
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10927960150399332
# 28 :	 0.09937203069154618
# 11 :	 0.10571880036593338
# 2 :	 0.1549692073481877
# 6 :	 0.09516930286228932
# [(1203500.014, 1), (658598.3676, 7), (415310.2567, 24), (415308.4804, 21), (415306.9559, 20), (386381.0071, 8), (5931.781774, 15), (4711.828952000001, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 28, 11, 6]
# The target controller set for 14 is : [13, 19, 9, 5, 3]
# The mean load ratio is : 0.11290178855439
# The reward is = 0.48345613403474497
# Q value = 7.0684830667913054
#
# At time step 926 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 927
# 0.04757815212590836
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.1094227951336328
# 28 :	 0.11237070290471159
# 11 :	 0.11728707205694895
# 2 :	 0.10462405970820976
# 6 :	 0.10295966380531861
# [(745823.7562, 26), (688483.2889, 10), (678668.8782, 4), (415310.1526, 22), (6466.0, 12), (6018.88175, 17), (797.0868855, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 26, 10, 4]
# Switch selected is : 26
# The underloaded domains are : [2, 6]
# Taking a random action
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 7]
# The mean load ratio is : 0.10933285872176435
# The reward is = 0.4142433806113429
# Q value = 6.533903444114211
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1094227951336328
# 28 :	 0.07939549301118964
# 11 :	 0.11728707205694895
# 2 :	 0.1375992696017317
# 6 :	 0.10295966380531861
# [(746228.3561, 1), (612910.7484, 5), (581414.5261, 9), (415308.3325, 19), (115975.9102, 3), (3055.246228, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [28, 6]
# The target controller set for 6 is : [32, 18, 0, 27, 30]
# The mean load ratio is : 0.10933285872176435
# The reward is = 0.7136139792566975
# Q value = 5.723654370312346
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07642969660822632
# 28 :	 0.07939549301118964
# 11 :	 0.11728707205694895
# 2 :	 0.1375992696017317
# 6 :	 0.1359527623307251
# [(745825.0743, 31), (745816.3358, 29), (745813.8919, 25), (415309.7575, 23)]
# Switches in the controller 11 : [23, 29, 25, 31]
# Switch selected is : 31
# The underloaded domains are : [14, 28]
# The target controller set for 14 is : [13, 19, 9, 5, 3]
# The mean load ratio is : 0.10933285872176435
# The reward is = 0.8577670026914006
# Q value = 7.884423397446376
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10940496477908765
# 28 :	 0.07939549301118964
# 11 :	 0.08431180388608762
# 2 :	 0.1375992696017317
# 6 :	 0.1359527623307251
# [(745823.7562, 26), (745822.9268, 7), (415310.4074, 20), (415309.0844, 24), (415308.9042, 21), (360622.6398, 8), (7523.894509999999, 15), (6458.85305, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 7, 26]
# Switch selected is : 26
# The underloaded domains are : [28, 11]
# The target controller set for 11 is : [23, 29, 25]
# The mean load ratio is : 0.10933285872176435
# The reward is = 3.5048863359462263
# Q value = 8.904934967545714
#
# At time step 927 the number of switch migrated are : 4
# The migrated switches are [26, 1, 31, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 928
# 0.44587907057293014
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.25524478812035944
# 28 :	 0.08414376692767188
# 11 :	 0.10256135472585746
# 2 :	 0.10697985371459089
# 6 :	 0.13993889389697103
# [(3286773.0739999996, 3), (741701.5451, 5), (691538.7062, 9), (634802.0827, 31), (415306.9982, 19), (2930.358016, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 3, 31]
# Switch selected is : 3
# The underloaded domains are : [28, 11, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 7]
# The mean load ratio is : 0.13777373147709013
# The reward is = 0.5088418862992676
# Q value = 6.979964006761802
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10992623117369307
# 28 :	 0.08414376692767188
# 11 :	 0.10256135472585746
# 2 :	 0.25229841066125724
# 6 :	 0.13993889389697103
# [(3286773.0739999996, 3), (634802.8669, 7), (526876.3692, 8), (415312.0636, 20), (415311.7218, 21), (415303.6941, 24), (6362.040245, 33), (5670.6215170000005, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 7, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 28, 11]
# The target controller set for 11 is : [23, 29, 25, 26]
# The mean load ratio is : 0.13777373147709013
# The reward is = 0.5037042149309285
# Q value = 7.175654342904321
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.10992623117369307
# 28 :	 0.08414376692767188
# 11 :	 0.24787991167252382
# 2 :	 0.10697985371459087
# 6 :	 0.13993889389697103
# [(1058530.7079999999, 1), (634806.9732, 30), (634791.0471, 27), (415312.7451, 18), (415307.0, 0), (6348.938314, 32)]
# Switches in the controller 6 : [32, 18, 0, 27, 30, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 28, 2]
# The target controller set for 14 is : [13, 19, 9, 5, 31]
# The mean load ratio is : 0.13777373147709013
# The reward is = 0.4365955446241385
# Q value = 5.69967813479274
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.15672719719934242
# 28 :	 0.08414376692767188
# 11 :	 0.24787991167252382
# 2 :	 0.10697985371459087
# 6 :	 0.09313792787132169
# [(3286773.0739999996, 3), (634802.2033, 29), (634800.9111, 25), (634791.0543, 26), (415308.87700000004, 23)]
# Switches in the controller 11 : [23, 29, 25, 26, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 2, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 10, 4]
# The mean load ratio is : 0.13777373147709013
# The reward is = 0.37377140934396147
# Q value = 5.588259925119891
#
# At time step 928 the number of switch migrated are : 4
# The migrated switches are [3, 3, 1, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 929
# 0.21160643799533016
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.1589364449454774
# 28 :	 0.10194896885482381
# 11 :	 0.10104858425938314
# 2 :	 0.10818770792672708
# 6 :	 0.09215488534960299
# [(1204523.832, 1), (896310.0023, 9), (623396.0261, 31), (451520.19, 5), (415308.1752, 19), (3720.2989060000004, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 31, 1]
# Switch selected is : 1
# The underloaded domains are : [28, 11, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8, 7]
# The mean load ratio is : 0.1124553182672029
# The reward is = 0.5322625256573743
# Q value = 6.125117942118959
#
# At time step 929 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 930
# 0.1733909982523166
# The overloaded domains are : [2, 11, 6, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09319508212444871
# 28 :	 0.08361425101834605
# 11 :	 0.12384247465509769
# 2 :	 0.13456832353044443
# 6 :	 0.10731886180862578
# [(795243.6047, 29), (795241.3479, 25), (795239.9189, 26), (415308.3872, 23)]
# Switches in the controller 11 : [23, 29, 25, 26]
# Switch selected is : 29
# The underloaded domains are : [14, 28, 6]
# The target controller set for 14 is : [13, 19, 9, 5, 31]
# The mean load ratio is : 0.10850779862739254
# The reward is = 0.6838319977071559
# Q value = 6.285547215606049
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.12835529868160467
# 28 :	 0.08361425101834605
# 11 :	 0.08868225809794172
# 2 :	 0.13456832353044443
# 6 :	 0.10731886180862578
# [(795241.948, 7), (552749.3477, 8), (438407.4028, 1), (415311.6313, 20), (415311.5681, 24), (415305.3895, 21), (6233.15967, 33), (5066.958035000001, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 7, 1]
# Switch selected is : 7
# The underloaded domains are : [28, 11, 6]
# The target controller set for 11 is : [23, 25, 26]
# The mean load ratio is : 0.10850779862739254
# The reward is = 1.8273599140239578
# Q value = 6.606607516130643
#
# At time step 930 the number of switch migrated are : 2
# The migrated switches are [29, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 931
# 0.22505127282164117
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.13832282646328764
# 28 :	 0.06527100859991873
# 11 :	 0.11425908340058387
# 2 :	 0.10648574055544478
# 6 :	 0.10084867697792911
# [(722993.5031, 29), (722990.3923, 31), (661976.5053, 5), (603462.8984, 9), (415311.5677, 19), (1810.7992980000001, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 31, 29]
# Switch selected is : 29
# The underloaded domains are : [28, 6]
# The target controller set for 6 is : [32, 18, 0, 27, 30]
# The mean load ratio is : 0.10503746719943283
# The reward is = 1.2914065453828878
# Q value = 5.591904437190592
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10635701373851564
# 28 :	 0.06527100859991873
# 11 :	 0.11425908340058387
# 2 :	 0.10648574055544478
# 6 :	 0.1328144897027011
# [(722990.3923, 31), (661976.5053, 5), (603462.8984, 9), (415311.5677, 19), (1810.7992980000001, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 31]
# Switch selected is : 31
# The underloaded domains are : [28]
# The target controller set for 28 is : [12, 17, 16, 22, 10, 4, 3]
# The mean load ratio is : 0.10503746719943283
# The reward is = 0.9390754471912044
# Q value = 5.625764546616386
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07439133855197849
# 28 :	 0.09723668378645588
# 11 :	 0.11425908340058387
# 2 :	 0.10648574055544478
# 6 :	 0.1328144897027011
# [(722994.212, 30), (722993.5031, 29), (722990.5485, 27), (415307.3593, 18), (415307.0, 0), (4367.07615, 32)]
# Switches in the controller 6 : [32, 18, 0, 27, 30, 29]
# Switch selected is : 30
# The underloaded domains are : [14, 28]
# The target controller set for 28 is : [12, 17, 16, 22, 10, 4, 3, 31]
# The mean load ratio is : 0.10503746719943283
# The reward is = 1.352261462909002
# Q value = 6.108235012787556
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07439133855197849
# 28 :	 0.12920252785392258
# 11 :	 0.11425908340058387
# 2 :	 0.10648574055544478
# 6 :	 0.1008486456352344
# [(722994.8287, 26), (722992.3995, 25), (722992.0872, 7), (415299.5728, 23)]
# Switches in the controller 11 : [23, 25, 26, 7]
# Switch selected is : 26
# The underloaded domains are : [14, 6]
# The target controller set for 14 is : [13, 19, 9, 5]
# The mean load ratio is : 0.10503746719943283
# The reward is = 0.7839529548372288
# Q value = 5.7060693171479615
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10635720988568842
# 28 :	 0.12920252785392258
# 11 :	 0.08229321206687394
# 2 :	 0.10648574055544478
# 6 :	 0.1008486456352344
# [(759274.4770000001, 1), (415316.3299, 20), (415312.5168, 24), (415303.0024, 21), (392844.4532, 8), (6044.844247, 15), (4368.04535, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [11, 6]
# The target controller set for 11 is : [23, 25, 7]
# The mean load ratio is : 0.10503746719943283
# The reward is = 0.6279423625921242
# Q value = 5.532374779252726
#
# At time step 931 the number of switch migrated are : 5
# The migrated switches are [29, 31, 30, 26, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 932
# 0.3058321947621126
# The overloaded domains are : [11, 28, 14, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08237047790401202
# 28 :	 0.14939116187423204
# 11 :	 0.08619163581718964
# 2 :	 0.07379201441563989
# 6 :	 0.07420362163033546
# [(787638.0283, 3), (699521.3917, 4), (620821.9236, 10), (420097.4268, 31), (420093.57700000005, 30), (415310.5535, 22), (7517.0, 12), (7287.743820999999, 17), (598.4291477999999, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 10, 4, 3, 31, 30]
# Switch selected is : 3
# The underloaded domains are : [14, 11, 2, 6]
# The target controller set for 11 is : [23, 25, 7, 1]
# The mean load ratio is : 0.0931897823282818
# The reward is = 6.088945552704389
# Q value = 8.91837294306587
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08237047790401202
# 28 :	 0.1145672117286329
# 11 :	 0.12101558596278877
# 2 :	 0.07379201441563989
# 6 :	 0.07420362163033546
# [(699521.3917, 4), (620821.9236, 10), (420097.4268, 31), (420093.57700000005, 30), (415310.5535, 22), (7517.0, 12), (7287.743820999999, 17), (598.4291477999999, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 10, 4, 31, 30]
# Switch selected is : 4
# The underloaded domains are : [14, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8]
# The mean load ratio is : 0.0931897823282818
# The reward is = 1.2764393679938424
# Q value = 6.348187886494338
#
# At time step 932 the number of switch migrated are : 2
# The migrated switches are [3, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 933
# 0.14490991925407473
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.08575599854956073
# 28 :	 0.09380871889104954
# 11 :	 0.1273425735423477
# 2 :	 0.10995206851744031
# 6 :	 0.09420772506002784
# [(624285.2321, 4), (606889.4629, 8), (415308.6553, 21), (415306.3629, 20), (415306.2243, 24), (6314.72196, 33), (3453.4123210000002, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 4]
# Switch selected is : 4
# The underloaded domains are : [14, 28, 6]
# The target controller set for 14 is : [13, 19, 9, 5, 26]
# The mean load ratio is : 0.10221341691208523
# The reward is = 0.9016725171238211
# Q value = 6.089875394994019
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.11335760870315745
# 28 :	 0.09380871889104954
# 11 :	 0.1273425735423477
# 2 :	 0.0823504583638436
# 6 :	 0.09420772506002784
# [(802983.1997, 3), (646902.7796, 7), (646891.7235, 25), (415312.2219, 23), (368107.5579, 1)]
# Switches in the controller 11 : [23, 25, 7, 1, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8]
# The mean load ratio is : 0.10221341691208523
# The reward is = 2.015294640812554
# Q value = 6.160225741094729
#
# At time step 933 the number of switch migrated are : 2
# The migrated switches are [4, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 934
# 0.0776183230109214
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.11005168698462058
# 28 :	 0.10135125417921059
# 11 :	 0.08954923147548832
# 2 :	 0.09920960900706023
# 6 :	 0.0902258897060501
# [(656650.3132, 10), (603230.2316, 30), (603211.8194, 31), (415306.7873, 22), (6767.434676999999, 17), (3672.0, 12), (3494.7554939999995, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 10, 31, 30]
# Switch selected is : 10
# The underloaded domains are : [11, 6]
# The target controller set for 11 is : [23, 25, 7, 1]
# The mean load ratio is : 0.09807753427048596
# The reward is = 0.4584897100421051
# Q value = 6.429737814511398
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.11005168698462058
# 28 :	 0.07231868217487984
# 11 :	 0.11858180347981907
# 2 :	 0.09920960900706023
# 6 :	 0.0902258897060501
# [(587867.0494, 3), (415307.2372, 24), (415304.1494, 20), (415301.0496, 21), (398410.5967, 8), (8029.767988, 15), (3674.3805509999997, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 31, 30]
# The mean load ratio is : 0.09807753427048596
# The reward is = 0.9765690974636786
# Q value = 5.616343219770676
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11005168698462058
# 28 :	 0.09831013013065151
# 11 :	 0.11858180347981907
# 2 :	 0.07321816105128856
# 6 :	 0.0902258897060501
# [(655230.1577, 5), (603211.0996, 26), (492578.1717, 9), (415321.3445, 19), (321877.9112, 4), (898.5287476999999, 13)]
# Switches in the controller 14 : [13, 19, 9, 5, 26, 4]
# Switch selected is : 5
# The underloaded domains are : [2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 8]
# The mean load ratio is : 0.09807753427048596
# The reward is = 1.085411194177992
# Q value = 5.659041559251866
#
# At time step 934 the number of switch migrated are : 3
# The migrated switches are [10, 3, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 935
# 0.2168294449384061
# The overloaded domains are : [2, 11, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.09248804965108927
# 28 :	 0.06568994937933804
# 11 :	 0.1218234021108378
# 2 :	 0.10455970789581272
# 6 :	 0.07602553336947326
# [(707993.8131, 4), (524119.602, 9), (443210.0278, 26), (415304.8347, 19), (1239.668567, 13)]
# Switches in the controller 14 : [13, 19, 9, 26, 4]
# Switch selected is : 4
# The underloaded domains are : [28, 6]
# The target controller set for 28 is : [12, 17, 16, 22, 31, 30, 3]
# The mean load ratio is : 0.09211732848131021
# The reward is = 0.4908329510311832
# Q value = 5.245295471360051
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.06118542031512196
# 28 :	 0.09699257871530535
# 11 :	 0.1218234021108378
# 2 :	 0.10455970789581272
# 6 :	 0.07602553336947326
# [(595516.4032, 8), (515663.8702, 5), (415305.0029, 21), (415303.5886, 20), (415302.0386, 24), (5344.737331, 15), (2465.5786559999997, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 8, 5]
# Switch selected is : 8
# The underloaded domains are : [14, 6]
# The target controller set for 14 is : [13, 19, 9, 26]
# The mean load ratio is : 0.09211732848131021
# The reward is = 2.2313531227334074
# Q value = 6.496240689640857
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08751507021875055
# 28 :	 0.09699257871530535
# 11 :	 0.1218234021108378
# 2 :	 0.07823005799218413
# 6 :	 0.07602553336947326
# [(890886.9253, 1), (562752.8853, 10), (443214.6204, 7), (443210.3621, 25), (415301.667, 23)]
# Switches in the controller 11 : [23, 25, 7, 1, 10]
# Switch selected is : 1
# The underloaded domains are : [14, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 5]
# The mean load ratio is : 0.09211732848131021
# The reward is = 0.7107306464233324
# Q value = 5.6189497739410506
#
# At time step 935 the number of switch migrated are : 3
# The migrated switches are [4, 8, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 936
# 0.13740012238871757
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.08634187671874015
# 28 :	 0.08750894384950363
# 11 :	 0.0873162398757794
# 2 :	 0.11172765639772586
# 6 :	 0.07396712588899802
# [(689895.6194, 5), (572943.4544, 1), (415308.1618, 21), (415307.86600000004, 24), (415304.9914, 20), (10820.34601, 33), (7443.365692, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 5, 1]
# Switch selected is : 5
# The underloaded domains are : [14, 28, 11, 6]
# The target controller set for 14 is : [13, 19, 9, 26, 8]
# The mean load ratio is : 0.08937236854614941
# The reward is = 0.6950954855534207
# Q value = 5.7370322251916
#
# At time step 936 the number of switch migrated are : 1
# The migrated switches are [5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 937
# 0.19036224722276526
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.11623120047228766
# 28 :	 0.1419728691640627
# 11 :	 0.0914424074759609
# 2 :	 0.10631120263186794
# 6 :	 0.0833230747249935
# [(1015753.9079999999, 3), (718474.9307, 4), (524079.0994, 30), (524064.2802, 31), (415310.2635, 22), (5780.0, 12), (5663.39449, 17), (1975.3994969999999, 16)]
# Switches in the controller 28 : [12, 17, 16, 22, 31, 30, 3, 4]
# Switch selected is : 3
# The underloaded domains are : [11, 2, 6]
# The target controller set for 11 is : [23, 25, 7, 10]
# The mean load ratio is : 0.10785615089383453
# The reward is = 0.9901669118597775
# Q value = 5.61713760310255
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.11623120047228766
# 28 :	 0.09706319977095848
# 11 :	 0.13635207686906514
# 2 :	 0.10631120263186794
# 6 :	 0.0833230747249935
# [(700738.5109, 8), (524089.9973, 26), (514014.2974, 5), (469170.0267, 9), (415311.6107, 19), (5559.218508, 13)]
# Switches in the controller 14 : [13, 19, 9, 26, 8, 5]
# Switch selected is : 8
# The underloaded domains are : [28, 2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 1]
# The mean load ratio is : 0.10785615089383453
# The reward is = 0.4751186596659991
# Q value = 4.969230346450141
#
# At time step 937 the number of switch migrated are : 2
# The migrated switches are [3, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 938
# 0.059094747873477654
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.10447889135815411
# 28 :	 0.09894366278839002
# 11 :	 0.10770266909040346
# 2 :	 0.11250606062482006
# 6 :	 0.09525703612319096
# [(751784.7365, 1), (534299.6335, 8), (415310.0126, 21), (415308.08200000005, 20), (415297.7937, 24), (8154.007619, 33), (4475.260365, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 1, 8]
# Switch selected is : 1
# The underloaded domains are : [28, 6]
# The target controller set for 6 is : [32, 18, 0, 27, 29]
# The mean load ratio is : 0.1037776639969917
# The reward is = 0.8440764427051044
# Q value = 5.377183168088879
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.10447889135815411
# 28 :	 0.09894366278839002
# 11 :	 0.10770266909040346
# 2 :	 0.07926729707679245
# 6 :	 0.12849579967121857
# [(696879.9468, 9), (657859.661, 26), (588703.578, 5), (415311.977, 19), (4318.171622, 13)]
# Switches in the controller 14 : [13, 19, 9, 26, 5]
# Switch selected is : 9
# The underloaded domains are : [28, 2]
# The target controller set for 28 is : [12, 17, 16, 22, 31, 30, 4]
# The mean load ratio is : 0.1037776639969917
# The reward is = 0.40298814877184147
# Q value = 5.006149990134747
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.07366764094505496
# ...
# Switch selected is : 3
# The underloaded domains are : [28, 6]
# The target controller set for 6 is : [32, 18, 0, 22, 29]
# The mean load ratio is : 0.10861520382137187
# The reward is = 1.0187203906227575
# Q value = 13.040738265599678
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.12140177809039898
# 28 :	 0.07886754229323256
# 11 :	 0.08815297071859748
# 2 :	 0.1418417667215534
# 6 :	 0.11281196128307683
# [(669295.0093, 10), (552074.0496, 30), (552070.1211, 31), (552068.8928, 25), (415306.7969, 19), (5015.4203, 13)]
# Switches in the controller 14 : [13, 19, 31, 10, 30, 25]
# Switch selected is : 10
# The underloaded domains are : [28, 11]
# The target controller set for 11 is : [23, 7, 8, 27]
# The mean load ratio is : 0.10861520382137187
# The reward is = 0.8977962494477544
# Q value = 14.466529138834572
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.09181014437145923
# 28 :	 0.07886754229323256
# 11 :	 0.11774460443753723
# 2 :	 0.1418417667215534
# 6 :	 0.11281196128307683
# [(1132168.172, 1), (820802.8262, 4), (415307.506, 20), (415306.0093, 24), (415303.4791, 21), (4750.802432, 33), (4497.243644, 15)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 28]
# The target controller set for 28 is : [12, 17, 16, 9, 5, 26]
# The mean load ratio is : 0.10861520382137187
# The reward is = 0.8489656720340657
# Q value = 15.66803912895907
#
# At time step 993 the number of switch migrated are : 4
# The migrated switches are [1, 3, 10, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 994
# 0.20119400725791786
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.07273586122878212
# 28 :	 0.13184005701324883
# 11 :	 0.11879398684235928
# 2 :	 0.08978509351002767
# 6 :	 0.11210836744292749
# [(1093782.945, 1), (744211.4187, 9), (716970.3266, 5), (408277.615, 26), (7768.999511, 17), (6150.957615, 16), (4758.0, 12)]
# Switches in the controller 28 : [12, 17, 16, 9, 5, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 4]
# The mean load ratio is : 0.10505267320746907
# The reward is = 0.4504780095872679
# Q value = 13.94809840540553
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.07273586122878212
# 28 :	 0.08348047890984278
# 11 :	 0.11879398684235928
# 2 :	 0.13814467161343372
# 6 :	 0.11210836744292749
# [(1093782.945, 1), (771782.0416, 4), (415308.5868, 24), (415308.5622, 21), (415301.5039, 20), (8258.678265999999, 15), (4773.893486, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 28]
# The target controller set for 28 is : [12, 17, 16, 9, 5, 26]
# The mean load ratio is : 0.10505267320746907
# The reward is = 0.7528418324893915
# Q value = 13.114240071714033
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.07273586122878212
# 28 :	 0.13184005701324883
# 11 :	 0.11879398684235928
# 2 :	 0.08978509351002767
# 6 :	 0.11210836744292749
# [(747756.4441, 8), (707214.6527, 10), (415308.8425, 23), (408285.3186, 27), (408282.7642, 7)]
# Switches in the controller 11 : [23, 7, 8, 27, 10]
# Switch selected is : 8
# The underloaded domains are : [14, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 4]
# The mean load ratio is : 0.10505267320746907
# The reward is = 0.7025243901742579
# Q value = 13.619010950482576
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.07273586122878212
# 28 :	 0.13184005701324883
# 11 :	 0.08573332674879829
# 2 :	 0.12284575360358867
# 6 :	 0.11210836744292749
# [(876685.4031, 3), (415307.7722, 18), (415307.0, 0), (415304.9148, 22), (408298.9284, 29), (4730.5984659999995, 32)]
# Switches in the controller 6 : [32, 18, 0, 22, 29, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 11]
# The target controller set for 11 is : [23, 7, 27, 10]
# The mean load ratio is : 0.10505267320746907
# The reward is = 0.5525858017821526
# Q value = 11.390042379649875
#
# At time step 994 the number of switch migrated are : 4
# The migrated switches are [1, 1, 8, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 995
# 0.12341382042982867
# The overloaded domains are : [2, 11, 28, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08079679626611369
# 28 :	 0.0951952131032906
# 11 :	 0.09878701817617218
# 2 :	 0.10617469059318597
# 6 :	 0.07602339718063723
# [(635366.6151, 1), (522512.5768, 9), (516632.6238, 5), (468795.7961, 26), (4758.0, 12), (3594.786001, 17), (1437.388027, 16)]
# Switches in the controller 28 : [12, 17, 16, 9, 5, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 6]
# Taking a random action
# The target controller set for 14 is : [13, 19, 31, 30, 25]
# The mean load ratio is : 0.09139542306387993
# The reward is = 0.421187793521406
# Q value = 10.215079904127618
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.1088883491538991
# 28 :	 0.06710366021550519
# 11 :	 0.09878701817617218
# 2 :	 0.10617469059318597
# 6 :	 0.07602339718063723
# [(524523.2598, 10), (468794.8607, 27), (468790.8976, 7), (415307.3593, 23), (356919.8163, 3)]
# Switches in the controller 11 : [23, 7, 27, 10, 3]
# Switch selected is : 10
# The underloaded domains are : [28, 6]
# The target controller set for 6 is : [32, 18, 0, 22, 29]
# The mean load ratio is : 0.09139542306387993
# The reward is = 0.7401569676778024
# Q value = 11.14893783845556
#
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.1088883491538991
# 28 :	 0.06710366021550519
# 11 :	 0.07559619803648601
# 2 :	 0.10617469059318597
# 6 :	 0.0992142173203234
# [(583510.3105, 8), (560994.9195, 4), (415307.2511, 24), (415305.4447, 21), (415304.6862, 20), (6265.547122, 15), (4740.271729, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 4, 8]
# Switch selected is : 8
# The underloaded domains are : [28, 11]
# The target controller set for 11 is : [23, 7, 27, 3]
# The mean load ratio is : 0.09139542306387993
# The reward is = 1.0809836591935984
# Q value = 11.720786856659696
#
# At time step 995 the number of switch migrated are : 3
# The migrated switches are [1, 10, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 996
# 0.2995093503327665
# The overloaded domains are : [11, 28, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.17751139023819884
# 28 :	 0.08723665161906498
# 11 :	 0.14432431387574757
# 2 :	 0.08070738006454763
# 6 :	 0.1142650559138967
# [(1186159.478, 1), (802549.8206, 31), (802544.5019, 30), (802540.8508, 25), (415308.0189, 19), (5798.5923920000005, 13)]
# Switches in the controller 14 : [13, 19, 31, 30, 25, 1]
# Switch selected is : 1
# The underloaded domains are : [28, 2, 6]
# The target controller set for 28 is : [12, 17, 16, 9, 5, 26]
# The mean load ratio is : 0.12080895834229115
# The reward is = 2.264672701060209
# Q value = 11.722352536079274
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.12506755558009275
# 28 :	 0.13968048627717106
# 11 :	 0.14432431387574757
# 2 :	 0.08070738006454763
# 6 :	 0.1142650559138967
# [(802549.8206, 31), (802544.5019, 30), (802540.8508, 25), (415308.0189, 19), (5798.5923920000005, 13)]
# Switches in the controller 14 : [13, 19, 31, 30, 25]
# Switch selected is : 31
# The underloaded domains are : [2, 6]
# Taking a random action
# The target controller set for 6 is : [32, 18, 0, 22, 29, 10]
# The mean load ratio is : 0.12080895834229115
# The reward is = 0.44200044256521476
# Q value = 7.703253051591862
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.08958430827897469
# 28 :	 0.13968048627717106
# 11 :	 0.14432431387574757
# 2 :	 0.08070738006454763
# 6 :	 0.14974830321501476
# [(1186159.478, 1), (802543.2879, 26), (650615.4806, 9), (503240.3344, 5), (7524.776364, 17), (4758.0, 12), (4411.465674, 16)]
# Switches in the controller 28 : [12, 17, 16, 9, 5, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 2]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 4]
# The mean load ratio is : 0.12080895834229115
# The reward is = 0.5333284049635535
# Q value = 12.070359459023198
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.08958430827897469
# 28 :	 0.08723665161906496
# 11 :	 0.14432431387574757
# 2 :	 0.1331512147226537
# 6 :	 0.14974830321501476
# [(802549.8206, 31), (802544.7783, 29), (531188.8454, 10), (415308.75, 18), (415307.0, 0), (415306.3729, 22), (4758.226178, 32)]
# Switches in the controller 6 : [32, 18, 0, 22, 29, 10, 31]
# Switch selected is : 31
# The underloaded domains are : [14, 28]
# The target controller set for 28 is : [12, 17, 16, 9, 5, 26]
# The mean load ratio is : 0.12080895834229115
# The reward is = 4.004213150090889
# Q value = 14.025036116985598
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.08958430827897469
# 28 :	 0.12271989892018302
# 11 :	 0.14432431387574757
# 2 :	 0.1331512147226537
# 6 :	 0.1142650559138967
# [(1001570.5279999999, 3), (802548.0592, 7), (802538.0599, 27), (415309.0775, 23), (242319.8473, 8)]
# Switches in the controller 11 : [23, 7, 27, 3, 8]
# Switch selected is : 3
# The underloaded domains are : [14, 6]
# Taking a random action
# The target controller set for 14 is : [13, 19, 30, 25]
# The mean load ratio is : 0.12080895834229115
# The reward is = 0.9878897145691057
# Q value = 10.558241583693432
#
# At time step 996 the number of switch migrated are : 5
# The migrated switches are [1, 31, 1, 31, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 997
# 0.15571694919149354
# The overloaded domains are : [2, 28, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 14 :	 0.12766874135398562
# 28 :	 0.08846644993003341
# 11 :	 0.08347784557409517
# 2 :	 0.09555297643190461
# 6 :	 0.09930127185554702
# [(1451621.5690000001, 3), (509680.7868, 30), (509677.0646, 25), (415309.3096, 19), (1285.921789, 13)]
# Switches in the controller 14 : [13, 19, 30, 25, 3]
# Switch selected is : 3
# The underloaded domains are : [28, 11, 2]
# The target controller set for 11 is : [23, 7, 27, 8]
# The mean load ratio is : 0.09889345702911316
# The reward is = 0.41809252197836766
# Q value = 11.75745176792353
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.06348799419245045
# 28 :	 0.08846644993003341
# 11 :	 0.14765859273563034
# 2 :	 0.09555297643190461
# 6 :	 0.09930127185554702
# [(509675.5094, 29), (485626.4968, 10), (415308.8474, 22), (415307.0, 0), (415296.2505, 18), (4753.330524, 32)]
# Switches in the controller 6 : [32, 18, 0, 22, 29, 10]
# Switch selected is : 29
# The underloaded domains are : [14, 28, 2]
# The target controller set for 28 is : [12, 17, 16, 9, 5, 26, 31]
# The mean load ratio is : 0.09889345702911316
# The reward is = 1.0969699211916015
# Q value = 12.66351572014597
#
# At time step 997 the number of switch migrated are : 2
# The migrated switches are [3, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 998
# 0.21752852629573474
# The overloaded domains are : [2, 11, 28, 6]
# Balance the overloaded controller : 2
# Controller	Controller Load Ratio
# 14 :	 0.06107890113214988
# 28 :	 0.1156824019588279
# 11 :	 0.09030649374488096
# 2 :	 0.11181878031881257
# 6 :	 0.0820762674163043
# [(669994.1217, 1), (600945.2109, 4), (415311.1577, 20), (415309.9753, 21), (415306.3633, 24), (7454.175037000001, 15), (4763.815246, 33)]
# Switches in the controller 2 : [15, 33, 24, 21, 20, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 11, 6]
# The target controller set for 6 is : [32, 18, 0, 22, 10]
# The mean load ratio is : 0.09219256891419512
# The reward is = 1.3144279873266416
# Q value = 11.984593446174298
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.06107890113214988
# 28 :	 0.1156824019588279
# 11 :	 0.09030649374488096
# 2 :	 0.0821962366456946
# 6 :	 0.11169881108942227
# [(676617.9415, 9), (482651.0285, 31), (482645.6491, 29), (482634.7124, 26), (480007.6833, 5), (4758.0, 12), (4705.209006, 17), (2450.871716, 16)]
# Switches in the controller 28 : [12, 17, 16, 9, 5, 26, 31, 29]
# Switch selected is : 9
# The underloaded domains are : [14, 11, 2]
# The target controller set for 11 is : [23, 7, 27, 8, 3]
# The mean load ratio is : 0.09219256891419512
# The reward is = 0.854072601106496
# Q value = 12.323208465234933
#
# At time step 998 the number of switch migrated are : 2
# The migrated switches are [1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# 0.21768497764503086
# The overloaded domains are : [11, 28, 6, 14]
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 14 :	 0.09037260250596324
# 28 :	 0.1360378836527396
# 11 :	 0.1500178402346831
# 2 :	 0.08877331048331799
# 6 :	 0.10422760373495538
# [(812140.6140000001, 29), (812140.2961, 31), (812132.2019, 26), (625350.2145, 5), (5554.886859, 16), (4789.277384, 17), (4758.0, 12)]
# Switches in the controller 28 : [12, 17, 16, 5, 26, 31, 29]
# Switch selected is : 29
# The underloaded domains are : [14, 2, 6]
# The target controller set for 6 is : [32, 18, 0, 22, 10, 1]
# The mean load ratio is : 0.11388584812233186
# The reward is = 0.8579989446398937
# Q value = 10.788861664014801
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 14 :	 0.09037260250596324
# 28 :	 0.10013059726359122
# 11 :	 0.1500178402346831
# 2 :	 0.08877331048331799
# 6 :	 0.14013489012410377
# [(812140.6140000001, 29), (629896.7819, 1), (476795.4841, 10), (415318.4624, 22), (415307.3047, 18), (415307.0, 0), (4764.750569, 32)]
# Switches in the controller 6 : [32, 18, 0, 22, 10, 1, 29]
# Switch selected is : 29
# The underloaded domains are : [14, 28, 2]
# The target controller set for 28 is : [12, 17, 16, 5, 26, 31]
# The mean load ratio is : 0.11388584812233186
# The reward is = 1.510615360875019
# Q value = 11.14752305998207
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.09037260250596324
# 28 :	 0.1360378836527396
# 11 :	 0.1500178402346831
# 2 :	 0.08877331048331799
# 6 :	 0.10422760373495538
# [(812149.4959999999, 27), (812146.9244, 7), (761384.4999, 9), (415308.8631, 23), (380970.9241, 8), (211099.3962, 3)]
# Switches in the controller 11 : [23, 7, 27, 8, 3, 9]
# Switch selected is : 27
# The underloaded domains are : [14, 2, 6]
# Taking a random action
# The target controller set for 14 is : [13, 19, 30, 25]
# The mean load ratio is : 0.11388584812233186
# The reward is = 1.975251138170068
# Q value = 10.346577058907297
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 14 :	 0.12628028159621807
# 28 :	 0.1360378836527396
# 11 :	 0.11411016114442826
# 2 :	 0.08877331048331799
# 6 :	 0.10422760373495538
# [(812146.9244, 7), (761384.4999, 9), (415308.8631, 23), (380970.9241, 8), (211099.3962, 3)]
# Switches in the controller 11 : [23, 7, 8, 3, 9]
# Switch selected is : 7
# The underloaded domains are : [2, 6]
# The target controller set for 2 is : [15, 33, 24, 21, 20, 4]
# The mean load ratio is : 0.11388584812233186
# The reward is = 0.8730248670714343
# Q value = 11.479400130555785
#
# At time step 999 the number of switch migrated are : 4
# The migrated switches are [29, 29, 27, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[ 1.         11.72235254 11.75745177  8.65592015  7.70325305]
#  [10.2150799   1.         12.32320847 12.07035946 10.78886166]
#  [10.34657706 12.20895955  1.         11.47940013 11.14893784]
#  [ 4.98689534 13.11424007 11.72078686  1.         11.98459345]
#  [10.8414984  11.14752306 11.39004238  4.69952252  1.        ]]

# %% [markdown]
# # **Results**

# %%
import matplotlib.pyplot as plt

'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

prandom = []
pQL = []
pGreedy = []


yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(200, 1000, 50):
    x.append(time_steps_list_rn[i])

    prandom.append(discrete_coeff_list_rn[i])
    pQL.append(discrete_coeff_list_QL[i])
    pGreedy.append(discrete_coeff_list_gr[i])

    yrandom.append(load_balance_rate_list_rn[i])
    yQL.append(load_balance_rate_list_QL[i])
    yGreedy.append(load_balance_rate_list_gr[i])

    zrandom.append(number_of_switches_list_QL[i])
    zQL.append(number_of_switches_list_rn[i])
    zGreedy.append(number_of_switches_list_gr[i])

plt.plot(x, prandom, label='Random Selection')
plt.plot(x, pQL, label='Q-Learning')
plt.plot(x, pGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

plt.plot(x, [mean(prandom)]*len(x), label='Random Selection')
plt.plot(x, [mean(pQL)]*len(x), label='Q-Learning')
plt.plot(x, [mean(pGreedy)]*len(x), label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

plt.plot(x, zrandom, label='Random Selection')
plt.plot(x, zQL, label='Q-Learning')
plt.plot(x, zGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Number of switches migrated')
plt.legend()
plt.show()
