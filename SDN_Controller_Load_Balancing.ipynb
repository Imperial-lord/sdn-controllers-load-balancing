# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph Building and Controller Allocation**

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
# Out:
# Enter the number of controllers to allocate: 5
# Graph with 34 nodes and 46 edges
#
# Controllers:
# [29, 24, 13, 6, 14]
#
# Cluster set for each controller:
# [[3, 4, 11, 12, 26, 27, 28, 29, 30, 31], [2, 24, 25, 32, 33], [13], [0, 1, 5, 6, 7, 9, 15, 20, 21], [8, 10, 14, 16, 17, 18, 19, 22, 23]]
#
# Cluster map for each controller:
# {29: [3, 4, 11, 12, 26, 27, 28, 30, 31], 24: [2, 25, 32, 33], 13: [], 6: [0, 1, 5, 7, 9, 15, 20, 21], 14: [8, 10, 16, 17, 18, 19, 22, 23]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1):
15): 3, (8, 16): 5, (8, 17): 3, (8, 18): 5, (8, 19): 2, (8, 20): 4, (8, 21): 4, (8, 22): 5, (8, 23): 4, (8, 24): 7, (8, 25): 6, (8, 26): 7, (8, 27): 7, (8, 28): 6, (8, 29): 5, (8, 30): 4, (8, 31): 6, (8, 32): 7, (8, 33): 8, (9, 0): 2, (9, 1): 4, (9, 2): 3, (9, 3): 2, (9, 4): 3, (9, 5): 2, (9, 6): 3, (9, 7): 1, (9, 8): 1, (9, 9): 0, (9, 10): 3, (9, 11): 3, (9, 12): 4, (9, 13): 5, (9, 14): 3, (9, 15): 4, (9, 16): 4, (9, 17): 2, (9, 18): 4, (9, 19): 1, (9, 20): 2, (9, 21): 2, (9, 22): 4, (9, 23): 3, (9, 24): 5, (9, 25): 4, (9, 26): 5, (9, 27): 5, (9, 28): 4, (9, 29): 3, (9, 30): 2, (9, 31): 4, (9, 32): 5, (9,  ...
# [[3, 4, 11, 12, 26, 27, 28, 29, 30, 31], [2, 24, 25, 32, 33], [13], [0, 1, 5, 6, 7, 9, 15, 20, 21], [8, 10, 14, 16, 17, 18, 19, 22, 23]]
# [[3, 4, 11, 12, 26, 27, 28, 29, 30, 31], [2, 24, 25, 32, 33], [13], [0, 1, 5, 6, 7, 9, 15, 20, 21], [8, 10, 14, 16, 17, 18, 19, 22, 23]]

# %% [markdown]
# # **Switch Migration Design**

# %% [markdown]
# Some **questions (with answers after discussion)** regarding the cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously - Yes
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool? - Yes

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions(with answers after discussion)** regarding the cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).
#
# We have calcuated hop count using the **Floyd Warshall** algorithm. The hop count is the number of hops involved in the shortest distance between the 2 nodes.

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 850
# {29: {12: 2838.6666666666665, 21: 103827.629725, 20: 103826.1464, 5: 148163.950275, 2: 77411.31313333333, 4: 241839.38053333331}, 24: {32: 8513.466267, 33: 4264.5244405, 22: 69217.40538333333, 10: 76058.62074285714, 18: 83061.1802, 9: 108208.79234, 1: 127031.24578}, 13: {19: 51912.9911125, 8: 92909.4806, 23: 83061.32154, 11: 159539.1477, 30: 310705.3709, 7: 155350.348025}, 6: {15: 1227.00027325, 26: 103565.10626666667, 3: 52287.45046666667, 25: 124279.97416000001, 31: 124279.76268}, 14: {16: 2228.3242379999997, 17: 4156.0015619999995, 27: 103565.87103333334, 0: 138435.66666666666, 28: 124281.79376}}
# {(29, 6), (13, 14), (24, 6), (13, 6), (24, 14), (29, 14), (6, 14)}
# (29, 6, [4])
# [[12, 21, 20, 5, 2, 4], [32, 33, 22, 10, 18, 9, 1], [19, 8, 23, 11, 30, 7], [15, 26, 3, 25, 31], [16, 17, 27, 0, 28]]
 7]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# 6 :	 0.11238974306624895
# 14 :	 0.09663738306769507
# Switches in the controller 24 : [18, 1, 15, 33, 28, 17, 20, 2, 32, 7]
# Switch selected is : 32
# The target controller set for 13 is : [8, 5, 22, 10]
# The mean load ratio is : 0.1133755779280307
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.11814680124685471
# 24 :	 0.161398862744808
# 13 :	 0.07830509951454673
# 6 :	 0.11238974306624895
# 14 :	 0.09663738306769507
# Switches in the controller 24 : [18, 1, 15, 33, 28, 17, 20, 2, 7]
# Switch selected is : 1
# The target controller set for 6 is : [23, 25, 27, 21, 19]
# The mean load ratio is : 0.1133755779280307
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.11814680124685471
# 24 :	 0.1152433017392278
# 13 :	 0.07830509951454673
# 6 :	 0.15854530407182915
# 14 :	 0.09663738306769507
# Switches in the controller 24 : [18, 15, 33, 28, 17, 20, 2, 7]
# Switch selected is : 18
# The target controller set for 6 is : [23, 25, 27, 21, 19, 1]
# The mean load ratio is : 0.1133755779280307
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11814680124685471
# 24 :	 0.09688151455341111
# 13 :	 0.07830509951454673
# 6 :	 0.17690709125764584
# 14 :	 0.09663738306769507
# Switches in the controller 29 : [4, 3, 11, 12, 30, 16]
# Switch selected is : 11
# The target controller set for 6 is : [23, 25, 27, 21, 19, 1, 18]
# The mean load ratio is : 0.1133755779280307
#
# At time step 943 the number of switch migrated are : 5
# The migrated switches are [16, 32, 1, 18, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 944
# The overloaded domains are : [24, 13, 14, 6]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04680644173753206
# 24 :	 0.09854240053824706
# 13 :	 0.10256500589300056
# 6 :	 0.17871906373014357
# 14 :	 0.08333787274271011
# Switches in the controller 13 : [8, 5, 22, 10, 32]
# Switch selected is : 22
# The target controller set for 6 is : [23, 25, 27, 21, 19, 1, 18, 11]
# The mean load ratio is : 0.10199415692832667
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.04680644173753206
# 24 :	 0.09854240053824706
# 13 :	 0.08420313866813714
# 6 :	 0.19708093095500698
# 14 :	 0.08333787274271011
# Switches in the controller 6 : [23, 25, 27, 21, 19, 1, 18, 11, 22]
# Switch selected is : 27
# The target controller set for 24 is : [15, 33, 28, 17, 20, 2, 7]
# The mean load ratio is : 0.10199415692832667
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.04680644173753206
# 24 :	 0.11868575217205124
# 13 :	 0.08420313866813714
# 6 :	 0.1769375793212028
# 14 :	 0.08333787274271011
# Switches in the controller 6 : [23, 25, 21, 19, 1, 18, 11, 22]
# Switch selected is : 25
# The target controller set for 29 is : [4, 3, 12, 30, 16]
# The mean load ratio is : 0.10199415692832667
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.06695035897676795
# 24 :	 0.11868575217205124
# 13 :	 0.08420313866813714
# 6 :	 0.1567936620819669
# 14 :	 0.08333787274271011
# Switches in the controller 6 : [23, 21, 19, 1, 18, 11, 22]
# Switch selected is : 23
# The target controller set for 13 is : [8, 5, 10, 32]
# The mean load ratio is : 0.10199415692832667
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.06695035897676795
# 24 :	 0.11868575217205124
# 13 :	 0.1025651847793636
# 6 :	 0.13843161597074044
# 14 :	 0.08333787274271011
# Switches in the controller 6 : [21, 19, 1, 18, 11, 22]
# Switch selected is : 11
# The target controller set for 14 is : [26, 0, 31, 9]
# The mean load ratio is : 0.10199415692832667
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.06695035897676795
# 24 :	 0.11868575217205124
# 13 :	 0.1025651847793636
# 6 :	 0.09870975434401157
# 14 :	 0.12305973436943898
# Switches in the controller 24 : [15, 33, 28, 17, 20, 2, 7, 27]
# Switch selected is : 2
# The target controller set for 14 is : [26, 0, 31, 9, 11]
# The mean load ratio is : 0.10199415692832667
#
# At time step 944 the number of switch migrated are : 6
# The migrated switches are [22, 27, 25, 23, 11, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 945
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.0906864390648833
# 24 :	 0.1025854360346724
# 13 :	 0.0802075082242963
# 6 :	 0.12046109788525436
# 14 :	 0.13294079106420575
# Switches in the controller 6 : [21, 19, 1, 18, 22]
# Switch selected is : 1
# The target controller set for 13 is : [8, 5, 10, 32, 23]
# The mean load ratio is : 0.10537625445466244
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.0906864390648833
# 24 :	 0.1025854360346724
# 13 :	 0.12722082916388908
# 6 :	 0.0734477769456616
# 14 :	 0.13294079106420575
# Switches in the controller 14 : [26, 0, 31, 9, 11, 2]
# Switch selected is : 26
# The target controller set for 24 is : [15, 33, 28, 17, 20, 7, 27]
# The mean load ratio is : 0.10537625445466244
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.0906864390648833
# 24 :	 0.13043785645754094
# 13 :	 0.12722082916388908
# 6 :	 0.0734477769456616
# 14 :	 0.10508837064133722
# Switches in the controller 24 : [15, 33, 28, 17, 20, 7, 27, 26]
# Switch selected is : 28
# The target controller set for 6 is : [21, 19, 18, 22]
# The mean load ratio is : 0.10537625445466244
#
# At time step 945 the number of switch migrated are : 3
# The migrated switches are [1, 26, 28]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 946
# The overloaded domains are : [24, 13, 6, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.08273158546490264
# 24 :	 0.10202151682424211
# 13 :	 0.11508121799818433
# 6 :	 0.10108148038274897
# 14 :	 0.1456228260172456
# Switches in the controller 13 : [8, 5, 10, 32, 23, 1]
# Switch selected is : 10
# The target controller set for 24 is : [15, 33, 17, 20, 7, 27, 26]
# The mean load ratio is : 0.10930772533746473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08273158546490264
# 24 :	 0.12053418787942427
# 13 :	 0.09656854694300217
# 6 :	 0.10108148038274897
# 14 :	 0.1456228260172456
# Switches in the controller 14 : [0, 31, 9, 11, 2]
# Switch selected is : 31
# The target controller set for 24 is : [15, 33, 17, 20, 7, 27, 26, 10]
# The mean load ratio is : 0.10930772533746473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08273158546490264
# 24 :	 0.14816696349051198
# 13 :	 0.09656854694300217
# 6 :	 0.10108148038274897
# 14 :	 0.1179900504061579
# Switches in the controller 14 : [0, 9, 11, 2]
# Switch selected is : 0
# The target controller set for 6 is : [21, 19, 18, 22, 28]
# The mean load ratio is : 0.10930772533746473
#
# At time step 946 the number of switch migrated are : 3
# The migrated switches are [10, 31, 0]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 947
# The overloaded domains are : [24, 13, 14, 6]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.05960534074183576
# 24 :	 0.11623063331709697
# 13 :	 0.11423035276962494
# 6 :	 0.10921224271741425
# 14 :	 0.07938912358955853
# Switches in the controller 24 : [15, 33, 17, 20, 7, 27, 26, 10, 31]
# Switch selected is : 27
# The target controller set for 13 is : [8, 5, 32, 23, 1]
# The mean load ratio is : 0.09573353862710608
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.05960534074183576
# 24 :	 0.0988291620770509
# 13 :	 0.131631824009671
# 6 :	 0.10921224271741425
# 14 :	 0.07938912358955853
# Switches in the controller 24 : [15, 33, 17, 20, 7, 26, 10, 31]
# Switch selected is : 10
# The target controller set for 29 is : [4, 3, 12, 30, 16, 25]
# The mean load ratio is : 0.09573353862710608
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.0871286095625305
# 24 :	 0.07130589325635617
# 13 :	 0.131631824009671
# 6 :	 0.10921224271741425
# 14 :	 0.07938912358955853
# Switches in the controller 6 : [21, 19, 18, 22, 28, 0]
# Switch selected is : 22
# The target controller set for 24 is : [15, 33, 17, 20, 7, 26, 31]
# The mean load ratio is : 0.09573353862710608
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.0871286095625305
# 24 :	 0.08966801047115384
# 13 :	 0.131631824009671
# 6 :	 0.09085012550261658
# 14 :	 0.07938912358955853
# Switches in the controller 13 : [8, 5, 32, 23, 1, 27]
# Switch selected is : 32
# The target controller set for 24 is : [15, 33, 17, 20, 7, 26, 31, 22]
# The mean load ratio is : 0.09573353862710608
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.0871286095625305
# 24 :	 0.0899316765641834
# 13 :	 0.13136815791664144
# 6 :	 0.09085012550261658
# 14 :	 0.07938912358955853
# Switches in the controller 13 : [8, 5, 23, 1, 27]
# Switch selected is : 27
# The target controller set for 29 is : [4, 3, 12, 30, 16, 25, 10]
# The mean load ratio is : 0.09573353862710608
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10453008080257657
# 24 :	 0.0899316765641834
# 13 :	 0.11396668667659537
# 6 :	 0.09085012550261658
# 14 :	 0.07938912358955853
# Switches in the controller 13 : [8, 5, 23, 1]
# Switch selected is : 23
# The target controller set for 29 is : [4, 3, 12, 30, 16, 25, 10, 27]
# The mean load ratio is : 0.09573353862710608
#
# At time step 947 the number of switch migrated are : 6
# The migrated switches are [27, 10, 22, 32, 27, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 948
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.21342829118256484
# 24 :	 0.14164473531838737
# 13 :	 0.09815269561284719
# 6 :	 0.10815678247818672
# 14 :	 0.05153305288566663
# Switches in the controller 29 : [4, 3, 12, 30, 16, 25, 10, 27, 23]
# Switch selected is : 27
# The target controller set for 24 is : [15, 33, 17, 20, 7, 26, 31, 22, 32]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.17872068007056618
# 24 :	 0.17635234643038605
# 13 :	 0.09815269561284719
# 6 :	 0.10815678247818672
# 14 :	 0.05153305288566663
# Switches in the controller 29 : [4, 3, 12, 30, 16, 25, 10, 23]
# Switch selected is : 12
# The target controller set for 6 is : [21, 19, 18, 28, 0]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.17848135434559456
# 24 :	 0.17635234643038605
# 13 :	 0.09815269561284719
# 6 :	 0.10839610820315836
# 14 :	 0.05153305288566663
# Switches in the controller 29 : [4, 3, 30, 16, 25, 10, 23]
# Switch selected is : 4
# The target controller set for 24 is : [15, 33, 17, 20, 7, 26, 31, 22, 32, 27]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.15179450544323458
# 24 :	 0.20303919533274603
# 13 :	 0.09815269561284719
# 6 :	 0.10839610820315836
# 14 :	 0.05153305288566663
# Switches in the controller 29 : [3, 30, 16, 25, 10, 23]
# Switch selected is : 3
# The target controller set for 6 is : [21, 19, 18, 28, 0, 12]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1041695443067065
# 24 :	 0.20303919533274603
# 13 :	 0.09815269561284719
# 6 :	 0.15602106933968646
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [15, 33, 17, 20, 7, 26, 31, 22, 32, 27, 4]
# Switch selected is : 7
# The target controller set for 29 is : [30, 16, 25, 10, 23]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13887760003930152
# 24 :	 0.168331139600151
# 13 :	 0.09815269561284719
# 6 :	 0.15602106933968646
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [15, 33, 17, 20, 26, 31, 22, 32, 27, 4]
# Switch selected is : 33
# The target controller set for 29 is : [30, 16, 25, 10, 23, 7]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13911732014388725
# 24 :	 0.16809141949556528
# 13 :	 0.09815269561284719
# 6 :	 0.15602106933968646
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [15, 17, 20, 26, 31, 22, 32, 27, 4]
# Switch selected is : 17
# The target controller set for 6 is : [21, 19, 18, 28, 0, 12, 3]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13911732014388725
# 24 :	 0.16789512500230375
# 13 :	 0.09815269561284719
# 6 :	 0.156217363832948
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [15, 20, 26, 31, 22, 32, 27, 4]
# Switch selected is : 32
# The target controller set for 13 is : [8, 5, 1]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13911732014388725
# 24 :	 0.1676553211270381
# 13 :	 0.09839249948811284
# 6 :	 0.156217363832948
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [15, 20, 26, 31, 22, 27, 4]
# Switch selected is : 15
# The target controller set for 29 is : [30, 16, 25, 10, 23, 7, 33]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13923750999286524
# 24 :	 0.1675351312780601
# 13 :	 0.09839249948811284
# 6 :	 0.156217363832948
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [20, 26, 31, 22, 27, 4]
# Switch selected is : 4
# The target controller set for 13 is : [8, 5, 1, 32]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13923750999286524
# 24 :	 0.14084828237570013
# 13 :	 0.1250793483904728
# 6 :	 0.156217363832948
# 14 :	 0.05153305288566663
# Switches in the controller 24 : [20, 26, 31, 22, 27]
# Switch selected is : 31
# The target controller set for 14 is : [9, 11, 2]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.13923750999286524
# 24 :	 0.10614008403362313
# 13 :	 0.1250793483904728
# 6 :	 0.156217363832948
# 14 :	 0.08624125122774362
# Switches in the controller 13 : [8, 5, 1, 32, 4]
# Switch selected is : 8
# The target controller set for 24 is : [20, 26, 22, 27]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13923750999286524
# 24 :	 0.13701349138299967
# 13 :	 0.09420594104109624
# 6 :	 0.156217363832948
# 14 :	 0.08624125122774362
# Switches in the controller 6 : [21, 19, 18, 28, 0, 12, 3, 17]
# Switch selected is : 17
# The target controller set for 29 is : [30, 16, 25, 10, 23, 7, 33, 15]
# The mean load ratio is : 0.12258311149553054
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13943380448612677
# 24 :	 0.13701349138299967
# 13 :	 0.09420594104109624
# 6 :	 0.15602106933968646
# 14 :	 0.08624125122774362
# Switches in the controller 6 : [21, 19, 18, 28, 0, 12, 3]
# Switch selected is : 28
# The target controller set for 29 is : [30, 16, 25, 10, 23, 7, 33, 15, 17]
# The mean load ratio is : 0.12258311149553054
#
# At time step 948 the number of switch migrated are : 14
# The migrated switches are [27, 12, 4, 3, 7, 33, 17, 32, 15, 4, 31, 8, 17, 28]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 949
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12029888848547192
# 24 :	 0.09945846653939631
# 13 :	 0.11614221052363227
# 6 :	 0.0876547104405663
# 14 :	 0.12574751303209802
# Switches in the controller 29 : [30, 16, 25, 10, 23, 7, 33, 15, 17, 28]
# Switch selected is : 7
# The target controller set for 24 is : [20, 26, 22, 27, 8]
# The mean load ratio is : 0.10986035780423298
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09973131106923389
# 24 :	 0.12002604395563435
# 13 :	 0.11614221052363227
# 6 :	 0.0876547104405663
# 14 :	 0.12574751303209802
# Switches in the controller 14 : [9, 11, 2, 31]
# Switch selected is : 31
# The target controller set for 24 is : [20, 26, 22, 27, 8, 7]
# The mean load ratio is : 0.10986035780423298
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.09973131106923389
# 24 :	 0.14059387687076383
# 13 :	 0.11614221052363227
# 6 :	 0.0876547104405663
# 14 :	 0.10517968011696853
# Switches in the controller 13 : [5, 1, 32, 4]
# Switch selected is : 4
# The target controller set for 29 is : [30, 16, 25, 10, 23, 33, 15, 17, 28]
# The mean load ratio is : 0.10986035780423298
#
# At time step 949 the number of switch migrated are : 3
# The migrated switches are [7, 31, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 950
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.13240862639851772
# 24 :	 0.14918481170291112
# 13 :	 0.04549494455588275
# 6 :	 0.07979493864482687
# 14 :	 0.04629737116261823
# Switches in the controller 29 : [30, 16, 25, 10, 23, 33, 15, 17, 28, 4]
# Switch selected is : 28
# The target controller set for 6 is : [21, 19, 18, 0, 12, 3]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11106310137001078
# 24 :	 0.14918481170291112
# 13 :	 0.04549494455588275
# 6 :	 0.1011404636733338
# 14 :	 0.04629737116261823
# Switches in the controller 29 : [30, 16, 25, 10, 23, 33, 15, 17, 4]
# Switch selected is : 30
# The target controller set for 14 is : [9, 11, 2]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.08971706595828356
# 24 :	 0.14918481170291112
# 13 :	 0.04549494455588275
# 6 :	 0.1011404636733338
# 14 :	 0.06764340657434545
# Switches in the controller 24 : [20, 26, 22, 27, 8, 7, 31]
# Switch selected is : 20
# The target controller set for 29 is : [16, 25, 10, 23, 33, 15, 17, 4]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1080792090598745
# 24 :	 0.1308226686013202
# 13 :	 0.04549494455588275
# 6 :	 0.1011404636733338
# 14 :	 0.06764340657434545
# Switches in the controller 24 : [26, 22, 27, 8, 7, 31]
# Switch selected is : 27
# The target controller set for 13 is : [5, 1, 32]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1080792090598745
# 24 :	 0.10947709977969841
# 13 :	 0.06684051337750452
# 6 :	 0.1011404636733338
# 14 :	 0.06764340657434545
# Switches in the controller 24 : [26, 22, 8, 7, 31]
# Switch selected is : 22
# The target controller set for 13 is : [5, 1, 32, 27]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1080792090598745
# 24 :	 0.09111482896845356
# 13 :	 0.08520278418874937
# 6 :	 0.1011404636733338
# 14 :	 0.06764340657434545
# Switches in the controller 24 : [26, 8, 7, 31]
# Switch selected is : 8
# The target controller set for 14 is : [9, 11, 2, 30]
# The mean load ratio is : 0.09063613849295134
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.1080792090598745
# 24 :	 0.0640376904459737
# 13 :	 0.08520278418874937
# 6 :	 0.1011404636733338
# 14 :	 0.09472054509682531
# Switches in the controller 14 : [9, 11, 2, 30, 8]
# Switch selected is : 30
# The target controller set for 6 is : [21, 19, 18, 0, 12, 3, 28]
# The mean load ratio is : 0.09063613849295134
#
# At time step 950 the number of switch migrated are : 7
# The migrated switches are [28, 30, 20, 27, 22, 8, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 951
# The overloaded domains are : [13, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.09619419630788742
# 13 :	 0.09848838222124892
# 6 :	 0.1607785409881435
# 14 :	 0.10794064830022762
# Switches in the controller 6 : [21, 19, 18, 0, 12, 3, 28, 30]
# Switch selected is : 28
# The target controller set for 14 is : [9, 11, 2, 8]
# The mean load ratio is : 0.11506628015376077
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.09619419630788742
# 13 :	 0.09848838222124892
# 6 :	 0.12871363237192313
# 14 :	 0.140005556916448
# Switches in the controller 6 : [21, 19, 18, 0, 12, 3, 30]
# Switch selected is : 18
# The target controller set for 24 is : [26, 7, 31]
# The mean load ratio is : 0.11506628015376077
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.11455651529376923
# 13 :	 0.09848838222124892
# 6 :	 0.11035131338604132
# 14 :	 0.140005556916448
# Switches in the controller 14 : [9, 11, 2, 8, 28]
# Switch selected is : 8
# The target controller set for 24 is : [26, 7, 31, 18]
# The mean load ratio is : 0.11506628015376077
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.13044193251220454
# 13 :	 0.09848838222124892
# 6 :	 0.11035131338604132
# 14 :	 0.1241201396980127
# Switches in the controller 14 : [9, 11, 2, 28]
# Switch selected is : 11
# The target controller set for 13 is : [5, 1, 32, 27, 22]
# The mean load ratio is : 0.11506628015376077
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.13044193251220454
# 13 :	 0.14282370276899714
# 6 :	 0.11035131338604132
# 14 :	 0.07978481915026447
# Switches in the controller 13 : [5, 1, 32, 27, 22, 11]
# Switch selected is : 5
# The target controller set for 14 is : [9, 2, 28]
# The mean load ratio is : 0.11506628015376077
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11192963295129638
# 24 :	 0.13044193251220454
# 13 :	 0.11853926181259976
# 6 :	 0.11035131338604132
# 14 :	 0.10406926010666186
# Switches in the controller 13 : [1, 32, 27, 22, 11]
# Switch selected is : 1
# The target controller set for 14 is : [9, 2, 28, 5]
# The mean load ratio is : 0.11506628015376077
#
# At time step 951 the number of switch migrated are : 6
# The migrated switches are [28, 18, 8, 11, 5, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 952
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13164333854341662
# 24 :	 0.15465845570613038
# 13 :	 0.1236834113586093
# 6 :	 0.1468518861959047
# 14 :	 0.1508756394388063
# Switches in the controller 6 : [21, 19, 0, 12, 3, 30]
# Switch selected is : 3
# The target controller set for 29 is : [16, 25, 10, 23, 33, 15, 17, 4, 20]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.18715607451762
# 24 :	 0.15465845570613038
# 13 :	 0.1236834113586093
# 6 :	 0.0913391502217013
# 14 :	 0.1508756394388063
# Switches in the controller 14 : [9, 2, 28, 5, 1]
# Switch selected is : 28
# The target controller set for 13 is : [32, 27, 22, 11]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.18715607451762
# 24 :	 0.15465845570613038
# 13 :	 0.15966518298304988
# 6 :	 0.0913391502217013
# 14 :	 0.11489386781436571
# Switches in the controller 29 : [16, 25, 10, 23, 33, 15, 17, 4, 20, 3]
# Switch selected is : 16
# The target controller set for 24 is : [26, 7, 31, 18, 8]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.18714888255385
# 24 :	 0.15466564766990037
# 13 :	 0.15966518298304988
# 6 :	 0.0913391502217013
# 14 :	 0.11489386781436571
# Switches in the controller 29 : [25, 10, 23, 33, 15, 17, 4, 20, 3]
# Switch selected is : 20
# The target controller set for 24 is : [26, 7, 31, 18, 8, 16]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.16878683550972629
# 24 :	 0.1730276947140241
# 13 :	 0.15966518298304988
# 6 :	 0.0913391502217013
# 14 :	 0.11489386781436571
# Switches in the controller 29 : [25, 10, 23, 33, 15, 17, 4, 3]
# Switch selected is : 25
# The target controller set for 24 is : [26, 7, 31, 18, 8, 16, 20]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13280551818855962
# 24 :	 0.20900901203519076
# 13 :	 0.15966518298304988
# 6 :	 0.0913391502217013
# 14 :	 0.11489386781436571
# Switches in the controller 24 : [26, 7, 31, 18, 8, 16, 20, 25]
# Switch selected is : 16
# The target controller set for 14 is : [9, 2, 5, 1]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13280551818855962
# 24 :	 0.20900182007142076
# 13 :	 0.15966518298304988
# 6 :	 0.0913391502217013
# 14 :	 0.11490105977813571
# Switches in the controller 24 : [26, 7, 31, 18, 8, 20, 25]
# Switch selected is : 31
# The target controller set for 13 is : [32, 27, 22, 11, 28]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13280551818855962
# 24 :	 0.1730201012286263
# 13 :	 0.19564690182584435
# 6 :	 0.0913391502217013
# 14 :	 0.11490105977813571
# Switches in the controller 24 : [26, 7, 18, 8, 20, 25]
# Switch selected is : 8
# The target controller set for 13 is : [32, 27, 22, 11, 28, 31]
# The mean load ratio is : 0.1415425462485735
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13280551818855962
# 24 :	 0.14466954257367728
# 13 :	 0.22399746048079336
# 6 :	 0.0913391502217013
# 14 :	 0.11490105977813571
# Switches in the controller 24 : [26, 7, 18, 20, 25]
# Switch selected is : 20
# The target controller set for 14 is : [9, 2, 5, 1, 16]
# The mean load ratio is : 0.1415425462485735
#
# At time step 952 the number of switch migrated are : 9
# The migrated switches are [3, 28, 16, 20, 25, 16, 31, 8, 20]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 953
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.10330607117254006
# 24 :	 0.07664590582348808
# 13 :	 0.1048892193292764
# 6 :	 0.07476165253420707
# 14 :	 0.13696165007828845
# Switches in the controller 29 : [10, 23, 33, 15, 17, 4, 3]
# Switch selected is : 4
# The target controller set for 14 is : [9, 2, 5, 1, 16, 20]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08742136759397068
# 24 :	 0.07664590582348808
# 13 :	 0.1048892193292764
# 6 :	 0.07476165253420707
# 14 :	 0.15284635365685784
# Switches in the controller 14 : [9, 2, 5, 1, 16, 20, 4]
# Switch selected is : 9
# The target controller set for 13 is : [32, 27, 22, 11, 28, 31, 8]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08742136759397068
# 24 :	 0.07664590582348808
# 13 :	 0.13504227990493936
# 6 :	 0.07476165253420707
# 14 :	 0.12269329308119487
# Switches in the controller 14 : [2, 5, 1, 16, 20, 4]
# Switch selected is : 16
# The target controller set for 24 is : [26, 7, 18, 25]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08742136759397068
# 24 :	 0.07722800467823561
# 13 :	 0.13504227990493936
# 6 :	 0.07476165253420707
# 14 :	 0.12211119422644734
# Switches in the controller 14 : [2, 5, 1, 20, 4]
# Switch selected is : 2
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09777271671407062
# 24 :	 0.07722800467823561
# 13 :	 0.13504227990493936
# 6 :	 0.07476165253420707
# 14 :	 0.1117598451063474
# Switches in the controller 14 : [5, 1, 20, 4]
# Switch selected is : 1
# The target controller set for 6 is : [21, 19, 0, 12, 30]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.09777271671407062
# 24 :	 0.07722800467823561
# 13 :	 0.13504227990493936
# 6 :	 0.12909015892801184
# 14 :	 0.05743133871254263
# Switches in the controller 13 : [32, 27, 22, 11, 28, 31, 8, 9]
# Switch selected is : 22
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2]
# The mean load ratio is : 0.09931289978756001
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1161346325866516
# 24 :	 0.07722800467823561
# 13 :	 0.11668036403235837
# 6 :	 0.12909015892801184
# 14 :	 0.05743133871254263
# Switches in the controller 13 : [32, 27, 11, 28, 31, 8, 9]
# Switch selected is : 27
# The target controller set for 14 is : [5, 20, 4]
# The mean load ratio is : 0.09931289978756001
#
# At time step 953 the number of switch migrated are : 7
# The migrated switches are [4, 9, 16, 2, 1, 22, 27]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 954
# The overloaded domains are : [13, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11289962764162816
# 24 :	 0.07623048202172442
# 13 :	 0.12439462655397089
# 6 :	 0.10494748608637798
# 14 :	 0.09299168551000253
# Switches in the controller 6 : [21, 19, 0, 12, 30, 1]
# Switch selected is : 12
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 22]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11313961656369467
# 24 :	 0.07623048202172442
# 13 :	 0.12439462655397089
# 6 :	 0.10470749716431146
# 14 :	 0.09299168551000253
# Switches in the controller 6 : [21, 19, 0, 30, 1]
# Switch selected is : 30
# The target controller set for 24 is : [26, 7, 18, 25, 16]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11313961656369467
# 24 :	 0.09548942548955475
# 13 :	 0.12439462655397089
# 6 :	 0.08544855369648113
# 14 :	 0.09299168551000253
# Switches in the controller 13 : [32, 11, 28, 31, 8, 9]
# Switch selected is : 9
# The target controller set for 14 is : [5, 20, 4, 27]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11313961656369467
# 24 :	 0.09548942548955475
# 13 :	 0.08961694262054085
# 6 :	 0.08544855369648113
# 14 :	 0.12776936944343256
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 22, 12]
# Switch selected is : 12
# The target controller set for 14 is : [5, 20, 4, 27, 9]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11289962764162816
# 24 :	 0.09548942548955475
# 13 :	 0.08961694262054085
# 6 :	 0.08544855369648113
# 14 :	 0.12800935836549907
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 22]
# Switch selected is : 22
# The target controller set for 14 is : [5, 20, 4, 27, 9, 12]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09453764930914478
# 24 :	 0.09548942548955475
# 13 :	 0.08961694262054085
# 6 :	 0.08544855369648113
# 14 :	 0.14637133669798244
# Switches in the controller 14 : [5, 20, 4, 27, 9, 12, 22]
# Switch selected is : 20
# The target controller set for 24 is : [26, 7, 18, 25, 16, 30]
# The mean load ratio is : 0.1022927815627408
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09453764930914478
# 24 :	 0.11385152604926271
# 13 :	 0.08961694262054085
# 6 :	 0.08544855369648113
# 14 :	 0.12800923613827447
# Switches in the controller 14 : [5, 4, 27, 9, 12, 22]
# Switch selected is : 5
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2]
# The mean load ratio is : 0.1022927815627408
#
# At time step 954 the number of switch migrated are : 7
# The migrated switches are [12, 30, 9, 12, 22, 20, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 955
# The overloaded domains are : [24, 13, 6, 14]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.07591608001353344
# 24 :	 0.1560320184705142
# 13 :	 0.09218148199782893
# 6 :	 0.07779781842401594
# 14 :	 0.09199124801905022
# Switches in the controller 24 : [26, 7, 18, 25, 16, 30, 20]
# Switch selected is : 25
# The target controller set for 13 is : [32, 11, 28, 31, 8]
# The mean load ratio is : 0.09878372938498856
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.07591608001353344
# 24 :	 0.12628723479079154
# 13 :	 0.12192626567755158
# 6 :	 0.07779781842401594
# 14 :	 0.09199124801905022
# Switches in the controller 24 : [26, 7, 18, 16, 30, 20]
# Switch selected is : 18
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 5]
# The mean load ratio is : 0.09878372938498856
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.09427803845452529
# 24 :	 0.1079252763497997
# 13 :	 0.12192626567755158
# 6 :	 0.07779781842401594
# 14 :	 0.09199124801905022
# Switches in the controller 24 : [26, 7, 16, 30, 20]
# Switch selected is : 26
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 5, 18]
# The mean load ratio is : 0.09878372938498856
#
# At time step 955 the number of switch migrated are : 3
# The migrated switches are [25, 18, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 956
# The overloaded domains are : [13, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.1438872842335685
# 24 :	 0.07194744205386923
# 13 :	 0.101211683008371
# 6 :	 0.10468173939824686
# 14 :	 0.08672881471140526
# Switches in the controller 6 : [21, 19, 0, 1]
# Switch selected is : 19
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 5, 18, 26]
# The mean load ratio is : 0.10169139268109217
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1622492482056241
# 24 :	 0.07194744205386923
# 13 :	 0.101211683008371
# 6 :	 0.08631977542619125
# 14 :	 0.08672881471140526
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 5, 18, 26, 19]
# Switch selected is : 19
# The target controller set for 13 is : [32, 11, 28, 31, 8, 25]
# The mean load ratio is : 0.10169139268109217
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1438872842335685
# 24 :	 0.07194744205386923
# 13 :	 0.1195736469804266
# 6 :	 0.08631977542619125
# 14 :	 0.08672881471140526
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 5, 18, 26]
# Switch selected is : 5
# The target controller set for 13 is : [32, 11, 28, 31, 8, 25, 19]
# The mean load ratio is : 0.10169139268109217
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11778344862112212
# 24 :	 0.07194744205386923
# 13 :	 0.145677482592873
# 6 :	 0.08631977542619125
# 14 :	 0.08672881471140526
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 18, 26]
# Switch selected is : 18
# The target controller set for 13 is : [32, 11, 28, 31, 8, 25, 19, 5]
# The mean load ratio is : 0.10169139268109217
#
# At time step 956 the number of switch migrated are : 4
# The migrated switches are [19, 19, 5, 18]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 957
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11251498686320326
# 24 :	 0.089819081596695
# 13 :	 0.22965177915476562
# 6 :	 0.06259170783981642
# 14 :	 0.10160671364709485
# Switches in the controller 13 : [32, 11, 28, 31, 8, 25, 19, 5, 18]
# Switch selected is : 8
# The target controller set for 6 is : [21, 0, 1]
# The mean load ratio is : 0.11923685382031504
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11251498686320326
# 24 :	 0.089819081596695
# 13 :	 0.2126949356824389
# 6 :	 0.07954855131214314
# 14 :	 0.10160671364709485
# Switches in the controller 13 : [32, 11, 28, 31, 25, 19, 5, 18]
# Switch selected is : 19
# The target controller set for 6 is : [21, 0, 1, 8]
# The mean load ratio is : 0.11923685382031504
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11251498686320326
# 24 :	 0.089819081596695
# 13 :	 0.19433304542252974
# 6 :	 0.09791044157205231
# 14 :	 0.10160671364709485
# Switches in the controller 13 : [32, 11, 28, 31, 25, 5, 18]
# Switch selected is : 31
# The target controller set for 14 is : [4, 27, 9, 12, 22]
# The mean load ratio is : 0.11923685382031504
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11251498686320326
# 24 :	 0.089819081596695
# 13 :	 0.15871248219022813
# 6 :	 0.09791044157205231
# 14 :	 0.13722727687939645
# Switches in the controller 13 : [32, 11, 28, 25, 5, 18]
# Switch selected is : 18
# The target controller set for 24 is : [7, 16, 30, 20]
# The mean load ratio is : 0.11923685382031504
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11251498686320326
# 24 :	 0.10818142699108513
# 13 :	 0.140350136795838
# 6 :	 0.09791044157205231
# 14 :	 0.13722727687939645
# Switches in the controller 13 : [32, 11, 28, 25, 5]
# Switch selected is : 5
# The target controller set for 14 is : [4, 27, 9, 12, 22, 31]
# The mean load ratio is : 0.11923685382031504
#
# At time step 957 the number of switch migrated are : 5
# The migrated switches are [8, 19, 31, 18, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 958
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.07985043760420783
# 24 :	 0.07110790720887054
# 13 :	 0.041514913838484734
# 6 :	 0.12342925434991055
# 14 :	 0.11584348413170452
# Switches in the controller 6 : [21, 0, 1, 8, 19]
# Switch selected is : 19
# The target controller set for 13 is : [32, 11, 28, 25]
# The mean load ratio is : 0.08634919942663563
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.07985043760420783
# 24 :	 0.07110790720887054
# 13 :	 0.05987664147362362
# 6 :	 0.10506752671477167
# 14 :	 0.11584348413170452
# Switches in the controller 6 : [21, 0, 1, 8]
# Switch selected is : 0
# The target controller set for 24 is : [7, 16, 30, 20, 18]
# The mean load ratio is : 0.08634919942663563
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.07985043760420783
# 24 :	 0.08946993360103672
# 13 :	 0.05987664147362362
# 6 :	 0.08670550032260549
# 14 :	 0.11584348413170452
# Switches in the controller 6 : [21, 1, 8]
# Switch selected is : 8
# The target controller set for 24 is : [7, 16, 30, 20, 18, 0]
# The mean load ratio is : 0.08634919942663563
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.07985043760420783
# 24 :	 0.11512838854905114
# 13 :	 0.05987664147362362
# 6 :	 0.06104704537459108
# 14 :	 0.11584348413170452
# Switches in the controller 14 : [4, 27, 9, 12, 22, 31, 5]
# Switch selected is : 5
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 26]
# The mean load ratio is : 0.08634919942663563
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.10017443310874237
# 24 :	 0.11512838854905114
# 13 :	 0.05987664147362362
# 6 :	 0.06104704537459108
# 14 :	 0.09551948862716998
# Switches in the controller 14 : [4, 27, 9, 12, 22, 31]
# Switch selected is : 4
# The target controller set for 29 is : [10, 23, 33, 15, 17, 3, 2, 26, 5]
# The mean load ratio is : 0.08634919942663563
#
# At time step 958 the number of switch migrated are : 5
# The migrated switches are [19, 0, 8, 5, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 959
# The overloaded domains are : [24, 13, 29]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.15887976326582
# 24 :	 0.1560519334558479
# 13 :	 0.10767086042475488
# 6 :	 0.04077824356401496
# 14 :	 0.10564478435142846
# Switches in the controller 29 : [10, 23, 33, 15, 17, 3, 2, 26, 5, 4]
# Switch selected is : 15
# The target controller set for 24 is : [7, 16, 30, 20, 18, 0, 8]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.15853460903267702
# 24 :	 0.15639708768899088
# 13 :	 0.10767086042475488
# 6 :	 0.04077824356401496
# 14 :	 0.10564478435142846
# Switches in the controller 29 : [10, 23, 33, 17, 3, 2, 26, 5, 4]
# Switch selected is : 3
# The target controller set for 13 is : [32, 11, 28, 25, 19]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1388505478044268
# 24 :	 0.15639708768899088
# 13 :	 0.1273549216530051
# 6 :	 0.04077824356401496
# 14 :	 0.10564478435142846
# Switches in the controller 29 : [10, 23, 33, 17, 2, 26, 5, 4]
# Switch selected is : 5
# The target controller set for 14 is : [27, 9, 12, 22, 31]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11859421410807702
# 24 :	 0.15639708768899088
# 13 :	 0.1273549216530051
# 6 :	 0.04077824356401496
# 14 :	 0.12590111804777823
# Switches in the controller 29 : [10, 23, 33, 17, 2, 26, 4]
# Switch selected is : 2
# The target controller set for 24 is : [7, 16, 30, 20, 18, 0, 8, 15]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.0905851953161766
# 24 :	 0.18440610648089129
# 13 :	 0.1273549216530051
# 6 :	 0.04077824356401496
# 14 :	 0.12590111804777823
# Switches in the controller 24 : [7, 16, 30, 20, 18, 0, 8, 15, 2]
# Switch selected is : 7
# The target controller set for 13 is : [32, 11, 28, 25, 19, 3]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.0905851953161766
# 24 :	 0.15193912072971133
# 13 :	 0.15982190740418506
# 6 :	 0.04077824356401496
# 14 :	 0.12590111804777823
# Switches in the controller 24 : [16, 30, 20, 18, 0, 8, 15, 2]
# Switch selected is : 18
# The target controller set for 29 is : [10, 23, 33, 17, 26, 4]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10894713920220288
# 24 :	 0.13357717684368506
# 13 :	 0.15982190740418506
# 6 :	 0.04077824356401496
# 14 :	 0.12590111804777823
# Switches in the controller 24 : [16, 30, 20, 0, 8, 15, 2]
# Switch selected is : 15
# The target controller set for 6 is : [21, 1]
# The mean load ratio is : 0.11380511701237324
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10894713920220288
# 24 :	 0.13323202261054207
# 13 :	 0.15982190740418506
# 6 :	 0.041123397797157964
# 14 :	 0.12590111804777823
# Switches in the controller 24 : [16, 30, 20, 0, 8, 2]
# Switch selected is : 8
# The target controller set for 6 is : [21, 1, 15]
# The mean load ratio is : 0.11380511701237324
#
# At time step 959 the number of switch migrated are : 8
# The migrated switches are [15, 3, 5, 2, 7, 18, 15, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 960
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1014866532600259
# 24 :	 0.09331435776090917
# 13 :	 0.1716551718851915
# 6 :	 0.05927301087557094
# 14 :	 0.11032171298526794
# Switches in the controller 13 : [32, 11, 28, 25, 19, 3, 7]
# Switch selected is : 3
# The target controller set for 29 is : [10, 23, 33, 17, 26, 4, 18]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.15889337203607437
# 24 :	 0.09331435776090917
# 13 :	 0.11424845310914303
# 6 :	 0.05927301087557094
# 14 :	 0.11032171298526794
# Switches in the controller 13 : [32, 11, 28, 25, 19, 7]
# Switch selected is : 32
# The target controller set for 6 is : [21, 1, 15, 8]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.15889337203607437
# 24 :	 0.09331435776090917
# 13 :	 0.11403828480713181
# 6 :	 0.05948317917758216
# 14 :	 0.11032171298526794
# Switches in the controller 13 : [11, 28, 25, 19, 7]
# Switch selected is : 11
# The target controller set for 6 is : [21, 1, 15, 8, 32]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.15889337203607437
# 24 :	 0.09331435776090917
# 13 :	 0.09082523764776002
# 6 :	 0.08269622633695396
# 14 :	 0.11032171298526794
# Switches in the controller 14 : [27, 9, 12, 22, 31, 5]
# Switch selected is : 31
# The target controller set for 24 is : [16, 30, 20, 0, 2]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.15889337203607437
# 24 :	 0.11746925966074455
# 13 :	 0.09082523764776002
# 6 :	 0.08269622633695396
# 14 :	 0.08616681108543256
# Switches in the controller 29 : [10, 23, 33, 17, 26, 4, 18, 3]
# Switch selected is : 18
# The target controller set for 6 is : [21, 1, 15, 8, 32, 11]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.14053164715541408
# 24 :	 0.11746925966074455
# 13 :	 0.09082523764776002
# 6 :	 0.10105795121761424
# 14 :	 0.08616681108543256
# Switches in the controller 29 : [10, 23, 33, 17, 26, 4, 3]
# Switch selected is : 23
# The target controller set for 14 is : [27, 9, 12, 22, 5]
# The mean load ratio is : 0.10721018135339308
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12216963729896213
# 24 :	 0.11746925966074455
# 13 :	 0.09082523764776002
# 6 :	 0.10105795121761424
# 14 :	 0.10452882094188451
# Switches in the controller 29 : [10, 33, 17, 26, 4, 3]
# Switch selected is : 4
# The target controller set for 13 is : [28, 25, 19, 7]
# The mean load ratio is : 0.10721018135339308
#
# At time step 960 the number of switch migrated are : 7
# The migrated switches are [3, 32, 11, 31, 18, 23, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 961
# The overloaded domains are : [24, 13, 6, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.08138818710046049
# 24 :	 0.09755043462684194
# 13 :	 0.0979619290111526
# 6 :	 0.08487565832453361
# 14 :	 0.11161316532737134
# Switches in the controller 14 : [27, 9, 12, 22, 5, 23]
# Switch selected is : 9
# The target controller set for 29 is : [10, 33, 17, 26, 3]
# The mean load ratio is : 0.094677874878072
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10982073963304756
# 24 :	 0.09755043462684194
# 13 :	 0.0979619290111526
# 6 :	 0.08487565832453361
# 14 :	 0.08318061279478427
# Switches in the controller 13 : [28, 25, 19, 7, 4]
# Switch selected is : 19
# The target controller set for 29 is : [10, 33, 17, 26, 3, 9]
# The mean load ratio is : 0.094677874878072
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1281826932901777
# 24 :	 0.09755043462684194
# 13 :	 0.07959997535402247
# 6 :	 0.08487565832453361
# 14 :	 0.08318061279478427
# Switches in the controller 24 : [16, 30, 20, 0, 2, 31]
# Switch selected is : 31
# The target controller set for 6 is : [21, 1, 15, 8, 32, 11, 18]
# The mean load ratio is : 0.094677874878072
#
# At time step 961 the number of switch migrated are : 3
# The migrated switches are [9, 19, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# ...
# 6 :	 0.15012204296482773
# 14 :	 0.0628128300321115
# Switches in the controller 6 : [11, 18, 25, 4]
# Switch selected is : 18
# The target controller set for 14 is : [33, 17, 3, 1, 21, 32]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10971990776369249
# 24 :	 0.0994909899425462
# 13 :	 0.1288509180790044
# 6 :	 0.13175993226262553
# 14 :	 0.0811749407343137
# Switches in the controller 6 : [11, 25, 4]
# Switch selected is : 11
# The target controller set for 29 is : [19, 27, 2, 16, 23, 8]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.19594997055137486
# 24 :	 0.0994909899425462
# 13 :	 0.1288509180790044
# 6 :	 0.04552986947494314
# 14 :	 0.0811749407343137
# Switches in the controller 13 : [5, 9, 26, 31, 30, 28]
# Switch selected is : 26
# The target controller set for 29 is : [19, 27, 2, 16, 23, 8, 11]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.21667690455567712
# 24 :	 0.0994909899425462
# 13 :	 0.10812398407470214
# 6 :	 0.04552986947494314
# 14 :	 0.0811749407343137
# Switches in the controller 29 : [19, 27, 2, 16, 23, 8, 11, 26]
# Switch selected is : 23
# The target controller set for 6 is : [25, 4]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.19831486227772985
# 24 :	 0.0994909899425462
# 13 :	 0.10812398407470214
# 6 :	 0.06389191175289041
# 14 :	 0.0811749407343137
# Switches in the controller 29 : [19, 27, 2, 16, 8, 11, 26]
# Switch selected is : 27
# The target controller set for 14 is : [33, 17, 3, 1, 21, 32, 18]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1775879696303984
# 24 :	 0.0994909899425462
# 13 :	 0.10812398407470214
# 6 :	 0.06389191175289041
# 14 :	 0.10190183338164512
# Switches in the controller 29 : [19, 2, 16, 8, 11, 26]
# Switch selected is : 16
# The target controller set for 6 is : [25, 4, 23]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.17752441819281717
# 24 :	 0.0994909899425462
# 13 :	 0.10812398407470214
# 6 :	 0.06395546319047167
# 14 :	 0.10190183338164512
# Switches in the controller 29 : [19, 2, 8, 11, 26]
# Switch selected is : 26
# The target controller set for 13 is : [5, 9, 31, 30, 28]
# The mean load ratio is : 0.11019933775643645
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1567974841885149
# 24 :	 0.0994909899425462
# 13 :	 0.1288509180790044
# 6 :	 0.06395546319047167
# 14 :	 0.10190183338164512
# Switches in the controller 29 : [19, 2, 8, 11]
# Switch selected is : 11
# The target controller set for 6 is : [25, 4, 23, 16]
# The mean load ratio is : 0.11019933775643645
#
# At time step 995 the number of switch migrated are : 11
# The migrated switches are [32, 30, 28, 18, 11, 26, 23, 27, 16, 26, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 996
# The overloaded domains are : [24, 13, 6, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04787399496606156
# 24 :	 0.11452302190089168
# 13 :	 0.19294782353220655
# 6 :	 0.09191679424909996
# 14 :	 0.16968707340751704
# Switches in the controller 13 : [5, 9, 31, 30, 28, 26]
# Switch selected is : 5
# The target controller set for 14 is : [33, 17, 3, 1, 21, 32, 18, 27]
# The mean load ratio is : 0.12338974161115535
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04787399496606156
# 24 :	 0.11452302190089168
# 13 :	 0.1706979883455727
# 6 :	 0.09191679424909996
# 14 :	 0.19193690859415086
# Switches in the controller 13 : [9, 31, 30, 28, 26]
# Switch selected is : 9
# The target controller set for 6 is : [25, 4, 23, 16, 11]
# The mean load ratio is : 0.12338974161115535
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04787399496606156
# 24 :	 0.11452302190089168
# 13 :	 0.14193223523780163
# 6 :	 0.12068254735687105
# 14 :	 0.19193690859415086
# Switches in the controller 13 : [31, 30, 28, 26]
# Switch selected is : 30
# The target controller set for 24 is : [20, 15, 0, 7, 22, 10, 12]
# The mean load ratio is : 0.12338974161115535
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.04787399496606156
# 24 :	 0.15000603404558382
# 13 :	 0.10644922309310947
# 6 :	 0.12068254735687105
# 14 :	 0.19193690859415086
# Switches in the controller 14 : [33, 17, 3, 1, 21, 32, 18, 27, 5]
# Switch selected is : 1
# The target controller set for 24 is : [20, 15, 0, 7, 22, 10, 12, 30]
# The mean load ratio is : 0.12338974161115535
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.04787399496606156
# 24 :	 0.20244986870368992
# 13 :	 0.10644922309310947
# 6 :	 0.12068254735687105
# 14 :	 0.13949307393604476
# Switches in the controller 14 : [33, 17, 3, 21, 32, 18, 27, 5]
# Switch selected is : 5
# The target controller set for 29 is : [19, 2, 8]
# The mean load ratio is : 0.12338974161115535
#
# At time step 996 the number of switch migrated are : 5
# The migrated switches are [5, 9, 30, 1, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 997
# The overloaded domains are : [24, 29, 14, 6]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10300179173344902
# 24 :	 0.13961502726588987
# 13 :	 0.06760264844837896
# 6 :	 0.08593620252507572
# 14 :	 0.12408620829458
# Switches in the controller 24 : [20, 15, 0, 7, 22, 10, 12, 30, 1]
# Switch selected is : 10
# The target controller set for 14 is : [33, 17, 3, 21, 32, 18, 27]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10300179173344902
# 24 :	 0.11814395514098755
# 13 :	 0.06760264844837896
# 6 :	 0.08593620252507572
# 14 :	 0.14555728041948232
# Switches in the controller 24 : [20, 15, 0, 7, 22, 12, 30, 1]
# Switch selected is : 15
# The target controller set for 13 is : [31, 28, 26]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10300179173344902
# 24 :	 0.11787067994727123
# 13 :	 0.06787592364209528
# 6 :	 0.08593620252507572
# 14 :	 0.14555728041948232
# Switches in the controller 24 : [20, 0, 7, 22, 12, 30, 1]
# Switch selected is : 12
# The target controller set for 6 is : [25, 4, 23, 16, 11, 9]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10300179173344902
# 24 :	 0.11766031382877593
# 13 :	 0.06787592364209528
# 6 :	 0.08614656864357102
# 14 :	 0.14555728041948232
# Switches in the controller 24 : [20, 0, 7, 22, 30, 1]
# Switch selected is : 22
# The target controller set for 13 is : [31, 28, 26, 15]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.10300179173344902
# 24 :	 0.09929820575725554
# 13 :	 0.08623803171361567
# 6 :	 0.08614656864357102
# 14 :	 0.14555728041948232
# Switches in the controller 14 : [33, 17, 3, 21, 32, 18, 27, 10]
# Switch selected is : 21
# The target controller set for 29 is : [19, 2, 8, 5]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.12136373667616933
# 24 :	 0.09929820575725554
# 13 :	 0.08623803171361567
# 6 :	 0.08614656864357102
# 14 :	 0.127195335476762
# Switches in the controller 14 : [33, 17, 3, 32, 18, 27, 10]
# Switch selected is : 33
# The target controller set for 13 is : [31, 28, 26, 15, 22]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.12136373667616933
# 24 :	 0.09929820575725554
# 13 :	 0.08644810391275277
# 6 :	 0.08614656864357102
# 14 :	 0.1269852632776249
# Switches in the controller 14 : [17, 3, 32, 18, 27, 10]
# Switch selected is : 27
# The target controller set for 13 is : [31, 28, 26, 15, 22, 33]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.12136373667616933
# 24 :	 0.09929820575725554
# 13 :	 0.1089823549625911
# 6 :	 0.08614656864357102
# 14 :	 0.10445101222778658
# Switches in the controller 14 : [17, 3, 32, 18, 10]
# Switch selected is : 3
# The target controller set for 29 is : [19, 2, 8, 5, 21]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1855444838377045
# 24 :	 0.09929820575725554
# 13 :	 0.1089823549625911
# 6 :	 0.08614656864357102
# 14 :	 0.04027026506625141
# Switches in the controller 29 : [19, 2, 8, 5, 21, 3]
# Switch selected is : 2
# The target controller set for 24 is : [20, 0, 7, 30, 1]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.14660303405584735
# 24 :	 0.1382396555391127
# 13 :	 0.1089823549625911
# 6 :	 0.08614656864357102
# 14 :	 0.04027026506625141
# Switches in the controller 29 : [19, 8, 5, 21, 3]
# Switch selected is : 5
# The target controller set for 13 is : [31, 28, 26, 15, 22, 33, 27]
# The mean load ratio is : 0.10404837565347473
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12095242354013189
# 24 :	 0.1382396555391127
# 13 :	 0.13463296547830655
# 6 :	 0.08614656864357102
# 14 :	 0.04027026506625141
# Switches in the controller 29 : [19, 8, 21, 3]
# Switch selected is : 19
# The target controller set for 14 is : [17, 32, 18, 10]
# The mean load ratio is : 0.10404837565347473
#
# At time step 997 the number of switch migrated are : 11
# The migrated switches are [10, 15, 12, 22, 21, 33, 27, 3, 2, 5, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 998
# The overloaded domains are : [24, 13, 14, 6]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04762764649230627
# 24 :	 0.14210329413756412
# 13 :	 0.12548162699666301
# 6 :	 0.11970524216475978
# 14 :	 0.06392245221657832
# Switches in the controller 13 : [31, 28, 26, 15, 22, 33, 27, 5]
# Switch selected is : 33
# The target controller set for 24 is : [20, 0, 7, 30, 1, 2]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04762764649230627
# 24 :	 0.14231391736634297
# 13 :	 0.12527100376788416
# 6 :	 0.11970524216475978
# 14 :	 0.06392245221657832
# Switches in the controller 13 : [31, 28, 26, 15, 22, 27, 5]
# Switch selected is : 22
# The target controller set for 14 is : [17, 32, 18, 10, 19]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.04762764649230627
# 24 :	 0.14231391736634297
# 13 :	 0.10690883202502136
# 6 :	 0.11970524216475978
# 14 :	 0.08228462395944112
# Switches in the controller 13 : [31, 28, 26, 15, 27, 5]
# Switch selected is : 27
# The target controller set for 6 is : [25, 4, 23, 16, 11, 9, 12]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.04762764649230627
# 24 :	 0.14231391736634297
# 13 :	 0.08556941545294044
# 6 :	 0.1410446587368407
# 14 :	 0.08228462395944112
# Switches in the controller 24 : [20, 0, 7, 30, 1, 2, 33]
# Switch selected is : 30
# The target controller set for 6 is : [25, 4, 23, 16, 11, 9, 12, 27]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.04762764649230627
# 24 :	 0.12097466318470271
# 13 :	 0.08556941545294044
# 6 :	 0.16238391291848095
# 14 :	 0.08228462395944112
# Switches in the controller 24 : [20, 0, 7, 1, 2, 33]
# Switch selected is : 7
# The target controller set for 29 is : [8, 21, 3]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.06896683792665873
# 24 :	 0.09963547175035026
# 13 :	 0.08556941545294044
# 6 :	 0.16238391291848095
# 14 :	 0.08228462395944112
# Switches in the controller 6 : [25, 4, 23, 16, 11, 9, 12, 27, 30]
# Switch selected is : 27
# The target controller set for 14 is : [17, 32, 18, 10, 19, 22]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.06896683792665873
# 24 :	 0.09963547175035026
# 13 :	 0.08556941545294044
# 6 :	 0.14104449634640004
# 14 :	 0.10362404053152204
# Switches in the controller 6 : [25, 4, 23, 16, 11, 9, 12, 30]
# Switch selected is : 30
# The target controller set for 13 is : [31, 28, 26, 15, 5]
# The mean load ratio is : 0.0997680524015743
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.06896683792665873
# 24 :	 0.09963547175035026
# 13 :	 0.1069086696345807
# 6 :	 0.11970524216475978
# 14 :	 0.10362404053152204
# Switches in the controller 6 : [25, 4, 23, 16, 11, 9, 12]
# Switch selected is : 25
# The target controller set for 29 is : [8, 21, 3, 7]
# The mean load ratio is : 0.0997680524015743
#
# At time step 998 the number of switch migrated are : 8
# The migrated switches are [33, 22, 27, 30, 7, 27, 30, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# The overloaded domains are : [29, 13, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.17150155740440656
# 6 :	 0.13481533038887122
# 14 :	 0.11249761045345193
# Switches in the controller 6 : [4, 23, 16, 11, 9, 12]
# Switch selected is : 23
# The target controller set for 13 is : [31, 28, 26, 15, 5, 30]
# The mean load ratio is : 0.12586346860619052
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.18986366617007325
# 6 :	 0.11645322162320454
# 14 :	 0.11249761045345193
# Switches in the controller 13 : [31, 28, 26, 15, 5, 30, 23]
# Switch selected is : 15
# The target controller set for 14 is : [17, 32, 18, 10, 19, 22, 27]
# The mean load ratio is : 0.12586346860619052
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.18964018330561241
# 6 :	 0.11645322162320454
# 14 :	 0.11272109331791277
# Switches in the controller 13 : [31, 28, 26, 5, 30, 23]
# Switch selected is : 30
# The target controller set for 14 is : [17, 32, 18, 10, 19, 22, 27, 15]
# The mean load ratio is : 0.12586346860619052
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.15373228759750113
# 6 :	 0.11645322162320454
# 14 :	 0.14862898902602406
# Switches in the controller 13 : [31, 28, 26, 5, 23]
# Switch selected is : 26
# The target controller set for 14 is : [17, 32, 18, 10, 19, 22, 27, 15, 30]
# The mean load ratio is : 0.12586346860619052
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.11782537313370486
# 6 :	 0.11645322162320454
# 14 :	 0.18453590348982032
# Switches in the controller 14 : [17, 32, 18, 10, 19, 22, 27, 15, 30, 26]
# Switch selected is : 30
# The target controller set for 6 is : [4, 16, 11, 9, 12]
# The mean load ratio is : 0.12586346860619052
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11635437575003105
# 24 :	 0.09414846903419169
# 13 :	 0.11782537313370486
# 6 :	 0.15236111733131583
# 14 :	 0.14862800778170904
# Switches in the controller 14 : [17, 32, 18, 10, 19, 22, 27, 15, 26]
# Switch selected is : 26
# The target controller set for 29 is : [8, 21, 3, 7, 25]
# The mean load ratio is : 0.12586346860619052
#
# At time step 999 the number of switch migrated are : 6
# The migrated switches are [23, 15, 30, 26, 30, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 0.7
epsilon_dec = 0.0025
epsilon_min = 0.05

load_controller = []

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon * epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# 13 :	 0.06509011732912719
# 6 :	 0.1058363524116471
# 14 :	 0.08138256910751103
# [(610972.3541, 4), (452612.3313, 26), (452607.9864, 7), (452591.7778, 27), (415307.6741, 23), (7840.0, 12), (1843.872057, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 7, 4]
# Switch selected is : 4
# The underloaded domains are : [29, 13, 14]
# The target controller set for 29 is : [0, 10, 1, 5]
# The mean load ratio is : 0.09066162058113257
# The reward is = 0.9399311829146396
# Q value = 15.291542975160821
#
# At time step 910 the number of switch migrated are : 3
# The migrated switches are [8, 8, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 911
# 0.17294043479594715
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.14518328971973518
# 24 :	 0.1026009626701192
# 13 :	 0.10028190098787235
# 6 :	 0.09933125808453937
# 14 :	 0.09368191954532486
# [(840838.4891, 1), (808367.6065, 4), (647902.4596, 5), (571298.0838, 10), (415307.0, 0)]
# Switches in the controller 29 : [0, 10, 1, 5, 4]
# Switch selected is : 1
# The underloaded domains are : [24, 13, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 27, 7]
# The mean load ratio is : 0.1082158662015182
# The reward is = 2.1448503463881052
# Q value = 13.915714882363682
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10800718017088737
# 24 :	 0.1026009626701192
# 13 :	 0.10028190098787235
# 6 :	 0.13650736763338717
# 14 :	 0.09368191954532486
# [(840838.4891, 1), (607226.8847, 27), (607221.4748, 26), (607217.2862, 7), (415301.7652, 23), (9609.0, 12), (69.24357502, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 24, 13, 14]
# The target controller set for 29 is : [0, 10, 5, 4]
# The mean load ratio is : 0.1082158662015182
# The reward is = 1.066537464466836
# Q value = 12.601139919337175
#
# At time step 911 the number of switch migrated are : 2
# The migrated switches are [1, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 912
# 0.25235056638563924
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.14386245736167438
# 24 :	 0.0915854745492904
# 13 :	 0.09013925588612984
# 6 :	 0.073572271023988
# 14 :	 0.08444299300522967
# [(1170257.697, 1), (718843.7861, 10), (526790.6052, 4), (422640.3466, 5), (415307.0, 0)]
# Switches in the controller 29 : [0, 10, 5, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 13, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 27, 7]
# The mean load ratio is : 0.09672049036526245
# The reward is = 1.6377365170383253
# Q value = 12.816874052575942
#
# At time step 912 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 913
# 0.19283225739866813
# The overloaded domains are : [24, 13, 14, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10147686918384934
# 24 :	 0.10820121663773873
# 13 :	 0.10962894162842478
# 6 :	 0.1662166748898672
# 14 :	 0.11939838373419226
# [(861788.9357, 1), (824896.3577, 27), (824885.2309999999, 7), (824885.1919, 26), (415311.158, 23), (6401.0, 12), (1272.784599, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 24, 13, 14]
# The target controller set for 13 is : [20, 19, 25, 11, 3]
# The mean load ratio is : 0.12098441721481445
# The reward is = 4.687173213249044
# Q value = 16.004525781014017
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10147686918384934
# 24 :	 0.10820121663773873
# 13 :	 0.14773133619870701
# 6 :	 0.12811428031958494
# 14 :	 0.11939838373419226
# [(824896.3577, 27), (824885.2309999999, 7), (824885.1919, 26), (415311.158, 23), (6401.0, 12), (1272.784599, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 7]
# Switch selected is : 27
# The underloaded domains are : [29, 24, 14]
# The target controller set for 29 is : [0, 10, 5, 4]
# The mean load ratio is : 0.12098441721481445
# The reward is = 0.9916450961390294
# Q value = 11.402158041636964
#
# At time step 913 the number of switch migrated are : 2
# The migrated switches are [1, 27]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 914
# 0.1220574996142984
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12519406661171267
# 24 :	 0.12932132731651366
# 13 :	 0.12281141326898076
# 6 :	 0.09001793696818954
# 14 :	 0.11193679545737237
# [(807111.9767, 27), (680278.0076, 4), (523947.3162, 10), (415307.0, 0), (404958.874, 5)]
# Switches in the controller 29 : [0, 10, 5, 4, 27]
# Switch selected is : 27
# The underloaded domains are : [6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 7]
# The mean load ratio is : 0.11585630792455379
# The reward is = 0.7432630926514527
# Q value = 12.294608304647136
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.08950911206580128
# 24 :	 0.12932132731651366
# 13 :	 0.12281141326898076
# 6 :	 0.1257028915141009
# 14 :	 0.11193679545737237
# [(807119.5705, 30), (697262.6498, 8), (583733.2469, 9), (415311.8401, 18), (415307.4348, 22), (6217.6208240000005, 33)]
# Switches in the controller 24 : [33, 18, 22, 30, 9, 8]
# Switch selected is : 30
# The underloaded domains are : [29, 14]
# The target controller set for 29 is : [0, 10, 5, 4]
# The mean load ratio is : 0.11585630792455379
# The reward is = 1.7335375032585192
# Q value = 11.863046470281063
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1251944023574526
# 24 :	 0.09363603702486234
# 13 :	 0.12281141326898076
# 6 :	 0.1257028915141009
# 14 :	 0.11193679545737237
# [(807124.583, 25), (513020.852, 3), (503214.0882, 1), (415309.0904, 19), (415297.1365, 20), (123747.2605, 11)]
# Switches in the controller 13 : [20, 19, 25, 11, 3, 1]
# Switch selected is : 25
# The underloaded domains are : [24, 14]
# The target controller set for 24 is : [33, 18, 22, 9, 8]
# The mean load ratio is : 0.11585630792455379
# The reward is = 1.0259231116406387
# Q value = 11.336792418356564
#
# At time step 914 the number of switch migrated are : 3
# The migrated switches are [27, 30, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 915
# 0.17377187254919782
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11896948322041148
# 24 :	 0.10551542614486767
# 13 :	 0.14213601477897864
# 6 :	 0.08989476762933635
# 14 :	 0.0930687748672545
# [(824744.5624, 10), (535559.6245, 30), (505428.1306, 5), (415307.0, 0), (409778.0309, 4)]
# Switches in the controller 29 : [0, 10, 5, 4, 30]
# Switch selected is : 10
# The underloaded domains are : [24, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 7, 27]
# The mean load ratio is : 0.10991689332816972
# The reward is = 0.5953346706749516
# Q value = 11.996944952289711
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.08250493670040496
# 24 :	 0.10551542614486767
# 13 :	 0.14213601477897864
# 6 :	 0.12635931414934287
# 14 :	 0.0930687748672545
# [(1391219.801, 3), (887559.0261, 1), (415305.6598, 20), (415300.9573, 19), (105405.8119, 11)]
# Switches in the controller 13 : [20, 19, 11, 3, 1]
# Switch selected is : 3
# The underloaded domains are : [29, 24, 14]
# The target controller set for 29 is : [0, 5, 4, 30]
# The mean load ratio is : 0.10991689332816972
# The reward is = 1.181276686019297
# Q value = 12.570896631916051
#
# At time step 915 the number of switch migrated are : 2
# The migrated switches are [10, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 916
# 0.25750759633277936
# The overloaded domains are : [24, 29, 14, 6]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.12706649830666594
# 24 :	 0.10345630876115582
# 13 :	 0.06122328455107477
# 6 :	 0.12566932890184374
# 14 :	 0.08047179568047853
# [(576601.0424, 25), (532037.5044, 8), (415312.4755, 22), (415311.4917, 18), (394179.3905, 9), (6502.952621, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 25]
# Switch selected is : 25
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 11, 1]
# The mean load ratio is : 0.09957744324024376
# The reward is = 2.090294950330288
# Q value = 13.821154466656894
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12706649830666594
# 24 :	 0.07796296634626916
# 13 :	 0.08671662696596143
# 6 :	 0.12566932890184374
# 14 :	 0.08047179568047853
# [(856939.7438, 3), (665312.0731, 4), (576595.1612, 30), (415307.0, 0), (359799.3147, 5)]
# Switches in the controller 29 : [0, 5, 4, 30, 3]
# Switch selected is : 3
# The underloaded domains are : [24, 13, 14]
# The target controller set for 13 is : [20, 19, 11, 1, 25]
# The mean load ratio is : 0.09957744324024376
# The reward is = 1.5086545915523515
# Q value = 13.620051585911433
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.08917850173508943
# 24 :	 0.07796296634626916
# 13 :	 0.12460462353753796
# 6 :	 0.12566932890184374
# 14 :	 0.08047179568047853
# [(684351.0411, 10), (576607.809, 26), (576604.8501, 7), (576600.9878, 27), (415311.1307, 23), (6491.0, 12), (6385.700764, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 7, 27, 10]
# Switch selected is : 10
# The underloaded domains are : [29, 24, 14]
# The target controller set for 29 is : [0, 5, 4, 30]
# The mean load ratio is : 0.09957744324024376
# The reward is = 1.1178910482482716
# Q value = 10.952019511686549
#
# At time step 916 the number of switch migrated are : 3
# The migrated switches are [25, 3, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 917
# 0.28048267539440475
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.09957004892005185
# 24 :	 0.07849274837837333
# 13 :	 0.14156461574145301
# 6 :	 0.06925883745050011
# 14 :	 0.07735401516772851
# [(630207.964, 5), (492649.0302, 4), (415307.0, 0), (379766.6406, 30), (334115.9217, 10)]
# Switches in the controller 29 : [0, 5, 4, 30, 10]
# Switch selected is : 5
# The underloaded domains are : [24, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 7, 27]
# The mean load ratio is : 0.09324805313162135
# The reward is = 0.9489559638462086
# Q value = 12.090052387249496
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.07170657619380039
# 24 :	 0.07849274837837333
# 13 :	 0.14156461574145301
# 6 :	 0.09712231017675158
# 14 :	 0.07735401516772851
# [(925079.4513, 3), (910531.48, 1), (415310.2159, 19), (415309.1158, 20), (379777.305, 25), (155859.95, 11)]
# Switches in the controller 13 : [20, 19, 11, 1, 25, 3]
# Switch selected is : 3
# The underloaded domains are : [29, 24, 14]
# The target controller set for 29 is : [0, 4, 30, 10]
# The mean load ratio is : 0.09324805313162135
# The reward is = 5.952327298491934
# Q value = 14.320176697944381
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11260724316936596
# 24 :	 0.07849274837837333
# 13 :	 0.10066394876588744
# 6 :	 0.09712231017675158
# 14 :	 0.07735401516772851
# [(910531.48, 1), (415310.2159, 19), (415309.1158, 20), (379777.305, 25), (155859.95, 11)]
# Switches in the controller 13 : [20, 19, 11, 1, 25]
# Switch selected is : 1
# The underloaded domains are : [24, 14]
# Taking a random action
# The target controller set for 14 is : [17, 32, 15, 21, 28, 31, 2]
# The mean load ratio is : 0.09324805313162135
# The reward is = 0.2829028523057846
# Q value = 9.490445305982677
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11260724316936596
# 24 :	 0.07849274837837333
# 13 :	 0.06040649327715709
# 6 :	 0.09712231017675158
# 14 :	 0.11761147065645886
# [(910531.48, 1), (555911.3358, 2), (415308.5495, 21), (379763.5999, 28), (379757.8426, 31), (7844.290981, 17), (5505.373021, 32), (5479.741359000001, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 28, 31, 2, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 13]
# The target controller set for 24 is : [33, 18, 22, 9, 8]
# The mean load ratio is : 0.09324805313162135
# The reward is = 0.4306593634829699
# Q value = 8.400485513065055
#
# At time step 917 the number of switch migrated are : 4
# The migrated switches are [5, 3, 1, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 918
# 0.14685961896653127
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.09994714712108717
# 24 :	 0.10931879013892958
# 13 :	 0.10433109054962801
# 6 :	 0.09080607730126931
# 14 :	 0.0697832329130327
# [(1172468.376, 11), (415309.9597, 19), (415308.5141, 20), (356643.5687, 25)]
# Switches in the controller 13 : [20, 19, 11, 25]
# Switch selected is : 11
# The underloaded domains are : [6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 7, 27, 5]
# The mean load ratio is : 0.09483726760478936
# The reward is = 0.3092192894288537
# Q value = 13.786241250944286
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.09994714712108717
# 24 :	 0.10931879013892958
# 13 :	 0.05249258249632714
# 6 :	 0.1426445853545702
# 14 :	 0.0697832329130327
# [(1172468.376, 11), (558550.437, 5), (415306.977, 23), (356644.8687, 7), (356641.8398, 27), (356640.7246, 26), (6596.0, 12), (3444.7351270000004, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 7, 27, 5, 11]
# Switch selected is : 11
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 25]
# The mean load ratio is : 0.09483726760478936
# The reward is = 2.885574516898578
# Q value = 14.147629235681393
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.09994714712108717
# 24 :	 0.10931879013892958
# 13 :	 0.10433109054962801
# 6 :	 0.09080607730126933
# 14 :	 0.0697832329130327
# [(608522.8911, 1), (522422.4585, 9), (504385.5306, 8), (415310.1561, 18), (415308.3539, 22), (6591.374451, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [6, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 28, 31, 2]
# The mean load ratio is : 0.09483726760478936
# The reward is = 1.1406868552626175
# Q value = 11.897614648053644
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.09994714712108717
# 24 :	 0.08241408256931126
# 13 :	 0.10433109054962801
# 6 :	 0.09080607730126933
# 14 :	 0.096687940482651
# [(801727.702, 10), (415307.0, 0), (363115.8473, 4), (356643.0134, 30), (323782.0918, 3)]
# Switches in the controller 29 : [0, 4, 30, 10, 3]
# Switch selected is : 10
# The underloaded domains are : [24, 6]
# The target controller set for 6 is : [16, 12, 23, 26, 7, 27, 5]
# The mean load ratio is : 0.09483726760478936
# The reward is = 0.38612307287754133
# Q value = 11.009699077612508
#
# At time step 918 the number of switch migrated are : 4
# The migrated switches are [11, 11, 1, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 919
# 0.26245337719045403
# The overloaded domains are : [29, 13, 6, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11568457845576643
# 24 :	 0.0779580177308367
# 13 :	 0.1726220275978841
# 6 :	 0.170255840749293
# 14 :	 0.15123749122028834
# [(2326647.275, 11), (747051.7236, 25), (415313.2005, 20), (415302.874, 19)]
# Switches in the controller 13 : [20, 19, 25, 11]
# Switch selected is : 11
# The underloaded domains are : [29, 24]
# The target controller set for 29 is : [0, 4, 30, 3]
# The mean load ratio is : 0.1375515911508137
# The reward is = 0.6458511151288249
# Q value = 11.836003014337848
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.21855295936148567
# 24 :	 0.0779580177308367
# 13 :	 0.06975364669216486
# 6 :	 0.170255840749293
# 14 :	 0.15123749122028834
# [(747037.9624, 7), (747030.0086, 27), (747029.4859999999, 26), (604794.2453, 10), (573028.6878, 5), (415305.4382, 23), (11192.5153, 16), (5379.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 26, 7, 27, 5, 10]
# Switch selected is : 7
# The underloaded domains are : [24, 13]
# The target controller set for 13 is : [20, 19, 25]
# The mean load ratio is : 0.1375515911508137
# The reward is = 1.1613375077705146
# Q value = 12.146075524331467
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.21855295936148567
# 24 :	 0.0779580177308367
# 13 :	 0.10278254045398166
# 6 :	 0.1372269469874762
# 14 :	 0.15123749122028834
# [(1144796.131, 1), (747030.6895, 28), (747029.0899, 31), (415307.8349, 21), (349665.2018, 2), (6030.527284000001, 15), (5396.093997, 32), (5390.248413, 17)]
# Switches in the controller 14 : [17, 32, 15, 21, 28, 31, 2, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 13, 6]
# The target controller set for 6 is : [16, 12, 23, 26, 27, 5, 10]
# The mean load ratio is : 0.1375515911508137
# The reward is = 0.661467625903511
# Q value = 12.263864265910648
#
# At time step 919 the number of switch migrated are : 3
# The migrated switches are [11, 7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 920
# 0.26243468625743444
# The overloaded domains are : [13, 29, 14, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13589986563710366
# 24 :	 0.07160370115669493
# 13 :	 0.0903240595324197
# 6 :	 0.14395272404118195
# 14 :	 0.09272799854974167
# [(610533.9405, 1), (606153.3689, 27), (606151.8075, 26), (506885.054, 5), (501905.8687, 10), (415301.7549, 23), (7269.0, 12), (1680.266039, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 5, 10, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 13, 14]
# The target controller set for 13 is : [20, 19, 25, 7]
# The mean load ratio is : 0.10690166978342838
# The reward is = 217.78182698763865
# Q value = 141.31774772771237
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13589986563710366
# 24 :	 0.07160370115669493
# 13 :	 0.11731768191002041
# 6 :	 0.11695910166358124
# 14 :	 0.09272799854974167
# [(606153.3689, 27), (606151.8075, 26), (506885.054, 5), (501905.8687, 10), (415301.7549, 23), (7269.0, 12), (1680.266039, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 27, 5, 10]
# Switch selected is : 27
# The underloaded domains are : [24, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 28, 31, 2]
# The mean load ratio is : 0.10690166978342838
# The reward is = 0.7139795105571608
# Q value = 8.064020389587203
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.13589986563710366
# 24 :	 0.07160370115669493
# 13 :	 0.11731768191002041
# 6 :	 0.09015915810991554
# 14 :	 0.11952794210340739
# [(873262.8819, 11), (632181.4199, 3), (606160.3428, 30), (546832.1946, 4), (415307.0, 0)]
# Switches in the controller 29 : [0, 4, 30, 3, 11]
# Switch selected is : 11
# The underloaded domains are : [24, 6]
# The target controller set for 24 is : [33, 18, 22, 9, 8]
# The mean load ratio is : 0.10690166978342838
# The reward is = 2.676107014025679
# Q value = 12.1953916666329
#
# At time step 920 the number of switch migrated are : 3
# The migrated switches are [1, 27, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 921
# 0.1915774143763344
# The overloaded domains are : [29, 13, 14, 6]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09997396727142067
# 24 :	 0.0713033249682176
# 13 :	 0.13231687267058553
# 6 :	 0.09886761452819501
# 14 :	 0.10831077281734781
# [(590972.0786, 27), (590971.9736, 28), (590967.7459, 31), (415306.6665, 21), (246853.8178, 2), (6220.183565, 32), (4342.1202140000005, 17), (4107.1343560000005, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 28, 31, 2, 27]
# Switch selected is : 27
# The underloaded domains are : [29, 24, 6]
# The target controller set for 6 is : [16, 12, 23, 26, 5, 10]
# The mean load ratio is : 0.10215451045115334
# The reward is = 0.5376665920525386
# Q value = 64.58159970723499
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.09997396727142067
# 24 :	 0.0713033249682176
# 13 :	 0.13231687267058553
# 6 :	 0.1249963455736301
# 14 :	 0.08218204177191273
# [(645865.4587, 5), (590972.0786, 27), (590966.6883, 26), (564019.6599, 10), (415309.4993, 23), (13791.792469999999, 16), (6206.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 26, 5, 10, 27]
# Switch selected is : 5
# The underloaded domains are : [29, 24, 14]
# The target controller set for 29 is : [0, 4, 30, 3]
# The mean load ratio is : 0.10215451045115334
# The reward is = 1.001543046358602
# Q value = 10.702155298572583
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.12852970699754596
# 24 :	 0.0713033249682176
# 13 :	 0.13231687267058553
# 6 :	 0.0964406058475048
# 14 :	 0.08218204177191273
# [(980168.9768, 1), (590966.5185, 7), (590953.8541, 25), (415310.5866, 19), (415304.805, 20)]
# Switches in the controller 13 : [20, 19, 25, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 26, 10, 27]
# The mean load ratio is : 0.10215451045115334
# The reward is = 1.5011388496117186
# Q value = 65.76863385578395
#
# At time step 921 the number of switch migrated are : 3
# The migrated switches are [27, 5, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 922
# 0.17019802378556378
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.13464887708525342
# 24 :	 0.16312191977650067
# 13 :	 0.10137576060417218
# 6 :	 0.13376047296387217
# 14 :	 0.10884657474572133
# [(1527364.289, 11), (668078.201, 8), (657254.5514, 9), (415309.1861, 22), (415306.2368, 18), (6131.918893, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 11]
# Switch selected is : 11
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 25, 7]
# The mean load ratio is : 0.12835072103510398
# The reward is = 0.5153982534452772
# Q value = 33.46052695815918
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.13464887708525342
# 24 :	 0.09559234915748838
# 13 :	 0.16890533122318446
# 6 :	 0.13376047296387217
# 14 :	 0.10884657474572133
# [(731148.8516, 26), (731129.9488, 27), (662996.5041, 1), (477723.8433, 10), (415305.2068, 23), (6131.0, 12), (920.3201367999999, 16)]
# Switches in the controller 6 : [16, 12, 23, 26, 10, 27, 1]
# Switch selected is : 26
# The underloaded domains are : [24, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 28, 31, 2]
# The mean load ratio is : 0.12835072103510398
# The reward is = 0.6105030694567048
# Q value = 30.716181874547594
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.13464887708525342
# 24 :	 0.09559234915748838
# 13 :	 0.16890533122318446
# 6 :	 0.10143408667690566
# 14 :	 0.14117296103268784
# [(777847.5524, 4), (731136.2687, 30), (730212.3447, 5), (415307.0, 0), (390946.1763, 3)]
# Switches in the controller 29 : [0, 4, 30, 3, 5]
# Switch selected is : 4
# The underloaded domains are : [24, 6]
# The target controller set for 24 is : [33, 18, 22, 9, 8]
# The mean load ratio is : 0.12835072103510398
# The reward is = 0.9681929868721694
# Q value = 19.512493781203315
#
# At time step 922 the number of switch migrated are : 3
# The migrated switches are [11, 26, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 923
# 0.5460130453164713
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.2709828447121311
# 24 :	 0.11242267143465545
# 13 :	 0.07901904449237564
# 6 :	 0.0903201359348749
# 14 :	 0.09894048430728322
# [(4525304.717, 3), (733230.5997, 5), (455169.2578, 30), (415307.0, 0)]
# Switches in the controller 29 : [0, 30, 3, 5]
# Switch selected is : 3
# The underloaded domains are : [24, 13, 6, 14]
# The target controller set for 24 is : [33, 18, 22, 9, 8, 4]
# The mean load ratio is : 0.13033703617626405
# The reward is = 0.26449528348600443
# Q value = 22.01711600499978
#
# At time step 923 the number of switch migrated are : 1
# The migrated switches are [3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 924
# 0.2579628598438102
# The overloaded domains are : [24, 13, 6, 14]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.06874476791363478
# 24 :	 0.1268595707593055
# 13 :	 0.10748744963411157
# 6 :	 0.07562077356415317
# 14 :	 0.13452676922593124
# [(779502.6978, 3), (657165.9455, 4), (415310.1073, 18), (415305.5506, 22), (394595.3457, 9), (201240.1423, 8), (6153.276207, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [29, 6]
# The target controller set for 29 is : [0, 30, 5]
# The mean load ratio is : 0.10264786621942726
# The reward is = 3.6177065939004507
# Q value = 16.1630312665526
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10320902955566907
# 24 :	 0.0923953091172712
# 13 :	 0.10748744963411157
# 6 :	 0.07562077356415317
# 14 :	 0.13452676922593124
# [(692580.0947, 7), (692577.8252, 25), (415307.7542, 19), (415302.9933, 20), (215351.3676, 11)]
# Switches in the controller 13 : [20, 19, 25, 7, 11]
# Switch selected is : 7
# The underloaded domains are : [24, 6]
# The target controller set for 6 is : [16, 12, 23, 10, 27, 1]
# The mean load ratio is : 0.10264786621942726
# The reward is = 1.558335770757699
# Q value = 86.59590905040739
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10320902955566907
# 24 :	 0.0923953091172712
# 13 :	 0.07686630918242075
# 6 :	 0.10624191401584399
# 14 :	 0.13452676922593124
# [(692585.3385, 27), (692580.0947, 7), (415311.4494, 23), (363375.4667, 1), (230704.1724, 10), (6135.0, 12), (2257.3490739999997, 16)]
# Switches in the controller 6 : [16, 12, 23, 10, 27, 1, 7]
# Switch selected is : 27
# The underloaded domains are : [24, 13]
# The target controller set for 13 is : [20, 19, 25, 11]
# The mean load ratio is : 0.10264786621942726
# The reward is = 1.1491977289404067
# Q value = 93.5868995296203
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.10320902955566907
# 24 :	 0.0923953091172712
# 13 :	 0.10748768147897331
# 6 :	 0.07562054171929143
# 14 :	 0.13452676922593124
# [(692578.6012, 28), (692576.3637, 31), (692564.2139, 26), (531038.3348, 2), (415317.4631, 21), (6606.293293, 17), (6147.438926, 32), (5858.83295, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 28, 31, 2, 26]
# Switch selected is : 28
# The underloaded domains are : [24, 6]
# The target controller set for 6 is : [16, 12, 23, 10, 1, 7]
# The mean load ratio is : 0.10264786621942726
# The reward is = 11.245418887719442
# Q value = 71.88638901796618
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.10320902955566907
# 24 :	 0.0923953091172712
# 13 :	 0.10748768147897331
# 6 :	 0.10624161613865817
# 14 :	 0.1039056948065645
# [(692576.3637, 31), (692564.2139, 26), (531038.3348, 2), (415317.4631, 21), (6606.293293, 17), (6147.438926, 32), (5858.83295, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 31, 2, 26]
# Switch selected is : 31
# The underloaded domains are : [24]
# The target controller set for 24 is : [33, 18, 22, 9, 8, 4]
# The mean load ratio is : 0.10264786621942726
# The reward is = 0.4385790499161322
# Q value = 17.676762957602556
#
# At time step 924 the number of switch migrated are : 5
# The migrated switches are [3, 7, 27, 28, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 925
# 0.2715784407533754
# The overloaded domains are : [24, 29, 13, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10842832454065932
# 24 :	 0.1507792965812501
# 13 :	 0.11146680584164291
# 6 :	 0.16299346659221695
# 14 :	 0.0710498591723139
# [(890233.6634, 1), (833554.4368, 28), (833549.5931, 7), (700631.9538, 10), (415310.9661, 23), (6777.453038, 16), (6481.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 10, 1, 7, 28]
# Switch selected is : 1
# The underloaded domains are : [29, 13, 14]
# The target controller set for 13 is : [20, 19, 25, 11, 27]
# The mean load ratio is : 0.12094355054561663
# The reward is = 3.364301326941046
# Q value = 75.82362240918386
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10842832454065932
# 24 :	 0.1507792965812501
# 13 :	 0.15082683113027417
# 6 :	 0.12363344130358567
# 14 :	 0.0710498591723139
# [(833554.4368, 28), (833549.5931, 7), (700631.9538, 10), (415310.9661, 23), (6777.453038, 16), (6481.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 10, 7, 28]
# Switch selected is : 28
# The underloaded domains are : [29, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 2, 26]
# The mean load ratio is : 0.12094355054561663
# The reward is = 1.023997806328795
# Q value = 43.0931548211621
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10842832454065932
# 24 :	 0.1507792965812501
# 13 :	 0.15082683113027417
# 6 :	 0.08677938257635781
# 14 :	 0.10790391789954176
# [(890233.6634, 1), (833554.2998, 25), (833547.3133, 27), (415309.2629, 20), (415308.8788, 19), (23404.2075, 11)]
# Switches in the controller 13 : [20, 19, 25, 11, 27, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 10, 7]
# The mean load ratio is : 0.12094355054561663
# The reward is = 5.397956757057968
# Q value = 69.72305908625495
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10842832454065932
# 24 :	 0.1507792965812501
# 13 :	 0.1114668058416429
# 6 :	 0.1261394078649891
# 14 :	 0.10790391789954176
# [(833555.4639, 31), (678283.0312, 9), (661227.4912, 4), (415310.2885, 22), (415306.9777, 18), (400140.0419, 8), (6459.208624, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4, 31]
# Switch selected is : 31
# The underloaded domains are : [29, 13, 14]
# The target controller set for 13 is : [20, 19, 25, 11, 27]
# The mean load ratio is : 0.12094355054561663
# The reward is = 1.089197481539179
# Q value = 43.32141408841426
#
# At time step 925 the number of switch migrated are : 4
# The migrated switches are [1, 28, 1, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 926
# 0.1267545915337847
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11840937970275006
# 24 :	 0.10284415501671004
# 13 :	 0.1425947548503193
# 6 :	 0.12343371049843645
# 14 :	 0.10212277859594886
# [(658603.1098, 31), (658599.4491, 25), (658587.7241, 27), (418765.8518, 11), (415306.9559, 20), (415303.8156, 19)]
# Switches in the controller 13 : [20, 19, 25, 11, 27, 31]
# Switch selected is : 31
# The underloaded domains are : [24, 14]
# The target controller set for 24 is : [33, 18, 22, 9, 8, 4]
# The mean load ratio is : 0.11788095573283294
# The reward is = 1.8965910647886308
# Q value = 23.867665523349793
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11840937970275006
# 24 :	 0.1319630662898413
# 13 :	 0.11347584357718804
# 6 :	 0.12343371049843645
# 14 :	 0.10212277859594886
# [(1278697.836, 3), (658600.9529, 30), (415307.0, 0), (325543.3002, 5)]
# Switches in the controller 29 : [0, 30, 5, 3]
# Switch selected is : 3
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 25, 11, 27]
# The mean load ratio is : 0.11788095573283294
# The reward is = 0.536091527145148
# Q value = 35.053360366878735
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.061874133698618695
# 24 :	 0.1319630662898413
# 13 :	 0.1700110895813194
# 6 :	 0.12343371049843645
# 14 :	 0.10212277859594886
# [(1203500.014, 1), (658598.3676, 7), (505613.3709, 10), (415313.5177, 23), (4716.0, 12), (4046.679078, 16)]
# Switches in the controller 6 : [16, 12, 23, 10, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 2, 26, 28]
# The mean load ratio is : 0.11788095573283294
# The reward is = 0.2944636788596791
# Q value = 47.60622352332644
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.061874133698618695
# 24 :	 0.1319630662898413
# 13 :	 0.1700110895813194
# 6 :	 0.07022319630040855
# 14 :	 0.15533329279397676
# [(658603.1098, 31), (654819.7987, 4), (449571.0627, 9), (415308.9269, 18), (415306.7165, 22), (386381.0071, 8), (4711.828952000001, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4, 31]
# Switch selected is : 31
# The underloaded domains are : [29, 6]
# The target controller set for 29 is : [0, 30, 5]
# The mean load ratio is : 0.11788095573283294
# The reward is = 3.271207494540024
# Q value = 23.150348357434122
#
# At time step 926 the number of switch migrated are : 4
# The migrated switches are [31, 3, 1, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 927
# 0.20380256307867461
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11141081835823897
# 24 :	 0.10866622257250627
# 13 :	 0.14731644523371815
# 6 :	 0.0820984532125649
# 14 :	 0.14334260543644145
# [(893728.6035, 11), (745823.5877, 27), (745813.8919, 25), (415310.4074, 20), (415308.3325, 19), (115975.9102, 3)]
# Switches in the controller 13 : [20, 19, 25, 11, 27, 3]
# Switch selected is : 11
# The underloaded domains are : [29, 24, 6]
# The target controller set for 6 is : [16, 12, 23, 10, 7]
# The mean load ratio is : 0.11856690896269395
# The reward is = 2.3729861887452426
# Q value = 61.15893675960635
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11141081835823897
# 24 :	 0.10866622257250627
# 13 :	 0.10780189767034737
# 6 :	 0.12161300077593568
# 14 :	 0.14334260543644145
# [(746228.3561, 1), (745828.2882, 28), (745823.7562, 26), (568889.1574, 2), (415308.9042, 21), (7523.894509999999, 15), (6460.336111, 32), (6018.88175, 17)]
# Switches in the controller 14 : [17, 32, 15, 21, 2, 26, 28, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 24, 13]
# The target controller set for 24 is : [33, 18, 22, 9, 8, 4]
# The mean load ratio is : 0.11856690896269395
# The reward is = 0.7317160465602712
# Q value = 25.70472872811117
#
# At time step 927 the number of switch migrated are : 2
# The migrated switches are [11, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 928
# 0.40363619662482175
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.10728838289086624
# 24 :	 0.1666998810601164
# 13 :	 0.2381754800863155
# 6 :	 0.08391249006090551
# 14 :	 0.10309852596257833
# [(1058530.7079999999, 1), (691538.7062, 9), (656442.4613, 4), (526876.3692, 8), (415312.7451, 18), (415306.6462, 22), (6362.040245, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 30, 5, 31]
# The mean load ratio is : 0.1398349520121564
# The reward is = 1.6027188475946097
# Q value = 24.94418200561948
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1540893489165156
# 24 :	 0.11989891503446706
# 13 :	 0.2381754800863155
# 6 :	 0.08391249006090551
# 14 :	 0.10309852596257833
# [(1058530.7079999999, 1), (741701.5451, 5), (634806.9732, 30), (634802.0827, 31), (415307.0, 0)]
# Switches in the controller 29 : [0, 30, 5, 31, 1]
# Switch selected is : 1
# The underloaded domains are : [24, 6, 14]
# The target controller set for 24 is : [33, 18, 22, 9, 8, 4]
# The mean load ratio is : 0.1398349520121564
# The reward is = 0.5764630424956861
# Q value = 27.347718144631312
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10728838289086626
# 24 :	 0.1666998810601164
# 13 :	 0.2381754800863155
# 6 :	 0.08391249006090551
# 14 :	 0.10309852596257833
# [(3286773.0739999996, 3), (634800.9111, 25), (634791.0471, 27), (415312.0636, 20), (415306.9982, 19)]
# Switches in the controller 13 : [20, 19, 25, 27, 3]
# Switch selected is : 3
# The underloaded domains are : [29, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 10, 7, 11]
# The mean load ratio is : 0.1398349520121564
# The reward is = 0.47235936116320815
# Q value = 56.59291173239768
#
# At time step 928 the number of switch migrated are : 3
# The migrated switches are [1, 1, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 929
# 0.29365396640985914
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.09344968887106102
# 24 :	 0.18025965237828812
# 13 :	 0.09184815251972261
# 6 :	 0.11112808215340389
# 14 :	 0.09561218005920151
# [(1204523.832, 1), (896310.0023, 9), (572629.4466, 4), (566027.1737, 8), (415309.1806, 18), (415307.7623, 22), (6953.262984, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 13, 6, 14]
# The target controller set for 13 is : [20, 19, 25, 27]
# The mean load ratio is : 0.11445955119633541
# The reward is = 3.006705950777
# Q value = 42.901612133438924
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.09344968887106102
# 24 :	 0.1270038719720413
# 13 :	 0.14510393292596943
# 6 :	 0.11112808215340389
# 14 :	 0.09561218005920151
# [(896310.0023, 9), (572629.4466, 4), (566027.1737, 8), (415309.1806, 18), (415307.7623, 22), (6953.262984, 33)]
# Switches in the controller 24 : [33, 18, 22, 9, 8, 4]
# Switch selected is : 9
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 30, 5, 31]
# The mean load ratio is : 0.11445955119633541
# The reward is = 0.803932324719687
# Q value = 25.18244355116867
#
# At time step 929 the number of switch migrated are : 2
# The migrated switches are [1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 930
# 0.14744527644434496
# The overloaded domains are : [13, 29, 6, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12832264921565192
# 24 :	 0.08430329699372684
# 13 :	 0.12642729121273222
# 6 :	 0.10477936584517426
# 14 :	 0.1055911873318439
# [(795253.6649, 31), (795226.4902, 30), (649350.346, 5), (415307.0, 0), (247227.0495, 9)]
# Switches in the controller 29 : [0, 30, 5, 31, 9]
# Switch selected is : 31
# The underloaded domains are : [24, 6, 14]
# The target controller set for 24 is : [33, 18, 22, 8, 4]
# The mean load ratio is : 0.10988475811982583
# The reward is = 1.3473385095085941
# Q value = 29.76616745960203
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.09316198786546837
# 24 :	 0.1194639583439104
# 13 :	 0.12642729121273222
# 6 :	 0.10477936584517426
# 14 :	 0.1055911873318439
# [(795241.3479, 25), (795232.0154, 27), (438407.4028, 1), (415311.6313, 20), (415303.4943, 19)]
# Switches in the controller 13 : [20, 19, 25, 27, 1]
# Switch selected is : 25
# The underloaded domains are : [29, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 10, 7, 11, 3]
# The mean load ratio is : 0.10988475811982583
# The reward is = 0.6786101515958626
# Q value = 54.89025219577381
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.09316198786546837
# 24 :	 0.1194639583439104
# 13 :	 0.09126717443578983
# 6 :	 0.13993948262211664
# 14 :	 0.1055911873318439
# [(795241.948, 7), (795241.3479, 25), (722326.125, 10), (415308.3872, 23), (220034.3581, 3), (208801.4327, 11), (6239.0, 12), (1918.1284289999999, 16)]
# Switches in the controller 6 : [16, 12, 23, 10, 7, 11, 3, 25]
# Switch selected is : 7
# The underloaded domains are : [29, 13, 14]
# The target controller set for 13 is : [20, 19, 27, 1]
# The mean load ratio is : 0.10988475811982583
# The reward is = 1.780048098427681
# Q value = 54.45138374495515
#
# At time step 930 the number of switch migrated are : 3
# The migrated switches are [31, 25, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 931
# 0.14713293548276404
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.10627691954483116
# 24 :	 0.1017356116595556
# 13 :	 0.1342260079476395
# 6 :	 0.0866110083458319
# 14 :	 0.1192312870842066
# [(818403.573, 2), (722997.8903, 28), (722994.8287, 26), (415303.0024, 21), (6627.537643, 17), (6044.844247, 15), (4367.07615, 32)]
# Switches in the controller 14 : [17, 32, 15, 21, 2, 26, 28]
# Switch selected is : 2
# The underloaded domains are : [29, 24, 6]
# The target controller set for 6 is : [16, 12, 23, 10, 11, 3, 25]
# The mean load ratio is : 0.10961616691641296
# The reward is = 0.6473336891268597
# Q value = 52.01253699354375
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10627691954483116
# 24 :	 0.1017356116595556
# 13 :	 0.1342260079476395
# 6 :	 0.12279519981592295
# 14 :	 0.08304709561411555
# [(759274.4770000001, 1), (722992.0872, 7), (722990.5485, 27), (415316.3299, 20), (415311.5677, 19)]
# Switches in the controller 13 : [20, 19, 27, 1, 7]
# Switch selected is : 1
# The underloaded domains are : [29, 24, 14]
# The target controller set for 24 is : [33, 18, 22, 8, 4, 31]
# The mean load ratio is : 0.10961616691641296
# The reward is = 0.7566636673697414
# Q value = 28.01974150580611
#
# At time step 931 the number of switch migrated are : 2
# The migrated switches are [2, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 932
# 0.36455481543574086
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.08213503367055534
# 24 :	 0.1353665353050314
# 13 :	 0.07387058314144992
# 6 :	 0.14911222315594652
# 14 :	 0.05641129461424001
# [(787638.0283, 3), (642594.1949, 11), (620821.9236, 10), (478006.2213, 2), (420088.1048, 25), (415313.2166, 23), (7517.0, 12), (598.4291477999999, 16)]
# Switches in the controller 6 : [16, 12, 23, 10, 11, 3, 25, 2]
# Switch selected is : 3
# The underloaded domains are : [29, 13, 14]
# The target controller set for 13 is : [20, 19, 27, 7]
# The mean load ratio is : 0.09937913397744465
# The reward is = 7.9725842576713815
# Q value = 49.61800997480989
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.08213503367055534
# 24 :	 0.1353665353050314
# 13 :	 0.10869453328704906
# 6 :	 0.11428827301034739
# 14 :	 0.05641129461424001
# [(642594.1949, 11), (620821.9236, 10), (478006.2213, 2), (420088.1048, 25), (415313.2166, 23), (7517.0, 12), (598.4291477999999, 16)]
# Switches in the controller 6 : [16, 12, 23, 10, 11, 25, 2]
# Switch selected is : 11
# The underloaded domains are : [29, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 26, 28]
# The mean load ratio is : 0.09937913397744465
# The reward is = 20.22958045709616
# Q value = 53.025503220876644
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.08213503367055534
# 24 :	 0.1353665353050314
# 13 :	 0.10869453328704906
# 6 :	 0.08587716612747139
# 14 :	 0.084822401497116
# [(699521.3917, 4), (693967.3875, 1), (420097.4268, 31), (415311.57200000004, 18), (415310.5535, 22), (409946.0748, 8), (7526.721765, 33)]
# Switches in the controller 24 : [33, 18, 22, 8, 4, 31, 1]
# Switch selected is : 4
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 30, 5, 9]
# The mean load ratio is : 0.09937913397744465
# The reward is = 4.203137278304947
# Q value = 27.317271141539504
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1130630706559185
# 24 :	 0.10443849831966823
# 13 :	 0.10869453328704906
# 6 :	 0.08587716612747139
# 14 :	 0.084822401497116
# [(693967.3875, 1), (420097.4268, 31), (415311.57200000004, 18), (415310.5535, 22), (409946.0748, 8), (7526.721765, 33)]
# Switches in the controller 24 : [33, 18, 22, 8, 31, 1]
# Switch selected is : 1
# The underloaded domains are : [6, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 26, 28, 11]
# The mean load ratio is : 0.09937913397744465
# The reward is = 0.41211993554011905
# Q value = 26.851583357833903
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1130630706559185
# 24 :	 0.07375602129766375
# 13 :	 0.10869453328704906
# 6 :	 0.08587716612747139
# 14 :	 0.11550487851912049
# [(787638.0283, 3), (420088.771, 7), (420081.4086, 27), (415309.3769, 20), (415303.919, 19)]
# Switches in the controller 13 : [20, 19, 27, 7, 3]
# Switch selected is : 3
# The underloaded domains are : [24, 6]
# The target controller set for 6 is : [16, 12, 23, 10, 25, 2]
# The mean load ratio is : 0.09937913397744465
# The reward is = 0.8309608556779084
# Q value = 44.725388744484455
#
# At time step 932 the number of switch migrated are : 5
# The migrated switches are [3, 11, 4, 1, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 933
# 0.15871589780505366
# The overloaded domains are : [13, 29, 6, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11333253442228437
# 24 :	 0.0924367638147537
# 13 :	 0.09392677035220684
# 6 :	 0.13285522862172808
# 14 :	 0.13387778089523303
# [(934720.9549, 11), (646900.7276, 26), (646897.9032, 28), (415308.6553, 21), (368107.5579, 1), (6357.394689, 32), (6262.305676, 17), (3453.4123210000002, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 26, 28, 11, 1]
# Switch selected is : 11
# The underloaded domains are : [24, 13]
# The target controller set for 24 is : [33, 18, 22, 8, 31]
# The mean load ratio is : 0.11328581562124121
# The reward is = 0.6101505411714687
# Q value = 28.666658911991696
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11333253442228437
# 24 :	 0.13376371193550432
# 13 :	 0.09392677035220684
# 6 :	 0.13285522862172808
# 14 :	 0.09255083277448241
# [(646899.4491, 30), (624285.2321, 4), (501729.0127, 5), (415307.0, 0), (375101.7776, 9)]
# Switches in the controller 29 : [0, 30, 5, 9, 4]
# Switch selected is : 30
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 27, 7]
# The mean load ratio is : 0.11328581562124121
# The reward is = 1.827821405815209
# Q value = 33.902700262924085
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.0847310787341983
# 24 :	 0.13376371193550432
# 13 :	 0.12252822604029293
# 6 :	 0.13285522862172808
# 14 :	 0.09255083277448241
# [(646902.7796, 7), (646899.4491, 30), (646898.0355, 27), (415306.3629, 20), (415301.3367, 19)]
# Switches in the controller 13 : [20, 19, 27, 7, 30]
# Switch selected is : 7
# The underloaded domains are : [29, 14]
# The target controller set for 29 is : [0, 5, 9, 4]
# The mean load ratio is : 0.11328581562124121
# The reward is = 3.5600446459592145
# Q value = 21.10956210373878
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11333268167414601
# 24 :	 0.13376371193550432
# 13 :	 0.09392662310034522
# 6 :	 0.13285522862172808
# ...
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.08000635440094292
# 24 :	 0.12404169240973632
# 13 :	 0.09774547427466702
# 6 :	 0.129841452435046
# 14 :	 0.11982206435893143
# [(748806.4322, 3), (669295.0093, 10), (552072.3657, 7), (415312.106, 22), (415302.3926, 18), (4750.802432, 33)]
# Switches in the controller 24 : [33, 18, 22, 3, 10, 7]
# Switch selected is : 3
# The underloaded domains are : [29, 13]
# The target controller set for 29 is : [0, 28, 2, 27]
# The mean load ratio is : 0.11029140757586472
# The reward is = 1.840025453037201
# Q value = 9.181516081102465
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.11311343776500901
# 24 :	 0.09093460904567022
# 13 :	 0.09774547427466702
# 6 :	 0.129841452435046
# 14 :	 0.11982206435893143
# [(621687.0495, 9), (552074.9259, 26), (552074.0496, 30), (552068.8928, 25), (415303.4791, 21), (7641.509496, 17), (4753.631862, 32), (4497.243644, 15)]
# Switches in the controller 14 : [17, 32, 15, 21, 26, 9, 30, 25]
# Switch selected is : 9
# The underloaded domains are : [24, 13]
# The target controller set for 24 is : [33, 18, 22, 10, 7]
# The mean load ratio is : 0.11029140757586472
# The reward is = 0.7344815158179855
# Q value = 7.704440746109072
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.11311343776500901
# 24 :	 0.11842134538911477
# 13 :	 0.09774547427466702
# 6 :	 0.129841452435046
# 14 :	 0.09233532801548688
# [(1132168.172, 1), (820802.8262, 4), (552070.1211, 31), (415311.7778, 23), (11605.50526, 16), (4758.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 31, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [13, 14]
# The target controller set for 13 is : [20, 19, 8, 5, 11]
# The mean load ratio is : 0.11029140757586472
# The reward is = 1.1153361248869036
# Q value = 12.124720882245933
#
# At time step 993 the number of switch migrated are : 3
# The migrated switches are [3, 9, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 994
# 0.3402500645335782
# The overloaded domains are : [24, 29, 13, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11680274484689225
# 24 :	 0.11915863002448128
# 13 :	 0.17437802700488275
# 6 :	 0.07101881663575166
# 14 :	 0.07343421761325784
# [(876685.4031, 3), (533257.5246, 2), (415307.0, 0), (408285.3186, 27), (408275.4405, 28)]
# Switches in the controller 29 : [0, 28, 2, 27, 3]
# Switch selected is : 3
# The underloaded domains are : [6, 14]
# The target controller set for 6 is : [16, 12, 23, 31, 4]
# The mean load ratio is : 0.11095848722505315
# The reward is = 0.9863096236215381
# Q value = 9.561640575033982
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.07804173068303502
# 24 :	 0.11915863002448128
# 13 :	 0.17437802700488275
# 6 :	 0.10977983079960887
# 14 :	 0.07343421761325784
# [(744211.4187, 9), (707214.6527, 10), (415307.7722, 18), (415304.9148, 22), (408282.7642, 7), (4773.893486, 33)]
# Switches in the controller 24 : [33, 18, 22, 10, 7, 9]
# Switch selected is : 9
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 28, 2, 27]
# The mean load ratio is : 0.11095848722505315
# The reward is = 1.3311245696488565
# Q value = 8.584047111866047
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11094565407349277
# 24 :	 0.08625470663402351
# 13 :	 0.17437802700488275
# 6 :	 0.10977983079960887
# 14 :	 0.07343421761325784
# [(1093782.945, 1), (747756.4441, 8), (716970.3266, 5), (554916.3491, 11), (415304.1909, 19), (415301.5039, 20)]
# Switches in the controller 13 : [20, 19, 8, 5, 11, 1]
# Switch selected is : 1
# The underloaded domains are : [29, 24, 6, 14]
# The target controller set for 24 is : [33, 18, 22, 10, 7]
# The mean load ratio is : 0.11095848722505315
# The reward is = 3.3689792568420986
# Q value = 12.07196378529496
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.11094565407349277
# 24 :	 0.13461428473742956
# 13 :	 0.1260184489014767
# 6 :	 0.10977983079960887
# 14 :	 0.07343421761325784
# [(747756.4441, 8), (716970.3266, 5), (554916.3491, 11), (415304.1909, 19), (415301.5039, 20)]
# Switches in the controller 13 : [20, 19, 8, 5, 11]
# Switch selected is : 8
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 28, 2, 27, 9]
# The mean load ratio is : 0.11095848722505315
# The reward is = 0.7736563766464447
# Q value = 9.93835580216544
#
# At time step 994 the number of switch migrated are : 4
# The migrated switches are [3, 9, 1, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 995
# 0.24506891041771656
# The overloaded domains are : [24, 13, 29, 14]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.1351229183913327
# 24 :	 0.10894289971610024
# 13 :	 0.1457958534672596
# 6 :	 0.07994673858511195
# 14 :	 0.08118827862237783
# [(597258.6999, 2), (583510.3105, 8), (522512.5768, 9), (468794.8607, 27), (468787.6233, 28), (415307.0, 0)]
# Switches in the controller 29 : [0, 28, 2, 27, 9, 8]
# Switch selected is : 2
# The underloaded domains are : [24, 6, 14]
# The target controller set for 24 is : [33, 18, 22, 10, 7, 1]
# The mean load ratio is : 0.11019933775643646
# The reward is = 1.8327837485843879
# Q value = 8.732488850241847
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1087162360803804
# 24 :	 0.13534958202705255
# 13 :	 0.1457958534672596
# 6 :	 0.07994673858511195
# 14 :	 0.08118827862237783
# [(1950326.61, 11), (516632.6238, 5), (415304.6862, 20), (415304.5086, 19)]
# Switches in the controller 13 : [20, 19, 5, 11]
# Switch selected is : 11
# The underloaded domains are : [29, 6, 14]
# The target controller set for 6 is : [16, 12, 23, 31, 4, 3]
# The mean load ratio is : 0.11019933775643646
# The reward is = 0.30249166115277365
# Q value = 9.346650701380783
#
# At time step 995 the number of switch migrated are : 2
# The migrated switches are [2, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 996
# 0.28694069640939507
# The overloaded domains are : [24, 29, 6, 14]
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.12880724539634375
# 24 :	 0.1671456556877631
# 13 :	 0.05897418006507336
# 6 :	 0.13641013458294957
# 14 :	 0.125611492323647
# [(1001570.5279999999, 3), (802549.8206, 31), (568897.0119, 4), (415309.0775, 23), (287789.0509, 11), (4758.0, 12), (4411.465674, 16)]
# Switches in the controller 6 : [16, 12, 23, 31, 4, 3, 11]
# Switch selected is : 3
# The underloaded domains are : [13]
# The target controller set for 13 is : [20, 19, 5]
# The mean load ratio is : 0.12338974161115537
# The reward is = 3.5112011921312365
# Q value = 12.026833858000998
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.12880724539634375
# 24 :	 0.1671456556877631
# 13 :	 0.10325675769740755
# 6 :	 0.09212755695061536
# 14 :	 0.125611492323647
# [(1186159.478, 1), (802548.0592, 7), (531188.8454, 10), (425172.2999, 2), (415308.75, 18), (415306.3729, 22), (4768.2723909999995, 33)]
# Switches in the controller 24 : [33, 18, 22, 10, 7, 1, 2]
# Switch selected is : 1
# The underloaded domains are : [13, 6]
# The target controller set for 13 is : [20, 19, 5, 3]
# The mean load ratio is : 0.12338974161115537
# The reward is = 1.3190756924690394
# Q value = 9.400621310529823
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.12880724539634375
# 24 :	 0.11470182102965701
# 13 :	 0.15570059235551365
# 6 :	 0.09212755695061536
# 14 :	 0.125611492323647
# [(802544.6190000001, 28), (802538.0599, 27), (650615.4806, 9), (415307.0, 0), (242319.8473, 8)]
# Switches in the controller 29 : [0, 28, 27, 9, 8]
# Switch selected is : 28
# The underloaded domains are : [24, 6]
# The target controller set for 6 is : [16, 12, 23, 31, 4, 11]
# The mean load ratio is : 0.12338974161115537
# The reward is = 0.920544710083213
# Q value = 9.42825327642394
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 29 :	 0.09332422807429294
# 24 :	 0.11470182102965701
# 13 :	 0.15570059235551365
# 6 :	 0.12761057427266617
# 14 :	 0.125611492323647
# [(802544.5019, 30), (802543.2879, 26), (802540.8508, 25), (415305.0376, 21), (7524.776364, 17), (5827.707731, 15), (4758.226178, 32)]
# Switches in the controller 14 : [17, 32, 15, 21, 26, 30, 25]
# Switch selected is : 30
# The underloaded domains are : [29, 24]
# The target controller set for 29 is : [0, 27, 9, 8]
# The mean load ratio is : 0.12338974161115537
# The reward is = 1.132072073517115
# Q value = 8.519675455173738
#
# At time step 996 the number of switch migrated are : 4
# The migrated switches are [3, 1, 28, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 997
# 0.25840826958238733
# The overloaded domains are : [24, 29, 13, 6]
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.1007322972969787
# 24 :	 0.1198802608950445
# 13 :	 0.14406107014650826
# 6 :	 0.09142708770738367
# 14 :	 0.06414116222145842
# [(1451621.5690000001, 3), (580158.0868, 5), (415309.3096, 19), (415308.4588, 20), (395934.1772, 1)]
# Switches in the controller 13 : [20, 19, 5, 3, 1]
# Switch selected is : 3
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 27, 9, 8, 30]
# The mean load ratio is : 0.10404837565347472
# The reward is = 0.9596045820222203
# Q value = 8.625552396279797
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.16491304445851387
# 24 :	 0.1198802608950445
# 13 :	 0.07988032298497309
# 6 :	 0.09142708770738367
# 14 :	 0.06414116222145842
# [(1451621.5690000001, 3), (509680.7868, 30), (509673.1701, 27), (453430.8824, 8), (415307.0, 0), (390242.1147, 9)]
# Switches in the controller 29 : [0, 27, 9, 8, 30, 3]
# Switch selected is : 3
# The underloaded domains are : [13, 6, 14]
# The target controller set for 13 is : [20, 19, 5, 1]
# The mean load ratio is : 0.10404837565347472
# The reward is = 1.412418073168121
# Q value = 9.798101658677412
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.1007322972969787
# 24 :	 0.1198802608950445
# 13 :	 0.14406107014650826
# 6 :	 0.09142708770738367
# 14 :	 0.06414116222145842
# [(880766.4437, 2), (509667.6637, 7), (485626.4968, 10), (415308.8474, 22), (415296.2505, 18), (4751.352217000001, 33)]
# Switches in the controller 24 : [33, 18, 22, 10, 7, 2]
# Switch selected is : 2
# The underloaded domains are : [29, 6, 14]
# The target controller set for 29 is : [0, 27, 9, 8, 30]
# The mean load ratio is : 0.10404837565347472
# The reward is = 0.6260117440184997
# Q value = 7.924428587802031
#
# At time step 997 the number of switch migrated are : 3
# The migrated switches are [3, 3, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 998
# 0.2971871853716845
# The overloaded domains are : [24, 13, 29, 6]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.15004293034254704
# 24 :	 0.08505324885374546
# 13 :	 0.09082647863984922
# 6 :	 0.11112899084789167
# 14 :	 0.06178861332383809
# [(748150.1765, 2), (676617.9415, 9), (588258.6402, 8), (482648.7496, 27), (482645.0767, 30), (415307.0, 0)]
# Switches in the controller 29 : [0, 27, 9, 8, 30, 2]
# Switch selected is : 2
# The underloaded domains are : [24, 13, 14]
# The target controller set for 13 is : [20, 19, 5, 1, 3]
# The mean load ratio is : 0.0997680524015743
# The reward is = 6.941796832882093
# Q value = 13.154543553024105
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.11696486210339675
# 24 :	 0.08505324885374546
# 13 :	 0.1239045468789995
# 6 :	 0.11112899084789167
# 14 :	 0.06178861332383809
# [(676617.9415, 9), (588258.6402, 8), (482648.7496, 27), (482645.0767, 30), (415307.0, 0)]
# Switches in the controller 29 : [0, 27, 9, 8, 30]
# Switch selected is : 9
# The underloaded domains are : [24, 14]
# The target controller set for 24 is : [33, 18, 22, 10, 7]
# The mean load ratio is : 0.0997680524015743
# The reward is = 0.9044768275777066
# Q value = 7.983942587065888
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.08704945856038844
# 24 :	 0.11496865239675377
# 13 :	 0.1239045468789995
# 6 :	 0.11112899084789167
# 14 :	 0.06178861332383809
# [(600945.2109, 4), (524726.1824, 11), (482651.0285, 31), (482636.6805, 28), (415315.3865, 23), (4758.0, 12), (2450.871716, 16)]
# Switches in the controller 6 : [16, 12, 23, 31, 4, 11, 28]
# Switch selected is : 4
# The underloaded domains are : [29, 14]
# The target controller set for 29 is : [0, 27, 8, 30]
# The mean load ratio is : 0.0997680524015743
# The reward is = 1.1366121752080278
# Q value = 10.18930045391508
#
# Balance the overloaded controller : 24
# Controller	Controller Load Ratio
# 29 :	 0.11361913309703645
# 24 :	 0.11496865239675377
# 13 :	 0.1239045468789995
# 6 :	 0.08455931631124367
# 14 :	 0.06178861332383809
# [(676617.9415, 9), (605682.3277, 10), (482643.6575, 7), (415310.2875, 22), (415309.685, 18), (4763.815246, 33)]
# Switches in the controller 24 : [33, 18, 22, 10, 7, 9]
# Switch selected is : 9
# The underloaded domains are : [6, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 26, 25]
# The mean load ratio is : 0.0997680524015743
# The reward is = 2.9529967294739263
# Q value = 8.946061280658459
#
# At time step 998 the number of switch migrated are : 4
# The migrated switches are [2, 9, 4, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# 0.13516524544478373
# The overloaded domains are : [13, 29, 6]
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 29 :	 0.14027390727658176
# 24 :	 0.09392394973702743
# 13 :	 0.13091963954295682
# 6 :	 0.13971431374683096
# 14 :	 0.12448553272755546
# [(812154.3954, 30), (812149.4959999999, 27), (752092.8319, 4), (415307.0, 0), (380970.9241, 8)]
# Switches in the controller 29 : [0, 27, 8, 30, 4]
# Switch selected is : 30
# The underloaded domains are : [24, 14]
# The target controller set for 14 is : [17, 32, 15, 21, 26, 25, 9]
# The mean load ratio is : 0.1258634686061905
# The reward is = 0.675076226217975
# Q value = 7.6518834518912096
#
# Balance the overloaded controller : 13
# Controller	Controller Load Ratio
# 29 :	 0.10436601156847047
# 24 :	 0.09392394973702743
# 13 :	 0.13091963954295682
# 6 :	 0.13971431374683096
# 14 :	 0.16039342843566673
# [(664136.1047, 2), (629896.7819, 1), (625350.2145, 5), (415313.6276, 19), (415306.4015, 20), (211099.3962, 3)]
# Switches in the controller 13 : [20, 19, 5, 1, 3, 2]
# Switch selected is : 2
# The underloaded domains are : [29, 24]
# The target controller set for 24 is : [33, 18, 22, 10, 7]
# The mean load ratio is : 0.1258634686061905
# The reward is = 1.7244144580449643
# Q value = 9.811695139367488
#
# Balance the overloaded controller : 6
# Controller	Controller Load Ratio
# 29 :	 0.10436601156847047
# 24 :	 0.12328749208640234
# 13 :	 0.10155609719358191
# 6 :	 0.13971431374683096
# 14 :	 0.16039342843566673
# [(1110115.053, 11), (812140.8238, 28), (812140.2961, 31), (415308.8631, 23), (5554.886859, 16), (4758.0, 12)]
# Switches in the controller 6 : [16, 12, 23, 31, 11, 28]
# Switch selected is : 11
# The underloaded domains are : [29, 24, 13]
# The target controller set for 13 is : [20, 19, 5, 1, 3]
# The mean load ratio is : 0.1258634686061905
# The reward is = 0.8041659845055267
# Q value = 9.41414509243806
#
# At time step 999 the number of switch migrated are : 3
# The migrated switches are [30, 2, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[ 1.          7.98394259 13.15454355  9.42825328  7.65188345]
#  [ 7.92442859  1.          9.40062131  6.73562365  8.94606128]
#  [ 8.6255524   9.81169514  1.          9.3466507   9.49044531]
#  [10.18930045 10.81576932  9.41414509  1.          9.43698853]
#  [ 8.51967546  7.70444075  5.64150749  9.33225216  1.        ]]

# %% [markdown]
# # **Results**

# %%
import matplotlib.pyplot as plt

'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(200, 1000, 50):
    x.append(time_steps_list_rn[i])

    yrandom.append(discrete_coeff_list_rn[i])
    yQL.append(discrete_coeff_list_QL[i])
    yGreedy.append(discrete_coeff_list_gr[i])

plt.plot(x, yrandom, label='Random Selection')
plt.plot(x, yQL, label='Q-Learning')
plt.plot(x, yGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

x = []

for i in range(900, 1000, 10):
    x.append(time_steps_list_rn[i])

    zrandom.append(number_of_switches_list_QL[i])
    zQL.append(number_of_switches_list_rn[i])
    zGreedy.append(number_of_switches_list_gr[i])

plt.plot(x, zrandom, label='Random Selection')
plt.plot(x, zQL, label='Q-Learning')
plt.plot(x, zGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Number of switches migrated')
plt.legend()
plt.show()
