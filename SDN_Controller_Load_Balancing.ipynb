# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph Building and Controller Allocation**

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
# Out:
# Enter the number of controllers to allocate: 5
# Graph with 34 nodes and 46 edges
#
# Controllers:
# [27, 4, 18, 23, 12]
#
# Cluster set for each controller:
# [[13, 27, 28, 29], [1, 4, 5, 6, 7, 8, 9, 15, 20, 21, 24, 25, 31, 33], [14, 16, 18, 30], [0, 2, 3, 10, 17, 19, 22, 23, 32], [11, 12, 26]]
#
# Cluster map for each controller:
# {27: [13, 28, 29], 4: [1, 5, 6, 7, 8, 9, 15, 20, 21, 24, 25, 31, 33], 18: [14, 16, 30], 23: [0, 2, 3, 10, 17, 19, 22, 32], 12: [11, 26]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1):
4, (8, 21): 4, (8, 22): 5, (8, 23): 4, (8, 24): 7, (8, 25): 6, (8, 26): 7, (8, 27): 7, (8, 28): 6, (8, 29): 5, (8, 30): 4, (8, 31): 6, (8, 32): 7, (8, 33): 8, (9, 0): 2, (9, 1): 4, (9, 2): 3, (9, 3): 2, (9, 4): 3, (9, 5): 2, (9, 6): 3, (9, 7): 1, (9, 8): 1, (9, 9): 0, (9, 10): 3, (9, 11): 3, (9, 12): 4, (9, 13): 5, (9, 14): 3, (9, 15): 4, (9, 16): 4, (9, 17): 2, (9, 18): 4, (9, 19): 1, (9, 20): 2, (9, 21): 2, (9, 22): 4, (9, 23): 3, (9, 24): 5, (9, 25): 4, (9, 26): 5, (9, 27): 5, (9, 28): 4, (9, 29): 3, (9, 30): 2, (9, 31): 4, (9, 32): 5, (9,  ...
# [[13, 27, 28, 29], [1, 4, 5, 6, 7, 8, 9, 15, 20, 21, 24, 25, 31, 33], [14, 16, 18, 30], [0, 2, 3, 10, 17, 19, 22, 23, 32], [11, 12, 26]]
# [[13, 27, 28, 29], [1, 4, 5, 6, 7, 8, 9, 15, 20, 21, 24, 25, 31, 33], [14, 16, 18, 30], [0, 2, 3, 10, 17, 19, 22, 23, 32], [11, 12, 26]]

# %% [markdown]
# # **Switch Migration Design**

# %% [markdown]
# Some **questions (with answers after discussion)** regarding the cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously - Yes
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool? - Yes

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions(with answers after discussion)** regarding the cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).
#
# We have calcuated hop count using the **Floyd Warshall** algorithm. The hop count is the number of hops involved in the shortest distance between the 2 nodes.

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4847
# {27: {13: 666.9863553333333, 19: 51913.79045, 21: 69218.34671666667, 5: 116165.74018333334, 11: 98918.20913333334}, 4: {15: 7774.212184, 24: 83061.48806, 33: 792.5418263333332, 28: 101027.781125, 6: 138435.66666666666, 0: 207653.5}, 18: {14: 6245.603977000001, 16: 2847.004057, 22: 103826.030025, 8: 152065.74402, 9: 80318.053125, 7: 404112.9003}, 23: {17: 3257.718976, 32: 950.4419271999999, 26: 80821.81898000001, 25: 101028.87525, 31: 101029.126325, 2: 146247.2728, 3: 396544.4558}, 12: {20: 59329.35964285715, 10: 59767.921299999995, 30: 202055.20545, 29: 134701.4197, 1: 240229.8566}}
# {(23, 4), (12, 27), (18, 27), (18, 4), (12, 18), (12, 4), (27, 4), (23, 27), (23, 18)}
# (23, 4, [3])
# [[13, 19, 21, 5, 11], [15, 24, 33, 28, 6, 0], [14, 16, 22, 8, 9, 7], [17, 32, 26, 25, 31, 2, 3], [20, 10, 30, 29, 1]]
# 3
# (12, 27, [1])
# [[13, 19, 21, 5, 11], [15, 24, 33, 28, 6, 0, 3], [14, 16, 22, 8, 9, 7], [17, 32, 26, 25, 31, 2], [20, 10, 30, 29, 1]]
# 1
# (18, 27, [7])
# [[13, 19, 21, 5, 11, 1], [15, 24, 33, 28, 6, 0, 3], [14, 16, 22, 8, 
 29], [14, 16, 22, 8, 1, 6, 31], [17, 32, 25, 11, 28, 3, 7, 30], [20, 0, 2]]
# 9
# (12, 23, [5])
# [[13, 19, 21, 10, 5, 9], [15, 24, 33, 26, 29], [14, 16, 22, 8, 1, 6, 31], [17, 32, 25, 11, 28, 3, 7, 30], [20, 0, 2]]
# 5
# At time step 4999 the number of switch migrated are : 10
# The migrated switches are [7, 30, 7, 5, 7, 7, 9, 9, 9, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Switches in the controller 4 : [20, 2, 31, 25, 7]
# Switch selected is : 20
# The target controller set for 27 is : [14, 11, 10]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06216229140171524
# 4 :	 0.10884439953352819
# 18 :	 0.13802581706547087
# 23 :	 0.10198288025464042
# 12 :	 0.09869710139083032
# Switches in the controller 4 : [2, 31, 25, 7]
# Switch selected is : 2
# The target controller set for 23 is : [6, 3, 9, 0, 30, 17, 32, 19, 13]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06216229140171524
# 4 :	 0.08378762174492399
# 18 :	 0.13802581706547087
# 23 :	 0.12703965804324463
# 12 :	 0.09869710139083032
# Switches in the controller 18 : [22, 24, 15, 16, 1, 29, 28]
# Switch selected is : 29
# The target controller set for 23 is : [6, 3, 9, 0, 30, 17, 32, 19, 13, 2]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06216229140171524
# 4 :	 0.08378762174492399
# 18 :	 0.11009693735694409
# 23 :	 0.1549685377517714
# 12 :	 0.09869710139083032
# Switches in the controller 18 : [22, 24, 15, 16, 1, 28]
# Switch selected is : 16
# The target controller set for 27 is : [14, 11, 10, 20]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.062298339992917506
# 4 :	 0.08378762174492399
# 18 :	 0.10996088876574182
# 23 :	 0.1549685377517714
# 12 :	 0.09869710139083032
# Switches in the controller 18 : [22, 24, 15, 1, 28]
# Switch selected is : 28
# The target controller set for 12 is : [21, 33, 26, 5, 8]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.062298339992917506
# 4 :	 0.08378762174492399
# 18 :	 0.08203159470493411
# 23 :	 0.1549685377517714
# 12 :	 0.12662639545163804
# Switches in the controller 23 : [6, 3, 9, 0, 30, 17, 32, 19, 13, 2, 29]
# Switch selected is : 0
# The target controller set for 18 is : [22, 24, 15, 1]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.062298339992917506
# 4 :	 0.08378762174492399
# 18 :	 0.10039362109710029
# 23 :	 0.13660651135960522
# 12 :	 0.12662639545163804
# Switches in the controller 23 : [6, 3, 9, 30, 17, 32, 19, 13, 2, 29]
# Switch selected is : 29
# The target controller set for 4 is : [31, 25, 7]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.062298339992917506
# 4 :	 0.11171650145345077
# 18 :	 0.10039362109710029
# 23 :	 0.10867763165107844
# 12 :	 0.12662639545163804
# Switches in the controller 23 : [6, 3, 9, 30, 17, 32, 19, 13, 2]
# Switch selected is : 17
# The target controller set for 18 is : [22, 24, 15, 1, 0]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.062298339992917506
# 4 :	 0.11171650145345077
# 18 :	 0.10067609301099584
# 23 :	 0.10839515973718289
# 12 :	 0.12662639545163804
# Switches in the controller 23 : [6, 3, 9, 30, 32, 19, 13, 2]
# Switch selected is : 3
# The target controller set for 27 is : [14, 11, 10, 20, 16]
# The mean load ratio is : 0.101942497929237
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06364929308248624
# 4 :	 0.11171650145345077
# 18 :	 0.10067609301099584
# 23 :	 0.10704420664761416
# 12 :	 0.12662639545163804
# Switches in the controller 23 : [6, 9, 30, 32, 19, 13, 2]
# Switch selected is : 2
# The target controller set for 27 is : [14, 11, 10, 20, 16, 3]
# The mean load ratio is : 0.101942497929237
#
# At time step 4941 the number of switch migrated are : 11
# The migrated switches are [28, 20, 2, 29, 16, 28, 0, 29, 17, 3, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4942
# The overloaded domains are : [18, 27, 4, 12]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.12104761709390154
# 4 :	 0.10136802088627321
# 18 :	 0.08360522268917056
# 23 :	 0.07798904246603937
# 12 :	 0.12017108512287986
# Switches in the controller 4 : [31, 25, 7, 29]
# Switch selected is : 7
# The target controller set for 12 is : [21, 33, 26, 5, 8, 28]
# The mean load ratio is : 0.1008361976516529
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.12104761709390154
# 4 :	 0.07602604383068554
# 18 :	 0.08360522268917056
# 23 :	 0.07798904246603937
# 12 :	 0.14551306217846754
# Switches in the controller 27 : [14, 11, 10, 20, 16, 3, 2]
# Switch selected is : 20
# The target controller set for 4 is : [31, 25, 29]
# The mean load ratio is : 0.1008361976516529
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.10268559997765206
# 4 :	 0.09438806094693503
# 18 :	 0.08360522268917056
# 23 :	 0.07798904246603937
# 12 :	 0.14551306217846754
# Switches in the controller 27 : [14, 11, 10, 16, 3, 2]
# Switch selected is : 14
# The target controller set for 4 is : [31, 25, 29, 20]
# The mean load ratio is : 0.1008361976516529
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.10252019444917651
# 4 :	 0.09455346647541057
# 18 :	 0.08360522268917056
# 23 :	 0.07798904246603937
# 12 :	 0.14551306217846754
# Switches in the controller 27 : [11, 10, 16, 3, 2]
# Switch selected is : 10
# The target controller set for 18 is : [22, 24, 15, 1, 0, 17]
# The mean load ratio is : 0.1008361976516529
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07709306333758052
# 4 :	 0.09455346647541057
# 18 :	 0.10903235380076655
# 23 :	 0.07798904246603937
# 12 :	 0.14551306217846754
# Switches in the controller 12 : [21, 33, 26, 5, 8, 28, 7]
# Switch selected is : 26
# The target controller set for 4 is : [31, 25, 29, 20, 14]
# The mean load ratio is : 0.1008361976516529
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07709306333758052
# 4 :	 0.11989541506215763
# 18 :	 0.10903235380076655
# 23 :	 0.07798904246603937
# 12 :	 0.12017111359172049
# Switches in the controller 12 : [21, 33, 5, 8, 28, 7]
# Switch selected is : 5
# The target controller set for 23 is : [6, 9, 30, 32, 19, 13]
# The mean load ratio is : 0.1008361976516529
#
# At time step 4942 the number of switch migrated are : 6
# The migrated switches are [7, 20, 14, 10, 26, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4943
# The overloaded domains are : [18, 12, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08177397112872146
# 4 :	 0.1644432774498412
# 18 :	 0.13385382050325362
# 23 :	 0.12024623198508147
# 12 :	 0.11127419830889065
# Switches in the controller 4 : [31, 25, 29, 20, 14, 26]
# Switch selected is : 31
# The target controller set for 23 is : [6, 9, 30, 32, 19, 13, 5]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08177397112872146
# 4 :	 0.12800347732917222
# 18 :	 0.13385382050325362
# 23 :	 0.15668603210575044
# 12 :	 0.11127419830889065
# Switches in the controller 4 : [25, 29, 20, 14, 26]
# Switch selected is : 26
# The target controller set for 12 is : [21, 33, 8, 28, 7]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08177397112872146
# 4 :	 0.09156464842085686
# 18 :	 0.13385382050325362
# 23 :	 0.15668603210575044
# 12 :	 0.14771302721720603
# Switches in the controller 23 : [6, 9, 30, 32, 19, 13, 5, 31]
# Switch selected is : 9
# The target controller set for 4 is : [25, 29, 20, 14]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08177397112872146
# 4 :	 0.11212797525658914
# 18 :	 0.13385382050325362
# 23 :	 0.13612270527001816
# 12 :	 0.14771302721720603
# Switches in the controller 23 : [6, 30, 32, 19, 13, 5, 31]
# Switch selected is : 5
# The target controller set for 12 is : [21, 33, 8, 28, 7, 26]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08177397112872146
# 4 :	 0.11212797525658914
# 18 :	 0.13385382050325362
# 23 :	 0.11001489155380312
# 12 :	 0.17382084093342107
# Switches in the controller 18 : [22, 24, 15, 1, 0, 17, 10]
# Switch selected is : 17
# The target controller set for 27 is : [11, 16, 3, 2]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08202164342637985
# 4 :	 0.11212797525658914
# 18 :	 0.13360614820559524
# 23 :	 0.11001489155380312
# 12 :	 0.17382084093342107
# Switches in the controller 18 : [22, 24, 15, 1, 0, 10]
# Switch selected is : 0
# The target controller set for 27 is : [11, 16, 3, 2, 17]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10038366981854605
# 4 :	 0.11212797525658914
# 18 :	 0.11524412181342905
# 23 :	 0.11001489155380312
# 12 :	 0.17382084093342107
# Switches in the controller 12 : [21, 33, 8, 28, 7, 26, 5]
# Switch selected is : 7
# The target controller set for 18 is : [22, 24, 15, 1, 10]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10038366981854605
# 4 :	 0.11212797525658914
# 18 :	 0.1516833036752383
# 23 :	 0.11001489155380312
# 12 :	 0.13738165907161182
# Switches in the controller 12 : [21, 33, 8, 28, 26, 5]
# Switch selected is : 33
# The target controller set for 4 is : [25, 29, 20, 14, 9]
# The mean load ratio is : 0.12231829987515767
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10038366981854605
# 4 :	 0.11233848649826025
# 18 :	 0.1516833036752383
# 23 :	 0.11001489155380312
# 12 :	 0.13717114782994072
# Switches in the controller 12 : [21, 8, 28, 26, 5]
# Switch selected is : 5
# The target controller set for 18 is : [22, 24, 15, 1, 10, 7]
# The mean load ratio is : 0.12231829987515767
#
# At time step 4943 the number of switch migrated are : 9
# The migrated switches are [31, 26, 9, 5, 17, 0, 7, 33, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4944
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06371004945650155
# 4 :	 0.08617337164309712
# 18 :	 0.16781528321634903
# 23 :	 0.08220017704180076
# 12 :	 0.0828380620292466
# Switches in the controller 18 : [22, 24, 15, 1, 10, 7, 5]
# Switch selected is : 15
# The target controller set for 23 is : [6, 30, 32, 19, 13, 31]
# The mean load ratio is : 0.09654738867739901
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06371004945650155
# 4 :	 0.08617337164309712
# 18 :	 0.16753931964625704
# 23 :	 0.08247614061189276
# 12 :	 0.0828380620292466
# Switches in the controller 18 : [22, 24, 1, 10, 7, 5]
# Switch selected is : 10
# The target controller set for 12 is : [21, 8, 28, 26]
# The mean load ratio is : 0.09654738867739901
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06371004945650155
# 4 :	 0.08617337164309712
# 18 :	 0.1341371157812059
# 23 :	 0.08247614061189276
# 12 :	 0.11624026589429773
# Switches in the controller 18 : [22, 24, 1, 7, 5]
# Switch selected is : 22
# The target controller set for 23 is : [6, 30, 32, 19, 13, 31, 15]
# The mean load ratio is : 0.09654738867739901
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06371004945650155
# 4 :	 0.08617337164309712
# 18 :	 0.11577497850248546
# 23 :	 0.10083827789061321
# 12 :	 0.11624026589429773
# Switches in the controller 18 : [24, 1, 7, 5]
# Switch selected is : 7
# The target controller set for 27 is : [11, 16, 3, 2, 17, 0]
# The mean load ratio is : 0.09654738867739901
#
# At time step 4944 the number of switch migrated are : 4
# The migrated switches are [15, 10, 22, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4945
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10674703919109488
# 4 :	 0.11659998816741646
# 18 :	 0.08819455437462241
# 23 :	 0.12571135033620312
# 12 :	 0.13216793965295173
# Switches in the controller 4 : [25, 29, 20, 14, 9, 33]
# Switch selected is : 14
# The target controller set for 23 is : [6, 30, 32, 19, 13, 31, 15, 22]
# The mean load ratio is : 0.11388417434445772
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10674703919109488
# 4 :	 0.11625511160742506
# 18 :	 0.08819455437462241
# 23 :	 0.12605622689619453
# 12 :	 0.13216793965295173
# Switches in the controller 4 : [25, 29, 20, 9, 33]
# Switch selected is : 29
# The target controller set for 18 is : [24, 1, 5]
# The mean load ratio is : 0.11388417434445772
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10674703919109488
# 4 :	 0.08114722720793044
# 18 :	 0.12330243877411703
# 23 :	 0.12605622689619453
# 12 :	 0.13216793965295173
# Switches in the controller 23 : [6, 30, 32, 19, 13, 31, 15, 22, 14]
# Switch selected is : 30
# The target controller set for 12 is : [21, 8, 28, 26, 10]
# The mean load ratio is : 0.11388417434445772
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10674703919109488
# 4 :	 0.08114722720793044
# 18 :	 0.12330243877411703
# 23 :	 0.09094838091791826
# 12 :	 0.167275785631228
# Switches in the controller 12 : [21, 8, 28, 26, 10, 30]
# Switch selected is : 26
# The target controller set for 27 is : [11, 16, 3, 2, 17, 0, 7]
# The mean load ratio is : 0.11388417434445772
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.1418550681012365
# 4 :	 0.08114722720793044
# 18 :	 0.12330243877411703
# 23 :	 0.09094838091791826
# 12 :	 0.13216775672108638
# Switches in the controller 12 : [21, 8, 28, 10, 30]
# Switch selected is : 10
# The target controller set for 18 is : [24, 1, 5, 29]
# The mean load ratio is : 0.11388417434445772
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.1418550681012365
# 4 :	 0.08114722720793044
# 18 :	 0.1371896558834905
# 23 :	 0.09094838091791826
# 12 :	 0.11828053961171292
# Switches in the controller 12 : [21, 8, 28, 30]
# Switch selected is : 30
# The target controller set for 4 is : [25, 20, 9, 33]
# The mean load ratio is : 0.11388417434445772
#
# At time step 4945 the number of switch migrated are : 6
# The migrated switches are [14, 29, 30, 26, 10, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4946
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.13211583054673343
# 4 :	 0.08931746241438943
# 18 :	 0.13209122131808693
# 23 :	 0.07983231511381833
# 12 :	 0.06322667217897013
# Switches in the controller 18 : [24, 1, 5, 29, 10]
# Switch selected is : 29
# The target controller set for 4 is : [25, 20, 9, 33, 30]
# The mean load ratio is : 0.09931670031439965
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.13211583054673343
# 4 :	 0.1130082766901703
# 18 :	 0.10840040704230605
# 23 :	 0.07983231511381833
# 12 :	 0.06322667217897013
# Switches in the controller 18 : [24, 1, 5, 10]
# Switch selected is : 5
# The target controller set for 27 is : [11, 16, 3, 2, 17, 0, 7, 26]
# The mean load ratio is : 0.09931670031439965
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.15699966628742423
# 4 :	 0.1130082766901703
# 18 :	 0.08351657130161523
# 23 :	 0.07983231511381833
# 12 :	 0.06322667217897013
# Switches in the controller 27 : [11, 16, 3, 2, 17, 0, 7, 26, 5]
# Switch selected is : 5
# The target controller set for 18 is : [24, 1, 10]
# The mean load ratio is : 0.09931670031439965
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.13211583054673343
# 4 :	 0.1130082766901703
# 18 :	 0.10840040704230605
# 23 :	 0.07983231511381833
# 12 :	 0.06322667217897013
# Switches in the controller 27 : [11, 16, 3, 2, 17, 0, 7, 26]
# Switch selected is : 26
# The target controller set for 18 is : [24, 1, 10, 5]
# The mean load ratio is : 0.09931670031439965
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.1084257870695654
# 4 :	 0.1130082766901703
# 18 :	 0.13209045051947407
# 23 :	 0.07983231511381833
# 12 :	 0.06322667217897013
# Switches in the controller 27 : [11, 16, 3, 2, 17, 0, 7]
# Switch selected is : 2
# The target controller set for 23 is : [6, 32, 19, 13, 31, 15, 22, 14]
# The mean load ratio is : 0.09931670031439965
#
# At time step 4946 the number of switch migrated are : 5
# The migrated switches are [29, 5, 5, 26, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4947
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09241641577670533
# 4 :	 0.1350523423402786
# 18 :	 0.1340953504180196
# 23 :	 0.10512114858492613
# 12 :	 0.07069759681711364
# Switches in the controller 4 : [25, 20, 9, 33, 30, 29]
# Switch selected is : 33
# The target controller set for 12 is : [21, 8, 28]
# The mean load ratio is : 0.10747657078740866
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09241641577670533
# 4 :	 0.13484254016931072
# 18 :	 0.1340953504180196
# 23 :	 0.10512114858492613
# 12 :	 0.07090739898808154
# Switches in the controller 4 : [25, 20, 9, 30, 29]
# Switch selected is : 25
# The target controller set for 23 is : [6, 32, 19, 13, 31, 15, 22, 14, 2]
# The mean load ratio is : 0.10747657078740866
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09241641577670533
# 4 :	 0.10383148117395985
# 18 :	 0.1340953504180196
# 23 :	 0.136132207580277
# 12 :	 0.07090739898808154
# Switches in the controller 18 : [24, 1, 10, 5, 26]
# Switch selected is : 26
# The target controller set for 23 is : [6, 32, 19, 13, 31, 15, 22, 14, 2, 25]
# The mean load ratio is : 0.10747657078740866
#
# At time step 4947 the number of switch migrated are : 3
# The migrated switches are [33, 25, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4948
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06430934811232147
# 4 :	 0.08321675381773855
# 18 :	 0.09713529245698597
# 23 :	 0.15706047580413018
# 12 :	 0.07337173191934827
# Switches in the controller 23 : [6, 32, 19, 13, 31, 15, 22, 14, 2, 25, 26]
# Switch selected is : 22
# The target controller set for 27 is : [11, 16, 3, 17, 0, 7]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08321675381773855
# 18 :	 0.09713529245698597
# 23 :	 0.1386986690628418
# 12 :	 0.07337173191934827
# Switches in the controller 23 : [6, 32, 19, 13, 31, 15, 14, 2, 25, 26]
# Switch selected is : 19
# The target controller set for 12 is : [21, 8, 28, 33]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08321675381773855
# 18 :	 0.09713529245698597
# 23 :	 0.12033650845284757
# 12 :	 0.09173389252934253
# Switches in the controller 23 : [6, 32, 13, 31, 15, 14, 2, 25, 26]
# Switch selected is : 31
# The target controller set for 12 is : [21, 8, 28, 33, 19]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08321675381773855
# 18 :	 0.09713529245698597
# 23 :	 0.09723502360578723
# 12 :	 0.11483537737640287
# Switches in the controller 23 : [6, 32, 13, 15, 14, 2, 25, 26]
# Switch selected is : 15
# The target controller set for 4 is : [20, 9, 30, 29]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08345825758525166
# 18 :	 0.09713529245698597
# 23 :	 0.09699351983827412
# 12 :	 0.11483537737640287
# Switches in the controller 23 : [6, 32, 13, 14, 2, 25, 26]
# Switch selected is : 13
# The target controller set for 12 is : [21, 8, 28, 33, 19, 31]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08345825758525166
# 18 :	 0.09713529245698597
# 23 :	 0.09678744264532368
# 12 :	 0.1150414545693533
# Switches in the controller 23 : [6, 32, 14, 2, 25, 26]
# Switch selected is : 32
# The target controller set for 12 is : [21, 8, 28, 33, 19, 31, 13]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.08345825758525166
# 18 :	 0.09713529245698597
# 23 :	 0.09657659855581867
# 12 :	 0.11525229865885832
# Switches in the controller 23 : [6, 14, 2, 25, 26]
# Switch selected is : 25
# The target controller set for 4 is : [20, 9, 30, 29, 15]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08267115485360983
# 4 :	 0.10655969564596762
# 18 :	 0.09713529245698597
# 23 :	 0.0734751604951027
# 12 :	 0.11525229865885832
# Switches in the controller 4 : [20, 9, 30, 29, 15, 25]
# Switch selected is : 25
# The target controller set for 27 is : [11, 16, 3, 17, 0, 7, 22]
# The mean load ratio is : 0.09501872042210488
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.1057725929143258
# 4 :	 0.08345825758525166
# 18 :	 0.09713529245698597
# 23 :	 0.0734751604951027
# 12 :	 0.11525229865885832
# Switches in the controller 18 : [24, 1, 10, 5]
# Switch selected is : 1
# The target controller set for 12 is : [21, 8, 28, 33, 19, 31, 13, 32]
# The mean load ratio is : 0.09501872042210488
#
# At time step 4948 the number of switch migrated are : 9
# The migrated switches are [22, 19, 31, 15, 13, 32, 25, 25, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4949
# The overloaded domains are : [27, 12, 4, 23]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.1938385586097708
# 4 :	 0.12366882830172908
# 18 :	 0.05914577756930315
# 23 :	 0.08927624948160555
# 12 :	 0.18590210059834575
# Switches in the controller 27 : [11, 16, 3, 17, 0, 7, 22, 25]
# Switch selected is : 25
# The target controller set for 12 is : [21, 8, 28, 33, 19, 31, 13, 32, 1]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.15792975157158226
# 4 :	 0.12366882830172908
# 18 :	 0.05914577756930315
# 23 :	 0.08927624948160555
# 12 :	 0.2218109076365343
# Switches in the controller 27 : [11, 16, 3, 17, 0, 7, 22]
# Switch selected is : 16
# The target controller set for 23 is : [6, 14, 2, 26]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.15790130256865353
# 4 :	 0.12366882830172908
# 18 :	 0.05914577756930315
# 23 :	 0.08930469848453428
# 12 :	 0.2218109076365343
# Switches in the controller 27 : [11, 3, 17, 0, 7, 22]
# Switch selected is : 17
# The target controller set for 18 is : [24, 10, 5]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.15753105058045352
# 4 :	 0.12366882830172908
# 18 :	 0.05951602955750315
# 23 :	 0.08930469848453428
# 12 :	 0.2218109076365343
# Switches in the controller 27 : [11, 3, 0, 7, 22]
# Switch selected is : 0
# The target controller set for 12 is : [21, 8, 28, 33, 19, 31, 13, 32, 1, 25]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.13916902418828733
# 4 :	 0.12366882830172908
# 18 :	 0.05951602955750315
# 23 :	 0.08930469848453428
# 12 :	 0.2401729340287005
# Switches in the controller 27 : [11, 3, 7, 22]
# Switch selected is : 3
# The target controller set for 4 is : [20, 9, 30, 29, 15]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0704687616543216
# 4 :	 0.1923690908356948
# 18 :	 0.05951602955750315
# 23 :	 0.08930469848453428
# 12 :	 0.2401729340287005
# Switches in the controller 12 : [21, 8, 28, 33, 19, 31, 13, 32, 1, 25, 0]
# Switch selected is : 25
# The target controller set for 27 is : [11, 7, 22]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.1923690908356948
# 18 :	 0.05951602955750315
# 23 :	 0.08930469848453428
# 12 :	 0.20426412699051194
# Switches in the controller 12 : [21, 8, 28, 33, 19, 31, 13, 32, 1, 0]
# Switch selected is : 28
# The target controller set for 23 is : [6, 14, 2, 26, 16]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.1923690908356948
# 18 :	 0.05951602955750315
# 23 :	 0.12521311354671188
# 12 :	 0.16835571192833435
# Switches in the controller 12 : [21, 8, 33, 19, 31, 13, 32, 1, 0]
# Switch selected is : 19
# The target controller set for 4 is : [20, 9, 30, 29, 15, 3]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.2107313373120276
# 18 :	 0.05951602955750315
# 23 :	 0.12521311354671188
# 12 :	 0.14999346545200157
# Switches in the controller 12 : [21, 8, 33, 31, 13, 32, 1, 0]
# Switch selected is : 33
# The target controller set for 18 is : [24, 10, 5, 17]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.2107313373120276
# 18 :	 0.05972599839595819
# 23 :	 0.12521311354671188
# 12 :	 0.14978349661354654
# Switches in the controller 12 : [21, 8, 31, 13, 32, 1, 0]
# Switch selected is : 13
# The target controller set for 23 is : [6, 14, 2, 26, 16, 28]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.2107313373120276
# 18 :	 0.05972599839595819
# 23 :	 0.12535655578206062
# 12 :	 0.1496400543781978
# Switches in the controller 12 : [21, 8, 31, 32, 1, 0]
# Switch selected is : 0
# The target controller set for 23 is : [6, 14, 2, 26, 16, 28, 13]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10637756869251015
# 4 :	 0.2107313373120276
# 18 :	 0.05972599839595819
# 23 :	 0.1437185821742268
# 12 :	 0.1312780279860316
# Switches in the controller 12 : [21, 8, 31, 32, 1]
# Switch selected is : 8
# The target controller set for 27 is : [11, 7, 22, 25]
# The mean load ratio is : 0.13036630291215087
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.14027293402158106
# 4 :	 0.2107313373120276
# 18 :	 0.05972599839595819
# 23 :	 0.1437185821742268
# 12 :	 0.0973826626569607
# Switches in the controller 23 : [6, 14, 2, 26, 16, 28, 13, 0]
# Switch selected is : 2
# The target controller set for 27 is : [11, 7, 22, 25, 8]
# The mean load ratio is : 0.13036630291215087
#
# At time step 4949 the number of switch migrated are : 13
# The migrated switches are [25, 16, 17, 0, 3, 25, 28, 19, 33, 13, 0, 8, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4950
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11411358792360932
# 4 :	 0.1599519964963006
# 18 :	 0.05505226791966432
# 23 :	 0.08110421129240354
# 12 :	 0.06943055459592795
# Switches in the controller 4 : [20, 9, 30, 29, 15, 3, 19]
# Switch selected is : 20
# The target controller set for 23 is : [6, 14, 26, 16, 28, 13, 0]
# The mean load ratio is : 0.09593052364558115
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11411358792360932
# 4 :	 0.14159014481235577
# 18 :	 0.05505226791966432
# 23 :	 0.09946606297634836
# 12 :	 0.06943055459592795
# Switches in the controller 4 : [9, 30, 29, 15, 3, 19]
# Switch selected is : 29
# The target controller set for 23 is : [6, 14, 26, 16, 28, 13, 0, 20]
# The mean load ratio is : 0.09593052364558115
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11411358792360932
# 4 :	 0.11970801508125666
# 18 :	 0.05505226791966432
# 23 :	 0.12134819270744747
# 12 :	 0.06943055459592795
# Switches in the controller 4 : [9, 30, 15, 3, 19]
# Switch selected is : 3
# The target controller set for 18 is : [24, 10, 5, 17, 33]
# The mean load ratio is : 0.09593052364558115
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.11411358792360932
# 4 :	 0.058977872367988966
# 18 :	 0.11578241063293201
# 23 :	 0.12134819270744747
# 12 :	 0.06943055459592795
# Switches in the controller 27 : [11, 7, 22, 25, 8, 2]
# Switch selected is : 7
# The target controller set for 4 is : [9, 30, 15, 19]
# The mean load ratio is : 0.09593052364558115
#
# At time step 4950 the number of switch migrated are : 4
# The migrated switches are [20, 29, 3, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4951
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09573400981252542
# 4 :	 0.08903735621189646
# 18 :	 0.09665868522945331
# 23 :	 0.11909393692410343
# 12 :	 0.05885985228542745
# Switches in the controller 18 : [24, 10, 5, 17, 33, 3]
# Switch selected is : 33
# The target controller set for 23 is : [6, 14, 26, 16, 28, 13, 0, 20, 29]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09573400981252542
# 4 :	 0.08903735621189646
# 18 :	 0.09644816537532788
# 23 :	 0.11930445677822886
# 12 :	 0.05885985228542745
# Switches in the controller 18 : [24, 10, 5, 17, 3]
# Switch selected is : 24
# The target controller set for 12 is : [21, 31, 32, 1]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09573400981252542
# 4 :	 0.08903735621189646
# 18 :	 0.07808616548893893
# 23 :	 0.11930445677822886
# 12 :	 0.0772218521718164
# Switches in the controller 23 : [6, 14, 26, 16, 28, 13, 0, 20, 29, 33]
# Switch selected is : 33
# The target controller set for 27 is : [11, 22, 25, 8, 2]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09594452966665085
# 4 :	 0.08903735621189646
# 18 :	 0.07808616548893893
# 23 :	 0.11909393692410343
# 12 :	 0.0772218521718164
# Switches in the controller 23 : [6, 14, 26, 16, 28, 13, 0, 20, 29]
# Switch selected is : 20
# The target controller set for 27 is : [11, 22, 25, 8, 2, 33]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.11430657662234828
# 4 :	 0.08903735621189646
# 18 :	 0.07808616548893893
# 23 :	 0.10073188996840599
# 12 :	 0.0772218521718164
# Switches in the controller 23 : [6, 14, 26, 16, 28, 13, 0, 29]
# Switch selected is : 28
# The target controller set for 4 is : [9, 30, 15, 19, 7]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.11430657662234828
# 4 :	 0.11020335892880806
# 18 :	 0.07808616548893893
# 23 :	 0.07956588725149438
# 12 :	 0.0772218521718164
# Switches in the controller 27 : [11, 22, 25, 8, 2, 33, 20]
# Switch selected is : 20
# The target controller set for 12 is : [21, 31, 32, 1, 24]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.09594452966665085
# 4 :	 0.11020335892880806
# 18 :	 0.07808616548893893
# 23 :	 0.07956588725149438
# 12 :	 0.09558389912751383
# Switches in the controller 27 : [11, 22, 25, 8, 2, 33]
# Switch selected is : 33
# The target controller set for 18 is : [10, 5, 17, 3]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.09573400981252542
# 4 :	 0.11020335892880806
# 18 :	 0.07829668534306436
# 23 :	 0.07956588725149438
# 12 :	 0.09558389912751383
# Switches in the controller 27 : [11, 22, 25, 8, 2]
# Switch selected is : 11
# The target controller set for 18 is : [10, 5, 17, 3, 33]
# The mean load ratio is : 0.09187676809268122
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08568278171719115
# 4 :	 0.11020335892880806
# 18 :	 0.08834791343839862
# 23 :	 0.07956588725149438
# 12 :	 0.09558389912751383
# Switches in the controller 4 : [9, 30, 15, 19, 7, 28]
# Switch selected is : 30
# The target controller set for 23 is : [6, 14, 26, 16, 13, 0, 29]
# The mean load ratio is : 0.09187676809268122
#
# At time step 4951 the number of switch migrated are : 9
# The migrated switches are [33, 24, 33, 20, 28, 20, 33, 11, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4952
# The overloaded domains are : [18, 27, 12, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08677943840703047
# 4 :	 0.08298980155209947
# 18 :	 0.1573082193615206
# 23 :	 0.08894704308849298
# 12 :	 0.10312241481248062
# Switches in the controller 18 : [10, 5, 17, 3, 33, 11]
# Switch selected is : 5
# The target controller set for 27 is : [22, 25, 8, 2]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.10606055429574027
# 4 :	 0.08298980155209947
# 18 :	 0.13802710347281077
# 23 :	 0.08894704308849298
# 12 :	 0.10312241481248062
# Switches in the controller 18 : [10, 17, 3, 33, 11]
# Switch selected is : 33
# The target controller set for 4 is : [9, 15, 19, 7, 28]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.10606055429574027
# 4 :	 0.0832006218029407
# 18 :	 0.13781628322196954
# 23 :	 0.08894704308849298
# 12 :	 0.10312241481248062
# Switches in the controller 18 : [10, 17, 3, 11]
# Switch selected is : 17
# The target controller set for 27 is : [22, 25, 8, 2, 5]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.10625237661131161
# 4 :	 0.0832006218029407
# 18 :	 0.13762446090639818
# 23 :	 0.08894704308849298
# 12 :	 0.10312241481248062
# Switches in the controller 18 : [10, 3, 11]
# Switch selected is : 11
# The target controller set for 12 is : [21, 31, 32, 1, 24, 20]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.10625237661131161
# 4 :	 0.0832006218029407
# 18 :	 0.0824574138093247
# 23 :	 0.08894704308849298
# 12 :	 0.15828946190955412
# Switches in the controller 27 : [22, 25, 8, 2, 5, 17]
# Switch selected is : 8
# The target controller set for 4 is : [9, 15, 19, 7, 28, 33]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.08405453071828368
# 4 :	 0.10539846769596863
# 18 :	 0.0824574138093247
# 23 :	 0.08894704308849298
# 12 :	 0.15828946190955412
# Switches in the controller 12 : [21, 31, 32, 1, 24, 20, 11]
# Switch selected is : 1
# The target controller set for 18 is : [10, 3]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.08405453071828368
# 4 :	 0.10539846769596863
# 18 :	 0.1130077128604709
# 23 :	 0.08894704308849298
# 12 :	 0.12773916285840792
# Switches in the controller 12 : [21, 31, 32, 24, 20, 11]
# Switch selected is : 24
# The target controller set for 18 is : [10, 3, 1]
# The mean load ratio is : 0.10382938344432482
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.08405453071828368
# 4 :	 0.10539846769596863
# 18 :	 0.13136973879282043
# 23 :	 0.08894704308849298
# 12 :	 0.10937713692605838
# Switches in the controller 12 : [21, 31, 32, 20, 11]
# Switch selected is : 20
# The target controller set for 4 is : [9, 15, 19, 7, 28, 33, 8]
# The mean load ratio is : 0.10382938344432482
#
# At time step 4952 the number of switch migrated are : 8
# The migrated switches are [5, 33, 17, 11, 8, 1, 24, 20]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4953
# The overloaded domains are : [27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.1024928686368123
# 4 :	 0.11493619380131245
# 18 :	 0.08790121326681344
# 23 :	 0.09157408073207711
# 12 :	 0.04514396817499892
# Switches in the controller 4 : [9, 15, 19, 7, 28, 33, 8, 20]
# Switch selected is : 33
# The target controller set for 12 is : [21, 31, 32, 11]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.1024928686368123
# 4 :	 0.1147256429358698
# 18 :	 0.08790121326681344
# 23 :	 0.09157408073207711
# 12 :	 0.04535451904044158
# Switches in the controller 4 : [9, 15, 19, 7, 28, 8, 20]
# Switch selected is : 9
# The target controller set for 12 is : [21, 31, 32, 11, 33]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.1024928686368123
# 4 :	 0.09583504483802972
# 18 :	 0.08790121326681344
# 23 :	 0.09157408073207711
# 12 :	 0.06424511713828165
# Switches in the controller 4 : [15, 19, 7, 28, 8, 20]
# Switch selected is : 28
# The target controller set for 18 is : [10, 3, 1, 24]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.1024928686368123
# 4 :	 0.0777380277339875
# 18 :	 0.10599823037085566
# 23 :	 0.09157408073207711
# 12 :	 0.06424511713828165
# Switches in the controller 23 : [6, 14, 26, 16, 13, 0, 29, 30]
# Switch selected is : 0
# The target controller set for 27 is : [22, 25, 2, 5, 17]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.12085489502897848
# 4 :	 0.0777380277339875
# 18 :	 0.10599823037085566
# 23 :	 0.07321205433991093
# 12 :	 0.06424511713828165
# Switches in the controller 27 : [22, 25, 2, 5, 17, 0]
# Switch selected is : 17
# The target controller set for 18 is : [10, 3, 1, 24, 28]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.12059394420403832
# 4 :	 0.0777380277339875
# 18 :	 0.10625918119579582
# 23 :	 0.07321205433991093
# 12 :	 0.06424511713828165
# Switches in the controller 27 : [22, 25, 2, 5, 0]
# Switch selected is : 5
# The target controller set for 18 is : [10, 3, 1, 24, 28, 17]
# The mean load ratio is : 0.08840966492240285
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.08898362380659375
# 4 :	 0.0777380277339875
# 18 :	 0.1378695015932404
# 23 :	 0.07321205433991093
# 12 :	 0.06424511713828165
# Switches in the controller 27 : [22, 25, 2, 0]
# Switch selected is : 25
# The target controller set for 23 is : [6, 14, 26, 16, 13, 29, 30]
# The mean load ratio is : 0.08840966492240285
#
# At time step 4953 the number of switch migrated are : 7
# The migrated switches are [33, 9, 28, 0, 17, 5, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4954
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06098246955070688
# 4 :	 0.08405231384493334
# 18 :	 0.13673621981217987
# 23 :	 0.10577161241345472
# 12 :	 0.0582390928399026
# Switches in the controller 18 : [10, 3, 1, 24, 28, 17, 5]
# Switch selected is : 28
# The target controller set for 4 is : [15, 19, 7, 8, 20]
# The mean load ratio is : 0.08915634169223549
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06098246955070688
# 4 :	 0.1057020162282826
# 18 :	 0.11508651742883061
# 23 :	 0.10577161241345472
# 12 :	 0.0582390928399026
# Switches in the controller 18 : [10, 3, 1, 24, 17, 5]
# Switch selected is : 10
# The target controller set for 12 is : [21, 31, 32, 11, 33, 9]
# The mean load ratio is : 0.08915634169223549
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06098246955070688
# 4 :	 0.1057020162282826
# 18 :	 0.08943438323547492
# 23 :	 0.10577161241345472
# 12 :	 0.08389122703325828
# Switches in the controller 18 : [3, 1, 24, 17, 5]
# Switch selected is : 3
# The target controller set for 12 is : [21, 31, 32, 11, 33, 9, 10]
# The mean load ratio is : 0.08915634169223549
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06098246955070688
# 4 :	 0.1057020162282826
# 18 :	 0.0744621450701245
# 23 :	 0.10577161241345472
# 12 :	 0.09886346519860872
# Switches in the controller 23 : [6, 14, 26, 16, 13, 29, 30, 25]
# Switch selected is : 16
# The target controller set for 4 is : [15, 19, 7, 8, 20, 28]
# The mean load ratio is : 0.08915634169223549
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06098246955070688
# 4 :	 0.10619004187056667
# 18 :	 0.0744621450701245
# 23 :	 0.10528358677117064
# 12 :	 0.09886346519860872
# Switches in the controller 23 : [6, 14, 26, 13, 29, 30, 25]
# Switch selected is : 26
# The target controller set for 4 is : [15, 19, 7, 8, 20, 28, 16]
# The mean load ratio is : 0.08915634169223549
#
# At time step 4954 the number of switch migrated are : 5
# The migrated switches are [28, 10, 3, 16, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4955
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.05681534268130131
# 4 :	 0.13941200004183543
# 18 :	 0.09255527233516676
# 23 :	 0.09919325785186944
# 12 :	 0.1470903287774714
# Switches in the controller 12 : [21, 31, 32, 11, 33, 9, 10, 3]
# Switch selected is : 11
# The target controller set for 27 is : [22, 2, 0]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0776624233194209
# 4 :	 0.13941200004183543
# 18 :	 0.09255527233516676
# 23 :	 0.09919325785186944
# 12 :	 0.1262432481393518
# Switches in the controller 12 : [21, 31, 32, 33, 9, 10, 3]
# Switch selected is : 21
# The target controller set for 23 is : [6, 14, 13, 29, 30, 25]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0776624233194209
# 4 :	 0.13941200004183543
# 18 :	 0.09255527233516676
# 23 :	 0.11755571480485356
# 12 :	 0.10788079118636769
# Switches in the controller 12 : [31, 32, 33, 9, 10, 3]
# Switch selected is : 9
# The target controller set for 23 is : [6, 14, 13, 29, 30, 25, 21]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.0776624233194209
# 4 :	 0.13941200004183543
# 18 :	 0.09255527233516676
# 23 :	 0.13358861788738458
# 12 :	 0.09184788810383668
# Switches in the controller 23 : [6, 14, 13, 29, 30, 25, 21, 9]
# Switch selected is : 14
# The target controller set for 18 is : [1, 24, 17, 5]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.0776624233194209
# 4 :	 0.13941200004183543
# 18 :	 0.09281612903179162
# 23 :	 0.1333277611907597
# 12 :	 0.09184788810383668
# Switches in the controller 23 : [6, 13, 29, 30, 25, 21, 9]
# Switch selected is : 21
# The target controller set for 27 is : [22, 2, 0, 11]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09602488027240502
# 4 :	 0.13941200004183543
# 18 :	 0.09281612903179162
# 23 :	 0.11496530423777558
# 12 :	 0.09184788810383668
# Switches in the controller 23 : [6, 13, 29, 30, 25, 9]
# Switch selected is : 30
# The target controller set for 4 is : [15, 19, 7, 8, 20, 28, 16, 26]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09602488027240502
# 4 :	 0.16619562259353898
# 18 :	 0.09281612903179162
# 23 :	 0.08818168168607204
# 12 :	 0.09184788810383668
# Switches in the controller 4 : [15, 19, 7, 8, 20, 28, 16, 26, 30]
# Switch selected is : 30
# The target controller set for 23 is : [6, 13, 29, 25, 9]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09602488027240502
# 4 :	 0.13941200004183543
# 18 :	 0.09281612903179162
# 23 :	 0.1149653042377756
# 12 :	 0.09184788810383668
# Switches in the controller 4 : [15, 19, 7, 8, 20, 28, 16, 26]
# Switch selected is : 20
# The target controller set for 27 is : [22, 2, 0, 11, 21]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11438710323619013
# 4 :	 0.12104977707805033
# 18 :	 0.09281612903179162
# 23 :	 0.1149653042377756
# 12 :	 0.09184788810383668
# Switches in the controller 4 : [15, 19, 7, 8, 28, 16, 26]
# Switch selected is : 15
# The target controller set for 18 is : [1, 24, 17, 5, 14]
# The mean load ratio is : 0.10701324033752888
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11438710323619013
# 4 :	 0.12085110216305564
# 18 :	 0.09301480394678631
# 23 :	 0.1149653042377756
# 12 :	 0.09184788810383668
# Switches in the controller 4 : [19, 7, 8, 28, 16, 26]
# Switch selected is : 7
# The target controller set for 23 is : [6, 13, 29, 25, 9, 30]
# The mean load ratio is : 0.10701324033752888
#
# At time step 4955 the number of switch migrated are : 10
# The migrated switches are [11, 21, 9, 14, 21, 30, 30, 20, 15, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4956
# The overloaded domains are : [27, 12, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10393707912488874
# 4 :	 0.08590901166052946
# 18 :	 0.07862732822963525
# 23 :	 0.14022849152944394
# 12 :	 0.12090063593064287
# Switches in the controller 23 : [6, 13, 29, 25, 9, 30, 7]
# Switch selected is : 30
# The target controller set for 12 is : [31, 32, 33, 10, 3]
# The mean load ratio is : 0.10592050929502805
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10393707912488874
# 4 :	 0.08590901166052946
# 18 :	 0.07862732822963525
# 23 :	 0.11696882123406922
# 12 :	 0.1441603062260176
# Switches in the controller 23 : [6, 13, 29, 25, 9, 7]
# Switch selected is : 13
# The target controller set for 12 is : [31, 32, 33, 10, 3, 30]
# The mean load ratio is : 0.10592050929502805
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10393707912488874
# 4 :	 0.08590901166052946
# 18 :	 0.07862732822963525
# 23 :	 0.11682322187956101
# 12 :	 0.14430590558052583
# Switches in the controller 23 : [6, 29, 25, 9, 7]
# Switch selected is : 29
# The target controller set for 4 is : [19, 8, 28, 16, 26]
# The mean load ratio is : 0.10592050929502805
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10393707912488874
# 4 :	 0.1091689209146601
# 18 :	 0.07862732822963525
# 23 :	 0.09356331262543038
# 12 :	 0.14430590558052583
# Switches in the controller 12 : [31, 32, 33, 10, 3, 30, 13]
# Switch selected is : 10
# The target controller set for 23 is : [6, 25, 9, 7]
# The mean load ratio is : 0.10592050929502805
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10393707912488874
# 4 :	 0.1091689209146601
# 18 :	 0.07862732822963525
# 23 :	 0.12313813729566585
# 12 :	 0.11473108091029037
# Switches in the controller 12 : [31, 32, 33, 3, 30, 13]
# Switch selected is : 32
# The target controller set for 27 is : [22, 2, 0, 11, 21, 20]
# The mean load ratio is : 0.10592050929502805
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# ...
# Switch selected is : 7
# The target controller set for 23 is : [0, 14, 19, 13, 8, 22, 15]
# The mean load ratio is : 0.12286061179482244
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.14304278640209842
# 4 :	 0.10393577104378143
# 18 :	 0.16122037043918253
# 23 :	 0.12569222827344118
# 12 :	 0.08041190281560862
# Switches in the controller 18 : [10, 11, 9, 17, 25, 29, 26]
# Switch selected is : 10
# The target controller set for 23 is : [0, 14, 19, 13, 8, 22, 15, 7]
# The mean load ratio is : 0.12286061179482244
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.14304278640209842
# 4 :	 0.10393577104378143
# 18 :	 0.1417252651298119
# 23 :	 0.1451873335828118
# 12 :	 0.08041190281560862
# Switches in the controller 18 : [11, 9, 17, 25, 29, 26]
# Switch selected is : 25
# The target controller set for 4 is : [21, 31, 6, 2]
# The mean load ratio is : 0.12286061179482244
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.14304278640209842
# 4 :	 0.14093881229409558
# 18 :	 0.10472222387949776
# 23 :	 0.1451873335828118
# 12 :	 0.08041190281560862
# Switches in the controller 27 : [33, 16, 20, 32, 30, 1, 3]
# Switch selected is : 1
# The target controller set for 23 is : [0, 14, 19, 13, 8, 22, 15, 7, 10]
# The mean load ratio is : 0.12286061179482244
#
# At time step 4993 the number of switch migrated are : 4
# The migrated switches are [7, 10, 25, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4994
# The overloaded domains are : [18, 12, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.13059272014725024
# 18 :	 0.12018567438343833
# 23 :	 0.17210019496601464
# 12 :	 0.08323266317326392
# Switches in the controller 18 : [11, 9, 17, 29, 26]
# Switch selected is : 11
# The target controller set for 4 is : [21, 31, 6, 2, 25]
# The mean load ratio is : 0.1141404534457621
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.14659593362899861
# 18 :	 0.10418246090168994
# 23 :	 0.17210019496601464
# 12 :	 0.08323266317326392
# Switches in the controller 4 : [21, 31, 6, 2, 25, 11]
# Switch selected is : 6
# The target controller set for 23 is : [0, 14, 19, 13, 8, 22, 15, 7, 10, 1]
# The mean load ratio is : 0.1141404534457621
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.12823390723683242
# 18 :	 0.10418246090168994
# 23 :	 0.19046222135818083
# 12 :	 0.08323266317326392
# Switches in the controller 4 : [21, 31, 2, 25, 11]
# Switch selected is : 2
# The target controller set for 18 is : [9, 17, 29, 26]
# The mean load ratio is : 0.1141404534457621
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.10185393402164945
# 18 :	 0.1305624341168729
# 23 :	 0.19046222135818083
# 12 :	 0.08323266317326392
# Switches in the controller 23 : [0, 14, 19, 13, 8, 22, 15, 7, 10, 1, 6]
# Switch selected is : 7
# The target controller set for 4 is : [21, 31, 25, 11]
# The mean load ratio is : 0.1141404534457621
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.13559811694539328
# 18 :	 0.1305624341168729
# 23 :	 0.156718038434437
# 12 :	 0.08323266317326392
# Switches in the controller 23 : [0, 14, 19, 13, 8, 22, 15, 10, 1, 6]
# Switch selected is : 0
# The target controller set for 18 is : [9, 17, 29, 26, 2]
# The mean load ratio is : 0.1141404534457621
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06459101455884338
# 4 :	 0.13559811694539328
# 18 :	 0.1489244605090391
# 23 :	 0.1383560120422708
# 12 :	 0.08323266317326392
# Switches in the controller 23 : [14, 19, 13, 8, 22, 15, 10, 1, 6]
# Switch selected is : 1
# The target controller set for 18 is : [9, 17, 29, 26, 2, 0]
# The mean load ratio is : 0.1141404534457621
#
# At time step 4994 the number of switch migrated are : 6
# The migrated switches are [11, 6, 2, 7, 0, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4995
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.14036412392719747
# 18 :	 0.15779259607862148
# 23 :	 0.10013792674611577
# 12 :	 0.06720750036129615
# Switches in the controller 4 : [21, 31, 25, 11, 7]
# Switch selected is : 11
# The target controller set for 12 is : [5, 28, 24]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.11346842737125326
# 18 :	 0.15779259607862148
# 23 :	 0.10013792674611577
# 12 :	 0.09410319691724035
# Switches in the controller 4 : [21, 31, 25, 7]
# Switch selected is : 7
# The target controller set for 23 is : [14, 19, 13, 8, 22, 15, 10, 6]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.0817662605428602
# 18 :	 0.15779259607862148
# 23 :	 0.13184009357450882
# 12 :	 0.09410319691724035
# Switches in the controller 18 : [9, 17, 29, 26, 2, 0, 1]
# Switch selected is : 29
# The target controller set for 4 is : [21, 31, 25]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.11346860459078095
# 18 :	 0.1260902520307007
# 23 :	 0.13184009357450882
# 12 :	 0.09410319691724035
# Switches in the controller 18 : [9, 17, 26, 2, 0, 1]
# Switch selected is : 0
# The target controller set for 23 is : [14, 19, 13, 8, 22, 15, 10, 6, 7]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.11346860459078095
# 18 :	 0.10772822563853451
# 23 :	 0.150202119966675
# 12 :	 0.09410319691724035
# Switches in the controller 18 : [9, 17, 26, 2, 1]
# Switch selected is : 26
# The target controller set for 4 is : [21, 31, 25, 29]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.14517079754471823
# 18 :	 0.07602603268459722
# 23 :	 0.150202119966675
# 12 :	 0.09410319691724035
# Switches in the controller 23 : [14, 19, 13, 8, 22, 15, 10, 6, 7, 0]
# Switch selected is : 13
# The target controller set for 18 is : [9, 17, 2, 1]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.14517079754471823
# 18 :	 0.07624390483562518
# 23 :	 0.14998424781564706
# 12 :	 0.09410319691724035
# Switches in the controller 23 : [14, 19, 8, 22, 15, 10, 6, 7, 0]
# Switch selected is : 7
# The target controller set for 4 is : [21, 31, 25, 29, 26]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.17687296437311129
# 18 :	 0.07624390483562518
# 23 :	 0.118282080987254
# 12 :	 0.09410319691724035
# Switches in the controller 23 : [14, 19, 8, 22, 15, 10, 6, 0]
# Switch selected is : 15
# The target controller set for 4 is : [21, 31, 25, 29, 26, 7]
# The mean load ratio is : 0.1070553905675451
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06977480572449461
# 4 :	 0.17712162631606757
# 18 :	 0.07624390483562518
# 23 :	 0.11803341904429772
# 12 :	 0.09410319691724035
# Switches in the controller 23 : [14, 19, 8, 22, 10, 6, 0]
# Switch selected is : 19
# The target controller set for 4 is : [21, 31, 25, 29, 26, 7, 15]
# The mean load ratio is : 0.1070553905675451
#
# At time step 4995 the number of switch migrated are : 9
# The migrated switches are [11, 7, 29, 0, 26, 13, 7, 15, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4996
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10096823602230375
# 4 :	 0.21419558426897728
# 18 :	 0.08556782270601979
# 23 :	 0.09277113396162436
# 12 :	 0.09320780910775728
# Switches in the controller 4 : [21, 31, 25, 29, 26, 7, 15, 19]
# Switch selected is : 15
# The target controller set for 23 is : [14, 8, 22, 10, 6, 0]
# The mean load ratio is : 0.11734211721333647
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10096823602230375
# 4 :	 0.21382582324125374
# 18 :	 0.08556782270601979
# 23 :	 0.09314089498934791
# 12 :	 0.09320780910775728
# Switches in the controller 4 : [21, 31, 25, 29, 26, 7, 19]
# Switch selected is : 25
# The target controller set for 12 is : [5, 28, 24, 11]
# The mean load ratio is : 0.11734211721333647
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10096823602230375
# 4 :	 0.17840518785172677
# 18 :	 0.08556782270601979
# 23 :	 0.09314089498934791
# 12 :	 0.12862844449728428
# Switches in the controller 4 : [21, 31, 29, 26, 7, 19]
# Switch selected is : 19
# The target controller set for 23 is : [14, 8, 22, 10, 6, 0, 15]
# The mean load ratio is : 0.11734211721333647
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10096823602230375
# 4 :	 0.1600433045023313
# 18 :	 0.08556782270601979
# 23 :	 0.11150277833874336
# 12 :	 0.12862844449728428
# Switches in the controller 4 : [21, 31, 29, 26, 7]
# Switch selected is : 29
# The target controller set for 23 is : [14, 8, 22, 10, 6, 0, 15, 19]
# The mean load ratio is : 0.11734211721333647
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10096823602230375
# 4 :	 0.12462307164249173
# 18 :	 0.08556782270601979
# 23 :	 0.14692301119858295
# 12 :	 0.12862844449728428
# Switches in the controller 4 : [21, 31, 26, 7]
# Switch selected is : 21
# The target controller set for 12 is : [5, 28, 24, 11, 25]
# The mean load ratio is : 0.11734211721333647
#
# At time step 4996 the number of switch migrated are : 5
# The migrated switches are [15, 25, 19, 29, 21]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4997
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07615176418643767
# 4 :	 0.09368365504829405
# 18 :	 0.10289040461371388
# 23 :	 0.15800824468833863
# 12 :	 0.15420627090478378
# Switches in the controller 23 : [14, 8, 22, 10, 6, 0, 15, 19, 29]
# Switch selected is : 0
# The target controller set for 18 is : [9, 17, 2, 1, 13]
# The mean load ratio is : 0.11698806788831359
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07615176418643767
# 4 :	 0.09368365504829405
# 18 :	 0.12125243100588007
# 23 :	 0.13964621829617244
# 12 :	 0.15420627090478378
# Switches in the controller 23 : [14, 8, 22, 10, 6, 15, 19, 29]
# Switch selected is : 6
# The target controller set for 18 is : [9, 17, 2, 1, 13, 0]
# The mean load ratio is : 0.11698806788831359
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07615176418643767
# 4 :	 0.09368365504829405
# 18 :	 0.13961445739804626
# 23 :	 0.12128419190400624
# 12 :	 0.15420627090478378
# Switches in the controller 23 : [14, 8, 22, 10, 15, 19, 29]
# Switch selected is : 22
# The target controller set for 4 is : [31, 26, 7]
# The mean load ratio is : 0.11698806788831359
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07615176418643767
# 4 :	 0.11204588971087591
# 18 :	 0.13961445739804626
# 23 :	 0.10292195724142439
# 12 :	 0.15420627090478378
# Switches in the controller 12 : [5, 28, 24, 11, 25, 21]
# Switch selected is : 5
# The target controller set for 4 is : [31, 26, 7, 22]
# The mean load ratio is : 0.11698806788831359
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07615176418643767
# 4 :	 0.14026770529610144
# 18 :	 0.13961445739804626
# 23 :	 0.10292195724142439
# 12 :	 0.12598445531955826
# Switches in the controller 12 : [28, 24, 11, 25, 21]
# Switch selected is : 28
# The target controller set for 27 is : [33, 16, 20, 32, 30, 3]
# The mean load ratio is : 0.11698806788831359
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10737961630795978
# 4 :	 0.14026770529610144
# 18 :	 0.13961445739804626
# 23 :	 0.10292195724142439
# 12 :	 0.09475660319803615
# Switches in the controller 4 : [31, 26, 7, 22, 5]
# Switch selected is : 26
# The target controller set for 18 is : [9, 17, 2, 1, 13, 0, 6]
# The mean load ratio is : 0.11698806788831359
#
# At time step 4997 the number of switch migrated are : 6
# The migrated switches are [0, 6, 22, 5, 28, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08681440261012864
# 4 :	 0.09357169344269702
# 18 :	 0.11110541786037302
# 23 :	 0.08787407208787937
# 12 :	 0.08530240562472258
# Switches in the controller 18 : [9, 17, 2, 1, 13, 0, 6, 26]
# Switch selected is : 6
# The target controller set for 4 is : [31, 7, 22, 5]
# The mean load ratio is : 0.09293359832516013
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08681440261012864
# 4 :	 0.1119337198348632
# 18 :	 0.09274339146820684
# 23 :	 0.08787407208787937
# 12 :	 0.08530240562472258
# Switches in the controller 4 : [31, 7, 22, 5, 6]
# Switch selected is : 31
# The target controller set for 23 is : [14, 8, 10, 15, 19, 29]
# The mean load ratio is : 0.09293359832516013
#
# At time step 4998 the number of switch migrated are : 2
# The migrated switches are [6, 31]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# The overloaded domains are : [18, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08090576069233078
# 4 :	 0.08529275694262045
# 18 :	 0.09124873600285828
# 23 :	 0.0966892606570247
# 12 :	 0.05714698583626117
# Switches in the controller 23 : [14, 8, 10, 15, 19, 29, 31]
# Switch selected is : 29
# The target controller set for 12 is : [24, 11, 25, 21]
# The mean load ratio is : 0.08225670002621907
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08090576069233078
# 4 :	 0.08529275694262045
# 18 :	 0.09124873600285828
# 23 :	 0.07913241030485649
# 12 :	 0.07470383618842938
# Switches in the controller 4 : [7, 22, 5, 6]
# Switch selected is : 7
# The target controller set for 18 is : [9, 17, 2, 1, 13, 0, 26]
# The mean load ratio is : 0.08225670002621907
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08090576069233078
# 4 :	 0.0677363496945379
# 18 :	 0.10880514325094083
# 23 :	 0.07913241030485649
# 12 :	 0.07470383618842938
# Switches in the controller 18 : [9, 17, 2, 1, 13, 0, 26, 7]
# Switch selected is : 13
# The target controller set for 27 is : [33, 16, 20, 32, 30, 3, 28]
# The mean load ratio is : 0.08225670002621907
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08098223341785502
# 4 :	 0.0677363496945379
# 18 :	 0.1087286705254166
# 23 :	 0.07913241030485649
# 12 :	 0.07470383618842938
# Switches in the controller 18 : [9, 17, 2, 1, 0, 26, 7]
# Switch selected is : 1
# The target controller set for 4 is : [22, 5, 6]
# The mean load ratio is : 0.08225670002621907
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08098223341785502
# 4 :	 0.08630192966778824
# 18 :	 0.09016309055216626
# 23 :	 0.07913241030485649
# 12 :	 0.07470383618842938
# Switches in the controller 18 : [9, 17, 2, 0, 26, 7]
# Switch selected is : 9
# The target controller set for 4 is : [22, 5, 6, 1]
# The mean load ratio is : 0.08225670002621907
#
# At time step 4999 the number of switch migrated are : 5
# The migrated switches are [29, 7, 13, 1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 0.7
epsilon_dec = 0.0025
epsilon_min = 0.05

load_controller = []

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon * epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31, 25]
# The mean load ratio is : 0.11030749451827948
# The reward is = 0.7751132494407242
# Q value = 42.13297304562943
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09450849514957389
# 4 :	 0.12791705957223345
# 18 :	 0.08264212948702973
# 23 :	 0.12780135142202423
# 12 :	 0.11866843696053611
# [(732818.343, 10), (703792.6404, 8), (635466.5414, 28), (415310.3387, 19), (388951.6388, 11), (7400.665572, 15), (6833.820065999999, 14)]
# Switches in the controller 23 : [14, 15, 19, 10, 28, 8, 11]
# Switch selected is : 10
# The underloaded domains are : [27, 18]
# The target controller set for 18 is : [17, 24, 26, 7, 3]
# The mean load ratio is : 0.11030749451827948
# The reward is = 1.7857337418978567
# Q value = 34.0104213278279
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.09450849514957389
# 4 :	 0.12791705957223345
# 18 :	 0.11504232923042315
# 23 :	 0.09540115167863081
# 12 :	 0.11866843696053611
# [(880505.6152, 2), (752730.8692, 9), (635464.8868, 29), (415307.0, 6)]
# Switches in the controller 12 : [6, 9, 2, 29]
# Switch selected is : 2
# The underloaded domains are : [27, 23]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 30, 5]
# The mean load ratio is : 0.11030749451827948
# The reward is = 0.5671118761931043
# Q value = 30.78342280366366
#
# At time step 4911 the number of switch migrated are : 3
# The migrated switches are [1, 10, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4912
# 0.1934467389090262
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.11698755810109528
# 4 :	 0.14218044580541073
# 18 :	 0.14020935266965484
# 23 :	 0.10601963723909974
# 12 :	 0.08118888923864268
# [(823166.4012, 26), (823159.7829, 7), (578701.9284, 10), (522225.703, 3), (415307.0291, 24), (8653.725379000001, 17)]
# Switches in the controller 18 : [17, 24, 26, 7, 3, 10]
# Switch selected is : 26
# The underloaded domains are : [27, 23, 12]
# Taking a random action
# The target controller set for 12 is : [6, 9, 29]
# The mean load ratio is : 0.11731717661078064
# The reward is = 3.2158759051127745
# Q value = 40.41837305772516
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11698755810109528
# 4 :	 0.14218044580541073
# 18 :	 0.10381458161118759
# 23 :	 0.10601963723909974
# 12 :	 0.11758366029710993
# [(823164.4258, 25), (823141.9485, 31), (738873.75, 1), (415309.0599, 20), (415307.0, 0)]
# Switches in the controller 4 : [0, 20, 31, 25, 1]
# Switch selected is : 25
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 7, 3, 10]
# The mean load ratio is : 0.11731717661078064
# The reward is = 1.191022626133549
# Q value = 40.00501681717921
#
# At time step 4912 the number of switch migrated are : 2
# The migrated switches are [26, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4913
# 0.17419748564940338
# The overloaded domains are : [18, 27, 4, 12]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.11344553233661112
# 4 :	 0.10561874879862868
# 18 :	 0.11306913159683706
# 23 :	 0.06896891578350792
# 12 :	 0.08857763942826444
# [(623949.9398, 2), (553261.2978, 5), (547526.3899, 30), (415305.1752, 21), (415302.3105, 22), (4762.297867, 33), (4742.396086, 32), (660.5358317, 13), (367.8826463, 16)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 30, 5, 2]
# Switch selected is : 2
# The underloaded domains are : [23, 12]
# The target controller set for 23 is : [14, 15, 19, 28, 8, 11]
# The mean load ratio is : 0.09793599358876985
# The reward is = 2.131616501551617
# Q value = 45.08577698758939
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08585874650830072
# 4 :	 0.10561874879862868
# 18 :	 0.11306913159683706
# 23 :	 0.09655570161181831
# 12 :	 0.08857763942826444
# [(547546.418, 25), (547541.9115, 7), (536874.1999, 10), (504358.3464, 3), (415305.2113, 24), (5738.815508, 17)]
# Switches in the controller 18 : [17, 24, 7, 3, 10, 25]
# Switch selected is : 25
# The underloaded domains are : [27, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 28, 8, 11, 2]
# The mean load ratio is : 0.09793599358876985
# The reward is = 0.9386392323149697
# Q value = 46.65348270296661
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08585874650830072
# 4 :	 0.10561874879862868
# 18 :	 0.08886038534827381
# 23 :	 0.12076444786038157
# 12 :	 0.08857763942826444
# [(1010681.9770000001, 1), (547556.0718, 31), (415309.2514, 20), (415307.0, 0)]
# Switches in the controller 4 : [0, 20, 31, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 9, 29, 26]
# The mean load ratio is : 0.09793599358876985
# The reward is = 0.29831957417191424
# Q value = 42.10279938736994
#
# At time step 4913 the number of switch migrated are : 3
# The migrated switches are [2, 25, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4914
# 0.19752166629743298
# The overloaded domains are : [18, 27, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0729974849212919
# 4 :	 0.05328842671210964
# 18 :	 0.06465553642872583
# 23 :	 0.08996923490808086
# 12 :	 0.09166902092406376
# [(526217.7265, 1), (415307.0, 6), (382539.8167, 9), (374641.1224, 26), (374637.7258, 29)]
# Switches in the controller 12 : [6, 9, 29, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 18]
# The target controller set for 4 is : [0, 20, 31]
# The mean load ratio is : 0.0745159407788544
# The reward is = 2.223033307345277
# Q value = 39.59698929310299
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.0729974849212919
# 4 :	 0.07655416454464964
# 18 :	 0.06465553642872583
# 23 :	 0.08996923490808086
# 12 :	 0.06840328309152377
# [(614952.1323, 8), (415304.584, 19), (374660.669, 28), (374646.8356, 25), (144787.9227, 11), (101473.7295, 2), (4717.558814, 14), (4354.691199, 15)]
# Switches in the controller 23 : [14, 15, 19, 28, 8, 11, 2, 25]
# Switch selected is : 8
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 9, 29, 26]
# The mean load ratio is : 0.0745159407788544
# The reward is = 0.4826667927698379
# Q value = 46.76837462960154
#
# At time step 4914 the number of switch migrated are : 2
# The migrated switches are [1, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4915
# 0.08807268364787982
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07515175632941903
# 4 :	 0.08953326474015029
# 18 :	 0.08160052400422568
# 23 :	 0.09723537908027015
# 12 :	 0.09040995179753564
# [(443764.4458, 29), (443758.2917, 26), (415307.0, 6), (388082.3522, 9), (353954.0405, 8)]
# Switches in the controller 12 : [6, 9, 29, 26, 8]
# Switch selected is : 29
# The underloaded domains are : [27, 18]
# The target controller set for 18 is : [17, 24, 7, 3, 10]
# The mean load ratio is : 0.08678617519032016
# The reward is = 0.8074961781794188
# Q value = 40.5240206271804
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.07515175632941903
# 4 :	 0.08953326474015029
# 18 :	 0.10122074342187239
# 23 :	 0.09723537908027015
# 12 :	 0.07078973237988893
# [(750663.9526, 1), (443764.5513, 31), (415307.0, 0), (415301.9721, 20)]
# Switches in the controller 4 : [0, 20, 31, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 9, 26, 8]
# The mean load ratio is : 0.08678617519032016
# The reward is = 0.37396259548372796
# Q value = 34.085585975653984
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07515175632941903
# 4 :	 0.05634405456722042
# 18 :	 0.10122074342187239
# 23 :	 0.09723537908027015
# 12 :	 0.10397894255281881
# [(464613.66299999994, 11), (443764.5761, 28), (443762.7613, 25), (419741.0107, 2), (415305.9059, 19), (6358.9644, 14), (5694.788186, 15)]
# Switches in the controller 23 : [14, 15, 19, 28, 11, 2, 25]
# Switch selected is : 11
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31]
# The mean load ratio is : 0.08678617519032016
# The reward is = 199.21265818343426
# Q value = 158.11233573863234
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.07515175632941903
# 4 :	 0.0768860833367018
# 18 :	 0.10122074342187239
# 23 :	 0.07669335031078876
# 12 :	 0.10397894255281881
# [(523633.9015, 10), (456143.653, 3), (443764.4458, 29), (443763.8781, 7), (415308.3481, 24), (6767.260624, 17)]
# Switches in the controller 18 : [17, 24, 7, 3, 10, 29]
# Switch selected is : 10
# The underloaded domains are : [27, 4, 23]
# The target controller set for 23 is : [14, 15, 19, 28, 2, 25]
# The mean load ratio is : 0.08678617519032016
# The reward is = 1.63406800987822
# Q value = 86.04901489733916
#
# At time step 4915 the number of switch migrated are : 4
# The migrated switches are [29, 1, 11, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4916
# 0.23867995187288132
# The overloaded domains are : [18, 27, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07266013107748456
# 4 :	 0.06177264894470671
# 18 :	 0.07172592525828582
# 23 :	 0.10311019848616008
# 12 :	 0.11409932298296596
# [(652586.6516, 8), (624813.0057, 1), (457404.7867, 9), (430554.0293, 26), (415307.0, 6)]
# Switches in the controller 12 : [6, 9, 26, 8, 1]
# Switch selected is : 8
# The underloaded domains are : [27, 4, 18]
# The target controller set for 18 is : [17, 24, 7, 3, 29]
# The mean load ratio is : 0.08467364534992064
# The reward is = 1.3466407022423086
# Q value = 53.15817892909999
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07266013107748456
# 4 :	 0.06177264894470671
# 18 :	 0.10057883002477075
# 23 :	 0.10311019848616008
# 12 :	 0.08524641821648103
# [(624813.0057, 1), (457404.7867, 9), (430554.0293, 26), (415307.0, 6)]
# Switches in the controller 12 : [6, 9, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31, 11]
# The mean load ratio is : 0.08467364534992064
# The reward is = 0.5783394367345772
# Q value = 32.98790644249721
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07266013107748456
# 4 :	 0.08939759362618832
# 18 :	 0.10057883002477075
# 23 :	 0.10311019848616008
# 12 :	 0.057621473534999426
# [(608463.2118, 10), (436905.7467, 2), (430554.0676, 25), (430552.6716, 28), (415307.2057, 19), (5968.3414490000005, 14), (4365.390217, 15)]
# Switches in the controller 23 : [14, 15, 19, 28, 2, 25, 10]
# Switch selected is : 10
# The underloaded domains are : [27, 12]
# Taking a random action
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 30, 5]
# The mean load ratio is : 0.08467364534992064
# The reward is = 0.6271937671868308
# Q value = 22.47894063178134
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09956220003787725
# 4 :	 0.08939759362618832
# 18 :	 0.10057883002477075
# 23 :	 0.0762081295257674
# 12 :	 0.057621473534999426
# [(652586.6516, 8), (430553.9805, 29), (430552.7628, 7), (415305.3403, 24), (341146.3893, 3), (4717.751142, 17)]
# Switches in the controller 18 : [17, 24, 7, 3, 29, 8]
# Switch selected is : 8
# The underloaded domains are : [23, 12]
# The target controller set for 23 is : [14, 15, 19, 28, 2, 25]
# The mean load ratio is : 0.08467364534992064
# The reward is = 0.7576180389887887
# Q value = 101.28135779255453
#
# At time step 4916 the number of switch migrated are : 4
# The migrated switches are [8, 1, 10, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4917
# 0.22706058260280632
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10425052848608872
# 4 :	 0.13525389616114444
# 18 :	 0.09932066840251272
# 23 :	 0.14947996028286528
# 12 :	 0.07809145572449011
# [(824282.8701, 8), (719410.1411, 28), (719405.3248, 25), (688946.6293, 2), (415306.1191, 19), (7873.805287, 15), (5669.6008950000005, 14)]
# Switches in the controller 23 : [14, 15, 19, 28, 2, 25, 8]
# Switch selected is : 8
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 9, 26]
# The mean load ratio is : 0.11327930181142025
# The reward is = 15.17382773405584
# Q value = 50.13808164249611
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10425052848608872
# 4 :	 0.13525389616114444
# 18 :	 0.09932066840251272
# 23 :	 0.11303582662899793
# 12 :	 0.11453558937835746
# [(1088552.92, 1), (719411.3726, 31), (420556.7919, 11), (415307.0, 0), (415305.404, 20)]
# Switches in the controller 4 : [0, 20, 31, 11, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 7, 3, 29]
# The mean load ratio is : 0.11327930181142025
# The reward is = 0.6481021287021376
# Q value = 58.92903827696587
#
# At time step 4917 the number of switch migrated are : 2
# The migrated switches are [8, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4918
# 0.20636581939998505
# The overloaded domains are : [18, 27, 12, 23]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.13478997732632145
# 4 :	 0.09038353064425966
# 18 :	 0.15092470700173824
# 23 :	 0.10023340833684015
# 12 :	 0.09767216076273812
# [(796154.3286, 30), (737644.0939, 10), (662603.3349, 5), (415300.6962, 22), (415300.3449, 21), (7002.967758, 16), (5122.939325, 13), (4768.175115999999, 32), (4743.825827000001, 33)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 30, 5, 10]
# Switch selected is : 30
# The underloaded domains are : [4, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 28, 2, 25]
# The mean load ratio is : 0.11480075681437951
# The reward is = 0.936681129537656
# Q value = 85.00350048298392
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09958949480618443
# 4 :	 0.09038353064425966
# 18 :	 0.15092470700173824
# 23 :	 0.13543389085697718
# 12 :	 0.09767216076273812
# [(1172263.635, 1), (796169.7548, 29), (796160.1125, 7), (415306.7274, 24), (226174.0267, 3), (7497.097441, 17)]
# Switches in the controller 18 : [17, 24, 7, 3, 29, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 12]
# The target controller set for 4 is : [0, 20, 31, 11]
# The mean load ratio is : 0.11480075681437951
# The reward is = 0.9327493515410564
# Q value = 42.163034905502066
#
# At time step 4918 the number of switch migrated are : 2
# The migrated switches are [30, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4919
# 0.1321663039244268
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09243860018500494
# 4 :	 0.119107952380602
# 18 :	 0.0878456176046745
# 23 :	 0.10228463349433542
# 12 :	 0.0828913062774512
# [(524631.5092, 2), (455333.5848, 28), (455324.6175, 25), (455319.6234, 30), (415306.2464, 19), (4438.070573, 15), (3090.59308, 14)]
# Switches in the controller 23 : [14, 15, 19, 28, 2, 25, 30]
# Switch selected is : 2
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 9, 26, 8]
# The mean load ratio is : 0.09691362198841362
# The reward is = 0.8573631726816755
# Q value = 42.89608571082944
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09243860018500494
# 4 :	 0.119107952380602
# 18 :	 0.0878456176046745
# 23 :	 0.07908902730880911
# 12 :	 0.10608691246297751
# [(965443.5293, 11), (455312.1933, 31), (442581.9274, 1), (415307.0, 0), (415304.5538, 20)]
# Switches in the controller 4 : [0, 20, 31, 11, 1]
# Switch selected is : 11
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 7, 3, 29]
# The mean load ratio is : 0.09691362198841362
# The reward is = 0.7649613187004085
# Q value = 66.5687623748795
#
# At time step 4919 the number of switch migrated are : 2
# The migrated switches are [2, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4920
# 0.17589633700845592
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.09349166289519764
# 4 :	 0.09704467959916184
# 18 :	 0.14666570774513205
# 23 :	 0.1290349059178821
# 12 :	 0.1345305994425397
# [(831133.0144, 26), (673047.3087, 9), (625671.3148, 2), (497615.5347, 8), (415307.0, 6)]
# Switches in the controller 12 : [6, 9, 26, 8, 2]
# Switch selected is : 26
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31, 1]
# The mean load ratio is : 0.12015351111998265
# The reward is = 0.7145781277538771
# Q value = 41.5827896511006
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09349166289519764
# 4 :	 0.1337916796396462
# 18 :	 0.14666570774513205
# 23 :	 0.1290349059178821
# 12 :	 0.09778359940205533
# [(831152.7476, 28), (831149.3432, 25), (831143.2946, 30), (415308.5442, 19), (6993.536204000001, 14), (2726.7008, 15)]
# Switches in the controller 23 : [14, 15, 19, 28, 25, 30]
# Switch selected is : 28
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 9, 8, 2]
# The mean load ratio is : 0.12015351111998265
# The reward is = 0.7670274423983665
# Q value = 39.94508589999279
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09349166289519764
# 4 :	 0.1337916796396462
# 18 :	 0.14666570774513205
# 23 :	 0.09228703341067024
# 12 :	 0.1345314719092672
# [(1051715.872, 3), (831149.6028, 7), (831138.5347, 29), (415304.0495, 24), (181107.0952, 11), (6827.38677, 17)]
# Switches in the controller 18 : [17, 24, 7, 3, 29, 11]
# Switch selected is : 3
# The underloaded domains are : [27, 23]
# The target controller set for 23 is : [14, 15, 19, 25, 30]
# The mean load ratio is : 0.12015351111998265
# The reward is = 1.237435200819718
# Q value = 107.66218524773923
#
# At time step 4920 the number of switch migrated are : 3
# The migrated switches are [26, 28, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4921
# 0.1385494025157614
# The overloaded domains are : [18, 27, 4, 12]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.09447305492140123
# 4 :	 0.10653086346901072
# 18 :	 0.08703114200225853
# 23 :	 0.07312076694158039
# 12 :	 0.1082971976443488
# [(665277.385, 5), (616874.2354, 10), (415313.025, 21), (415306.1479, 22), (11671.92912, 16), (4768.066922999999, 32), (4751.12514, 33), (2802.306539, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 5, 10]
# Switch selected is : 5
# The underloaded domains are : [18, 23]
# The target controller set for 23 is : [14, 15, 19, 25, 30, 3]
# The mean load ratio is : 0.09389060499571993
# The reward is = 0.6388663694227786
# Q value = 100.79190102507282
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.0650590529867329
# 4 :	 0.10653086346901072
# 18 :	 0.08703114200225853
# 23 :	 0.10253476887624872
# 12 :	 0.1082971976443488
# [(670002.2464, 1), (454436.6482, 26), (454430.3302, 31), (415308.0211, 20), (415307.0, 0)]
# Switches in the controller 4 : [0, 20, 31, 1, 26]
# Switch selected is : 1
# The underloaded domains are : [27, 18]
# The target controller set for 18 is : [17, 24, 7, 29, 11]
# The mean load ratio is : 0.09389060499571993
# The reward is = 0.8116606906064249
# Q value = 72.33261916836614
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.0650590529867329
# 4 :	 0.07690796057739697
# 18 :	 0.11665404489387228
# 23 :	 0.10253476887624872
# 12 :	 0.1082971976443488
# [(670002.2464, 1), (638207.9972, 11), (454434.2552, 29), (454433.9435, 7), (415306.9301, 24), (6062.061888, 17)]
# Switches in the controller 18 : [17, 24, 7, 29, 11, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31, 26]
# The mean load ratio is : 0.09389060499571993
# The reward is = 1.6543997461818474
# Q value = 48.237553860623706
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0650590529867329
# 4 :	 0.10653086346901072
# 18 :	 0.08703114200225853
# 23 :	 0.10253476887624872
# 12 :	 0.1082971976443488
# [(659292.8797, 2), (601926.5015, 9), (454425.4357, 28), (415307.0, 6), (318482.8643, 8)]
# Switches in the controller 12 : [6, 9, 8, 2, 28]
# Switch selected is : 2
# The underloaded domains are : [27, 18]
# The target controller set for 18 is : [17, 24, 7, 29, 11]
# The mean load ratio is : 0.09389060499571993
# The reward is = 0.7534963097814145
# Q value = 66.93348716155931
#
# At time step 4921 the number of switch migrated are : 4
# The migrated switches are [5, 1, 1, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4922
# 0.18864042865360378
# The overloaded domains are : [18, 12, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06943644203533435
# 4 :	 0.12222605830086616
# 18 :	 0.09130811025922805
# 23 :	 0.10946622807531868
# 12 :	 0.08880404602961471
# [(836457.6948, 3), (450752.1497, 5), (415309.896, 19), (380552.0746, 25), (380542.2503, 30), (6562.035047, 15), (5699.372789, 14)]
# Switches in the controller 23 : [14, 15, 19, 25, 30, 3, 5]
# Switch selected is : 3
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 9, 8, 28]
# The mean load ratio is : 0.0962481769400724
# The reward is = 0.531386708006523
# Q value = 44.40893099265594
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.06943644203533435
# 4 :	 0.12222605830086616
# 18 :	 0.09130811025922805
# 23 :	 0.07248380719667206
# 12 :	 0.12578646690826134
# [(1172763.19, 1), (415307.0, 0), (415299.2621, 20), (380558.3026, 31), (380545.8666, 26)]
# Switches in the controller 4 : [0, 20, 31, 26, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 7, 29, 11, 2]
# The mean load ratio is : 0.0962481769400724
# The reward is = 0.4889601006369957
# Q value = 74.44454153177914
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.06943644203533435
# 4 :	 0.07037451559501001
# 18 :	 0.1431596529650842
# 23 :	 0.07248380719667206
# 12 :	 0.12578646690826134
# [(836457.6948, 3), (657878.8774, 9), (554812.2169, 8), (415307.0, 6), (380546.1239, 28)]
# Switches in the controller 12 : [6, 9, 8, 28, 3]
# Switch selected is : 3
# The underloaded domains are : [27, 4, 23]
# The target controller set for 4 is : [0, 20, 31, 26]
# The mean load ratio is : 0.0962481769400724
# The reward is = 1.7621780920060242
# Q value = 48.95713015899109
#
# At time step 4922 the number of switch migrated are : 3
# The migrated switches are [3, 1, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4923
# 0.22885925990197706
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.059151519717037464
# 4 :	 0.08219727512024921
# 18 :	 0.11648728654713564
# 23 :	 0.07228103945184121
# 12 :	 0.08980796080441751
# [(880631.0848, 1), (415310.1105, 24), (385795.8506, 29), (385781.4755, 7), (306671.6455, 11), (252764.9243, 2), (7720.651051999999, 17)]
# Switches in the controller 18 : [17, 24, 7, 29, 11, 2, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 23]
# The target controller set for 23 is : [14, 15, 19, 25, 30, 5]
# The mean load ratio is : 0.08398501632813621
# The reward is = 0.8010443338002171
# Q value = 109.9526817096014
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.059151519717037464
# 4 :	 0.08219727512024921
# 18 :	 0.0775518214072282
# 23 :	 0.11121650459174864
# 12 :	 0.08980796080441751
# [(673005.3604, 9), (557154.8514, 8), (415307.0, 6), (385783.2603, 28)]
# Switches in the controller 12 : [6, 9, 8, 28]
# Switch selected is : 9
# The underloaded domains are : [27, 4, 18]
# The target controller set for 18 is : [17, 24, 7, 29, 11, 2]
# The mean load ratio is : 0.08398501632813621
# The reward is = 0.44270183311331956
# Q value = 73.2191422825243
#
# At time step 4923 the number of switch migrated are : 2
# The migrated switches are [1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4924
# 0.25895990989580925
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.06532660108445933
# 4 :	 0.1033419386067526
# 18 :	 0.1324366299920125
# 23 :	 0.13281106655412622
# 12 :	 0.08282019320042731
# [(749929.3157, 25), (749922.3825, 30), (565919.4756, 1), (511422.9376, 5), (415309.37299999996, 19), (7784.407940000001, 15), (3594.3829259999998, 14)]
# Switches in the controller 23 : [14, 15, 19, 25, 30, 5, 1]
# Switch selected is : 25
# The underloaded domains are : [27, 4, 12]
# The target controller set for 4 is : [0, 20, 31, 26, 3]
# The mean load ratio is : 0.1033472858875556
# The reward is = 1.281896006949572
# Q value = 95.28077934296992
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.06532660108445933
# 4 :	 0.13649866817582446
# 18 :	 0.1324366299920125
# 23 :	 0.09965433698505435
# 12 :	 0.08282019320042731
# [(749927.7874, 7), (749922.9291, 29), (415307.7343, 24), (404013.3353, 11), (336390.7843, 2), (332633.0952, 9), (7217.711845000001, 17)]
# Switches in the controller 18 : [17, 24, 7, 29, 11, 2, 9]
# Switch selected is : 7
# The underloaded domains are : [27, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 30, 5, 1]
# The mean load ratio is : 0.1033472858875556
# The reward is = 1.7304192573970414
# Q value = 85.03725156232616
#
# At time step 4924 the number of switch migrated are : 2
# The migrated switches are [25, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4925
# 0.3876908333095319
# The overloaded domains are : [18, 12, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.0553622804564137
# 4 :	 0.18169011387404935
# 18 :	 0.11815441978140136
# 23 :	 0.13414953602197513
# 12 :	 0.07859101773462175
# [(862066.978, 3), (805586.646, 26), (805577.6858, 31), (805570.0524, 25), (415307.0, 0), (415306.0625, 20)]
# Switches in the controller 4 : [0, 20, 31, 26, 3, 25]
# Switch selected is : 3
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 8, 28]
# The mean load ratio is : 0.11358947357369224
# The reward is = 1.383826022731919
# Q value = 45.21656976256095
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.0553622804564137
# 4 :	 0.14357542618072622
# 18 :	 0.11815441978140136
# 23 :	 0.13414953602197513
# 12 :	 0.11670570542794487
# [(805586.646, 26), (805577.6858, 31), (805570.0524, 25), (415307.0, 0), (415306.0625, 20)]
# Switches in the controller 4 : [0, 20, 31, 26, 25]
# Switch selected is : 26
# The underloaded domains are : [27]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 10]
# The mean load ratio is : 0.11358947357369224
# The reward is = 1.9528836141287869
# Q value = 46.3302272957207
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09097979534306053
# 4 :	 0.10795791129407939
# 18 :	 0.11815441978140136
# 23 :	 0.13414953602197513
# 12 :	 0.11670570542794487
# [(805571.3274, 30), (805568.8405, 7), (664154.6097, 1), (415306.4645, 19), (331656.5209, 5), (6237.329865, 14), (5660.297547, 15)]
# Switches in the controller 23 : [14, 15, 19, 30, 5, 1, 7]
# Switch selected is : 30
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 31, 25]
# The mean load ratio is : 0.11358947357369224
# The reward is = 1.7917142221807918
# Q value = 70.45404771384368
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.09097979534306053
# 4 :	 0.14357474889732505
# 18 :	 0.11815441978140136
# 23 :	 0.09853269841872947
# 12 :	 0.11670570542794487
# [(805561.9358, 29), (740269.4240000001, 2), (415310.4388, 24), (410221.5641, 9), (290707.6894, 11), (10311.42727, 17)]
# Switches in the controller 18 : [17, 24, 29, 11, 2, 9]
# Switch selected is : 29
# The underloaded domains are : [27, 23]
# The target controller set for 23 is : [14, 15, 19, 5, 1, 7]
# The mean load ratio is : 0.11358947357369224
# The reward is = 0.6997429494881783
# Q value = 64.02544643443771
#
# At time step 4925 the number of switch migrated are : 4
# The migrated switches are [3, 26, 30, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4926
# 0.2805754507076073
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.09936845648251906
# 4 :	 0.14526185984237097
# 18 :	 0.14317287553617222
# 23 :	 0.18208042062627453
# 12 :	 0.07923508328756003
# [(818311.3616, 25), (818287.5294, 31), (818278.3782, 30), (415307.0, 0), (415306.4461, 20)]
# Switches in the controller 4 : [0, 20, 31, 25, 30]
# Switch selected is : 25
# The underloaded domains are : [27, 12]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 10, 26]
# The mean load ratio is : 0.12982373915497936
# The reward is = 0.8402639569912772
# Q value = 61.36884772301363
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.1355485709971038
# 4 :	 0.10908174532778622
# 18 :	 0.14317287553617222
# 23 :	 0.18208042062627453
# 12 :	 0.07923508328756003
# [(1531136.975, 11), (666846.0062, 9), (618344.7216, 2), (415308.9531, 24), (6606.016797, 17)]
# Switches in the controller 18 : [17, 24, 11, 2, 9]
# Switch selected is : 11
# The underloaded domains are : [4, 12]
# The target controller set for 4 is : [0, 20, 31, 30]
# The mean load ratio is : 0.12982373915497936
# The reward is = 0.4980268465234376
# Q value = 50.86054509551078
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.1355485709971038
# 4 :	 0.17677811823980433
# 18 :	 0.07547650262415413
# 23 :	 0.18208042062627453
# 12 :	 0.07923508328756003
# [(1189723.261, 1), (869248.2056, 5), (818289.3496, 7), (818288.6751, 29), (415312.0873, 19), (4001.947887, 14), (3378.7434020000005, 15)]
# Switches in the controller 23 : [14, 15, 19, 5, 1, 7, 29]
# Switch selected is : 1
# The underloaded domains are : [18, 12]
# The target controller set for 12 is : [6, 8, 28, 3]
# The mean load ratio is : 0.12982373915497936
# The reward is = 12.316224295820493
# Q value = 55.90534673321488
#
# At time step 4926 the number of switch migrated are : 3
# The migrated switches are [25, 11, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4927
# 0.15003854933575306
# The overloaded domains are : [27, 12, 4, 23]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.1226418780757297
# 4 :	 0.09295568379646148
# 18 :	 0.07782286356808954
# 23 :	 0.09492967719887108
# 12 :	 0.09468566288385548
# [(675196.6694, 10), (627305.1784, 25), (627297.7227, 26), (415306.6073, 22), (415304.2243, 21), (4765.704912, 32), (4728.680784, 33), (2074.260009, 16), (1899.464848, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 10, 26, 25]
# Switch selected is : 10
# The underloaded domains are : [4, 18, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 5, 7, 29]
# The mean load ratio is : 0.09660715310460145
# The reward is = 0.9715162788352937
# Q value = 70.49037021714464
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.09278931343457145
# 4 :	 0.09295568379646148
# 18 :	 0.07782286356808954
# 23 :	 0.12478224184002931
# 12 :	 0.09468566288385548
# [(675196.6694, 10), (627300.9442, 7), (627288.5103, 29), (466327.6271, 5), (415306.5468, 19), (7646.337382, 14), (3222.005791, 15)]
# Switches in the controller 23 : [14, 15, 19, 5, 7, 29, 10]
# Switch selected is : 10
# The underloaded domains are : [27, 4, 18, 12]
# The target controller set for 4 is : [0, 20, 31, 30, 11]
# The mean load ratio is : 0.09660715310460145
# The reward is = 1.952556353873106
# Q value = 60.61986034120857
#
# At time step 4927 the number of switch migrated are : 2
# The migrated switches are [10, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4928
# 0.28592575159089856
# The overloaded domains are : [18, 12, 4, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07048045103803595
# 4 :	 0.13944084537273194
# 18 :	 0.07157499151786942
# 23 :	 0.0771175477788185
# 12 :	 0.09350082891293265
# [(682272.6819, 8), (559597.9961, 1), (415307.0, 6), (375393.1481, 28), (82203.86837000001, 3)]
# Switches in the controller 12 : [6, 8, 28, 3, 1]
# Switch selected is : 8
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 2, 9]
# The mean load ratio is : 0.0904229329240777
# The reward is = 0.4775877904862976
# Q value = 56.46489708976533
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.07048045103803595
# 4 :	 0.13944084537273194
# 18 :	 0.10174040888791569
# 23 :	 0.0771175477788185
# 12 :	 0.06333541154288638
# [(1157226.863, 11), (415307.0, 0), (415297.6061, 20), (415212.2893, 10), (375395.9168, 30), (375393.0191, 31)]
# Switches in the controller 4 : [0, 20, 31, 30, 11, 10]
# Switch selected is : 11
# The underloaded domains are : [27, 23, 12]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 26, 25]
# The mean load ratio is : 0.0904229329240777
# The reward is = 0.7863664811749701
# Q value = 54.62531446911118
#
# At time step 4928 the number of switch migrated are : 2
# The migrated switches are [8, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4929
# 0.1841708394726137
# The overloaded domains are : [18, 27, 12, 4]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.13075975766984138
# 4 :	 0.09650576321698394
# 18 :	 0.08769827553351389
# 23 :	 0.07678218572744695
# 12 :	 0.10546412882169315
# [(1270205.39, 11), (417154.3718, 25), (417142.5296, 26), (415312.2194, 21), (415305.7304, 22), (11982.23479, 16), (4765.645025, 33), (4737.737206, 32), (880.5062337000002, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 26, 25, 11]
# Switch selected is : 11
# The underloaded domains are : [4, 18, 23]
# The target controller set for 23 is : [14, 15, 19, 5, 7, 29]
# The mean load ratio is : 0.09944202219389586
# The reward is = 0.44466694041182453
# Q value = 53.92328959441255
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07459998936675055
# 4 :	 0.09650576321698394
# 18 :	 0.08769827553351389
# 23 :	 0.13294195403053777
# 12 :	 0.10546412882169315
# [(1120955.3490000002, 1), (431940.19200000004, 3), (417154.6093, 28), (415307.0, 6)]
# Switches in the controller 12 : [6, 28, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 18]
# The target controller set for 18 is : [17, 24, 2, 9, 8]
# The mean load ratio is : 0.09944202219389586
# The reward is = 0.296785528761387
# Q value = 49.654717655626804
#
# At time step 4929 the number of switch migrated are : 2
# The migrated switches are [11, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4930
# 0.29487258934463273
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08886886147576141
# 4 :	 0.11011469881963615
# 18 :	 0.14385927682585034
# 23 :	 0.1233706657945903
# 12 :	 0.05420511084584591
# [(581200.6346, 31), (581197.9118, 30), (497531.0553, 10), (415307.0, 0), (415305.7952, 20)]
# Switches in the controller 4 : [0, 20, 31, 30, 10]
# Switch selected is : 31
# The underloaded domains are : [27, 12]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 26, 25]
# The mean load ratio is : 0.10408372275233682
# The reward is = 0.7333686523591515
# Q value = 44.937928608713236
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.11456556630295897
# 4 :	 0.0844179939924386
# 18 :	 0.14385927682585034
# 23 :	 0.1233706657945903
# 12 :	 0.05420511084584591
# [(833957.848, 11), (581205.4724, 29), (581198.5332, 7), (415315.544, 19), (366997.0006, 5), (6993.318243000001, 14), (4694.305965, 15)]
# Switches in the controller 23 : [14, 15, 19, 5, 7, 29, 11]
# Switch selected is : 11
# The underloaded domains are : [4, 12]
# The target controller set for 4 is : [0, 20, 30, 10]
# The mean load ratio is : 0.10408372275233682
# The reward is = 1.4931157210807064
# Q value = 56.41052101247909
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.11456556630295897
# 4 :	 0.12128988879539188
# 18 :	 0.14385927682585034
# 23 :	 0.08649877099163703
# 12 :	 0.05420511084584591
# [(581200.6346, 31), (581198.9973, 25), (581195.7948, 26), (415309.7909, 21), (415304.5256, 22), (5764.988541, 13), (4767.513638, 33), (4751.378742, 32), (1717.205686, 16)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 26, 25, 31]
# Switch selected is : 31
# The underloaded domains are : [23, 12]
# The target controller set for 23 is : [14, 15, 19, 5, 7, 29]
# The mean load ratio is : 0.10408372275233682
# The reward is = 0.9577250085696983
# Q value = 45.83636966814805
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08886886147576142
# 4 :	 0.12128988879539188
# 18 :	 0.14385927682585034
# 23 :	 0.11219547581883457
# 12 :	 0.05420511084584591
# [(1131895.966, 1), (722895.8714, 9), (529105.9285, 8), (451534.84, 2), (415310.3744, 24), (3024.518161, 17)]
# Switches in the controller 18 : [17, 24, 2, 9, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 28, 3]
# The mean load ratio is : 0.10408372275233682
# The reward is = 2.108938047895349
# Q value = 38.287693467190536
#
# At time step 4930 the number of switch migrated are : 4
# The migrated switches are [31, 11, 31, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4931
# 0.19681445453170035
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.10861169154393549
# 4 :	 0.11410851674723152
# 18 :	 0.08423247268876745
# 23 :	 0.14498697842667432
# 12 :	 0.0904131963213124
# [(800622.4975, 25), (800619.3826, 26), (415308.8092, 21), (415300.1207, 22), (10441.767909999999, 16), (4772.504713, 32), (4764.760541, 33), (4717.970060000001, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 26, 25]
# Switch selected is : 25
# The underloaded domains are : [18, 12]
# The target controller set for 18 is : [17, 24, 2, 9, 8]
# The mean load ratio is : 0.10847057114558423
# The reward is = 0.46162394649620925
# Q value = 45.58616197998344
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.07321365724820485
# 4 :	 0.11410851674723152
# 18 :	 0.11963050698449809
# 23 :	 0.14498697842667432
# 12 :	 0.0904131963213124
# [(800617.792, 30), (666906.6054, 10), (415308.7088, 20), (415307.0, 0), (282733.309, 11)]
# Switches in the controller 4 : [0, 20, 30, 10, 11]
# Switch selected is : 30
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 28, 3, 1]
# The mean load ratio is : 0.10847057114558423
# The reward is = 0.723709381142299
# Q value = 39.37583494907302
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07321365724820485
# 4 :	 0.07871069049642954
# 18 :	 0.11963050698449809
# 23 :	 0.14498697842667432
# 12 :	 0.12581102257211438
# [(800621.0335, 28), (800617.792, 30), (722554.3835, 1), (415307.0, 6), (106457.0969, 3)]
# Switches in the controller 12 : [6, 28, 3, 1, 30]
# Switch selected is : 28
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 20, 10, 11]
# The mean load ratio is : 0.10847057114558423
# The reward is = 1.0789009992085787
# Q value = 51.49690010646882
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07321365724820485
# 4 :	 0.11410866006412372
# 18 :	 0.11963050698449809
# 23 :	 0.14498697842667432
# 12 :	 0.0904130530044202
# [(800621.0318, 29), (800617.7411, 7), (800611.8279, 31), (445370.0906, 5), (415308.5906, 19), (9874.322065999999, 14), (6869.922909000001, 15)]
# Switches in the controller 23 : [14, 15, 19, 5, 7, 29, 31]
# Switch selected is : 29
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 3, 1, 30]
# The mean load ratio is : 0.10847057114558423
# The reward is = 2.073021070320417
# Q value = 45.2346493801951
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.07321365724820485
# 4 :	 0.11410866006412372
# 18 :	 0.11963050698449809
# 23 :	 0.10958900893414247
# 12 :	 0.12581102249695203
# [(800617.7411, 7), (800611.8279, 31), (445370.0906, 5), (415308.5906, 19), (9874.322065999999, 14), (6869.922909000001, 15)]
# Switches in the controller 23 : [14, 15, 19, 5, 7, 31]
# Switch selected is : 7
# The underloaded domains are : [27]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 26]
# The mean load ratio is : 0.10847057114558423
# The reward is = 0.5900997239491843
# Q value = 28.59691134770423
#
# At time step 4931 the number of switch migrated are : 5
# The migrated switches are [25, 30, 28, 29, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4932
# 0.26065626648978485
# The overloaded domains are : [18, 27, 12, 4]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.07603220683940548
# 4 :	 0.1361536018125826
# 18 :	 0.1220996396510099
# 23 :	 0.0681153440983168
# 12 :	 0.12123969716383133
# [(645075.3977, 9), (644213.2606, 8), (616918.4549, 2), (433613.3268, 25), (415298.4398, 24), (6495.441056000001, 17)]
# Switches in the controller 18 : [17, 24, 2, 9, 8, 25]
# Switch selected is : 9
# The underloaded domains are : [27, 23]
# The target controller set for 23 is : [14, 15, 19, 5, 31]
# The mean load ratio is : 0.10472809791302921
# The reward is = 10.36936898921438
# Q value = 55.52421879254493
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.07603220683940548
# 4 :	 0.1361536018125826
# 18 :	 0.09357883100221635
# 23 :	 0.09663615274711033
# 12 :	 0.12123969716383133
# [(1220474.405, 11), (594781.2805, 10), (433613.2849, 28), (415307.0, 0), (415306.8002, 20)]
# Switches in the controller 4 : [0, 20, 10, 11, 28]
# Switch selected is : 11
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 2, 8, 25]
# The mean load ratio is : 0.10472809791302921
# The reward is = 0.7031128887104976
# Q value = 53.519856238806824
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.07603220683940548
# 4 :	 0.08219259649465316
# 18 :	 0.14753983632014578
# 23 :	 0.09663615274711033
# 12 :	 0.12123969716383133
# [(998923.8047, 3), (460711.5649, 1), (433622.3126, 29), (433599.7083, 30), (415307.0, 6)]
# Switches in the controller 12 : [6, 3, 1, 30, 29]
# Switch selected is : 3
# The underloaded domains are : [27, 4, 23]
# The target controller set for 4 is : [0, 20, 10, 28]
# The mean load ratio is : 0.10472809791302921
# The reward is = 0.6879590163593514
# Q value = 43.489875072702006
#
# At time step 4932 the number of switch migrated are : 3
# The migrated switches are [9, 11, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4933
# 0.10462178375384881
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.0993262552816147
# 4 :	 0.09620725540146631
# 18 :	 0.0947817700510237
# 23 :	 0.09603800784855598
# 12 :	 0.12296709543122607
# [(967864.9672, 1), (699034.7302, 29), (699027.4873, 30), (415307.0, 6)]
# Switches in the controller 12 : [6, 1, 30, 29]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 18, 23]
# The target controller set for 18 is : [17, 24, 2, 8, 25, 11]
# The mean load ratio is : 0.10186407680277736
# The reward is = 0.47419696376078146
# Q value = 43.46657713337606
#
# At time step 4933 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4934
# 0.34460206744238764
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.10195928126873455
# 4 :	 0.1085173015167374
# 18 :	 0.20226051808124657
# 23 :	 0.11017529129381845
# 12 :	 0.08265157244751525
# [(1605347.5480000002, 11), (926962.4646, 1), (727040.2397, 25), (479065.9269, 8), (415677.9255, 2), (415313.4615, 24), (5262.30894, 17)]
# Switches in the controller 18 : [17, 24, 2, 8, 25, 11, 1]
# Switch selected is : 11
# The underloaded domains are : [27, 4, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 5, 31, 9]
# The mean load ratio is : 0.12111279292161044
# The reward is = 1.0441741521278922
# Q value = 46.52861083353592
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.10195928126873455
# 4 :	 0.1085173015167374
# 18 :	 0.13128306274103974
# 23 :	 0.18115274663402525
# 12 :	 0.08265157244751525
# [(926962.4646, 1), (727040.2397, 25), (479065.9269, 8), (415677.9255, 2), (415313.4615, 24), (5262.30894, 17)]
# Switches in the controller 18 : [17, 24, 2, 8, 25, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 4, 12]
# The target controller set for 4 is : [0, 20, 10, 28, 3]
# The mean load ratio is : 0.12111279292161044
# The reward is = 0.6750899120456255
# Q value = 43.22761160573055
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.10195928126873455
# 4 :	 0.14950122242231476
# 18 :	 0.0902991418354624
# 23 :	 0.18115274663402525
# 12 :	 0.08265157244751525
# [(1605347.5480000002, 11), (727039.9982, 31), (674031.3789, 9), (668618.3253, 5), (415306.1948, 19), (4087.494393, 15), (2829.468356, 14)]
# Switches in the controller 23 : [14, 15, 19, 5, 31, 9, 11]
# Switch selected is : 11
# The underloaded domains are : [27, 18, 12]
# The target controller set for 12 is : [6, 30, 29]
# The mean load ratio is : 0.12111279292161044
# The reward is = 1.2141847415977725
# Q value = 37.08811812757155
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10195928126873455
# 4 :	 0.14950122242231476
# 18 :	 0.0902991418354624
# 23 :	 0.11017529129381844
# 12 :	 0.15362902778772208
# [(926962.4646, 1), (727055.1762, 28), (554836.6847, 10), (415311.0168, 20), (415307.0, 0), (341903.0492, 3)]
# Switches in the controller 4 : [0, 20, 10, 28, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18, 23]
# The target controller set for 18 is : [17, 24, 2, 8, 25]
# The mean load ratio is : 0.12111279292161044
# The reward is = 1.7555629694311268
# Q value = 42.003296827266496
#
# At time step 4934 the number of switch migrated are : 4
# The migrated switches are [11, 1, 11, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4935
# 0.32135740949439867
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.07531242047877669
# 4 :	 0.12922228817599024
# 18 :	 0.15370638010584975
# 23 :	 0.08312759527668856
# 12 :	 0.07124692434140842
# ...
# Q value = 13.300160884560253
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.1124582362369127
# 4 :	 0.080642260630296
# 18 :	 0.09383104218674795
# 23 :	 0.11336750196917808
# 12 :	 0.12714699270451513
# [(712518.4363, 30), (712509.9492, 28), (610871.0334, 8), (424567.4729, 1), (415307.0, 6)]
# Switches in the controller 12 : [6, 28, 8, 1, 30]
# Switch selected is : 30
# The underloaded domains are : [4, 18]
# The target controller set for 4 is : [0, 9, 3, 2]
# The mean load ratio is : 0.10548920674552997
# The reward is = 2.0988022038340497
# Q value = 14.323240258354998
#
# At time step 4992 the number of switch migrated are : 4
# The migrated switches are [30, 31, 5, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4993
# 0.16572518141247214
# The overloaded domains are : [27, 4, 12, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11783429378964864
# 4 :	 0.14176833820788806
# 18 :	 0.08576960640572168
# 23 :	 0.12972093856039132
# 12 :	 0.13920988201046247
# [(836929.8807, 30), (823014.6358, 3), (683243.5313, 2), (447980.206, 9), (415307.0, 0)]
# Switches in the controller 4 : [0, 9, 3, 2, 30]
# Switch selected is : 30
# The underloaded domains are : [27, 18]
# The target controller set for 18 is : [17, 24, 11, 10, 26]
# The mean load ratio is : 0.12286061179482244
# The reward is = 3.158869226529706
# Q value = 14.915239796771482
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.11783429378964864
# 4 :	 0.10476504050809995
# 18 :	 0.12277290410550978
# 23 :	 0.12972093856039132
# 12 :	 0.13920988201046247
# [(836938.0985, 31), (836930.7028, 29), (836924.0804, 25), (415311.7168, 19), (3947.013662, 14), (3939.042251, 15)]
# Switches in the controller 23 : [14, 15, 19, 25, 29, 31]
# Switch selected is : 31
# The underloaded domains are : [27, 4, 18]
# The target controller set for 4 is : [0, 9, 3, 2]
# The mean load ratio is : 0.12286061179482244
# The reward is = 0.9560822494709115
# Q value = 15.299112601402115
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.11783429378964864
# 4 :	 0.14176870154262713
# 18 :	 0.12277290410550978
# 23 :	 0.09271727752586414
# 12 :	 0.13920988201046247
# [(1149186.1409999998, 1), (836941.6639, 28), (747174.0269, 8), (415307.0, 6)]
# Switches in the controller 12 : [6, 28, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18, 23]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 7, 20, 5]
# The mean load ratio is : 0.12286061179482244
# The reward is = 0.533889236873839
# Q value = 13.04516520199042
#
# At time step 4993 the number of switch migrated are : 3
# The migrated switches are [30, 31, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4994
# 0.25460368158738983
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.15875677963733179
# 4 :	 0.12692984475021285
# 18 :	 0.12006306192534515
# 23 :	 0.08622366507359897
# 12 :	 0.07872891584232176
# [(865677.2747, 1), (763216.1657, 7), (703998.5524, 5), (415308.5289, 22), (415305.8196, 20), (415303.0713, 21), (4766.313641, 32), (4761.623721, 33), (1662.5318220000001, 16), (715.0247674, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 7, 20, 5, 1]
# Switch selected is : 1
# The underloaded domains are : [23, 12]
# The target controller set for 23 is : [14, 15, 19, 25, 29]
# The mean load ratio is : 0.11414045344576211
# The reward is = 6.77873471113465
# Q value = 16.30000193771637
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.12048246939180282
# 4 :	 0.12692984475021285
# 18 :	 0.12006306192534515
# 23 :	 0.12449797531912793
# 12 :	 0.07872891584232176
# [(763216.1657, 7), (703998.5524, 5), (415308.5289, 22), (415305.8196, 20), (415303.0713, 21), (4766.313641, 32), (4761.623721, 33), (1662.5318220000001, 16), (715.0247674, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 7, 20, 5]
# Switch selected is : 7
# The underloaded domains are : [12]
# The target controller set for 12 is : [6, 28, 8]
# The mean load ratio is : 0.11414045344576211
# The reward is = 1.5481860363096973
# Q value = 9.748906251734793
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.08673828646805898
# 4 :	 0.12692984475021285
# 18 :	 0.12006306192534515
# 23 :	 0.12449797531912793
# 12 :	 0.1124730987660656
# [(824510.0766, 9), (763219.705, 31), (596654.6013, 2), (415307.0, 0), (271171.1193, 3)]
# Switches in the controller 4 : [0, 9, 3, 2, 31]
# Switch selected is : 9
# The underloaded domains are : [27, 12]
# The target controller set for 12 is : [6, 28, 8, 7]
# The mean load ratio is : 0.11414045344576211
# The reward is = 0.5119682201552987
# Q value = 12.515563802930679
#
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.08673828646805898
# 4 :	 0.09047566558362966
# 18 :	 0.12006306192534515
# 23 :	 0.12449797531912793
# 12 :	 0.1489272779326488
# [(763233.4702, 30), (763215.1939, 26), (415317.1748, 24), (406407.07899999997, 10), (361956.0521, 11), (5422.625128, 17)]
# Switches in the controller 18 : [17, 24, 11, 10, 26, 30]
# Switch selected is : 30
# The underloaded domains are : [27, 4]
# The target controller set for 4 is : [0, 3, 2, 31]
# The mean load ratio is : 0.11414045344576211
# The reward is = 1.388686295731223
# Q value = 14.269587100385749
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.08673828646805898
# 4 :	 0.12422061359364871
# 18 :	 0.0863181139153261
# 23 :	 0.12449797531912793
# 12 :	 0.1489272779326488
# [(865677.2747, 1), (763223.9805, 25), (763220.8605, 29), (415310.9332, 19), (5077.412606, 14), (3348.721548, 15)]
# Switches in the controller 23 : [14, 15, 19, 25, 29, 1]
# Switch selected is : 1
# The underloaded domains are : [27, 18]
# Taking a random action
# The target controller set for 18 is : [17, 24, 11, 10, 26]
# The mean load ratio is : 0.11414045344576211
# The reward is = 0.7849246338110939
# Q value = 12.066494980653598
#
# At time step 4994 the number of switch migrated are : 5
# The migrated switches are [1, 7, 9, 30, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4995
# 0.23058237231024462
# The overloaded domains are : [18, 4, 12, 23]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.07308414744389609
# 4 :	 0.13122315825465766
# 18 :	 0.11718479383197027
# 23 :	 0.0823365408370088
# 12 :	 0.13144831247019265
# [(717031.0274, 26), (608319.0826, 11), (480610.0379, 1), (422177.7956, 10), (415309.1332, 24), (7004.683501, 17)]
# Switches in the controller 18 : [17, 24, 11, 10, 26, 1]
# Switch selected is : 26
# The underloaded domains are : [27, 23]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 20, 5]
# The mean load ratio is : 0.1070553905675451
# The reward is = 1.6427640965688015
# Q value = 13.777171589618073
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.10478634039783338
# 4 :	 0.13122315825465766
# 18 :	 0.08548260087803297
# 23 :	 0.0823365408370088
# 12 :	 0.13144831247019265
# [(717041.0325, 30), (717025.5463, 31), (687182.5244, 2), (431411.3216, 3), (415307.0, 0)]
# Switches in the controller 4 : [0, 3, 2, 31, 30]
# Switch selected is : 30
# The underloaded domains are : [27, 18, 23]
# The target controller set for 23 is : [14, 15, 19, 25, 29]
# The mean load ratio is : 0.1070553905675451
# The reward is = 4.903110871489865
# Q value = 16.20865532223776
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.10478634039783338
# 4 :	 0.09952052294383677
# 18 :	 0.08548260087803297
# 23 :	 0.11403917614782969
# 12 :	 0.13144831247019265
# [(717030.4365, 7), (717017.5329, 28), (578967.3645, 8), (544737.5638, 9), (415307.0, 6)]
# Switches in the controller 12 : [6, 28, 8, 7, 9]
# Switch selected is : 7
# The underloaded domains are : [27, 4, 18]
# The target controller set for 4 is : [0, 3, 2, 31]
# The mean load ratio is : 0.1070553905675451
# The reward is = 1.4675615878093682
# Q value = 13.417468291367479
#
# At time step 4995 the number of switch migrated are : 3
# The migrated switches are [26, 30, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4996
# 0.1847252363210534
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11379107107953641
# 4 :	 0.15412164832608471
# 18 :	 0.10310096342969595
# 23 :	 0.12518111036368854
# 12 :	 0.09051579286767689
# [(1054805.5990000002, 3), (801130.4040000001, 31), (801127.5991, 7), (415307.0, 0), (413508.2456, 2)]
# Switches in the controller 4 : [0, 3, 2, 31, 7]
# Switch selected is : 3
# The underloaded domains are : [27, 18, 12]
# The target controller set for 18 is : [17, 24, 11, 10, 1]
# The mean load ratio is : 0.1173421172133365
# The reward is = 1.5219606599042288
# Q value = 13.112616119029187
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.11379107107953641
# 4 :	 0.10748538106489561
# 18 :	 0.14973723069088507
# 23 :	 0.12518111036368854
# 12 :	 0.09051579286767689
# [(801133.6825, 25), (801124.5782, 29), (801118.4559, 30), (415303.7647, 19), (8363.147937, 15), (4266.504594, 14)]
# Switches in the controller 23 : [14, 15, 19, 25, 29, 30]
# Switch selected is : 25
# The underloaded domains are : [27, 4, 12]
# The target controller set for 4 is : [0, 2, 31, 7]
# The mean load ratio is : 0.1173421172133365
# The reward is = 0.8755823534698564
# Q value = 13.452629687982618
#
# At time step 4996 the number of switch migrated are : 2
# The migrated switches are [3, 25]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4997
# 0.1823487757787636
# The overloaded domains are : [18, 27, 4, 12]
# Balance the overloaded controller : 18
# Controller	Controller Load Ratio
# 27 :	 0.11523666938088349
# 4 :	 0.14536054519713235
# 18 :	 0.13043905100222367
# 23 :	 0.08140329368181141
# 12 :	 0.11250078017951702
# [(846951.6744, 1), (606261.7416, 11), (588612.7718, 3), (486163.6793, 10), (415302.6236, 24), (6940.2231409999995, 17)]
# Switches in the controller 18 : [17, 24, 11, 10, 1, 3]
# Switch selected is : 1
# The underloaded domains are : [27, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 29, 30]
# The mean load ratio is : 0.11698806788831359
# The reward is = 1.1704048929441677
# Q value = 12.90951884749409
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11523666938088349
# 4 :	 0.14536054519713235
# 18 :	 0.09299265833794845
# 23 :	 0.11884968634608661
# 12 :	 0.11250078017951702
# [(753491.4341, 2), (706311.8477, 31), (706307.7423, 25), (706304.728, 7), (415307.0, 0)]
# Switches in the controller 4 : [0, 2, 31, 7, 25]
# Switch selected is : 2
# The underloaded domains are : [27, 18, 12]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 20, 5, 26]
# The mean load ratio is : 0.11698806788831359
# The reward is = 0.7138756255409392
# Q value = 12.59439054298954
#
# At time step 4997 the number of switch migrated are : 2
# The migrated switches are [1, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# 0.15205836893657795
# The overloaded domains are : [18, 27, 4, 23]
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 27 :	 0.11584043778899342
# 4 :	 0.1001704783183412
# 18 :	 0.07922618467748144
# 23 :	 0.09172998900739275
# 12 :	 0.07770090183359185
# [(616775.6388, 7), (616773.8028, 31), (616770.4533, 25), (415307.0, 0)]
# Switches in the controller 4 : [0, 31, 7, 25]
# Switch selected is : 7
# The underloaded domains are : [18, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 29, 30, 1]
# The mean load ratio is : 0.09293359832516013
# The reward is = 2.0814093159232767
# Q value = 14.003065721245175
#
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.11584043778899342
# 4 :	 0.07290089086209615
# 18 :	 0.07922618467748144
# 23 :	 0.11899957646363779
# 12 :	 0.07770090183359185
# [(616781.5335, 29), (616777.8332, 30), (616775.6388, 7), (415306.8103, 19), (412022.3846, 1), (9094.362637999999, 15), (4739.42563, 14)]
# Switches in the controller 23 : [14, 15, 19, 29, 30, 1, 7]
# Switch selected is : 29
# The underloaded domains are : [4, 18, 12]
# The target controller set for 4 is : [0, 31, 25]
# The mean load ratio is : 0.09293359832516013
# The reward is = 5.68357502997462
# Q value = 14.672484496100793
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.11584043778899342
# 4 :	 0.10017073894153554
# 18 :	 0.07922618467748144
# 23 :	 0.0917297283841984
# 12 :	 0.07770090183359185
# [(616781.0317, 26), (467519.1601, 5), (415308.8862, 22), (415307.2731, 21), (415303.1656, 20), (269557.4193, 2), (7501.722229000001, 16), (4762.189124, 32), (4762.119076, 33), (3242.537773, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 20, 5, 26, 2]
# Switch selected is : 26
# The underloaded domains are : [18, 23, 12]
# The target controller set for 23 is : [14, 15, 19, 30, 1, 7]
# The mean load ratio is : 0.09293359832516013
# The reward is = 0.6821471596643495
# Q value = 13.200047073681263
#
# At time step 4998 the number of switch migrated are : 3
# The migrated switches are [7, 29, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# 0.14432462464031584
# The overloaded domains are : [27, 12, 4, 23]
# Balance the overloaded controller : 23
# Controller	Controller Load Ratio
# 27 :	 0.0970600679974525
# 4 :	 0.07103196662646118
# 18 :	 0.06577746388273255
# 23 :	 0.09025136175942262
# 12 :	 0.08716263986502659
# [(419910.916, 1), (415306.4295, 19), (397085.7393, 7), (397083.2936, 30), (397074.2271, 26), (8779.092471, 14), (6039.488634, 15)]
# Switches in the controller 23 : [14, 15, 19, 30, 1, 7, 26]
# Switch selected is : 1
# The underloaded domains are : [4, 18]
# The target controller set for 4 is : [0, 31, 25, 29]
# The mean load ratio is : 0.08225670002621908
# The reward is = 1.8008647396260156
# Q value = 12.8308002451389
#
# Balance the overloaded controller : 27
# Controller	Controller Load Ratio
# 27 :	 0.0970600679974525
# 4 :	 0.08959754659971152
# 18 :	 0.06577746388273255
# 23 :	 0.07168578178617228
# 12 :	 0.08716263986502659
# [(701425.0498, 5), (415309.1085, 22), (415305.0979, 21), (415304.0426, 20), (233352.3143, 2), (4776.966685, 32), (4775.167539, 33), (3299.148937, 16), (1729.6379789999999, 13)]
# Switches in the controller 27 : [33, 16, 32, 13, 22, 21, 20, 5, 2]
# Switch selected is : 5
# The underloaded domains are : [18, 23]
# The target controller set for 18 is : [17, 24, 11, 10, 3]
# The mean load ratio is : 0.08225670002621908
# The reward is = 0.662117681048614
# Q value = 12.005243727305754
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 27 :	 0.06604786431065193
# 4 :	 0.08959754659971152
# 18 :	 0.09678966756953311
# 23 :	 0.07168578178617228
# 12 :	 0.08716263986502659
# [(590599.7209, 9), (568425.2573, 8), (415307.0, 6), (397087.3903, 28)]
# Switches in the controller 12 : [6, 28, 8, 9]
# Switch selected is : 9
# The underloaded domains are : [27, 23]
# The target controller set for 27 is : [33, 16, 32, 13, 22, 21, 20, 2]
# The mean load ratio is : 0.08225670002621908
# The reward is = 0.703548167832554
# Q value = 12.141518879022899
#
# At time step 4999 the number of switch migrated are : 3
# The migrated switches are [1, 5, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[ 1.         15.47934261 12.00524373 13.20004707  9.74890625]
#  [12.59439054  1.         13.11261612 14.00306572 12.5155638 ]
#  [13.77717159 14.2695871   1.         12.90951885 13.99527613]
#  [14.9303762  12.83080025 12.06649498  1.         12.97857408]
#  [12.14151888 13.41746829 13.65279657  7.56515669  1.        ]]

# %% [markdown]
# # **Results**

# %%
import matplotlib.pyplot as plt

'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(4000, 5000, 100):
    x.append(time_steps_list_rn[i])

    yrandom.append(discrete_coeff_list_rn[i])
    yQL.append(discrete_coeff_list_QL[i])
    yGreedy.append(discrete_coeff_list_gr[i])

plt.plot(x, yrandom, label='Random Selection')
plt.plot(x, yQL, label='Q-Learning')
plt.plot(x, yGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

x = []

for i in range(4500, 5000, 10):
    x.append(time_steps_list_rn[i])

    zrandom.append(number_of_switches_list_rn[i])
    zQL.append(number_of_switches_list_QL[i])
    zGreedy.append(number_of_switches_list_gr[i])

plt.plot(x, zrandom, label='Random Selection')
plt.plot(x, zQL, label='Q-Learning')
plt.plot(x, zGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Number of switches migrated')
plt.legend()
plt.show()
