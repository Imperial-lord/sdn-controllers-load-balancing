# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
    

# 1,2,3..31 .. (32 -> 33)
# Out:
# Enter the number of controllers to allocate: 10
# Graph with 34 nodes and 46 edges
#
# Controllers:
# [20, 7, 31, 9, 25, 32, 28, 8, 29, 4]
#
# Cluster set for each controller:
# [[6, 20], [0, 3, 7, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12, 31], [9, 19], [24, 25], [32, 33], [26, 27, 28], [5, 8], [1, 13, 29], [4, 15, 22]]
#
# Cluster map for each controller:
# {20: [6], 7: [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], 31: [2, 11, 12], 9: [19], 25: [24], 32: [33], 28: [26, 27], 8: [5], 29: [1, 13], 4: [15, 22]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1):
4, (8, 11): 5, (8, 12): 6, (8, 13): 7, (8, 14): 4, (8, 15): 3, (8, 16): 5, (8, 17): 3, (8, 18): 5, (8, 19): 2, (8, 20): 4, (8, 21): 4, (8, 22): 5, (8, 23): 4, (8, 24): 7, (8, 25): 6, (8, 26): 7, (8, 27): 7, (8, 28): 6, (8, 29): 5, (8, 30): 4, (8, 31): 6, (8, 32): 7, (8, 33): 8, (9, 0): 2, (9, 1): 4, (9, 2): 3, (9, 3): 2, (9, 4): 3, (9, 5): 2, (9, 6): 3, (9, 7): 1, (9, 8): 1, (9, 9): 0, (9, 10): 3, (9, 11): 3, (9, 12): 4, (9, 13): 5, (9, 14): 3, (9, 15): 4, (9, 16): 4, (9, 17): 2, (9, 18): 4, (9, 19): 1, (9, 20): 2, (9, 21): 2, (9, 22): 4, (9, 23): 3, (9, 24): 5, (9, 25): 4, (9, 26): 5, (9, 27): 5, (9, 28): 4, (9, 29): 3, (9, 30): 2, (9, 31): 4, (9, 32): 5, (9,  ...
# [[6, 20], [0, 3, 7, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12, 31], [9, 19], [24, 25], [32, 33], [26, 27, 28], [5, 8], [1, 13, 29], [4, 15, 22]]
# [[6, 20], [0, 3, 7, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12, 31], [9, 19], [24, 25], [32, 33], [26, 27, 28], [5, 8], [1, 13, 29], [4, 15, 22]]

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions** regarding the last cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool?

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions** regarding the last cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# At time step : 0
# {20: {6: 651680.0}, 7: {0: 651680.0, 3: 879667.411, 10: 155411.33163333332, 14: 3415.2884314999997, 16: 532.7325236666667, 17: 2335.0742396666665, 18: 651679.2055, 21: 651681.2606, 23: 651682.7399, 30: 379224.8684}, 31: {2: 670298.7742, 11: 11243.927945, 12: 2408.6666666666665}, 9: {19: 651682.2874}, 25: {24: 651675.918}, 32: {33: 7212.752546}, 28: {26: 189608.58285, 27: 379223.0564}, 8: {5: 476537.778}, 29: {1: 195199.22405, 13: 634.6565896000001}, 4: {15: 6506.027056, 22: 325838.87195}}
# {(20, 25), (4, 8), (28, 29), (9, 8), (7, 25), (28, 8), (20, 29), (9, 29), (20, 8), (4, 31), (7, 29), (9, 25), (7, 20), (4, 9), (31, 8), (28, 9), (20, 9), (8, 29), (31, 25), (7, 28), (8, 25), (25, 29), (28, 31), (4, 28), (7, 32), (31, 29), (20, 31), (4, 25), (7, 31), (9, 31), (4, 20), (7, 9), (7, 8), (4, 29), (20, 28), (28, 25), (4, 32)}
# (20, 25, [6])
# [[6], [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [19], [24], [32, 33], [26, 27], [5], [1, 13, 29], [15, 22]]
# 6
# (4, 8, [22])
# [[], [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [19], [24, 6], [32, 33], [26, 27], [5], [1, 13, 29], [15, 22]]
# 22
# (28, 29, [27])
# [[], [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [19], [24, 6], [32, 33], [26, 27], [5, 22], [1, 13, 29], [15]]
# 27
# (9, 8, [19])
# [[], [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [19], [24, 6], [32, 33], [26], [5, 22], [1, 13, 29, 27], [15]]
# 19
# (7, 25, [3])
# [[], [0, 3, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 3
# (28, 8, [27])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 27
# (20, 29, [6])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 6
# (9, 29, [19])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 19
# (20, 8, [6])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 6
# (4, 31, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 22
# (7, 29, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 3
# (9, 25, [19])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 19
# (7, 20, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 3
# (4, 9, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 22
# (31, 8, [2])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [2, 11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19], [1, 13, 29, 27], [15]]
# 2
# (28, 9, [27])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19, 2], [1, 13, 29, 27], [15]]
# 27
# (20, 9, [6])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19, 2], [1, 13, 29, 27], [15]]
# 6
# (8, 29, [5])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [5, 22, 19, 2], [1, 13, 29, 27], [15]]
# 5
# (31, 25, [2])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5], [15]]
# 2
# (7, 28, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5], [15]]
# 3
# (8, 25, [5])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5], [15]]
# 5
# (25, 29, [24])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [24, 6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5], [15]]
# 24
# (28, 31, [27])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 27
# (4, 28, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 22
# (7, 32, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 3
# (31, 29, [2])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 2
# (20, 31, [6])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 6
# (4, 25, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 22
# (7, 31, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 3
# (9, 31, [19])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 19
# (4, 20, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 22
# (7, 9, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 3
# (7, 8, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 3
# (4, 29, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 22
# (20, 28, [6])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 6
# (28, 25, [27])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 27
# (4, 32, [22])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [32, 33], [26], [22, 19, 2], [1, 13, 29, 27, 5, 24], [15]]
# 22
# At time step 0 the number of switch migrated are : 37
# The migrated switches are [6, 22, 27, 19, 3, 27, 6, 19, 6, 22, 3, 19, 3, 22, 2, 27, 6, 5, 2, 3, 5, 24, 27, 22, 3, 2, 6, 22, 3, 19, 22, 3, 3, 22, 6, 27, 22]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 1
# {20: {}, 7: {0: 459151.0, 10: 235964.41446666667, 14: 3621.5696729999995, 16: 723.5105963333334, 17: 1718.7642223333335, 18: 459147.0752, 21: 459152.1942, 23: 459147.7435, 30: 460757.1225}, 31: {11: 200360.10655, 12: 1999.6666666666667}, 9: {}, 25: {6: 91830.2, 3: 364864.10115}, 32: {33: 6008.160882}, 28: {26: 230380.52895}, 8: {22: 91830.36496, 19: 229576.81825, 2: 128468.50252000001}, 29: {1: 381883.7, 13: 3249.884814, 27: 230385.94845, 5: 121488.4075, 24: 153052.82553333332}, 4: {15: 8695.587017}}
# {(29, 28), (28, 4), (25, 31), (31, 9), (29, 9), (8, 9), (25, 32), (8, 28), (32, 9), (29, 4), (31, 32), (7, 20), (4, 9), (25, 4), (32, 20), (29, 31), (28, 9), (8, 32), (8, 20), (7, 28), (28, 31), (7, 32), (31, 4), (28, 20), (7, 31), (28, 32), (32, 4), (4, 20), (25, 28), (7, 9), (29, 20), (8, 31), (29, 32), (7, 4), (25, 20), (31, 20), (25, 9), (8, 4)}
# (29, 28, [1])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [33], [26], [22, 19, 2], [1, 13, 27, 5, 24], [15]]
# 1
# (28, 4, [26])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [33], [26, 1], [22, 19, 2], [13, 27, 5, 24], [15]]
# 26
# (25, 31, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12], [], [6, 3], [33], [1], [22, 19, 2], [13, 27, 5, 24], [15, 26]]
# 3
# (31, 9, [11])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [11, 12, 3], [], [6], [33], [1], [22, 19, 2], [13, 27, 5, 24], [15, 26]]
# 11
# (29, 9, [1])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11], [6], [33], [1], [22, 19, 2], [13, 27, 5, 24], [15, 26]]
# 1
# (8, 9, [19])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11], [6], [33], [1], [22, 19, 2], [13, 27, 5, 24], [15, 26]]
# 19
# (25, 32, [3])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19], [6], [33], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 3
# (8, 28, [19])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19], [6], [33], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 19
# (32, 9, [33])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19], [6], [33], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 33
# (29, 4, [1])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19, 33], [6], [], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 1
# (31, 32, [11])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19, 33], [6], [], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 11
# (7, 20, [30])
# [[], [0, 10, 14, 16, 17, 18, 21, 23, 30], [12, 3], [11, 19, 33], [6], [], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 30
# (4, 9, [15])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33], [6], [], [1], [22, 2], [13, 27, 5, 24], [15, 26]]
# 15
# (25, 4, [3])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 3
# (32, 20, [33])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 33
# (29, 31, [1])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 1
# (28, 9, [26])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 26
# (8, 32, [19])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 19
# (8, 20, [19])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 19
# (7, 28, [30])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 30
# (28, 31, [26])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 26
# (7, 32, [30])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 30
# (31, 4, [11])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 11
# (28, 20, [26])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 26
# (7, 31, [30])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 30
# (28, 32, [26])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 26
# (32, 4, [33])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 33
# (4, 20, [15])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 15
# (25, 28, [3])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 3
# (7, 9, [30])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 30
# (29, 20, [1])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 1
# (8, 31, [19])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 19
# (29, 32, [1])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 1
# (7, 4, [30])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 30
# (25, 20, [3])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 3
# (31, 20, [11])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 11
# (25, 9, [3])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 3
# (8, 4, [19])
# [[30], [0, 10, 14, 16, 17, 18, 21, 23], [12, 3], [11, 19, 33, 15], [6], [], [1], [22, 2], [13, 27, 5, 24], [26]]
# 19
# At time step 1 the number of switch migrated are : 38
# The migrated switches are [1, 26, 3, 11, 1, 19, 3, 19, 33, 1, 11, 30, 15, 3, 33, 1, 26, 19, 19, 30, 26, 30, 11, 26, 30, 26, 33, 15, 3, 30, 1, 19, 1, 30, 3, 11, 3, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step :
[0, 10, 14, 16, 17, 23], [12, 3, 6], [11, 33, 15, 26, 24], [18, 21], [30], [], [22, 1, 27], [13, 5], [19, 2]]
# 2
# (7, 25, [23])
# [[], [0, 10, 14, 16, 17, 23], [12, 3, 6], [11, 33, 15, 26, 24], [18, 21], [30], [], [22, 1, 27], [13, 5], [19, 2]]
# 23
# (20, 29, [21])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26, 24], [18, 21, 23], [30], [], [22, 1, 27], [13, 5], [19, 2]]
# 21
# (9, 29, [24])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26, 24], [18, 21, 23], [30], [], [22, 1, 27], [13, 5], [19, 2]]
# 24
# (25, 32, [18])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [18, 21, 23], [30], [], [22, 1, 27], [13, 5, 24], [19, 2]]
# 18
# (9, 4, [24])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [21, 23], [30, 18], [], [22, 1, 27], [13, 5, 24], [19, 2]]
# 24
# (8, 28, [1])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [21, 23], [30, 18], [], [22, 1, 27], [13, 5, 24], [19, 2]]
# 1
# (8, 4, [1])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [21, 23], [30, 18], [1], [22, 27], [13, 5, 24], [19, 2]]
# 1
# (7, 29, [23])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [21, 23], [30, 18], [1], [22, 27], [13, 5, 24], [19, 2]]
# 23
# (31, 32, [3])
# [[], [0, 10, 14, 16, 17], [12, 3, 6], [11, 33, 15, 26], [21, 23], [30, 18], [1], [22, 27], [13, 5, 24], [19, 2]]
# 3
# (9, 25, [24])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 24
# (7, 20, [23])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 23
# (25, 4, [18])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 18
# (8, 32, [1])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 1
# (9, 28, [24])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 24
# (8, 20, [1])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 1
# (8, 29, [1])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 1
# (31, 25, [3])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 3
# (7, 28, [23])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 23
# (20, 4, [21])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 21
# (8, 25, [1])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 1
# (25, 29, [18])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 18
# (9, 32, [24])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 24
# (31, 29, [3])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 3
# (7, 32, [23])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 23
# (9, 20, [24])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 24
# (31, 4, [3])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 3
# (20, 32, [21])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 21
# (28, 20, [2])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 2
# (28, 32, [2])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 2
# (31, 28, [3])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 3
# (4, 29, [19])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24], [19, 2]]
# 19
# (29, 32, [5])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3], [1], [22, 27], [13, 5, 24, 19], [2]]
# 5
# (7, 4, [23])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3, 5], [1], [22, 27], [13, 24, 19], [2]]
# 23
# (31, 20, [3])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3, 5], [1], [22, 27], [13, 24, 19], [2]]
# 3
# (28, 25, [2])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3, 5], [1], [22, 27], [13, 24, 19], [2]]
# 2
# (4, 32, [19])
# [[], [0, 10, 14, 16, 17], [12, 6], [11, 33, 15, 26], [21, 23], [30, 18, 3, 5], [1], [22, 27], [13, 24, 19], [2]]
# 19
# At time step 4 the number of switch migrated are : 39
# The migrated switches are [2, 21, 2, 23, 21, 24, 18, 24, 1, 1, 23, 3, 24, 23, 18, 1, 24, 1, 1, 3, 23, 21, 1, 18, 24, 3, 23, 24, 3, 21, 2, 2, 3, 19, 5, 23, 3, 2, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 5
# {20: {}, 7: {0: 465275.0, 10: 203876.00163333336, 14: 3983.275093, 16: 1209.6264196666668, 17: 1462.2897556666667}, 31: {12: 2209.0, 6: 93055.0}, 9: {11: 209001.07393333336, 33: 1106.166902, 15: 1351.8373585000002, 26: 130403.38858}, 25: {21: 232637.9067, 23: 116318.258225}, 32: {30: 652011.7939, 18: 93054.12722, 3: 238489.04263333333, 5: 100954.05378333334}, 28: {1: 241918.19086666664}, 8: {22: 93054.89052, 27: 93143.55892857142}, 29: {13: 432.5232356000001, 24: 155088.64726666667, 19: 77545.08896666666}, 4: {2: 189952.3289}}

# [[], [12, 11, 21, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 30, 23], [18], [3], [24, 2], [], [22]]
# 2
# (25, 32, [30])
# [[], [12, 11, 21, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 30, 23], [18], [3], [24, 2], [], [22]]
# 30
# (9, 4, [2])
# [[], [12, 11, 21, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30], [3], [24, 2], [], [22]]
# 2
# (25, 8, [30])
# [[], [12, 11, 21, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30], [3], [24, 2], [], [22]]
# 30
# (7, 29, [21])
# [[], [12, 11, 21, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30], [3], [24, 2], [], [22]]
# 21
# (31, 32, [10])
# [[], [12, 11, 0], [13, 16, 14, 6, 10], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30], [3], [24, 2], [21], [22]]
# 10
# (7, 20, [21])
# [[], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30, 10], [3], [24, 2], [21], [22]]
# 21
# (31, 8, [10])
# [[], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30, 10], [3], [24, 2], [21], [22]]
# 10
# (25, 4, [30])
# [[], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30, 10], [3], [24, 2], [21], [22]]
# 30
# (32, 20, [18])
# [[], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [18, 30, 10], [3], [24, 2], [21], [22]]
# 18
# (9, 28, [2])
# [[18], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [24, 2], [21], [22]]
# 2
# (8, 20, [24])
# [[18], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [24, 2], [21], [22]]
# 24
# (8, 29, [24])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 24
# (7, 28, [21])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 21
# (25, 29, [30])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 30
# (9, 32, [2])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 2
# (31, 29, [10])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 10
# (7, 32, [21])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 21
# (9, 20, [2])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 2
# (31, 4, [10])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 10
# (28, 20, [22])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 22
# (28, 32, [22])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 22
# (32, 4, [18])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 18
# (32, 29, [18])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 18
# (25, 28, [30])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 30
# (31, 28, [10])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 10
# (7, 4, [21])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 21
# (25, 20, [30])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 30
# (31, 20, [10])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 10
# (32, 8, [18])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 18
# (7, 8, [21])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 21
# (8, 4, [24])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 24
# At time step 998 the number of switch migrated are : 36
# The migrated switches are [22, 22, 2, 22, 2, 30, 2, 30, 21, 10, 21, 10, 30, 18, 2, 24, 24, 21, 30, 2, 10, 21, 2, 10, 22, 22, 18, 18, 30, 10, 21, 30, 10, 18, 21, 24]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# {20: {18: 207653.65235, 24: 83061.83854}, 7: {12: 1586.0, 11: 555057.5265, 0: 415307.0}, 31: {13: 1470.1341766666665, 16: 925.8144765000001, 14: 1553.5620513999997, 6: 83061.4}, 9: {33: 796.0905403333333, 17: 2394.638692, 15: 1263.66769125, 5: 312675.10725, 26: 162426.44038, 27: 162429.89919999999, 1: 157474.195475}, 25: {19: 59330.51822857143, 23: 103827.215775}, 32: {30: 812154.3954, 10: 68113.64058571428}, 28: {3: 70366.4654}, 8: {2: 132827.22094}, 29: {21: 103827.3526}, 4: {22: 207659.2312}}
# {(29, 28), (25, 31), (9, 8), (7, 25), (20, 29), (9, 29), (32, 31), (8, 28), (20, 8), (9, 4), (25, 8), (7, 29), (9, 25), (7, 20), (25, 4), (32, 20), (9, 28), (8, 29), (7, 28), (20, 4), (32, 28), (25, 29), (4, 28), (31, 29), (9, 20), (31, 4), (20, 31), (7, 31), (9, 31), (32, 4), (32, 29), (25, 28), (31, 28), (4, 29), (32, 25), (8, 31), (7, 4), (20, 28), (25, 20), (32, 8), (7, 8), (8, 4)}
# (29, 28, [21])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3], [2], [21], [22]]
# 21
# (25, 31, [23])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6], [33, 17, 15, 5, 26, 27, 1], [19, 23], [30, 10], [3, 21], [2], [], [22]]
# 23
# (9, 8, [5])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6, 23], [33, 17, 15, 5, 26, 27, 1], [19], [30, 10], [3, 21], [2], [], [22]]
# 5
# (7, 25, [11])
# [[18, 24], [12, 11, 0], [13, 16, 14, 6, 23], [33, 17, 15, 26, 27, 1], [19], [30, 10], [3, 21], [2, 5], [], [22]]
# 11
# (20, 29, [18])
# [[18, 24], [12, 0], [13, 16, 14, 6, 23], [33, 17, 15, 26, 27, 1], [19, 11], [30, 10], [3, 21], [2, 5], [], [22]]
# 18
# (9, 29, [5])
# [[24], [12, 0], [13, 16, 14, 6, 23], [33, 17, 15, 26, 27, 1], [19, 11], [30, 10], [3, 21], [2, 5], [18], [22]]
# 5
# (32, 31, [30])
# [[24], [12, 0], [13, 16, 14, 6, 23], [33, 17, 15, 26, 27, 1], [19, 11], [30, 10], [3, 21], [2, 5], [18], [22]]
# 30
# (8, 28, [2])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21], [2, 5], [18], [22]]
# 2
# (20, 8, [18])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 18
# (9, 4, [5])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 5
# (25, 8, [23])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 23
# (7, 29, [11])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 11
# (9, 25, [5])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 5
# (7, 20, [11])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 11
# (25, 4, [23])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 23
# (32, 20, [30])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 30
# (9, 28, [5])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 5
# (8, 29, [2])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 2
# (7, 28, [11])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 11
# (20, 4, [18])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 18
# (32, 28, [30])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 30
# (25, 29, [23])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 23
# (4, 28, [22])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2], [5], [18], [22]]
# 22
# (31, 29, [6])
# [[24], [12, 0], [13, 16, 14, 6, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18], []]
# 6
# (9, 20, [5])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 5
# (31, 4, [6])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 6
# (20, 31, [18])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 18
# (7, 31, [11])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 11
# (9, 31, [5])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 5
# (32, 4, [30])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 30
# (32, 29, [30])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 30
# (25, 28, [23])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 23
# (31, 28, [6])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 6
# (4, 29, [22])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 22
# (32, 25, [30])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 30
# (8, 31, [2])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 2
# (7, 4, [11])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 11
# (20, 28, [18])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 18
# (25, 20, [23])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 23
# (32, 8, [30])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 30
# (7, 8, [11])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 11
# (8, 4, [2])
# [[24], [12, 0], [13, 16, 14, 23, 30], [33, 17, 15, 26, 27, 1], [19, 11], [10], [3, 21, 2, 22], [5], [18, 6], []]
# 2
# At time step 999 the number of switch migrated are : 42
# The migrated switches are [21, 23, 5, 11, 18, 5, 30, 2, 18, 5, 23, 11, 5, 11, 23, 30, 5, 2, 11, 18, 30, 23, 22, 6, 5, 6, 18, 11, 5, 30, 30, 23, 6, 22, 30, 2, 11, 18, 23, 30, 11, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Switches in the controller 28 : [33, 2, 23]
# Switch selected is : 2
# The target controller set for 20 is : [3, 14, 5]
# The mean load ratio is : 0.04078227961891404
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.07104026666340361
# 7 :	 0.02776912862430264
# 31 :	 0.07002767613202304
# 9 :	 0.0367236575763409
# 25 :	 0.05178695973615592
# 32 :	 0.03320798320908962
# 28 :	 0.01857230066476109
# 8 :	 0.01851532166672774
# 29 :	 0.01769159946300101
# 4 :	 0.06248790245333477
# Switches in the controller 4 : [17, 6, 1]
# Switch selected is : 1
# The target controller set for 29 is : [10]
# The mean load ratio is : 0.04078227961891404
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.07104026666340361
# 7 :	 0.02776912862430264
# 31 :	 0.07002767613202304
# 9 :	 0.0367236575763409
# 25 :	 0.05178695973615592
# 32 :	 0.03320798320908962
# 28 :	 0.01857230066476109
# 8 :	 0.01851532166672774
# 29 :	 0.06157583830513057
# 4 :	 0.018603663611205218
# Switches in the controller 25 : [27, 15, 0]
# Switch selected is : 0
# The target controller set for 28 is : [33, 23]
# The mean load ratio is : 0.04078227961891404
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.07104026666340361
# 7 :	 0.02776912862430264
# 31 :	 0.07002767613202304
# 9 :	 0.0367236575763409
# 25 :	 0.033424933343989736
# 32 :	 0.03320798320908962
# 28 :	 0.03693432705692727
# 8 :	 0.01851532166672774
# 29 :	 0.06157583830513057
# 4 :	 0.018603663611205218
# Switches in the controller 31 : [22, 13, 24, 26]
# Switch selected is : 24
# The target controller set for 25 is : [27, 15]
# The mean load ratio is : 0.04078227961891404
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.07104026666340361
# 7 :	 0.02776912862430264
# 31 :	 0.05166548209689521
# 9 :	 0.0367236575763409
# 25 :	 0.051787127379117566
# 32 :	 0.03320798320908962
# 28 :	 0.03693432705692727
# 8 :	 0.01851532166672774
# 29 :	 0.06157583830513057
# 4 :	 0.018603663611205218
# Switches in the controller 31 : [22, 13, 26]
# Switch selected is : 22
# The target controller set for 32 is : [30]
# The mean load ratio is : 0.04078227961891404
#
# At time step 972 the number of switch migrated are : 7
# The migrated switches are [5, 1, 2, 1, 0, 24, 22]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 973
# The overloaded domains are : [32, 7, 8, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.08154834952131997
# 7 :	 0.16813173728319905
# 31 :	 0.03216263198705992
# 9 :	 0.03672404213780834
# 25 :	 0.050485844803823045
# 32 :	 0.05030990701911606
# 28 :	 0.03693422452298672
# 8 :	 0
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 9 : [21, 15, 10]
# Switch selected is : 10
# The target controller set for 32 is : [22, 19, 30]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.03391970497229861
# 7 :	 0.019382665713000607
# 31 :	 0.03390642333647941
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.09649032136235469
# 28 :	 0.03672429102683542
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 32 : [22, 19, 30, 10]
# Switch selected is : 10
# The target controller set for 28 is : [23, 0]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.03391970497229861
# 7 :	 0.019382665713000607
# 31 :	 0.03390642333647941
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.0703556618389212
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 32 : [22, 19, 30]
# Switch selected is : 22
# The target controller set for 20 is : [14, 27]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.052281855316001824
# 7 :	 0.019382665713000607
# 31 :	 0.03390642333647941
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.051993511495217984
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 32 : [19, 30]
# Switch selected is : 30
# The target controller set for 20 is : [14, 27, 22]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.08591346543612731
# 7 :	 0.019382665713000607
# 31 :	 0.03390642333647941
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.0183619013750925
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 20 : [14, 27, 22, 30]
# Switch selected is : 14
# The target controller set for 31 is : [26, 16]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.08562562779831547
# 7 :	 0.019382665713000607
# 31 :	 0.03419426097429126
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.0183619013750925
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.018833815219169447
# Switches in the controller 20 : [27, 22, 30]
# Switch selected is : 27
# The target controller set for 4 is : [17, 6, 33]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.051993760463828705
# 7 :	 0.019382665713000607
# 31 :	 0.03419426097429126
# 9 :	 0.01862909513443685
# 25 :	 0.035222790392391165
# 32 :	 0.0183619013750925
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.052465682553656204
# Switches in the controller 20 : [22, 30]
# Switch selected is : 22
# The target controller set for 9 is : [21, 15]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.033631610120125485
# 7 :	 0.019382665713000607
# 31 :	 0.03419426097429126
# 9 :	 0.03699124547814006
# 25 :	 0.035222790392391165
# 32 :	 0.0183619013750925
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.052465682553656204
# Switches in the controller 4 : [17, 6, 33, 27]
# Switch selected is : 17
# The target controller set for 32 is : [19]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.033631610120125485
# 7 :	 0.019382665713000607
# 31 :	 0.03419426097429126
# 9 :	 0.03699124547814006
# 25 :	 0.035222790392391165
# 32 :	 0.018623445769921497
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.052204138158827205
# Switches in the controller 4 : [6, 33, 27]
# Switch selected is : 6
# The target controller set for 7 is : [13, 5]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 20 :	 0.033631610120125485
# 7 :	 0.03774469210516679
# 31 :	 0.03419426097429126
# 9 :	 0.03699124547814006
# 25 :	 0.035222790392391165
# 32 :	 0.018623445769921497
# 28 :	 0.06285895055026892
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.03384211176666102
# Switches in the controller 28 : [23, 0, 10]
# Switch selected is : 23
# The target controller set for 9 is : [21, 15, 22]
# The mean load ratio is : 0.037808935608286326
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 20 :	 0.033631610120125485
# 7 :	 0.03774469210516679
# 31 :	 0.03419426097429126
# 9 :	 0.0553535101128093
# 25 :	 0.035222790392391165
# 32 :	 0.018623445769921497
# 28 :	 0.04449668591559969
# 8 :	 0.03668213491234213
# 29 :	 0.04829811401355497
# 4 :	 0.03384211176666102
# Switches in the controller 28 : [0, 10]
# Switch selected is : 10
# The target controller set for 29 is : [1]
# The mean load ratio is : 0.037808935608286326
#
# At time step 976 the number of switch migrated are : 15
# The migrated switches are [16, 33, 2, 3, 10, 10, 22, 30, 14, 27, 22, 17, 6, 23, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step :

# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.027849714388604927
# 7 :	 0.054515401417056665
# 31 :	 0.0462524999868646
# 9 :	 0.050444167676445856
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.037159791427327483
# 8 :	 0.06376679680642164
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 4 : [11]
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.027849714388604927
# 7 :	 0.054515401417056665
# 31 :	 0.0462524999868646
# 9 :	 0.050444167676445856
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.037159791427327483
# 8 :	 0.06376679680642164
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 8 : [5, 26, 33]
# Switch selected is : 5
# The target controller set for 7 is : [27, 16, 24]
# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.027849714388604927
# 7 :	 0.08216409778623845
# 31 :	 0.0462524999868646
# 9 :	 0.050444167676445856
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.037159791427327483
# 8 :	 0.03611810043723984
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 9 : [10, 2]
# Switch selected is : 10
# The target controller set for 20 is : [1]
# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.04893033971567587
# 7 :	 0.08216409778623845
# 31 :	 0.0462524999868646
# 9 :	 0.02936354234937491
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.037159791427327483
# 8 :	 0.03611810043723984
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 31 : [0, 3, 13, 23]
# Switch selected is : 23
# The target controller set for 9 is : [2]
# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.04893033971567587
# 7 :	 0.08216409778623845
# 31 :	 0.027890391221197915
# 9 :	 0.047725651115041595
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.037159791427327483
# 8 :	 0.03611810043723984
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 20 : [1, 10]
# Switch selected is : 10
# The target controller set for 28 is : [22, 17, 6, 15]
# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.027849714388604924
# 7 :	 0.08216409778623845
# 31 :	 0.027890391221197915
# 9 :	 0.047725651115041595
# 25 :	 0.01836213296351802
# 32 :	 0.05448030169051642
# 28 :	 0.05824041675439843
# 8 :	 0.03611810043723984
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 32 : [30, 12, 18]
# Switch selected is : 12
# The target controller set for 28 is : [22, 17, 6, 15, 10]
# The mean load ratio is : 0.04206182369309881
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.027849714388604924
# 7 :	 0.08216409778623845
# 31 :	 0.027890391221197915
# 9 :	 0.047725651115041595
# 25 :	 0.01836213296351802
# 32 :	 0.054269935572021116
# 28 :	 0.05845078287289373
# 8 :	 0.03611810043723984
# 29 :	 0.01870575869890431
# 4 :	 0.04908167187532828
# Switches in the controller 32 : [30, 18]
# Switch selected is : 30
# The target controller set for 31 is : [0, 3, 13]
# The mean load ratio is : 0.04206182369309881
#
# At time step 999 the number of switch migrated are : 9
# The migrated switches are [24, 24, 15, 5, 10, 23, 10, 12, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 1
epsilon_dec = 0.9 # approx 60 time steps needed to reach epsilon mean
epsilon_min = 0.0025

load_controller = []

for i in range(0, 1000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon*epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# 20 :	 0.07348810509442359
# 7 :	 0.05227218910157708
# 31 :	 0.01844566051326496
# 9 :	 0.040398574258375654
# 25 :	 0.03882152030529658
# 32 :	 0.046786297644527915
# 28 :	 0.018989864400611622
# 8 :	 0.01857305415362028
# 29 :	 0.018564804587303165
# 4 :	 0.04091811444432128
# [(762379.642, 5), (415309.0731, 24), (4588.533367, 16)]
# Switches in the controller 7 : [16, 24, 5]
# Switch selected is : 5
# The underloaded domains are : [31, 28, 8, 29]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.03672581845033221
# The reward is = 0.3502584591585651
# Q value = 9.904172622748868
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.07348810509442359
# 7 :	 0.018564991517009015
# 31 :	 0.01844566051326496
# 9 :	 0.040398574258375654
# 25 :	 0.03882152030529658
# 32 :	 0.046786297644527915
# 28 :	 0.018989864400611622
# 8 :	 0.01857305415362028
# 29 :	 0.052272002171871224
# 4 :	 0.04091811444432128
# [(462741.4162, 26), (415312.4973, 18)]
# Switches in the controller 25 : [18, 26]
# Switch selected is : 26
# The underloaded domains are : [7, 31, 28, 8]
# The target controller set for 7 is : [16, 24]
# The mean load ratio is : 0.03672581845033221
# The reward is = 0.3967710704286612
# Q value = 10.478962363610162
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.07348810509442359
# 7 :	 0.03902424237724676
# 31 :	 0.01844566051326496
# 9 :	 0.040398574258375654
# 25 :	 0.018362269445058834
# 32 :	 0.046786297644527915
# 28 :	 0.018989864400611622
# 8 :	 0.01857305415362028
# 29 :	 0.052272002171871224
# 4 :	 0.04091811444432128
# [(498414.597, 10), (415308.6665, 21)]
# Switches in the controller 9 : [21, 10]
# Switch selected is : 10
# The underloaded domains are : [31, 25, 28, 8]
# The target controller set for 8 is : [33, 22]
# The mean load ratio is : 0.03672581845033221
# The reward is = 0.530143329007225
# Q value = 9.580856962881612
#
# At time step 965 the number of switch migrated are : 7
# The migrated switches are [2, 1, 30, 10, 5, 26, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 966
# 0.555671659500156
# The overloaded domains are : [32, 4, 7, 8, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.09035752836184749
# 7 :	 0.04381480916302241
# 31 :	 0.01857276494680801
# 9 :	 0.018361854871712196
# 25 :	 0.018362119438718596
# 32 :	 0.06496667109389863
# 28 :	 0.018932740982877724
# 8 :	 0.04128322544266747
# 29 :	 0.04216785699088706
# 4 :	 0.050793498230722135
# [(574422.1389, 26), (415315.6562, 24), (1252.881007, 16)]
# Switches in the controller 7 : [16, 24, 26]
# Switch selected is : 26
# The underloaded domains are : [31, 9, 25, 28]
# The target controller set for 9 is : [21]
# The mean load ratio is : 0.040761306952316174
# The reward is = 0.408932304786525
# Q value = 10.321559617917714
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.09035752836184749
# 7 :	 0.018417802912883717
# 31 :	 0.01857276494680801
# 9 :	 0.04375886112185089
# 25 :	 0.018362119438718596
# 32 :	 0.06496667109389863
# 28 :	 0.018932740982877724
# 8 :	 0.04128322544266747
# 29 :	 0.04216785699088706
# 4 :	 0.050793498230722135
# [(574421.3059, 30), (574411.3403, 27)]
# Switches in the controller 4 : [27, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 31, 25, 28]
# The target controller set for 25 is : [18]
# The mean load ratio is : 0.040761306952316174
# The reward is = 0.5380172441269544
# Q value = 9.562123633450657
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.09035752836184749
# 7 :	 0.018417802912883717
# 31 :	 0.01857276494680801
# 9 :	 0.04375886112185089
# 25 :	 0.043759088859311956
# 32 :	 0.06496667109389863
# 28 :	 0.018932740982877724
# 8 :	 0.04128322544266747
# 29 :	 0.04216785699088706
# 4 :	 0.025396528810128775
# [(1199518.76, 11), (428854.6721, 1), (415307.0, 6)]
# Switches in the controller 20 : [6, 11, 1]
# Switch selected is : 11
# The underloaded domains are : [7, 31, 28, 4]
# The target controller set for 7 is : [16, 24]
# The mean load ratio is : 0.040761306952316174
# The reward is = 1.0623860163410495
# Q value = 10.953567062009531
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.03732303790293768
# 7 :	 0.07145229337179353
# 31 :	 0.01857276494680801
# 9 :	 0.04375886112185089
# 25 :	 0.043759088859311956
# 32 :	 0.06496667109389863
# 28 :	 0.018932740982877724
# 8 :	 0.04128322544266747
# 29 :	 0.04216785699088706
# 4 :	 0.025396528810128775
# [(936368.0477, 3), (533029.3214, 2)]
# Switches in the controller 32 : [3, 2]
# Switch selected is : 3
# The underloaded domains are : [20, 31, 28, 4]
# The target controller set for 20 is : [6, 1]
# The mean load ratio is : 0.040761306952316174
# The reward is = 0.26493653619753654
# Q value = 8.753869692248424
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.07872280916768526
# 7 :	 0.07145229337179353
# 31 :	 0.01857276494680801
# 9 :	 0.04375886112185089
# 25 :	 0.043759088859311956
# 32 :	 0.023566899829151042
# 28 :	 0.018932740982877724
# 8 :	 0.04128322544266747
# 29 :	 0.04216785699088706
# 4 :	 0.025396528810128775
# [(513652.4004, 10), (415310.0936, 22), (4769.554018, 33)]
# Switches in the controller 8 : [33, 22, 10]
# Switch selected is : 10
# The underloaded domains are : [31, 32, 28, 4]
# The target controller set for 32 is : [2]
# The mean load ratio is : 0.040761306952316174
# The reward is = 0.16720128062281558
# Q value = 10.662075543578712
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.07872280916768526
# 7 :	 0.07145229337179353
# 31 :	 0.01857276494680801
# 9 :	 0.04375886112185089
# 25 :	 0.043759088859311956
# 32 :	 0.04627708514397673
# 28 :	 0.018932740982877724
# 8 :	 0.018573040127841785
# 29 :	 0.04216785699088706
# 4 :	 0.025396528810128775
# [(534865.1489, 5), (415307.0, 0), (3568.2395130000004, 14)]
# Switches in the controller 29 : [14, 0, 5]
# Switch selected is : 5
# The underloaded domains are : [31, 28, 8, 4]
# The target controller set for 4 is : [27]
# The mean load ratio is : 0.040761306952316174
# The reward is = 0.5533563740671829
# Q value = 9.663629096082008
#
# At time step 966 the number of switch migrated are : 6
# The migrated switches are [26, 30, 11, 3, 10, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 967
# 0.4267848016485351
# The overloaded domains are : [32, 4, 7, 8, 9, 20, 25, 28, 29]
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.06107727534659807
# 7 :	 0.023294769526860448
# 31 :	 0.01844339760444197
# 9 :	 0.03547098310673445
# 25 :	 0.03547047454951685
# 32 :	 0.038337832001635805
# 28 :	 0.01926809919659296
# 8 :	 0.018572859151214118
# 29 :	 0.018608326074820696
# 4 :	 0.03865244839708613
# [(901912.2614, 1), (415307.0, 6), (64208.88006, 3)]
# Switches in the controller 20 : [6, 1, 3]
# Switch selected is : 1
# The underloaded domains are : [7, 31, 28, 8, 29]
# The target controller set for 7 is : [16, 24, 11]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.5025706633060925
# Q value = 9.256935793129692
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.021200902573576944
# 7 :	 0.06317114229988158
# 31 :	 0.01844339760444197
# 9 :	 0.03547098310673445
# 25 :	 0.03547047454951685
# 32 :	 0.038337832001635805
# 28 :	 0.01926809919659296
# 8 :	 0.018572859151214118
# 29 :	 0.018608326074820696
# 4 :	 0.03865244839708613
# [(487277.1682, 5), (386952.7258, 27)]
# Switches in the controller 4 : [27, 5]
# Switch selected is : 5
# The underloaded domains are : [20, 31, 28, 8, 29]
# The target controller set for 20 is : [6, 3]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.4669374383335982
# Q value = 8.928667930872555
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.042744956063617806
# 7 :	 0.06317114229988158
# 31 :	 0.01844339760444197
# 9 :	 0.03547098310673445
# 25 :	 0.03547047454951685
# 32 :	 0.038337832001635805
# 28 :	 0.01926809919659296
# 8 :	 0.018572859151214118
# 29 :	 0.018608326074820696
# 4 :	 0.01710839490704526
# [(526379.1095, 10), (340734.8819, 2)]
# Switches in the controller 32 : [2, 10]
# Switch selected is : 10
# The underloaded domains are : [31, 28, 8, 29, 4]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.30336711514170117
# Q value = 9.728525927637923
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.042744956063617806
# 7 :	 0.06317114229988158
# 31 :	 0.01844339760444197
# 9 :	 0.03547098310673445
# 25 :	 0.03547047454951685
# 32 :	 0.015064958919978298
# 28 :	 0.01926809919659296
# 8 :	 0.018572859151214118
# 29 :	 0.0418811991564782
# 4 :	 0.01710839490704526
# [(526379.1095, 10), (415307.0, 0), (5570.734957, 14)]
# Switches in the controller 29 : [14, 0, 10]
# Switch selected is : 10
# The underloaded domains are : [31, 32, 28, 8, 4]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.3263195719897361
# Q value = 8.841678133918284
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.042744956063617806
# 7 :	 0.06317114229988158
# 31 :	 0.041716270686099476
# 9 :	 0.03547098310673445
# 25 :	 0.03547047454951685
# 32 :	 0.015064958919978298
# 28 :	 0.01926809919659296
# 8 :	 0.018572859151214118
# 29 :	 0.018608326074820693
# 4 :	 0.01710839490704526
# [(415306.3555, 21), (386966.0771, 26)]
# Switches in the controller 9 : [21, 26]
# Switch selected is : 21
# The underloaded domains are : [32, 28, 8, 29, 4]
# The target controller set for 8 is : [33, 22]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.5451850259029611
# Q value = 8.788680052690065
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.042744956063617806
# 7 :	 0.06317114229988158
# 31 :	 0.041716270686099476
# 9 :	 0.017108985209936776
# 25 :	 0.03547047454951685
# 32 :	 0.015064958919978298
# 28 :	 0.01926809919659296
# 8 :	 0.03693485704801179
# 29 :	 0.018608326074820693
# 4 :	 0.01710839490704526
# [(901912.2614, 1), (415312.2982, 24), (105990.3675, 11), (5571.691261999999, 16)]
# Switches in the controller 7 : [16, 24, 11, 1]
# Switch selected is : 1
# The underloaded domains are : [9, 32, 28, 29, 4]
# The target controller set for 9 is : [26]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.4765730204708784
# Q value = 9.09932160460137
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.042744956063617806
# 7 :	 0.02329476952686045
# 31 :	 0.041716270686099476
# 9 :	 0.0569853579829579
# 25 :	 0.03547047454951685
# 32 :	 0.015064958919978298
# 28 :	 0.01926809919659296
# 8 :	 0.03693485704801179
# 29 :	 0.018608326074820693
# 4 :	 0.01710839490704526
# [(415309.9107, 18), (386951.0195, 30)]
# Switches in the controller 25 : [18, 30]
# Switch selected is : 18
# The underloaded domains are : [7, 32, 28, 29, 4]
# The target controller set for 32 is : [2]
# The mean load ratio is : 0.030719646495550153
# The reward is = 0.5161271088825821
# Q value = 9.566725332197063
#
# At time step 967 the number of switch migrated are : 7
# The migrated switches are [1, 5, 10, 10, 21, 1, 18]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 968
# 0.4161551049011157
# The overloaded domains are : [32, 4, 7, 8, 9, 20, 25, 28, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.06241430322707791
# 7 :	 0.021556242625059445
# 31 :	 0.047934835522071645
# 9 :	 0.0435237693576658
# 25 :	 0.02404087594737718
# 32 :	 0.04462506334265819
# 28 :	 0.018922563210710643
# 8 :	 0.03693450426893874
# 29 :	 0.01855635612265065
# 4 :	 0.024040979689088075
# [(667184.2955, 10), (415304.3311, 23), (1687.6135920000002, 13)]
# Switches in the controller 31 : [13, 23, 10]
# Switch selected is : 10
# The underloaded domains are : [7, 25, 28, 29, 4]
# The target controller set for 25 is : [30]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.25630429649809894
# Q value = 9.290859932315158
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.06241430322707791
# 7 :	 0.021556242625059445
# 31 :	 0.018436523087150485
# 9 :	 0.0435237693576658
# 25 :	 0.05353918838229834
# 32 :	 0.04462506334265819
# 28 :	 0.018922563210710643
# 8 :	 0.03693450426893874
# 29 :	 0.01855635612265065
# 4 :	 0.024040979689088075
# [(415311.3955, 22), (415298.7543, 21), (4763.780986, 33)]
# Switches in the controller 8 : [33, 22, 21]
# Switch selected is : 22
# The underloaded domains are : [7, 31, 28, 29, 4]
# The target controller set for 7 is : [16, 24, 11]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.5480207455596102
# Q value = 9.160535158363158
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.06241430322707791
# 7 :	 0.039918463356081
# 31 :	 0.018436523087150485
# 9 :	 0.0435237693576658
# 25 :	 0.05353918838229834
# 32 :	 0.04462506334265819
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.01855635612265065
# 4 :	 0.024040979689088075
# [(543757.5788, 26), (440650.4432, 1)]
# Switches in the controller 9 : [26, 1]
# Switch selected is : 26
# The underloaded domains are : [31, 28, 8, 29, 4]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.3368108163893525
# Q value = 8.878925335668958
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.06241430322707791
# 7 :	 0.039918463356081
# 31 :	 0.04247775285902042
# 9 :	 0.019482539585795867
# 25 :	 0.05353918838229834
# 32 :	 0.04462506334265819
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.01855635612265065
# 4 :	 0.024040979689088075
# [(594006.7006, 2), (415310.0701, 18)]
# Switches in the controller 32 : [2, 18]
# Switch selected is : 2
# The underloaded domains are : [9, 28, 8, 29, 4]
# The target controller set for 9 is : [1]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.29264028108622686
# Q value = 9.114224633523836
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.06241430322707791
# 7 :	 0.039918463356081
# 31 :	 0.04247775285902042
# 9 :	 0.045745440797527806
# 25 :	 0.05353918838229834
# 32 :	 0.018362162130926254
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.01855635612265065
# 4 :	 0.024040979689088075
# [(586568.3275, 5), (415307.0, 6), (409793.3237, 3)]
# Switches in the controller 20 : [6, 3, 5]
# Switch selected is : 5
# The underloaded domains are : [32, 28, 8, 29, 4]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.034254949331329825
# The reward is = 1.263570084981177
# Q value = 8.991942405265844
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.03648027584404854
# 7 :	 0.039918463356081
# 31 :	 0.04247775285902042
# 9 :	 0.045745440797527806
# 25 :	 0.05353918838229834
# 32 :	 0.018362162130926254
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.04449038350568002
# 4 :	 0.024040979689088075
# [(415307.0, 6), (409793.3237, 3)]
# Switches in the controller 20 : [6, 3]
# Switch selected is : 6
# The underloaded domains are : [32, 28, 8, 4]
# The target controller set for 32 is : [18]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.29475769949088615
# Q value = 8.42299277966066
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.018118249451882354
# 7 :	 0.039918463356081
# 31 :	 0.04247775285902042
# 9 :	 0.045745440797527806
# 25 :	 0.05353918838229834
# 32 :	 0.036724188523092435
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.04449038350568002
# 4 :	 0.024040979689088075
# [(667184.2955, 10), (543749.5761, 30)]
# Switches in the controller 25 : [30, 10]
# Switch selected is : 10
# The underloaded domains are : [20, 28, 8, 4]
# The target controller set for 20 is : [3]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.3799329424512405
# Q value = 9.61264418934613
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.047616561886803514
# 7 :	 0.039918463356081
# 31 :	 0.04247775285902042
# 9 :	 0.045745440797527806
# 25 :	 0.02404087594737718
# 32 :	 0.036724188523092435
# 28 :	 0.018922563210710643
# 8 :	 0.018572283537917185
# 29 :	 0.04449038350568002
# 4 :	 0.024040979689088075
# [(415311.3955, 22), (415305.9756, 24), (66474.42223, 11), (5772.460699, 16)]
# Switches in the controller 7 : [16, 24, 11, 22]
# Switch selected is : 22
# The underloaded domains are : [25, 28, 8, 4]
# The target controller set for 25 is : [30]
# The mean load ratio is : 0.034254949331329825
# The reward is = 0.38350714177190837
# Q value = 8.987427116200578
#
# At time step 968 the number of switch migrated are : 8
# The migrated switches are [10, 22, 26, 2, 5, 6, 10, 22]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 969
# 0.3756221314486799
# The overloaded domains are : [32, 4, 7, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.03877496919249815
# 7 :	 0.02532913556471291
# 31 :	 0.054173019587317045
# 9 :	 0.06468604465931062
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.04565433817510423
# 4 :	 0.03576440134878687
# [(808925.1846, 26), (415311.0911, 23), (1033.4067, 13)]
# Switches in the controller 31 : [13, 23, 26]
# Switch selected is : 26
# The underloaded domains are : [20, 7, 32, 28, 8, 4]
# The target controller set for 20 is : [3, 10]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.15053424017341904
# Q value = 9.315623676442208
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.07454009135252218
# 7 :	 0.02532913556471291
# 31 :	 0.018407897427293006
# 9 :	 0.06468604465931062
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.04565433817510423
# 4 :	 0.03576440134878687
# [(808925.1846, 26), (592529.3698, 3), (284471.6641, 10)]
# Switches in the controller 20 : [3, 10, 26]
# Switch selected is : 26
# The underloaded domains are : [7, 31, 32, 28, 8, 4]
# The target controller set for 7 is : [16, 24, 11]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.8949140719515345
# Q value = 8.42369941322543
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.03877496919249814
# 7 :	 0.06109425772473695
# 31 :	 0.018407897427293006
# 9 :	 0.06468604465931062
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.04565433817510423
# 4 :	 0.03576440134878687
# [(611641.9583, 5), (415307.0, 0), (5647.652746, 14)]
# Switches in the controller 29 : [14, 0, 5]
# Switch selected is : 5
# The underloaded domains are : [20, 31, 32, 28, 8, 4]
# The target controller set for 4 is : [27]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.46056235417755714
# Q value = 8.157880976988613
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.03877496919249814
# 7 :	 0.06109425772473695
# 31 :	 0.018407897427293006
# 9 :	 0.06468604465931062
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.018611726851767978
# 4 :	 0.06280701267212313
# [(986019.562, 1), (477030.6796, 2)]
# Switches in the controller 9 : [1, 2]
# Switch selected is : 1
# The underloaded domains are : [20, 31, 32, 28, 8, 29]
# The target controller set for 20 is : [3, 10]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.42209024177948856
# Q value = 9.043839874730123
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.08236998979324925
# 7 :	 0.06109425772473695
# 31 :	 0.018407897427293006
# 9 :	 0.021091024058559504
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.018611726851767978
# 4 :	 0.06280701267212313
# [(808908.8815, 27), (611641.9583, 5)]
# Switches in the controller 4 : [27, 5]
# Switch selected is : 27
# The underloaded domains are : [31, 9, 32, 28, 8, 29]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.3741975936917904
# Q value = 8.80781741098351
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.08236998979324925
# 7 :	 0.06109425772473695
# 31 :	 0.054172298776079875
# 9 :	 0.021091024058559504
# 25 :	 0.054126976368539144
# 32 :	 0.03672397332005646
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.018611726851767978
# 4 :	 0.02704261132333626
# [(808925.1846, 26), (415303.9791, 24), (149560.3128, 11), (8022.767475, 16)]
# Switches in the controller 7 : [16, 24, 11, 26]
# Switch selected is : 26
# The underloaded domains are : [9, 32, 28, 8, 29, 4]
# The target controller set for 32 is : [18, 6]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.25927246126888215
# Q value = 8.226284035705097
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.08236998979324925
# 7 :	 0.02532913556471291
# 31 :	 0.054172298776079875
# 9 :	 0.021091024058559504
# 25 :	 0.054126976368539144
# 32 :	 0.0724890954800805
# 28 :	 0.019100828948401035
# 8 :	 0.018572412825847533
# 29 :	 0.018611726851767978
# 4 :	 0.02704261132333626
# [(808919.5069, 30), (415308.7833, 22)]
# Switches in the controller 25 : [30, 22]
# Switch selected is : 30
# The underloaded domains are : [7, 9, 28, 8, 29, 4]
# The target controller set for 7 is : [16, 24, 11]
# The mean load ratio is : 0.0392906099990574
# The reward is = 0.4648524241936842
# Q value = 8.6302489015148
#
# At time step 969 the number of switch migrated are : 7
# The migrated switches are [26, 26, 5, 1, 27, 26, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 970
# 0.626164164282405
# The overloaded domains are : [32, 4, 7, 8, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.07092770404454728
# 7 :	 0.06348630692900985
# 31 :	 0.04567460884197094
# 9 :	 0.009728354219591687
# 25 :	 0.018362142292490485
# 32 :	 0.06384873350577054
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.01857839749428093
# 4 :	 0.024252237224062542
# [(613496.4405, 30), (415308.7535, 24), (406548.1764, 11), (561.5503527000001, 16)]
# Switches in the controller 7 : [16, 24, 11, 30]
# Switch selected is : 30
# The underloaded domains are : [9, 25, 28, 8, 29, 4]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.03525049963124365
# The reward is = 2.9283832897706894
# Q value = 9.734858923914837
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.07092770404454728
# 7 :	 0.03636170312517073
# 31 :	 0.04567460884197094
# 9 :	 0.009728354219591687
# 25 :	 0.018362142292490485
# 32 :	 0.06384873350577054
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.024252237224062542
# [(415308.7535, 24), (406548.1764, 11), (561.5503527000001, 16)]
# Switches in the controller 7 : [16, 24, 11]
# Switch selected is : 24
# The underloaded domains are : [9, 25, 28, 8, 4]
# The target controller set for 9 is : [2]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.7612509771657121
# Q value = 8.781233173291733
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.07092770404454728
# 7 :	 0.017999599205264154
# 31 :	 0.04567460884197094
# 9 :	 0.028090458139498262
# 25 :	 0.018362142292490485
# 32 :	 0.06384873350577054
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.024252237224062542
# [(985585.5716, 1), (602670.6245, 10), (15966.09149, 3)]
# Switches in the controller 20 : [3, 10, 1]
# Switch selected is : 1
# The underloaded domains are : [7, 9, 25, 28, 8, 4]
# The target controller set for 25 is : [22]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.25816682955091635
# Q value = 8.815907528230328
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.027351871521961828
# 7 :	 0.017999599205264154
# 31 :	 0.04567460884197094
# 9 :	 0.028090458139498262
# 25 :	 0.06193797481507593
# 32 :	 0.06384873350577054
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.024252237224062542
# [(613497.2839, 27), (415304.2943, 23), (4253.508924000001, 13)]
# Switches in the controller 31 : [13, 23, 27]
# Switch selected is : 27
# The underloaded domains are : [20, 7, 9, 28, 8, 4]
# The target controller set for 9 is : [2, 24]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.22353986531015085
# Q value = 9.361458164205766
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.027351871521961828
# 7 :	 0.017999599205264154
# 31 :	 0.01854996774876984
# 9 :	 0.05521509923269936
# 25 :	 0.06193797481507593
# 32 :	 0.06384873350577054
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.024252237224062542
# [(613501.5568, 26), (415307.0, 6), (415303.6234, 18)]
# Switches in the controller 32 : [18, 6, 26]
# Switch selected is : 26
# The underloaded domains are : [20, 7, 31, 28, 8, 4]
# The target controller set for 4 is : [5]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.6012419726209777
# Q value = 7.996654822733212
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.027351871521961828
# 7 :	 0.017999599205264154
# 31 :	 0.01854996774876984
# 9 :	 0.05521509923269936
# 25 :	 0.06193797481507593
# 32 :	 0.036723903494244994
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.05137706723558809
# [(415307.0, 6), (415303.6234, 18)]
# Switches in the controller 32 : [18, 6]
# Switch selected is : 6
# The underloaded domains are : [20, 7, 31, 28, 8]
# The target controller set for 20 is : [3, 10]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.39043900666125514
# Q value = 7.990480117828612
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.04571389791412801
# 7 :	 0.017999599205264154
# 31 :	 0.01854996774876984
# 9 :	 0.05521509923269936
# 25 :	 0.06193797481507593
# 32 :	 0.01836187710207881
# 28 :	 0.01907408189136264
# 8 :	 0.018572429869349674
# 29 :	 0.04570300129812005
# 4 :	 0.05137706723558809
# [(613496.4405, 30), (415307.0, 0), (4893.818982, 14)]
# Switches in the controller 29 : [14, 0, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 31, 32, 28, 8]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.03525049963124365
# The reward is = 0.7904310144620055
# Q value = 8.41321220142067
#
# At time step 970 the number of switch migrated are : 7
# The migrated switches are [30, 24, 1, 27, 26, 6, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 971
# 0.5647074994430377
# The overloaded domains are : [4, 7, 8, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.023204153595250417
# 31 :	 0.05104158344718304
# 9 :	 0.08274948064581429
# 25 :	 0.040155697006849414
# 32 :	 0.018361925913384997
# 28 :	 0.01897672236424384
# 8 :	 0.018571506324862017
# 29 :	 0.018564608361652066
# 4 :	 0.06251269360503543
# [(737227.8216, 30), (415307.66299999994, 23), (1908.2812440000002, 13)]
# Switches in the controller 31 : [13, 23, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 32, 28, 8, 29]
# The target controller set for 32 is : [18]
# The mean load ratio is : 0.03934977157623196
# The reward is = 0.7115975545277259
# Q value = 8.705589269158995
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.023204153595250417
# 31 :	 0.018446426810626505
# 9 :	 0.08274948064581429
# 25 :	 0.040155697006849414
# 32 :	 0.05095708254994154
# 28 :	 0.01897672236424384
# 8 :	 0.018571506324862017
# 29 :	 0.018564608361652066
# 4 :	 0.06251269360503543
# [(737245.4923, 26), (676648.5240000001, 5)]
# Switches in the controller 4 : [5, 26]
# Switch selected is : 26
# The underloaded domains are : [7, 31, 28, 8, 29]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.03934977157623196
# The reward is = 0.47903423925765654
# Q value = 8.135291476484204
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.023204153595250417
# 31 :	 0.05104236472431
# 9 :	 0.08274948064581429
# 25 :	 0.040155697006849414
# 32 :	 0.05095708254994154
# 28 :	 0.01897672236424384
# 8 :	 0.018571506324862017
# 29 :	 0.018564608361652066
# 4 :	 0.029916755691351937
# [(492923.4792, 1), (415306.4569, 22)]
# Switches in the controller 25 : [22, 1]
# Switch selected is : 1
# The underloaded domains are : [7, 28, 8, 29, 4]
# The target controller set for 28 is : [17, 15, 12, 19]
# The mean load ratio is : 0.03934977157623196
# The reward is = 0.3298561076129902
# Q value = 8.277963904314758
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.023204153595250417
# 31 :	 0.05104236472431
# 9 :	 0.08274948064581429
# 25 :	 0.01836200238001004
# 32 :	 0.05095708254994154
# 28 :	 0.04077041699108322
# 8 :	 0.018571506324862017
# 29 :	 0.018564608361652066
# 4 :	 0.029916755691351937
# [(737242.3645, 27), (719054.3990000001, 2), (415307.0467, 24)]
# Switches in the controller 9 : [2, 24, 27]
# Switch selected is : 27
# The underloaded domains are : [7, 25, 8, 29, 4]
# The target controller set for 7 is : [16, 11]
# The mean load ratio is : 0.03934977157623196
# The reward is = 3.75304733964948
# Q value = 10.85962411016965
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.05579995321907569
# 31 :	 0.05104236472431
# 9 :	 0.05015368102198902
# 25 :	 0.01836200238001004
# 32 :	 0.05095708254994154
# 28 :	 0.04077041699108322
# 8 :	 0.018571506324862017
# 29 :	 0.018564608361652066
# 4 :	 0.029916755691351937
# [(719054.3990000001, 2), (415307.0467, 24)]
# Switches in the controller 9 : [2, 24]
# Switch selected is : 2
# The underloaded domains are : [25, 8, 29, 4]
# The target controller set for 8 is : [33, 21]
# The mean load ratio is : 0.03934977157623196
# The reward is = 0.35793103981495716
# Q value = 8.359456896960644
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.05935934449804403
# 7 :	 0.05579995321907569
# 31 :	 0.05104236472431
# 9 :	 0.018362028456919817
# 25 :	 0.01836200238001004
# 32 :	 0.05095708254994154
# 28 :	 0.04077041699108322
# 8 :	 0.05036315888993122
# 29 :	 0.018564608361652066
# 4 :	 0.029916755691351937
# [(535284.1803, 3), (415307.0, 6), (391981.2983, 10)]
# Switches in the controller 20 : [3, 10, 6]
# Switch selected is : 3
# The underloaded domains are : [9, 25, 29, 4]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.03934977157623196
# The reward is = 3.0667194684137637
# Q value = 10.453139366302835
#
# At time step 971 the number of switch migrated are : 6
# The migrated switches are [30, 26, 1, 27, 2, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 972
# 0.3746262676215234
# The overloaded domains are : [32, 4, 7, 8, 9, 20, 28, 29, 31]
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.03605362585516719
# 7 :	 0.06091912518059021
# 31 :	 0.05166551208224653
# 9 :	 0.03144990730988032
# 25 :	 0.018361965413403968
# 32 :	 0.05157008546658215
# 28 :	 0.06291572542468118
# 8 :	 0.044840930250242675
# 29 :	 0.018750195268647206
# 4 :	 0.03129572393769893
# [(751088.5557, 30), (415308.7159, 18)]
# Switches in the controller 32 : [18, 30]
# Switch selected is : 30
# The underloaded domains are : [20, 9, 25, 29, 4]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.6977033098968052
# Q value = 8.32619225794613
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.03605362585516719
# 7 :	 0.06091912518059021
# 31 :	 0.05166551208224653
# 9 :	 0.03144990730988032
# 25 :	 0.018361965413403968
# 32 :	 0.018362102257492532
# 28 :	 0.06291572542468118
# 8 :	 0.044840930250242675
# 29 :	 0.05195817847773682
# 4 :	 0.03129572393769893
# [(594136.9642, 2), (415305.5981, 21), (4756.623656000001, 33)]
# Switches in the controller 8 : [33, 21, 2]
# Switch selected is : 2
# The underloaded domains are : [20, 9, 25, 32, 4]
# The target controller set for 20 is : [10, 6]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.2641453881704922
# Q value = 8.957592673412005
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.06232228642963836
# 7 :	 0.06091912518059021
# 31 :	 0.05166551208224653
# 9 :	 0.03144990730988032
# 25 :	 0.018361965413403968
# 32 :	 0.018362102257492532
# 28 :	 0.06291572542468118
# 8 :	 0.018572269675771507
# 29 :	 0.05195817847773682
# 4 :	 0.03129572393769893
# [(751081.1981, 26), (415306.299, 23), (2168.1060820000002, 13)]
# Switches in the controller 31 : [13, 23, 26]
# Switch selected is : 26
# The underloaded domains are : [9, 25, 32, 8, 4]
# The target controller set for 8 is : [33, 21]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.162141959870436
# Q value = 8.694160683783611
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.06232228642963836
# 7 :	 0.06091912518059021
# 31 :	 0.01845785417575327
# 9 :	 0.03144990730988032
# 25 :	 0.018361965413403968
# 32 :	 0.018362102257492532
# 28 :	 0.06291572542468118
# 8 :	 0.05177992758226477
# 29 :	 0.05195817847773682
# 4 :	 0.03129572393769893
# [(751069.5581, 27), (623316.1164, 11), (3465.472265, 16)]
# Switches in the controller 7 : [16, 11, 27]
# Switch selected is : 27
# The underloaded domains are : [31, 9, 25, 32, 4]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.4734088059621014
# Q value = 8.164548457711213
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.06232228642963836
# 7 :	 0.027711981915042566
# 31 :	 0.05166499744130091
# 9 :	 0.03144990730988032
# 25 :	 0.018361965413403968
# 32 :	 0.018362102257492532
# 28 :	 0.06291572542468118
# 8 :	 0.05177992758226477
# 29 :	 0.05195817847773682
# 4 :	 0.03129572393769893
# [(751088.5557, 30), (415307.0, 0), (8779.491334, 14)]
# Switches in the controller 29 : [14, 0, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 9, 25, 32, 4]
# The target controller set for 25 is : [22]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.3060880663325951
# Q value = 8.084201446251573
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 20 :	 0.06232228642963836
# 7 :	 0.027711981915042566
# 31 :	 0.05166499744130091
# 9 :	 0.03144990730988032
# 25 :	 0.05156994862249359
# 32 :	 0.018362102257492532
# 28 :	 0.06291572542468118
# 8 :	 0.05177992758226477
# 29 :	 0.018750195268647206
# 4 :	 0.03129572393769893
# [(992561.0165, 1), (415299.4632, 19), (5465.280704, 17), (4925.912978, 15), (4758.0, 12)]
# Switches in the controller 28 : [17, 15, 12, 19, 1]
# Switch selected is : 1
# The underloaded domains are : [7, 9, 32, 29, 4]
# The target controller set for 4 is : [5]
# The mean load ratio is : 0.04078227961891403
# The reward is = 0.2097373244631109
# Q value = 8.265149670556937
#
# At time step 972 the number of switch migrated are : 6
# The migrated switches are [30, 2, 26, 27, 30, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 973
# 0.7467108719370192
# The overloaded domains are : [4, 7, 8, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.0536159809687099
# 7 :	 0.16862906984885834
# 31 :	 0.05052419939378068
# 9 :	 0.05873904678032881
# 25 :	 0.05030990701911606
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.018609061967557718
# 4 :	 0.06437065062105342
# [(913242.3187, 3), (415300.4456, 24)]
# Switches in the controller 9 : [24, 3]
# Switch selected is : 3
# The underloaded domains are : [20, 31, 25, 32, 28, 8, 29]
# The target controller set for 20 is : [10, 6, 2]
# The mean load ratio is : 0.05527382846572785
# The reward is = 0.3713893903927181
# Q value = 8.230688117974871
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.0939932911474751
# 7 :	 0.16862906984885834
# 31 :	 0.05052419939378068
# 9 :	 0.018361736601563608
# 25 :	 0.05030990701911606
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.018609061967557718
# 4 :	 0.06437065062105342
# [(3797996.986, 11), (16006.52407, 16)]
# Switches in the controller 7 : [16, 11]
# Switch selected is : 11
# The underloaded domains are : [31, 9, 25, 32, 28, 8, 29]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.05527382846572785
# The reward is = 0.25190423062672185
# Q value = 7.57863523253865
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.0939932911474751
# 7 :	 0.0007076986841545729
# 31 :	 0.05052419939378068
# 9 :	 0.018361736601563608
# 25 :	 0.05030990701911606
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.18653043313226148
# 4 :	 0.06437065062105342
# [(916843.4028, 1), (539073.3477, 5)]
# Switches in the controller 4 : [5, 1]
# Switch selected is : 1
# The underloaded domains are : [7, 31, 9, 25, 32, 28, 8]
# The target controller set for 25 is : [22, 30]
# The mean load ratio is : 0.05527382846572785
# The reward is = 0.1711335758918446
# Q value = 8.003164013983692
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.0939932911474751
# 7 :	 0.0007076986841545729
# 31 :	 0.05052419939378068
# 9 :	 0.018361736601563608
# 25 :	 0.09084643243211668
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.18653043313226148
# 4 :	 0.023834125208052788
# [(913242.3187, 3), (415307.0, 6), (410829.8157, 10), (386533.9284, 2)]
# Switches in the controller 20 : [10, 6, 2, 3]
# Switch selected is : 3
# The underloaded domains are : [7, 31, 9, 32, 28, 8, 4]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.05527382846572785
# The reward is = 5.482802284826291
# Q value = 12.031979243688161
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.05361598096870989
# 7 :	 0.0007076986841545729
# 31 :	 0.05052419939378068
# 9 :	 0.05873904678032881
# 25 :	 0.09084643243211668
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.18653043313226148
# 4 :	 0.023834125208052788
# [(3797996.986, 11), (415307.0, 0), (5587.379166, 14)]
# Switches in the controller 29 : [14, 0, 11]
# Switch selected is : 11
# The underloaded domains are : [20, 7, 31, 32, 28, 8, 4]
# The target controller set for 31 is : [13, 23, 27]
# The mean load ratio is : 0.05527382846572785
# The reward is = 0.29656071630447467
# Q value = 7.475033739317374
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.05361598096870989
# 7 :	 0.0007076986841545729
# 31 :	 0.21844557055848446
# 9 :	 0.05873904678032881
# 25 :	 0.09084643243211668
# 32 :	 0.018362162091134428
# 28 :	 0.01905805238265106
# 8 :	 0.05052015358408797
# 29 :	 0.01860906196755771
# 4 :	 0.023834125208052788
# [(916843.4028, 1), (722592.1453, 30), (415302.7748, 22)]
# Switches in the controller 25 : [22, 30, 1]
# Switch selected is : 1
# The underloaded domains are : [20, 7, 32, 28, 8, 29, 4]
# The target controller set for 20 is : [10, 6, 2]
# The mean load ratio is : 0.05527382846572785
# The reward is = 0.5491706525202013
# Q value = 9.2279913495996
#
# At time step 973 the number of switch migrated are : 6
# The migrated switches are [3, 11, 1, 3, 11, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 974
# 0.6377438364365389
# The overloaded domains are : [4, 8, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.08004438874991286
# 7 :	 0.00035533516119977805
# 31 :	 0.059236213785686394
# 9 :	 0.07295295785145238
# 25 :	 0.05128336754899242
# 32 :	 0.018361886833390854
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.01859906290379581
# 4 :	 0.026292274998057974
# [(744621.5948, 27), (415304.2008, 23), (178472.9232, 11), (1388.824975, 13)]
# Switches in the controller 31 : [13, 23, 27, 11]
# Switch selected is : 27
# The underloaded domains are : [7, 32, 28, 29, 4]
# The target controller set for 32 is : [18]
# The mean load ratio is : 0.039782226514902215
# The reward is = 0.5179465537836542
# Q value = 7.620977986013802
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.08004438874991286
# 7 :	 0.00035533516119977805
# 31 :	 0.02631415522203475
# 9 :	 0.07295295785145238
# 25 :	 0.05128336754899242
# 32 :	 0.051283945397042494
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.01859906290379581
# 4 :	 0.026292274998057974
# [(744607.7474, 30), (415304.6213, 22)]
# Switches in the controller 25 : [22, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 31, 28, 29, 4]
# The target controller set for 31 is : [13, 23, 11]
# The mean load ratio is : 0.039782226514902215
# The reward is = 0.6328238787697734
# Q value = 8.19306334200764
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.08004438874991286
# 7 :	 0.00035533516119977805
# 31 :	 0.05923560154865629
# 9 :	 0.07295295785145238
# 25 :	 0.018361921222370875
# 32 :	 0.051283945397042494
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.01859906290379581
# 4 :	 0.026292274998057974
# [(677926.4114, 10), (415307.0, 6), (383050.6021, 1), (334136.8109, 2)]
# Switches in the controller 20 : [10, 6, 2, 1]
# Switch selected is : 10
# The underloaded domains are : [7, 25, 28, 29, 4]
# The target controller set for 29 is : [14, 0]
# The mean load ratio is : 0.039782226514902215
# The reward is = 7.3126962778759665
# Q value = 11.410704739167135
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.05007113364447686
# 7 :	 0.00035533516119977805
# 31 :	 0.05923560154865629
# 9 :	 0.07295295785145238
# 25 :	 0.018361921222370875
# 32 :	 0.051283945397042494
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.04857231800923181
# 4 :	 0.026292274998057974
# [(415307.0, 6), (383050.6021, 1), (334136.8109, 2)]
# Switches in the controller 20 : [6, 2, 1]
# Switch selected is : 6
# The underloaded domains are : [7, 25, 28, 4]
# The target controller set for 25 is : [22]
# The mean load ratio is : 0.039782226514902215
# The reward is = 1.516234259470496
# Q value = 8.454128206497195
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.03170910725231067
# 7 :	 0.00035533516119977805
# 31 :	 0.05923560154865629
# 9 :	 0.07295295785145238
# 25 :	 0.03672394761453706
# 32 :	 0.051283945397042494
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.04857231800923181
# 4 :	 0.026292274998057974
# [(1234725.841, 3), (415303.0512, 24)]
# Switches in the controller 9 : [24, 3]
# Switch selected is : 3
# The underloaded domains are : [20, 7, 25, 28, 4]
# The target controller set for 7 is : [16]
# The mean load ratio is : 0.039782226514902215
# The reward is = 1.0019012677590171
# Q value = 8.719709793527512
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.03170910725231067
# 7 :	 0.054946441209331856
# 31 :	 0.05923560154865629
# 9 :	 0.018361851803320305
# 25 :	 0.03672394761453706
# 32 :	 0.051283945397042494
# 28 :	 0.01920212639944829
# 8 :	 0.051494650917085404
# 29 :	 0.04857231800923181
# 4 :	 0.026292274998057974
# [(744612.2339, 26), (415313.1316, 21), (4765.749286, 33)]
# Switches in the controller 8 : [33, 21, 26]
# Switch selected is : 26
# The underloaded domains are : [20, 9, 25, 28, 4]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.039782226514902215
# The reward is = 0.3559332299651166
# Q value = 8.152158059068256
#
# At time step 974 the number of switch migrated are : 6
# The migrated switches are [27, 30, 10, 6, 3, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 975
# 0.7616535389350552
# The overloaded domains are : [32, 4, 7, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.039572361213031204
# 7 :	 0.029719531460867213
# 31 :	 0.14459325786735908
# 9 :	 0.053168888782692554
# 25 :	 0.03672367834767392
# 32 :	 0.0531692194306575
# 28 :	 0.019074674016366075
# 8 :	 0.018572797012387544
# 29 :	 0.049211330475686786
# 4 :	 0.019056665550779492
# [(2064373.7859999998, 11), (787253.4926, 30), (415306.6635, 23), (3434.5271850000004, 13)]
# Switches in the controller 31 : [13, 23, 11, 30]
# Switch selected is : 11
# The underloaded domains are : [20, 7, 25, 28, 8, 4]
# The target controller set for 20 is : [2, 1]
# The mean load ratio is : 0.04628624041575014
# The reward is = 0.23755950121818253
# Q value = 8.92221645365682
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.13084480772086282
# 7 :	 0.029719531460867213
# 31 :	 0.05332081135952746
# 9 :	 0.053168888782692554
# 25 :	 0.03672367834767392
# 32 :	 0.0531692194306575
# 28 :	 0.019074674016366075
# 8 :	 0.018572797012387544
# 29 :	 0.049211330475686786
# 4 :	 0.019056665550779492
# [(787253.4926, 30), (415306.6635, 23), (3434.5271850000004, 13)]
# Switches in the controller 31 : [13, 23, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 25, 28, 8, 4]
# The target controller set for 25 is : [22, 6]
# The mean load ratio is : 0.04628624041575014
# The reward is = 0.3396830833987812
# Q value = 7.938178462488098
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.13084480772086282
# 7 :	 0.029719531460867213
# 31 :	 0.018513862744536126
# 9 :	 0.053168888782692554
# 25 :	 0.07153062696266525
# 32 :	 0.0531692194306575
# 28 :	 0.019074674016366075
# 8 :	 0.018572797012387544
# 29 :	 0.049211330475686786
# 4 :	 0.019056665550779492
# [(787248.7596, 26), (415309.7828, 24)]
# Switches in the controller 9 : [24, 26]
# Switch selected is : 26
# The underloaded domains are : [7, 31, 28, 8, 4]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.04628624041575014
# The reward is = 0.25631408876771866
# Q value = 7.637171016494636
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.13084480772086282
# 7 :	 0.029719531460867213
# 31 :	 0.05332060209873746
# 9 :	 0.018362149428491223
# 25 :	 0.07153062696266525
# 32 :	 0.0531692194306575
# 28 :	 0.019074674016366075
# 8 :	 0.018572797012387544
# 29 :	 0.049211330475686786
# 4 :	 0.019056665550779492
# [(787255.5646, 27), (415310.4563, 18)]
# Switches in the controller 32 : [18, 27]
# Switch selected is : 27
# The underloaded domains are : [7, 9, 28, 8, 4]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.04628624041575014
# The reward is = 0.20550851090164796
# Q value = 7.431273073232078
#
# Balance the overloaded controller : 29
# Controller	Controller Load Ratio
# 20 :	 0.13084480772086282
# 7 :	 0.029719531460867213
# 31 :	 0.05332060209873746
# 9 :	 0.053169189653107934
# 25 :	 0.07153062696266525
# 32 :	 0.018362179206040788
# 28 :	 0.019074674016366075
# 8 :	 0.018572797012387544
# 29 :	 0.049211330475686786
# 4 :	 0.019056665550779492
# [(694019.0976, 10), (415307.0, 0), (3721.536107, 14)]
# Switches in the controller 29 : [14, 0, 10]
# Switch selected is : 10
# The underloaded domains are : [7, 32, 28, 8, 4]
# The target controller set for 4 is : [5]
# The mean load ratio is : 0.04628624041575014
# The reward is = 0.3645058390779493
# Q value = 7.353110622541706
#
# At time step 975 the number of switch migrated are : 5
# The migrated switches are [11, 30, 26, 27, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 976
# 0.623573088918739
# The overloaded domains are : [32, 4, 8, 9, 20, 25, 28, 29, 31]
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.07740599304722608
# 7 :	 0.006137668056770676
# 31 :	 0.05208114614459194
# 9 :	 0.05199393496866962
# 25 :	 0.07035578685599488
# 32 :	 0.018361975241984914
# 28 :	 0.01910105535659406
# 8 :	 0.01857209609843383
# 29 :	 0.018649864029978036
# 4 :	 0.04542983628261927
# [(1092392.768, 1), (381350.9488, 2), (277002.637, 11)]
# Switches in the controller 20 : [2, 1, 11]
# Switch selected is : 1
# The underloaded domains are : [7, 32, 28, 8, 29]
# ...
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 997
# 0.650938034554954
# The overloaded domains are : [4, 7, 8, 9, 20, 25, 28, 31]
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.06654641268857521
# 7 :	 0.03592339939954715
# 31 :	 0.040953426448314054
# 9 :	 0.018362155905716188
# 25 :	 0.08779483410949863
# 32 :	 0.018362026392166185
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.061475326810640545
# [(580158.0868, 5), (509673.1701, 27), (415296.2505, 18)]
# Switches in the controller 20 : [18, 5, 27]
# Switch selected is : 5
# The underloaded domains are : [7, 9, 32, 28, 29]
# The target controller set for 7 is : [16, 21, 1]
# The mean load ratio is : 0.038882878812547525
# The reward is = 1.651816465666528
# Q value = 6.743171813470923
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.04089580217285975
# 7 :	 0.06157400991526261
# 31 :	 0.040953426448314054
# 9 :	 0.018362155905716188
# 25 :	 0.08779483410949863
# 32 :	 0.018362026392166185
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.061475326810640545
# [(509673.1701, 27), (415296.2505, 18)]
# Switches in the controller 20 : [18, 27]
# Switch selected is : 27
# The underloaded domains are : [9, 32, 28, 29]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.3756590521618672
# Q value = 5.919178059733949
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.018361551123021423
# 7 :	 0.06157400991526261
# 31 :	 0.040953426448314054
# 9 :	 0.040896406955554514
# 25 :	 0.08779483410949863
# 32 :	 0.018362026392166185
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.061475326810640545
# [(509680.7868, 30), (415306.0412, 23), (1285.921789, 13)]
# Switches in the controller 31 : [13, 23, 30]
# Switch selected is : 30
# The underloaded domains are : [20, 32, 28, 29]
# The target controller set for 20 is : [18]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.2932092812841812
# Q value = 6.841882571627473
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.040896138931080586
# 7 :	 0.06157400991526261
# 31 :	 0.01841883864025489
# 9 :	 0.040896406955554514
# 25 :	 0.08779483410949863
# 32 :	 0.018362026392166185
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.061475326810640545
# [(880766.4437, 2), (509664.7106, 26)]
# Switches in the controller 4 : [2, 26]
# Switch selected is : 2
# The underloaded domains are : [31, 32, 28, 29]
# The target controller set for 31 is : [13, 23]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.45881365466325325
# Q value = 5.86612644843714
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.040896138931080586
# 7 :	 0.06157400991526261
# 31 :	 0.05736028842211205
# 9 :	 0.040896406955554514
# 25 :	 0.08779483410949863
# 32 :	 0.018362026392166185
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.022533877028783386
# [(580158.0868, 5), (415305.1578, 21), (395934.1772, 1), (1265.718407, 16)]
# Switches in the controller 7 : [16, 21, 1, 5]
# Switch selected is : 5
# The underloaded domains are : [32, 28, 29, 4]
# The target controller set for 32 is : [6]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.988177640044184
# Q value = 6.330411614746255
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.040896138931080586
# 7 :	 0.03592339939954715
# 31 :	 0.05736028842211205
# 9 :	 0.040896406955554514
# 25 :	 0.08779483410949863
# 32 :	 0.044012636907881646
# 28 :	 0.019073251971072062
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.022533877028783386
# [(1451621.5690000001, 3), (415307.0, 0), (118789.586, 11)]
# Switches in the controller 25 : [0, 11, 3]
# Switch selected is : 3
# The underloaded domains are : [7, 28, 29, 4]
# The target controller set for 28 is : [17, 15, 12, 19]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.22398609036702974
# Q value = 5.40140750727819
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.040896138931080586
# 7 :	 0.03592339939954715
# 31 :	 0.05736028842211205
# 9 :	 0.040896406955554514
# 25 :	 0.023614086947963464
# 32 :	 0.044012636907881646
# 28 :	 0.08325399913260723
# 8 :	 0.04004325239555981
# 29 :	 0.00029470200438545216
# 4 :	 0.022533877028783386
# [(485626.4968, 10), (415308.8474, 22), (4751.352217000001, 33)]
# Switches in the controller 8 : [33, 22, 10]
# Switch selected is : 10
# The underloaded domains are : [7, 25, 29, 4]
# The target controller set for 7 is : [16, 21, 1]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.32612986569362123
# Q value = 5.404293619871624
#
# Balance the overloaded controller : 28
# Controller	Controller Load Ratio
# 20 :	 0.040896138931080586
# 7 :	 0.057394471524449465
# 31 :	 0.05736028842211205
# 9 :	 0.040896406955554514
# 25 :	 0.023614086947963464
# 32 :	 0.044012636907881646
# 28 :	 0.08325399913260723
# 8 :	 0.01857218027065749
# 29 :	 0.00029470200438545216
# 4 :	 0.022533877028783386
# [(1451621.5690000001, 3), (415309.3096, 19), (6180.859261, 15), (5145.125494, 17), (4758.0, 12)]
# Switches in the controller 28 : [17, 15, 12, 19, 3]
# Switch selected is : 3
# The underloaded domains are : [25, 8, 29, 4]
# The target controller set for 29 is : [14]
# The mean load ratio is : 0.038882878812547525
# The reward is = 0.6133969007302602
# Q value = 5.754720235655755
#
# At time step 997 the number of switch migrated are : 8
# The migrated switches are [5, 27, 30, 2, 5, 3, 10, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 998
# 0.5484335697220043
# The overloaded domains are : [32, 4, 7, 9, 20, 25, 28, 31]
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.07487217968940842
# 31 :	 0.051478513440381964
# 9 :	 0.03970141481374108
# 25 :	 0.04156181837710602
# 32 :	 0.039584673131077754
# 28 :	 0.019110321535748327
# 8 :	 0.018572794971641656
# 29 :	 0.0034810443499650595
# 4 :	 0.0213387959433969
# [(482648.7496, 27), (415306.3633, 24)]
# Switches in the controller 9 : [24, 27]
# Switch selected is : 27
# The underloaded domains are : [28, 8, 29, 4]
# The target controller set for 8 is : [33, 22]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.3380141124856393
# Q value = 5.7544639622849445
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.07487217968940842
# 31 :	 0.051478513440381964
# 9 :	 0.018361998241660165
# 25 :	 0.04156181837710602
# 32 :	 0.039584673131077754
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.0034810443499650595
# 4 :	 0.0213387959433969
# [(669994.1217, 1), (605682.3277, 10), (415309.9753, 21), (2450.871716, 16)]
# Switches in the controller 7 : [16, 21, 1, 10]
# Switch selected is : 1
# The underloaded domains are : [9, 28, 29, 4]
# The target controller set for 29 is : [14, 3]
# The mean load ratio is : 0.034940295553855354
# The reward is = 1.6127308257630764
# Q value = 6.460561618115232
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.04524963601629045
# 31 :	 0.051478513440381964
# 9 :	 0.018361998241660165
# 25 :	 0.04156181837710602
# 32 :	 0.039584673131077754
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.0213387959433969
# [(605682.3277, 10), (415309.9753, 21), (2450.871716, 16)]
# Switches in the controller 7 : [16, 21, 10]
# Switch selected is : 10
# The underloaded domains are : [9, 28, 29, 4]
# The target controller set for 9 is : [24]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.5962711902163791
# Q value = 5.901627832776691
#
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.018470518672985263
# 31 :	 0.051478513440381964
# 9 :	 0.04514111558496535
# 25 :	 0.04156181837710602
# 32 :	 0.039584673131077754
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.0213387959433969
# [(480007.6833, 5), (415307.0, 6)]
# Switches in the controller 32 : [6, 5]
# Switch selected is : 5
# The underloaded domains are : [7, 28, 29, 4]
# The target controller set for 4 is : [26]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.41959324103815987
# Q value = 5.961582679020685
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.018470518672985263
# 31 :	 0.051478513440381964
# 9 :	 0.04514111558496535
# 25 :	 0.04156181837710602
# 32 :	 0.018362026392166185
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.042561442682308465
# [(524726.1824, 11), (415307.0, 0)]
# Switches in the controller 25 : [0, 11]
# Switch selected is : 11
# The underloaded domains are : [7, 32, 28, 29]
# The target controller set for 32 is : [6]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.8609825008800628
# Q value = 6.116856703562203
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.039701399286086424
# 7 :	 0.018470518672985263
# 31 :	 0.051478513440381964
# 9 :	 0.04514111558496535
# 25 :	 0.018362026392166185
# 32 :	 0.04156181837710602
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.042561442682308465
# [(482645.0767, 30), (415309.685, 18)]
# Switches in the controller 20 : [18, 30]
# Switch selected is : 30
# The underloaded domains are : [7, 25, 28, 29]
# The target controller set for 25 is : [0]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.3887118627089298
# Q value = 6.771943076281044
#
# Balance the overloaded controller : 4
# Controller	Controller Load Ratio
# 20 :	 0.018362145104446163
# 7 :	 0.018470518672985263
# 31 :	 0.051478513440381964
# 9 :	 0.04514111558496535
# 25 :	 0.039701280573806445
# 32 :	 0.04156181837710602
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.042561442682308465
# [(482634.7124, 26), (480007.6833, 5)]
# Switches in the controller 4 : [26, 5]
# Switch selected is : 26
# The underloaded domains are : [20, 7, 28, 29]
# The target controller set for 20 is : [18]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.3663372505431784
# Q value = 6.1646826274725
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 20 :	 0.039700941047843066
# 7 :	 0.018470518672985263
# 31 :	 0.051478513440381964
# 9 :	 0.04514111558496535
# 25 :	 0.039701280573806445
# 32 :	 0.04156181837710602
# 28 :	 0.019110321535748327
# 8 :	 0.03991221154372257
# 29 :	 0.033103588023083025
# 4 :	 0.021222646738911565
# [(748150.1765, 2), (415315.3865, 23), (860.5590072000001, 13)]
# Switches in the controller 31 : [13, 23, 2]
# Switch selected is : 2
# The underloaded domains are : [7, 28, 29, 4]
# The target controller set for 7 is : [16, 21]
# The mean load ratio is : 0.034940295553855354
# The reward is = 0.42203893493286193
# Q value = 4.82078587981866
#
# At time step 998 the number of switch migrated are : 8
# The migrated switches are [27, 1, 10, 5, 11, 30, 26, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 999
# 0.3721742529581805
# The overloaded domains are : [32, 4, 7, 8, 9, 20, 25, 28, 29]
# Balance the overloaded controller : 32
# Controller	Controller Load Ratio
# 20 :	 0.054268954327706106
# 7 :	 0.047971274301377244
# 31 :	 0.01855710650867592
# 9 :	 0.03944274866538846
# 25 :	 0.054269922100277465
# 32 :	 0.06744369826749447
# 28 :	 0.019007917391968974
# 8 :	 0.054481398244556604
# 29 :	 0.03752652075436115
# 4 :	 0.027648696369181797
# [(1110115.053, 11), (415307.0, 6)]
# Switches in the controller 32 : [6, 11]
# Switch selected is : 11
# The underloaded domains are : [31, 9, 28, 29, 4]
# The target controller set for 9 is : [24, 10]
# The mean load ratio is : 0.04206182369309882
# The reward is = 0.1904268807920429
# Q value = 5.557536997464209
#
# Balance the overloaded controller : 8
# Controller	Controller Load Ratio
# 20 :	 0.054268954327706106
# 7 :	 0.047971274301377244
# 31 :	 0.01855710650867592
# 9 :	 0.08852442054071674
# 25 :	 0.054269922100277465
# 32 :	 0.018362026392166178
# 28 :	 0.019007917391968974
# 8 :	 0.054481398244556604
# 29 :	 0.03752652075436115
# 4 :	 0.027648696369181797
# [(812149.4959999999, 27), (415318.4624, 22), (4776.543242, 33)]
# Switches in the controller 8 : [33, 22, 27]
# Switch selected is : 27
# The underloaded domains are : [31, 32, 28, 29, 4]
# The target controller set for 32 is : [6]
# The mean load ratio is : 0.04206182369309882
# The reward is = 0.18551468088200188
# Q value = 5.726656281233701
#
# Balance the overloaded controller : 7
# Controller	Controller Load Ratio
# 20 :	 0.054268954327706106
# 7 :	 0.047971274301377244
# 31 :	 0.01855710650867592
# 9 :	 0.08852442054071674
# 25 :	 0.054269922100277465
# 32 :	 0.054269705482421014
# 28 :	 0.019007917391968974
# 8 :	 0.018573719154301768
# 29 :	 0.03752652075436115
# 4 :	 0.027648696369181797
# [(664136.1047, 2), (415309.4104, 21), (5554.886859, 16)]
# Switches in the controller 7 : [16, 21, 2]
# Switch selected is : 2
# The underloaded domains are : [31, 28, 8, 29, 4]
# The target controller set for 29 is : [14, 3, 1]
# The mean load ratio is : 0.04206182369309882
# The reward is = 0.35415769295417854
# Q value = 5.689910471757531
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 20 :	 0.054268954327706106
# 7 :	 0.018607731952002337
# 31 :	 0.01855710650867592
# 9 :	 0.08852442054071674
# 25 :	 0.054269922100277465
# 32 :	 0.054269705482421014
# 28 :	 0.019007917391968974
# 8 :	 0.018573719154301768
# 29 :	 0.06689006310373606
# 4 :	 0.027648696369181797
# [(812132.2019, 26), (415307.3047, 18)]
# Switches in the controller 20 : [18, 26]
# Switch selected is : 26
# The underloaded domains are : [7, 31, 28, 8, 4]
# The target controller set for 7 is : [16, 21]
# The mean load ratio is : 0.04206182369309882
# The reward is = 0.4031614493694151
# Q value = 5.597938473203445
#
# Balance the overloaded controller : 25
# Controller	Controller Load Ratio
# 20 :	 0.018362039863909836
# 7 :	 0.054514646415798604
# 31 :	 0.01855710650867592
# 9 :	 0.08852442054071674
# 25 :	 0.054269922100277465
# 32 :	 0.054269705482421014
# 28 :	 0.019007917391968974
# 8 :	 0.018573719154301768
# 29 :	 0.06689006310373606
# 4 :	 0.027648696369181797
# [(812154.3954, 30), (415307.0, 0)]
# Switches in the controller 25 : [0, 30]
# Switch selected is : 30
# The underloaded domains are : [20, 31, 28, 8, 4]
# The target controller set for 20 is : [18]
# The mean load ratio is : 0.04206182369309882
# The reward is = 0.22474764419166932
# Q value = 6.042613187426534
#
# At time step 999 the number of switch migrated are : 5
# The migrated switches are [11, 27, 2, 26, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[1.         5.59793847 1.3462441  5.91917806 6.77194308 6.73064695
#   5.92906318 1.         5.61514574 1.        ]
#  [4.73070334 1.         6.15916912 5.90162783 6.27576705 6.33041161
#   5.66475542 1.         5.68991047 4.54065084]
#  [6.84188257 4.82078588 1.         6.3776173  6.63779855 6.1570038
#   1.         6.69920801 1.         1.        ]
#  [7.02524275 6.94096303 6.63493445 1.         3.41626718 1.
#   5.30864112 5.75446396 4.73970927 5.39787952]
#  [6.04261319 6.16900788 6.26790074 1.         1.         6.1168567
#   5.40140751 1.81331414 4.91962664 1.        ]
#  [7.3653693  1.         1.         5.557537   5.55213094 1.
#   1.         5.80980272 5.96692372 5.96158268]
#  [5.11070863 4.7136593  4.76219487 1.         0.98865586 4.89650749
#   1.         1.         5.75472024 5.95766862]
#  [6.90574247 5.40429362 5.64031835 7.38841735 1.         5.72665628
#   4.20443837 1.         1.         1.        ]
#  [5.03129904 6.34358342 6.8885505  4.87166809 5.7395033  1.
#   4.88590222 1.         1.         6.30314587]
#  [6.16468263 5.84834126 5.86612645 6.16526449 6.97633516 1.
#   4.60191599 1.         1.         1.        ]]

# %%
'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

prandom = []
pQL = []
pGreedy = []


yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(200, 1000, 1):
    x.append(time_steps_list_rn[i])

    prandom.append(discrete_coeff_list_rn[i])
    pQL.append(discrete_coeff_list_QL[i])
    pGreedy.append(discrete_coeff_list_gr[i])

    yrandom.append(load_balance_rate_list_rn[i])
    yQL.append(load_balance_rate_list_QL[i])
    yGreedy.append(load_balance_rate_list_gr[i])

    zrandom.append(number_of_switches_list_QL[i])
    zQL.append(number_of_switches_list_rn[i])
    zGreedy.append(number_of_switches_list_gr[i])

# %%
import matplotlib.pyplot as plt

plt.plot(x, yrandom, label='Random Selection')
plt.plot(x, yQL, label='Q-Learning')
plt.plot(x, yGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Load Ratio balancing rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from statistics import mean

plt.plot(x, [mean(yrandom)]*len(x), label='Random Selection')
plt.plot(x, [mean(yQL)]*len(x), label='Q-Learning')
plt.plot(x, [mean(yGreedy)]*len(x), label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Mean Load Ratio balancing rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(x, prandom, label='Random Selection')
plt.plot(x, pQL, label='Q-Learning')
plt.plot(x, pGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from statistics import mean

plt.plot(x, [mean(prandom)]*len(x), label='Random Selection')
plt.plot(x, [mean(pQL)]*len(x), label='Q-Learning')
plt.plot(x, [mean(pGreedy)]*len(x), label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()
