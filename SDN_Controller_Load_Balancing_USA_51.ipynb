# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing_USA_51.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph Building and Controller Allocation**

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/USA - 51 nodes/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

rm_nodes = 0

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)
        rm_nodes += 1 


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)
n += rm_nodes

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/USA - 51 nodes/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
# Out:
# Enter the number of controllers to allocate: 10
# Graph with 51 nodes and 64 edges
#
# Controllers:
# [40, 1, 14, 12, 38, 47, 50, 9, 20, 31]
#
# Cluster set for each controller:
# [[39, 40], [1, 3, 5, 35], [4, 6, 7, 8, 14, 15, 18, 25, 28], [11, 12, 24], [21, 30, 32, 37, 38], [10, 22, 29, 43, 44, 45, 46, 47, 48, 49], [2, 41, 42, 50], [0, 9, 16, 17, 34, 36], [19, 20], [13, 23, 26, 27, 31, 33]]
#
# Cluster map for each controller:
# {40: [39], 1: [3, 5, 35], 14: [4, 6, 7, 8, 15, 18, 25, 28], 12: [11, 24], 38: [21, 30, 32, 37], 47: [10, 22, 29, 43, 44, 45, 46, 48, 49], 50: [2, 41, 42], 9: [0, 16, 17, 34, 36], 20: [19], 31: [13, 23, 26, 27, 33]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1):
 6): 1, (5, 7): 2, (5, 8): 1, (5, 9): 4, (5, 10): 7, (5, 11): 6, (5, 12): 7, (5, 13): 6, (5, 14): 2, (5, 15): 3, (5, 16): 4, (5, 17): 5, (5, 18): 3, (5, 19): 4, (5, 20): 5, (5, 21): 9, (5, 22): 8, (5, 23): 3, (5, 24): 4, (5, 25): 5, (5, 26): 4, (5, 27): 5, (5, 28): 4, (5, 29): 6, (5, 30): 7, (5, 31): 5, (5, 32): 5, (5, 33): 4, (5, 34): 5, (5, 35): 4, (5, 36): 4, (5, 37): 7, (5, 38): 6, (5, 39): 7, (5, 40): 8, (5, 41): 6, (5, 42): 6, (5, 43): 9, (5, 44): 9, (5, 45): 8, (5, 46): 7, (5, 47): 6, (5, 48): 7, (5, 49): 8, (5, 50): 6, (6, 0): 2, (6, 1): 1, (6, 2): 4, (6, 3): 3, (6, 4): 2, (6, 5): 1, (6, 6): 0, (6, 7): 1, (6, 8): 2, (6, 9): 3, (6, 10): 6, (6, 11): 5, (6, 12): 6, (6, 13): 5, (6, 14): 1, (6, 15): 2, (6, 16): 3, (6, 17): 4, (6, 18): 2, (6, 19): 3, (6, 20): 4, (6, 21): 8, (6, 22): 7, (6, 23): 2, (6, 24): 3, (6, 25): 4, (6, 26): 3, (6, 27): 4, (6, 28): 3, (6, 29): 5, (6,  ...
# [[39, 40], [1, 3, 5, 35], [4, 6, 7, 8, 14, 15, 18, 25, 28], [11, 12, 24], [21, 30, 32, 37, 38], [10, 22, 29, 43, 44, 45, 46, 47, 48, 49], [2, 41, 42, 50], [0, 9, 16, 17, 34, 36], [19, 20], [13, 23, 26, 27, 31, 33]]
# [[39, 40], [1, 3, 5, 35], [4, 6, 7, 8, 14, 15, 18, 25, 28], [11, 12, 24], [21, 30, 32, 37, 38], [10, 22, 29, 43, 44, 45, 46, 47, 48, 49], [2, 41, 42, 50], [0, 9, 16, 17, 34, 36], [19, 20], [13, 23, 26, 27, 31, 33]]

# %% [markdown]
# # **Switch Migration Design**

# %% [markdown]
# Some **questions (with answers after discussion)** regarding the cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously - Yes
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool? - Yes

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions(with answers after discussion)** regarding the cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).
#
# We have calcuated hop count using the **Floyd Warshall** algorithm. The hop count is the number of hops involved in the shortest distance between the 2 nodes.

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# [[5, 0], [45, 39, 36, 25, 3, 7], [15, 43, 35, 37], [41, 8], [32, 18, 23, 6], [19, 26, 2], [21, 27, 28], [16, 17, 44, 11, 24, 10, 48], [22, 49, 46, 34, 29], [13, 33, 42, 4, 30]]
# 3
# (14, 40, [3])
# [[5, 0], [45, 39, 36, 25, 3, 7], [15, 43, 35, 37], [41, 8], [32, 18, 23, 6], [19, 26, 2], [21, 27, 28], [16, 17, 44, 11, 24, 10, 48], [22, 49, 46, 34, 29], [13, 33, 42, 4, 30]]
# 3
# (50, 20, [7])
# [[5, 0], [45, 39, 36, 25, 3, 7], [15, 43, 35, 37], [41, 8], [32, 18, 23, 6], [19, 26, 2], [21, 27, 28], [16, 17, 44, 11, 24, 10, 48], [22, 49, 46, 34, 29], [13, 33, 42, 4, 30]]
# 7
# (14, 12, [3])
# [[5, 0], [45, 39, 36, 25, 3, 7], [15, 43, 35, 37], [41, 8], [32, 18, 23, 6], [19, 26, 2], [21, 27, 28], [16, 17, 44, 11, 24, 10, 48], [22, 49, 46, 34, 29], [13, 33, 42, 4, 30]]
# 3
# (31, 20, [0])
# [[5, 0], [45, 39, 36, 25, 3, 7], [15, 43, 35, 37], [41, 8], [32, 18, 23, 6], [19, 26, 2], [21, 27, 28], [16, 17, 44, 11, 24, 10, 48], [22, 49, 46, 34, 29], [13, 33, 42, 4, 30]]
#

# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# (47, 12, [26])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 26
# (9, 14, [10])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# (50, 12, [28])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 28
# (9, 47, [10])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# (50, 47, [28])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 28
# (20, 31, [29])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 29
# (1, 50, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (1, 40, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (47, 40, [26])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 26
# (9, 31, [10])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# (50, 40, [28])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 28
# (20, 50, [29])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 29
# (20, 14, [29])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 29
# (14, 40, [37])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 37
# (1, 31, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (31, 38, [30])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 30
# (1, 12, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (31, 14, [30])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 30
# (1, 47, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (14, 12, [37])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 37
# (1, 38, [3])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 3
# (38, 12, [6])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 6
# (9, 38, [10])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# (9, 12, [10])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 10
# At time step 4959 the number of switch migrated are : 42
# The migrated switches are [30, 30, 28, 28, 29, 29, 8, 29, 6, 10, 3, 30, 37, 30, 26, 37, 29, 10, 26, 10, 28, 10, 28, 29, 3, 3, 26, 10, 28, 29, 29, 37, 3, 30, 3, 30, 3, 37, 3, 6, 10, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4960
# {40: {5: 102488.87675000001, 0: 83061.4, 30: 125047.32652, 8: 59745.464288888885, 6: 59329.57142857143, 10: 93163.1921}, 1: {45: 69218.03641666667, 39: 83061.42974, 36: 312614.78805, 25: 104206.30015000001, 7: 312614.78805}, 14: {15: 4882.707039, 43: 46145.04667777778, 35: 83061.4, 28: 312611.50915, 3: 53390.99552}, 12: {41: 34609.3589}, 38: {32: 4753.418283, 18: 59329.592671428574, 23: 69216.62263333333, 29: 312613.15635, 37: 179236.39286666666, 26: 89318.92807142857}, 47: {19: 51913.6719, 2: 108438.91238}, 50: {21: 46144.96525555555, 27: 62522.96331}, 9: {16: 136.438931, 17: 4668.450411, 44: 59328.53368571429, 11: 6164.180811249999, 24: 69218.03641666667, 48: 125045.92662}, 20: {22: 41530.54201, 49: 52101.918191666664, 46: 56839.80008181818, 34: 117130.14485714286}, 31: {13: 322.46459960000004, 33: 4757.870632, 42: 83060.93746, 4: 85054.8969}}
# {(38, 50), (40, 12), (14, 50), (38, 31), (40, 31), (20, 47), (14, 9), (38, 9), (20, 12), (14, 31), (1, 14), (47, 31), (31, 12), (40, 9), (14, 47), (20, 9), (9, 50), (40, 47), (38, 14), (47, 12), (40, 14), (50, 12), (9, 47), (50, 47), (20, 31), (1, 50), (1, 9), (9, 31), (50, 31), (20, 50), (20, 14), (1, 31), (1, 12), (1, 47), (40, 50), (38, 12), (38, 47)}
# (38, 50, [29])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 29, 37, 26], [19, 2], [21, 27], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 29
# (40, 12, [30])
# [[5, 0, 30, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41], [32, 18, 23, 37, 26], [19, 2], [21, 27, 29], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 30
# (14, 50, [28])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 28, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2], [21, 27, 29], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 28
# (38, 31, [29])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 29
# (40, 31, [30])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 30
# (20, 47, [34])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46, 34], [13, 33, 42, 4]]
# 34
# (14, 9, [28])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 28
# (38, 9, [29])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 29
# (20, 12, [34])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 34
# (14, 31, [28])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 28
# (1, 14, [36])
# [[5, 0, 8, 6, 10], [45, 39, 36, 25, 7], [15, 43, 35, 3], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 36
# (47, 31, [2])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30], [32, 18, 23, 37, 26], [19, 2, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4]]
# 2
# (31, 12, [4])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 4, 2]]
# 4
# (40, 9, [30])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 2]]
# 30
# (14, 47, [28])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 2]]
# 28
# (20, 9, [34])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 2]]
# 34
# (9, 50, [48])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28], [16, 17, 44, 11, 24, 48], [22, 49, 46], [13, 33, 42, 2]]
# 48
# (40, 47, [30])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 30
# (38, 14, [29])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 29
# (47, 12, [2])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 2
# (40, 14, [30])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 30
# (50, 12, [27])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34], [21, 27, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 27
# (9, 47, [48])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 48
# (50, 47, [27])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 27
# (20, 31, [34])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 34
# (1, 50, [36])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 36
# (1, 9, [36])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 36
# (9, 31, [48])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 48
# (50, 31, [27])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 27
# (20, 50, [34])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 34
# (20, 14, [34])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 34
# (1, 31, [36])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 36
# (1, 12, [36])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 36
# (1, 47, [36])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 36
# (40, 50, [30])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 30
# (38, 12, [29])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 29
# (38, 47, [29])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 29
# At time step 4960 the number of switch migrated are : 37
# The migrated switches are [29, 30, 28, 29, 30, 34, 28, 29, 34, 28, 36, 2, 4, 30, 28, 34, 48, 30, 29, 2, 30, 27, 48, 27, 34, 36, 36, 48, 27, 34, 34, 36, 36, 36, 30, 29, 29]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4961
# {40: {5: 71643.2774625, 0: 83061.4, 8: 30473.64791111111, 6: 59329.57142857143, 10: 126370.95592000001}, 1: {45: 69217.75233333332, 39: 83060.50616, 25: 109679.33103333334, 7: 329036.83755}, 14: {15: 4347.353949, 43: 46145.04027777778, 35: 83061.4, 3: 48957.424119999996, 36: 219357.8917}, 12: {41: 34608.75099166667, 30: 131616.44396, 4: 49407.0098375, 27: 164517.62}, 38: {32: 4750.415965, 18: 59328.93297142857, 23: 69217.2023, 37: 91420.94373333333, 26: 94010.05519999999}, 47: {19: 51913.0417, 34: 143286.554925}, 50: {21: 46145.44802222223, 29: 109677.87038333334, 28: 73119.97016666667, 48: 94010.06857142856}, 9: {16: 3161.671816, 17: 8367.203525, 44: 59329.030542857145, 11: 109885.7888375, 24: 69217.75233333332}, 20: {22: 41530.53625, 49: 54839.977625, 46: 59825.08965454546}, 31: {13: 1534.3022455, 33: 4763.170954, 42: 83061.80644, 2: 149253.050825}}
# {(12, 47), (50, 14), (40, 31), (38, 20), (12, 31), (50, 38), (14, 9), (12, 9), (1, 20), (38, 9), (12, 20), (1, 14), (31, 47), (40, 9), (20, 9), (40, 38), (40, 47), (38, 14), (40, 14), (12, 14), (50, 47), (12, 38), (40, 20), (1, 9), (50, 9), (50, 31), (14, 20), (50, 20), (1, 31), (1, 47), (1, 38)}
# (12, 47, [27])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4, 27], [32, 18, 23, 37, 26], [19, 34], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 27
# (50, 14, [29])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34, 27], [21, 29, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 29
# (40, 31, [10])
# [[5, 0, 8, 6, 10], [45, 39, 25, 7], [15, 43, 35, 3, 36, 29], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2]]
# 10
# (38, 20, [26])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 36, 29], [41, 30, 4], [32, 18, 23, 37, 26], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46], [13, 33, 42, 2, 10]]
# 26
# (12, 31, [27])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 36, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46, 26], [13, 33, 42, 2, 10]]
# 27
# (50, 38, [29])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 36, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46, 26], [13, 33, 42, 2, 10]]
# 29
# (14, 9, [36])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 36, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24], [22, 49, 46, 26], [13, 33, 42, 2, 10]]
# 36
# (12, 9, [27])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26], [13, 33, 42, 2, 10]]
# 27
# (1, 20, [7])
# [[5, 0, 8, 6], [45, 39, 25, 7], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26], [13, 33, 42, 2, 10]]
# 7
# (38, 9, [26])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 2, 10]]
# 26
# (12, 20, [27])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 2, 10]]
# 27
# (1, 14, [7])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 2, 10]]
# 7
# (31, 47, [2])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 2, 10]]
# 2
# (40, 9, [10])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 10]]
# 10
# (20, 9, [46])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36], [22, 49, 46, 26, 7], [13, 33, 42, 10]]
# 46
# (40, 38, [10])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 10
# (40, 47, [10])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 10
# (38, 14, [26])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 26
# (40, 14, [10])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 10
# (12, 14, [27])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 27
# (50, 47, [29])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 29
# (12, 38, [27])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 27
# (40, 20, [10])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 10
# (1, 9, [7])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 7
# (50, 9, [29])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 29
# (50, 31, [29])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 29
# (14, 20, [36])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 36
# (50, 20, [29])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 29
# (1, 31, [7])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 7
# (1, 47, [7])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 7
# (1, 38, [7])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24, 36, 46], [22, 49, 26, 7], [13, 33, 42, 10]]
# 7
# At time step 4961 the number of switch migrated are : 31
# The migrated switches are [27, 29, 10, 26, 27, 29, 36, 27, 7, 26, 27, 7, 2, 10, 46, 10, 10, 26, 10, 27, 29, 27, 10, 7, 29, 29, 36, 29, 7, 7, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4962
# {40: {5: 63163.0381625, 0: 83061.4, 8: 74628.29996666667, 6: 59329.57142857143}, 1: {45: 69216.27285, 39: 83061.18542, 25: 92561.47806666668}, 14: {15: 8694.480037000001, 43: 46145.33595555556, 35: 83061.4, 3: 93308.12932, 29: 111075.25090000001}, 12: {41: 34609.125916666664, 30: 111072.05928, 4: 49638.7146125}, 38: {32: 4759.762051, 18: 59329.418157142856, 23: 69217.8563, 37: 223884.8999}, 47: {19: 51913.9368, 34: 126326.076325, 27: 138840.3278, 2: 93266.13996}, 50: {21: 46144.664211111114, 28: 61706.93778888889, 48: 79337.33017142858}, 9: {16: 3856.0960035, 17: 8346.443298, 44: 59329.591114285715, 11: 60448.515175, 24: 69216.27285, 36: 277682.9544, 46: 111073.77368000001}, 20: {22: 41530.80236, 49: 46280.20334166667, 26: 111072.27296, 7: 111073.18175999999}, 31: {13: 1741.7058075, 33: 4770.0824299999995, 42: 83060.39558, 10: 108467.253875}}
# {(9, 1), (40, 12), (38, 1), (14, 50), (40, 31), (12, 31), (50, 38), (20, 38), (20, 12), (14, 31), (47, 31), (47, 1), (14, 38), (14, 1), (47, 38), (9, 50), (40, 38), (50, 1), (47, 12), (50, 12), (40, 1), (20, 31), (20, 1), (9, 31), (20, 50), (1, 31), (1, 12), (14, 12), (40, 50), (47, 50), (38, 12), (9, 38), (9, 12)}
# (9, 1, [36])
# [[5, 0, 8, 6], [45, 39, 25], [15, 43, 35, 3, 29], [41, 30, 4], [32, 18, 23, 37], [19, 34, 27, 2], [21, 28, 48], [16, 17, 44, 11, 24,
# {(12, 47), (38, 50), (31, 40), (9, 1), (31, 50), (40, 12), (38, 1), (14, 50), (38, 20), (20, 47), (1, 20), (31, 1), (20, 12), (38, 40), (9, 40), (31, 47), (31, 12), (14, 1), (14, 47), (20, 40), (9, 50), (40, 47), (50, 12), (9, 20), (9, 47), (50, 47), (1, 50), (1, 40), (50, 40), (14, 20), (14, 40), (50, 20), (1, 12), (1, 47), (14, 12), (31, 20), (38, 12), (38, 47), (9, 12)}
# (12, 47, [4])
# [[5, 8, 6], [45, 39, 36, 37], [15, 43, 35, 3], [41, 4, 0], [32, 18, 23, 48, 7], [19, 34, 2], [21, 28, 29], [16, 17, 44, 11, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 27, 25]]
# 4
# (38, 50, [48])
# [[5, 8, 6], [45, 39, 36, 37], [15, 43, 35, 3], [41, 0], [32, 18, 23, 48, 7], [19, 34, 2, 4], [21, 28, 29], [16, 17, 44, 11, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 27, 25]]
# 48
# (31, 40, [27])
# [[5, 8, 6], [45, 39, 36, 37], [15, 43, 35, 3], [41, 0], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 11, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 27, 25]]
# 27
# (9, 1, [11])
# [[5, 8, 6, 27], [45, 39, 36, 37], [15, 43, 35, 3], [41, 0], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 11, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 11
# (31, 50, [27])
# [[5, 8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35, 3], [41, 0], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 27
# (40, 12, [5])
# [[5, 8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35, 3], [41, 0], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 5
# (38, 1, [48])
# [[8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35, 3], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 48
# (14, 50, [3])
# [[8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35, 3], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 3
# (38, 20, [48])
# [[8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 48
# (20, 47, [26])
# [[8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 26], [13, 33, 42, 10, 30, 25]]
# 26
# (1, 20, [36])
# [[8, 6, 27], [45, 39, 36, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49], [13, 33, 42, 10, 30, 25]]
# 36
# (31, 1, [27])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 27
# (20, 12, [26])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 26
# (38, 40, [48])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 48
# (9, 40, [11])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 11
# (31, 47, [27])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 27
# (31, 12, [27])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 27
# (14, 1, [3])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 3
# (14, 47, [3])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 3
# (20, 40, [26])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 26
# (9, 50, [11])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 11
# (40, 47, [5])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 5
# (50, 12, [29])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 29, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 29
# (9, 20, [11])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 11
# (9, 47, [11])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 11
# (50, 47, [29])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 29
# (1, 50, [36])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 36
# (1, 40, [36])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 36
# (50, 40, [29])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 29
# (14, 20, [3])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 3
# (14, 40, [3])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 3
# (50, 20, [29])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 29
# (1, 12, [36])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 36
# (1, 47, [36])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 36
# (14, 12, [3])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 3
# (31, 20, [27])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 27
# (38, 12, [48])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 48
# (38, 47, [48])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 48
# (9, 12, [11])
# [[8, 6, 27], [45, 39, 37, 11], [15, 43, 35], [41, 0, 5, 29], [32, 18, 23, 7], [19, 34, 2, 4, 26], [21, 28, 48, 3], [16, 17, 44, 24, 46], [22, 49, 36], [13, 33, 42, 10, 30, 25]]
# 11
# At time step 4963 the number of switch migrated are : 39
# The migrated switches are [4, 48, 27, 11, 27, 5, 48, 3, 48, 26, 36, 27, 26, 48, 11, 27, 27, 3, 3, 26, 11, 5, 29, 11, 11, 29, 36, 36, 29, 3, 3, 29, 36, 36, 3, 27, 48, 48, 11]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 
# [[26, 0, 25, 5], [22, 49, 46, 30], [15, 43, 37, 10], [41, 4], [32, 24, 23, 3, 2], [19, 6, 29, 34], [21, 18, 11, 27], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 0
# (38, 1, [3])
# [[26, 25, 5], [22, 49, 46, 30], [15, 43, 37, 10], [41, 4, 0], [32, 24, 23, 3, 2], [19, 6, 29, 34], [21, 18, 11, 27], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 3
# (50, 14, [27])
# [[26, 25, 5], [22, 49, 46, 30, 3], [15, 43, 37, 10], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11, 27], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 27
# (38, 20, [3])
# [[26, 25, 5], [22, 49, 46, 30, 3], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 3
# (50, 38, [27])
# [[26, 25, 5], [22, 49, 46, 30, 3], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 27
# (1, 20, [49])
# [[26, 25, 5], [22, 49, 46, 30, 3], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48], [13, 33, 42, 7, 36, 28, 35]]
# 49
# (31, 1, [28])
# [[26, 25, 5], [22, 46, 30, 3], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49], [13, 33, 42, 7, 36, 28, 35]]
# 28
# (12, 20, [46])
# [[26, 25, 5], [22, 46, 30, 3, 28], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49], [13, 33, 42, 7, 36, 35]]
# 46
# (47, 20, [29])
# [[26, 25, 5], [22, 46, 30, 3, 28], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 29, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49], [13, 33, 42, 7, 36, 35]]
# 29
# (47, 1, [29])
# [[26, 25, 5], [22, 46, 30, 3, 28], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 29
# (31, 12, [28])
# [[26, 25, 5], [22, 46, 30, 3, 28], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 28
# (14, 1, [10])
# [[26, 25, 5], [22, 46, 30, 3, 28], [15, 43, 37, 10, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 10
# (47, 38, [29])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 29
# (40, 38, [0])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 0
# (50, 1, [27])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 27
# (38, 14, [3])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 3
# (47, 12, [29])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 29
# (40, 14, [0])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 0
# (9, 14, [30])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 30
# (12, 14, [46])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 46
# (50, 12, [27])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 27
# (9, 20, [30])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 30
# (40, 1, [0])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 0
# (12, 38, [46])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 46
# (40, 20, [0])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 0
# (14, 20, [10])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 10
# (50, 20, [27])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 27
# (31, 38, [28])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 28
# (31, 14, [28])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 28
# (31, 20, [28])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 28
# (47, 14, [29])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 29
# (9, 38, [30])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 30
# (9, 12, [30])
# [[26, 25, 5], [22, 46, 30, 3, 28, 10], [15, 43, 37, 27], [41, 4, 0], [32, 24, 23, 2], [19, 6, 34], [21, 18, 11], [16, 17, 44, 45, 8], [39, 48, 49, 29], [13, 33, 42, 7, 36, 35]]
# 30
# At time step 4998 the number of switch migrated are : 35
# The migrated switches are [46, 30, 0, 3, 27, 3, 27, 49, 28, 46, 29, 29, 28, 10, 29, 0, 27, 3, 29, 0, 30, 46, 27, 30, 0, 46, 0, 10, 27, 28, 28, 28, 29, 30, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 

# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 3
# (31, 14, [36])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 36
# (12, 50, [4])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 4
# (1, 38, [3])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 3
# (40, 50, [5])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 5
# (47, 50, [34])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 34
# (47, 14, [34])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 34
# (9, 38, [8])
# [[26, 25, 36], [22, 46, 30, 28, 10], [15, 43, 37, 3], [41, 0, 5], [32, 24, 2, 29], [19, 6], [21, 18, 11, 23, 27, 8], [16, 17, 44, 45, 34, 4], [39, 48, 49], [13, 33, 42, 7, 35]]
# 8
# At time step 4999 the number of switch migrated are : 39
# The migrated switches are [23, 36, 36, 5, 36, 27, 29, 34, 4, 29, 3, 27, 36, 5, 34, 29, 29, 8, 5, 34, 5, 8, 4, 4, 3, 3, 34, 3, 29, 29, 36, 3, 36, 4, 3, 5, 34, 34, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Controller	Controller Load Ratio
# 40 :	 0.06416128503421138
# 1 :	 0.05094737605660844
# 14 :	 0.05158704296089634
# 12 :	 0.019779342541686118
# 38 :	 0.05343123349267426
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.030123375807156884
# 20 :	 0.04360797472537847
# 31 :	 0.041758749105233285
# Switches in the controller 14 : [49, 19, 18, 32, 7]
# Switch selected is : 32
# The target controller set for 1 is : [41, 2, 35, 42, 45]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.06416128503421138
# 1 :	 0.051069901353120055
# 14 :	 0.05146451766438473
# 12 :	 0.019779342541686118
# 38 :	 0.05343123349267426
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.030123375807156884
# 20 :	 0.04360797472537847
# 31 :	 0.041758749105233285
# Switches in the controller 14 : [49, 19, 18, 7]
# Switch selected is : 7
# The target controller set for 20 is : [17, 5, 3, 43, 6]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.06416128503421138
# 1 :	 0.051069901353120055
# 14 :	 0.03640288728857599
# 12 :	 0.019779342541686118
# 38 :	 0.05343123349267426
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.030123375807156884
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 40 : [24, 36, 28, 37, 44]
# Switch selected is : 36
# The target controller set for 38 is : [22, 34, 8, 16, 10]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.049099654658402644
# 1 :	 0.051069901353120055
# 14 :	 0.03640288728857599
# 12 :	 0.019779342541686118
# 38 :	 0.068492863868483
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.030123375807156884
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 40 : [24, 28, 37, 44]
# Switch selected is : 28
# The target controller set for 12 is : [11, 48]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03403814969261799
# 1 :	 0.051069901353120055
# 14 :	 0.03640288728857599
# 12 :	 0.034840847507470775
# 38 :	 0.068492863868483
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.030123375807156884
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 38 : [22, 34, 8, 16, 10, 36]
# Switch selected is : 10
# The target controller set for 9 is : [46, 29]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03403814969261799
# 1 :	 0.051069901353120055
# 14 :	 0.03640288728857599
# 12 :	 0.034840847507470775
# 38 :	 0.04965052250929181
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.048965717166348066
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 38 : [22, 34, 8, 16, 36]
# Switch selected is : 16
# The target controller set for 14 is : [49, 19, 18]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03403814969261799
# 1 :	 0.051069901353120055
# 14 :	 0.03681133286406725
# 12 :	 0.034840847507470775
# 38 :	 0.04924207693380055
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.048965717166348066
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 38 : [22, 34, 8, 36]
# Switch selected is : 36
# The target controller set for 14 is : [49, 19, 18, 16]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03403814969261799
# 1 :	 0.051069901353120055
# 14 :	 0.05187296323987599
# 12 :	 0.034840847507470775
# 38 :	 0.034180446557991816
# 47 :	 0.04079389033980023
# 50 :	 0.03652538558927597
# 9 :	 0.048965717166348066
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 1 : [41, 2, 35, 42, 45, 32]
# Switch selected is : 32
# The target controller set for 50 is : [33, 30, 21, 39]
# The mean load ratio is : 0.043271565565292144
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03403814969261799
# 1 :	 0.05094737605660844
# 14 :	 0.05187296323987599
# 12 :	 0.034840847507470775
# 38 :	 0.034180446557991816
# 47 :	 0.04079389033980023
# 50 :	 0.03664791088578758
# 9 :	 0.048965717166348066
# 20 :	 0.05866960510118721
# 31 :	 0.041758749105233285
# Switches in the controller 1 : [41, 2, 35, 42, 45]
# Switch selected is : 45
# The target controller set for 12 is : [11, 48, 28]
# The mean load ratio is : 0.043271565565292144
#
# At time step 4975 the number of switch migrated are : 14
# The migrated switches are [10, 32, 7, 6, 48, 32, 7, 36, 28, 10, 16, 36, 32, 45]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4976
# The overloaded domains are : [1, 38, 40, 9, 12, 14, 47, 20, 31]
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03553196989438493
# 1 :	 0.04070403606677764
# 14 :	 0.04728996556170153
# 12 :	 0.03809060507527823
# 38 :	 0.03819882363760907
# 47 :	 0.03579498791604
# 50 :	 0.0341485800274744
# 9 :	 0.035707909405438575
# 20 :	 0.047642675732615526
# 31 :	 0.04382730035674098
# Switches in the controller 1 : [41, 2, 35, 42]
# Switch selected is : 35
# The target controller set for 14 is : [49, 19, 18, 16, 36]
# The mean load ratio is : 0.03969368536740609
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.04198941204922501
# 9 :	 0.05897514037218596
# 20 :	 0.02984847475278435
# 31 :	 0.031381769710205475
# Switches in the controller 50 : [30, 21, 39, 32, 13, 46]
# Switch selected is : 21
# The target controller set for 12 is : [11, 18, 5, 7, 43]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.030375985099996533
# 1 :	 0.044481151706535986
# 14 :	 0.042258802426195216
# 12 :	 0.05439253943999207
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.02984847475278435
# 31 :	 0.031381769710205475
# Switches in the controller 12 : [11, 18, 5, 7, 43, 21]
# Switch selected is : 18
# The target controller set for 14 is : [19, 36, 35, 6]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.030375985099996533
# 1 :	 0.044481151706535986
# 14 :	 0.05292948270253522
# 12 :	 0.043721859163652066
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.02984847475278435
# 31 :	 0.031381769710205475
# Switches in the controller 12 : [11, 5, 7, 43, 21]
# Switch selected is : 43
# The target controller set for 14 is : [19, 36, 35, 6, 18]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.030375985099996533
# 1 :	 0.044481151706535986
# 14 :	 0.06360024625668101
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.02984847475278435
# 31 :	 0.031381769710205475
# Switches in the controller 14 : [19, 36, 35, 6, 18, 43]
# Switch selected is : 18
# The target controller set for 20 is : [3]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.030375985099996533
# 1 :	 0.044481151706535986
# 14 :	 0.05292956598034101
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.04051915502912435
# 31 :	 0.031381769710205475
# Switches in the controller 14 : [19, 36, 35, 6, 43]
# Switch selected is : 6
# The target controller set for 40 is : [37, 44, 0]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.04104667980838131
# 1 :	 0.044481151706535986
# 14 :	 0.04225887127195624
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.04051915502912435
# 31 :	 0.031381769710205475
# Switches in the controller 14 : [19, 36, 35, 43]
# Switch selected is : 43
# The target controller set for 40 is : [37, 44, 0, 6]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.0517174433625271
# 1 :	 0.044481151706535986
# 14 :	 0.03158810771781045
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.03498915372007069
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.04051915502912435
# 31 :	 0.031381769710205475
# Switches in the controller 1 : [41, 2, 42, 24, 33]
# Switch selected is : 24
# The target controller set for 47 is : [26, 4, 27]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0517174433625271
# 1 :	 0.03381056553781639
# 14 :	 0.03158810771781045
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.04565973988879028
# 50 :	 0.03131863778859345
# 9 :	 0.05897514037218596
# 20 :	 0.04051915502912435
# 31 :	 0.031381769710205475
# Switches in the controller 9 : [29, 10, 49, 45, 28, 17]
# Switch selected is : 29
# The target controller set for 20 is : [3, 18]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0517174433625271
# 1 :	 0.03381056553781639
# 14 :	 0.03158810771781045
# 12 :	 0.033051095609506274
# 38 :	 0.02818314479151359
# 47 :	 0.04565973988879028
# 50 :	 0.03131863778859345
# 9 :	 0.04872832782734905
# 20 :	 0.05076596757396126
# 31 :	 0.031381769710205475
# Switches in the controller 9 : [10, 49, 45, 28, 17]
# Switch selected is : 17
# The target controller set for 12 is : [11, 5, 7, 21]
# The mean load ratio is : 0.03862047998080733
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0517174433625271
# 1 :	 0.03381056553781639
# 14 :	 0.03158810771781045
# 12 :	 0.03326266726315373
# 38 :	 0.02818314479151359
# 47 :	 0.04565973988879028
# 50 :	 0.03131863778859345
# 9 :	 0.048516756173701596
# 20 :	 0.05076596757396126
# 31 :	 0.031381769710205475
# Switches in the controller 9 : [10, 49, 45, 28]
# Switch selected is : 10
# The target controller set for 47 is : [26, 4, 27, 24]
# The mean load ratio is : 0.03862047998080733
#
# At time step 4978 the number of switch migrated are : 14
# The migrated switches are [6, 17, 43, 33, 21, 18, 43, 18, 6, 43, 24, 29, 17, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4979
# The overloaded domains are : [1, 40, 9, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.05530929734441254
# 38 :	 0.036289731961289484
# 47 :	 0.07461704437894945
# 50 :	 0.0532058420829458
# 9 :	 0.053060887374586516
# 20 :	 0.036402464925805886
# 31 :	 0.05317752354475768
# Switches in the controller 12 : [11, 5, 7, 21, 17]
# Switch selected is : 11
# The target controller set for 50 is : [30, 39, 32, 13, 46]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.04747762939126348
# 38 :	 0.036289731961289484
# 47 :	 0.07461704437894945
# 50 :	 0.06103751003609486
# 9 :	 0.053060887374586516
# 20 :	 0.036402464925805886
# 31 :	 0.05317752354475768
# Switches in the controller 50 : [30, 39, 32, 13, 46, 11]
# Switch selected is : 11
# The target controller set for 9 is : [49, 45, 28]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.04747762939126348
# 38 :	 0.036289731961289484
# 47 :	 0.07461704437894945
# 50 :	 0.0532058420829458
# 9 :	 0.060892555327735576
# 20 :	 0.036402464925805886
# 31 :	 0.05317752354475768
# Switches in the controller 50 : [30, 39, 32, 13, 46]
# Switch selected is : 30
# The target controller set for 47 is : [26, 4, 27, 24, 10]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.04747762939126348
# 38 :	 0.036289731961289484
# 47 :	 0.09581178683404741
# 50 :	 0.03201109962784784
# 9 :	 0.060892555327735576
# 20 :	 0.036402464925805886
# 31 :	 0.05317752354475768
# Switches in the controller 31 : [23, 15, 25, 48]
# Switch selected is : 48
# The target controller set for 9 is : [49, 45, 28, 11]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.04747762939126348
# 38 :	 0.036289731961289484
# 47 :	 0.09581178683404741
# 50 :	 0.03201109962784784
# 9 :	 0.08208777231884579
# 20 :	 0.036402464925805886
# 31 :	 0.03198230655364747
# Switches in the controller 9 : [49, 45, 28, 11, 48]
# Switch selected is : 48
# The target controller set for 12 is : [5, 7, 21, 17]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0.04253606298242752
# 12 :	 0.0686728463823737
# 38 :	 0.036289731961289484
# 47 :	 0.09581178683404741
# 50 :	 0.03201109962784784
# 9 :	 0.060892555327735576
# 20 :	 0.036402464925805886
# 31 :	 0.03198230655364747
# Switches in the controller 9 : [49, 45, 28, 11]
# Switch selected is : 45
# The target controller set for 50 is : [39, 32, 13, 46]
# The mean load ratio is : 0.049362664267042
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.0525573591546766
# 1 :	 0.036470428920568516
# 14 :	 0
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.06806591188182946
# 47 :	 0.04541725675758525
# 50 :	 0.03970753406441564
# 9 :	 0.030411777223643716
# 20 :	 0.039476642513648755
# 31 :	 0.05206490998989869
# Switches in the controller 38 : [22, 34, 8, 30, 39]
# Switch selected is : 39
# The target controller set for 1 is : [2, 42, 3, 27]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.05739526049013381
# 47 :	 0.04541725675758525
# 50 :	 0.03970753406441564
# 9 :	 0.030411777223643716
# 20 :	 0.039476642513648755
# 31 :	 0.05206490998989869
# Switches in the controller 38 : [22, 34, 8, 30]
# Switch selected is : 8
# The target controller set for 47 is : [26, 10, 33, 24]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.06174648249999575
# 50 :	 0.03970753406441564
# 9 :	 0.030411777223643716
# 20 :	 0.039476642513648755
# 31 :	 0.05206490998989869
# Switches in the controller 47 : [26, 10, 33, 24, 8]
# Switch selected is : 24
# The target controller set for 9 is : [28, 11]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.05107567522834208
# 50 :	 0.03970753406441564
# 9 :	 0.04108258449529739
# 20 :	 0.039476642513648755
# 31 :	 0.05206490998989869
# Switches in the controller 47 : [26, 10, 33, 8]
# Switch selected is : 33
# The target controller set for 31 is : [23, 15, 25, 4, 5]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.0509536077349184
# 50 :	 0.03970753406441564
# 9 :	 0.04108258449529739
# 20 :	 0.039476642513648755
# 31 :	 0.05218697748332237
# Switches in the controller 47 : [26, 10, 8]
# Switch selected is : 26
# The target controller set for 9 is : [28, 11, 24]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.032817985869362354
# 50 :	 0.03970753406441564
# 9 :	 0.05921820636085344
# 20 :	 0.039476642513648755
# 31 :	 0.05218697748332237
# Switches in the controller 9 : [28, 11, 24, 26]
# Switch selected is : 24
# The target controller set for 50 is : [32, 13, 46, 45, 44]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.032817985869362354
# 50 :	 0.05037834133606932
# 9 :	 0.048547399089199764
# 20 :	 0.039476642513648755
# 31 :	 0.05218697748332237
# Switches in the controller 9 : [28, 11, 26]
# Switch selected is : 26
# The target controller set for 31 is : [23, 15, 25, 4, 5, 33]
# The mean load ratio is : 0.0472601962167865
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.05586603692174
# 1 :	 0.05500862730344857
# 14 :	 0.05761215344747379
# 12 :	 0.039641763455876874
# 38 :	 0.04106603474772331
# 47 :	 0.032817985869362354
# 50 :	 0.05037834133606932
# 9 :	 0.03041177722364372
# 20 :	 0.039476642513648755
# 31 :	 0.07032259934887841
# Switches in the controller 14 : [19, 36, 35, 49]
# Switch selected is : 49
# The target controller set for 12 is : [17, 48, 0, 41]
# The mean load ratio is : 0.0472601962167865
#
# At time step 4980 the number of switch migrated are : 17
# The migrated switches are [33, 41, 44, 21, 5, 7, 24, 39, 16, 39, 8, 24, 33, 26, 24, 26, 49]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4981
# The overloaded domains are : [1, 38, 40, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.04714402496139202
# 1 :	 0.07854806452537892
# 14 :	 0.030943801617443277
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.028090714350735145
# 50 :	 0.04183307688742461
# 9 :	 0.01934498296286158
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 40 : [37, 6, 43, 7, 16]
# Switch selected is : 16
# The target controller set for 47 is : [10, 8]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.04700349259296062
# 1 :	 0.07854806452537892
# 14 :	 0.030943801617443277
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.028231246719166547
# 50 :	 0.04183307688742461
# 9 :	 0.01934498296286158
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 40 : [37, 6, 43, 7]
# Switch selected is : 7
# The target controller set for 47 is : [10, 8, 16]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03740116996243337
# 1 :	 0.07854806452537892
# 14 :	 0.030943801617443277
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.01934498296286158
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 1 : [2, 42, 3, 27, 39]
# Switch selected is : 39
# The target controller set for 40 is : [37, 6, 43]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.0678773052235091
# 14 :	 0.030943801617443277
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.01934498296286158
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 1 : [2, 42, 3, 27]
# Switch selected is : 42
# The target controller set for 9 is : [28, 11]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.05720666576644901
# 14 :	 0.030943801617443277
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.030015622419921666
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 1 : [2, 3, 27]
# Switch selected is : 27
# The target controller set for 14 is : [19, 36, 35]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.04760451215297163
# 14 :	 0.04054595523092066
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.030015622419921666
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 1 : [2, 3]
# Switch selected is : 2
# The target controller set for 9 is : [28, 11, 42]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.033276745195237274
# 14 :	 0.04054595523092066
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.04434338937765602
# 20 :	 0.03094357318415069
# 31 :	 0.0634803110564543
# Switches in the controller 31 : [23, 15, 25, 4, 5, 33, 26]
# Switch selected is : 26
# The target controller set for 14 is : [19, 36, 35, 27]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.033276745195237274
# 14 :	 0.050147925521201606
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.04434338937765602
# 20 :	 0.03094357318415069
# 31 :	 0.05387834076617336
# Switches in the controller 31 : [23, 15, 25, 4, 5, 33]
# Switch selected is : 33
# The target controller set for 14 is : [19, 36, 35, 27, 26]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.033276745195237274
# 14 :	 0.05027021882273484
# 12 :	 0.04082711261138764
# 38 :	 0.04028428331282832
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.04434338937765602
# 20 :	 0.03094357318415069
# 31 :	 0.053756047464640126
# Switches in the controller 31 : [23, 15, 25, 4, 5]
# Switch selected is : 5
# The target controller set for 38 is : [22, 34, 30]
# The mean load ratio is : 0.042143994547005646
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.04807192926430319
# 1 :	 0.033276745195237274
# 14 :	 0.05027021882273484
# 12 :	 0.04082711261138764
# 38 :	 0.06029553923030466
# 47 :	 0.0378335693496938
# 50 :	 0.04183307688742461
# 9 :	 0.04434338937765602
# 20 :	 0.03094357318415069
# 31 :	 0.03374479154716378
# Switches in the controller 14 : [19, 36, 35, 27, 26, 33]
# Switch selected is : 26
# The target controller set for 40 is : [37, 6, 43, 39]
# The mean load ratio is : 0.042143994547005646
#
# At time step 4981 the number of switch migrated are : 10
# The migrated switches are [16, 7, 39, 42, 27, 2, 26, 33, 5, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4982
# The overloaded domains are : [38, 40, 9, 12, 14, 47, 50, 31]
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.06356084997329826
# 1 :	 0.01630871922507272
# 14 :	 0.046270414084752416
# 12 :	 0.04628399662617216
# 38 :	 0.0420118477765324
# 47 :	 0.03886646852059075
# 50 :	 0.04464392397361005
# 9 :	 0.03949431957683676
# 20 :	 0.033744603399907994
# 31 :	 0.03630004590188911
# Switches in the controller 38 : [22, 34, 30, 5]
# Switch selected is : 5
# The target controller set for 9 is : [28, 11, 42, 2]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.06356084997329826
# 1 :	 0.01630871922507272
# 14 :	 0.046270414084752416
# 12 :	 0.04628399662617216
# 38 :	 0.03254277578372459
# 47 :	 0.03886646852059075
# 50 :	 0.04464392397361005
# 9 :	 0.04896339156964457
# 20 :	 0.033744603399907994
# 31 :	 0.03630004590188911
# Switches in the controller 14 : [19, 36, 35, 27, 33]
# Switch selected is : 19
# The target controller set for 20 is : [18, 29, 21]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.06356084997329826
# 1 :	 0.01630871922507272
# 14 :	 0.035599664196984786
# 12 :	 0.04628399662617216
# 38 :	 0.03254277578372459
# 47 :	 0.03886646852059075
# 50 :	 0.04464392397361005
# 9 :	 0.04896339156964457
# 20 :	 0.044415353287675624
# 31 :	 0.03630004590188911
# Switches in the controller 50 : [32, 13, 46, 45, 44, 24]
# Switch selected is : 13
# The target controller set for 40 is : [37, 6, 43, 39, 26]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.06366688474557164
# 1 :	 0.01630871922507272
# 14 :	 0.035599664196984786
# 12 :	 0.04628399662617216
# 38 :	 0.03254277578372459
# 47 :	 0.03886646852059075
# 50 :	 0.044537889201336674
# 9 :	 0.04896339156964457
# 20 :	 0.044415353287675624
# 31 :	 0.03630004590188911
# Switches in the controller 50 : [32, 46, 45, 44, 24]
# Switch selected is : 44
# The target controller set for 12 is : [17, 48, 0, 41, 49]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.06366688474557164
# 1 :	 0.01630871922507272
# 14 :	 0.035599664196984786
# 12 :	 0.056954693482534395
# 38 :	 0.03254277578372459
# 47 :	 0.03886646852059075
# 50 :	 0.033867192344974435
# 9 :	 0.04896339156964457
# 20 :	 0.044415353287675624
# 31 :	 0.03630004590188911
# Switches in the controller 40 : [37, 6, 43, 39, 26, 13]
# Switch selected is : 6
# The target controller set for 38 is : [22, 34, 30]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.05299619003718686
# 1 :	 0.01630871922507272
# 14 :	 0.035599664196984786
# 12 :	 0.056954693482534395
# 38 :	 0.04321347049210936
# 47 :	 0.03886646852059075
# 50 :	 0.033867192344974435
# 9 :	 0.04896339156964457
# 20 :	 0.044415353287675624
# 31 :	 0.03630004590188911
# Switches in the controller 40 : [37, 43, 39, 26, 13]
# Switch selected is : 43
# The target controller set for 9 is : [28, 11, 42, 2, 5]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.042325481192232686
# 1 :	 0.01630871922507272
# 14 :	 0.035599664196984786
# 12 :	 0.056954693482534395
# 38 :	 0.04321347049210936
# 47 :	 0.03886646852059075
# 50 :	 0.033867192344974435
# 9 :	 0.05963410041459874
# 20 :	 0.044415353287675624
# 31 :	 0.03630004590188911
# Switches in the controller 40 : [37, 39, 26, 13]
# Switch selected is : 26
# The target controller set for 1 is : [3]
# The mean load ratio is : 0.04074851890586627
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 38 :	 0.05015929866106722
# 47 :	 0.03658973458112781
# 50 :	 0.025889667666207587
# 9 :	 0.047157675739765065
# 20 :	 0.046965463445848205
# 31 :	 0.04969434607703072
# Switches in the controller 14 : [5, 43, 46, 32, 42, 2, 11]
# Switch selected is : 43
# The target controller set for 20 is : [7, 49, 41]
# The mean load ratio is : 0.050225330393915704
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.04521864565035821
# 1 :	 0.046979407162330566
# 14 :	 0.08027793748331241
# 12 :	 0.06265031173187458
# 38 :	 0.05015929866106722
# 47 :	 0.03658973458112781
# 50 :	 0.025889667666207587
# 9 :	 0.047157675739765065
# 20 :	 0.05763627918608289
# 31 :	 0.04969434607703072
# Switches in the controller 14 : [5, 46, 32, 42, 2, 11]
# Switch selected is : 2
# The target controller set for 50 is : [3, 22, 13]
# The mean load ratio is : 0.050225330393915704
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.04521864565035821
# 1 :	 0.046979407162330566
# 14 :	 0.060918097512726505
# 12 :	 0.06265031173187458
# 38 :	 0.05015929866106722
# 47 :	 0.03658973458112781
# 50 :	 0.0452495076367935
# 9 :	 0.047157675739765065
# 20 :	 0.05763627918608289
# 31 :	 0.04969434607703072
# Switches in the controller 14 : [5, 46, 32, 42, 11]
# Switch selected is : 5
# The target controller set for 12 is : [10, 39, 44, 24, 28]
# The mean load ratio is : 0.050225330393915704
#
# At time step 4997 the number of switch migrated are : 12
# The migrated switches are [23, 16, 36, 2, 11, 24, 41, 13, 28, 43, 2, 5]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# The overloaded domains are : [1, 38, 40, 9, 12, 14, 47, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.07508308729857276
# 38 :	 0.04785935609776549
# 47 :	 0.03204988525556872
# 50 :	 0.02532779088864457
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.05051636667076137
# Switches in the controller 12 : [10, 39, 44, 24, 28, 5]
# Switch selected is : 10
# The target controller set for 31 is : [48, 4, 6, 0, 16]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.05987156340106478
# 38 :	 0.04785935609776549
# 47 :	 0.03204988525556872
# 50 :	 0.02532779088864457
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.06572789056826935
# Switches in the controller 12 : [39, 44, 24, 28, 5]
# Switch selected is : 24
# The target controller set for 50 is : [3, 22, 13, 2]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.049200767843082485
# 38 :	 0.04785935609776549
# 47 :	 0.03204988525556872
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.06572789056826935
# Switches in the controller 12 : [39, 44, 28, 5]
# Switch selected is : 39
# The target controller set for 31 is : [48, 4, 6, 0, 16, 10]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.04785935609776549
# 47 :	 0.03204988525556872
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.07639867898345576
# Switches in the controller 38 : [19, 21, 35, 26]
# Switch selected is : 26
# The target controller set for 47 is : [25, 33, 15, 27]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.03201208626799308
# 47 :	 0.047897155085341134
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.07639867898345576
# Switches in the controller 31 : [48, 4, 6, 0, 16, 10, 39]
# Switch selected is : 0
# The target controller set for 38 is : [19, 21, 35]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.04268278097637786
# 47 :	 0.047897155085341134
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.05303568252909697
# 31 :	 0.06572798427507098
# Switches in the controller 31 : [48, 4, 6, 16, 10, 39]
# Switch selected is : 39
# The target controller set for 20 is : [7, 49, 41, 43]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.04268278097637786
# 47 :	 0.047897155085341134
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.06370647094428339
# 31 :	 0.05505719585988457
# Switches in the controller 31 : [48, 4, 6, 16, 10]
# Switch selected is : 10
# The target controller set for 47 is : [25, 33, 15, 27, 26]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.04268278097637786
# 47 :	 0.06310867898284911
# 50 :	 0.035998586446626867
# 9 :	 0.035626276473311694
# 20 :	 0.06370647094428339
# 31 :	 0.039845671962376594
# Switches in the controller 20 : [7, 49, 41, 43, 39]
# Switch selected is : 7
# The target controller set for 9 is : [8, 29, 17, 23]
# The mean load ratio is : 0.04325509497393536
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.03853019159205788
# 1 :	 0.03549910207761973
# 14 :	 0.039023210855954435
# 12 :	 0.03852997942789607
# 38 :	 0.04268278097637786
# 47 :	 0.06310867898284911
# 50 :	 0.035998586446626867
# 9 :	 0.05147340774055206
# 20 :	 0.04785933967704302
# 31 :	 0.039845671962376594
# Switches in the controller 20 : [49, 41, 43, 39]
# Switch selected is : 39
# The target controller set for 1 is : [37, 18, 36]
# The mean load ratio is : 0.04325509497393536
#
# At time step 4998 the number of switch migrated are : 9
# The migrated switches are [10, 24, 39, 26, 0, 39, 10, 7, 39]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# The overloaded domains are : [1, 38, 40, 9, 12, 47, 50, 20, 31]
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.03889529198072784
# 1 :	 0.04614873253963726
# 14 :	 0.02266171604757864
# 12 :	 0.03889530773855774
# 38 :	 0.04268271530376536
# 47 :	 0.04101264235552752
# 50 :	 0.04299237383698476
# 9 :	 0.04583147667073035
# 20 :	 0.03154393658329405
# 31 :	 0.036321454953521036
# Switches in the controller 9 : [8, 29, 17, 23, 7]
# Switch selected is : 23
# The target controller set for 40 is : [34, 45, 30]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.04614873253963726
# 14 :	 0.02266171604757864
# 12 :	 0.03889530773855774
# 38 :	 0.04268271530376536
# 47 :	 0.04101264235552752
# 50 :	 0.04299237383698476
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.036321454953521036
# Switches in the controller 38 : [19, 21, 35, 0]
# Switch selected is : 0
# The target controller set for 14 is : [46, 32, 42, 11]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.04614873253963726
# 14 :	 0.03333241075596341
# 12 :	 0.03889530773855774
# 38 :	 0.032012020595380594
# 47 :	 0.04101264235552752
# 50 :	 0.04299237383698476
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.036321454953521036
# Switches in the controller 50 : [3, 22, 13, 2, 24]
# Switch selected is : 3
# The target controller set for 31 is : [48, 4, 6, 16]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.04614873253963726
# 14 :	 0.03333241075596341
# 12 :	 0.03889530773855774
# 38 :	 0.032012020595380594
# 47 :	 0.04101264235552752
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 12 : [44, 28, 5]
# Switch selected is : 5
# The target controller set for 14 is : [46, 32, 42, 11, 0]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.04614873253963726
# 14 :	 0.05135448254196602
# 12 :	 0.020873235952555132
# 38 :	 0.032012020595380594
# 47 :	 0.04101264235552752
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 1 : [37, 18, 36, 39]
# Switch selected is : 39
# The target controller set for 47 is : [25, 33, 15, 27, 26, 10]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.035478049668252715
# 14 :	 0.05135448254196602
# 12 :	 0.020873235952555132
# 38 :	 0.032012020595380594
# 47 :	 0.05168332522691207
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 47 : [25, 33, 15, 27, 26, 10, 39]
# Switch selected is : 15
# The target controller set for 38 is : [19, 21, 35]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.035478049668252715
# 14 :	 0.05135448254196602
# 12 :	 0.020873235952555132
# 38 :	 0.03216719625918634
# 47 :	 0.05152814956310632
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 47 : [25, 33, 27, 26, 10, 39]
# Switch selected is : 25
# The target controller set for 14 is : [46, 32, 42, 11, 0, 5]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.035478049668252715
# 14 :	 0.061557074145416696
# 12 :	 0.020873235952555132
# 38 :	 0.03216719625918634
# 47 :	 0.041325557959655645
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 47 : [33, 27, 26, 10, 39]
# Switch selected is : 39
# The target controller set for 14 is : [46, 32, 42, 11, 0, 5, 25]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.049565958955537524
# 1 :	 0.035478049668252715
# 14 :	 0.07222775701680124
# 12 :	 0.020873235952555132
# 38 :	 0.03216719625918634
# 47 :	 0.030654875088271097
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 40 : [34, 45, 30, 23]
# Switch selected is : 30
# The target controller set for 12 is : [44, 28]
# The mean load ratio is : 0.03869856480103245
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.039363495236395984
# 1 :	 0.035478049668252715
# 14 :	 0.07222775701680124
# 12 :	 0.031075699671696676
# 38 :	 0.03216719625918634
# 47 :	 0.030654875088271097
# 50 :	 0.027381585935802838
# 9 :	 0.03516080969592066
# 20 :	 0.03154393658329405
# 31 :	 0.05193224285470296
# Switches in the controller 40 : [34, 45, 23]
# Switch selected is : 45
# The target controller set for 14 is : [46, 32, 42, 11, 0, 5, 25, 39]
# The mean load ratio is : 0.03869856480103245
#
# At time step 4999 the number of switch migrated are : 10
# The migrated switches are [23, 0, 3, 5, 39, 15, 25, 39, 30, 45]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 0.7
epsilon_dec = 0.0025
epsilon_min = 0.05

load_controller = []

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon * epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.05650461148973883
# 1 :	 0.037421136504957354
# 14 :	 0.03872047889924742
# 12 :	 0.03527615293378426
# 38 :	 0.03959165068424225
# 47 :	 0.05435669464891375
# 50 :	 0.03865658524108023
# 9 :	 0.05301600529195396
# 20 :	 0.049269140190894664
# 31 :	 0.032003432442777376
# [(543478.3069, 49), (543468.1955, 7), (415312.4401, 39), (415312.4401, 18)]
# Switches in the controller 20 : [39, 7, 18, 49]
# Switch selected is : 49
# The underloaded domains are : [1, 14, 12, 38, 50, 31]
# The target controller set for 50 is : [13, 45, 30, 25]
# The mean load ratio is : 0.04348158883275901
# The reward is = 0.2821087411372203
# Q value = 6.008436381273773
#
# At time step 4964 the number of switch migrated are : 9
# The migrated switches are [4, 2, 26, 5, 4, 49, 5, 46, 49]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4965
# 0.2797182972891735
# The overloaded domains are : [1, 40, 9, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.05527300945009454
# 1 :	 0.037660200055804706
# 14 :	 0.04667047986500297
# 12 :	 0.04068064972573237
# 38 :	 0.032758968345170336
# 47 :	 0.052572614363867474
# 50 :	 0.06452484016357553
# 9 :	 0.07578941261457631
# 20 :	 0.03928040685344277
# 31 :	 0.033687219675989005
# [(698164.6282, 26), (543268.0748, 34), (494511.4789, 2), (415299.7964, 44)]
# Switches in the controller 40 : [44, 34, 2, 26]
# Switch selected is : 26
# The underloaded domains are : [1, 14, 12, 38, 20, 31]
# The target controller set for 20 is : [39, 7, 18]
# The mean load ratio is : 0.047889780111325594
# The reward is = 0.27972069653012815
# Q value = 5.961228087745061
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.037334709340259745
# 1 :	 0.037660200055804706
# 14 :	 0.04667047986500297
# 12 :	 0.04068064972573237
# 38 :	 0.032758968345170336
# 47 :	 0.052572614363867474
# 50 :	 0.06452484016357553
# 9 :	 0.07578941261457631
# 20 :	 0.05721870696327758
# 31 :	 0.033687219675989005
# [(698183.9288, 7), (698164.6282, 26), (415311.309, 39), (415311.309, 18)]
# Switches in the controller 20 : [39, 7, 18, 26]
# Switch selected is : 7
# The underloaded domains are : [40, 1, 14, 12, 38, 31]
# The target controller set for 12 is : [0, 37, 29]
# The mean load ratio is : 0.047889780111325594
# The reward is = 0.562459563848781
# Q value = 5.919278384084692
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.037334709340259745
# 1 :	 0.037660200055804706
# 14 :	 0.04667047986500297
# 12 :	 0.058619445735733286
# 38 :	 0.032758968345170336
# 47 :	 0.052572614363867474
# 50 :	 0.06452484016357553
# 9 :	 0.07578941261457631
# 20 :	 0.03927991095327666
# 31 :	 0.033687219675989005
# [(1286478.575, 3), (698189.9351, 27), (543268.0748, 5), (415299.7964, 23), (6512.856675, 17)]
# Switches in the controller 9 : [17, 27, 23, 3, 5]
# Switch selected is : 3
# The underloaded domains are : [40, 1, 14, 38, 20, 31]
# The target controller set for 38 is : [15, 43, 19, 35, 11]
# The mean load ratio is : 0.047889780111325594
# The reward is = 0.5879466044997029
# Q value = 7.28280687505665
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.037334709340259745
# 1 :	 0.037660200055804706
# 14 :	 0.04667047986500297
# 12 :	 0.058619445735733286
# 38 :	 0.065813118943891
# 47 :	 0.052572614363867474
# 50 :	 0.06452484016357553
# 9 :	 0.042735262015855646
# 20 :	 0.03927991095327666
# 31 :	 0.033687219675989005
# [(698195.7172, 49), (698191.7991, 30), (698173.6291, 25), (415305.5007, 45), (1461.671892, 13)]
# Switches in the controller 50 : [13, 45, 30, 25, 49]
# Switch selected is : 49
# The underloaded domains are : [40, 1, 14, 9, 20, 31]
# Taking a random action
# The target controller set for 14 is : [32, 24, 48, 46]
# The mean load ratio is : 0.047889780111325594
# The reward is = 0.411289845375772
# Q value = 5.480162067521103
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.037334709340259745
# 1 :	 0.037660200055804706
# 14 :	 0.06460957876038145
# 12 :	 0.058619445735733286
# 38 :	 0.065813118943891
# 47 :	 0.052572614363867474
# 50 :	 0.04658574126819705
# 9 :	 0.042735262015855646
# 20 :	 0.03927991095327666
# 31 :	 0.033687219675989005
# [(698183.9288, 36), (512583.2917, 4), (415310.2141, 42), (415310.2141, 21), (4756.051434, 33)]
# Switches in the controller 47 : [33, 42, 21, 36, 4]
# Switch selected is : 36
# The underloaded domains are : [40, 1, 50, 9, 20, 31]
# Taking a random action
# The target controller set for 1 is : [41, 28, 10]
# The mean load ratio is : 0.047889780111325594
# The reward is = 0.7173229156418994
# Q value = 5.624591661459999
#
# At time step 4965 the number of switch migrated are : 5
# The migrated switches are [26, 7, 3, 49, 36]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4966
# 0.16689570542213328
# The overloaded domains are : [1, 38, 40, 9, 12, 14, 50, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.041007022877182706
# 1 :	 0.051121402387770826
# 14 :	 0.05156584487903771
# 12 :	 0.05337029927377015
# 38 :	 0.047080633119886965
# 47 :	 0.032655490950757454
# 50 :	 0.037965574037642086
# 9 :	 0.04043181154736283
# 20 :	 0.0349318332892882
# 31 :	 0.03689549729845434
# [(603949.7068, 37), (528972.9298, 29), (528960.2265, 7), (415307.0, 0)]
# Switches in the controller 12 : [0, 37, 29, 7]
# Switch selected is : 37
# The underloaded domains are : [40, 47, 50, 9, 20, 31]
# The target controller set for 20 is : [39, 18, 26]
# The mean load ratio is : 0.04270254096611533
# The reward is = 0.6372669151240465
# Q value = 5.747552842746585
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.041007022877182706
# 1 :	 0.051121402387770826
# 14 :	 0.05156584487903771
# 12 :	 0.03785271122328871
# 38 :	 0.047080633119886965
# 47 :	 0.032655490950757454
# 50 :	 0.037965574037642086
# 9 :	 0.04043181154736283
# 20 :	 0.05044942133976964
# 31 :	 0.03689549729845434
# [(528967.1453, 49), (528964.3052, 48), (528952.4477, 46), (415310.87, 24), (4765.127518, 32)]
# Switches in the controller 14 : [32, 24, 48, 46, 49]
# Switch selected is : 49
# The underloaded domains are : [40, 12, 47, 50, 9, 31]
# The target controller set for 40 is : [44, 34, 2]
# The mean load ratio is : 0.04270254096611533
# The reward is = 0.506262529104669
# Q value = 5.84383119409616
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.05459804570670908
# 1 :	 0.051121402387770826
# 14 :	 0.03797482204951134
# 12 :	 0.03785271122328871
# 38 :	 0.047080633119886965
# 47 :	 0.032655490950757454
# 50 :	 0.037965574037642086
# 9 :	 0.04043181154736283
# 20 :	 0.05044942133976964
# 31 :	 0.03689549729845434
# [(464126.9265, 3), (415307.0, 35), (415306.8118, 43), (415306.4224, 19), (116831.1798, 11), (5515.616358, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 11, 3]
# Switch selected is : 3
# The underloaded domains are : [14, 12, 47, 50, 9, 31]
# The target controller set for 14 is : [32, 24, 48, 46]
# The mean load ratio is : 0.04270254096611533
# The reward is = 0.5244277392812101
# Q value = 6.8797350343256
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.05459804570670908
# 1 :	 0.051121402387770826
# 14 :	 0.049899872045351616
# 12 :	 0.03785271122328871
# 38 :	 0.03515558312404669
# 47 :	 0.032655490950757454
# 50 :	 0.037965574037642086
# 9 :	 0.04043181154736283
# 20 :	 0.05044942133976964
# 31 :	 0.03689549729845434
# [(603949.7068, 37), (528951.9503, 26), (415303.3309, 39), (415303.3309, 18)]
# Switches in the controller 20 : [39, 18, 26, 37]
# Switch selected is : 37
# The underloaded domains are : [12, 38, 47, 50, 9, 31]
# The target controller set for 38 is : [15, 43, 19, 35, 11]
# The mean load ratio is : 0.04270254096611533
# The reward is = 0.41832532859516347
# Q value = 5.955689086006114
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.05459804570670908
# 1 :	 0.051121402387770826
# 14 :	 0.049899872045351616
# 12 :	 0.03785271122328871
# 38 :	 0.050673171174528124
# 47 :	 0.032655490950757454
# 50 :	 0.037965574037642086
# 9 :	 0.04043181154736283
# 20 :	 0.0349318332892882
# 31 :	 0.03689549729845434
# [(528967.1453, 28), (528960.2265, 36), (516423.8421, 10), (415310.8317, 41)]
# Switches in the controller 1 : [41, 28, 10, 36]
# Switch selected is : 28
# The underloaded domains are : [12, 47, 50, 9, 20, 31]
# The target controller set for 9 is : [17, 27, 23, 5]
# The mean load ratio is : 0.04270254096611533
# The reward is = 0.6939022642617202
# Q value = 6.052581821443475
#
# At time step 4966 the number of switch migrated are : 5
# The migrated switches are [37, 49, 3, 37, 28]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4967
# 0.17775863601352682
# The overloaded domains are : [1, 38, 40, 9, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.04557212500560523
# 1 :	 0.03297753167980778
# 14 :	 0.04584637626850563
# 12 :	 0.031293249450227524
# 38 :	 0.049666559091303145
# 47 :	 0.03429694583455291
# 50 :	 0.03132514171451703
# 9 :	 0.044934600016168676
# 20 :	 0.031653019170331524
# 31 :	 0.037740462966639764
# [(523938.9932, 34), (433114.7871, 2), (415307.1451, 44), (401321.3921, 49)]
# Switches in the controller 40 : [44, 34, 2, 49]
# Switch selected is : 34
# The underloaded domains are : [1, 12, 47, 50, 20, 31]
# The target controller set for 47 is : [33, 42, 21, 4]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.7291355973704328
# Q value = 6.1819126707734435
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.032110293054167655
# 1 :	 0.03297753167980778
# 14 :	 0.04584637626850563
# 12 :	 0.031293249450227524
# 38 :	 0.049666559091303145
# 47 :	 0.04775877778599048
# 50 :	 0.03132514171451703
# 9 :	 0.044934600016168676
# 20 :	 0.031653019170331524
# 31 :	 0.037740462966639764
# [(561660.2921, 3), (415308.9314, 24), (401316.5991, 48), (401312.7828, 46), (4757.662799000001, 32)]
# Switches in the controller 14 : [32, 24, 48, 46, 3]
# Switch selected is : 3
# The underloaded domains are : [40, 1, 12, 50, 20, 31]
# The target controller set for 50 is : [13, 45, 30, 25]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.597916743075569
# Q value = 5.927607063604163
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.032110293054167655
# 1 :	 0.03297753167980778
# 14 :	 0.03141535173286979
# 12 :	 0.031293249450227524
# 38 :	 0.049666559091303145
# 47 :	 0.04775877778599048
# 50 :	 0.04575616625015287
# 9 :	 0.044934600016168676
# 20 :	 0.031653019170331524
# 31 :	 0.037740462966639764
# [(523938.9932, 34), (499465.4592, 4), (415308.0381, 42), (415308.0381, 21), (4767.045032, 33)]
# Switches in the controller 47 : [33, 42, 21, 4, 34]
# Switch selected is : 34
# The underloaded domains are : [40, 1, 14, 12, 20, 31]
# The target controller set for 40 is : [44, 2, 49]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.7870687525077942
# Q value = 6.092774014893492
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.04557212500560523
# 1 :	 0.03297753167980778
# 14 :	 0.03141535173286979
# 12 :	 0.031293249450227524
# 38 :	 0.049666559091303145
# 47 :	 0.03429694583455291
# 50 :	 0.04575616625015287
# 9 :	 0.044934600016168676
# 20 :	 0.031653019170331524
# 31 :	 0.037740462966639764
# [(634008.1088, 37), (415307.8277, 19), (415307.0, 35), (415303.4046, 43), (48015.14533, 11), (5097.572435, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 11, 37]
# Switch selected is : 37
# The underloaded domains are : [1, 14, 12, 47, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 8]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.6045755701443154
# Q value = 6.071154196983921
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.04557212500560523
# 1 :	 0.03297753167980778
# 14 :	 0.03141535173286979
# 12 :	 0.031293249450227524
# 38 :	 0.033376665177535264
# 47 :	 0.03429694583455291
# 50 :	 0.04575616625015287
# 9 :	 0.044934600016168676
# 20 :	 0.031653019170331524
# 31 :	 0.054030356880407644
# [(523938.9932, 5), (415307.1451, 23), (401321.3921, 28), (401316.5991, 27), (6985.502601, 17)]
# Switches in the controller 9 : [17, 27, 23, 5, 28]
# Switch selected is : 5
# The underloaded domains are : [1, 14, 12, 38, 47, 20]
# The target controller set for 38 is : [15, 43, 19, 35, 11]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.5096488742336704
# Q value = 6.188697758087354
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.04557212500560523
# 1 :	 0.03297753167980778
# 14 :	 0.03141535173286979
# 12 :	 0.031293249450227524
# 38 :	 0.04683849712897284
# 47 :	 0.03429694583455291
# 50 :	 0.04575616625015287
# 9 :	 0.0314727680647311
# 20 :	 0.031653019170331524
# 31 :	 0.054030356880407644
# [(561660.2921, 3), (415308.9314, 45), (401322.0876, 30), (401312.7828, 25), (1241.170272, 13)]
# Switches in the controller 50 : [13, 45, 30, 25, 3]
# Switch selected is : 3
# The underloaded domains are : [1, 14, 12, 47, 9, 20]
# Taking a random action
# The target controller set for 47 is : [33, 42, 21, 4]
# The mean load ratio is : 0.03853060111976592
# The reward is = 0.4600005761627483
# Q value = 5.982399660200148
#
# At time step 4967 the number of switch migrated are : 6
# The migrated switches are [34, 3, 34, 37, 5, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4968
# 0.1228066543351976
# The overloaded domains are : [38, 40, 9, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.06056802172114515
# 1 :	 0.04097590121193659
# 14 :	 0.05188189826558072
# 12 :	 0.051759363062088296
# 38 :	 0.053888282536635065
# 47 :	 0.06227290221802139
# 50 :	 0.05184695551725401
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.05205454453821723
# [(1022990.882, 3), (565311.9531, 4), (415305.55, 42), (415305.55, 21), (4768.206339, 33)]
# Switches in the controller 47 : [33, 42, 21, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [1, 14, 12, 50, 20]
# The target controller set for 50 is : [13, 45, 30, 25]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.33849391617871194
# Q value = 5.849820338266423
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.06056802172114515
# 1 :	 0.04097590121193659
# 14 :	 0.05188189826558072
# 12 :	 0.051759363062088296
# 38 :	 0.053888282536635065
# 47 :	 0.035988675389956204
# 50 :	 0.0781311823453192
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.05205454453821723
# [(799592.2792, 49), (647913.4279, 34), (494519.8285, 2), (415302.0878, 44)]
# Switches in the controller 40 : [44, 2, 49, 34]
# Switch selected is : 49
# The underloaded domains are : [1, 14, 12, 47, 20]
# The target controller set for 14 is : [32, 24, 48, 46]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.21690026951635016
# Q value = 5.3603031139931465
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.040023689209232854
# 1 :	 0.04097590121193659
# 14 :	 0.07242623077749301
# 12 :	 0.051759363062088296
# 38 :	 0.053888282536635065
# 47 :	 0.035988675389956204
# 50 :	 0.0781311823453192
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.05205454453821723
# [(647913.4279, 5), (415311.198, 19), (415309.2754, 43), (415307.0, 35), (195928.8956, 11), (7580.147697, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 11, 5]
# Switch selected is : 5
# The underloaded domains are : [40, 1, 12, 47, 20]
# The target controller set for 40 is : [44, 2, 34]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.48334118664198755
# Q value = 5.964591080332642
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.05667085958339936
# 1 :	 0.04097590121193659
# 14 :	 0.07242623077749301
# 12 :	 0.051759363062088296
# 38 :	 0.03724111216246856
# 47 :	 0.035988675389956204
# 50 :	 0.0781311823453192
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.05205454453821723
# [(597312.8869, 37), (597312.8869, 8), (415309.2754, 22), (415307.0, 6), (738.2003844999999, 16)]
# Switches in the controller 31 : [16, 22, 6, 8, 37]
# Switch selected is : 37
# The underloaded domains are : [1, 12, 38, 47, 20]
# The target controller set for 38 is : [15, 43, 19, 35, 11]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.9371508786413422
# Q value = 6.191431689564128
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.05667085958339936
# 1 :	 0.04097590121193659
# 14 :	 0.07242623077749301
# 12 :	 0.051759363062088296
# 38 :	 0.05258817701207105
# 47 :	 0.035988675389956204
# 50 :	 0.0781311823453192
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.036707479688614736
# [(1022990.882, 3), (799593.234, 30), (799591.5637, 25), (415302.1482, 45), (3413.869694, 13)]
# Switches in the controller 50 : [13, 45, 30, 25, 3]
# Switch selected is : 3
# The underloaded domains are : [1, 12, 47, 20, 31]
# The target controller set for 1 is : [41, 10, 36]
# The mean load ratio is : 0.051907897566875895
# The reward is = 1.2879360536306386
# Q value = 6.350916882231465
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.05667085958339936
# 1 :	 0.06726012804000178
# 14 :	 0.07242623077749301
# 12 :	 0.051759363062088296
# 38 :	 0.05258817701207105
# 47 :	 0.035988675389956204
# 50 :	 0.051846955517254004
# 9 :	 0.05194562499858658
# 20 :	 0.04188548159929395
# 31 :	 0.036707479688614736
# [(799595.3415, 27), (799592.2792, 28), (415302.0878, 23), (7251.356244, 17)]
# Switches in the controller 9 : [17, 27, 23, 28]
# Switch selected is : 27
# The underloaded domains are : [12, 47, 50, 20, 31]
# The target controller set for 47 is : [33, 42, 21, 4]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.4373644433826342
# Q value = 5.9888666052368364
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.05667085958339936
# 1 :	 0.06726012804000178
# 14 :	 0.07242623077749301
# 12 :	 0.051759363062088296
# 38 :	 0.05258817701207105
# 47 :	 0.05653308658310528
# 50 :	 0.051846955517254004
# 9 :	 0.0314012138054375
# 20 :	 0.04188548159929395
# 31 :	 0.036707479688614736
# [(799595.3415, 48), (799592.2792, 49), (799591.5637, 46), (415302.1482, 24), (4771.745623, 32)]
# Switches in the controller 14 : [32, 24, 48, 46, 49]
# Switch selected is : 48
# The underloaded domains are : [12, 50, 9, 20, 31]
# The target controller set for 12 is : [0, 29, 7]
# The mean load ratio is : 0.051907897566875895
# The reward is = 0.4343560497963842
# Q value = 5.584778329082937
#
# At time step 4968 the number of switch migrated are : 7
# The migrated switches are [3, 49, 5, 37, 3, 27, 48]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4969
# 0.224423011405652
# The overloaded domains are : [1, 38, 40, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.05965939014630782
# 1 :	 0.06026126872515885
# 14 :	 0.04608793223983122
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(730230.6529, 2), (588213.0963, 34), (588213.0963, 5), (415306.5337, 44)]
# Switches in the controller 40 : [44, 2, 34, 5]
# Switch selected is : 2
# The underloaded domains are : [14, 47, 50, 9, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 8]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.7371997204828651
# Q value = 5.924117039669943
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.040897201298538854
# 1 :	 0.06026126872515885
# 14 :	 0.04608793223983122
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.05541314491928359
# [(730230.6529, 2), (592702.0659, 8), (415307.0, 6), (415306.4496, 22), (3151.929139, 16)]
# Switches in the controller 31 : [16, 22, 6, 8, 2]
# Switch selected is : 2
# The underloaded domains are : [40, 14, 47, 50, 9, 20]
# The target controller set for 50 is : [13, 45, 30, 25]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.6014438240527569
# Q value = 5.906744887926747
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.040897201298538854
# 1 :	 0.06026126872515885
# 14 :	 0.04608793223983122
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.06475037470385697
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(730230.6529, 2), (686845.5783, 30), (686845.168, 25), (415303.7063, 45), (881.0920847000001, 13)]
# Switches in the controller 50 : [13, 45, 30, 25, 2]
# Switch selected is : 2
# The underloaded domains are : [40, 14, 47, 9, 20, 31]
# The target controller set for 40 is : [44, 34, 5]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.5151829775912018
# Q value = 5.687863303378229
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.05965939014630782
# 1 :	 0.06026126872515885
# 14 :	 0.04608793223983122
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(718299.0568, 10), (686846.8846, 36), (524936.5519, 3), (415306.2011, 41)]
# Switches in the controller 1 : [41, 10, 36, 3]
# Switch selected is : 10
# The underloaded domains are : [14, 47, 50, 9, 20, 31]
# The target controller set for 14 is : [32, 24, 46, 49]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.5846469148387258
# Q value = 5.555225217616396
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.05965939014630782
# 1 :	 0.04180564446543404
# 14 :	 0.06454355649955604
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(718299.0568, 10), (686852.2706, 49), (686845.168, 46), (415303.7063, 24), (4756.562336, 32)]
# Switches in the controller 14 : [32, 24, 46, 49, 10]
# Switch selected is : 10
# The underloaded domains are : [1, 47, 50, 9, 20, 31]
# Taking a random action
# The target controller set for 1 is : [41, 36, 3]
# The mean load ratio is : 0.0474048210882463
# The reward is = 1.0719242438593233
# Q value = 5.712679139998259
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.05965939014630782
# 1 :	 0.060261268725158856
# 14 :	 0.04608793223983122
# 12 :	 0.06361322549017134
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(686852.9193, 29), (686846.8846, 7), (686841.1667, 48), (415307.0, 0)]
# Switches in the controller 12 : [0, 29, 7, 48]
# Switch selected is : 29
# The underloaded domains are : [14, 47, 50, 9, 20, 31]
# The target controller set for 14 is : [32, 24, 46, 49]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.6173379881416177
# Q value = 5.260253038519804
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.05965939014630782
# 1 :	 0.060261268725158856
# 14 :	 0.06373559483981904
# 12 :	 0.045965562890183526
# 38 :	 0.04841533345606504
# 47 :	 0.04596067001300664
# 50 :	 0.04598818585608801
# 9 :	 0.02842254276387604
# 20 :	 0.03898870612044346
# 31 :	 0.036650956071514626
# [(592702.0659, 37), (415308.8643, 19), (415307.0, 35), (415306.4496, 43), (36426.4664, 11), (9290.093273999999, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 11, 37]
# Switch selected is : 37
# The underloaded domains are : [12, 47, 50, 9, 20, 31]
# The target controller set for 50 is : [13, 45, 30, 25]
# The mean load ratio is : 0.0474048210882463
# The reward is = 0.25907232702857524
# Q value = 5.5883385831932815
#
# At time step 4969 the number of switch migrated are : 7
# The migrated switches are [2, 2, 2, 10, 10, 29, 37]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4970
# 0.37279104539304575
# The overloaded domains are : [1, 38, 40, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.0657371884528352
# 1 :	 0.08076084409781714
# 14 :	 0.041435697749907366
# 12 :	 0.031099037272152793
# 38 :	 0.05011506019747771
# 47 :	 0.045566638196060875
# 50 :	 0.04519762998000035
# 9 :	 0.02096995942077342
# 20 :	 0.03155615635258898
# 31 :	 0.03552776182446412
# [(862409.6799, 34), (862409.6799, 5), (418393.2815, 2), (415300.6768, 44)]
# Switches in the controller 40 : [44, 34, 5, 2]
# Switch selected is : 34
# The underloaded domains are : [14, 12, 9, 20, 31]
# The target controller set for 9 is : [17, 23, 28]
# The mean load ratio is : 0.04479659735440779
# The reward is = 21.382328630480714
# Q value = 18.254580406037498
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.04357885640505191
# 1 :	 0.08076084409781714
# 14 :	 0.041435697749907366
# 12 :	 0.031099037272152793
# 38 :	 0.05011506019747771
# 47 :	 0.045566638196060875
# 50 :	 0.04519762998000035
# 9 :	 0.043128291468556706
# 20 :	 0.03155615635258898
# 31 :	 0.03552776182446412
# [(1526443.5469999998, 3), (803948.4927, 10), (415304.0856, 41), (397542.8855, 36)]
# Switches in the controller 1 : [41, 36, 3, 10]
# Switch selected is : 3
# The underloaded domains are : [40, 14, 12, 9, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 8]
# The mean load ratio is : 0.04479659735440779
# The reward is = 0.5836673172260504
# Q value = 5.754594789190216
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.04357885640505191
# 1 :	 0.04154115100422378
# 14 :	 0.041435697749907366
# 12 :	 0.031099037272152793
# 38 :	 0.05011506019747771
# 47 :	 0.045566638196060875
# 50 :	 0.04519762998000035
# 9 :	 0.043128291468556706
# 20 :	 0.03155615635258898
# 31 :	 0.07474745491805748
# [(697011.0383, 11), (415317.3287, 43), (415310.2037, 19), (415307.0, 35), (7549.300929999999, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 11]
# Switch selected is : 11
# The underloaded domains are : [40, 1, 14, 12, 9, 20]
# The target controller set for 14 is : [32, 24, 46, 49, 29]
# The mean load ratio is : 0.04479659735440779
# The reward is = 0.33735315380663367
# Q value = 5.506067922242526
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.04357885640505191
# 1 :	 0.04154115100422378
# 14 :	 0.059344358085691704
# 12 :	 0.031099037272152793
# 38 :	 0.03220639986169337
# 47 :	 0.045566638196060875
# 50 :	 0.04519762998000035
# 9 :	 0.043128291468556706
# 20 :	 0.03155615635258898
# 31 :	 0.07474745491805748
# [(540555.7366, 4), (415312.1443, 42), (415312.1443, 21), (397535.0262, 27), (4753.717640999999, 33)]
# Switches in the controller 47 : [33, 42, 21, 4, 27]
# Switch selected is : 4
# The underloaded domains are : [40, 1, 12, 38, 9, 20]
# The target controller set for 38 is : [15, 43, 19, 35]
# The mean load ratio is : 0.04479659735440779
# The reward is = 0.599380076435441
# Q value = 6.234812058688291
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.04357885640505191
# 1 :	 0.04154115100422378
# 14 :	 0.059344358085691704
# 12 :	 0.031099037272152793
# 38 :	 0.046095174281880494
# 47 :	 0.031677863775873755
# 50 :	 0.04519762998000035
# 9 :	 0.043128291468556706
# 20 :	 0.03155615635258898
# 31 :	 0.07474745491805748
# [(547971.4651, 37), (415309.6296, 45), (397543.3941, 25), (397537.5543, 30), (744.8029945000001, 13)]
# Switches in the controller 50 : [13, 45, 30, 25, 37]
# Switch selected is : 37
# The underloaded domains are : [40, 1, 12, 47, 9, 20]
# The target controller set for 1 is : [41, 36, 10]
# The mean load ratio is : 0.04479659735440779
# The reward is = 0.39333876640175375
# Q value = 5.465831257745041
#
# At time step 4970 the number of switch migrated are : 5
# The migrated switches are [34, 3, 11, 4, 37]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4971
# 0.18090383475708657
# The overloaded domains are : [1, 38, 9, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.0537185530726021
# 14 :	 0.06462537073814434
# 12 :	 0.04629891128499503
# 38 :	 0.04410603135424144
# 47 :	 0.03927798339352414
# 50 :	 0.046411169222496204
# 9 :	 0.04438347951783181
# 20 :	 0.039155191198196826
# 31 :	 0.037880755727619536
# [(693325.9244, 36), (550250.6844, 37), (431862.5582, 10), (415304.8502, 41)]
# Switches in the controller 1 : [41, 36, 10, 37]
# Switch selected is : 36
# The underloaded domains are : [40, 38, 47, 9, 20, 31]
# The target controller set for 38 is : [15, 43, 19, 35, 4]
# The mean load ratio is : 0.045167507770989455
# The reward is = 0.4700315215522147
# Q value = 5.726898548805425
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.06462537073814434
# 12 :	 0.04629891128499503
# 38 :	 0.06192000817784678
# 47 :	 0.03927798339352414
# 50 :	 0.046411169222496204
# 9 :	 0.04438347951783181
# 20 :	 0.039155191198196826
# 31 :	 0.037880755727619536
# [(693331.0339, 30), (693313.48, 25), (415306.6797, 45), (4387.0049, 13)]
# Switches in the controller 50 : [13, 45, 30, 25]
# Switch selected is : 30
# The underloaded domains are : [40, 1, 47, 9, 20, 31]
# The target controller set for 20 is : [39, 18, 26]
# The mean load ratio is : 0.045167507770989455
# The reward is = 0.17740282899303297
# Q value = 5.331479797353864
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.06462537073814434
# 12 :	 0.04629891128499503
# 38 :	 0.06192000817784678
# 47 :	 0.03927798339352414
# 50 :	 0.02859706111789967
# 9 :	 0.04438347951783181
# 20 :	 0.05696929930279336
# 31 :	 0.037880755727619536
# [(693325.9244, 36), (463901.1264, 4), (415307.0, 35), (415304.2562, 19), (415300.99799999996, 43), (6808.082597, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 4, 36]
# Switch selected is : 36
# The underloaded domains are : [40, 1, 47, 50, 9, 31]
# Taking a random action
# The target controller set for 47 is : [33, 42, 21, 27]
# The mean load ratio is : 0.045167507770989455
# The reward is = 1.298815980485111
# Q value = 6.041264257559895
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.06462537073814434
# 12 :	 0.04629891128499503
# 38 :	 0.044106031354241446
# 47 :	 0.05709196021712948
# 50 :	 0.02859706111789967
# 9 :	 0.04438347951783181
# 20 :	 0.05696929930279336
# 31 :	 0.037880755727619536
# [(693319.1956, 29), (693316.2745, 49), (693313.48, 46), (415306.6797, 24), (15227.162, 11), (4758.209712, 32)]
# Switches in the controller 14 : [32, 24, 46, 49, 29, 11]
# Switch selected is : 29
# The underloaded domains are : [40, 1, 38, 50, 9, 31]
# The target controller set for 31 is : [16, 22, 6, 8, 3]
# The mean load ratio is : 0.045167507770989455
# The reward is = 2.3079186944895995
# Q value = 6.63476458568676
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.04681156680103154
# 12 :	 0.04629891128499503
# 38 :	 0.044106031354241446
# 47 :	 0.05709196021712948
# 50 :	 0.02859706111789967
# 9 :	 0.04438347951783181
# 20 :	 0.05696929930279336
# 31 :	 0.055694559664732336
# [(693316.2745, 49), (693313.48, 46), (415306.6797, 24), (15227.162, 11), (4758.209712, 32)]
# Switches in the controller 14 : [32, 24, 46, 49, 11]
# Switch selected is : 49
# The underloaded domains are : [40, 1, 38, 50, 9]
# The target controller set for 9 is : [17, 23, 28, 34]
# The mean load ratio is : 0.045167507770989455
# The reward is = 0.2746890829201592
# Q value = 5.485449179009036
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.02899783791723186
# 12 :	 0.04629891128499503
# 38 :	 0.044106031354241446
# 47 :	 0.05709196021712948
# 50 :	 0.02859706111789967
# 9 :	 0.06219720840163149
# 20 :	 0.05696929930279336
# 31 :	 0.055694559664732336
# [(693331.0339, 30), (693326.8791, 26), (415303.1163, 39), (415303.1163, 18)]
# Switches in the controller 20 : [39, 18, 26, 30]
# Switch selected is : 30
# The underloaded domains are : [40, 1, 14, 38, 50]
# The target controller set for 14 is : [32, 24, 46, 11]
# The mean load ratio is : 0.045167507770989455
# The reward is = 1.6039457819593483
# Q value = 6.433986137161412
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.04681194602182839
# 12 :	 0.04629891128499503
# 38 :	 0.044106031354241446
# 47 :	 0.05709196021712948
# 50 :	 0.02859706111789967
# 9 :	 0.06219720840163149
# 20 :	 0.039155191198196826
# 31 :	 0.055694559664732336
# [(693336.1577, 48), (693325.9244, 7), (415307.0, 0)]
# Switches in the controller 12 : [0, 7, 48]
# Switch selected is : 48
# The underloaded domains are : [40, 1, 38, 50, 20]
# Taking a random action
# The target controller set for 20 is : [39, 18, 26]
# The mean load ratio is : 0.045167507770989455
# The reward is = 0.23076875609044517
# Q value = 5.14350365035242
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.03581763220024312
# 1 :	 0.03590457624899676
# 14 :	 0.04681194602182839
# 12 :	 0.0284846715319901
# 38 :	 0.044106031354241446
# 47 :	 0.05709196021712948
# 50 :	 0.02859706111789967
# 9 :	 0.06219720840163149
# 20 :	 0.05696943095120176
# 31 :	 0.055694559664732336
# [(693316.2745, 49), (693316.2745, 28), (613052.1893, 34), (415307.5369, 23), (5743.837638, 17)]
# Switches in the controller 9 : [17, 23, 28, 34, 49]
# Switch selected is : 49
# The underloaded domains are : [40, 1, 12, 38, 50]
# Taking a random action
# The target controller set for 1 is : [41, 10, 37]
# The mean load ratio is : 0.045167507770989455
# The reward is = 1.313653150806609
# Q value = 6.203222291350982
#
# At time step 4971 the number of switch migrated are : 8
# The migrated switches are [36, 30, 36, 29, 49, 30, 48, 49]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4972
# 0.3485150509210801
# The overloaded domains are : [1, 38, 40, 9, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04552086176079576
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.0227304337237497
# 38 :	 0.047538069247912235
# 47 :	 0.04558285137979495
# 50 :	 0.022824635919090744
# 9 :	 0.04358043210482121
# 20 :	 0.0454609249855465
# 31 :	 0.048944725138528954
# [(469355.5632, 29), (415307.0, 6), (415302.6503, 22), (392359.5057, 8), (195982.1019, 3), (16638.21937, 16)]
# Switches in the controller 31 : [16, 22, 6, 8, 3, 29]
# Switch selected is : 29
# The underloaded domains are : [12, 50, 9, 20]
# The target controller set for 12 is : [0, 7]
# The mean load ratio is : 0.04549294419833867
# The reward is = 3.8004669846998658
# Q value = 7.686209820002752
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.04552086176079576
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.03478982575082652
# 38 :	 0.047538069247912235
# 47 :	 0.04558285137979495
# 50 :	 0.022824635919090744
# 9 :	 0.04358043210482121
# 20 :	 0.0454609249855465
# 31 :	 0.03688533311145213
# [(469374.7033, 27), (469369.0681, 36), (415303.2123, 42), (415303.2123, 21), (4749.595564, 33)]
# Switches in the controller 47 : [33, 42, 21, 27, 36]
# Switch selected is : 27
# The underloaded domains are : [12, 50, 9, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 8, 3]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.8912252106359291
# Q value = 6.242518650534599
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.04552086176079576
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.03478982575082652
# 38 :	 0.047538069247912235
# 47 :	 0.03352296757636043
# 50 :	 0.022824635919090744
# 9 :	 0.04358043210482121
# 20 :	 0.0454609249855465
# 31 :	 0.04894521691488665
# [(801635.0442, 5), (554750.9576, 2), (415301.1331, 44)]
# Switches in the controller 40 : [44, 5, 2]
# Switch selected is : 5
# The underloaded domains are : [12, 47, 50, 9, 20]
# The target controller set for 9 is : [17, 23, 28, 34]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.22699111927800186
# Q value = 10.248152147086488
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.02492404344518651
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.03478982575082652
# 38 :	 0.047538069247912235
# 47 :	 0.03352296757636043
# 50 :	 0.022824635919090744
# 9 :	 0.06417725042043046
# 20 :	 0.0454609249855465
# 31 :	 0.04894521691488665
# [(1892977.0790000001, 11), (469376.8662, 46), (469374.9327, 30), (415303.5713, 24), (4760.128262, 32)]
# Switches in the controller 14 : [32, 24, 46, 11, 30]
# Switch selected is : 11
# The underloaded domains are : [40, 12, 47, 50, 20]
# The target controller set for 20 is : [39, 18, 26, 48]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.5449437998988611
# Q value = 5.463237078803889
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.02492404344518651
# 1 :	 0.04919654143534361
# 14 :	 0.03491274009132925
# 12 :	 0.03478982575082652
# 38 :	 0.047538069247912235
# 47 :	 0.03352296757636043
# 50 :	 0.022824635919090744
# 9 :	 0.06417725042043046
# 20 :	 0.09409815118202033
# 31 :	 0.04894521691488665
# [(1892977.0790000001, 11), (469374.7033, 48), (469354.1699, 26), (415312.7512, 39), (415312.7512, 18)]
# Switches in the controller 20 : [39, 18, 26, 48, 11]
# Switch selected is : 11
# The underloaded domains are : [40, 14, 12, 47, 50]
# The target controller set for 14 is : [32, 24, 46, 30]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.4838695513103483
# Q value = 5.650517311639212
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.02492404344518651
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.03478982575082652
# 38 :	 0.047538069247912235
# 47 :	 0.03352296757636043
# 50 :	 0.022824635919090744
# 9 :	 0.06417725042043046
# 20 :	 0.04546092498554649
# 31 :	 0.04894521691488665
# [(597145.3302, 4), (415308.4429, 19), (415307.0, 35), (415302.6503, 43), (7134.100256000001, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 4]
# Switch selected is : 4
# The underloaded domains are : [40, 12, 47, 50, 20]
# The target controller set for 12 is : [0, 7, 29]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.28686035985494235
# Q value = 5.389369173631915
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.02492404344518651
# 1 :	 0.04919654143534361
# 14 :	 0.08354996628780309
# 12 :	 0.05013258548062115
# 38 :	 0.03219530951811761
# 47 :	 0.03352296757636043
# 50 :	 0.022824635919090744
# 9 :	 0.06417725042043046
# 20 :	 0.04546092498554649
# 31 :	 0.04894521691488665
# [(637719.2297, 10), (469361.4091, 49), (415305.6703, 41), (392359.5057, 37)]
# Switches in the controller 1 : [41, 10, 37, 49]
# Switch selected is : 10
# The underloaded domains are : [40, 38, 47, 50, 20]
# The target controller set for 47 is : [33, 42, 21, 36]
# The mean load ratio is : 0.04549294419833867
# The reward is = 0.6911814819600386
# Q value = 5.553475448513961
#
# At time step 4972 the number of switch migrated are : 7
# The migrated switches are [29, 27, 5, 11, 11, 4, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4973
# 0.29556914432883513
# The overloaded domains are : [1, 38, 40, 9, 12, 14, 47, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.038080949337692155
# 14 :	 0.07561682587941736
# 12 :	 0.058000913468781355
# 38 :	 0.03216179888628499
# 47 :	 0.054022093793030315
# 50 :	 0.02677661084484072
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.05159005162306716
# [(625273.459, 29), (625267.8179, 7), (591566.6364, 4), (415307.0, 0)]
# Switches in the controller 12 : [0, 7, 29, 4]
# Switch selected is : 29
# The underloaded domains are : [40, 1, 38, 50]
# The target controller set for 38 is : [15, 43, 19, 35]
# The mean load ratio is : 0.04753328823023588
# The reward is = 1.4330135301904046
# Q value = 6.321213396440055
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.038080949337692155
# 14 :	 0.07561682587941736
# 12 :	 0.04193544337016818
# 38 :	 0.04822726898489817
# 47 :	 0.054022093793030315
# 50 :	 0.02677661084484072
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.05159005162306716
# [(625276.2685, 27), (441546.3435, 8), (415314.6749, 22), (415307.0, 6), (109102.3944, 3), (1355.348976, 16)]
# Switches in the controller 31 : [16, 22, 6, 8, 3, 27]
# Switch selected is : 27
# The underloaded domains are : [40, 1, 12, 50]
# The target controller set for 12 is : [0, 7, 4]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.5944341457751681
# Q value = 6.086054041971025
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.038080949337692155
# 14 :	 0.07561682587941736
# 12 :	 0.05800098565469872
# 38 :	 0.04822726898489817
# 47 :	 0.054022093793030315
# 50 :	 0.02677661084484072
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.03552450933853661
# [(625273.459, 29), (415314.6749, 43), (415310.5153, 19), (415307.0, 35), (5815.758279, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 29]
# Switch selected is : 29
# The underloaded domains are : [40, 1, 50, 31]
# The target controller set for 1 is : [41, 37, 49]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.490730657178152
# Q value = 5.582701782130746
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.05414641943630533
# 14 :	 0.07561682587941736
# 12 :	 0.05800098565469872
# 38 :	 0.03216179888628499
# 47 :	 0.054022093793030315
# 50 :	 0.02677661084484072
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.03552450933853661
# [(641925.1837, 10), (625267.8179, 36), (415299.2049, 42), (415299.2049, 21), (4766.511963, 33)]
# Switches in the controller 47 : [33, 42, 21, 36, 10]
# Switch selected is : 10
# The underloaded domains are : [40, 38, 50, 31]
# The target controller set for 31 is : [16, 22, 6, 8, 3]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.8828999994307478
# Q value = 5.700829766018184
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.05414641943630533
# 14 :	 0.07561682587941736
# 12 :	 0.05800098565469872
# 38 :	 0.03216179888628499
# 47 :	 0.037528782433273525
# 50 :	 0.02677661084484072
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.0520178206982934
# [(1272435.874, 11), (625268.7131, 30), (625260.6443, 46), (415305.82200000004, 24), (4761.051232, 32)]
# Switches in the controller 14 : [32, 24, 46, 30, 11]
# Switch selected is : 11
# The underloaded domains are : [40, 38, 47, 50]
# The target controller set for 50 is : [13, 45, 25]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.3437907315790442
# Q value = 5.337527646889856
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.03330329116231789
# 1 :	 0.05414641943630533
# 14 :	 0.04292348156436668
# 12 :	 0.05800098565469872
# 38 :	 0.03216179888628499
# 47 :	 0.037528782433273525
# 50 :	 0.0594699551598914
# 9 :	 0.05230862103821866
# 20 :	 0.05347172626870815
# 31 :	 0.0520178206982934
# [(625276.2685, 48), (625264.3577, 26), (415298.4047, 39), (415298.4047, 18)]
# Switches in the controller 20 : [39, 18, 26, 48]
# Switch selected is : 48
# The underloaded domains are : [40, 14, 38, 47]
# The target controller set for 40 is : [44, 2]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.5181306657968175
# Q value = 7.087453285232775
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.049368833446848434
# 1 :	 0.05414641943630533
# 14 :	 0.04292348156436668
# 12 :	 0.05800098565469872
# 38 :	 0.03216179888628499
# 47 :	 0.037528782433273525
# 50 :	 0.0594699551598914
# 9 :	 0.05230862103821866
# 20 :	 0.03740618398417761
# 31 :	 0.0520178206982934
# [(625271.9907, 28), (493789.239, 34), (493789.239, 5), (415303.2979, 23), (7715.225176999999, 17)]
# Switches in the controller 9 : [17, 23, 28, 34, 5]
# Switch selected is : 28
# The underloaded domains are : [14, 38, 47, 20]
# The target controller set for 38 is : [15, 43, 19, 35]
# The mean load ratio is : 0.04753328823023588
# The reward is = 0.7831749712525329
# Q value = 5.5812054000472715
#
# At time step 4973 the number of switch migrated are : 7
# The migrated switches are [29, 27, 29, 10, 11, 48, 28]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4974
# 0.26418087981474647
# The overloaded domains are : [1, 38, 40, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03600274407096287
# 1 :	 0.05753023960737593
# 14 :	 0.04257365953867153
# 12 :	 0.05428485617034663
# 38 :	 0.04811591205747503
# 47 :	 0.03735329536849352
# 50 :	 0.06606851006684387
# 9 :	 0.023890855938093477
# 20 :	 0.03723218836960685
# 31 :	 0.056684562417826434
# [(678226.9633, 10), (586852.6586, 8), (415312.0872, 22), (415307.0, 6), (99007.17903, 3), (11476.20286, 16)]
# Switches in the controller 31 : [16, 22, 6, 8, 3, 10]
# Switch selected is : 10
# The underloaded domains are : [40, 14, 47, 9, 20]
# The target controller set for 14 is : [32, 24, 46, 30]
# The mean load ratio is : 0.04597368236056962
# The reward is = 0.5981959379406883
# Q value = 5.692263742225133
#
# Balance the overloaded controller : 50
# Controller	Controller Load Ratio
# 40 :	 0.03600274407096287
# 1 :	 0.05753023960737593
# 14 :	 0.05999969104878136
# 12 :	 0.05428485617034663
# 38 :	 0.04811591205747503
# 47 :	 0.03735329536849352
# 50 :	 0.06606851006684387
# 9 :	 0.023890855938093477
# 20 :	 0.03723218836960685
# 31 :	 0.03925853090771661
# [(1536848.1530000002, 11), (618454.4996, 25), (415309.5495, 45), (796.2638146, 13)]
# Switches in the controller 50 : [13, 45, 25, 11]
# Switch selected is : 11
# The underloaded domains are : [40, 47, 9, 20, 31]
# The target controller set for 47 is : [33, 42, 21, 36]
# The mean load ratio is : 0.04597368236056962
# The reward is = 0.13718557696205744
# Q value = 5.093892274906376
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03600274407096287
# 1 :	 0.05753023960737593
# 14 :	 0.05999969104878136
# 12 :	 0.05428485617034663
# 38 :	 0.04811591205747503
# 47 :	 0.07684031931417229
# 50 :	 0.026581486121165107
# 9 :	 0.023890855938093477
# 20 :	 0.03723218836960685
# 31 :	 0.03925853090771661
# [(618471.9396, 49), (618464.6803, 29), (586852.6586, 37), (415306.851, 41)]
# Switches in the controller 1 : [41, 37, 49, 29]
# Switch selected is : 49
# The underloaded domains are : [40, 50, 9, 20, 31]
# The target controller set for 9 is : [17, 23, 34, 5]
# The mean load ratio is : 0.04597368236056962
# The reward is = 5.4778755717834615
# Q value = 8.517883384752155
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03600274407096287
# 1 :	 0.041639524417951754
# 14 :	 0.05999969104878136
# 12 :	 0.05428485617034663
# 38 :	 0.04811591205747503
# 47 :	 0.07684031931417229
# 50 :	 0.026581486121165107
# 9 :	 0.03978157112751765
# 20 :	 0.03723218836960685
# 31 :	 0.03925853090771661
# [(618471.9396, 28), (415312.0872, 43), (415307.0, 35), (415302.3593, 19), (8293.972592, 15)]
# Switches in the controller 38 : [15, 43, 19, 35, 28]
# Switch selected is : 28
# The underloaded domains are : [40, 1, 50, 9, 20, 31]
# Taking a random action
# The target controller set for 50 is : [13, 45, 25]
# The mean load ratio is : 0.04597368236056962
# The reward is = 0.4859787631758897
# Q value = 5.287133073683611
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.03600274407096287
# 1 :	 0.041639524417951754
# 14 :	 0.05999969104878136
# 12 :	 0.05428485617034663
# 38 :	 0.03222519686805085
# 47 :	 0.07684031931417229
# 50 :	 0.042472201310589285
# 9 :	 0.03978157112751765
# ...
# 14 :	 0.05456453900451899
# 12 :	 0.06066931150759911
# 38 :	 0.03791429125417699
# 47 :	 0.05775864085087873
# 50 :	 0.04403682391125352
# 9 :	 0.05781452086241202
# 20 :	 0.0550656174518634
# 31 :	 0.04221750297632456
# [(706307.7423, 46), (706304.728, 36), (415305.3264, 42), (415305.3264, 21), (4762.459039, 33)]
# Switches in the controller 47 : [33, 42, 21, 36, 46]
# Switch selected is : 46
# The underloaded domains are : [40, 1, 38, 50, 31]
# The target controller set for 38 is : [15, 19, 35, 5]
# The mean load ratio is : 0.050225330393915704
# The reward is = 1.1631471768687873
# Q value = 5.114439741201333
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.04523246538280632
# 1 :	 0.04697959073732342
# 14 :	 0.05456453900451899
# 12 :	 0.06066931150759911
# 38 :	 0.05606181655052837
# 47 :	 0.03961111555452734
# 50 :	 0.04403682391125352
# 9 :	 0.05781452086241202
# 20 :	 0.0550656174518634
# 31 :	 0.04221750297632456
# [(706308.5635, 48), (606261.7416, 11), (415300.9537, 39), (415300.9537, 18)]
# Switches in the controller 20 : [39, 18, 11, 48]
# Switch selected is : 48
# The underloaded domains are : [40, 1, 47, 50, 31]
# The target controller set for 1 is : [41, 8, 27]
# The mean load ratio is : 0.050225330393915704
# The reward is = 0.36174614186083254
# Q value = 4.822703224314802
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.04523246538280632
# 1 :	 0.06512713713318552
# 14 :	 0.05456453900451899
# 12 :	 0.06066931150759911
# 38 :	 0.05606181655052837
# 47 :	 0.03961111555452734
# 50 :	 0.04403682391125352
# 9 :	 0.05781452086241202
# 20 :	 0.0369180710560013
# 31 :	 0.04221750297632456
# [(706848.5271, 8), (706308.5635, 48), (706308.5635, 27), (415304.263, 41)]
# Switches in the controller 1 : [41, 8, 27, 48]
# Switch selected is : 8
# The underloaded domains are : [40, 47, 50, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 24, 4]
# The mean load ratio is : 0.050225330393915704
# The reward is = 0.8892119044277683
# Q value = 5.075082511617849
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.04523246538280632
# 1 :	 0.04696571717697111
# 14 :	 0.05456453900451899
# 12 :	 0.06066931150759911
# 38 :	 0.05606181655052837
# 47 :	 0.03961111555452734
# 50 :	 0.04403682391125352
# 9 :	 0.05781452086241202
# 20 :	 0.0369180710560013
# 31 :	 0.06037892293253898
# [(753491.4341, 2), (706307.7423, 25), (486163.6793, 10), (415307.0, 0)]
# Switches in the controller 12 : [0, 10, 2, 25]
# Switch selected is : 2
# The underloaded domains are : [40, 1, 47, 50, 20]
# The target controller set for 1 is : [41, 27, 48]
# The mean load ratio is : 0.050225330393915704
# The reward is = 0.4302632728407519
# Q value = 4.854037300904363
#
# Balance the overloaded controller : 9
# Controller	Controller Load Ratio
# 40 :	 0.04523246538280632
# 1 :	 0.06632555714755702
# 14 :	 0.05456453900451899
# 12 :	 0.0413094715370132
# 38 :	 0.05606181655052837
# 47 :	 0.03961111555452734
# 50 :	 0.04403682391125352
# 9 :	 0.05781452086241202
# 20 :	 0.0369180710560013
# 31 :	 0.06037892293253898
# [(706304.728, 7), (706302.5237, 49), (415311.7106, 43), (415301.2654, 23), (6940.2231409999995, 17)]
# Switches in the controller 9 : [17, 23, 43, 49, 7]
# Switch selected is : 7
# The underloaded domains are : [40, 12, 47, 50, 20]
# The target controller set for 47 is : [33, 42, 21, 36]
# The mean load ratio is : 0.050225330393915704
# The reward is = 0.5385163650010768
# Q value = 4.877987064078607
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.04523246538280632
# 1 :	 0.06632555714755702
# 14 :	 0.05456453900451899
# 12 :	 0.0413094715370132
# 38 :	 0.05606181655052837
# 47 :	 0.05775856340293044
# 50 :	 0.04403682391125352
# 9 :	 0.039667073014008916
# 20 :	 0.0369180710560013
# 31 :	 0.06037892293253898
# [(706309.3003, 30), (706302.5237, 28), (706293.2274, 26), (4765.020665999999, 32)]
# Switches in the controller 14 : [32, 30, 26, 28]
# Switch selected is : 30
# The underloaded domains are : [40, 12, 50, 9, 20]
# The target controller set for 12 is : [0, 10, 25]
# The mean load ratio is : 0.050225330393915704
# The reward is = 0.41611869623282755
# Q value = 4.82619776682965
#
# At time step 4997 the number of switch migrated are : 6
# The migrated switches are [46, 48, 8, 2, 7, 30]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# 0.2280015355580981
# The overloaded domains are : [1, 38, 9, 12, 14, 47, 50, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.049290203666456596
# 14 :	 0.03181683908656508
# 12 :	 0.057576404288514654
# 38 :	 0.049434257061934696
# 47 :	 0.053158021540875365
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.0337247305718937
# 31 :	 0.05432152752152485
# [(616777.8332, 30), (616770.4533, 25), (592037.5878, 10), (415307.0, 0)]
# Switches in the controller 12 : [0, 10, 25, 30]
# Switch selected is : 30
# The underloaded domains are : [40, 14, 50, 9, 20]
# The target controller set for 20 is : [39, 18, 11]
# The mean load ratio is : 0.04325509497393536
# The reward is = 1.293504595906844
# Q value = 5.648648142924447
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.049290203666456596
# 14 :	 0.03181683908656508
# 12 :	 0.04172921663943514
# 38 :	 0.049434257061934696
# 47 :	 0.053158021540875365
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.04957191822097322
# 31 :	 0.05432152752152485
# [(616775.6388, 36), (616775.6388, 7), (415307.2731, 42), (415307.2731, 21), (4762.119076, 33)]
# Switches in the controller 47 : [33, 42, 21, 36, 7]
# Switch selected is : 36
# The underloaded domains are : [40, 14, 12, 50, 9]
# The target controller set for 12 is : [0, 10, 25]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.29263846361902424
# Q value = 4.8840161854630475
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.049290203666456596
# 14 :	 0.03181683908656508
# 12 :	 0.05757634790667551
# 38 :	 0.049434257061934696
# 47 :	 0.03731089027363499
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.04957191822097322
# 31 :	 0.05432152752152485
# [(511232.8337, 4), (415310.9251, 24), (415308.8862, 22), (415307.0, 6), (349550.6168, 8), (7501.722229000001, 16)]
# Switches in the controller 31 : [16, 22, 6, 24, 4, 8]
# Switch selected is : 4
# The underloaded domains are : [40, 14, 47, 50, 9]
# The target controller set for 47 is : [33, 42, 21, 7]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.9895407990771681
# Q value = 5.242480012655413
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.049290203666456596
# 14 :	 0.03181683908656508
# 12 :	 0.05757634790667551
# 38 :	 0.049434257061934696
# 47 :	 0.0504462563842836
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.04957191822097322
# 31 :	 0.04118616141087624
# [(616777.8332, 30), (481956.4772, 11), (415310.6471, 39), (415310.6471, 18)]
# Switches in the controller 20 : [39, 18, 11, 30]
# Switch selected is : 30
# The underloaded domains are : [40, 14, 50, 9, 31]
# The target controller set for 14 is : [32, 26, 28]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.8341142331048411
# Q value = 4.843276925769951
#
# Balance the overloaded controller : 1
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.049290203666456596
# 14 :	 0.0476640267356446
# 12 :	 0.05757634790667551
# 38 :	 0.049434257061934696
# 47 :	 0.0504462563842836
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.03372473057189371
# 31 :	 0.04118616141087624
# [(616765.2976, 48), (616765.2976, 27), (415303.1656, 41), (269557.4193, 2)]
# Switches in the controller 1 : [41, 27, 48, 2]
# Switch selected is : 48
# The underloaded domains are : [40, 50, 9, 20, 31]
# The target controller set for 31 is : [16, 22, 6, 24, 8]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.5479171463131709
# Q value = 4.749534064169598
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.03344333810094559
# 14 :	 0.0476640267356446
# 12 :	 0.05757634790667551
# 38 :	 0.049434257061934696
# 47 :	 0.0504462563842836
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.03372473057189371
# 31 :	 0.05703302697638725
# [(616770.4533, 46), (467519.1601, 5), (415307.0, 35), (415306.8103, 19), (9094.362637999999, 15)]
# Switches in the controller 38 : [15, 19, 35, 5, 46]
# Switch selected is : 46
# The underloaded domains are : [40, 1, 50, 9, 20]
# Taking a random action
# The target controller set for 1 is : [41, 27, 2]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.5864214779401324
# Q value = 4.724804120886831
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 40 :	 0.03166394992190505
# 1 :	 0.04929033613448797
# 14 :	 0.0476640267356446
# 12 :	 0.05757634790667551
# 38 :	 0.03358725902839231
# 47 :	 0.0504462563842836
# 50 :	 0.03424924965167282
# 9 :	 0.037315766428010815
# 20 :	 0.03372473057189371
# 31 :	 0.05703302697638725
# [(616781.0317, 26), (616778.7771, 28), (616777.8332, 30), (4762.189124, 32)]
# Switches in the controller 14 : [32, 26, 28, 30]
# Switch selected is : 26
# The underloaded domains are : [40, 38, 50, 9, 20]
# The target controller set for 20 is : [39, 18, 11]
# The mean load ratio is : 0.04325509497393536
# The reward is = 0.5729909964823813
# Q value = 5.298630485989609
#
# At time step 4998 the number of switch migrated are : 7
# The migrated switches are [30, 36, 4, 30, 48, 46, 26]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# 0.23763403759311466
# The overloaded domains are : [1, 38, 40, 9, 12, 47, 50, 20, 31]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.020527769739912414
# 12 :	 0.0412030193205298
# 38 :	 0.03951862220843024
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.03320933807604277
# 31 :	 0.05690455407538824
# [(415307.0, 0), (397088.2709, 25), (397085.7393, 36), (394154.2556, 10)]
# Switches in the controller 12 : [0, 10, 25, 36]
# Switch selected is : 0
# The underloaded domains are : [1, 14, 50, 9, 20]
# The target controller set for 20 is : [39, 18, 11, 26]
# The mean load ratio is : 0.03869856480103246
# The reward is = 0.6194351572578933
# Q value = 5.436304761707725
#
# Balance the overloaded controller : 38
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.020527769739912414
# 12 :	 0.030532324612145025
# 38 :	 0.03951862220843024
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.043880032784427536
# 31 :	 0.05690455407538824
# [(701425.0498, 5), (415307.0, 35), (415306.4295, 19), (6039.488634, 15)]
# Switches in the controller 38 : [15, 19, 35, 5]
# Switch selected is : 5
# The underloaded domains are : [1, 14, 12, 50, 9]
# The target controller set for 12 is : [10, 25, 36]
# The mean load ratio is : 0.03869856480103246
# The reward is = 0.17259552462388555
# Q value = 4.542552984144342
#
# Balance the overloaded controller : 20
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.020527769739912414
# 12 :	 0.04855439639814763
# 38 :	 0.021496550422427634
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.043880032784427536
# 31 :	 0.05690455407538824
# [(415307.0, 0), (415306.5393, 39), (415306.5393, 18), (397074.2271, 26), (64831.21772000001, 11)]
# Switches in the controller 20 : [39, 18, 11, 26, 0]
# Switch selected is : 0
# The underloaded domains are : [1, 14, 38, 50, 9]
# The target controller set for 38 is : [15, 19, 35]
# The mean load ratio is : 0.03869856480103246
# The reward is = 4.8258343576802645
# Q value = 7.252518083850706
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.020527769739912414
# 12 :	 0.04855439639814763
# 38 :	 0.03216724513081241
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.03320933807604276
# 31 :	 0.05690455407538824
# [(568425.2573, 8), (415309.404, 24), (415309.1085, 22), (415307.0, 6), (397094.321, 48), (3299.148937, 16)]
# Switches in the controller 31 : [16, 22, 6, 24, 8, 48]
# Switch selected is : 8
# The underloaded domains are : [1, 14, 38, 50, 9, 20]
# The target controller set for 14 is : [32, 28, 30]
# The mean load ratio is : 0.03869856480103246
# The reward is = 2.1607702457631803
# Q value = 5.815129256041701
#
# Balance the overloaded controller : 31
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.03513260997902074
# 12 :	 0.04855439639814763
# 38 :	 0.03216724513081241
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.03320933807604276
# 31 :	 0.04229971383627991
# [(415309.404, 24), (415309.1085, 22), (415307.0, 6), (397094.321, 48), (3299.148937, 16)]
# Switches in the controller 31 : [16, 22, 6, 24, 48]
# Switch selected is : 24
# The underloaded domains are : [1, 14, 38, 50, 9, 20]
# The target controller set for 14 is : [32, 28, 30, 8]
# The mean load ratio is : 0.03869856480103246
# The reward is = 1.3657063815199726
# Q value = 5.3872371430224035
#
# Balance the overloaded controller : 47
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.04580336645460442
# 12 :	 0.04855439639814763
# 38 :	 0.03216724513081241
# 47 :	 0.04702975552390247
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.03320933807604276
# 31 :	 0.03162895736069622
# [(597942.6812, 4), (415305.0979, 42), (415305.0979, 21), (397085.7393, 7), (4775.167539, 33)]
# Switches in the controller 47 : [33, 42, 21, 7, 4]
# Switch selected is : 4
# The underloaded domains are : [1, 38, 50, 9, 20, 31]
# The target controller set for 20 is : [39, 18, 11, 26]
# The mean load ratio is : 0.03869856480103246
# The reward is = 0.2966355703772024
# Q value = 5.346473999252198
#
# Balance the overloaded controller : 40
# Controller	Controller Load Ratio
# 40 :	 0.04329757899992063
# 1 :	 0.037071597483335474
# 14 :	 0.04580336645460442
# 12 :	 0.04855439639814763
# 38 :	 0.03216724513081241
# 47 :	 0.03166650904792628
# 50 :	 0.036528768906224224
# 9 :	 0.03169464367663831
# 20 :	 0.048572584552018946
# 31 :	 0.03162895736069622
# [(701425.0498, 34), (568425.2573, 37), (415305.9206, 44)]
# Switches in the controller 40 : [44, 34, 37]
# Switch selected is : 34
# The underloaded domains are : [1, 38, 47, 50, 9, 31]
# The target controller set for 31 is : [16, 22, 6, 48]
# The mean load ratio is : 0.03869856480103246
# The reward is = 0.3842304206205211
# Q value = 4.673654567727253
#
# At time step 4999 the number of switch migrated are : 7
# The migrated switches are [0, 5, 0, 8, 24, 4, 34]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[1.         5.41151686 5.36030311 5.73150139 5.39839522 5.20249851
#   5.18691094 4.87474164 5.33251674 4.67365457]
#  [4.79584578 1.         5.56534617 4.21398525 4.85592454 4.85835829
#   4.92216179 4.74177811 4.83747354 4.74953406]
#  [4.98423354 4.7405609  1.         4.82619777 4.13892341 5.00118987
#   5.33752765 4.86298528 5.29863049 5.13994734]
#  [4.89899645 4.8540373  4.94983509 1.         5.04941326 4.92716672
#   4.14219651 4.79778255 5.43630476 4.91215923]
#  [5.31210463 4.72480412 5.04168214 4.54255298 1.         5.34005294
#   5.28713307 5.28821499 4.91240686 5.46522747]
#  [5.10656134 5.07369109 5.14886416 4.88401619 5.11443974 1.
#   5.03162395 5.16894576 5.346474   4.94446015]
#  [5.03523841 5.46583126 5.48016207 5.11703233 5.09949135 5.09389227
#   1.         4.67600093 5.3314798  5.6237417 ]
#  [5.01303531 5.25176737 5.15640687 4.96294882 5.30715971 4.87798706
#   5.03201288 1.         5.17093698 5.27995065]
#  [5.04909326 4.82270322 4.84327693 6.6790105  7.25251808 4.2575564
#   5.14182622 4.12014355 1.         4.03994827]
#  [4.94487264 5.1522932  5.38723714 5.16951986 5.41295372 5.24248001
#   5.12760388 1.         5.05372099 1.        ]]

# %% [markdown]
# # **Results**

# %%
import matplotlib.pyplot as plt

'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(4000, 5000, 100):
    x.append(time_steps_list_rn[i])

    yrandom.append(discrete_coeff_list_rn[i])
    yQL.append(discrete_coeff_list_QL[i])
    yGreedy.append(discrete_coeff_list_gr[i])

plt.plot(x, yrandom, label='Random Selection')
plt.plot(x, yQL, label='Q-Learning')
plt.plot(x, yGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

x = []

for i in range(4500, 5000, 10):
    x.append(time_steps_list_rn[i])

    zrandom.append(number_of_switches_list_rn[i])
    zQL.append(number_of_switches_list_QL[i])
    zGreedy.append(number_of_switches_list_gr[i])

plt.plot(x, zrandom, label='Random Selection')
plt.plot(x, zQL, label='Q-Learning')
plt.plot(x, zGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Number of switches migrated')
plt.legend()
plt.show()
