# %% [markdown]
# <a href="https://colab.research.google.com/github/Imperial-lord/sdn-controllers-load-balancing/blob/main/SDN_Controller_Load_Balancing_USA_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph Building and Controller Allocation**

# %%
####### Graph Building using data from Arnes.gml ########
import networkx as nx
import time
import random
import math
import numpy as np
import pandas as pd

from math import radians, cos, sin, asin, sqrt
from collections import defaultdict

####### Data collection, cleaning, and handling corner cases #######

k = int(input("Enter the number of controllers to allocate: "))
start = time.time()
graph = nx.read_gml('/content/drive/MyDrive/BTP Documents/USA - 25 nodes/Arnes.gml', label='id')

lat = nx.get_node_attributes(graph, "Latitude")
lon = nx.get_node_attributes(graph, "Longitude")

# Remove bad nodes from 'graph'
for node in list(graph.nodes):
    # removing nodes 
    # (a) with undefined latitude or longitude  
    # (b) that are isolated
    check_bad_node = lat.get(node) == None or lon.get(node) == None or nx.is_isolate(graph,node)
    if check_bad_node == True:
        graph.remove_node(node)


def dist_between_nodes(node_1, node_2):
    '''Compute distance between any 2 nodes of 'graph' using Haversine formula

    Args:
        node_1 (int): The first among the 2 graph nodes 
        node_2 (int): The second among the 2 graph nodes 

    Returns:
        dist: distanct between the two nodes
    '''
    lat_1 = radians(lat.get(node_1))
    lat_2 = radians(lat.get(node_2))
    lon_1 = radians(lon.get(node_1))
    lon_2 = radians(lon.get(node_2))

    # Applying Haversine formula
    dlon = lon_2 - lon_1
    dlat = lat_2 - lat_1
    a = sin(dlat/2)**2 + cos(lat_1)*cos(lat_2)*sin(dlon/2)**2
    c = 2*asin(sqrt(a))

    # Mean radius of Earth
    R = 6371.009
    dist = c*R

    return dist

# Assigning weights (based on distance) to the edges of the graph
for node in list(graph.nodes):
    for neighbor in list(graph.neighbors(node)):
        graph[node][neighbor]['weight'] = dist_between_nodes(node, neighbor)

# Removing edges with no weights assigned
for edge in list(graph.edges):
    if 'weight' not in graph.edges[edge] == False:
        graph.remove_edge(edge[0],edge[1])

print(nx.info(graph))
n = nx.number_of_nodes(graph)

####### Graph building and Controllers' Cluster formation #######

# Store the graph as an adjacency list
adj_list = [];
for i in range(0,n):
    adj_list.append([])

for edge in graph.edges:
    i,j = edge
    adj_list[i].append(j)
    adj_list[j].append(i)

# Random sampling for controller index selection
controllers = random.sample(range(0,n),k)

# List of lists represents index of switches in particular controller 
# e.g. [[s1,s2],[s3,s4],[s5]] controller distribution set
lol = []
for i in range(0,k):
    lol.append([])

# Controllers set
# Keeping copies for Greedy approach and Q-learning
controllers_Q = list(controllers)
controllers_G = list(controllers)
print("\nControllers: \n{}\n".format(controllers))

def BFS(queue, adj_list, listx):
    '''Performs a breadth first search in the graph
    '''
    while queue:
        p = queue.pop(0)
        u, w = p
        for v in adj_list[u]:
            if listx[v] == math.inf:
                listx[v] = w + 1
                queue.append((v, w + 1))
    return listx

index = 0
for j in range(0, k):
    listx = n*[math.inf]
    listx[controllers[index]] = 0
    queue = []
    queue.append((controllers[index], 0))
    listx = BFS(queue, adj_list, listx)
    lol[j] = listx
    index += 1

transpose_list = np.transpose(lol).tolist()
minumum_pos = []

for x in transpose_list:
    min_ele = n+5
    for i in range(0, len(x)):
        if x[i] < min_ele:
            min_ele = x[i]
    ts = []
    for i in range(0, len(x)):
        if(x[i] == min_ele):
            ts.append(i)
    minumum_pos.append(random.choice(ts))

final = []
controller_sets = []
for i in range(0, k):
    controller_sets.append([])

for i in range(0, n):
    final.append((i, controllers[minumum_pos[i]]))
    controller_sets[minumum_pos[i]].append(i)

print('Cluster set for each controller: \n{}\n'.format(controller_sets))
controller_maps = {}
index = 0

for controller_set in controller_sets:
    switch_array, controller = [], controllers[index]
    for switch in controller_set:
        if switch != controller:
            switch_array.append(switch)
    controller_maps[controller] = switch_array
    index += 1 

print('Cluster map for each controller: \n{}\n'.format(controller_maps))

def floyd_warshall(graph):
    d = defaultdict(set)
    cnt = defaultdict(set)
    inf = float('inf')

    # Initialising distance between all nodes as infinity
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            d[(node1, node2)] = inf
            cnt[(node1, node2)] = inf

    # Changing the distance between adjacent nodes
    for edge in graph.edges:
        # Undirected graph
        d[(edge[0], edge[1])] = graph.edges[edge]['weight']
        d[(edge[1], edge[0])] = graph.edges[edge]['weight']
        cnt[(edge[0], edge[1])] = 1
        cnt[(edge[1], edge[0])] = 1

    for node in graph.nodes:
        d[(node, node)] = 0
        cnt[(node, node)] = 0

    # Updating the matrix
    for node1 in graph.nodes:
        for node2 in graph.nodes:
            for node3 in graph.nodes:
                if d[(node2, node3)] > d[(node2, node1)] + d[(node1, node3)]:
                    d[(node2, node3)] = d[(node2, node1)] + d[(node1, node3)]
                    d[(node3, node2)] = d[(node2, node3)]
                    cnt[(node2, node3)] = cnt[(node2, node1)] + cnt[(node1, node3)]
                    cnt[(node3, node2)] = cnt[(node2, node3)]

    return [d, cnt]


[dist, hop_count] = floyd_warshall(graph)

print('Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count')
print(dist)
print(hop_count)

# Keeping another copy of the controller set for Greedy approach
controller_sets_G = list(controller_sets)
print(controller_sets_G)

# Keeping another copy of the controller set for Q-learning
controller_sets_Q = list(controller_sets)
print(controller_sets_Q)

frame = pd.read_csv('/content/drive/MyDrive/BTP Documents/USA - 25 nodes/data.csv')
nodes = list(graph.nodes)
# random.shuffle(nodes)
frame = frame.rename(columns=dict(zip(frame.columns, nodes)))

load_array = [] # Array of maps, with each node mapped to a load
for i in frame.index:
    Load = dict(frame.loc[i])
    load_array.append(Load)
# Out:
# Enter the number of controllers to allocate: 5
# Graph with 25 nodes and 30 edges
#
# Controllers:
# [0, 5, 14, 11, 12]
#
# Cluster set for each controller:
# [[0, 2, 3, 15, 16], [1, 4, 5, 6, 7, 9, 23], [13, 14, 17, 18, 21], [10, 11], [8, 12, 19, 20, 22, 24]]
#
# Cluster map for each controller:
# {0: [2, 3, 15, 16], 5: [1, 4, 6, 7, 9, 23], 14: [13, 17, 18, 21], 11: [10], 12: [8, 19, 20, 22, 24]}
#
# Having used Floyd Warshall algorithm, we obtain the following - (i) Dist and (ii) Hop Count
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1): 2496.127528428409, (0, 2): 1846.455318462049, (0, 3): 974.5276193754663, (0, 4): 3076.524482984332, (0, 5): 3555.9650231414303, (0, 6): 2133.4156099169736, (0, 7): 3015.1574398075227, (0, 8): 4309.873291447367, (0, 9): 4130.226769984965, (0, 10): 4627.244854976113, (0, 11): 4716.273176165248, (0, 12): 4711.9113349254185, (0, 13): 4832.35596052989, (0, 14): 4689.40157251916, (0, 15): 2174.9448589272574, (0, 16): 2480.785335199808, (0, 17): 5782.614683253603, (0, 18): 6908.869951905211, (0, 19): 3433.663242951784, (0, 20): 4005.0336816172953, (0, 21): 3817.295348838563, (0, 22): 6042.810314771954, (0, 23): 2045.6739858801025, (0, 24): 2054.7058204136733, (1, 0): 2496.127528428409, (1, 1): 0, (1, 2): 2393.5276081395255, (1, 3): 1521.5999090529428, (1, 4): 1305.8207915787937, (1, 5): 1785.261331735892, (1, 6): 362.7119185114354, (1, 7): 1244.4537484019843, (1, 8): 2539.1696000418283, (1, 9): 2359.523078579427, (1, 10): 2856.5411635705746, (1, 11): 2945.5694847597088, (1, 12): 2941.2076435198796, (1, 13): 3061.6522691243513, (1, 14): 2918.6978811136223, (1, 15): 2722.017148604734, (1, 16): 3027.8576248772843, (1, 17): 4011.9109918480654, (1, 18): 5138.166260499673, (1, 19): 1662.9595515462456, (1, 20): 2234.329990211757, (1, 21): 2046.5916574330245, (1, 22): 5351.601330864169, (1, 23): 2592.746275557579, (1, 24): 2601.7781100911498, (2, 0): 1846.455318462049, (2, 1): 2393.5276081395255, (2, 2): 0, (2, 3): 871.9276990865828, (2, 4): 2973.9245626954485, (2, 5): 3453.365102852547, (2, 6): 2030.8156896280902, (2, 7): 2912.5575195186393, (2, 8): 4207.273371158483, (2, 9): 4027.626849696082, (2, 10): 4524.64493468723, (2, 11): 4613.673255876364, (2, 12): 4609.311414636535, (2, 13): 4729.756040241006, (2, 14): 4586.801652230277, (2, 15): 328.8679255640442, (2, 16): 634.7084018365945, (2, 17): 5680.01476296472, (2, 18): 6806.270031616327, (2, 19): 3331.0633226629006, (2, 20): 3902.433761328412, (2, 21): 3714.6954285496795, (2, 22): 4196.354996309904, (2, 23): 199.2186674180533, (2, 24): 208.25050195162416, (3, 0): 974.5276193754663, (3, 1): 1521.5999090529428, (3, 2): 871.9276990865828, (3, 3): 0, (3, 4): 2101.9968636088656, (3, 5): 2581.437403765964, (3, 6): 1158.8879905415074, (3, 7): 2040.6298204320565, (3, 8): 3335.3456720719005, (3, 9): 3155.699150609499, (3, 10): 3652.7172356006467, (3, 11): 3741.745556789781, (3, 12): 3737.3837155499523, (3, 13): 3857.8283411544235, (3, 14): 3714.8739531436945, (3, 15): 1200.4172395517912, (3, 16): 1506.2577158243416, (3, 17): 4808.087063878138, (3, 18): 5934.342332529745, (3, 19): 2459.135623576318, (3, 20): 3030.506062241829, (3, 21): 2842.7677294630967, (3, 22): 5068.282695396487, (3, 23): 1071.146366504636, (3, 24): 1080.178201038207, (4, 0): 3076.524482984332, (4, 1): 1305.8207915787937, (4, 2): 2973.9245626954485, (4, 3): 2101.9968636088656, (4, 4): 0, (4, 5): 2365.658286291815, (4, 6): 943.1088730673583, (4, 7): 1824.8507029579073, (4, 8): 3119.5665545977513, (4, 9): 2939.92003313535, (4, 10): 3436.9381181264976, (4, 11): 3525.9664393156318, (4, 12): 3521.6045980758026, (4, 13): 3642.0492236802743, (4, 14): 3499.0948356695453, (4, 15): 3302.414103160657, (4, 16): 3608.2545794332073, (4, 17): 4592.307946403988, (4, 18): 5718.563215055596, (4, 19): 2243.3565061021686, (4, 20): 2814.72694476768, (4, 21): 2626.9886119889475, (4, 22): 5931.998285420092, (4, 23): 3173.143230113502, (4, 24): 3182.1750646470728, (5, 0): 3555.9650231414303, (5, 1): 1785.261331735892, (5, 2): 3453.365102852547, (5, 3): 2581.437403765964, (5, 4): 2365.658286291815, (5, 5): 0, (5, 6): 1422.5494132244567, (5, 7): 2304.2912431150057, (5, 8): 753.9082683059361, (5, 9): 574.2617468435349, (5, 10): 1071.2798318346825, (5, 11): 1160.3081530238169, (5, 12): 1155.9463117839878, (5, 13): 1276.390937388459, (5, 14): 1133.4365493777302, (5, 15): 3781.8546433177553, (5, 16): 4087.6951195903057, (5, 17): 2226.6496601121735, (5, 18): 3352.904928763781, (5, 19): 2722.797046259267, (5, 20): ...
# defaultdict(<class 'set'>, {(0, 0): 0, (0, 1): 3, (0, 2): 2, (0, 3): 1, (0, 4): 3, (0, 5): 3, (0, 6): 2, (0, 7): 3, (0, 8): 5, (0, 9): 4, (0, 10): 5, (0, 11): 6, (0, 12): 5, (0, 13): 6, (0, 14): 6, (0, 15): 2, (0, 16): 3, (0, 17): 7, (0, 18): 8, (0, 19): 4, (0, 20): 5, (0, 21): 5, (0, 22): 4, (0, 23): 3, (0, 24): 4, (1, 0): 3, (1, 1): 0, (1, 2): 3, (1, 3): 2, (1, 4): 2, (1, 5): 2, (1, 6): 1, (1, 7): 2, (1, 8): 4, (1, 9): 3, (1, 10): 4, (1, 11): 5, (1, 12): 4, (1, 13): 5, (1, 14): 5, (1, 15): 3, (1, 16): 4, (1, 17): 6, (1, 18): 7, (1, 19): 3, (1, 20): 4, (1, 21): 4, (1, 22): 5, (1, 23): 4, (1, 24): 5, (2, 0): 2, (2, 1): 3, (2, 2): 0, (2, 3): 1, (2, 4): 3, (2, 5): 3, (2, 6): 2, (2, 7): 3, (2, 8): 5, (2, 9): 4, (2, 10): 5, (2, 11): 6, (2, 12): 5, (2, 13): 6, (2, 14): 6, (2, 15): 2, (2, 16): 3, (2, 17): 7, (2, 18): 8, (2, 19): 4, (2, 20): 5, (2, 21): 5, (2, 22): 2, (2, 23): 1, (2, 24): 2, (3, 0): 1, (3, 1): 2, (3, 2): 1, (3, 3): 0, (3, 4): 2, (3, 5): 2, (3, 6): 1, (3, 7): 2, (3, 8): 4, (3, 9): 3, (3, 10): 4, (3, 11): 5, (3, 12): 4, (3, 13): 5, (3, 14): 5, (3, 15): 1, (3, 16): 2, (3, 17): 6, (3, 18): 7, (3, 19): 3, (3, 20): 4, (3, 21): 4, (3, 22): 3, (3, 23): 2, (3, 24): 3, (4, 0): 3, (4, 1): 2, (4, 2): 3, (4, 3): 2, (4, 4): 0, (4, 5): 2, (4, 6): 1, (4, 7): 2, (4, 8): 4, (4, 9): 3, (4, 10): 4, (4, 11): 5, (4, 12): 4, (4, 13): 5, (4, 14): 5, (4, 15): 3, (4, 16): 4, (4, 17): 6, (4, 18): 7, (4, 19): 3, (4, 20): 4, (4, 21): 4, (4, 22): 5, (4, 23): 4, (4, 24): 5, (5, 0): 3, (5, 1): 2, (5, 2): 3, (5, 3): 2, (5, 4): 2, (5, 5): 0, (5, 6): 1, (5, 7): 2, (5, 8): 2, (5, 9): 1, (5, 10): 2, (5, 11): 3, (5, 12): 2, (5, 13): 3, (5, 14): 3, (5, 15): 3, (5, 16): 4, (5, 17): 4, (5, 18): 5, (5, 19): 3, (5, 20): 4, (5, 21): 4, (5, 22): 5, (5, 23): 4, (5, 24): 5, (6, 0): 2, (6, 1): 1, (6, 2): 2, (6, 3): 1, (6, 4): 1, (6, 5): 1, (6, 6): 0, (6, 7): 1, (6, 8): 3, (6, 9): 2, (6, 10): 3, (6, 11): 4, (6, 12): 3, (6, 13): 4, (6, 14): 4, (6, 15): 2, (6, 16): 3, (6, 17): 5, (6, 18): 6, (6, 19): 2, (6, 20): 3, (6, 21): 3, (6, 22): 4, (6, 23): 3, (6, 24): 4, (7, 0): 3, (7, 1): 2, (7, 2): 3, (7, 3): 2, (7, 4): 2, (7, 5): 2, (7, 6): 1, (7, 7): 0, (7, 8): 4, (7, 9): 3, (7, 10): 4, (7, 11): 5, (7, 12): 4, (7, 13): 5, (7, 14): 5, (7, 15): 3, (7, 16): 4, (7, 17): 2, (7, 18): 3, (7, 19): 1, (7, 20): 2, (7, 21): 2, (7, 22): 3, (7, 23): 4, (7, 24): 5, (8, 0): 5, (8, 1): 4, (8, 2): 5, (8, 3): 4, (8, 4): 4, (8, 5): 2, (8, 6): 3, (8, 7): 4, (8, 8): 0, (8, 9): 1, (8, 10): 2, (8, 11): 3, (8, 12): 2, (8, 13): 3, (8, 14): 3, (8, 15): 4, (8, 16): 5, (8, 17): 4, (8, 18): 5, (8, 19): 2, (8, 20): 3, (8, 21): 3, (8, 22): 4, (8, 23): 3, (8, 24): 2, (9, 0): 4, (9, 1): 3, (9, 2): 4, (9, 3): 3, (9, 4): 3, (9, 5): 1, (9, 6): 2, (9, 7): 3, (9, 8): 1, (9, 9): 0, (9, 10): 1, (9, 11): 2, (9, 12): 1, (9, 13): 2, (9, 14): 2, (9, 15): 3, (9, 16): 4, (9, 17): 3, (9, 18): 4, (9, 19): 1, (9, 20): 2, (9, 21): 2, (9, 22): 3, (9, 23): 2, (9, 24): 1, (10, 0): 5, (10, 1): 4, (10, 2): 5, (10, 3): 4, (10, 4): 4, (10, 5): 2, (10, 6): 3, (10, 7): 4, (10, 8): 2, (10, 9): 1, (10, 10): 0, (10, 11): 1, (10, 12): 1, (10, 13): 1, (10, 14): 1, (10, 15): 4, (10, 16): 5, (10, 17): 2, (10, 18): 3, (10, 19): 2, (10, 20): 3, (10, 21): 3, (10, 22): 4, (10, 23): 3, (10, 24): 2, (11, 0): 6, (11, 1): 5, (11, 2): 6, (11, 3): 5, (11, 4): 5, (11, 5): 3, (11, 6): 4, (11, 7): 5, (11, 8): 3, (11, 9): 2, (11, 10): 1, (11, 11): 0, (11, 12): 2, (11, 13): 2, (11, 14): 2, (11, 15): 5, (11, 16): 6, (11, 17): 3, (11, 18): 4, (11, 19): 3, (11, 20): 4, (11, 21): 4, (11, 22): 5, (11, 23): 4, (11, 24): 3, (12, 0): 5, (12, 1): 4, (12, 2): 5, (12, 3): 4, (12, 4): 4, (12, 5): 2, (12, 6): 3, (12, 7): 4, (12, 8): 2, (12, 9): 1, (12, 10): 1, (12, 11): 2, (12, 12): 0, (12, 13): 2, (12, 14): 2, (12, 15): 4, (12, 16): 5, (12, 17): 3, (12, 18): 4, (12, 19): 2, (12, 20): 3, (12, 21): 3, (12, 22): 4, (12, 23): 3, (12, 24): 2, (13, 0): 6, (13, 1): 5, (13, 2): 6, (13, 3): 5, (13, 4): 5, (13, 5): 3, (13, 6): 4, (13, 7): 5, (13, 8): 3, (13, 9): 2, (13, 10 ...
# [[0, 2, 3, 15, 16], [1, 4, 5, 6, 7, 9, 23], [13, 14, 17, 18, 21], [10, 11], [8, 12, 19, 20, 22, 24]]
# [[0, 2, 3, 15, 16], [1, 4, 5, 6, 7, 9, 23], [13, 14, 17, 18, 21], [10, 11], [8, 12, 19, 20, 22, 24]]

# %% [markdown]
# # **Switch Migration Design**

# %% [markdown]
# Some **questions (with answers after discussion)** regarding the cell:
#
#
# 1.   For finding the load - LCi = sum of LSk. Should we add the controller's contribution too? That's something that was done previously - Yes
# 2.   For finding the load ratio - RCi was earlier taken  = LCi. I have now used a new technique to find load ratio. Is that cool? - Yes

# %%
# Switch Migration Design
'''
LCi: the load of the controller Ci
CCi: the load capacity of the controller Ci
RCi: the load ratio of the controller Ci
LSk: the packet-in message sending rate of the switch Sk
R: mean load ratio of all controllers
D: load ratio deviation coefficient between two controllers
E: migrate switch efficiency between controllers
HSk: number of hops between the switch and the controller
'''

# A. Load Balancing

'''
Controllers' Load
Populating `controller_cluster_load` array
Eg - {c1:36363663, c2:3234325, c3:32523525, c4:3523535, c5:3542646}
Load for a controller is the sum of load on it + all it's switches
'''

def calculate_controller_cluster_load(time_step, controller_sets):
    controller_cluster_load = {}
    index = 0 
    for controller_set in controller_sets:
        total_load = 0
        for switch in controller_set:
            total_load += load_array[time_step][switch]

        controller_cluster_load[controllers[index]] = total_load
        index += 1
    return controller_cluster_load

# TEST ABOVE FUNCTION --------------------------------------
# controller_cluster_load = calculate_controller_cluster_load(0, controller_sets)
# print(controller_cluster_load)
# -----------------------------------------------------------

'''
Controllers' Load Capacity
For finding this, we assume the extreme most case, i.e, number of controllers = 1
For this, the load capacity at a given time step = sum of all load on all switches at that time step.
The `load capacity of all controllers` = max of the load capacity over all time steps, and assumed to be uniform for all controllers.
'''

def calculate_controller_load_capacity():
    load_capacity_at_ts = []
    for time_step in range(0,len(load_array)):
        values = load_array[time_step].values()
        total = sum(values)
        load_capacity_at_ts.append(total)
    return max(load_capacity_at_ts)

CONTROLLERS_LOAD_CAPACITY = calculate_controller_load_capacity()

'''
Controllers' Load Ratio
The `load ratio for a controller` is the ratio of it's load to load capacity
'''

def calculate_controller_cluster_load_ratio(controller_cluster_load):
    controller_cluster_load_ratio = {}
    for controller in controller_cluster_load:
        controller_cluster_load_ratio[controller] = controller_cluster_load[controller]/CONTROLLERS_LOAD_CAPACITY
    return controller_cluster_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
# print(controller_cluster_load_ratio)
# -----------------------------------------------------------

'''
Controllers' Mean Load Ratio
The mean load ratio of controllers is given as mean of load ratios of all controllers
'''

def calculate_controller_mean_load_ratio(controller_cluster_load_ratio):
    values = controller_cluster_load_ratio.values()
    no_of_controllers = len(values)
    controller_mean_load_ratio = sum(values)/no_of_controllers
    return controller_mean_load_ratio

# TEST ABOVE FUNCTION ---------------------------------------
# controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
# print(controller_mean_load_ratio)
# -----------------------------------------------------------

'''
Discrete Coefficient 
The discrete coefficient is used to describe the degree of discrete of 
the controller’s load ratio and the mean load ratio between controllers
'''

def calculate_discrete_coefficient(controller_cluster_load_ratio):
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)
    D_num = 0
    D_denom = controller_mean_load_ratio
    no_of_controllers = len(controller_cluster_load_ratio.values())

    for controller in controller_cluster_load_ratio:
        load_ratio = controller_cluster_load_ratio[controller]
        D_num += ((load_ratio - controller_mean_load_ratio)**2)/no_of_controllers
    
    D_num = sqrt(D_num)
    D = D_num/D_denom
    return D

# TEST ABOVE FUNCTION ---------------------------------------
# discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
# print(discrete_coefficient)
# -----------------------------------------------------------

# %% [markdown]
# Some **questions(with answers after discussion)** regarding the cell:
#
#
# 1.   Hop Count is taken same as the haversine distance and the LSk = load of switch to the controller is taken as the switches contribution to the LCi. This is concerning with respect to the question 1. of previous cell.
# 2.   Hop Count being taken as a distance is giving efficiency a dimension. That is ofcourse not correct. We have to divide is by a common ratio (1 hop = x km).
#
# We have calcuated hop count using the **Floyd Warshall** algorithm. The hop count is the number of hops involved in the shortest distance between the 2 nodes.

# %%
# B. Switch Migration Efficiency

'''
If the switch is migrating between controllers, there will be migration overhead. 
Because the hop count HSk between the switch and the controller is different, 
the load LSk of the switch to the controller is different, the migration efficiency 
is expressed as the ratio of these 2 quantities: E(Ci, Sk) = LSk / HSk
'''

def calculate_switch_migration_efficiency(time_step, controller_sets):
    switch_migration_efficiency = {}
    index = 0

    for controller_set in controller_sets:
        controller = controllers[index]
        ECi = {}
        for switch in controller_set:
            if switch != controller:
                LSk = load_array[time_step][switch]
                HSk = hop_count[(controller, switch)]
                ECi[switch] = LSk/HSk
        switch_migration_efficiency[controller] = ECi
        index += 1

    return switch_migration_efficiency

# TEST ABOVE FUNCTION ---------------------------------------
# switch_migration_efficiency = calculate_switch_migration_efficiency(0, controller_sets)
# print(switch_migration_efficiency)

# mean_switch_migration_efficiency = {}
# for controller in switch_migration_efficiency:
#     values = switch_migration_efficiency[controller].values()
#     l = len(values)
#     if l==0:
#         mean_switch_migration_efficiency[controller] = 0
#     else:
#         mean_switch_migration_efficiency[controller] = sum(values)/l
# print(mean_switch_migration_efficiency)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-04-03 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# a. Migration Domain Selection:

''' 
In a real-time changing network environment, the load of each controller also changes
fast. The traditional method tends to strip the selection process of the out-migration domain 
and the in-migration domain, which introduces the probability of controller overload to some
extents, while it is also easy to bring migration conflicts and migration jitter in the 
control plane. Next, a new selection algorithm will be proposed and which will add anti-collision
mechanism in the judgment part to avoid the two consequences of the commonly bad migration. 
The switch migration domain selection algorithm is as follows:
'''

def select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient):
    out_migration_domain, in_migration_domain, migration_queue = set(), set(), set()
    D = discrete_coefficient 
    R_mean = controller_mean_load_ratio

    for Ci, RCi in controller_cluster_load_ratio.items():
        for Cj, RCj in controller_cluster_load_ratio.items():
            if Ci!=Cj:
                D_CiCj = calculate_discrete_coefficient({Ci: RCi, Cj: RCj})

                if D_CiCj > D and RCi > R_mean and RCi > RCj:
                    out_migration_domain.add(Ci)
                    in_migration_domain.add(Cj)
                    migration_queue.add((Ci,Cj))
                if D_CiCj < D and RCi < R_mean and RCi < RCj:
                    out_migration_domain.add(Cj)
                    in_migration_domain.add(Ci)
                    migration_queue.add((Cj,Ci))
                if D_CiCj == D:
                    if RCi < R_mean and RCi < RCj:
                        out_migration_domain.add(Cj)
                        in_migration_domain.add(Ci)
                        migration_queue.add((Cj,Ci))
                    if RCi > R_mean and RCi > RCj:
                        out_migration_domain.add(Ci)
                        in_migration_domain.add(Cj)
                        migration_queue.add((Ci,Cj))
    
    return out_migration_domain, in_migration_domain, migration_queue

# TEST ABOVE FUNCTION ---------------------------------------
# out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
# print(out_migration_domain) 
# print(in_migration_domain) 
# print(migration_queue)
# -----------------------------------------------------------

# %% [markdown]
# ![Screenshot 2021-09-03 at 13-34-10 2103 06579 pdf.png](data:image/png;base64,...)
# ![Screenshot 2021-09-03 at 14-29-43 2103 06579 pdf.png](data:image/png;base64,...)

# %%
# C. Migration Tuples Selection

# b. Migration Switch Selection: 

'''
For each migration queue Q that will be migrating, the migration switch selected by the algorithm is defined 
as the fastest reduction of the factor of the load ratio under the best efficiency ECi,Sk in migration.
The switches under the out-migration controller are sorted according to the migration efficiency, 
the higher the efficiency of the switch migration, the higher the possibility of being selected. 
A switch combination managed by the out-migration controller, whose migration efficiency of each 
switch has greater than the average efficiency in migration and arranged by size, which is finding 
out by the selection algorithm. 
It is the optimal migration switch combination when it maximizes the reduction of the discrete coefficients 
between controllers. The specific algorithm of selecting migrating switch is as follows:
'''

def select_migrating_switch(controller_sets_input, controller_cluster_load_ratio, migration_queue, time_step, switch_migration_efficiency):
    # migration_tuples = set()
    migration_tuples = []
    n, Q = 0, migration_queue

    for q in Q:
        Ci, Cj = q
        ECiS = 0
        L, S_collection = {}, []
        S = controller_sets_input[controllers_G.index(Ci)]
        # Remove the controller from the list of switches since it the hop count for it is 0
        if  Ci in S:
            S.remove(Ci)
        n = len(S)

        for Sk in S:
            ECiS += switch_migration_efficiency[Ci][Sk]
            L[Sk]=switch_migration_efficiency[Ci][Sk]

        L = dict(sorted(L.items(), key=lambda x: x[1], reverse=True))
        ECiS_mean = ECiS/(n+1) # correct this !!!
        k = 1

        LSk_sum = 0
        for Sk in L:
            LSk = load_array[time_step][Sk]
            LSk_sum += LSk*((Ci+1)/(Cj+1))

        RCi_dash, RCj_dash = controller_cluster_load_ratio[Ci]+LSk_sum, controller_cluster_load_ratio[Cj]+LSk_sum
        RCiCj_mean = (controller_cluster_load_ratio[Ci] + controller_cluster_load_ratio[Cj])/2
        DCiCj_num = ((RCi_dash - RCiCj_mean)**2 + (RCj_dash - RCiCj_mean)**2)/2
        DCiCj_num = sqrt(DCiCj_num)
        DCiCj_dash = DCiCj_num/RCiCj_mean

        temp = math.inf
        for Sk in L:
            ECiSk = switch_migration_efficiency[Ci][Sk]
            if ECiSk >= ECiS_mean and DCiCj_dash < temp:
                k+=1
                temp = DCiCj_dash
                S_collection.append(Sk)
            else:
                break

        migration_tuples.append((Ci,Cj,S_collection))

    return migration_tuples

# TEST ABOVE FUNCTION ---------------------------------------
# migration_tuples = select_migrating_switch(controller_cluster_load_ratio,migration_queue,0, switch_migration_efficiency)
# print(migration_tuples)
# print(controller_sets)
# print(controller_sets_G)
# -----------------------------------------------------------

# %% [markdown]
# # **Greedy Approach Implementation**

# %%
'''
Implement a purely greedy approach using the above function from the research paper.
'''

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

# For making graph
time_steps_list_gr = []
load_balance_rate_list_gr = []
discrete_coeff_list_gr = []
number_of_switches_list_gr = []

load_rate_list_gr = []


for i in range(0,5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_G)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)

    out_migration_domain, in_migration_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    switch_migration_efficiency = calculate_switch_migration_efficiency(i, controller_sets_G)
    print(switch_migration_efficiency)
    print(migration_queue)
    migration_tuples = select_migrating_switch(controller_sets_G, controller_cluster_load_ratio, migration_queue, i, switch_migration_efficiency)

    switch_array = []

    for each_tuple in migration_tuples:
        index_of_overloaded_controller, target_controller_index = controllers_G.index(each_tuple[0]), controllers_G.index(each_tuple[1]) 
        current_switch = each_tuple[2][0]
        
        print(each_tuple)
        print(controller_sets_G)
        print(current_switch)
        
        if(current_switch in controller_sets_G[index_of_overloaded_controller]):
            controller_sets_G[index_of_overloaded_controller].remove(current_switch)
            controller_sets_G[target_controller_index].append(current_switch)

        switch_array.append(current_switch)


    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    time_steps_list_gr.append(i)
    load_balance_rate_list_gr.append(l_rate)
    discrete_coeff_list_gr.append(discrete_coeff)
    number_of_switches_list_gr.append(len(switch_array))

    load_rate_list_gr.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# 10
# (11, 0, [8])
# [[15, 16, 18, 19], [24, 20, 9, 8], [13, 17, 21, 6, 1], [22, 23, 3, 7], [2, 4, 10]]
# 8
# (12, 5, [2])
# [[15, 16, 18, 19], [24, 20, 9, 8], [13, 17, 21, 6, 1], [22, 23, 3, 7], [2, 4, 10]]
# 2
# (14, 12, [9])
# [[15, 16, 18, 19], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 10]]
# 9
# (0, 5, [10])
# [[15, 16, 18, 19], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 10]]
# 10
# (14, 0, [9])
# [[15, 16, 18, 19], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 10]]
# 9
# (11, 12, [8])
# [[15, 16, 18, 19], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 10]]
# 8
# At time step 4848 the number of switch migrated are : 9
# The migrated switches are [9, 8, 10, 8, 2, 9, 10, 9, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4849
# {0: {15: 2926.426865, 16: 7842.910553333332, 18: 51912.627075, 19: 103826.422375}, 5: {24: 83061.36504, 20: 103828.6839, 9: 860189.7761, 8: 292883.05915, 2: 174755.51656666666}, 14: {13: 822.410758, 17: 7939.067398, 21: 103826.294675, 6: 103826.75, 1: 149558.77844}, 11: {22: 83062.47546, 23: 103828.734575, 3: 94583.9461, 7: 72559.59654}, 12: {4: 101966.4164, 10: 565902.6436}}
# {(12, 0), (5, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (12, 0, [10])
# [[15, 16, 18, 19], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 10]]
# 10
# (5, 12, [9])
# [[15, 16, 18, 19, 10], [24, 20, 9, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4]]
# 9
# (11, 0, [23])
# [[15, 16, 18, 19, 10], [24, 20, 8, 2], [13, 17, 21, 6, 1], [22, 23, 3, 7], [4, 9]]
# 23
# (14, 12, [1])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6, 1], [22, 3, 7], [4, 9]]
# 1
# (14, 0, [1])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6], [22, 3, 7], [4, 9, 1]]
# 1
# (5, 0, [9])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6], [22, 3, 7], [4, 9, 1]]
# 9
# (11, 12, [23])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6], [22, 3, 7], [4, 9, 1]]
# 23
# At time step 4849 the number of switch migrated are : 7
# The migrated switches are [10, 9, 23, 1, 1, 9, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4850
# {0: {15: 1662.4958255000001, 16: 434.3846186666667, 18: 51913.402375, 19: 103826.436425, 10: 97848.49154, 23: 138438.36406666666}, 5: {24: 83059.80596, 20: 103828.3479, 8: 76323.06595, 2: 243284.781}, 14: {13: 2535.171428, 17: 3069.674914, 21: 103828.351725, 6: 103826.75}, 11: {22: 83061.43377999999, 3: 60568.64839999999, 7: 143222.64572}, 12: {4: 132163.918, 9: 449615.6772, 1: 164550.762425}}
# {(12, 14), (5, 11), (0, 14), (5, 14), (0, 11), (12, 11)}
# (12, 14, [9])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6], [22, 3, 7], [4, 9, 1]]
# 9
# (5, 11, [2])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8, 2], [13, 17, 21, 6, 9], [22, 3, 7], [4, 1]]
# 2
# (0, 14, [23])
# [[15, 16, 18, 19, 10, 23], [24, 20, 8], [13, 17, 21, 6, 9], [22, 3, 7, 2], [4, 1]]
# 23
# (5, 14, [2])
# [[15, 16, 18, 19, 10], [24, 20, 8], [13, 17, 21, 6, 9, 23], [22, 3, 7, 2], [4, 1]]
# 2
# (0, 11, [23])
# [[15, 16, 18, 19, 10], [24, 20, 8], [13, 17, 21, 6, 9, 23], [22, 3, 7, 2], [4, 1]]
# 23
# (12, 11, [9])
# [[15, 16, 18, 19, 10], [24, 20, 8], [13, 17, 21, 6, 9, 23], [22, 3, 7, 2], [4, 1]]
# 9
# At time step 4850 the number of switch migrated are : 6
# The migrated switches are [9, 2, 23, 2, 23, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4851
# {0: {15: 3918.305464, 16: 1400.771554, 18: 51913.4257875, 19: 103826.14085, 10: 81983.8303}, 5: {24: 83062.28242, 20: 103824.28855, 8: 226990.0076}, 14: {13: 2667.665837, 17: 8387.811462, 21: 103825.881825, 6: 103826.75, 9: 232618.77905, 23: 103827.852975}, 11: {22: 83061.12018, 3: 72703.24132, 7: 103159.78125999999, 2: 126165.04648333334}, 12: {4: 153341.718525, 1: 113028.16445}}
# {(14, 5), (11, 5), (5, 12), (0, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (14, 5, [9])
# [[15, 16, 18, 19, 10], [24, 20, 8], [13, 17, 21, 6, 9, 23], [22, 3, 7, 2], [4, 1]]
# 9
# (11, 5, [2])
# [[15, 16, 18, 19, 10], [24, 20, 8, 9], [13, 17, 21, 6, 23], [22, 3, 7, 2], [4, 1]]
# 2
# (5, 12, [8])
# [[15, 16, 18, 19, 10], [24, 20, 8, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1]]
# 8
# (0, 12, [19])
# [[15, 16, 18, 19, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8]]
# 19
# (11, 0, [2])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 2
# (14, 12, [9])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 9
# (14, 0, [9])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 9
# (5, 0, [8])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 8
# (11, 12, [2])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 2
# At time step 4851 the number of switch migrated are : 9
# The migrated switches are [9, 2, 8, 19, 2, 9, 9, 8, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4852
# {0: {15: 3088.0261535, 16: 659.4359986666667, 18: 51914.0724625, 10: 100800.33574}, 5: {24: 83061.1271, 20: 103826.229025, 9: 470756.8267, 2: 231989.70813333333}, 14: {13: 2544.511579, 17: 7809.163092, 21: 103827.51275000001, 6: 103826.75, 23: 103826.1881}, 11: {22: 83061.6375, 3: 123922.92308000001, 7: 92839.008}, 12: {4: 161144.088975, 1: 197326.1729, 8: 304905.2706, 19: 207659.5144}}
# {(12, 14), (5, 11), (12, 0), (11, 0), (5, 14), (14, 0), (5, 0), (11, 14), (12, 11)}
# (12, 14, [8])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23], [22, 3, 7], [4, 1, 8, 19]]
# 8
# (5, 11, [9])
# [[15, 16, 18, 10], [24, 20, 9, 2], [13, 17, 21, 6, 23, 8], [22, 3, 7], [4, 1, 19]]
# 9
# (12, 0, [8])
# [[15, 16, 18, 10], [24, 20, 2], [13, 17, 21, 6, 23, 8], [22, 3, 7, 9], [4, 1, 19]]
# 8
# (11, 0, [3])
# [[15, 16, 18, 10], [24, 20, 2], [13, 17, 21, 6, 23, 8], [22, 3, 7, 9], [4, 1, 19]]
# 3
# (5, 14, [9])
# [[15, 16, 18, 10, 3], [24, 20, 2], [13, 17, 21, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 9
# (14, 0, [21])
# [[15, 16, 18, 10, 3], [24, 20, 2], [13, 17, 21, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 21
# (5, 0, [9])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2], [13, 17, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 9
# (11, 14, [3])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2], [13, 17, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 3
# (12, 11, [8])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2], [13, 17, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 8
# At time step 4852 the number of switch migrated are : 9
# The migrated switches are [8, 9, 8, 3, 9, 21, 9, 3, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4853
# {0: {15: 2462.0318625, 16: 590.6939723333334, 18: 51912.8715375, 10: 106054.1821, 3: 91935.26026, 21: 83061.57243999999}, 5: {24: 83062.06938, 20: 103827.295925, 2: 245791.04386666665}, 14: {13: 1971.4641115, 17: 7167.5188849999995, 6: 103826.75, 23: 103827.1782, 8: 210368.53683333332}, 11: {22: 83061.91212000001, 7: 150517.0014, 9: 335882.16575}, 12: {4: 114172.779675, 1: 190232.255775, 19: 207654.3363}}
# {(12, 14), (11, 5), (12, 0), (12, 5), (5, 14), (11, 0), (14, 0), (5, 0), (11, 14)}
# (12, 14, [19])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2], [13, 17, 6, 23, 8], [22, 7, 9], [4, 1, 19]]
# 19
# (11, 5, [9])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2], [13, 17, 6, 23, 8, 19], [22, 7, 9], [4, 1]]
# 9
# (12, 0, [19])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2, 9], [13, 17, 6, 23, 8, 19], [22, 7], [4, 1]]
# 19
# (12, 5, [19])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2, 9], [13, 17, 6, 23, 8, 19], [22, 7], [4, 1]]
# 19
# (5, 14, [2])
# [[15, 16, 18, 10, 3, 21], [24, 20, 2, 9], [13, 17, 6, 23, 8, 19], [22, 7], [4, 1]]
# 2
# (11, 0, [9])
# [[15, 16, 18, 10, 3, 21], [24, 20, 9], [13, 17, 6, 23, 8, 19, 2], [22, 7], [4, 1]]
# 9
# (14, 0, [8])
# [[15, 16, 18, 10, 3, 21], [24, 20, 9], [13, 17, 6, 23, 8, 19, 2], [22, 7], [4, 1]]
# 8
# (5, 0, [2])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20, 9], [13, 17, 6, 23, 19, 2], [22, 7], [4, 1]]
# 2
# (11, 14, [9])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20, 9], [13, 17, 6, 23, 19, 2], [22, 7], [4, 1]]
# 9
# At time step 4853 the number of switch migrated are : 9
# The migrated switches are [19, 9, 19, 19, 2, 9, 8, 2, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4854
# {0: {15: 4374.3785035, 16: 5972.55688, 18: 51913.890075, 10: 46008.19244, 3: 1481244.9730000002, 21: 83062.50454, 8: 89824.12036}, 5: {24: 83061.54108, 20: 103824.5309, 9: 736761.074}, 14: {13: 258.18513585, 17: 5201.786501, 6: 103826.75, 23: 103827.250025, 19: 138434.95933333333, 2: 109552.59513333334}, 11: {22: 83060.5017, 7: 88891.1373}, 12: {4: 172348.523875, 1: 170814.41975}}
# {(14, 11), (14, 5), (5, 11), (5, 12), (0, 12), (14, 12), (0, 11), (0, 5), (12, 11)}
# (14, 11, [19])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20, 9], [13, 17, 6, 23, 19, 2], [22, 7], [4, 1]]
# 19
# (14, 5, [19])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20, 9], [13, 17, 6, 23, 2], [22, 7, 19], [4, 1]]
# 19
# (5, 11, [9])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20, 9], [13, 17, 6, 23, 2], [22, 7, 19], [4, 1]]
# 9
# (5, 12, [9])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1]]
# 9
# (0, 12, [3])
# [[15, 16, 18, 10, 3, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1]]
# 3
# (14, 12, [19])
# [[15, 16, 18, 10, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1, 3]]
# 19
# (0, 11, [3])
# [[15, 16, 18, 10, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1, 3]]
# 3
# (0, 5, [3])
# [[15, 16, 18, 10, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1, 3]]
# 3
# (12, 11, [4])
# [[15, 16, 18, 10, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9], [4, 1, 3]]
# 4
# At time step 4854 the number of switch migrated are : 9
# The migrated switches are [19, 19, 9, 9, 3, 19, 3, 3, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4855
# {0: {15: 3209.3123204999997, 16: 467.74827933333336, 18: 51913.952425, 10: 109314.11832000001, 21: 83060.57373999999, 8: 79641.67238}, 5: {24: 83060.73806, 20: 103827.610225}, 14: {13: 2244.493162, 17: 5068.949235, 6: 103826.75, 23: 103825.82195, 2: 84309.34491666667}, 11: {22: 83061.47424, 7: 81543.6026, 19: 138436.33663333333, 9: 268834.0623, 4: 129606.63986}, 12: {1: 165418.36525, 3: 21658.29198}}
# {(14, 5), (11, 5), (0, 14), (5, 12), (0, 12), (14, 12), (0, 5), (11, 14), (11, 12)}
# (14, 5, [6])
# [[15, 16, 18, 10, 21, 8], [24, 20], [13, 17, 6, 23, 2], [22, 7, 19, 9, 4], [1, 3]]
# 6
# (11, 5, [9])
# [[15, 16, 18, 10, 21, 8], [24, 20, 6], [13, 17, 23, 2], [22, 7, 19, 9, 4], [1, 3]]
# 9
# (0, 14, [10])
# [[15, 16, 18, 10, 21, 8], [24, 20, 6, 9], [13, 17, 23, 2], [22, 7, 19, 4], [1, 3]]
# 10
# (5, 12, [20])
# [[15, 16, 18, 21, 8], [24, 20, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3]]
# 20
# (0, 12, [10])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 10
# (14, 12, [6])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 6
# (0, 5, [10])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 10
# (11, 14, [9])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 9
# (11, 12, [9])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 9
# At time step 4855 the number of switch migrated are : 9
# The migrated switches are [6, 9, 10, 20, 10, 6, 10, 9, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4856
# {0: {15: 2009.2747399999998, 16: 822.2047736666667, 18: 51913.21065, 21: 83061.15651999999, 8: 112657.68288000001}, 5: {24: 83062.1017, 6: 415307.0, 9: 556525.4382}, 14: {13: 1017.2271345, 17: 4696.598404, 23: 103826.162825, 2: 99726.62595, 10: 523330.6011}, 11: {22: 83061.65242, 7: 114562.28322000001, 19: 138437.46413333333, 4: 95969.6727}, 12: {1: 233965.773425, 3: 109314.615975, 20: 138436.78023333332}}
# {(12, 14), (14, 5), (12, 0), (11, 5), (11, 0), (12, 5), (0, 5), (14, 0), (11, 14)}
# (12, 14, [1])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10], [22, 7, 19, 4], [1, 3, 20]]
# 1
# (14, 5, [10])
# [[15, 16, 18, 21, 8], [24, 6, 9], [13, 17, 23, 2, 10, 1], [22, 7, 19, 4], [3, 20]]
# 10
# (12, 0, [1])
# [[15, 16, 18, 21, 8], [24, 6, 9, 10], [13, 17, 23, 2, 1], [22, 7, 19, 4], [3, 20]]
# 1
# (11, 5, [19])
# [[15, 16, 18, 21, 8], [24, 6, 9, 10], [13, 17, 23, 2, 1], [22, 7, 19, 4], [3, 20]]
# 19
# (11, 0, [19])
# [[15, 16, 18, 21, 8], [24, 6, 9, 10, 19], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 19
# (12, 5, [1])
# [[15, 16, 18, 21, 8], [24, 6, 9, 10, 19], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 1
# (0, 5, [8])
# [[15, 16, 18, 21, 8], [24, 6, 9, 10, 19], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 8
# (14, 0, [10])
# [[15, 16, 18, 21], [24, 6, 9, 10, 19, 8], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 10
# (11, 14, [19])
# [[15, 16, 18, 21], [24, 6, 9, 10, 19, 8], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 19
# At time step 4856 the number of switch migrated are : 9
# The migrated switches are [1, 10, 1, 19, 19, 1, 8, 10, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4857
# {0: {15: 4385.0194329999995, 16: 5118.374173333333, 18: 51913.7636, 21: 83061.18526}, 5: {24: 83061.61798000001, 6: 415307.0, 9: 415769.3751, 10: 194622.223, 19: 138434.53063333334, 8: 264506.79695}, 14: {13: 321.20850735000005, 17: 6726.960421, 23: 103827.970425, 2: 134992.26251666667, 1: 166193.90904}, 11: {22: 83061.57776, 7: 109536.67286, 4: 107450.38911999999}, 12: {3: 151317.832475, 20: 138435.50293333334}}
# {(14, 11), (12, 0), (5, 11), (5, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (14, 11, [1])
# [[15, 16, 18, 21], [24, 6, 9, 10, 19, 8], [13, 17, 23, 2, 1], [22, 7, 4], [3, 20]]
# 1
# (12, 0, [3])
# [[15, 16, 18, 21], [24, 6, 9, 10, 19, 8], [13, 17, 23, 2], [22, 7, 4, 1], [3, 20]]
# 3
# (5, 11, [9])
# [[15, 16, 18, 21, 3], [24, 6, 9, 10, 19, 8], [13, 17, 23, 2], [22, 7, 4, 1], [20]]
# 9
# (5, 12, [9])
# [[15, 16, 18, 21, 3], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 7, 4, 1, 9], [20]]
# 9
# (11, 0, [7])
# [[15, 16, 18, 21, 3], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 7, 4, 1, 9], [20]]
# 7
# (14, 12, [1])
# [[15, 16, 18, 21, 3, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 4, 1, 9], [20]]
# 1
# (14, 0, [1])
# [[15, 16, 18, 21, 3, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 4, 1, 9], [20]]
# 1
# (5, 0, [9])
# [[15, 16, 18, 21, 3, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 4, 1, 9], [20]]
# 9
# (11, 12, [7])
# [[15, 16, 18, 21, 3, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 4, 1, 9], [20]]
# 7
# At time step 4857 the number of switch migrated are : 9
# The migrated switches are [1, 3, 9, 9, 7, 1, 1, 9, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4858
# {0: {15: 1586.6335345, 16: 1664.1853883333333, 18: 51913.1580875, 21: 83060.12054, 3: 364761.8952, 7: 171094.84553333334}, 5: {24: 83061.60803999999, 6: 415307.0, 10: 304767.7128, 19: 138433.47536666665, 8: 375052.22435}, 14: {13: 449.35839135, 17: 3545.701425, 23: 103827.993125, 2: 53416.565566666664}, 11: {22: 83061.82828, 4: 131597.63929999998, 1: 119349.7097, 9: 193342.818}, 12: {20: 138434.47176666665}}
# {(0, 14), (5, 12), (0, 12), (5, 14), (14, 12), (11, 14), (11, 12)}
# (0, 14, [3])
# [[15, 16, 18, 21, 3, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2], [22, 4, 1, 9], [20]]
# 3
# (5, 12, [6])
# [[15, 16, 18, 21, 7], [24, 6, 10, 19, 8], [13, 17, 23, 2, 3], [22, 4, 1, 9], [20]]
# 6
# (0, 12, [3])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 23, 2, 3], [22, 4, 1, 9], [20, 6]]
# 3
# (5, 14, [6])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 23, 2, 3], [22, 4, 1, 9], [20, 6]]
# 6
# (14, 12, [23])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 23, 2, 3], [22, 4, 1, 9], [20, 6]]
# 23
# (11, 14, [9])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 2, 3], [22, 4, 1, 9], [20, 6, 23]]
# 9
# (11, 12, [9])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 2, 3, 9], [22, 4, 1], [20, 6, 23]]
# 9
# At time step 4858 the number of switch migrated are : 7
# The migrated switches are [3, 6, 3, 6, 23, 9, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4859
# {0: {15: 2986.1679675, 16: 1850.3384516666665, 18: 51912.7462375, 21: 83061.09956, 7: 162633.6925}, 5: {24: 83061.8818, 10: 220405.09445, 19: 138437.12393333335, 8: 323608.35935}, 14: {13: 1039.062037, 17: 6615.954902, 2: 72868.45408333333, 3: 42964.81048, 9: 305508.4951}, 11: {22: 83061.6407, 4: 80408.65204, 1: 82267.0184}, 12: {20: 138432.99756666666, 6: 138435.66666666666, 23: 138436.49273333335}}
# {(14, 11), (5, 11), (0, 14), (5, 12), (0, 12), (5, 14), (14, 12), (0, 11), (5, 0), (12, 11)}
# (14, 11, [9])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 2, 3, 9], [22, 4, 1], [20, 6, 23]]
# 9
# (5, 11, [8])
# [[15, 16, 18, 21, 7], [24, 10, 19, 8], [13, 17, 2, 3], [22, 4, 1, 9], [20, 6, 23]]
# 8
# (0, 14, [7])
# [[15, 16, 18, 21, 7], [24, 10, 19], [13, 17, 2, 3], [22, 4, 1, 9, 8], [20, 6, 23]]
# 7
# (5, 12, [8])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 8
# (0, 12, [7])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 7
# (5, 14, [8])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 8
# (14, 12, [9])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 9
# (0, 11, [7])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 7
# (5, 0, [8])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 8
# (12, 11, [23])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8], [20, 6, 23]]
# 23
# At time step 4859 the number of switch migrated are : 10
# The migrated switches are [9, 8, 7, 8, 7, 8, 9, 7, 8, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4860
# {0: {15: 3743.585289, 16: 3378.9154099999996, 18: 51913.831025, 21: 83061.14884000001}, 5: {24: 83061.68992, 10: 442534.33155, 19: 138436.58953333335}, 14: {13: 1199.9201035, 17: 5367.738132, 2: 118486.3133, 3: 227376.22319999998, 7: 159128.4866}, 11: {22: 83062.13472, 4: 111025.7262, 1: 124738.99676000001, 9: 237510.52405, 8: 121016.40636666666, 23: 103826.15695}, 12: {20: 138435.0273, 6: 138435.66666666666}}
# {(14, 5), (11, 5), (5, 12), (0, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (14, 5, [3])
# [[15, 16, 18, 21], [24, 10, 19], [13, 17, 2, 3, 7], [22, 4, 1, 9, 8, 23], [20, 6]]
# 3
# (11, 5, [9])
# [[15, 16, 18, 21], [24, 10, 19, 3], [13, 17, 2, 7], [22, 4, 1, 9, 8, 23], [20, 6]]
# 9
# (5, 12, [10])
# [[15, 16, 18, 21], [24, 10, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6]]
# 10
# (0, 12, [21])
# [[15, 16, 18, 21], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10]]
# 21
# (11, 0, [9])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 9
# (14, 12, [3])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 3
# (14, 0, [3])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 3
# (5, 0, [10])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 10
# (11, 12, [9])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 9
# At time step 4860 the number of switch migrated are : 9
# The migrated switches are [3, 9, 10, 21, 9, 3, 3, 10, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4861
# {0: {15: 2829.855568, 16: 1564.0063976666668, 18: 51913.3278375}, 5: {24: 83061.09594, 19: 138436.52566666668, 3: 149462.6968, 9: 573929.9277}, 14: {13: 1068.892744, 17: 5973.529125999999, 2: 98826.97588333335, 7: 94181.09677999999}, 11: {22: 83060.42480000001, 4: 120696.02468, 1: 182624.21882, 8: 148143.50733333334, 23: 103825.698225}, 12: {20: 138434.85173333334, 6: 138435.66666666666, 10: 408413.1645, 21: 138433.78283333333}}
# {(12, 14), (12, 0), (5, 14), (11, 0), (14, 0), (5, 0), (11, 14)}
# (12, 14, [10])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7], [22, 4, 1, 8, 23], [20, 6, 10, 21]]
# 10
# (12, 0, [10])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7, 10], [22, 4, 1, 8, 23], [20, 6, 21]]
# 10
# (5, 14, [9])
# [[15, 16, 18], [24, 19, 3, 9], [13, 17, 2, 7, 10], [22, 4, 1, 8, 23], [20, 6, 21]]
# 9
# (11, 0, [1])
# [[15, 16, 18], [24, 19, 3], [13, 17, 2, 7, 10, 9], [22, 4, 1, 8, 23], [20, 6, 21]]
# 1
# (14, 0, [2])
# [[15, 16, 18, 1], [24, 19, 3], [13, 17, 2, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21]]
# 2
# (5, 0, [9])
# [[15, 16, 18, 1, 2], [24, 19, 3], [13, 17, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21]]
# 9
# (11, 14, [1])
# [[15, 16, 18, 1, 2], [24, 19, 3], [13, 17, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21]]
# 1
# At time step 4861 the number of switch migrated are : 7
# The migrated switches are [10, 10, 9, 1, 2, 9, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4862
# {0: {15: 5185.152185, 16: 1944.5540863333335, 18: 51913.1934625, 1: 168366.07923333332, 2: 358631.5078}, 5: {24: 83062.51806, 19: 138434.6549, 3: 1313274.8235}, 14: {13: 843.1487574999999, 17: 4827.741433, 7: 133348.42114, 10: 379267.2612, 9: 325117.02445}, 11: {22: 83062.20918, 4: 111750.29991999999, 8: 210012.9689, 23: 103826.5366}, 12: {20: 138435.1116, 6: 138435.66666666666, 21: 138436.95106666666}}
# {(5, 12), (0, 12), (11, 0), (5, 14), (14, 12), (14, 0), (5, 0), (11, 14), (11, 12)}
# (5, 12, [3])
# [[15, 16, 18, 1, 2], [24, 19, 3], [13, 17, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21]]
# 3
# (0, 12, [2])
# [[15, 16, 18, 1, 2], [24, 19], [13, 17, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21, 3]]
# 2
# (11, 0, [8])
# [[15, 16, 18, 1], [24, 19], [13, 17, 7, 10, 9], [22, 4, 8, 23], [20, 6, 21, 3, 2]]
# 8
# (5, 14, [3])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 10, 9], [22, 4, 23], [20, 6, 21, 3, 2]]
# 3
# (14, 12, [10])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 10, 9], [22, 4, 23], [20, 6, 21, 3, 2]]
# 10
# (14, 0, [10])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9], [22, 4, 23], [20, 6, 21, 3, 2, 10]]
# 10
# (5, 0, [3])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9], [22, 4, 23], [20, 6, 21, 3, 2, 10]]
# 3
# (11, 14, [8])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9], [22, 4, 23], [20, 6, 21, 3, 2, 10]]
# 8
# (11, 12, [8])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9], [22, 4, 23], [20, 6, 21, 3, 2, 10]]
# 8
# At time step 4862 the number of switch migrated are : 9
# The migrated switches are [3, 2, 8, 3, 10, 10, 3, 8, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4863
# {0: {15: 2965.7040644999997, 16: 137.83572113333332, 18: 51913.6853125, 1: 124683.56056666667, 8: 83422.04486}, 5: {24: 83062.36462, 19: 138435.7673}, 14: {13: 2174.905358, 17: 6436.382768, 7: 164044.19422, 9: 215719.4104}, 11: {22: 83062.4483, 4: 95114.31396, 23: 103826.375375}, 12: {20: 138435.4411, 6: 138435.66666666666, 21: 138435.9514, 3: 8589.9100225, 2: 121924.43607999998, 10: 437970.5388}}
# {(12, 14), (14, 5), (12, 0), (11, 5), (11, 0), (12, 5), (0, 5), (14, 0), (11, 14), (12, 11)}
# (12, 14, [10])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9], [22, 4, 23], [20, 6, 21, 3, 2, 10]]
# 10
# (14, 5, [9])
# [[15, 16, 18, 1, 8], [24, 19], [13, 17, 7, 9, 10], [22, 4, 23], [20, 6, 21, 3, 2]]
# 9
# (12, 0, [10])
# [[15, 16, 18, 1, 8], [24, 19, 9], [13, 17, 7, 10], [22, 4, 23], [20, 6, 21, 3, 2]]
# 10
# (11, 5, [23])
# [[15, 16, 18, 1, 8], [24, 19, 9], [13, 17, 7, 10], [22, 4, 23], [20, 6, 21, 3, 2]]
# 23
# (11, 0, [23])
# [[15, 16, 18, 1, 8], [24, 19, 9, 23], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 23
# (12, 5, [10])
# [[15, 16, 18, 1, 8], [24, 19, 9, 23], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 10
# (0, 5, [1])
# [[15, 16, 18, 1, 8], [24, 19, 9, 23], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 1
# (14, 0, [9])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 9
# (11, 14, [23])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 23
# (12, 11, [10])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 10
# At time step 4863 the number of switch migrated are : 10
# The migrated switches are [10, 9, 10, 23, 23, 10, 1, 9, 23, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4864
# {0: {15: 3219.48765, 16: 6144.22535, 18: 51913.83815, 8: 130764.8843}, 5: {24: 83061.88768, 19: 138434.0301, 9: 769435.8504, 23: 103825.050175, 1: 536265.762}, 14: {13: 2750.265923, 17: 1871.7920629999999, 7: 115298.2394, 10: 773905.7923}, 11: {22: 83062.51436, 4: 73367.00316}, 12: {20: 138434.51619999998, 6: 138435.66666666666, 21: 138436.55286666667, 3: 197112.507675, 2: 82028.19584}}
# {(14, 11), (12, 14), (5, 11), (12, 0), (5, 14), (0, 11), (14, 0), (5, 0), (12, 11)}
# (14, 11, [10])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7, 10], [22, 4], [20, 6, 21, 3, 2]]
# 10
# (12, 14, [3])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7], [22, 4, 10], [20, 6, 21, 3, 2]]
# 3
# (5, 11, [9])
# [[15, 16, 18, 8], [24, 19, 9, 23, 1], [13, 17, 7, 3], [22, 4, 10], [20, 6, 21, 2]]
# 9
# (12, 0, [3])
# [[15, 16, 18, 8], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9], [20, 6, 21, 2]]
# 3
# (5, 14, [9])
# [[15, 16, 18, 8], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9], [20, 6, 21, 2]]
# 9
# (0, 11, [8])
# [[15, 16, 18, 8], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9], [20, 6, 21, 2]]
# 8
# (14, 0, [10])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9, 8], [20, 6, 21, 2]]
# 10
# (5, 0, [9])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9, 8], [20, 6, 21, 2]]
# 9
# (12, 11, [3])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9, 8], [20, 6, 21, 2]]
# 3
# At time step 4864 the number of switch migrated are : 9
# The migrated switches are [10, 3, 9, 3, 9, 8, 10, 9, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4865
# {0: {15: 4974.2179615000005, 16: 1053.7324613333333, 18: 51913.2918}, 5: {24: 83061.30702, 19: 138437.38139999998, 23: 103826.3997, 1: 461514.9366}, 14: {13: 796.7446445, 17: 6056.357158, 7: 156880.43646, 3: 33748.598979999995}, 11: {22: 83060.75046, 4: 95442.13188, 10: 842058.1767, 9: 381498.35975, 8: 244145.3999333333}, 12: {20: 138437.50743333335, 6: 138435.66666666666, 21: 138433.41896666665, 2: 114257.01608}}
# {(12, 14), (12, 0), (5, 14), (11, 0), (14, 0), (5, 0), (11, 14)}
# (12, 14, [20])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3], [22, 4, 10, 9, 8], [20, 6, 21, 2]]
# 20
# (12, 0, [20])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3, 20], [22, 4, 10, 9, 8], [6, 21, 2]]
# 20
# (5, 14, [1])
# [[15, 16, 18], [24, 19, 23, 1], [13, 17, 7, 3, 20], [22, 4, 10, 9, 8], [6, 21, 2]]
# 1
# (11, 0, [10])
# [[15, 16, 18], [24, 19, 23], [13, 17, 7, 3, 20, 1], [22, 4, 10, 9, 8], [6, 21, 2]]
# 10
# (14, 0, [7])
# [[15, 16, 18, 10], [24, 19, 23], [13, 17, 7, 3, 20, 1], [22, 4, 9, 8], [6, 21, 2]]
# 7
# (5, 0, [1])
# [[15, 16, 18, 10, 7], [24, 19, 23], [13, 17, 3, 20, 1], [22, 4, 9, 8], [6, 21, 2]]
# 1
# (11, 14, [10])
# [[15, 16, 18, 10, 7], [24, 19, 23], [13, 17, 3, 20, 1], [22, 4, 9, 8], [6, 21, 2]]
# 10
# At time step 4865 the number of switch migrated are : 7
# The migrated switches are [20, 20, 1, 10, 7, 1, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4866
# {0: {15: 3048.614295, 16: 3362.91724, 18: 51912.5055375, 10: 58128.882, 7: 238798.46213333332}, 5: {24: 83060.60926, 19: 138435.13953333333, 23: 103827.86415}, 14: {13: 2726.504308, 17: 8145.36142, 3: 185158.06522, 20: 103826.49115, 1: 192079.40854}, 11: {22: 83061.41346, 4: 111429.68886, 9: 221377.6166, 8: 158982.27136666668}, 12: {6: 138435.66666666666, 21: 138435.44226666665, 2: 108882.63882}}
# {(14, 5), (11, 5), (0, 12), (11, 0), (12, 5), (14, 12), (0, 5), (14, 0), (11, 12)}
# (14, 5, [1])
# [[15, 16, 18, 10, 7], [24, 19, 23], [13, 17, 3, 20, 1], [22, 4, 9, 8], [6, 21, 2]]
# 1
# (11, 5, [9])
# [[15, 16, 18, 10, 7], [24, 19, 23, 1], [13, 17, 3, 20], [22, 4, 9, 8], [6, 21, 2]]
# 9
# (0, 12, [7])
# [[15, 16, 18, 10, 7], [24, 19, 23, 1, 9], [13, 17, 3, 20], [22, 4, 8], [6, 21, 2]]
# 7
# (11, 0, [9])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9], [13, 17, 3, 20], [22, 4, 8], [6, 21, 2, 7]]
# 9
# (12, 5, [6])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9], [13, 17, 3, 20], [22, 4, 8], [6, 21, 2, 7]]
# 6
# (14, 12, [1])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20], [22, 4, 8], [21, 2, 7]]
# 1
# (0, 5, [7])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20], [22, 4, 8], [21, 2, 7]]
# 7
# (14, 0, [1])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20], [22, 4, 8], [21, 2, 7]]
# 1
# (11, 12, [9])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20], [22, 4, 8], [21, 2, 7]]
# 9
# At time step 4866 the number of switch migrated are : 9
# The migrated switches are [1, 9, 7, 9, 6, 1, 7, 1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4867
# {0: {15: 1614.437701, 16: 585.6970936666665, 18: 51913.42795, 10: 118041.24288}, 5: {24: 83061.93106, 19: 138435.34446666666, 23: 103826.66415, 1: 374779.2418, 9: 392092.8019, 6: 415307.0}, 14: {13: 248.3219659, 17: 3057.7222739999997, 3: 104867.51836000002, 20: 103827.01675000001}, 11: {22: 83062.76512, 4: 120359.93612, 8: 244212.65079999997}, 12: {21: 138435.47986666666, 2: 60087.32204, 7: 116488.1328}}
# {(12, 14), (12, 0), (0, 14), (5, 12), (11, 0), (5, 14), (5, 0), (11, 14), (11, 12)}
# (12, 14, [21])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20], [22, 4, 8], [21, 2, 7]]
# 21
# (12, 0, [21])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20, 21], [22, 4, 8], [2, 7]]
# 21
# (0, 14, [10])
# [[15, 16, 18, 10], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20, 21], [22, 4, 8], [2, 7]]
# 10
# (5, 12, [6])
# [[15, 16, 18], [24, 19, 23, 1, 9, 6], [13, 17, 3, 20, 21, 10], [22, 4, 8], [2, 7]]
# 6
# (11, 0, [8])
# [[15, 16, 18], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4, 8], [2, 7, 6]]
# 8
# (5, 14, [6])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4], [2, 7, 6]]
# 6
# (5, 0, [6])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4], [2, 7, 6]]
# 6
# (11, 14, [8])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4], [2, 7, 6]]
# 8
# (11, 12, [8])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4], [2, 7, 6]]
# 8
# At time step 4867 the number of switch migrated are : 9
# The migrated switches are [21, 21, 10, 6, 8, 6, 6, 8, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4868
# {0: {15: 3881.0569765, 16: 339.83356699999996, 18: 51913.9509375, 8: 70937.70296}, 5: {24: 83062.67922, 19: 138436.7978, 23: 103825.6019, 1: 354751.29865, 9: 466941.4963}, 14: {13: 1636.6641505, 17: 4860.353713, 3: 25862.79692, 20: 103826.39175000001, 21: 103826.659175, 10: 842137.5201}, 11: {22: 83061.3433, 4: 75403.04972}, 12: {2: 112217.95459999998, 7: 97080.146725, 6: 138435.66666666666}}
# {(14, 11), (5, 11), (12, 0), (5, 12), (11, 0), (14, 12), (14, 0), (5, 0), (12, 11)}
# (14, 11, [10])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21, 10], [22, 4], [2, 7, 6]]
# 10
# (5, 11, [9])
# [[15, 16, 18, 8], [24, 19, 23, 1, 9], [13, 17, 3, 20, 21], [22, 4, 10], [2, 7, 6]]
# 9
# (12, 0, [6])
# [[15, 16, 18, 8], [24, 19, 23, 1], [13, 17, 3, 20, 21], [22, 4, 10, 9], [2, 7, 6]]
# 6
# (5, 12, [9])
# [[15, 16, 18, 8, 6], [24, 19, 23, 1], [13, 17, 3, 20, 21], [22, 4, 10, 9], [2, 7]]
# 9
# (11, 0, [22])
# [[15, 16, 18, 8, 6], [24, 19, 23, 1], [13, 17, 3, 20, 21], [22, 4, 10, 9], [2, 7]]
# 22
# (14, 12, [10])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21], [4, 10, 9], [2, 7]]
# 10
# (14, 0, [10])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21], [4, 10, 9], [2, 7]]
# 10
# (5, 0, [9])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21], [4, 10, 9], [2, 7]]
# 9
# (12, 11, [6])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21], [4, 10, 9], [2, 7]]
# 6
# At time step 4868 the number of switch migrated are : 9
# The migrated switches are [10, 9, 6, 9, 22, 10, 10, 9, 6]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4869
# {0: {15: 3170.9122885, 16: 1848.2551326666664, 18: 51913.37485, 8: 111349.78656, 6: 207653.5, 22: 103827.059325}, 5: {24: 83061.85996, 19: 138436.15966666667, 23: 103827.0667, 1: 547398.264}, 14: {13: 1506.9319970000001, 17: 7159.58125, 3: 96809.20086, 20: 103827.139525, 21: 103825.39415}, 11: {4: 105637.87718, 10: 475589.2012, 9: 299786.28145}, 12: {2: 164365.41577999998, 7: 167755.144175}}
# {(12, 14), (5, 11), (0, 14), (5, 12), (0, 12), (5, 14), (0, 11), (11, 14), (11, 12)}
# (12, 14, [7])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21], [4, 10, 9], [2, 7]]
# 7
# (5, 11, [1])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23, 1], [13, 17, 3, 20, 21, 7], [4, 10, 9], [2]]
# 1
# (0, 14, [6])
# [[15, 16, 18, 8, 6, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7], [4, 10, 9, 1], [2]]
# 6
# (5, 12, [1])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 10, 9, 1], [2]]
# 1
# (0, 12, [6])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 10, 9, 1], [2]]
# 6
# (5, 14, [1])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 10, 9, 1], [2]]
# 1
# (0, 11, [6])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 10, 9, 1], [2]]
# 6
# (11, 14, [10])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 10, 9, 1], [2]]
# 10
# (11, 12, [10])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6, 10], [4, 9, 1], [2]]
# 10
# At time step 4869 the number of switch migrated are : 9
# The migrated switches are [7, 1, 6, 1, 6, 1, 6, 10, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4870
# {0: {15: 2012.9226004999998, 16: 48.75255239999999, 18: 51912.5927625, 8: 133111.6606, 22: 103826.3497}, 5: {24: 83061.76310000001, 19: 138437.53286666668, 23: 103825.69125}, 14: {13: 598.899777, 17: 5526.211773, 3: 287141.3734, 20: 103824.88435, 21: 103828.9811, 7: 92068.35644, 6: 103826.75, 10: 566259.2748}, 11: {4: 61250.28508, 9: 186359.353, 1: 168817.11936}, 12: {2: 111161.80936}}
# {(14, 11), (14, 5), (11, 5), (5, 12), (0, 12), (11, 0), (14, 12), (0, 5), (14, 0), (11, 12)}
# (14, 11, [10])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6, 10], [4, 9, 1], [2]]
# 10
# (14, 5, [10])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 9, 1, 10], [2]]
# 10
# (11, 5, [9])
# [[15, 16, 18, 8, 22], [24, 19, 23], [13, 17, 3, 20, 21, 7, 6], [4, 9, 1, 10], [2]]
# 9
# (5, 12, [19])
# [[15, 16, 18, 8, 22], [24, 19, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2]]
# 19
# (0, 12, [8])
# [[15, 16, 18, 8, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19]]
# 8
# (11, 0, [9])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 9
# (14, 12, [10])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 10
# (0, 5, [8])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 8
# (14, 0, [10])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 10
# (11, 12, [9])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 9
# At time step 4870 the number of switch migrated are : 10
# The migrated switches are [10, 10, 9, 19, 8, 9, 10, 8, 10, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4871
# {0: {15: 2494.1620405000003, 16: 405.69637200000005, 18: 51912.6974625, 22: 103827.518625}, 5: {24: 83060.77593999999, 23: 103825.961825, 9: 961215.0344}, 14: {13: 1748.0636415, 17: 4146.826104, 3: 118749.08952, 20: 103826.3357, 21: 103826.140125, 7: 128063.58411999998, 6: 103826.75}, 11: {4: 79395.0184, 1: 193137.8935, 10: 373921.2107}, 12: {2: 122915.31206, 19: 207653.27855, 8: 295265.94795}}
# {(5, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (5, 12, [9])
# [[15, 16, 18, 22], [24, 23, 9], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8]]
# 9
# (11, 0, [10])
# [[15, 16, 18, 22], [24, 23], [13, 17, 3, 20, 21, 7, 6], [4, 1, 10], [2, 19, 8, 9]]
# 10
# (14, 12, [7])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 7, 6], [4, 1], [2, 19, 8, 9]]
# 7
# (14, 0, [7])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 6], [4, 1], [2, 19, 8, 9, 7]]
# 7
# (5, 0, [9])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 6], [4, 1], [2, 19, 8, 9, 7]]
# 9
# (11, 12, [10])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 6], [4, 1], [2, 19, 8, 9, 7]]
# 10
# At time step 4871 the number of switch migrated are : 6
# The migrated switches are [9, 10, 7, 7, 9, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4872
# {0: {15: 3026.474413, 16: 1031.088599, 18: 51913.3717, 22: 103825.97, 10: 84944.80916}, 5: {24: 83061.97358, 23: 103828.969275}, 14: {13: 2494.797952, 17: 6450.878958, 3: 41961.17598, 20: 103827.46135, 21: 103825.368125, 6: 103826.75}, 11: {4: 140594.03466, 1: 165722.02701999998}, 12: {2: 113863.96262, 19: 207651.1669, 8: 297226.81165, 9: 731782.1102, 7: 141515.672675}}
# {(12, 14), (14, 5), (12, 0), (11, 5), (11, 0), (12, 5), (0, 5), (14, 0), (11, 14), (12, 11)}
# (12, 14, [9])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 6], [4, 1], [2, 19, 8, 9, 7]]
# 9
# (14, 5, [20])
# [[15, 16, 18, 22, 10], [24, 23], [13, 17, 3, 20, 21, 6, 9], [4, 1], [2, 19, 8, 7]]
# 20
# (12, 0, [9])
# [[15, 16, 18, 22, 10], [24, 23, 20], [13, 17, 3, 21, 6, 9], [4, 1], [2, 19, 8, 7]]
# 9
# (11, 5, [1])
# [[15, 16, 18, 22, 10], [24, 23, 20], [13, 17, 3, 21, 6, 9], [4, 1], [2, 19, 8, 7]]
# 1
# (11, 0, [1])
# [[15, 16, 18, 22, 10], [24, 23, 20, 1], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 1
# (12, 5, [9])
# [[15, 16, 18, 22, 10], [24, 23, 20, 1], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 9
# (0, 5, [22])
# [[15, 16, 18, 22, 10], [24, 23, 20, 1], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 22
# (14, 0, [20])
# [[15, 16, 18, 10], [24, 23, 20, 1, 22], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 20
# (11, 14, [1])
# [[15, 16, 18, 10], [24, 23, 20, 1, 22], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 1
# (12, 11, [9])
# [[15, 16, 18, 10], [24, 23, 20, 1, 22], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 9
# At time step 4872 the number of switch migrated are : 10
# The migrated switches are [9, 20, 9, 1, 1, 9, 22, 20, 1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4873
# {0: {15: 3904.240387, 16: 30.238124199999998, 18: 51913.02165, 10: 65509.55112}, 5: {24: 83061.21944, 23: 103826.2857, 20: 103825.635725, 1: 548874.559, 22: 83062.47188}, 14: {13: 2826.0276485, 17: 5961.306165, 3: 124839.97439999999, 21: 103828.11005, 6: 103826.75, 9: 327077.89005}, 11: {4: 102489.41768}, 12: {2: 109214.36282, 19: 207651.06050000002, 8: 279790.12855, 7: 147154.67925000002}}
# {(14, 11), (5, 11), (12, 0), (0, 11), (14, 0), (5, 0), (12, 11)}
# (14, 11, [9])
# [[15, 16, 18, 10], [24, 23, 20, 1, 22], [13, 17, 3, 21, 6, 9], [4], [2, 19, 8, 7]]
# 9
# (5, 11, [1])
# [[15, 16, 18, 10], [24, 23, 20, 1, 22], [13, 17, 3, 21, 6], [4, 9], [2, 19, 8, 7]]
# 1
# (12, 0, [8])
# [[15, 16, 18, 10], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1], [2, 19, 8, 7]]
# 8
# (0, 11, [10])
# [[15, 16, 18, 10, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1], [2, 19, 7]]
# 10
# (14, 0, [9])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1, 10], [2, 19, 7]]
# 9
# (5, 0, [1])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1, 10], [2, 19, 7]]
# 1
# (12, 11, [8])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1, 10], [2, 19, 7]]
# 8
# At time step 4873 the number of switch migrated are : 7
# The migrated switches are [9, 1, 8, 10, 9, 1, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4874
# {0: {15: 3965.9361395000005, 16: 1019.0373883333333, 18: 51912.474675, 8: 89941.0934}, 5: {24: 83061.35096, 23: 103826.28925, 20: 103827.522375, 22: 83061.96764}, 14: {13: 1027.309964, 17: 7138.316067, 3: 38092.920640000004, 21: 103823.894075, 6: 103826.75}, 11: {4: 92355.56588, 9: 299323.5135, 1: 89920.97646, 10: 499806.37299999996}, 12: {2: 135753.0233, 19: 207651.9672, 7: 92911.78055}}
# {(12, 14), (12, 0), (5, 14), (11, 0), (14, 0), (5, 0), (11, 14)}
# (12, 14, [19])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6], [4, 9, 1, 10], [2, 19, 7]]
# 19
# (12, 0, [19])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6, 19], [4, 9, 1, 10], [2, 7]]
# 19
# (5, 14, [20])
# [[15, 16, 18, 8], [24, 23, 20, 22], [13, 17, 3, 21, 6, 19], [4, 9, 1, 10], [2, 7]]
# 20
# (11, 0, [10])
# [[15, 16, 18, 8], [24, 23, 22], [13, 17, 3, 21, 6, 19, 20], [4, 9, 1, 10], [2, 7]]
# 10
# (14, 0, [6])
# [[15, 16, 18, 8, 10], [24, 23, 22], [13, 17, 3, 21, 6, 19, 20], [4, 9, 1], [2, 7]]
# 6
# (5, 0, [20])
# [[15, 16, 18, 8, 10, 6], [24, 23, 22], [13, 17, 3, 21, 19, 20], [4, 9, 1], [2, 7]]
# 20
# (11, 14, [10])
# [[15, 16, 18, 8, 10, 6], [24, 23, 22], [13, 17, 3, 21, 19, 20], [4, 9, 1], [2, 7]]
# 10
# At time step 4874 the number of switch migrated are : 7
# The migrated switches are [19, 19, 20, 10, 6, 20, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4875
# {0: {15: 2617.121604, 16: 1145.2333436666668, 18: 51912.5926625, 8: 57888.744099999996, 10: 62763.679099999994, 6: 207653.5}, 5: {24: 83061.34248, 23: 103825.902775, 22: 83061.72320000001}, 14: {13: 500.79838600000005, 17: 4559.231138, 3: 237388.69580000002, 21: 103825.499775, 19: 138436.71933333334, 20: 103828.64224999999}, 11: {4: 109845.95914, 9: 206151.6097, 1: 231040.53340000001}, 12: {2: 108055.25212, 7: 135001.662975}}
# {(14, 5), (11, 5), (5, 12), (0, 12), (11, 0), (14, 12), (0, 5), (14, 0), (11, 12)}
# (14, 5, [3])
# [[15, 16, 18, 8, 10, 6], [24, 23, 22], [13, 17, 3, 21, 19, 20], [4, 9, 1], [2, 7]]
# 3
# (11, 5, [1])
# [[15, 16, 18, 8, 10, 6], [24, 23, 22, 3], [13, 17, 21, 19, 20], [4, 9, 1], [2, 7]]
# 1
# (5, 12, [23])
# [[15, 16, 18, 8, 10, 6], [24, 23, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7]]
# 23
# (0, 12, [6])
# [[15, 16, 18, 8, 10, 6], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23]]
# 6
# (11, 0, [1])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 1
# (14, 12, [3])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 3
# (0, 5, [6])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 6
# (14, 0, [3])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 3
# (11, 12, [1])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 1
# At time step 4875 the number of switch migrated are : 9
# The migrated switches are [3, 1, 23, 6, 1, 3, 6, 3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4876
# {0: {15: 3538.5618715000005, 16: 2301.422999, 18: 51913.1611625, 8: 114166.82578, 10: 111300.97416000001}, 5: {24: 83061.98814, 22: 83061.45142, 3: 165295.34985, 1: 388971.74025}, 14: {13: 2496.168627, 17: 6772.384421, 21: 103826.5027, 19: 138435.1131, 20: 103825.602175}, 11: {4: 89153.50262, 9: 252352.6485}, 12: {2: 67065.22158, 7: 110846.3376, 23: 138435.53893333333, 6: 138435.66666666666}}
# {(14, 11), (12, 14), (5, 11), (0, 14), (5, 14), (0, 11), (12, 11)}
# (14, 11, [19])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 19, 20], [4, 9], [2, 7, 23, 6]]
# 19
# (12, 14, [6])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 20], [4, 9, 19], [2, 7, 23, 6]]
# 6
# (5, 11, [1])
# [[15, 16, 18, 8, 10], [24, 22, 3, 1], [13, 17, 21, 20, 6], [4, 9, 19], [2, 7, 23]]
# 1
# (0, 14, [8])
# [[15, 16, 18, 8, 10], [24, 22, 3], [13, 17, 21, 20, 6], [4, 9, 19, 1], [2, 7, 23]]
# 8
# (5, 14, [1])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8], [4, 9, 19, 1], [2, 7, 23]]
# 1
# (0, 11, [8])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8], [4, 9, 19, 1], [2, 7, 23]]
# 8
# (12, 11, [6])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8], [4, 9, 19, 1], [2, 7, 23]]
# 6
# At time step 4876 the number of switch migrated are : 7
# The migrated switches are [19, 6, 1, 8, 1, 8, 6]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4877
# {0: {15: 3110.1160955, 16: 1877.4208786666668, 18: 51913.982475, 10: 76515.33114}, 5: {24: 83059.9786, 22: 83061.87058, 3: 500790.94149999996}, 14: {13: 1400.0067175000001, 17: 5253.483485, 21: 103827.609025, 20: 103825.7493, 6: 103826.75, 8: 143562.131}, 11: {4: 106284.77479999998, 9: 343345.99955, 19: 138436.61976666667, 1: 168085.10476}, 12: {2: 139667.02914, 7: 175319.52195, 23: 138436.27413333333}}
# {(12, 14), (12, 0), (5, 14), (11, 0), (5, 0), (11, 14)}
# (12, 14, [7])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8], [4, 9, 19, 1], [2, 7, 23]]
# 7
# (12, 0, [7])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8, 7], [4, 9, 19, 1], [2, 23]]
# 7
# (5, 14, [3])
# [[15, 16, 18, 10], [24, 22, 3], [13, 17, 21, 20, 6, 8, 7], [4, 9, 19, 1], [2, 23]]
# 3
# (11, 0, [9])
# [[15, 16, 18, 10], [24, 22], [13, 17, 21, 20, 6, 8, 7, 3], [4, 9, 19, 1], [2, 23]]
# 9
# (5, 0, [3])
# [[15, 16, 18, 10, 9], [24, 22], [13, 17, 21, 20, 6, 8, 7, 3], [4, 19, 1], [2, 23]]
# 3
# (11, 14, [9])
# [[15, 16, 18, 10, 9], [24, 22], [13, 17, 21, 20, 6, 8, 7, 3], [4, 19, 1], [2, 23]]
# 9
# At time step 4877 the number of switch migrated are : 6
# The migrated switches are [7, 7, 3, 9, 3, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4878
# {0: {15: 2537.0863455, 16: 5496.371743333333, 18: 51912.7186875, 10: 100030.85342, 9: 142122.83800000002}, 5: {24: 83059.97488, 22: 83061.64404}, 14: {13: 1230.7972405, 17: 6476.356003, 21: 103828.8306, 20: 103828.62975, 6: 103826.75, 8: 125493.2463, 7: 141710.1533, 3: 118287.39406}, 11: {4: 80901.44644, 19: 138436.05049999998, 1: 180669.19118}, 12: {2: 117747.57624, 23: 138436.08293333332}}
# {(14, 5), (11, 5), (0, 12), (11, 0), (12, 5), (14, 12), (0, 5), (14, 0), (11, 12)}
# (14, 5, [7])
# [[15, 16, 18, 10, 9], [24, 22], [13, 17, 21, 20, 6, 8, 7, 3], [4, 19, 1], [2, 23]]
# 7
# (11, 5, [1])
# [[15, 16, 18, 10, 9], [24, 22, 7], [13, 17, 21, 20, 6, 8, 3], [4, 19, 1], [2, 23]]
# 1
# (0, 12, [9])
# [[15, 16, 18, 10, 9], [24, 22, 7, 1], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 23]]
# 9
# (11, 0, [1])
# [[15, 16, 18, 10], [24, 22, 7, 1], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 23, 9]]
# 1
# (12, 5, [23])
# [[15, 16, 18, 10], [24, 22, 7, 1], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 23, 9]]
# 23
# (14, 12, [7])
# [[15, 16, 18, 10], [24, 22, 7, 1, 23], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 9]]
# 7
# (0, 5, [9])
# [[15, 16, 18, 10], [24, 22, 7, 1, 23], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 9]]
# 9
# (14, 0, [7])
# [[15, 16, 18, 10], [24, 22, 7, 1, 23], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 9]]
# 7
# (11, 12, [1])
# [[15, 16, 18, 10], [24, 22, 7, 1, 23], [13, 17, 21, 20, 6, 8, 3], [4, 19], [2, 9]]
# 1
# At time step 4878 the number of switch migrated are : 9
# The migrated switches are [7, 1, 9, 1, 23, 7, 9, 7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4879
# ...
# {(12, 0), (5, 12), (5, 14), (11, 0), (14, 12), (14, 0), (11, 14), (5, 0), (11, 12)}
# (12, 0, [7])
# [[15, 16, 18, 19, 10], [24, 20, 1], [13, 17, 6, 8, 4], [22, 2, 23, 9], [21, 3, 7]]
# 7
# (5, 12, [1])
# [[15, 16, 18, 19, 10, 7], [24, 20, 1], [13, 17, 6, 8, 4], [22, 2, 23, 9], [21, 3]]
# 1
# (5, 14, [1])
# [[15, 16, 18, 19, 10, 7], [24, 20], [13, 17, 6, 8, 4], [22, 2, 23, 9], [21, 3, 1]]
# 1
# (11, 0, [9])
# [[15, 16, 18, 19, 10, 7], [24, 20], [13, 17, 6, 8, 4], [22, 2, 23, 9], [21, 3, 1]]
# 9
# (14, 12, [8])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 8, 4], [22, 2, 23], [21, 3, 1]]
# 8
# (14, 0, [8])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4], [22, 2, 23], [21, 3, 1, 8]]
# 8
# (11, 14, [9])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4], [22, 2, 23], [21, 3, 1, 8]]
# 9
# (5, 0, [1])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4], [22, 2, 23], [21, 3, 1, 8]]
# 1
# (11, 12, [9])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4], [22, 2, 23], [21, 3, 1, 8]]
# 9
# At time step 4990 the number of switch migrated are : 9
# The migrated switches are [7, 1, 1, 9, 8, 8, 9, 1, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4991
# {0: {15: 3671.80264, 16: 6005.100933333334, 18: 51913.656525, 19: 103827.1221, 10: 121205.1088, 7: 222480.90806666669, 9: 146592.2317}, 5: {24: 83061.9963, 20: 103826.625825}, 14: {13: 446.47402115, 17: 9373.353127, 6: 103826.75, 4: 151163.64394}, 11: {22: 83060.57876, 2: 141759.1599333333, 23: 103827.256075}, 12: {21: 138437.91153333333, 3: 254387.1825, 1: 202672.994275, 8: 316180.68575}}
# {(12, 14), (14, 5), (11, 5), (0, 14), (12, 5), (0, 11), (0, 5), (11, 14), (12, 11)}
# (12, 14, [8])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4], [22, 2, 23], [21, 3, 1, 8]]
# 8
# (14, 5, [4])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20], [13, 17, 6, 4, 8], [22, 2, 23], [21, 3, 1]]
# 4
# (11, 5, [2])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20, 4], [13, 17, 6, 8], [22, 2, 23], [21, 3, 1]]
# 2
# (0, 14, [7])
# [[15, 16, 18, 19, 10, 7, 9], [24, 20, 4, 2], [13, 17, 6, 8], [22, 23], [21, 3, 1]]
# 7
# (12, 5, [8])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 8
# (0, 11, [7])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 7
# (0, 5, [7])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 7
# (11, 14, [2])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 2
# (12, 11, [8])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 8
# At time step 4991 the number of switch migrated are : 9
# The migrated switches are [8, 4, 2, 7, 8, 7, 7, 2, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4992
# {0: {15: 1650.086094, 16: 1475.5482143333331, 18: 51914.2068, 19: 103825.912675, 10: 122112.02420000001, 9: 127246.4692}, 5: {24: 83060.81718, 20: 103826.819625, 4: 227276.94035, 2: 183176.64583333334}, 14: {13: 2416.4099530000003, 17: 9138.596851999999, 6: 103826.75, 8: 203623.67779999998, 7: 142502.24672}, 11: {22: 83062.18818, 23: 103824.5838}, 12: {21: 138435.90123333334, 3: 87530.125825, 1: 106141.868225}}
# {(14, 11), (5, 11), (5, 12), (0, 12), (14, 12), (0, 11), (12, 11)}
# (14, 11, [8])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 8, 7], [22, 23], [21, 3, 1]]
# 8
# (5, 11, [4])
# [[15, 16, 18, 19, 10, 9], [24, 20, 4, 2], [13, 17, 6, 7], [22, 23, 8], [21, 3, 1]]
# 4
# (5, 12, [4])
# [[15, 16, 18, 19, 10, 9], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4], [21, 3, 1]]
# 4
# (0, 12, [9])
# [[15, 16, 18, 19, 10, 9], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4], [21, 3, 1]]
# 9
# (14, 12, [8])
# [[15, 16, 18, 19, 10], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4], [21, 3, 1, 9]]
# 8
# (0, 11, [9])
# [[15, 16, 18, 19, 10], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4], [21, 3, 1, 9]]
# 9
# (12, 11, [21])
# [[15, 16, 18, 19, 10], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4], [21, 3, 1, 9]]
# 21
# At time step 4992 the number of switch migrated are : 7
# The migrated switches are [8, 4, 4, 9, 8, 9, 21]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4993
# {0: {15: 1969.5211255, 16: 446.1547403333334, 18: 51913.1261875, 19: 103827.9292, 10: 88186.93022000001}, 5: {24: 83062.2879, 20: 103827.58215, 2: 227747.8437666667}, 14: {13: 2480.661106, 17: 5957.804383, 6: 103826.75, 7: 167386.18396}, 11: {22: 83059.88184, 23: 103827.76115, 8: 249058.00896666668, 4: 150515.99195999998, 21: 103825.141625}, 12: {3: 205753.65895, 1: 287296.53524999996, 9: 447980.206}}
# {(12, 14), (11, 5), (12, 0), (0, 14), (12, 5), (5, 14), (11, 0), (5, 0), (11, 14)}
# (12, 14, [9])
# [[15, 16, 18, 19, 10], [24, 20, 2], [13, 17, 6, 7], [22, 23, 8, 4, 21], [3, 1, 9]]
# 9
# (11, 5, [8])
# [[15, 16, 18, 19, 10], [24, 20, 2], [13, 17, 6, 7, 9], [22, 23, 8, 4, 21], [3, 1]]
# 8
# (12, 0, [9])
# [[15, 16, 18, 19, 10], [24, 20, 2, 8], [13, 17, 6, 7, 9], [22, 23, 4, 21], [3, 1]]
# 9
# (0, 14, [19])
# [[15, 16, 18, 19, 10], [24, 20, 2, 8], [13, 17, 6, 7, 9], [22, 23, 4, 21], [3, 1]]
# 19
# (12, 5, [9])
# [[15, 16, 18, 10], [24, 20, 2, 8], [13, 17, 6, 7, 9, 19], [22, 23, 4, 21], [3, 1]]
# 9
# (5, 14, [2])
# [[15, 16, 18, 10], [24, 20, 2, 8], [13, 17, 6, 7, 9, 19], [22, 23, 4, 21], [3, 1]]
# 2
# (11, 0, [8])
# [[15, 16, 18, 10], [24, 20, 8], [13, 17, 6, 7, 9, 19, 2], [22, 23, 4, 21], [3, 1]]
# 8
# (5, 0, [2])
# [[15, 16, 18, 10], [24, 20, 8], [13, 17, 6, 7, 9, 19, 2], [22, 23, 4, 21], [3, 1]]
# 2
# (11, 14, [8])
# [[15, 16, 18, 10], [24, 20, 8], [13, 17, 6, 7, 9, 19, 2], [22, 23, 4, 21], [3, 1]]
# 8
# At time step 4993 the number of switch migrated are : 9
# The migrated switches are [9, 8, 9, 19, 9, 2, 8, 2, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4994
# {0: {15: 1674.360774, 16: 554.177274, 18: 51912.9781625, 10: 81281.41579999999}, 5: {24: 83063.43496, 20: 103826.4549, 8: 301072.1366}, 14: {13: 357.5123837, 17: 5422.625128, 6: 103826.75, 7: 152643.23314, 9: 412255.0383, 19: 138436.97773333333, 2: 99442.43355}, 11: {22: 83061.70577999999, 23: 103824.8236, 4: 162776.3618, 21: 103825.767825}, 12: {3: 67792.779825, 1: 216419.318675}}
# {(14, 5), (11, 5), (12, 0), (5, 12), (11, 0), (14, 12), (14, 0), (5, 0), (11, 12)}
# (14, 5, [9])
# [[15, 16, 18, 10], [24, 20, 8], [13, 17, 6, 7, 9, 19, 2], [22, 23, 4, 21], [3, 1]]
# 9
# (11, 5, [4])
# [[15, 16, 18, 10], [24, 20, 8, 9], [13, 17, 6, 7, 19, 2], [22, 23, 4, 21], [3, 1]]
# 4
# (12, 0, [1])
# [[15, 16, 18, 10], [24, 20, 8, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 1]]
# 1
# (5, 12, [8])
# [[15, 16, 18, 10, 1], [24, 20, 8, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3]]
# 8
# (11, 0, [4])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 4
# (14, 12, [9])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 9
# (14, 0, [9])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 9
# (5, 0, [8])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 8
# (11, 12, [4])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 4
# At time step 4994 the number of switch migrated are : 9
# The migrated switches are [9, 4, 1, 8, 4, 9, 9, 8, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4995
# {0: {15: 2812.0819385, 16: 1619.1903926666666, 18: 51913.879575, 10: 84435.55912, 1: 160203.34596666667}, 5: {24: 83061.82664, 20: 103826.7185, 9: 544737.5638, 4: 183131.76985}, 14: {13: 2463.884636, 17: 7004.683501, 6: 103826.75, 7: 143406.08729999998, 19: 138435.73666666666, 2: 114530.42073333333}, 11: {22: 83062.0865, 23: 103827.846025, 21: 103827.6887}, 12: {3: 107852.8304, 8: 289483.68225}}
# {(14, 11), (5, 11), (5, 12), (0, 12), (14, 12), (0, 11), (14, 0), (5, 0), (11, 12)}
# (14, 11, [7])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 7, 19, 2], [22, 23, 21], [3, 8]]
# 7
# (5, 11, [9])
# [[15, 16, 18, 10, 1], [24, 20, 9, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7], [3, 8]]
# 9
# (5, 12, [9])
# [[15, 16, 18, 10, 1], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8]]
# 9
# (0, 12, [1])
# [[15, 16, 18, 10, 1], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8]]
# 1
# (14, 12, [7])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8, 1]]
# 7
# (0, 11, [1])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8, 1]]
# 1
# (14, 0, [7])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8, 1]]
# 7
# (5, 0, [9])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8, 1]]
# 9
# (11, 12, [23])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 23, 21, 7, 9], [3, 8, 1]]
# 23
# At time step 4995 the number of switch migrated are : 9
# The migrated switches are [7, 9, 9, 1, 7, 1, 7, 9, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4996
# {0: {15: 4181.5739685, 16: 977.455609, 18: 51914.71095, 10: 97580.76905999999}, 5: {24: 83061.05064, 20: 103827.881925, 4: 342189.56865}, 14: {13: 961.6537085000001, 17: 3430.328531, 6: 103826.75, 19: 138434.58823333334, 2: 68918.04093333334}, 11: {22: 83061.5558, 21: 103825.8834, 7: 160225.51982, 9: 235322.89845}, 12: {3: 263701.39975000004, 8: 180089.26815, 1: 261460.14425, 23: 138437.13726666666}}
# {(12, 14), (11, 5), (12, 0), (11, 0), (12, 5), (5, 14), (14, 0), (5, 0), (11, 14)}
# (12, 14, [3])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2], [22, 21, 7, 9], [3, 8, 1, 23]]
# 3
# (11, 5, [9])
# [[15, 16, 18, 10], [24, 20, 4], [13, 17, 6, 19, 2, 3], [22, 21, 7, 9], [8, 1, 23]]
# 9
# (12, 0, [3])
# [[15, 16, 18, 10], [24, 20, 4, 9], [13, 17, 6, 19, 2, 3], [22, 21, 7], [8, 1, 23]]
# 3
# (11, 0, [9])
# [[15, 16, 18, 10], [24, 20, 4, 9], [13, 17, 6, 19, 2, 3], [22, 21, 7], [8, 1, 23]]
# 9
# (12, 5, [3])
# [[15, 16, 18, 10], [24, 20, 4, 9], [13, 17, 6, 19, 2, 3], [22, 21, 7], [8, 1, 23]]
# 3
# (5, 14, [4])
# [[15, 16, 18, 10], [24, 20, 4, 9], [13, 17, 6, 19, 2, 3], [22, 21, 7], [8, 1, 23]]
# 4
# (14, 0, [19])
# [[15, 16, 18, 10], [24, 20, 9], [13, 17, 6, 19, 2, 3, 4], [22, 21, 7], [8, 1, 23]]
# 19
# (5, 0, [4])
# [[15, 16, 18, 10, 19], [24, 20, 9], [13, 17, 6, 2, 3, 4], [22, 21, 7], [8, 1, 23]]
# 4
# (11, 14, [9])
# [[15, 16, 18, 10, 19], [24, 20, 9], [13, 17, 6, 2, 3, 4], [22, 21, 7], [8, 1, 23]]
# 9
# At time step 4996 the number of switch migrated are : 9
# The migrated switches are [3, 9, 3, 9, 3, 4, 19, 4, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4997
# {0: {15: 3352.959479, 16: 874.9178416666667, 18: 51912.6192125, 10: 97232.73586, 19: 103827.7734}, 5: {24: 83060.52472, 20: 103826.06575, 9: 716052.0439}, 14: {13: 1855.012657, 17: 6940.2231409999995, 6: 103826.75, 2: 125581.90568333333, 3: 117722.55436, 4: 78914.64412}, 11: {22: 83062.34212, 21: 103826.3316, 7: 141260.9456}, 12: {8: 353424.26355, 1: 211737.9186, 23: 138433.75513333332}}
# {(14, 11), (14, 5), (5, 11), (12, 0), (11, 0), (12, 5), (14, 0), (5, 0), (12, 11)}
# (14, 11, [2])
# [[15, 16, 18, 10, 19], [24, 20, 9], [13, 17, 6, 2, 3, 4], [22, 21, 7], [8, 1, 23]]
# 2
# (14, 5, [2])
# [[15, 16, 18, 10, 19], [24, 20, 9], [13, 17, 6, 3, 4], [22, 21, 7, 2], [8, 1, 23]]
# 2
# (5, 11, [9])
# [[15, 16, 18, 10, 19], [24, 20, 9], [13, 17, 6, 3, 4], [22, 21, 7, 2], [8, 1, 23]]
# 9
# (12, 0, [8])
# [[15, 16, 18, 10, 19], [24, 20], [13, 17, 6, 3, 4], [22, 21, 7, 2, 9], [8, 1, 23]]
# 8
# (11, 0, [7])
# [[15, 16, 18, 10, 19, 8], [24, 20], [13, 17, 6, 3, 4], [22, 21, 7, 2, 9], [1, 23]]
# 7
# (12, 5, [8])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20], [13, 17, 6, 3, 4], [22, 21, 2, 9], [1, 23]]
# 8
# (14, 0, [2])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20], [13, 17, 6, 3, 4], [22, 21, 2, 9], [1, 23]]
# 2
# (5, 0, [9])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20], [13, 17, 6, 3, 4], [22, 21, 2, 9], [1, 23]]
# 9
# (12, 11, [8])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20], [13, 17, 6, 3, 4], [22, 21, 2, 9], [1, 23]]
# 8
# At time step 4997 the number of switch migrated are : 9
# The migrated switches are [2, 2, 9, 8, 7, 8, 2, 9, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# {0: {15: 4547.181318999999, 16: 2500.574076333334, 18: 51913.8308875, 10: 118407.51756, 19: 103826.702575, 8: 69910.12336, 7: 205591.8796}, 5: {24: 83062.18502, 20: 103825.7914}, 14: {13: 1621.2688865, 17: 4952.698632, 6: 103826.75, 3: 59531.44654, 4: 102246.56674000001}, 11: {22: 83061.77724, 21: 103826.818275, 2: 44926.23655, 9: 187890.06075}, 12: {1: 103005.59615, 23: 138433.9079}}
# {(14, 5), (11, 5), (0, 14), (5, 12), (0, 12), (14, 12), (0, 5), (11, 14), (11, 12)}
# (14, 5, [6])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20], [13, 17, 6, 3, 4], [22, 21, 2, 9], [1, 23]]
# 6
# (11, 5, [9])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20, 6], [13, 17, 3, 4], [22, 21, 2, 9], [1, 23]]
# 9
# (0, 14, [7])
# [[15, 16, 18, 10, 19, 8, 7], [24, 20, 6, 9], [13, 17, 3, 4], [22, 21, 2], [1, 23]]
# 7
# (5, 12, [20])
# [[15, 16, 18, 10, 19, 8], [24, 20, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23]]
# 20
# (0, 12, [7])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 7
# (14, 12, [6])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 6
# (0, 5, [7])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 7
# (11, 14, [9])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 9
# (11, 12, [9])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 9
# At time step 4998 the number of switch migrated are : 9
# The migrated switches are [6, 9, 7, 20, 7, 6, 7, 9, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# {0: {15: 3019.744317, 16: 1099.7163123333332, 18: 51913.3174125, 10: 78830.85111999999, 19: 103826.607375, 8: 113685.05146000002}, 5: {24: 83061.8808, 6: 415307.0, 9: 590599.7209}, 14: {13: 864.8189894999999, 17: 5863.6923799999995, 3: 121515.41522, 4: 119588.53624, 7: 79417.14786}, 11: {22: 83061.8217, 21: 103826.274475, 2: 38892.052383333335}, 12: {1: 104977.729, 23: 138435.30686666668, 20: 138434.68086666666}}
# {(14, 11), (14, 5), (5, 11), (5, 12), (0, 12), (14, 12), (0, 11), (0, 5), (12, 11)}
# (14, 11, [3])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 3, 4, 7], [22, 21, 2], [1, 23, 20]]
# 3
# (14, 5, [3])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 4, 7], [22, 21, 2, 3], [1, 23, 20]]
# 3
# (5, 11, [9])
# [[15, 16, 18, 10, 19, 8], [24, 6, 9], [13, 17, 4, 7], [22, 21, 2, 3], [1, 23, 20]]
# 9
# (5, 12, [9])
# [[15, 16, 18, 10, 19, 8], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20]]
# 9
# (0, 12, [8])
# [[15, 16, 18, 10, 19, 8], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20]]
# 8
# (14, 12, [3])
# [[15, 16, 18, 10, 19], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20, 8]]
# 3
# (0, 11, [8])
# [[15, 16, 18, 10, 19], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20, 8]]
# 8
# (0, 5, [8])
# [[15, 16, 18, 10, 19], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20, 8]]
# 8
# (12, 11, [23])
# [[15, 16, 18, 10, 19], [24, 6], [13, 17, 4, 7], [22, 21, 2, 3, 9], [1, 23, 20, 8]]
# 23
# At time step 4999 the number of switch migrated are : 9
# The migrated switches are [3, 3, 9, 9, 8, 3, 8, 8, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **Random Approach Implementation**

# %%
'''
To compare with the Q-learning based implementation, we have to make a random approach of selecting and assigning 
switches and hope to balance the load between the controller.
'''

def select_random_switch(index_of_overloaded_controller, current_controller):
    '''
    Select a switch randomly from the controller. 
    Ensure that the controller itself is not selected
    '''
    if(len(controller_sets[index_of_overloaded_controller]) == 1):
        return -1
    x = random.choice(controller_sets[index_of_overloaded_controller])
    # To avoid controller to be selected itself
    while(x == current_controller):
        x = random.choice(controller_sets[index_of_overloaded_controller])
    return x

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s

def random_action(available_act, controller):
    '''
    Radomly choose the next action
    Ensure that the controller itself is not choosen
    '''
    next_action = int(np.random.choice(available_act, 1))
    while(next_action == controller):
        next_action = int(np.random.choice(available_act, 1))
    return next_action


# For making graph
time_steps_list_rn = []
load_balance_rate_list_rn = []
discrete_coeff_list_rn = []
number_of_switches_list_rn = []

load_rate_list_rn = []
migration_cost_random = 0
migration_array_random = []
normalize = 10**9

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    # print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_random_switch(index_of_overloaded_controller, current_state)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = [item for item in range(0, k)]

            target_controller_index = random_action(underloaded_domain, index_of_overloaded_controller)
            target_state = controllers[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Migrate the selected switch
            controller_sets[index_of_overloaded_controller].remove(current_switch)
            controller_sets[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            print()

    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_rn.append(discrete_coeff)
    time_steps_list_rn.append(i)
    load_balance_rate_list_rn.append(l_rate)
    number_of_switches_list_rn.append(len(switch_array))

    load_rate_list_rn.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Switches in the controller 11 : [21, 8, 1]
# Switch selected is : 1
# The target controller set for 12 is : [19, 3, 20, 2]
# The mean load ratio is : 0.09618412887968689
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08055014132822703
# 5 :	 0.06888045586183189
# 14 :	 0.10996984867733449
# 11 :	 0.05591301924061069
# 12 :	 0.16560717929043034
# Switches in the controller 14 : [23, 18, 22, 9]
# Switch selected is : 23
# The target controller set for 11 is : [21, 8]
# The mean load ratio is : 0.09618412887968689
#
# At time step 4929 the number of switch migrated are : 6
# The migrated switches are [16, 1, 10, 2, 1, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4930
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08844406794281297
# 5 :	 0.0641087102630724
# 14 :	 0.09185908359967838
# 11 :	 0.08040050231082646
# 12 :	 0.15631264078017326
# Switches in the controller 12 : [19, 3, 20, 2, 1]
# Switch selected is : 20
# The target controller set for 5 is : [17, 6, 13, 15, 4]
# The mean load ratio is : 0.09622500097931269
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08844406794281297
# 5 :	 0.08866572709651763
# 14 :	 0.09185908359967838
# 11 :	 0.08040050231082646
# 12 :	 0.13175562394672805
# Switches in the controller 12 : [19, 3, 2, 1]
# Switch selected is : 3
# The target controller set for 14 is : [18, 22, 9]
# The mean load ratio is : 0.09622500097931269
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08844406794281297
# 5 :	 0.08866572709651763
# 14 :	 0.10542890727578885
# 11 :	 0.08040050231082646
# 12 :	 0.11818580027061758
# Switches in the controller 12 : [19, 2, 1]
# Switch selected is : 19
# The target controller set for 5 is : [17, 6, 13, 15, 4, 20]
# The mean load ratio is : 0.09622500097931269
#
# At time step 4930 the number of switch migrated are : 3
# The migrated switches are [20, 3, 19]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4931
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.11194916216922644
# 5 :	 0.11553626786935353
# 14 :	 0.08734871295731067
# 11 :	 0.06729891533426617
# 12 :	 0.08042427716860229
# Switches in the controller 5 : [17, 6, 13, 15, 4, 20, 19]
# Switch selected is : 4
# The target controller set for 0 is : [24, 7, 16, 10]
# The mean load ratio is : 0.09251146709975182
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.15285895254932097
# 5 :	 0.07462647748925902
# 14 :	 0.08734871295731067
# 11 :	 0.06729891533426617
# 12 :	 0.08042427716860229
# Switches in the controller 0 : [24, 7, 16, 10, 4]
# Switch selected is : 16
# The target controller set for 11 is : [21, 8, 23]
# The mean load ratio is : 0.09251146709975182
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1522415311858331
# 5 :	 0.07462647748925902
# 14 :	 0.08734871295731067
# 11 :	 0.06791633669775404
# 12 :	 0.08042427716860229
# Switches in the controller 0 : [24, 7, 10, 4]
# Switch selected is : 10
# The target controller set for 5 is : [17, 6, 13, 15, 20, 19]
# The mean load ratio is : 0.09251146709975182
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.11280736743365918
# 5 :	 0.11406064124143295
# 14 :	 0.08734871295731067
# 11 :	 0.06791633669775404
# 12 :	 0.08042427716860229
# Switches in the controller 0 : [24, 7, 4]
# Switch selected is : 24
# The target controller set for 14 is : [18, 22, 9, 3]
# The mean load ratio is : 0.09251146709975182
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08825028880940129
# 5 :	 0.11406064124143295
# 14 :	 0.11190579158156856
# 11 :	 0.06791633669775404
# 12 :	 0.08042427716860229
# Switches in the controller 14 : [18, 22, 9, 3, 24]
# Switch selected is : 18
# The target controller set for 11 is : [21, 8, 23, 16]
# The mean load ratio is : 0.09251146709975182
#
# At time step 4931 the number of switch migrated are : 5
# The migrated switches are [4, 16, 10, 24, 18]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4932
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.059513885725626894
# 5 :	 0.10965032413908526
# 14 :	 0.14632342644974683
# 11 :	 0.11223242534203108
# 12 :	 0.06372022457261994
# Switches in the controller 14 : [22, 9, 3, 24]
# Switch selected is : 22
# The target controller set for 0 is : [7, 4]
# The mean load ratio is : 0.098288057245822
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08407111616015506
# 5 :	 0.10965032413908526
# 14 :	 0.12176619601521865
# 11 :	 0.11223242534203108
# 12 :	 0.06372022457261994
# Switches in the controller 14 : [9, 3, 24]
# Switch selected is : 24
# The target controller set for 0 is : [7, 4, 22]
# The mean load ratio is : 0.098288057245822
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.10862769806906106
# 5 :	 0.10965032413908526
# 14 :	 0.09720961410631265
# 11 :	 0.11223242534203108
# 12 :	 0.06372022457261994
# Switches in the controller 5 : [17, 6, 13, 15, 20, 19, 10]
# Switch selected is : 6
# The target controller set for 12 is : [2, 1]
# The mean load ratio is : 0.098288057245822
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.10862769806906106
# 5 :	 0.08509323606585908
# 14 :	 0.09720961410631265
# 11 :	 0.11223242534203108
# 12 :	 0.08827731264584612
# Switches in the controller 11 : [21, 8, 23, 16, 18]
# Switch selected is : 18
# The target controller set for 12 is : [2, 1, 6]
# The mean load ratio is : 0.098288057245822
#
# At time step 4932 the number of switch migrated are : 4
# The migrated switches are [22, 24, 6, 18]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4933
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.12116190836938004
# 5 :	 0.08204001976524782
# 14 :	 0.04095471030822403
# 11 :	 0.07845100922566572
# 12 :	 0.1361754506664391
# Switches in the controller 0 : [7, 4, 22, 24]
# Switch selected is : 24
# The target controller set for 11 is : [21, 8, 23, 16]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09660492210612634
# 5 :	 0.08204001976524782
# 14 :	 0.04095471030822403
# 11 :	 0.10300799548891942
# 12 :	 0.1361754506664391
# Switches in the controller 0 : [7, 4, 22]
# Switch selected is : 7
# The target controller set for 5 is : [17, 13, 15, 20, 19, 10]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0552716748638998
# 5 :	 0.12337326700747436
# 14 :	 0.04095471030822403
# 11 :	 0.10300799548891942
# 12 :	 0.1361754506664391
# Switches in the controller 5 : [17, 13, 15, 20, 19, 10, 7]
# Switch selected is : 19
# The target controller set for 12 is : [2, 1, 6, 18]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0552716748638998
# 5 :	 0.09881618955398977
# 14 :	 0.04095471030822403
# 11 :	 0.10300799548891942
# 12 :	 0.1607325281199237
# Switches in the controller 5 : [17, 13, 15, 20, 10, 7]
# Switch selected is : 10
# The target controller set for 11 is : [21, 8, 23, 16, 24]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.0552716748638998
# 5 :	 0.06693506495000891
# 14 :	 0.04095471030822403
# 11 :	 0.13488912009290027
# 12 :	 0.1607325281199237
# Switches in the controller 12 : [2, 1, 6, 18, 19]
# Switch selected is : 6
# The target controller set for 0 is : [4, 22]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07982876293712599
# 5 :	 0.06693506495000891
# 14 :	 0.04095471030822403
# 11 :	 0.13488912009290027
# 12 :	 0.13617544004669752
# Switches in the controller 12 : [2, 1, 18, 19]
# Switch selected is : 19
# The target controller set for 11 is : [21, 8, 23, 16, 24, 10]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07982876293712599
# 5 :	 0.06693506495000891
# 14 :	 0.04095471030822403
# 11 :	 0.15944619754638487
# 12 :	 0.11161836259321292
# Switches in the controller 12 : [2, 1, 18]
# Switch selected is : 2
# The target controller set for 5 is : [17, 13, 15, 20, 7]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07982876293712599
# 5 :	 0.09676652674942739
# 14 :	 0.04095471030822403
# 11 :	 0.15944619754638487
# 12 :	 0.08178690079379444
# Switches in the controller 11 : [21, 8, 23, 16, 24, 10, 19]
# Switch selected is : 19
# The target controller set for 0 is : [4, 22, 6]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.10438584039061058
# 5 :	 0.09676652674942739
# 14 :	 0.04095471030822403
# 11 :	 0.13488912009290027
# 12 :	 0.08178690079379444
# Switches in the controller 11 : [21, 8, 23, 16, 24, 10]
# Switch selected is : 8
# The target controller set for 5 is : [17, 13, 15, 20, 7, 2]
# The mean load ratio is : 0.09175661966699133
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.10438584039061058
# 5 :	 0.12591989869548167
# 14 :	 0.04095471030822403
# 11 :	 0.10573574814684598
# 12 :	 0.08178690079379444
# Switches in the controller 11 : [21, 23, 16, 24, 10]
# Switch selected is : 24
# The target controller set for 0 is : [4, 22, 6, 19]
# The mean load ratio is : 0.09175661966699133
#
# At time step 4933 the number of switch migrated are : 10
# The migrated switches are [24, 7, 19, 10, 6, 19, 2, 19, 8, 24]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4934
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.12380944101310953
# 5 :	 0.12129797819178612
# 14 :	 0.06007216643946375
# 11 :	 0.08233273810895864
# 12 :	 0.07936853124622638
# Switches in the controller 5 : [17, 13, 15, 20, 7, 2, 8]
# Switch selected is : 15
# The target controller set for 0 is : [4, 22, 6, 19, 24]
# The mean load ratio is : 0.09337617099990889
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.12405113441054257
# 5 :	 0.12105628479435308
# 14 :	 0.06007216643946375
# 11 :	 0.08233273810895864
# 12 :	 0.07936853124622638
# Switches in the controller 5 : [17, 13, 20, 7, 2, 8]
# Switch selected is : 8
# The target controller set for 0 is : [4, 22, 6, 19, 24, 15]
# The mean load ratio is : 0.09337617099990889
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.15237828555358865
# 5 :	 0.092729133651307
# 14 :	 0.06007216643946375
# 11 :	 0.08233273810895864
# 12 :	 0.07936853124622638
# Switches in the controller 0 : [4, 22, 6, 19, 24, 15, 8]
# Switch selected is : 22
# The target controller set for 5 is : [17, 13, 20, 7, 2]
# The mean load ratio is : 0.09337617099990889
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1278212474156173
# 5 :	 0.11728617178927836
# 14 :	 0.06007216643946375
# 11 :	 0.08233273810895864
# 12 :	 0.07936853124622638
# Switches in the controller 0 : [4, 6, 19, 24, 15, 8]
# Switch selected is : 24
# The target controller set for 5 is : [17, 13, 20, 7, 2, 22]
# The mean load ratio is : 0.09337617099990889
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10326377727412694
# 5 :	 0.1418436419307687
# 14 :	 0.06007216643946375
# 11 :	 0.08233273810895864
# 12 :	 0.07936853124622638
# Switches in the controller 0 : [4, 6, 19, 15, 8]
# Switch selected is : 4
# The target controller set for 14 is : [9, 3]
# The mean load ratio is : 0.09337617099990889
#
# At time step 4934 the number of switch migrated are : 5
# The migrated switches are [15, 8, 22, 24, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4935
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08482069977334397
# 5 :	 0.15101620542187702
# 14 :	 0.12167666895055766
# 11 :	 0.09215328343057118
# 12 :	 0.09319645396424991
# Switches in the controller 14 : [9, 3, 4]
# Switch selected is : 4
# The target controller set for 0 is : [6, 19, 15, 8]
# The mean load ratio is : 0.10857266230811995
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.12652371959983424
# 5 :	 0.15101620542187702
# 14 :	 0.07997364912406739
# 11 :	 0.09215328343057118
# 12 :	 0.09319645396424991
# Switches in the controller 5 : [17, 13, 20, 7, 2, 22, 24]
# Switch selected is : 17
# The target controller set for 11 is : [21, 23, 16, 10]
# The mean load ratio is : 0.10857266230811995
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.12652371959983424
# 5 :	 0.15066679471089467
# 14 :	 0.07997364912406739
# 11 :	 0.09250269414155353
# 12 :	 0.09319645396424991
# Switches in the controller 5 : [13, 20, 7, 2, 22, 24]
# Switch selected is : 7
# The target controller set for 12 is : [1, 18]
# The mean load ratio is : 0.10857266230811995
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.12652371959983424
# 5 :	 0.12536243207116696
# 14 :	 0.07997364912406739
# 11 :	 0.09250269414155353
# 12 :	 0.11850081660397764
# Switches in the controller 5 : [13, 20, 2, 22, 24]
# Switch selected is : 20
# The target controller set for 0 is : [6, 19, 15, 8, 4]
# The mean load ratio is : 0.10857266230811995
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.15108121552198903
# 5 :	 0.10080493614901219
# 14 :	 0.07997364912406739
# 11 :	 0.09250269414155353
# 12 :	 0.11850081660397764
# Switches in the controller 12 : [1, 18, 7]
# Switch selected is : 1
# The target controller set for 11 is : [21, 23, 16, 10, 17]
# The mean load ratio is : 0.10857266230811995
#
# At time step 4935 the number of switch migrated are : 5
# The migrated switches are [4, 17, 7, 20, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4936
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.16284858300781702
# 5 :	 0.062227134579279295
# 14 :	 0.07833002820090675
# 11 :	 0.09778551765752816
# 12 :	 0.05519144356770553
# Switches in the controller 11 : [21, 23, 16, 10, 17, 1]
# Switch selected is : 16
# The target controller set for 0 is : [6, 19, 15, 8, 4, 20]
# The mean load ratio is : 0.09127654140264736
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.16286294813433172
# 5 :	 0.062227134579279295
# 14 :	 0.07833002820090675
# 11 :	 0.09777115253101346
# 12 :	 0.05519144356770553
# Switches in the controller 11 : [21, 23, 10, 17, 1]
# Switch selected is : 1
# The target controller set for 0 is : [6, 19, 15, 8, 4, 20, 16]
# The mean load ratio is : 0.09127654140264736
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.18712319607634922
# 5 :	 0.062227134579279295
# 14 :	 0.07833002820090675
# 11 :	 0.07351090458899595
# 12 :	 0.05519144356770553
# Switches in the controller 0 : [6, 19, 15, 8, 4, 20, 16, 1]
# Switch selected is : 4
# The target controller set for 11 is : [21, 23, 10, 17]
# The mean load ratio is : 0.09127654140264736
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.14682434598341798
# 5 :	 0.062227134579279295
# 14 :	 0.07833002820090675
# 11 :	 0.1138097546819272
# 12 :	 0.05519144356770553
# Switches in the controller 0 : [6, 19, 15, 8, 20, 16, 1]
# Switch selected is : 20
# The target controller set for 14 is : [9, 3]
# The mean load ratio is : 0.09127654140264736
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.12226693180252582
# 5 :	 0.062227134579279295
# 14 :	 0.10288744238179891
# 11 :	 0.1138097546819272
# 12 :	 0.05519144356770553
# Switches in the controller 0 : [6, 19, 15, 8, 16, 1]
# Switch selected is : 6
# The target controller set for 11 is : [21, 23, 10, 17, 4]
# The mean load ratio is : 0.09127654140264736
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09770984372929964
# 5 :	 0.062227134579279295
# 14 :	 0.10288744238179891
# 11 :	 0.13836684275515337
# 12 :	 0.05519144356770553
# Switches in the controller 0 : [19, 15, 8, 16, 1]
# Switch selected is : 1
# The target controller set for 11 is : [21, 23, 10, 17, 4, 6]
# The mean load ratio is : 0.09127654140264736
#
# At time step 4936 the number of switch migrated are : 6
# The migrated switches are [16, 1, 4, 20, 6, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4937
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.06090690424157133
# 5 :	 0.07430591495310584
# 14 :	 0.0849908774091065
# 11 :	 0.20370269349840614
# 12 :	 0.04654767473272585
# Switches in the controller 11 : [21, 23, 10, 17, 4, 6, 1]
# Switch selected is : 21
# The target controller set for 0 is : [19, 15, 8, 16]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08546408355824539
# 5 :	 0.07430591495310584
# 14 :	 0.0849908774091065
# 11 :	 0.17914551418173208
# 12 :	 0.04654767473272585
# Switches in the controller 11 : [23, 10, 17, 4, 6, 1]
# Switch selected is : 6
# The target controller set for 14 is : [9, 3, 20]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08546408355824539
# 5 :	 0.07430591495310584
# 14 :	 0.10954796548233268
# 11 :	 0.1545884261085059
# 12 :	 0.04654767473272585
# Switches in the controller 11 : [23, 10, 17, 4, 1]
# Switch selected is : 4
# The target controller set for 14 is : [9, 3, 20, 6]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08546408355824539
# 5 :	 0.07430591495310584
# 14 :	 0.1541153470112058
# 11 :	 0.1100210445796328
# 12 :	 0.04654767473272585
# Switches in the controller 11 : [23, 10, 17, 1]
# Switch selected is : 1
# The target controller set for 0 is : [19, 15, 8, 16, 21]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.12821590578184067
# 5 :	 0.07430591495310584
# 14 :	 0.1541153470112058
# 11 :	 0.06726922235603751
# 12 :	 0.04654767473272585
# Switches in the controller 14 : [9, 3, 20, 6, 4]
# Switch selected is : 6
# The target controller set for 11 is : [23, 10, 17]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.12821590578184067
# 5 :	 0.07430591495310584
# 14 :	 0.12955825893797962
# 11 :	 0.09182631042926369
# 12 :	 0.04654767473272585
# Switches in the controller 14 : [9, 3, 20, 4]
# Switch selected is : 20
# The target controller set for 11 is : [23, 10, 17, 6]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.12821590578184067
# 5 :	 0.07430591495310584
# 14 :	 0.10500141463394416
# 11 :	 0.11638315473329915
# 12 :	 0.04654767473272585
# Switches in the controller 14 : [9, 3, 4]
# Switch selected is : 9
# The target controller set for 5 is : [13, 2, 22, 24]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.12821590578184067
# 5 :	 0.09900448086752468
# 14 :	 0.08030284871952532
# 11 :	 0.11638315473329915
# 12 :	 0.04654767473272585
# Switches in the controller 0 : [19, 15, 8, 16, 21, 1]
# Switch selected is : 19
# The target controller set for 12 is : [18, 7]
# The mean load ratio is : 0.09409081296698314
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10365898260434586
# 5 :	 0.09900448086752468
# 14 :	 0.08030284871952532
# 11 :	 0.11638315473329915
# 12 :	 0.07110459791022067
# Switches in the controller 0 : [15, 8, 16, 21, 1]
# Switch selected is : 8
# The target controller set for 14 is : [3, 4]
# The mean load ratio is : 0.09409081296698314
#
# At time step 4937 the number of switch migrated are : 9
# The migrated switches are [21, 6, 4, 1, 6, 20, 9, 19, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4938
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09447948166038335
# 5 :	 0.11639803072066747
# 14 :	 0.1279404675678974
# 11 :	 0.0858977624123182
# 12 :	 0.09161266422169777
# Switches in the controller 14 : [3, 4, 8]
# Switch selected is : 8
# The target controller set for 5 is : [13, 2, 22, 24, 9]
# The mean load ratio is : 0.10326568131659283
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09447948166038335
# 5 :	 0.15004469347108368
# 14 :	 0.09429380481748119
# 11 :	 0.0858977624123182
# 12 :	 0.09161266422169777
# Switches in the controller 5 : [13, 2, 22, 24, 9, 8]
# Switch selected is : 24
# The target controller set for 12 is : [18, 7, 19]
# The mean load ratio is : 0.10326568131659283
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09447948166038335
# 5 :	 0.1254875575262384
# 14 :	 0.09429380481748119
# 11 :	 0.0858977624123182
# 12 :	 0.11616980016654302
# Switches in the controller 5 : [13, 2, 22, 9, 8]
# Switch selected is : 2
# The target controller set for 14 is : [3, 4]
# The mean load ratio is : 0.10326568131659283
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09447948166038335
# 5 :	 0.10550106640014872
# 14 :	 0.11428029594357088
# 11 :	 0.0858977624123182
# 12 :	 0.11616980016654302
# Switches in the controller 5 : [13, 22, 9, 8]
# Switch selected is : 8
# The target controller set for 14 is : [3, 4, 2]
# The mean load ratio is : 0.10326568131659283
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09447948166038335
# 5 :	 0.07185440364973252
# 14 :	 0.1479269586939871
# 11 :	 0.0858977624123182
# 12 :	 0.11616980016654302
# Switches in the controller 12 : [18, 7, 19, 24]
# Switch selected is : 24
# The target controller set for 14 is : [3, 4, 2, 8]
# The mean load ratio is : 0.10326568131659283
#
# At time step 4938 the number of switch migrated are : 5
# The migrated switches are [8, 24, 2, 8, 24]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4939
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.04760832795295441
# 14 :	 0.13993080482060477
# 11 :	 0.10816412190093404
# 12 :	 0.08297797146371554
# Switches in the controller 11 : [23, 10, 17, 6, 20]
# Switch selected is : 10
# The target controller set for 5 is : [13, 22, 9]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.08179406257527297
# 14 :	 0.13993080482060477
# 11 :	 0.07397838727861547
# 12 :	 0.08297797146371554
# Switches in the controller 14 : [3, 4, 2, 8, 24]
# Switch selected is : 8
# The target controller set for 12 is : [18, 7, 19]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.08179406257527297
# 14 :	 0.09655387332172176
# 11 :	 0.07397838727861547
# 12 :	 0.12635490296259855
# Switches in the controller 14 : [3, 4, 2, 24]
# Switch selected is : 2
# The target controller set for 5 is : [13, 22, 9, 10]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.10991802741476009
# 14 :	 0.06842990848223464
# 11 :	 0.07397838727861547
# 12 :	 0.12635490296259855
# Switches in the controller 5 : [13, 22, 9, 10, 2]
# Switch selected is : 22
# The target controller set for 12 is : [18, 7, 19, 8]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.08536100283528955
# 14 :	 0.06842990848223464
# 11 :	 0.07397838727861547
# 12 :	 0.15091192754206909
# Switches in the controller 5 : [13, 9, 10, 2]
# Switch selected is : 9
# The target controller set for 14 is : [3, 4, 24]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.047559950713020556
# 5 :	 0.062492312595708935
# 14 :	 0.09129859872181526
# 11 :	 0.07397838727861547
# 12 :	 0.15091192754206909
# Switches in the controller 12 : [18, 7, 19, 8, 22]
# Switch selected is : 7
# The target controller set for 0 is : [15, 16, 21, 1]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.0814241585563925
# 5 :	 0.062492312595708935
# 14 :	 0.09129859872181526
# 11 :	 0.07397838727861547
# 12 :	 0.11704771969869715
# Switches in the controller 12 : [18, 19, 8, 22]
# Switch selected is : 19
# The target controller set for 11 is : [23, 17, 6, 20]
# The mean load ratio is : 0.08524823537024587
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.0814241585563925
# 5 :	 0.062492312595708935
# 14 :	 0.09129859872181526
# 11 :	 0.09853505907098016
# 12 :	 0.09249104790633246
# Switches in the controller 12 : [18, 8, 22]
# Switch selected is : 22
# The target controller set for 14 is : [3, 4, 24, 9]
# The mean load ratio is : 0.08524823537024587
#
# At time step 4939 the number of switch migrated are : 8
# The migrated switches are [10, 8, 2, 22, 9, 7, 19, 22]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4940
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.13109043573453627
# 5 :	 0.05717752722497828
# 14 :	 0.12096422535131746
# 11 :	 0.09866316172058068
# 12 :	 0.06792330227199733
# Switches in the controller 0 : [15, 16, 21, 1, 7]
# Switch selected is : 1
# The target controller set for 14 is : [3, 4, 24, 9, 22]
# The mean load ratio is : 0.095163730460682
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.061388630527440605
# 5 :	 0.05717752722497828
# 14 :	 0.19066603055841314
# 11 :	 0.09866316172058068
# 12 :	 0.06792330227199733
# Switches in the controller 14 : [3, 4, 24, 9, 22, 1]
# Switch selected is : 3
# The target controller set for 11 is : [23, 17, 6, 20, 19]
# The mean load ratio is : 0.095163730460682
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.061388630527440605
# 5 :	 0.05717752722497828
# 14 :	 0.18847481631300025
# 11 :	 0.10085437596599355
# 12 :	 0.06792330227199733
# Switches in the controller 14 : [4, 24, 9, 22, 1]
# Switch selected is : 9
# The target controller set for 12 is : [18, 8]
# The mean load ratio is : 0.095163730460682
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.061388630527440605
# 5 :	 0.05717752722497828
# 14 :	 0.1575453929187755
# 11 :	 0.10085437596599355
# 12 :	 0.09885272566622208
# Switches in the controller 14 : [4, 24, 22, 1]
# Switch selected is : 4
# The target controller set for 0 is : [15, 16, 21, 7]
# The mean load ratio is : 0.095163730460682
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.10011778968458955
# 5 :	 0.05717752722497828
# 14 :	 0.11881623376162656
# 11 :	 0.10085437596599355
# 12 :	 0.09885272566622208
# Switches in the controller 14 : [24, 22, 1]
# Switch selected is : 24
# The target controller set for 0 is : [15, 16, 21, 7, 4]
# The mean load ratio is : 0.095163730460682
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.12467499309081105
# 5 :	 0.05717752722497828
# 14 :	 0.09425903035540506
# 11 :	 0.10085437596599355
# 12 :	 0.09885272566622208
# Switches in the controller 11 : [23, 17, 6, 20, 19, 3]
# Switch selected is : 6
# The target controller set for 5 is : [13, 10, 2]
# The mean load ratio is : 0.095163730460682
#
# At time step 4940 the number of switch migrated are : 6
# The migrated switches are [1, 3, 9, 4, 24, 6]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4941
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.11033485844799067
# 5 :	 0.09695539490266794
# 14 :	 0.08479814741191011
# 11 :	 0.07585643294049757
# 12 :	 0.08434527640226634
# Switches in the controller 5 : [13, 10, 2, 6]
# Switch selected is : 10
# The target controller set for 11 is : [23, 17, 20, 19, 3]
# The mean load ratio is : 0.09045802202106654
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.11033485844799067
# 5 :	 0.05826604835846221
# 14 :	 0.08479814741191011
# 11 :	 0.11454577948470329
# 12 :	 0.08434527640226634
# Switches in the controller 0 : [15, 16, 21, 7, 4, 24]
# Switch selected is : 24
# The target controller set for 11 is : [23, 17, 20, 19, 3, 10]
# The mean load ratio is : 0.09045802202106654
#
# At time step 4941 the number of switch migrated are : 2
# The migrated switches are [10, 24]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4942
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09426994823041657
# 5 :	 0.0645843038229593
# 14 :	 0.06195682591385599
# 11 :	 0.1724447010504992
# 12 :	 0.07689952282090506
# Switches in the controller 11 : [23, 17, 20, 19, 3, 10, 24]
# Switch selected is : 20
# The target controller set for 14 is : [22, 1]
# The mean load ratio is : 0.09403106036772721
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09426994823041657
# 5 :	 0.0645843038229593
# 14 :	 0.08651390158161568
# 11 :	 0.14788762538273953
# 12 :	 0.07689952282090506
# Switches in the controller 11 : [23, 17, 19, 3, 10, 24]
# Switch selected is : 24
# The target controller set for 14 is : [22, 1, 20]
# The mean load ratio is : 0.09403106036772721
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09426994823041657
# 5 :	 0.0645843038229593
# 14 :	 0.11107094751291632
# 11 :	 0.12333057945143888
# 12 :	 0.07689952282090506
# Switches in the controller 11 : [23, 17, 19, 3, 10]
# Switch selected is : 3
# The target controller set for 14 is : [22, 1, 20, 24]
# The mean load ratio is : 0.09403106036772721
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09426994823041657
# 5 :	 0.0645843038229593
# 14 :	 0.15095096342971462
# 11 :	 0.08345056353464059
# 12 :	 0.07689952282090506
# Switches in the controller 0 : [15, 16, 21, 7, 4]
# Switch selected is : 21
# The target controller set for 12 is : [18, 8, 9]
# The mean load ratio is : 0.09403106036772721
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.06971264523750922
# 5 :	 0.0645843038229593
# 14 :	 0.15095096342971462
# 11 :	 0.08345056353464059
# 12 :	 0.1014568258138124
# Switches in the controller 12 : [18, 8, 9, 21]
# Switch selected is : 9
# The target controller set for 0 is : [15, 16, 7, 4]
# The mean load ratio is : 0.09403106036772721
#
# At time step 4942 the number of switch migrated are : 5
# The migrated switches are [20, 24, 3, 21, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4943
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.10238323837407817
# 5 :	 0.04912242644115463
# 14 :	 0.19129892275552726
# 11 :	 0.08297727383456062
# 12 :	 0.07562640189882863
# Switches in the controller 14 : [22, 1, 20, 24, 3]
# Switch selected is : 1
# The target controller set for 5 is : [13, 2, 6]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.10238323837407817
# 5 :	 0.12022617359536228
# 14 :	 0.1201951756013196
# 11 :	 0.08297727383456062
# 12 :	 0.07562640189882863
# Switches in the controller 14 : [22, 20, 24, 3]
# Switch selected is : 3
# The target controller set for 5 is : [13, 2, 6, 1]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10238323837407817
# 5 :	 0.16675015059352472
# 14 :	 0.07367119860315718
# 11 :	 0.08297727383456062
# 12 :	 0.07562640189882863
# Switches in the controller 0 : [15, 16, 7, 4, 9]
# Switch selected is : 15
# The target controller set for 12 is : [18, 8, 21]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10200706230991936
# 5 :	 0.16675015059352472
# 14 :	 0.07367119860315718
# 11 :	 0.08297727383456062
# 12 :	 0.07600257796298744
# Switches in the controller 0 : [16, 7, 4, 9]
# Switch selected is : 16
# The target controller set for 14 is : [22, 20, 24]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10057723782328229
# 5 :	 0.16675015059352472
# 14 :	 0.07510102308979426
# 11 :	 0.08297727383456062
# 12 :	 0.07600257796298744
# Switches in the controller 0 : [7, 4, 9]
# Switch selected is : 7
# The target controller set for 11 is : [23, 17, 19, 10]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.05184404361120323
# 5 :	 0.16675015059352472
# 14 :	 0.07510102308979426
# 11 :	 0.13171046804663966
# 12 :	 0.07600257796298744
# Switches in the controller 11 : [23, 17, 19, 10, 7]
# Switch selected is : 19
# The target controller set for 0 is : [4, 9]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07640090276277273
# 5 :	 0.16675015059352472
# 14 :	 0.07510102308979426
# 11 :	 0.10715360889507017
# 12 :	 0.07600257796298744
# Switches in the controller 11 : [23, 17, 10, 7]
# Switch selected is : 17
# The target controller set for 5 is : [13, 2, 6, 1, 3]
# The mean load ratio is : 0.10028165266082985
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07640090276277273
# 5 :	 0.16708138366644362
# 14 :	 0.07510102308979426
# 11 :	 0.10682237582215126
# 12 :	 0.07600257796298744
# Switches in the controller 11 : [23, 10, 7]
# Switch selected is : 10
# The target controller set for 5 is : [13, 2, 6, 1, 3, 17]
# The mean load ratio is : 0.10028165266082985
#
# At time step 4943 the number of switch migrated are : 8
# The migrated switches are [1, 3, 15, 16, 7, 19, 17, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4944
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08571285209101058
# 5 :	 0.17960379129435158
# 14 :	 0.07412321153726706
# 11 :	 0.05475748943988468
# 12 :	 0.07531351372265618
# Switches in the controller 5 : [13, 2, 6, 1, 3, 17, 10]
# Switch selected is : 2
# The target controller set for 14 is : [22, 20, 24, 16]
# The mean load ratio is : 0.093902171617034
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08571285209101058
# 5 :	 0.14389018227550923
# 14 :	 0.10983682055610941
# 11 :	 0.05475748943988468
# 12 :	 0.07531351372265618
# Switches in the controller 5 : [13, 6, 1, 3, 17, 10]
# Switch selected is : 3
# The target controller set for 14 is : [22, 20, 24, 16, 2]
# The mean load ratio is : 0.093902171617034
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08571285209101058
# 5 :	 0.13142914810282808
# 14 :	 0.12229785472879057
# 11 :	 0.05475748943988468
# 12 :	 0.07531351372265618
# Switches in the controller 5 : [13, 6, 1, 17, 10]
# Switch selected is : 10
# The target controller set for 0 is : [4, 9, 19]
# The mean load ratio is : 0.093902171617034
#
# At time step 4944 the number of switch migrated are : 3
# The migrated switches are [2, 3, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4945
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10085450335824944
# 5 :	 0.05819815719913236
# 14 :	 0.1236687804542797
# 11 :	 0.07150964559814206
# 12 :	 0.08906279685884946
# Switches in the controller 0 : [4, 9, 19, 10]
# Switch selected is : 4
# The target controller set for 5 is : [13, 6, 1, 17]
# The mean load ratio is : 0.08865877669373061
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07986371047260757
# 5 :	 0.07918895008477422
# 14 :	 0.1236687804542797
# 11 :	 0.07150964559814206
# 12 :	 0.08906279685884946
# Switches in the controller 14 : [22, 20, 24, 16, 2, 3]
# Switch selected is : 2
# The target controller set for 11 is : [23, 7]
# The mean load ratio is : 0.08865877669373061
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07986371047260757
# 5 :	 0.07918895008477422
# 14 :	 0.08393580061305492
# 11 :	 0.11124262543936683
# 12 :	 0.08906279685884946
# Switches in the controller 11 : [23, 7, 2]
# Switch selected is : 23
# The target controller set for 5 is : [13, 6, 1, 17, 4]
# The mean load ratio is : 0.08865877669373061
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07986371047260757
# 5 :	 0.10374601112378073
# 14 :	 0.08393580061305492
# 11 :	 0.08668556440036032
# 12 :	 0.08906279685884946
# Switches in the controller 12 : [18, 8, 21, 15]
# Switch selected is : 8
# The target controller set for 14 is : [22, 20, 24, 16, 3]
# The mean load ratio is : 0.08865877669373061
#
# At time step 4945 the number of switch migrated are : 4
# The migrated switches are [4, 2, 23, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4946
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09186692119957411
# 5 :	 0.13832688754722655
# 14 :	 0.10947721411659364
# 11 :	 0.0766588970027371
# 12 :	 0.04959458342097134
# Switches in the controller 14 : [22, 20, 24, 16, 3, 8]
# Switch selected is : 20
# The target controller set for 12 is : [18, 21, 15]
# The mean load ratio is : 0.09318490065742055
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09186692119957411
# 5 :	 0.13832688754722655
# 14 :	 0.08492043930800519
# 11 :	 0.0766588970027371
# 12 :	 0.07415135822955979
# Switches in the controller 5 : [13, 6, 1, 17, 4, 23]
# Switch selected is : 23
# The target controller set for 12 is : [18, 21, 15, 20]
# The mean load ratio is : 0.09318490065742055
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09186692119957411
# 5 :	 0.11377047383941694
# 14 :	 0.08492043930800519
# 11 :	 0.0766588970027371
# 12 :	 0.0987077719373694
# Switches in the controller 5 : [13, 6, 1, 17, 4]
# Switch selected is : 1
# The target controller set for 11 is : [7, 2]
# The mean load ratio is : 0.09318490065742055
#
# At time step 4946 the number of switch migrated are : 3
# The migrated switches are [20, 23, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4947
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08482273433105031
# 5 :	 0.05741996578023152
# 14 :	 0.13262593649170099
# 11 :	 0.12280881163824857
# 12 :	 0.09838370880574586
# Switches in the controller 11 : [7, 2, 1]
# Switch selected is : 1
# The target controller set for 12 is : [18, 21, 15, 20, 23]
# The mean load ratio is : 0.09921223140939545
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08482273433105031
# 5 :	 0.05741996578023152
# 14 :	 0.13262593649170099
# 11 :	 0.06617502752071586
# 12 :	 0.15501749292327857
# Switches in the controller 14 : [22, 24, 16, 3, 8]
# Switch selected is : 24
# The target controller set for 0 is : [9, 19, 10]
# The mean load ratio is : 0.09921223140939545
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.10938003853020892
# 5 :	 0.05741996578023152
# 14 :	 0.10806863229254238
# 11 :	 0.06617502752071586
# 12 :	 0.15501749292327857
# Switches in the controller 14 : [22, 16, 3, 8]
# Switch selected is : 16
# The target controller set for 12 is : [18, 21, 15, 20, 23, 1]
# The mean load ratio is : 0.09921223140939545
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.10938003853020892
# 5 :	 0.05741996578023152
# 14 :	 0.10771954795832646
# 11 :	 0.06617502752071586
# 12 :	 0.15536657725749448
# Switches in the controller 14 : [22, 3, 8]
# Switch selected is : 8
# The target controller set for 11 is : [7, 2]
# The mean load ratio is : 0.09921223140939545
#
# At time step 4947 the number of switch migrated are : 4
# The migrated switches are [1, 24, 16, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4948
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.05587563155152323
# 14 :	 0.03505728330881881
# 11 :	 0.11576373955276861
# 12 :	 0.14410277259522314
# Switches in the controller 12 : [18, 21, 15, 20, 23, 1, 16]
# Switch selected is : 23
# The target controller set for 5 is : [13, 6, 17, 4]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.08043294577321078
# 14 :	 0.03505728330881881
# 11 :	 0.11576373955276861
# 12 :	 0.11954545837353558
# Switches in the controller 12 : [18, 21, 15, 20, 1, 16]
# Switch selected is : 16
# The target controller set for 5 is : [13, 6, 17, 4, 23]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.08080228879306653
# 14 :	 0.03505728330881881
# 11 :	 0.11576373955276861
# 12 :	 0.11917611535367983
# Switches in the controller 12 : [18, 21, 15, 20, 1]
# Switch selected is : 15
# The target controller set for 5 is : [13, 6, 17, 4, 23, 16]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.0811252721698558
# 14 :	 0.03505728330881881
# 11 :	 0.11576373955276861
# 12 :	 0.11885313197689057
# Switches in the controller 12 : [18, 21, 20, 1]
# Switch selected is : 21
# The target controller set for 14 is : [22, 3]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.0811252721698558
# 14 :	 0.05961402730478288
# 11 :	 0.11576373955276861
# 12 :	 0.0942963879809265
# Switches in the controller 12 : [18, 20, 1]
# Switch selected is : 20
# The target controller set for 5 is : [13, 6, 17, 4, 23, 16, 15]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09488990631002367
# 5 :	 0.10568256201225908
# 14 :	 0.05961402730478288
# 11 :	 0.11576373955276861
# 12 :	 0.06973909813852322
# Switches in the controller 0 : [9, 19, 10, 24]
# Switch selected is : 10
# The target controller set for 12 is : [18, 1]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07405860612570533
# 5 :	 0.10568256201225908
# 14 :	 0.05961402730478288
# 11 :	 0.11576373955276861
# 12 :	 0.09057039832284156
# Switches in the controller 5 : [13, 6, 17, 4, 23, 16, 15, 20]
# Switch selected is : 17
# The target controller set for 11 is : [7, 2, 8]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07405860612570533
# 5 :	 0.10545501706403915
# 14 :	 0.05961402730478288
# 11 :	 0.11599128450098854
# 12 :	 0.09057039832284156
# Switches in the controller 5 : [13, 6, 4, 23, 16, 15, 20]
# Switch selected is : 20
# The target controller set for 14 is : [22, 3, 21]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07405860612570533
# 5 :	 0.08089772722163587
# 14 :	 0.08417131714718616
# 11 :	 0.11599128450098854
# 12 :	 0.09057039832284156
# Switches in the controller 11 : [7, 2, 8, 17]
# Switch selected is : 17
# The target controller set for 0 is : [9, 19, 24]
# The mean load ratio is : 0.08913786666367149
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07428615107392526
# 5 :	 0.08089772722163587
# 14 :	 0.08417131714718616
# 11 :	 0.11576373955276861
# 12 :	 0.09057039832284156
# Switches in the controller 11 : [7, 2, 8]
# Switch selected is : 2
# The target controller set for 5 is : [13, 6, 4, 23, 16, 15]
# The mean load ratio is : 0.08913786666367149
#
# At time step 4948 the number of switch migrated are : 10
# The migrated switches are [23, 16, 15, 21, 20, 10, 17, 20, 17, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4949
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09383901306194897
# 5 :	 0.12939373526503586
# 14 :	 0.1655500618026632
# 11 :	 0.0933543741751295
# 12 :	 0.10662611759320355
# Switches in the controller 5 : [13, 6, 4, 23, 16, 15, 2]
# Switch selected is : 4
# The target controller set for 12 is : [18, 1, 10]
# The mean load ratio is : 0.11775266037959622
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09383901306194897
# 5 :	 0.09648498897193312
# 14 :	 0.1655500618026632
# 11 :	 0.0933543741751295
# 12 :	 0.1395348638863063
# Switches in the controller 14 : [22, 3, 21, 20]
# Switch selected is : 21
# The target controller set for 5 is : [13, 6, 23, 16, 15, 2]
# The mean load ratio is : 0.11775266037959622
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09383901306194897
# 5 :	 0.12104196858306585
# 14 :	 0.1409930821915305
# 11 :	 0.0933543741751295
# 12 :	 0.1395348638863063
# Switches in the controller 14 : [22, 3, 20]
# Switch selected is : 3
# The target controller set for 11 is : [7, 8]
# The mean load ratio is : 0.11775266037959622
#
# At time step 4949 the number of switch migrated are : 3
# The migrated switches are [4, 21, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4950
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07401125588621163
# 5 :	 0.11483231449061773
# 14 :	 0.049114091596516446
# 11 :	 0.1312925677711729
# 12 :	 0.10935703339674305
# Switches in the controller 12 : [18, 1, 10, 4]
# Switch selected is : 4
# The target controller set for 0 is : [9, 19, 24, 17]
# The mean load ratio is : 0.09572145262825235
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09689135059295795
# 5 :	 0.11483231449061773
# 14 :	 0.049114091596516446
# 11 :	 0.1312925677711729
# 12 :	 0.08647693868999673
# Switches in the controller 0 : [9, 19, 24, 17, 4]
# Switch selected is : 9
# The target controller set for 12 is : [18, 1, 10]
# The mean load ratio is : 0.09572145262825235
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07221445281846976
# 5 :	 0.11483231449061773
# 14 :	 0.049114091596516446
# 11 :	 0.1312925677711729
# 12 :	 0.11115383646448491
# Switches in the controller 11 : [7, 8, 3]
# Switch selected is : 3
# The target controller set for 0 is : [19, 24, 17, 4]
# The mean load ratio is : 0.09572145262825235
#
# Balance the overloaded controller : 5
# ...
#
# At time step 4992 the number of switch migrated are : 9
# The migrated switches are [16, 8, 19, 10, 16, 7, 2, 15, 20]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4993
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09444038903960668
# 5 :	 0.14424348850034993
# 14 :	 0.09364633631388714
# 11 :	 0.07404504596925804
# 12 :	 0.1387851073918252
# Switches in the controller 5 : [6, 4, 22, 10, 20]
# Switch selected is : 20
# The target controller set for 14 is : [21, 18, 17, 8]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09444038903960668
# 5 :	 0.11968620360712466
# 14 :	 0.1182036212071124
# 11 :	 0.07404504596925804
# 12 :	 0.1387851073918252
# Switches in the controller 5 : [6, 4, 22, 10]
# Switch selected is : 6
# The target controller set for 12 is : [23, 13, 3, 19, 16, 2, 15]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09444038903960668
# 5 :	 0.09512911553389848
# 14 :	 0.1182036212071124
# 11 :	 0.07404504596925804
# 12 :	 0.16334219546505138
# Switches in the controller 14 : [21, 18, 17, 8, 20]
# Switch selected is : 8
# The target controller set for 11 is : [24, 7]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09444038903960668
# 5 :	 0.09512911553389848
# 14 :	 0.07402324768918381
# 11 :	 0.11822541948718664
# 12 :	 0.16334219546505138
# Switches in the controller 12 : [23, 13, 3, 19, 16, 2, 15, 6]
# Switch selected is : 19
# The target controller set for 0 is : [9, 1]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.11899775601704836
# 5 :	 0.09512911553389848
# 14 :	 0.07402324768918381
# 11 :	 0.11822541948718664
# 12 :	 0.1387848284876097
# Switches in the controller 12 : [23, 13, 3, 16, 2, 15, 6]
# Switch selected is : 13
# The target controller set for 5 is : [4, 22, 10]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.11899775601704836
# 5 :	 0.09542247833905163
# 14 :	 0.07402324768918381
# 11 :	 0.11822541948718664
# 12 :	 0.13849146568245654
# Switches in the controller 12 : [23, 3, 16, 2, 15, 6]
# Switch selected is : 6
# The target controller set for 0 is : [9, 1, 19]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.14355484409027455
# 5 :	 0.09542247833905163
# 14 :	 0.07402324768918381
# 11 :	 0.11822541948718664
# 12 :	 0.11393437760923036
# Switches in the controller 12 : [23, 3, 16, 2, 15]
# Switch selected is : 16
# The target controller set for 11 is : [24, 7, 8]
# The mean load ratio is : 0.1090320734429854
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.14355484409027455
# 5 :	 0.09542247833905163
# 14 :	 0.07402324768918381
# 11 :	 0.11830456282875795
# 12 :	 0.11385523426765905
# Switches in the controller 12 : [23, 3, 2, 15]
# Switch selected is : 23
# The target controller set for 5 is : [4, 22, 10, 13]
# The mean load ratio is : 0.1090320734429854
#
# At time step 4993 the number of switch migrated are : 8
# The migrated switches are [20, 6, 8, 19, 13, 6, 16, 23]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4994
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.14905512641713356
# 5 :	 0.12131172866017575
# 14 :	 0.07399141402897676
# 11 :	 0.10538970913090925
# 12 :	 0.05151251364164853
# Switches in the controller 11 : [24, 7, 8, 16]
# Switch selected is : 7
# The target controller set for 12 is : [3, 2, 15]
# The mean load ratio is : 0.10025209837576876
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.14905512641713356
# 5 :	 0.12131172866017575
# 14 :	 0.07399141402897676
# 11 :	 0.06026076451883941
# 12 :	 0.09664145825371837
# Switches in the controller 5 : [4, 22, 10, 13, 23]
# Switch selected is : 13
# The target controller set for 12 is : [3, 2, 15, 7]
# The mean load ratio is : 0.10025209837576876
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.14905512641713356
# 5 :	 0.12126944927122353
# 14 :	 0.07399141402897676
# 11 :	 0.06026076451883941
# 12 :	 0.09668373764267059
# Switches in the controller 5 : [4, 22, 10, 23]
# Switch selected is : 10
# The target controller set for 0 is : [9, 1, 19, 6]
# The mean load ratio is : 0.10025209837576876
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.17308596247957794
# 5 :	 0.09723861320877915
# 14 :	 0.07399141402897676
# 11 :	 0.06026076451883941
# 12 :	 0.09668373764267059
# Switches in the controller 0 : [9, 1, 19, 6, 10]
# Switch selected is : 19
# The target controller set for 5 is : [4, 22, 23]
# The mean load ratio is : 0.10025209837576876
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.14852864183637626
# 5 :	 0.12179593385198081
# 14 :	 0.07399141402897676
# 11 :	 0.06026076451883941
# 12 :	 0.09668373764267059
# Switches in the controller 0 : [9, 1, 6, 10]
# Switch selected is : 1
# The target controller set for 12 is : [3, 2, 15, 7, 13]
# The mean load ratio is : 0.10025209837576876
#
# At time step 4994 the number of switch migrated are : 5
# The migrated switches are [7, 13, 10, 19, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4995
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08173075873165705
# 5 :	 0.0953288888500065
# 14 :	 0.07408590415967968
# 11 :	 0.05907876179885694
# 12 :	 0.13758278804829868
# Switches in the controller 5 : [4, 22, 23, 19]
# Switch selected is : 22
# The target controller set for 12 is : [3, 2, 15, 7, 13, 1]
# The mean load ratio is : 0.08956142031769979
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08173075873165705
# 5 :	 0.07077159781317793
# 14 :	 0.07408590415967968
# 11 :	 0.05907876179885694
# 12 :	 0.16214007908512723
# Switches in the controller 12 : [3, 2, 15, 7, 13, 1, 22]
# Switch selected is : 3
# The target controller set for 11 is : [24, 8, 16]
# The mean load ratio is : 0.08956142031769979
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08173075873165705
# 5 :	 0.07077159781317793
# 14 :	 0.07408590415967968
# 11 :	 0.0845880978329669
# 12 :	 0.13663074305101727
# Switches in the controller 12 : [2, 15, 7, 13, 1, 22]
# Switch selected is : 7
# The target controller set for 5 is : [4, 23, 19]
# The mean load ratio is : 0.08956142031769979
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08173075873165705
# 5 :	 0.1131695819076293
# 14 :	 0.07408590415967968
# 11 :	 0.0845880978329669
# 12 :	 0.09423275895656591
# Switches in the controller 12 : [2, 15, 13, 1, 22]
# Switch selected is : 22
# The target controller set for 0 is : [9, 6, 10]
# The mean load ratio is : 0.08956142031769979
#
# At time step 4995 the number of switch migrated are : 4
# The migrated switches are [22, 3, 7, 22]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4996
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.10579322830795325
# 5 :	 0.13695220596670513
# 14 :	 0.07387479413520592
# 11 :	 0.10839833690094183
# 12 :	 0.08689948148294303
# Switches in the controller 5 : [4, 23, 19, 7]
# Switch selected is : 23
# The target controller set for 14 is : [21, 18, 17, 20]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.10579322830795325
# 5 :	 0.11239485702390256
# 14 :	 0.09843214307800849
# 11 :	 0.10839833690094183
# 12 :	 0.08689948148294303
# Switches in the controller 5 : [4, 19, 7]
# Switch selected is : 19
# The target controller set for 11 is : [24, 8, 16, 3]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10579322830795325
# 5 :	 0.0878379602538498
# 14 :	 0.09843214307800849
# 11 :	 0.1329552336709946
# 12 :	 0.08689948148294303
# Switches in the controller 0 : [9, 6, 10, 22]
# Switch selected is : 10
# The target controller set for 12 is : [2, 15, 13, 1]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07694349136564835
# 5 :	 0.0878379602538498
# 14 :	 0.09843214307800849
# 11 :	 0.1329552336709946
# 12 :	 0.11574921842524794
# Switches in the controller 11 : [24, 8, 16, 3, 19]
# Switch selected is : 8
# The target controller set for 5 is : [4, 7]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07694349136564835
# 5 :	 0.10913530423795022
# 14 :	 0.09843214307800849
# 11 :	 0.11165788968689418
# 12 :	 0.11574921842524794
# Switches in the controller 11 : [24, 16, 3, 19]
# Switch selected is : 16
# The target controller set for 12 is : [2, 15, 13, 1, 10]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07694349136564835
# 5 :	 0.10913530423795022
# 14 :	 0.09843214307800849
# 11 :	 0.11148449894117199
# 12 :	 0.11592260917097012
# Switches in the controller 11 : [24, 3, 19]
# Switch selected is : 24
# The target controller set for 14 is : [21, 18, 17, 20, 23]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07694349136564835
# 5 :	 0.10913530423795022
# 14 :	 0.12298912786301308
# 11 :	 0.0869275141561674
# 12 :	 0.11592260917097012
# Switches in the controller 12 : [2, 15, 13, 1, 10, 16]
# Switch selected is : 16
# The target controller set for 5 is : [4, 7, 8]
# The mean load ratio is : 0.10238360935874984
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07694349136564835
# 5 :	 0.1093086949836724
# 14 :	 0.12298912786301308
# 11 :	 0.0869275141561674
# 12 :	 0.11574921842524794
# Switches in the controller 12 : [2, 15, 13, 1, 10]
# Switch selected is : 10
# The target controller set for 11 is : [3, 19]
# The mean load ratio is : 0.10238360935874984
#
# At time step 4996 the number of switch migrated are : 8
# The migrated switches are [23, 19, 10, 8, 16, 24, 16, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4997
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09145458645902835
# 5 :	 0.1070460035095763
# 14 :	 0.12319459933332771
# 11 :	 0.08810882328498017
# 12 :	 0.0952500382427354
# Switches in the controller 5 : [4, 7, 8, 16]
# Switch selected is : 8
# The target controller set for 14 is : [21, 18, 17, 20, 23, 24]
# The mean load ratio is : 0.10101081016592958
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09145458645902835
# 5 :	 0.06525007535419991
# 14 :	 0.1649905274887041
# 11 :	 0.08810882328498017
# 12 :	 0.0952500382427354
# Switches in the controller 14 : [21, 18, 17, 20, 23, 24, 8]
# Switch selected is : 24
# The target controller set for 0 is : [9, 6, 22]
# The mean load ratio is : 0.10101081016592958
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.11601141575587888
# 5 :	 0.06525007535419991
# 14 :	 0.14043369819185358
# 11 :	 0.08810882328498017
# 12 :	 0.0952500382427354
# Switches in the controller 14 : [21, 18, 17, 20, 23, 8]
# Switch selected is : 8
# The target controller set for 11 is : [3, 19, 10]
# The mean load ratio is : 0.10101081016592958
#
# At time step 4997 the number of switch migrated are : 3
# The migrated switches are [8, 24, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09589147300125232
# 5 :	 0.06714267724841205
# 14 :	 0.09852089827200099
# 11 :	 0.09783361529198288
# 12 :	 0.04103126993585005
# Switches in the controller 11 : [3, 19, 10, 8]
# Switch selected is : 8
# The target controller set for 0 is : [9, 6, 22, 24]
# The mean load ratio is : 0.08008398674989967
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.11656038848499842
# 5 :	 0.06714267724841205
# 14 :	 0.09852089827200099
# 11 :	 0.07716469980823679
# 12 :	 0.04103126993585005
# Switches in the controller 14 : [21, 18, 17, 20, 23]
# Switch selected is : 18
# The target controller set for 5 is : [4, 7, 16]
# The mean load ratio is : 0.08008398674989967
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.11656038848499842
# 5 :	 0.09169998097453094
# 14 :	 0.0739635945458821
# 11 :	 0.07716469980823679
# 12 :	 0.04103126993585005
# Switches in the controller 0 : [9, 6, 22, 24, 8]
# Switch selected is : 24
# The target controller set for 14 is : [21, 17, 20, 23]
# The mean load ratio is : 0.08008398674989967
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09200306832074946
# 5 :	 0.09169998097453094
# 14 :	 0.09852091471013105
# 11 :	 0.07716469980823679
# 12 :	 0.04103126993585005
# Switches in the controller 0 : [9, 6, 22, 8]
# Switch selected is : 8
# The target controller set for 5 is : [4, 7, 16, 18]
# The mean load ratio is : 0.08008398674989967
#
# At time step 4998 the number of switch migrated are : 4
# The migrated switches are [8, 18, 24, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# The overloaded domains are : [0, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08403644121972179
# 5 :	 0.1171990995050251
# 14 :	 0.09857486319534398
# 11 :	 0.08378939219631659
# 12 :	 0.03908681964899418
# Switches in the controller 14 : [21, 17, 20, 23, 24]
# Switch selected is : 17
# The target controller set for 5 is : [4, 7, 16, 18, 8]
# The mean load ratio is : 0.08453732315308032
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08403644121972179
# 5 :	 0.11754581942597507
# 14 :	 0.09822814327439401
# 11 :	 0.08378939219631659
# 12 :	 0.03908681964899418
# Switches in the controller 14 : [21, 20, 23, 24]
# Switch selected is : 24
# The target controller set for 0 is : [9, 6, 22]
# The mean load ratio is : 0.08453732315308032
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10859367144138209
# 5 :	 0.11754581942597507
# 14 :	 0.07367091305273371
# 11 :	 0.08378939219631659
# 12 :	 0.03908681964899418
# Switches in the controller 0 : [9, 6, 22, 24]
# Switch selected is : 6
# The target controller set for 11 is : [3, 19, 10]
# The mean load ratio is : 0.08453732315308032
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0840365833681559
# 5 :	 0.11754581942597507
# 14 :	 0.07367091305273371
# 11 :	 0.10834648026954277
# 12 :	 0.03908681964899418
# Switches in the controller 5 : [4, 7, 16, 18, 8, 17]
# Switch selected is : 16
# The target controller set for 14 is : [21, 20, 23]
# The mean load ratio is : 0.08453732315308032
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0840365833681559
# 5 :	 0.11735074086719181
# 14 :	 0.07386599161151697
# 11 :	 0.10834648026954277
# 12 :	 0.03908681964899418
# Switches in the controller 5 : [4, 7, 18, 8, 17]
# Switch selected is : 8
# The target controller set for 12 is : [2, 15, 13, 1]
# The mean load ratio is : 0.08453732315308032
#
# At time step 4999 the number of switch migrated are : 5
# The migrated switches are [17, 24, 6, 16, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Q-learning Implementation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''
When the migration efficiency can’t be optimized by using the greedy strategy only
to make decisions, exploring non-greedy situations at the case of probability in each 
decision and combining ε-greedy and decision-making to select migration triples, so as 
to obtain global optimal switch migration decision based on reinforcement learning
'''

# Q-evaluation matrix with size = (k*k); k = number of controllers
Q_matrix = np.ones([k,k])

# Q-learning parameters
# alpha - learning rate. gamma - discount factor
alpha, gamma = 0.6, 0.7

def update_Q_matrix(current_state, action, reward):
    ''' 
    Q learning formula -
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    The updation here is done in 2 parts -
        (a) Select the maximum Q-value in the matrix
        (b) Use the Q-learing formula to update the Q-matrix
    '''
    # (a) Select the maximum Q-value in the matrix
    list_of_max_indices = []
    max_value = max(Q_matrix[action, ])

    for i in range(0, len(Q_matrix[action, ])):
        if Q_matrix[action,i] == max_value:
            list_of_max_indices.append(i)

    # choose a random index from the list
    max_index = random.choice(list_of_max_indices) 
    max_value = Q_matrix[action,max_index]

    # (b) Use the Q-learing formula to update the Q-matrix
    Q_matrix[current_state, action] = Q_matrix[current_state, action] + alpha*(reward + gamma*max_value - Q_matrix[current_state, action])
    print('Q value =',Q_matrix[current_state, action])



def select_max_load_switch(index, current_controller, time_step):
    '''
    The following steps are followed to select a switch to migrate:
    (a) If the controller has no switch with it, return -1
    (b) Sort the switches based on load and select the switch with max load. If that switch is the controller itself, choose the next switch.
    '''
    if(len(controller_sets_Q[index]) == 1):
        return -1

    x = controller_sets_Q[index]
    load_x = []
    for i in x:
        load_x.append((load_array[time_step][i], i))

    load_x.sort(reverse=True)
    print(load_x)
    if(load_x[0][1] == current_controller):
        return load_x[1][1]
    return load_x[0][1]


def find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio):
    '''
    If the controller load ratios are less than mean, then they are underloaded
    '''
    I_domain = []
    for controller, controller_load_ratio in controller_cluster_load_ratio.items():
        if(controller_load_ratio < controller_mean_load_ratio):
            I_domain.append(controller)
    return I_domain

def load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, no_of_controllers):
    '''
    Find the load rate for controllers
    '''
    s = 0
    for current_controller, controller_load in controller_cluster_load_ratio.items():
        s = s + abs(controller_load - controller_mean_load_ratio)
    s /= no_of_controllers
    return s


def sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix):
    '''
    Epsilon greedy strategy - 
    Randomly generate a number. 
    (a) If it's less than epsilon : next action = random selection
    (b) If it's greater than or equal to epsilon: next action = greedy selection
    '''
    ran = np.random.random()
    next_action = -1

    if ran < epsilon:
        print('Taking a random action')
        next_action = int(np.random.choice(underloaded_domain, 1))
        while(next_action == index_of_overloaded_controller):
            next_action = int(np.random.choice(underloaded_domain, 1))
    else:
        ls = []
        for i in underloaded_domain:
            ind = controllers_Q.index(i)
            if ind != index_of_overloaded_controller:
                ls.append(ind)

        max_ele = Q_matrix[index_of_overloaded_controller][ls[0]]
        next_action = controllers_Q[ls[0]]

        if len(ls) > 1:
            for i in range(1, len(ls)):
                if max_ele < Q_matrix[index_of_overloaded_controller][ls[i]]:
                    max_ele = Q_matrix[index_of_overloaded_controller][ls[i]]
                    next_action = controllers_Q[ls[i]]
    return next_action


# For making graph
time_steps_list_QL = []
load_balance_rate_list_QL = []
number_of_switches_list_QL = []
discrete_coeff_list_QL = []
reward_list = []
load_rate_list_QL = []

epsilon = 0.7
epsilon_dec = 0.0025
epsilon_min = 0.05

load_controller = []

for i in range(0, 5000):
    print('At time step :', i)
    
    # Store the controller load ratios for each controller
    # print(controller_sets_Q)
    controller_cluster_load = calculate_controller_cluster_load(i, controller_sets_Q)
    controller_cluster_load_ratio = calculate_controller_cluster_load_ratio(controller_cluster_load)
    controller_mean_load_ratio = calculate_controller_mean_load_ratio(controller_cluster_load_ratio)

    # Calculate the discrete coefficient
    discrete_coefficient = calculate_discrete_coefficient(controller_cluster_load_ratio)
    print(discrete_coefficient)
    # print(controller_cluster_load, controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)

    switch_array = []
    reward = 0

    # Classify the domains as overloaded and underloaded (O-Domain and I-Domain)
    O_domain, I_domain, migration_queue = select_migration_domain(controller_cluster_load_ratio, controller_mean_load_ratio, discrete_coefficient)
    O_domain = list(O_domain)

    print('The overloaded domains are :', O_domain)

    # Loop until there are no overloaded controllers in O_domain
    while(len(O_domain) >= 1):

        # Assign current state to a random overloaded domain
        current_state = random.choice(O_domain)
        O_domain.remove(current_state)

        while(controller_cluster_load_ratio[current_state] >= controller_mean_load_ratio):
            print('Balance the overloaded controller :', current_state)
            
            print('Controller\tController Load Ratio')
            for C,C_load_ratio in controller_cluster_load_ratio.items():
                print(C, ':\t', C_load_ratio)
            
            # Select switch to migrate from selected overloaded controller
            index_of_overloaded_controller = controllers_Q.index(current_state)
            current_switch = select_max_load_switch(index_of_overloaded_controller, current_state, i)
            
            # Print all the switches of the overloaded controller
            print('Switches in the controller', current_state, ':', controller_sets_Q[index_of_overloaded_controller])

            # Controller can't be balanced by switch migration if it has no switches on it
            if(current_switch == -1):
                break
            
            print('Switch selected is :', current_switch)
            switch_array.append(current_switch)

            # Find domains that are currently underloaded
            underloaded_domain = find_underloaded(controller_cluster_load_ratio, controller_mean_load_ratio)
            print('The underloaded domains are :', underloaded_domain)

            target = sample_next_action(underloaded_domain, index_of_overloaded_controller, epsilon, Q_matrix)
            target_controller_index = controllers_Q.index(target)
            target_state = controllers_Q[target_controller_index]

            print('The target controller set for {} is : {}'.format(target_state, controller_sets_Q[target_controller_index]))
            print('The mean load ratio is :', controller_mean_load_ratio)

            # Reward calculation -
            '''
            The reward in this case is given as -
            Rij = (D'ij − Dij) / cost(St)
            '''
            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            D_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, D_ij)

            # Migrate the selected switch
            controller_sets_Q[index_of_overloaded_controller].remove(current_switch)
            controller_sets_Q[target_controller_index].append(current_switch)

            # Update the loads
            controller_cluster_load_ratio[current_state] -= (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)
            controller_cluster_load_ratio[target_state] += (load_array[i][current_switch]/CONTROLLERS_LOAD_CAPACITY)

            R_initial = controller_cluster_load_ratio[current_state]
            R_target = controller_cluster_load_ratio[target_state]
            Dt_ij = calculate_discrete_coefficient({current_state: R_initial, target_state: R_target})
            # print(R_initial, R_target, Dt_ij)

            # reward =  (Dt_ij - D_ij)/(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)])
            reward =  1/(Dt_ij*(hop_count[(current_state, target_state)]+hop_count[(target_state, current_switch)]))
            # 1 - research paper, 2 - cs->uc + oc->uc
            print('The reward is =', reward)
            
            # Update the Q-matrix
            update_Q_matrix(index_of_overloaded_controller, target_controller_index, reward)
            print()

    if(epsilon > epsilon_min):
        epsilon = epsilon * epsilon_dec
    else:
        epsilon = epsilon_min
    
    l_rate = load_rate(controller_cluster_load_ratio, controller_mean_load_ratio, k)
    reward_list.append(reward)
    discrete_coeff = calculate_discrete_coefficient(controller_cluster_load_ratio)

    discrete_coeff_list_QL.append(discrete_coeff)
    time_steps_list_QL.append(i)
    load_balance_rate_list_QL.append(l_rate)
    number_of_switches_list_QL.append(len(switch_array))

    load_controller.append(controller_cluster_load_ratio)
    load_rate_list_QL.append([l_rate, len(switch_array)])

    print('At time step', i, 'the number of switch migrated are :', len(switch_array))
    print('The migrated switches are', switch_array)
    print('\n---------------------------------------------------------------------------------------------------------------------------\n')

# Finally print the Q_matrix   
print(Q_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# The reward is = 0.39081828971775084
# Q value = 8.744213909402982
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.05975843719986206
# 5 :	 0.11315526252551547
# 14 :	 0.06791216469787104
# 11 :	 0.13337626765167895
# 12 :	 0.14616424520978635
# [(880505.6152, 2), (752730.8692, 9), (415306.2439, 24), (415303.6863, 23), (7400.665572, 15), (667.9125312000001, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 14]
# The target controller set for 0 is : [19, 22, 3]
# The mean load ratio is : 0.10407327545694275
# The reward is = 1.6598761849271733
# Q value = 12.324751839913393
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.11182270277072073
# 5 :	 0.11315526252551547
# 14 :	 0.06791216469787104
# 11 :	 0.13337626765167895
# 12 :	 0.09409997963892769
# [(791653.2452, 1), (703792.6404, 8), (415307.0, 6), (2917.516752, 17)]
# Switches in the controller 5 : [17, 6, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.10407327545694275
# The reward is = 0.46325051654966026
# Q value = 22.305841304362378
#
# At time step 4911 the number of switch migrated are : 4
# The migrated switches are [4, 2, 2, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4912
# 0.3264937805538135
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.11019277454973528
# 5 :	 0.056265422112803026
# 14 :	 0.059282078594264515
# 11 :	 0.12088965041508844
# 12 :	 0.12878557445825703
# [(738873.75, 1), (597846.4374, 9), (415315.0827, 23), (415307.0291, 24), (5491.714777, 13), (5174.6494299999995, 15)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 14]
# The target controller set for 5 is : [17, 6, 8]
# The mean load ratio is : 0.09508310002602967
# The reward is = 3.1134487526909442
# Q value = 18.09568532300327
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.11019277454973528
# 5 :	 0.09995500055416064
# 14 :	 0.059282078594264515
# 11 :	 0.12088965041508844
# 12 :	 0.08509599601689942
# [(522225.703, 3), (510726.5814, 2), (415310.35799999995, 19), (415306.4617, 22)]
# Switches in the controller 0 : [19, 22, 3, 2]
# Switch selected is : 3
# The underloaded domains are : [14, 12]
# The target controller set for 14 is : [16, 21, 10]
# The mean load ratio is : 0.09508310002602967
# The reward is = 1.4202859181439835
# Q value = 22.717856317856832
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07931358738777206
# 5 :	 0.09995500055416064
# 14 :	 0.09016126575622774
# 11 :	 0.12088965041508844
# 12 :	 0.08509599601689942
# [(823159.7829, 7), (415309.0599, 20), (415306.3935, 18), (390698.355, 4)]
# Switches in the controller 11 : [18, 20, 7, 4]
# Switch selected is : 7
# The underloaded domains are : [0, 14, 12]
# The target controller set for 0 is : [19, 22, 2]
# The mean load ratio is : 0.09508310002602967
# The reward is = 0.39886145643352666
# Q value = 16.426896483827328
#
# At time step 4912 the number of switch migrated are : 3
# The migrated switches are [1, 3, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4913
# 0.1584767049372964
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.11838411178757473
# 5 :	 0.10777306966474405
# 14 :	 0.08614677632545921
# 11 :	 0.08590969981613716
# 12 :	 0.07852973776265562
# [(1010681.9770000001, 1), (415307.0, 6), (390919.5063, 8), (5738.815508, 17)]
# Switches in the controller 5 : [17, 6, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.09534867907131414
# The reward is = 0.34393576322388014
# Q value = 16.728885815340654
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.11838411178757473
# 5 :	 0.04801148047118035
# 14 :	 0.08614677632545921
# 11 :	 0.08590969981613716
# 12 :	 0.13829132695621932
# [(623949.9398, 2), (547541.9115, 7), (415306.0126, 19), (415302.3105, 22)]
# Switches in the controller 0 : [19, 22, 2, 7]
# Switch selected is : 2
# The underloaded domains are : [5, 14, 11]
# The target controller set for 14 is : [16, 21, 10, 3]
# The mean load ratio is : 0.09534867907131414
# The reward is = 0.4102010867310416
# Q value = 25.36222560867202
#
# At time step 4913 the number of switch migrated are : 2
# The migrated switches are [1, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4914
# 0.18690582303179767
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07126695983393068
# 5 :	 0.06135783894812066
# 14 :	 0.06999397193369664
# 11 :	 0.08453482501225587
# 12 :	 0.10321122162614749
# [(526217.7265, 1), (415309.7265, 24), (415305.8339, 23), (382539.8167, 9), (4354.691199, 15), (1769.989469, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 14]
# The target controller set for 5 is : [17, 6, 8]
# The mean load ratio is : 0.07807296347083027
# The reward is = 2.019045362265048
# Q value = 16.0760699988192
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07126695983393068
# 5 :	 0.0924730743170245
# 14 :	 0.06999397193369664
# 11 :	 0.08453482501225587
# 12 :	 0.07209598625724364
# [(599020.3146, 4), (415315.5642, 18), (415308.5671, 20)]
# Switches in the controller 11 : [18, 20, 4]
# Switch selected is : 4
# The underloaded domains are : [0, 14, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.07807296347083027
# The reward is = 0.3006885106997955
# Q value = 17.403306455593057
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10668700963632712
# 5 :	 0.0924730743170245
# 14 :	 0.06999397193369664
# 11 :	 0.049114775209859435
# 12 :	 0.07209598625724364
# [(599020.3146, 4), (415308.1098, 22), (415304.584, 19), (374646.9526, 7)]
# Switches in the controller 0 : [19, 22, 7, 4]
# Switch selected is : 4
# The underloaded domains are : [14, 11, 12]
# The target controller set for 14 is : [16, 21, 10, 3, 2]
# The mean load ratio is : 0.07807296347083027
# The reward is = 0.47037450722633245
# Q value = 26.45607737729527
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07126695983393068
# 5 :	 0.0924730743170245
# 14 :	 0.10541402173609307
# 11 :	 0.049114775209859435
# 12 :	 0.07209598625724364
# [(599020.3146, 4), (516603.3866, 10), (415301.8993, 21), (148381.6898, 3), (101473.7295, 2), (1970.2980519999999, 16)]
# Switches in the controller 14 : [16, 21, 10, 3, 2, 4]
# Switch selected is : 4
# The underloaded domains are : [0, 11, 12]
# The target controller set for 11 is : [18, 20]
# The mean load ratio is : 0.07807296347083027
# The reward is = 1.5181738170094825
# Q value = 13.73894292459767
#
# At time step 4914 the number of switch migrated are : 4
# The migrated switches are [1, 4, 4, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4915
# 0.17458607695446074
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07535413826214746
# 5 :	 0.09027325842187212
# 14 :	 0.10760192405845775
# 11 :	 0.06820125496810531
# 12 :	 0.07254488986045325
# [(750663.9526, 1), (415307.0, 6), (353954.0405, 8), (6767.260624, 17)]
# Switches in the controller 5 : [17, 6, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.08279509311420717
# The reward is = 0.38195961797042494
# Q value = 14.021087370502263
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07535413826214746
# 5 :	 0.04588652572197954
# 14 :	 0.10760192405845775
# 11 :	 0.06820125496810531
# 12 :	 0.11693162256034582
# [(750663.9526, 1), (415308.3481, 24), (415308.3014, 23), (388082.3522, 9), (5694.788186, 15), (2478.080404, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 11]
# The target controller set for 11 is : [18, 20, 4]
# The mean load ratio is : 0.08279509311420717
# The reward is = 0.6604772203126809
# Q value = 14.467920065997403
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07535413826214746
# 5 :	 0.04588652572197954
# 14 :	 0.10760192405845775
# 11 :	 0.11258798766799788
# 12 :	 0.07254488986045325
# [(523633.9015, 10), (456143.653, 3), (419741.0107, 2), (415309.7468, 21), (4924.589553, 16)]
# Switches in the controller 14 : [16, 21, 10, 3, 2]
# Switch selected is : 10
# The underloaded domains are : [0, 5, 12]
# The target controller set for 5 is : [17, 6, 8]
# The mean load ratio is : 0.08279509311420717
# The reward is = 146.52174978211127
# Q value = 110.80509702580244
#
# At time step 4915 the number of switch migrated are : 3
# The migrated switches are [1, 1, 10]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4916
# 0.20136411677390814
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07457251240307211
# 5 :	 0.09940188190175618
# 14 :	 0.07066766438563434
# 11 :	 0.11662134631612023
# 12 :	 0.0767434203281007
# [(652586.6516, 8), (608463.2118, 10), (415307.0, 6), (4717.751142, 17)]
# Switches in the controller 5 : [17, 6, 8, 10]
# Switch selected is : 8
# The underloaded domains are : [0, 14, 12]
# The target controller set for 14 is : [16, 21, 3, 2]
# The mean load ratio is : 0.0876013650669367
# The reward is = 0.5851476841832282
# Q value = 54.1524376015935
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07457251240307211
# 5 :	 0.06081445650619827
# 14 :	 0.10925508978119225
# 11 :	 0.11662134631612023
# 12 :	 0.0767434203281007
# [(624813.0057, 1), (516859.3293, 4), (415310.0059, 18), (415306.1214, 20)]
# Switches in the controller 11 : [18, 20, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 12]
# Taking a random action
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.0876013650669367
# The reward is = 0.6671719949506185
# Q value = 18.473178277671607
#
# At time step 4916 the number of switch migrated are : 2
# The migrated switches are [8, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4917
# 0.3600694722005647
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.1560191529454202
# 5 :	 0.05684160262766544
# 14 :	 0.13707685816641538
# 11 :	 0.07942253724431732
# 12 :	 0.08701225560830311
# [(824282.8701, 8), (688946.6293, 2), (415310.0882, 21), (384406.2865, 3), (5284.144246, 16)]
# Switches in the controller 14 : [16, 21, 3, 2, 8]
# Switch selected is : 8
# The underloaded domains are : [5, 11, 12]
# The target controller set for 5 is : [17, 6, 10]
# The mean load ratio is : 0.10327448131842429
# The reward is = 2.2490630072829516
# Q value = 68.41550040736001
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1560191529454202
# 5 :	 0.10558141928930936
# 14 :	 0.08833704150477145
# 11 :	 0.07942253724431732
# 12 :	 0.08701225560830311
# [(1088552.92, 1), (719411.8064, 7), (415309.3542, 22), (415306.1191, 19)]
# Switches in the controller 0 : [19, 22, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [14, 11, 12]
# The target controller set for 14 is : [16, 21, 3, 2]
# The mean load ratio is : 0.10327448131842429
# The reward is = 0.36386848014444234
# Q value = 39.53526221009597
#
# At time step 4917 the number of switch migrated are : 2
# The migrated switches are [8, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4918
# 0.14471969748868369
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09619053065394623
# 5 :	 0.09697212168198395
# 14 :	 0.12254695482549242
# 11 :	 0.11360742123479581
# 12 :	 0.0802776872129398
# [(1090706.297, 4), (415306.7745, 18), (415304.1934, 20)]
# Switches in the controller 11 : [18, 20, 4]
# Switch selected is : 4
# The underloaded domains are : [0, 5, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.10191894312183165
# The reward is = 0.20893512846267695
# Q value = 24.119442516386556
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.16068395503025434
# 5 :	 0.09697212168198395
# 14 :	 0.12254695482549242
# 11 :	 0.04911399685848769
# 12 :	 0.0802776872129398
# [(1172263.635, 1), (415300.3449, 21), (251760.7822, 2), (226174.0267, 3), (7002.967758, 16)]
# Switches in the controller 14 : [16, 21, 3, 2, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 11, 12]
# The target controller set for 5 is : [17, 6, 10, 8]
# The mean load ratio is : 0.10191894312183165
# The reward is = 0.3883335206609238
# Q value = 50.343224068009825
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.16068395503025434
# 5 :	 0.16628802854060967
# 14 :	 0.0532310479668667
# 11 :	 0.04911399685848769
# 12 :	 0.0802776872129398
# [(1090706.297, 4), (796160.1125, 7), (415303.75700000004, 19), (415300.6962, 22)]
# Switches in the controller 0 : [19, 22, 7, 4]
# Switch selected is : 4
# The underloaded domains are : [14, 11, 12]
# The target controller set for 14 is : [16, 21, 3, 2]
# The mean load ratio is : 0.10191894312183165
# The reward is = 0.9030775106078767
# Q value = 37.50010549896724
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09619053065394623
# 5 :	 0.16628802854060967
# 14 :	 0.11772447234317482
# 11 :	 0.04911399685848769
# 12 :	 0.0802776872129398
# [(1172263.635, 1), (737644.0939, 10), (479534.5631, 8), (415307.0, 6), (7497.097441, 17)]
# Switches in the controller 5 : [17, 6, 10, 8, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.10191894312183165
# The reward is = 0.7809413931766206
# Q value = 12.828949183610941
#
# At time step 4918 the number of switch migrated are : 4
# The migrated switches are [4, 1, 4, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4919
# 0.3281278391214339
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07603733292950046
# 5 :	 0.08393883182806891
# 14 :	 0.13632444660467852
# 11 :	 0.04911409403267098
# 12 :	 0.1111846136092936
# [(704437.6559, 4), (650134.3311, 3), (524631.5092, 2), (415307.1783, 21), (10994.6353, 16)]
# Switches in the controller 14 : [16, 21, 3, 2, 4]
# Switch selected is : 4
# The underloaded domains are : [0, 5, 11]
# The target controller set for 5 is : [17, 6, 10, 8]
# The mean load ratio is : 0.09131986380084249
# The reward is = 1.424677970231346
# Q value = 43.736120202012
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07603733292950046
# 5 :	 0.1255922052555173
# 14 :	 0.09467107317723014
# 11 :	 0.04911409403267098
# 12 :	 0.1111846136092936
# [(650134.3311, 3), (524631.5092, 2), (415307.1783, 21), (10994.6353, 16)]
# Switches in the controller 14 : [16, 21, 3, 2]
# Switch selected is : 3
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [18, 20]
# The mean load ratio is : 0.09131986380084249
# The reward is = 0.655669998236058
# Q value = 16.019145025663054
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07603733292950046
# 5 :	 0.1255922052555173
# 14 :	 0.056228653405228486
# 11 :	 0.08755651380467264
# 12 :	 0.1111846136092936
# [(599581.8209, 9), (442581.9274, 1), (415308.9864, 23), (415305.92100000003, 24), (4438.070573, 15), (3126.2601, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 1]
# Switch selected is : 9
# The underloaded domains are : [0, 14, 11]
# The target controller set for 11 is : [18, 20, 3]
# The mean load ratio is : 0.09131986380084249
# The reward is = 1.050908621706125
# Q value = 16.54787905630499
#
# At time step 4919 the number of switch migrated are : 3
# The migrated switches are [4, 3, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4920
# 0.3021483709687695
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09825993053206596
# 5 :	 0.12227283762479167
# 14 :	 0.06227627162376204
# 11 :	 0.15109945536779051
# 12 :	 0.08114265757407363
# [(1051715.872, 3), (673047.3087, 9), (415307.8187, 20), (415307.7704, 18)]
# Switches in the controller 11 : [18, 20, 3, 9]
# Switch selected is : 3
# The underloaded domains are : [0, 14, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.10301023054449676
# The reward is = 0.4979676043050071
# Q value = 25.696601878703866
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.16044785247105053
# 5 :	 0.12227283762479167
# 14 :	 0.06227627162376204
# 11 :	 0.08891153342880592
# 12 :	 0.08114265757407363
# [(624913.4136, 10), (523202.57899999997, 4), (497615.5347, 8), (415307.0, 6), (6827.38677, 17)]
# Switches in the controller 5 : [17, 6, 10, 8, 4]
# Switch selected is : 10
# The underloaded domains are : [14, 11, 12]
# The target controller set for 14 is : [16, 21, 2]
# The mean load ratio is : 0.10301023054449676
# The reward is = 3.3178800345014188
# Q value = 42.02087354618329
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.16044785247105053
# 5 :	 0.0853217298035519
# 14 :	 0.0992273794450018
# 11 :	 0.08891153342880592
# 12 :	 0.08114265757407363
# [(1051715.872, 3), (831149.6028, 7), (415308.5442, 19), (415303.901, 22)]
# Switches in the controller 0 : [19, 22, 7, 3]
# Switch selected is : 3
# The underloaded domains are : [5, 14, 11, 12]
# The target controller set for 14 is : [16, 21, 2, 10]
# The mean load ratio is : 0.10301023054449676
# The reward is = 0.37378989223966874
# Q value = 33.59348661977573
#
# At time step 4920 the number of switch migrated are : 3
# The migrated switches are [3, 10, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4921
# 0.16912250508376536
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07598473228509643
# 5 :	 0.08146126799394102
# 14 :	 0.11941477246239313
# 11 :	 0.08470627479756522
# 12 :	 0.08930918623913486
# [(659292.8797, 2), (616874.2354, 10), (415313.025, 21), (316378.5347, 3), (11671.92912, 16)]
# Switches in the controller 14 : [16, 21, 2, 10, 3]
# Switch selected is : 2
# The underloaded domains are : [0, 5, 11, 12]
# The target controller set for 5 is : [17, 6, 8, 4]
# The mean load ratio is : 0.09017524675562613
# The reward is = 0.8366817865297269
# Q value = 35.64522404211962
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07598473228509643
# 5 :	 0.12044523241747304
# 14 :	 0.0804308080388611
# 11 :	 0.08470627479756522
# 12 :	 0.08930918623913486
# [(659292.8797, 2), (637812.833, 4), (415307.0, 6), (318482.8643, 8), (6062.061888, 17)]
# Switches in the controller 5 : [17, 6, 8, 4, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 14, 11, 12]
# The target controller set for 14 is : [16, 21, 10, 3]
# The mean load ratio is : 0.09017524675562613
# The reward is = 0.5880763940851987
# Q value = 32.132189352614674
#
# At time step 4921 the number of switch migrated are : 2
# The migrated switches are [2, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4922
# 0.30112536361458114
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07161602525844316
# 5 :	 0.08531165999665304
# 14 :	 0.15962045580336412
# 11 :	 0.08801417473168045
# 12 :	 0.11916294984652007
# [(836457.6948, 3), (722701.8008, 2), (720061.1739, 10), (415312.5911, 21), (4951.810295, 16)]
# Switches in the controller 14 : [16, 21, 10, 3, 2]
# Switch selected is : 3
# The underloaded domains are : [0, 5, 11]
# The target controller set for 5 is : [17, 6, 8, 4]
# The mean load ratio is : 0.10474505312733215
# The reward is = 1.9904577957609881
# Q value = 28.947883822402602
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07161602525844316
# 5 :	 0.13477137360786437
# 14 :	 0.11016074219215277
# 11 :	 0.08801417473168045
# 12 :	 0.11916294984652007
# [(722701.8008, 2), (720061.1739, 10), (415312.5911, 21), (4951.810295, 16)]
# Switches in the controller 14 : [16, 21, 10, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [18, 20, 9]
# The mean load ratio is : 0.10474505312733215
# The reward is = 0.3912164736478568
# Q value = 17.43496068350956
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07161602525844316
# 5 :	 0.13477137360786437
# 14 :	 0.06742741052925096
# 11 :	 0.13074750639458227
# 12 :	 0.11916294984652007
# [(836457.6948, 3), (554812.2169, 8), (466571.9614, 4), (415307.0, 6), (6091.02261, 17)]
# Switches in the controller 5 : [17, 6, 8, 4, 3]
# Switch selected is : 3
# The underloaded domains are : [0, 14]
# The target controller set for 14 is : [16, 21, 10]
# The mean load ratio is : 0.10474505312733215
# The reward is = 0.8004584794708343
# Q value = 25.491262034137463
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07161602525844316
# 5 :	 0.08531165999665302
# 14 :	 0.11688712414046229
# 11 :	 0.13074750639458227
# 12 :	 0.11916294984652007
# [(1172763.19, 1), (415306.7798, 24), (415306.25200000004, 23), (6562.035047, 15), (5333.548358, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5]
# The target controller set for 5 is : [17, 6, 8, 4]
# The mean load ratio is : 0.10474505312733215
# The reward is = 0.4875891540292502
# Q value = 17.429311546282964
#
# At time step 4922 the number of switch migrated are : 4
# The migrated switches are [3, 2, 3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4923
# 0.3703345147400405
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07192529900201973
# 5 :	 0.14192887885717753
# 14 :	 0.06893959929693587
# 11 :	 0.10385486760313198
# 12 :	 0.049932895926604916
# [(880631.0848, 1), (557154.8514, 8), (539473.3163, 4), (415307.0, 6), (7720.651051999999, 17)]
# Switches in the controller 5 : [17, 6, 8, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 14, 12]
# The target controller set for 14 is : [16, 21, 10, 3]
# The mean load ratio is : 0.087316308137174
# The reward is = 0.8460706154930424
# Q value = 22.862258388359905
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07192529900201973
# 5 :	 0.08985719427335323
# 14 :	 0.12101128388076016
# 11 :	 0.10385486760313198
# 12 :	 0.049932895926604916
# [(557154.8514, 8), (539473.3163, 4), (415307.0, 6), (7720.651051999999, 17)]
# Switches in the controller 5 : [17, 6, 8, 4]
# Switch selected is : 8
# The underloaded domains are : [0, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.087316308137174
# The reward is = 0.4216845990126952
# Q value = 19.89891660270757
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.1048698454610369
# 5 :	 0.056912647814336054
# 14 :	 0.12101128388076016
# 11 :	 0.10385486760313198
# 12 :	 0.049932895926604916
# [(880631.0848, 1), (484995.4891, 10), (415304.5919, 21), (256933.8735, 3), (8665.60492, 16)]
# Switches in the controller 14 : [16, 21, 10, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 12]
# The target controller set for 5 is : [17, 6, 4]
# The mean load ratio is : 0.087316308137174
# The reward is = 0.888625883685341
# Q value = 21.714477582283404
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.1048698454610369
# 5 :	 0.10898433239816036
# 14 :	 0.06893959929693586
# 11 :	 0.10385486760313198
# 12 :	 0.049932895926604916
# [(673005.3604, 9), (415306.9093, 20), (415305.8662, 18), (252764.9243, 2)]
# Switches in the controller 11 : [18, 20, 9, 2]
# Switch selected is : 9
# The underloaded domains are : [14, 12]
# The target controller set for 14 is : [16, 21, 10, 3]
# The mean load ratio is : 0.087316308137174
# The reward is = 0.9669680132578957
# Q value = 15.221380320870804
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1048698454610369
# 5 :	 0.10898433239816036
# 14 :	 0.10873438221438278
# 11 :	 0.06406008468568505
# 12 :	 0.049932895926604916
# [(557154.8514, 8), (415306.1234, 22), (415305.8132, 19), (385781.4755, 7)]
# Switches in the controller 0 : [19, 22, 7, 8]
# Switch selected is : 8
# The underloaded domains are : [11, 12]
# The target controller set for 11 is : [18, 20, 2]
# The mean load ratio is : 0.087316308137174
# The reward is = 0.7484247240611335
# Q value = 16.428183202054846
#
# At time step 4923 the number of switch migrated are : 5
# The migrated switches are [1, 8, 1, 9, 8]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4924
# 0.23737172056402023
# The overloaded domains are : [0, 11, 5]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09345707400036385
# 5 :	 0.09589611715408929
# 14 :	 0.08221458213537938
# 11 :	 0.11086644669703455
# 12 :	 0.049683226336740716
# [(633341.2868, 4), (565919.4756, 1), (415307.0, 6), (7217.711845000001, 17)]
# Switches in the controller 5 : [17, 6, 4, 1]
# Switch selected is : 4
# The underloaded domains are : [14, 12]
# The target controller set for 14 is : [16, 21, 10, 3, 9]
# The mean load ratio is : 0.08642348926472156
# The reward is = 0.3636850282307384
# Q value = 18.483194956841434
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09345707400036385
# 5 :	 0.0584466694916179
# 14 :	 0.11966402979785076
# 11 :	 0.11086644669703455
# 12 :	 0.049683226336740716
# [(707956.4144, 8), (415308.019, 18), (415306.9619, 20), (336390.7843, 2)]
# Switches in the controller 11 : [18, 20, 2, 8]
# Switch selected is : 8
# The underloaded domains are : [5, 12]
# The target controller set for 5 is : [17, 6, 1]
# The mean load ratio is : 0.08642348926472156
# The reward is = 1.0817658839257374
# Q value = 14.371723040471512
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09345707400036385
# 5 :	 0.10030810698346421
# 14 :	 0.11966402979785076
# 11 :	 0.06900500920518823
# 12 :	 0.049683226336740716
# [(749927.7874, 7), (415309.37299999996, 19), (415299.4617, 22)]
# Switches in the controller 0 : [19, 22, 7]
# Switch selected is : 7
# The underloaded domains are : [11, 12]
# The target controller set for 11 is : [18, 20, 2]
# The mean load ratio is : 0.08642348926472156
# The reward is = 0.22992810211157244
# Q value = 17.501802931144507
#
# At time step 4924 the number of switch migrated are : 3
# The migrated switches are [4, 8, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4925
# 0.44677069049631374
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.04911388348269419
# 5 :	 0.09735461735107047
# 14 :	 0.15340032153400568
# 11 :	 0.14052006984267668
# 12 :	 0.04978728768049079
# [(862066.978, 3), (500357.8398, 4), (415309.0475, 21), (410221.5641, 9), (393313.323, 10), (13022.03425, 16)]
# Switches in the controller 14 : [16, 21, 10, 3, 9, 4]
# Switch selected is : 3
# The underloaded domains are : [0, 5, 12]
# The target controller set for 5 is : [17, 6, 1, 8]
# The mean load ratio is : 0.09803523597818756
# The reward is = 1.0925599598773859
# Q value = 17.69887198197697
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.04911388348269419
# 5 :	 0.1483286069630104
# 14 :	 0.10242633192206574
# 11 :	 0.14052006984267668
# 12 :	 0.04978728768049079
# [(500357.8398, 4), (415309.0475, 21), (410221.5641, 9), (393313.323, 10), (13022.03425, 16)]
# Switches in the controller 14 : [16, 21, 10, 9, 4]
# Switch selected is : 4
# The underloaded domains are : [0, 12]
# The target controller set for 0 is : [19, 22]
# The mean load ratio is : 0.09803523597818756
# The reward is = 2.8734264263717724
# Q value = 21.05730735923066
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0787000246748672
# 5 :	 0.1483286069630104
# 14 :	 0.07284019072989273
# 11 :	 0.14052006984267668
# 12 :	 0.04978728768049079
# [(862066.978, 3), (664154.6097, 1), (556678.4457, 8), (415307.0, 6), (10311.42727, 17)]
# Switches in the controller 5 : [17, 6, 1, 8, 3]
# Switch selected is : 3
# The underloaded domains are : [0, 14, 12]
# The target controller set for 0 is : [19, 22, 4]
# The mean load ratio is : 0.09803523597818756
# The reward is = 1.7561329508197299
# Q value = 23.12251079188067
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.12967401428680714
# 5 :	 0.09735461735107045
# 14 :	 0.07284019072989273
# 11 :	 0.14052006984267668
# 12 :	 0.04978728768049079
# [(805568.8405, 7), (740269.4240000001, 2), (415316.9404, 18), (415306.0625, 20)]
# Switches in the controller 11 : [18, 20, 2, 7]
# Switch selected is : 7
# The underloaded domains are : [5, 14, 12]
# The target controller set for 14 is : [16, 21, 10, 9]
# The mean load ratio is : 0.09803523597818756
# The reward is = 1.1048842267176653
# Q value = 15.595551755255796
#
# At time step 4925 the number of switch migrated are : 4
# The migrated switches are [3, 4, 3, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4926
# 0.3545970574571431
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08070448586915886
# 5 :	 0.12685785951752548
# 14 :	 0.1469829985101953
# 11 :	 0.08567679686208225
# 12 :	 0.04953454084080672
# [(818289.3496, 7), (666846.0062, 9), (584612.4147, 10), (415301.8718, 21), (712.0237513999999, 16)]
# Switches in the controller 14 : [16, 21, 10, 9, 7]
# Switch selected is : 7
# The underloaded domains are : [0, 11, 12]
# Taking a random action
# The target controller set for 12 is : [15, 13, 23, 24]
# The mean load ratio is : 0.09795133631995372
# The reward is = 48.33540436710786
# Q value = 39.819239033464754
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.08070448586915886
# 5 :	 0.12685785951752548
# 14 :	 0.09859757850159884
# 11 :	 0.08567679686208225
# 12 :	 0.09791996084940319
# [(666846.0062, 9), (584612.4147, 10), (415301.8718, 21), (712.0237513999999, 16)]
# Switches in the controller 14 : [16, 21, 10, 9]
# Switch selected is : 9
# The underloaded domains are : [0, 11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 7]
# The mean load ratio is : 0.09795133631995372
# The reward is = 0.8378469893505467
# Q value = 23.750714656435076
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08070448586915886
# 5 :	 0.12685785951752548
# 14 :	 0.05916699797795601
# 11 :	 0.08567679686208225
# 12 :	 0.13735054137304603
# [(1189723.261, 1), (533771.0647, 8), (415307.0, 6), (6606.016797, 17)]
# Switches in the controller 5 : [17, 6, 1, 8]
# Switch selected is : 1
# The underloaded domains are : [0, 14, 11]
# The target controller set for 0 is : [19, 22, 4, 3]
# The mean load ratio is : 0.09795133631995372
# The reward is = 0.3659038306102209
# Q value = 23.57781099542421
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.15105277978942233
# 5 :	 0.056509565597262015
# 14 :	 0.05916699797795601
# 11 :	 0.08567679686208225
# 12 :	 0.13735054137304603
# [(1189723.261, 1), (509493.4117, 4), (415312.0873, 19), (415306.1465, 22), (24754.49062, 3)]
# Switches in the controller 0 : [19, 22, 4, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 14, 11]
# The target controller set for 14 is : [16, 21, 10]
# The mean load ratio is : 0.09795133631995372
# The reward is = 0.39152987714575715
# Q value = 23.64761272990048
#
# At time step 4926 the number of switch migrated are : 4
# The migrated switches are [7, 9, 1, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4927
# 0.26424338492606164
# The overloaded domains are : [0, 11, 12, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09958222688893181
# 5 :	 0.04507062349970285
# 14 :	 0.09780828327669502
# 11 :	 0.09871869535046382
# 12 :	 0.11615654392859219
# [(838909.9094, 2), (415307.1221, 20), (415303.6009, 18)]
# Switches in the controller 11 : [18, 20, 2]
# Switch selected is : 2
# The underloaded domains are : [5]
# The target controller set for 5 is : [17, 6, 8]
# The mean load ratio is : 0.09146727458887714
# The reward is = 0.5259915327589573
# Q value = 15.966964753922145
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09958222688893181
# 5 :	 0.09467533647260723
# 14 :	 0.09780828327669502
# 11 :	 0.04911398237755944
# 12 :	 0.11615654392859219
# [(675196.6694, 10), (561548.6814, 1), (415304.2243, 21), (2074.260009, 16)]
# Switches in the controller 14 : [16, 21, 10, 1]
# Switch selected is : 10
# The underloaded domains are : [11]
# Taking a random action
# The target controller set for 11 is : [18, 20]
# The mean load ratio is : 0.09146727458887714
# The reward is = 1.571979381167291
# Q value = 18.709744691159823
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09958222688893181
# 5 :	 0.09467533647260723
# 14 :	 0.05788392833636225
# 11 :	 0.08903833731789221
# 12 :	 0.11615654392859219
# [(627300.9442, 7), (501386.2638, 9), (415310.0153, 23), (415309.0772, 24), (3222.005791, 15), (1899.464848, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 7, 9]
# Switch selected is : 7
# The underloaded domains are : [14, 11]
# The target controller set for 11 is : [18, 20, 10]
# The mean load ratio is : 0.09146727458887714
# The reward is = 0.6228133122297091
# Q value = 17.785412398915444
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09958222688893181
# 5 :	 0.09467533647260723
# 14 :	 0.05788392833636225
# 11 :	 0.12613061973821582
# 12 :	 0.07906426150826856
# [(658453.1967, 4), (415306.6073, 22), (415306.5468, 19), (195058.24, 3)]
# Switches in the controller 0 : [19, 22, 4, 3]
# Switch selected is : 4
# The underloaded domains are : [14, 12]
# Taking a random action
# The target controller set for 14 is : [16, 21, 1]
# The mean load ratio is : 0.09146727458887714
# The reward is = 0.3957692739037923
# Q value = 19.671806812005197
#
# At time step 4927 the number of switch migrated are : 4
# The migrated switches are [2, 10, 7, 4]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4928
# 0.2125868888521135
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.0539747912453073
# 5 :	 0.10685623225445756
# 14 :	 0.08387168963014746
# 11 :	 0.09586204006815095
# 12 :	 0.0789138596592197
# [(702042.618, 2), (682272.6819, 8), (415307.0, 6), (7519.536973, 17)]
# Switches in the controller 5 : [17, 6, 8, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 14, 12]
# The target controller set for 0 is : [19, 22, 3]
# The mean load ratio is : 0.0838957225714566
# The reward is = 1.0671531830223198
# Q value = 18.33357516902526
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.095486546167291
# 5 :	 0.06534447733247387
# 14 :	 0.08387168963014746
# 11 :	 0.09586204006815095
# 12 :	 0.0789138596592197
# [(415306.0172, 18), (415297.6061, 20), (415212.2893, 10), (375393.2534, 7)]
# Switches in the controller 11 : [18, 20, 10, 7]
# Switch selected is : 18
# The underloaded domains are : [5, 14, 12]
# The target controller set for 5 is : [17, 6, 8]
# The mean load ratio is : 0.0838957225714566
# The reward is = 1.0835811967546884
# Q value = 14.799876501495072
#
# At time step 4928 the number of switch migrated are : 2
# The migrated switches are [2, 18]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4929
# 0.21454691234070583
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09932515690943902
# 5 :	 0.08087274100718947
# 14 :	 0.1350510007746831
# 11 :	 0.07984139134133522
# 12 :	 0.08583035436578762
# [(431940.19200000004, 3), (417233.7722, 2), (415305.7304, 22), (415297.3546, 19)]
# Switches in the controller 0 : [19, 22, 3, 2]
# Switch selected is : 3
# The underloaded domains are : [5, 11, 12]
# Taking a random action
# The target controller set for 5 is : [17, 6, 8, 18]
# The mean load ratio is : 0.09618412887968689
# The reward is = 1.1045327810376564
# Q value = 14.250923698913974
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.07378454878747087
# 5 :	 0.10641334912915762
# 14 :	 0.1350510007746831
# 11 :	 0.07984139134133522
# 12 :	 0.08583035436578762
# [(1120955.3490000002, 1), (735719.1190000001, 4), (415312.2194, 21), (11982.23479, 16)]
# Switches in the controller 14 : [16, 21, 1, 4]
# Switch selected is : 1
# The underloaded domains are : [0, 11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.09618412887968689
# The reward is = 0.4417090705168506
# Q value = 17.235184512428624
#
# At time step 4929 the number of switch migrated are : 2
# The migrated switches are [3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4930
# 0.3462875676485276
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.07581377399987614
# 5 :	 0.0941491008372186
# 14 :	 0.06341311623846325
# 11 :	 0.08834225886401427
# 12 :	 0.15940675495699122
# [(1131895.966, 1), (722895.8714, 9), (415310.3744, 24), (415309.4774, 23), (5764.988541, 13), (4694.305965, 15)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 14, 11]
# The target controller set for 11 is : [20, 10, 7]
# The mean load ratio is : 0.0962250009793127
# The reward is = 0.5636371613912587
# Q value = 18.244920045456556
#
# At time step 4930 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4931
# 0.34122442568735095
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08681352571119333
# 5 :	 0.07386314858938114
# 14 :	 0.06608440679473994
# 11 :	 0.15405646617920907
# 12 :	 0.08173978822423562
# [(800617.7411, 7), (722554.3835, 1), (666906.6054, 10), (415308.7088, 20)]
# Switches in the controller 11 : [20, 10, 7, 1]
# Switch selected is : 7
# The underloaded domains are : [0, 5, 14, 12]
# The target controller set for 0 is : [19, 22, 2]
# The mean load ratio is : 0.0925114670997518
# The reward is = 0.9754091926656273
# Q value = 19.126045128123103
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.1341540241405001
# 5 :	 0.07386314858938114
# 14 :	 0.06608440679473994
# 11 :	 0.10671596774990232
# 12 :	 0.08173978822423562
# [(722554.3835, 1), (666906.6054, 10), (415308.7088, 20)]
# Switches in the controller 11 : [20, 10, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 14, 12]
# The target controller set for 14 is : [16, 21, 4]
# The mean load ratio is : 0.0925114670997518
# The reward is = 0.550804369054572
# Q value = 15.412772414411936
#
# At time step 4931 the number of switch migrated are : 2
# The migrated switches are [7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4932
# 0.2967684356780183
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1112317965077954
# 5 :	 0.1466570771216198
# 14 :	 0.0861423574256017
# 11 :	 0.05972647212656155
# 12 :	 0.08768258304753158
# [(616918.4549, 2), (433608.6711, 7), (415309.4076, 22), (415304.4052, 19)]
# Switches in the controller 0 : [19, 22, 2, 7]
# Switch selected is : 2
# The underloaded domains are : [14, 11, 12]
# The target controller set for 14 is : [16, 21, 4, 1]
# The mean load ratio is : 0.098288057245822
# The reward is = 0.34361345757845685
# Q value = 16.918959890226027
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.07475343030886805
# 5 :	 0.1466570771216198
# 14 :	 0.12262072362452903
# 11 :	 0.05972647212656155
# 12 :	 0.08768258304753158
# [(998923.8047, 3), (644213.2606, 8), (415310.21, 18), (415307.0, 6), (6495.441056000001, 17)]
# Switches in the controller 5 : [17, 6, 8, 18, 3]
# Switch selected is : 3
# The underloaded domains are : [0, 11, 12]
# Taking a random action
# The target controller set for 12 is : [15, 13, 23, 24, 9]
# The mean load ratio is : 0.098288057245822
# The reward is = 0.6602065985053517
# Q value = 13.190570051639341
#
# At time step 4932 the number of switch migrated are : 2
# The migrated switches are [2, 3]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4933
# 0.3082396266653396
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.0904475379648107
# 5 :	 0.07860191722791832
# 14 :	 0.14251633605468156
# 11 :	 0.05643830403300185
# 12 :	 0.09077900305454427
# [(967864.9672, 1), (519439.8808, 4), (504506.6772, 2), (415309.601, 21), (3100.794305, 16)]
# Switches in the controller 14 : [16, 21, 4, 1, 2]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 11, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.09175661966699135
# The reward is = 0.4148825905182041
# Q value = 16.02260972908388
#
# At time step 4933 the number of switch migrated are : 1
# The migrated switches are [1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4934
# 0.33891375716307354
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.14691533857249447
# 5 :	 0.07775267318590831
# 14 :	 0.07512768234832277
# 11 :	 0.05736479893132898
# 12 :	 0.10972036196148989
# [(926962.4646, 1), (727042.5931, 7), (415306.1948, 19), (415306.1555, 22)]
# Switches in the controller 0 : [19, 22, 7, 1]
# Switch selected is : 1
# The underloaded domains are : [5, 14, 11]
# The target controller set for 11 is : [20, 10]
# The mean load ratio is : 0.09337617099990889
# The reward is = 0.9252164480222362
# Q value = 15.588789995082848
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09210408115627705
# 5 :	 0.07775267318590831
# 14 :	 0.07512768234832277
# 11 :	 0.1121760563475464
# 12 :	 0.10972036196148989
# [(674031.3789, 9), (415313.4615, 24), (415312.4021, 23), (341903.0492, 3), (4931.923898, 13), (4087.494393, 15)]
# Switches in the controller 12 : [15, 13, 23, 24, 9, 3]
# Switch selected is : 9
# The underloaded domains are : [0, 5, 14]
# The target controller set for 5 is : [17, 6, 8, 18]
# The mean load ratio is : 0.09337617099990889
# The reward is = 1.3088983033783752
# Q value = 15.520005482413612
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09210408115627705
# 5 :	 0.1176081245406059
# 14 :	 0.07512768234832277
# 11 :	 0.1121760563475464
# 12 :	 0.06986491060679231
# [(674031.3789, 9), (479065.9269, 8), (415310.1415, 18), (415307.0, 6), (5262.30894, 17)]
# Switches in the controller 5 : [17, 6, 8, 18, 9]
# Switch selected is : 9
# The underloaded domains are : [0, 14, 12]
# The target controller set for 14 is : [16, 21, 4, 2]
# The mean load ratio is : 0.09337617099990889
# The reward is = 1.0353662254612324
# Q value = 15.872590488300439
#
# At time step 4934 the number of switch migrated are : 3
# The migrated switches are [1, 9, 9]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4935
# 0.24841073432429162
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.07441892035775256
# 5 :	 0.08476181284416104
# 14 :	 0.14228742829956315
# 11 :	 0.13607488300858656
# 12 :	 0.10532026703053651
# [(1160819.358, 1), (725151.4599, 10), (415313.8975, 20)]
# Switches in the controller 11 : [20, 10, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 12]
# The target controller set for 0 is : [19, 22, 7]
# The mean load ratio is : 0.10857266230811997
# The reward is = 0.30927588107197734
# Q value = 14.941946733787358
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.1430581275262132
# 5 :	 0.08476181284416104
# 14 :	 0.14228742829956315
# 11 :	 0.06743567584012593
# 12 :	 0.10532026703053651
# [(869540.061, 2), (705277.2708, 4), (415307.1384, 21), (413512.0188, 9), (2714.166607, 16)]
# Switches in the controller 14 : [16, 21, 4, 2, 9]
# Switch selected is : 2
# The underloaded domains are : [5, 11, 12]
# The target controller set for 11 is : [20, 10]
# The mean load ratio is : 0.10857266230811997
# The reward is = 0.9369333292196375
# Q value = 14.519422288048725
#
# At time step 4935 the number of switch migrated are : 2
# The migrated switches are [1, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4936
# 0.1862794183188654
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.10400779598555848
# 5 :	 0.09791535142081512
# 14 :	 0.10871776302556684
# 11 :	 0.06152167431556362
# 12 :	 0.0842201222657327
# [(819590.3292, 8), (415311.2259, 18), (415307.0, 6), (5726.005678, 17)]
# Switches in the controller 5 : [17, 6, 8, 18]
# Switch selected is : 8
# The underloaded domains are : [11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 3]
# The mean load ratio is : 0.09127654140264733
# The reward is = 0.5470883254069001
# Q value = 13.26734743499163
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.10400779598555848
# 5 :	 0.049453004534947935
# 14 :	 0.10871776302556684
# 11 :	 0.06152167431556362
# 12 :	 0.13268246915159987
# [(819590.3292, 8), (583167.4868, 3), (415310.3709, 24), (415303.3806, 23), (7041.025326000001, 15), (3499.9611229999996, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 3, 8]
# Switch selected is : 8
# The underloaded domains are : [5, 11]
# The target controller set for 11 is : [20, 10, 2]
# The mean load ratio is : 0.09127654140264733
# The reward is = 1.5075679651737561
# Q value = 14.675873211339889
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.10400779598555848
# 5 :	 0.049453004534947935
# 14 :	 0.10871776302556684
# 11 :	 0.1099840212014308
# 12 :	 0.0842201222657327
# [(518080.9086, 7), (415303.7217, 22), (415297.8697, 19), (410286.8696, 1)]
# Switches in the controller 0 : [19, 22, 7, 1]
# Switch selected is : 7
# The underloaded domains are : [5, 12]
# Taking a random action
# The target controller set for 5 is : [17, 6, 18]
# The mean load ratio is : 0.09127654140264733
# The reward is = 4.571762394264016
# Q value = 16.143528487114608
#
# Balance the overloaded controller : 14
# ...
# The migrated switches are [22, 7, 4, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4993
# 0.22367168648725558
# The overloaded domains are : [0, 12, 5, 14]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.10011751253322272
# 5 :	 0.11442314803508402
# 14 :	 0.11907624004177901
# 11 :	 0.06873765841115387
# 12 :	 0.14280580819368732
# [(823014.6358, 3), (752579.9598, 4), (415311.4395, 24), (415311.0446, 23), (4961.322212, 13), (3939.042251, 15)]
# Switches in the controller 12 : [15, 13, 23, 24, 3, 4]
# Switch selected is : 3
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [20, 8]
# The mean load ratio is : 0.1090320734429854
# The reward is = 1.2991635240707837
# Q value = 6.709705138038991
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.10011751253322272
# 5 :	 0.11442314803508402
# 14 :	 0.11907624004177901
# 11 :	 0.11740248442394627
# 12 :	 0.09414098218089492
# [(683243.5313, 2), (415307.0, 6), (415305.0095, 18), (415299.4092, 22), (5957.804383, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 12]
# The target controller set for 0 is : [19, 10, 7]
# The mean load ratio is : 0.1090320734429854
# The reward is = 0.6452865400318714
# Q value = 5.1113771746403645
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.1405176781302297
# 5 :	 0.07402298243807706
# 14 :	 0.11907624004177901
# 11 :	 0.11740248442394627
# 12 :	 0.09414098218089492
# [(836930.9198, 7), (683243.5313, 2), (440934.6511, 10), (415311.7168, 19)]
# Switches in the controller 0 : [19, 10, 7, 2]
# Switch selected is : 7
# The underloaded domains are : [5, 12]
# The target controller set for 5 is : [17, 6, 18, 22]
# The mean load ratio is : 0.1090320734429854
# The reward is = 1.3210349101652068
# Q value = 5.352138720766418
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09102998274167423
# 5 :	 0.12351067782663253
# 14 :	 0.11907624004177901
# 11 :	 0.11740248442394627
# 12 :	 0.09414098218089492
# [(1149186.1409999998, 1), (447980.206, 9), (415300.5665, 21), (1338.4642210000002, 16)]
# Switches in the controller 14 : [16, 21, 9, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 4]
# The mean load ratio is : 0.1090320734429854
# The reward is = 0.3202399940875013
# Q value = 5.2341625871061765
#
# At time step 4993 the number of switch migrated are : 4
# The migrated switches are [3, 2, 7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4994
# 0.29142003777739917
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.08386832196512821
# 5 :	 0.11912075114574944
# 14 :	 0.07340841259044874
# 11 :	 0.07619612623569355
# 12 :	 0.1486668799418239
# [(865677.2747, 1), (813881.809, 4), (415317.1748, 24), (415299.2944, 23), (3348.721548, 15), (715.0247674, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 14, 11]
# The target controller set for 11 is : [20, 8, 3]
# The mean load ratio is : 0.10025209837576876
# The reward is = 1.0742072756167063
# Q value = 6.780786078788124
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.08386832196512821
# 5 :	 0.11912075114574944
# 14 :	 0.07340841259044874
# 11 :	 0.12738359256252724
# 12 :	 0.09747941361499021
# [(763216.1657, 7), (415308.5289, 22), (415307.0, 6), (415303.8253, 18), (5422.625128, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 7]
# Switch selected is : 7
# The underloaded domains are : [0, 14, 12]
# The target controller set for 14 is : [16, 21, 9]
# The mean load ratio is : 0.10025209837576876
# The reward is = 0.5402592426331772
# Q value = 5.009383381353812
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.08386832196512821
# 5 :	 0.0739918065336796
# 14 :	 0.11853735720251858
# 11 :	 0.12738359256252724
# 12 :	 0.09747941361499021
# [(865677.2747, 1), (602144.2732, 8), (415305.8196, 20), (271171.1193, 3)]
# Switches in the controller 11 : [20, 8, 3, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 12]
# The target controller set for 5 is : [17, 6, 18, 22]
# The mean load ratio is : 0.10025209837576876
# The reward is = 0.8222232052122599
# Q value = 6.123670039671858
#
# At time step 4994 the number of switch migrated are : 3
# The migrated switches are [1, 7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4995
# 0.12467245476153747
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09015353658040492
# 5 :	 0.10250434692378065
# 14 :	 0.09945283488592135
# 11 :	 0.0843007362363324
# 12 :	 0.07139564696205952
# [(480610.0379, 1), (415311.0366, 18), (415310.4325, 22), (415307.0, 6), (7004.683501, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 1]
# Switch selected is : 1
# The underloaded domains are : [11, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 4]
# The mean load ratio is : 0.08956142031769977
# The reward is = 1.1265196330269913
# Q value = 5.754656684988136
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09015353658040492
# 5 :	 0.07408589255246768
# 14 :	 0.09945283488592135
# 11 :	 0.0843007362363324
# 12 :	 0.09981410133337248
# [(717030.4365, 7), (544737.5638, 9), (415310.7548, 21), (4857.571178, 16)]
# Switches in the controller 14 : [16, 21, 9, 7]
# Switch selected is : 7
# The underloaded domains are : [5, 11]
# The target controller set for 5 is : [17, 6, 18, 22]
# The mean load ratio is : 0.08956142031769977
# The reward is = 0.5840200977229286
# Q value = 5.034230266440765
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09015353658040492
# 5 :	 0.11648387664691905
# 14 :	 0.05705485079146999
# 11 :	 0.0843007362363324
# 12 :	 0.09981410133337248
# [(687182.5244, 2), (422177.7956, 10), (415307.21, 19)]
# Switches in the controller 0 : [19, 10, 2]
# Switch selected is : 2
# The underloaded domains are : [14, 11]
# The target controller set for 11 is : [20, 8, 3]
# The mean load ratio is : 0.08956142031769977
# The reward is = 0.192775615088438
# Q value = 4.639646783305929
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.049520458462114836
# 5 :	 0.11648387664691905
# 14 :	 0.05705485079146999
# 11 :	 0.12493381435462249
# 12 :	 0.09981410133337248
# [(687182.5244, 2), (578967.3645, 8), (431411.3216, 3), (415306.874, 20)]
# Switches in the controller 11 : [20, 8, 3, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 14]
# The target controller set for 14 is : [16, 21, 9]
# The mean load ratio is : 0.08956142031769977
# The reward is = 1.6992795799835883
# Q value = 5.532576375128181
#
# At time step 4995 the number of switch migrated are : 4
# The migrated switches are [1, 7, 2, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4996
# 0.335435681342766
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.05340663371235767
# 5 :	 0.12124542375744918
# 14 :	 0.07701027079760843
# 11 :	 0.10822531716618047
# 12 :	 0.15203040136015344
# [(1054805.5990000002, 3), (415311.5277, 20), (360178.5363, 8)]
# Switches in the controller 11 : [20, 8, 3]
# Switch selected is : 3
# The underloaded domains are : [0, 14]
# The target controller set for 14 is : [16, 21, 9, 2]
# The mean load ratio is : 0.10238360935874984
# The reward is = 0.2829392205930535
# Q value = 4.691843971528371
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.05340663371235767
# 5 :	 0.12124542375744918
# 14 :	 0.13938088818372305
# 11 :	 0.04585469978006585
# 12 :	 0.15203040136015344
# [(1054805.5990000002, 3), (470645.7969, 9), (415303.5336, 21), (413508.2456, 2), (2932.366827, 16)]
# Switches in the controller 14 : [16, 21, 9, 2, 3]
# Switch selected is : 3
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [20, 8]
# The mean load ratio is : 0.10238360935874984
# The reward is = 0.8477394695979867
# Q value = 5.279680230917417
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.05340663371235767
# 5 :	 0.12124542375744918
# 14 :	 0.07701027079760842
# 11 :	 0.10822531716618047
# 12 :	 0.15203040136015344
# [(801127.5991, 7), (415317.6876, 18), (415307.779, 22), (415307.0, 6), (3430.328531, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 7]
# Switch selected is : 7
# The underloaded domains are : [0, 14]
# The target controller set for 0 is : [19, 10]
# The mean load ratio is : 0.10238360935874984
# The reward is = 1.0820062614581045
# Q value = 4.941652889452904
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.10077728002698982
# 5 :	 0.07387477744281702
# 14 :	 0.07701027079760842
# 11 :	 0.10822531716618047
# 12 :	 0.15203040136015344
# [(1045840.577, 1), (684379.1373, 4), (415311.4118, 23), (415305.2532, 24), (8363.147937, 15), (1923.3074170000002, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 4, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 5, 14]
# The target controller set for 5 is : [17, 6, 18, 22]
# The mean load ratio is : 0.10238360935874984
# The reward is = 1.2405445044783
# Q value = 5.305385362713394
#
# At time step 4996 the number of switch migrated are : 4
# The migrated switches are [3, 3, 7, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4997
# 0.16944711715636526
# The overloaded domains are : [0, 11, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09506794445056051
# 5 :	 0.12416178263623792
# 14 :	 0.1116062440504249
# 11 :	 0.10115750655833053
# 12 :	 0.07306057313409407
# [(846951.6744, 1), (415311.7106, 22), (415307.0, 6), (415300.9537, 18), (6940.2231409999995, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 1]
# Switch selected is : 1
# The underloaded domains are : [0, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 4]
# The mean load ratio is : 0.10101081016592958
# The reward is = 0.6700143740467982
# Q value = 5.551801451514345
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.09506794445056051
# 5 :	 0.07408156038617426
# 14 :	 0.1116062440504249
# 11 :	 0.10115750655833053
# 12 :	 0.12314079538415773
# [(706848.5271, 8), (588612.7718, 3), (415304.263, 20)]
# Switches in the controller 11 : [20, 8, 3]
# Switch selected is : 8
# The underloaded domains are : [0, 5]
# The target controller set for 5 is : [17, 6, 18, 22]
# The mean load ratio is : 0.10101081016592958
# The reward is = 0.6201406524808963
# Q value = 5.1533090169933065
#
# Balance the overloaded controller : 14
# Controller	Controller Load Ratio
# 0 :	 0.09506794445056051
# 5 :	 0.11587748854155067
# 14 :	 0.1116062440504249
# 11 :	 0.059361578402954134
# 12 :	 0.12314079538415773
# [(753491.4341, 2), (716052.0439, 9), (415305.3264, 21), (2624.753525, 16)]
# Switches in the controller 14 : [16, 21, 9, 2]
# Switch selected is : 2
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [20, 3]
# The mean load ratio is : 0.10101081016592958
# The reward is = 0.5797378101612706
# Q value = 4.624104565600918
#
# At time step 4997 the number of switch migrated are : 3
# The migrated switches are [1, 8, 2]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4998
# 0.2859776704981157
# The overloaded domains are : [0, 11, 12, 5]
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.09603415976047756
# 5 :	 0.09463335978043179
# 14 :	 0.047220545948634784
# 11 :	 0.05809624345440163
# 12 :	 0.10443562480555252
# [(511232.8337, 4), (415310.9251, 24), (415301.7237, 23), (412022.3846, 1), (9094.362637999999, 15), (3242.537773, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 4, 1]
# Switch selected is : 4
# The underloaded domains are : [14, 11]
# The target controller set for 11 is : [20, 3, 2]
# The mean load ratio is : 0.08008398674989967
# The reward is = 1.6445127905251702
# Q value = 5.86341189296754
#
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.09603415976047756
# 5 :	 0.09463335978043179
# 14 :	 0.047220545948634784
# 11 :	 0.0883254226473743
# 12 :	 0.07420644561257986
# [(415310.6471, 18), (415308.8862, 22), (415307.0, 6), (349550.6168, 8), (4952.698632, 17)]
# Switches in the controller 5 : [17, 6, 18, 22, 8]
# Switch selected is : 18
# The underloaded domains are : [14, 12]
# The target controller set for 12 is : [15, 13, 23, 24, 1]
# The mean load ratio is : 0.08008398674989967
# The reward is = 0.9809072931220291
# Q value = 5.271897951525323
#
# Balance the overloaded controller : 0
# Controller	Controller Load Ratio
# 0 :	 0.09603415976047756
# 5 :	 0.0700760560543129
# 14 :	 0.047220545948634784
# 11 :	 0.0883254226473743
# 12 :	 0.09876374933869875
# [(616775.6388, 7), (592037.5878, 10), (415306.8103, 19)]
# Switches in the controller 0 : [19, 10, 7]
# Switch selected is : 7
# The underloaded domains are : [5, 14]
# The target controller set for 5 is : [17, 6, 22, 8]
# The mean load ratio is : 0.08008398674989967
# The reward is = 0.7071267194281339
# Q value = 4.779328659604083
#
# At time step 4998 the number of switch migrated are : 3
# The migrated switches are [4, 18, 7]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# At time step : 4999
# 0.3032408784457092
# The overloaded domains are : [11, 12, 5, 14]
# Balance the overloaded controller : 5
# Controller	Controller Load Ratio
# 0 :	 0.04786338139211404
# 5 :	 0.1065516514791695
# 14 :	 0.059674194558644145
# 11 :	 0.1096373673925113
# 12 :	 0.09896002094296268
# [(568425.2573, 8), (415309.1085, 22), (415307.0, 6), (397085.7393, 7), (5863.6923799999995, 17)]
# Switches in the controller 5 : [17, 6, 22, 8, 7]
# Switch selected is : 8
# The underloaded domains are : [0, 14]
# The target controller set for 14 is : [16, 21, 9]
# The mean load ratio is : 0.08453732315308034
# The reward is = 1.361760864312757
# Q value = 5.019158157713773
#
# Balance the overloaded controller : 11
# Controller	Controller Load Ratio
# 0 :	 0.04786338139211404
# 5 :	 0.07294068632191872
# 14 :	 0.09328515971589493
# 11 :	 0.1096373673925113
# 12 :	 0.09896002094296268
# [(607577.0761, 3), (597942.6812, 4), (415304.0426, 20), (233352.3143, 2)]
# Switches in the controller 11 : [20, 3, 2, 4]
# Switch selected is : 3
# The underloaded domains are : [0, 5]
# The target controller set for 5 is : [17, 6, 22, 7]
# The mean load ratio is : 0.08453732315308034
# The reward is = 1.038693131235933
# Q value = 4.8987366251795175
#
# Balance the overloaded controller : 12
# Controller	Controller Load Ratio
# 0 :	 0.04786338139211404
# 5 :	 0.10886669712612126
# 14 :	 0.09328515971589493
# 11 :	 0.07371135658830875
# 12 :	 0.09896002094296268
# [(419910.916, 1), (415309.404, 24), (415306.5393, 18), (415305.9206, 23), (6039.488634, 15), (1729.6379789999999, 13)]
# Switches in the controller 12 : [15, 13, 23, 24, 1, 18]
# Switch selected is : 1
# The underloaded domains are : [0, 11]
# The target controller set for 11 is : [20, 2, 4]
# The mean load ratio is : 0.08453732315308034
# The reward is = 1.0105436046138072
# Q value = 5.009160302530698
#
# At time step 4999 the number of switch migrated are : 3
# The migrated switches are [8, 3, 1]
#
# ---------------------------------------------------------------------------------------------------------------------------
#
# [[1.         4.77932866 4.83638479 4.63964678 3.61298129]
#  [4.94165289 1.         5.01915816 5.04006068 5.27189795]
#  [4.98718873 5.03423027 1.         4.62410457 5.23416259]
#  [4.86801353 4.89873663 4.69184397 1.         4.0478076 ]
#  [5.03451089 5.30538536 3.74314531 5.0091603  1.        ]]

# %% [markdown]
# # **Results**

# %%
import matplotlib.pyplot as plt

'''
x = []  # For storing time steps
y = []  # For load balance rate
z = []  # For number of switches
'''

x = []

yrandom = []
yQL = []
yGreedy = []

zrandom = []
zQL = []
zGreedy = []

for i in range(4000, 5000, 100):
    x.append(time_steps_list_rn[i])

    yrandom.append(discrete_coeff_list_rn[i])
    yQL.append(discrete_coeff_list_QL[i])
    yGreedy.append(discrete_coeff_list_gr[i])

plt.plot(x, yrandom, label='Random Selection')
plt.plot(x, yQL, label='Q-Learning')
plt.plot(x, yGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Discrete Coefficient of all controllers')
plt.legend()
plt.show()

x = []

for i in range(4500, 5000, 10):
    x.append(time_steps_list_rn[i])

    zrandom.append(number_of_switches_list_rn[i])
    zQL.append(number_of_switches_list_QL[i])
    zGreedy.append(number_of_switches_list_gr[i])

plt.plot(x, zrandom, label='Random Selection')
plt.plot(x, zQL, label='Q-Learning')
plt.plot(x, zGreedy, label='Greedy Selection')
plt.xlabel('Time steps')
plt.ylabel('Number of switches migrated')
plt.legend()
plt.show()
